# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Kara = pd.read_excel(filepath, sheet_name='Kara-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Kara)
fp.date_time(Kara)
# Out:
#          Extent       Date
# 0    917992.880 1979-01-01
# 1    917992.880 1979-02-01
# 2    917992.880 1979-03-01
# 3    917992.880 1979-04-01
# 4    917992.880 1979-05-01
# ..          ...        ...
# 533  728642.743 2023-06-01
# 534  437024.646 2023-07-01
# 535  202260.789 2023-08-01
# 536   98103.856 2023-09-01
# 537  260413.272 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Kara['Extent'] = scaler.fit_transform(Kara['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 3
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Kara['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((524, 12, 1), (524,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Kara_model_LT3/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.6675 - root_mean_squared_error: 0.8170
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 6s 77ms/step - loss: 0.6692 - root_mean_squared_error: 0.8180 - val_loss: 0.5511 - val_root_mean_squared_error: 0.7423
# Epoch 2/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.6036 - root_mean_squared_error: 0.7769
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 3s 57ms/step - loss: 0.5954 - root_mean_squared_error: 0.7716 - val_loss: 0.4825 - val_root_mean_squared_error: 0.6946
# Epoch 3/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.5389 - root_mean_squared_error: 0.7341
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 3s 57ms/step - loss: 0.5389 - root_mean_squared_error: 0.7341 - val_loss: 0.4320 - val_root_mean_squared_error: 0.6573
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.4870 - root_mean_squared_error: 0.6979
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 4s 68ms/step - loss: 0.4859 - root_mean_squared_error: 0.6971 - val_loss: 0.3822 - val_root_mean_squared_error: 0.6182
# Epoch 5/50
# 42/53 [======================>.......] - ETA: 0s - loss: 0.4282 - root_mean_squared_error: 0.6544
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 3s 60ms/step - loss: 0.4360 - root_mean_squared_error: 0.6603 - val_loss: 0.3325 - val_root_mean_squared_error: 0.5766
# Epoch 6/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.3847 - root_mean_squared_error: 0.6203
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 3s 56ms/step - loss: 0.3832 - root_mean_squared_error: 0.6191 - val_loss: 0.2869 - val_root_mean_squared_error: 0.5357
# Epoch 7/50
# 41/53 [======================>.......] - ETA: 0s - loss: 0.3449 - root_mean_squared_error: 0.5873
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 3s 62ms/step - loss: 0.3337 - root_mean_squared_error: 0.5777 - val_loss: 0.2596 - val_root_mean_squared_error: 0.5095
# Epoch 8/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.2937 - root_mean_squared_error: 0.5419
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 3s 60ms/step - loss: 0.2889 - root_mean_squared_error: 0.5375 - val_loss: 0.2125 - val_root_mean_squared_error: 0.4610
# Epoch 9/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.2484 - root_mean_squared_error: 0.4984
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 3s 60ms/step - loss: 0.2478 - root_mean_squared_error: 0.4978 - val_loss: 0.2066 - val_root_mean_squared_error: 0.4546
# Epoch 10/50
# 41/53 [======================>.......] - ETA: 0s - loss: 0.2100 - root_mean_squared_error: 0.4583
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 3s 56ms/step - loss: 0.2089 - root_mean_squared_error: 0.4571 - val_loss: 0.1684 - val_root_mean_squared_error: 0.4104
# Epoch 11/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.1697 - root_mean_squared_error: 0.4119
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 3s 58ms/step - loss: 0.1695 - root_mean_squared_error: 0.4117 - val_loss: 0.1262 - val_root_mean_squared_error: 0.3553
# Epoch 12/50
# 43/53 [=======================>......] - ETA: 0s - loss: 0.1471 - root_mean_squared_error: 0.3835
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 3s 63ms/step - loss: 0.1428 - root_mean_squared_error: 0.3779 - val_loss: 0.1035 - val_root_mean_squared_error: 0.3216
# Epoch 13/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1181 - root_mean_squared_error: 0.3436
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 3s 65ms/step - loss: 0.1166 - root_mean_squared_error: 0.3415 - val_loss: 0.0773 - val_root_mean_squared_error: 0.2781
# Epoch 14/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0976 - root_mean_squared_error: 0.3125
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0944 - root_mean_squared_error: 0.3072 - val_loss: 0.0676 - val_root_mean_squared_error: 0.2599
# Epoch 15/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0758 - root_mean_squared_error: 0.2752
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0750 - root_mean_squared_error: 0.2738 - val_loss: 0.0295 - val_root_mean_squared_error: 0.1716
# Epoch 16/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0634 - root_mean_squared_error: 0.2519 - val_loss: 0.0394 - val_root_mean_squared_error: 0.1985
# Epoch 17/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0519 - root_mean_squared_error: 0.2279
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0531 - root_mean_squared_error: 0.2304 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1523
# Epoch 18/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0439 - root_mean_squared_error: 0.2095
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0447 - root_mean_squared_error: 0.2114 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1459
# Epoch 19/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0386 - root_mean_squared_error: 0.1965 - val_loss: 0.0279 - val_root_mean_squared_error: 0.1671
# Epoch 20/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0336 - root_mean_squared_error: 0.1833
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0334 - root_mean_squared_error: 0.1827 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1446
# Epoch 21/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0301 - root_mean_squared_error: 0.1736
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0306 - root_mean_squared_error: 0.1750 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1418
# Epoch 22/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0259 - root_mean_squared_error: 0.1609 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1833
# Epoch 23/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0291 - root_mean_squared_error: 0.1705
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0293 - root_mean_squared_error: 0.1711 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1416
# Epoch 24/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0244 - root_mean_squared_error: 0.1562
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0238 - root_mean_squared_error: 0.1542 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1401
# Epoch 25/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0272 - root_mean_squared_error: 0.1648 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1547
# Epoch 26/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0281 - root_mean_squared_error: 0.1677 - val_loss: 0.0284 - val_root_mean_squared_error: 0.1686
# Epoch 27/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0270 - root_mean_squared_error: 0.1644
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0273 - root_mean_squared_error: 0.1651 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1334
# Epoch 28/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0216 - root_mean_squared_error: 0.1470 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1587
# Epoch 29/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0253 - root_mean_squared_error: 0.1589 - val_loss: 0.0382 - val_root_mean_squared_error: 0.1955
# Epoch 30/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0236 - root_mean_squared_error: 0.1536 - val_loss: 0.0296 - val_root_mean_squared_error: 0.1720
# Epoch 31/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0285 - root_mean_squared_error: 0.1690 - val_loss: 0.0393 - val_root_mean_squared_error: 0.1983
# Epoch 32/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0225 - root_mean_squared_error: 0.1501 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1414
# Epoch 33/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0253 - root_mean_squared_error: 0.1590 - val_loss: 0.0434 - val_root_mean_squared_error: 0.2083
# Epoch 34/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0211 - root_mean_squared_error: 0.1452 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1480
# Epoch 35/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0267 - root_mean_squared_error: 0.1633
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# INFO:tensorflow:Assets written to: Kara_model_LT3\assets
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0263 - root_mean_squared_error: 0.1620 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1286
# Epoch 36/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0194 - root_mean_squared_error: 0.1394 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1693
# Epoch 37/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0215 - root_mean_squared_error: 0.1465 - val_loss: 0.0523 - val_root_mean_squared_error: 0.2287
# Epoch 38/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0233 - root_mean_squared_error: 0.1528 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1369
# Epoch 39/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0197 - root_mean_squared_error: 0.1405 - val_loss: 0.0296 - val_root_mean_squared_error: 0.1722
# Epoch 40/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0223 - root_mean_squared_error: 0.1493 - val_loss: 0.0240 - val_root_mean_squared_error: 0.1550
# Epoch 41/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0214 - root_mean_squared_error: 0.1464 - val_loss: 0.0365 - val_root_mean_squared_error: 0.1909
# Epoch 42/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0220 - root_mean_squared_error: 0.1484 - val_loss: 0.0259 - val_root_mean_squared_error: 0.1608
# Epoch 43/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0243 - root_mean_squared_error: 0.1559 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1485
# Epoch 44/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0228 - root_mean_squared_error: 0.1510 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1391
# Epoch 45/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0234 - root_mean_squared_error: 0.1530 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1478
# Epoch 46/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0248 - root_mean_squared_error: 0.1574 - val_loss: 0.0277 - val_root_mean_squared_error: 0.1664
# Epoch 47/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0246 - root_mean_squared_error: 0.1567 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1330
# Epoch 48/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0230 - root_mean_squared_error: 0.1517 - val_loss: 0.0492 - val_root_mean_squared_error: 0.2217
# Epoch 49/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0187 - root_mean_squared_error: 0.1368 - val_loss: 0.0371 - val_root_mean_squared_error: 0.1926
# Epoch 50/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0223 - root_mean_squared_error: 0.1495 - val_loss: 0.0403 - val_root_mean_squared_error: 0.2007

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.4249314626057943 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Kara_model_LT3/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 15ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.1387711089529255
# MAE : 0.10153134587572367

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       389986.375000     282691.615
# 1        66102.289062      71897.386
# 2          858.619141      60592.380
# 3       262920.312500     131973.043
# 4       602495.812500     753595.099
# 5       766606.812500     909176.475
# 6       926235.750000     917006.278
# 7       918956.437500     906368.363
# 8       874705.562500     917403.622
# 9       940088.437500     910653.838
# 10      779905.125000     822319.125
# 11      660023.250000     557314.102
# 12      296930.843750     197129.525
# 13       56560.339844      75730.217
# 14       60847.078125      59608.479
# 15      414543.593750      88785.283
# 16      674907.937500     396883.400
# 17      882932.250000     662542.207
# 18      912832.437500     871431.414
# 19      898841.625000     917876.960
# 20      934578.187500     917992.880
# 21      937152.687500     912733.060
# 22      826640.437500     910536.463
# 23      572698.437500     760170.733
# 24      209317.656250     383812.645
# 25      -57965.292969     201024.515
# 26      -72426.203125     121904.059
# 27      142414.421875     283554.493
# 28      484854.187500     702176.823
# 29      684429.000000     893690.080
# 30      860012.750000     910117.941
# 31      909205.937500     889204.715
# 32      901229.062500     905311.611
# 33      928006.687500     917930.089
# 34      832406.125000     912089.899
# 35      673622.187500     743951.228
# 36      321608.468750     307180.895
# 37       59089.050781     104402.284
# 38       -5795.671875      73177.670
# 39      304417.843750     127085.610
# 40      661555.250000     650570.950
# 41      795152.875000     789062.385
# 42      926047.562500     897053.619
# 43      892176.812500     904024.315
# 44      873465.250000     911832.551
# 45      934667.375000     917992.880
# 46      809333.125000     894286.938
# 47      672490.937500     728642.743
# 48      304166.875000     437024.646
# 49       17625.046875     202260.789
# 50      -20052.751953      98103.856
# 51      263402.593750     260413.272

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
