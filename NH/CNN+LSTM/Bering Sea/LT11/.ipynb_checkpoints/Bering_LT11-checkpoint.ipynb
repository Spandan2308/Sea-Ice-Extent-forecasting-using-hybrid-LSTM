# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bering = pd.read_excel(filepath, sheet_name='Bering-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Bering)
fp.date_time(Bering)
# Out:
#          Extent       Date
# 0    320266.650 1979-01-01
# 1    541778.338 1979-02-01
# 2    638262.988 1979-03-01
# 3    423025.159 1979-04-01
# 4    215587.216 1979-05-01
# ..          ...        ...
# 488  317377.493 2023-05-01
# 489   39601.476 2023-06-01
# 490   16935.702 2023-07-01
# 491    1305.744 2023-09-01
# 492   12255.644 2023-10-01
#
# [493 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bering['Extent'] = scaler.fit_transform(Bering['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 11
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]  # Adjusted for lead time
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bering['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((471, 12, 1), (471,))

# %%
X_train, y_train = X[:384], y[:384]
X_val, y_val = X[384:432], y[384:432]
X_test, y_test = X[432:], y[432:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Bering_model_LT11/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 33/48 [===================>..........] - ETA: 0s - loss: 0.2127 - root_mean_squared_error: 0.4611
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 6s 83ms/step - loss: 0.2014 - root_mean_squared_error: 0.4488 - val_loss: 0.0655 - val_root_mean_squared_error: 0.2560
# Epoch 2/50
# 48/48 [==============================] - ETA: 0s - loss: 0.1172 - root_mean_squared_error: 0.3424
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 3s 57ms/step - loss: 0.1172 - root_mean_squared_error: 0.3424 - val_loss: 0.0556 - val_root_mean_squared_error: 0.2359
# Epoch 3/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0750 - root_mean_squared_error: 0.2739
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 3s 60ms/step - loss: 0.0750 - root_mean_squared_error: 0.2739 - val_loss: 0.0466 - val_root_mean_squared_error: 0.2160
# Epoch 4/50
# 44/48 [==========================>...] - ETA: 0s - loss: 0.0522 - root_mean_squared_error: 0.2285
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 3s 73ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2019
# Epoch 5/50
# 44/48 [==========================>...] - ETA: 0s - loss: 0.0434 - root_mean_squared_error: 0.2084
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 3s 61ms/step - loss: 0.0413 - root_mean_squared_error: 0.2033 - val_loss: 0.0374 - val_root_mean_squared_error: 0.1934
# Epoch 6/50
# 46/48 [===========================>..] - ETA: 0s - loss: 0.0347 - root_mean_squared_error: 0.1862
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 3s 67ms/step - loss: 0.0341 - root_mean_squared_error: 0.1847 - val_loss: 0.0359 - val_root_mean_squared_error: 0.1895
# Epoch 7/50
# 35/48 [====================>.........] - ETA: 0s - loss: 0.0227 - root_mean_squared_error: 0.1506
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 3s 69ms/step - loss: 0.0261 - root_mean_squared_error: 0.1617 - val_loss: 0.0356 - val_root_mean_squared_error: 0.1888
# Epoch 8/50
# 43/48 [=========================>....] - ETA: 0s - loss: 0.0234 - root_mean_squared_error: 0.1530
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 3s 68ms/step - loss: 0.0247 - root_mean_squared_error: 0.1572 - val_loss: 0.0352 - val_root_mean_squared_error: 0.1876
# Epoch 9/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0223 - root_mean_squared_error: 0.1495
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 3s 53ms/step - loss: 0.0223 - root_mean_squared_error: 0.1495 - val_loss: 0.0347 - val_root_mean_squared_error: 0.1864
# Epoch 10/50
# 46/48 [===========================>..] - ETA: 0s - loss: 0.0207 - root_mean_squared_error: 0.1440
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 3s 67ms/step - loss: 0.0204 - root_mean_squared_error: 0.1429 - val_loss: 0.0343 - val_root_mean_squared_error: 0.1851
# Epoch 11/50
# 46/48 [===========================>..] - ETA: 0s - loss: 0.0204 - root_mean_squared_error: 0.1429
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 3s 58ms/step - loss: 0.0201 - root_mean_squared_error: 0.1417 - val_loss: 0.0318 - val_root_mean_squared_error: 0.1783
# Epoch 12/50
# 38/48 [======================>.......] - ETA: 0s - loss: 0.0183 - root_mean_squared_error: 0.1353
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 3s 63ms/step - loss: 0.0209 - root_mean_squared_error: 0.1445 - val_loss: 0.0301 - val_root_mean_squared_error: 0.1735
# Epoch 13/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0187 - root_mean_squared_error: 0.1367 - val_loss: 0.0302 - val_root_mean_squared_error: 0.1737
# Epoch 14/50
# 43/48 [=========================>....] - ETA: 0s - loss: 0.0192 - root_mean_squared_error: 0.1387
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 3s 57ms/step - loss: 0.0203 - root_mean_squared_error: 0.1425 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1700
# Epoch 15/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0193 - root_mean_squared_error: 0.1390 - val_loss: 0.0304 - val_root_mean_squared_error: 0.1743
# Epoch 16/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0211 - root_mean_squared_error: 0.1452 - val_loss: 0.0318 - val_root_mean_squared_error: 0.1784
# Epoch 17/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0153 - root_mean_squared_error: 0.1235 - val_loss: 0.0386 - val_root_mean_squared_error: 0.1965
# Epoch 18/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0214 - root_mean_squared_error: 0.1462 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1855
# Epoch 19/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0165 - root_mean_squared_error: 0.1284 - val_loss: 0.0379 - val_root_mean_squared_error: 0.1946
# Epoch 20/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0181 - root_mean_squared_error: 0.1346 - val_loss: 0.0434 - val_root_mean_squared_error: 0.2084
# Epoch 21/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0182 - root_mean_squared_error: 0.1350 - val_loss: 0.0363 - val_root_mean_squared_error: 0.1905
# Epoch 22/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0165 - root_mean_squared_error: 0.1286 - val_loss: 0.0385 - val_root_mean_squared_error: 0.1963
# Epoch 23/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0202 - root_mean_squared_error: 0.1421 - val_loss: 0.0354 - val_root_mean_squared_error: 0.1880
# Epoch 24/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0177 - root_mean_squared_error: 0.1330 - val_loss: 0.0391 - val_root_mean_squared_error: 0.1976
# Epoch 25/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331 - val_loss: 0.0398 - val_root_mean_squared_error: 0.1994
# Epoch 26/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0183 - root_mean_squared_error: 0.1353 - val_loss: 0.0340 - val_root_mean_squared_error: 0.1845
# Epoch 27/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0173 - root_mean_squared_error: 0.1317 - val_loss: 0.0419 - val_root_mean_squared_error: 0.2048
# Epoch 28/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0184 - root_mean_squared_error: 0.1358 - val_loss: 0.0461 - val_root_mean_squared_error: 0.2148
# Epoch 29/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0169 - root_mean_squared_error: 0.1301 - val_loss: 0.0401 - val_root_mean_squared_error: 0.2002
# Epoch 30/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0192 - root_mean_squared_error: 0.1387 - val_loss: 0.0382 - val_root_mean_squared_error: 0.1953
# Epoch 31/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0190 - root_mean_squared_error: 0.1377 - val_loss: 0.0361 - val_root_mean_squared_error: 0.1899
# Epoch 32/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0175 - root_mean_squared_error: 0.1323 - val_loss: 0.0372 - val_root_mean_squared_error: 0.1930
# Epoch 33/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0179 - root_mean_squared_error: 0.1337 - val_loss: 0.0432 - val_root_mean_squared_error: 0.2079
# Epoch 34/50
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0155 - root_mean_squared_error: 0.1244 - val_loss: 0.0353 - val_root_mean_squared_error: 0.1878
# Epoch 35/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0178 - root_mean_squared_error: 0.1336 - val_loss: 0.0372 - val_root_mean_squared_error: 0.1929
# Epoch 36/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0166 - root_mean_squared_error: 0.1287 - val_loss: 0.0407 - val_root_mean_squared_error: 0.2018
# Epoch 37/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0217 - root_mean_squared_error: 0.1471 - val_loss: 0.0403 - val_root_mean_squared_error: 0.2007
# Epoch 38/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0145 - root_mean_squared_error: 0.1206 - val_loss: 0.0370 - val_root_mean_squared_error: 0.1923
# Epoch 39/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0146 - root_mean_squared_error: 0.1208 - val_loss: 0.0372 - val_root_mean_squared_error: 0.1929
# Epoch 40/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0167 - root_mean_squared_error: 0.1294 - val_loss: 0.0374 - val_root_mean_squared_error: 0.1935
# Epoch 41/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0171 - root_mean_squared_error: 0.1307 - val_loss: 0.0455 - val_root_mean_squared_error: 0.2133
# Epoch 42/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2015
# Epoch 43/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0164 - root_mean_squared_error: 0.1279 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1838
# Epoch 44/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0152 - root_mean_squared_error: 0.1234 - val_loss: 0.0376 - val_root_mean_squared_error: 0.1939
# Epoch 45/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0175 - root_mean_squared_error: 0.1325 - val_loss: 0.0329 - val_root_mean_squared_error: 0.1815
# Epoch 46/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0184 - root_mean_squared_error: 0.1355 - val_loss: 0.0395 - val_root_mean_squared_error: 0.1987
# Epoch 47/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.0373 - val_root_mean_squared_error: 0.1932
# Epoch 48/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211 - val_loss: 0.0425 - val_root_mean_squared_error: 0.2062
# Epoch 49/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0161 - root_mean_squared_error: 0.1271 - val_loss: 0.0396 - val_root_mean_squared_error: 0.1989
# Epoch 50/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0156 - root_mean_squared_error: 0.1247 - val_loss: 0.0376 - val_root_mean_squared_error: 0.1939

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 0.8446332693099976 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bering_model_LT11/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 16ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.11842389368894964
# MAE : 0.10180107443713036

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       354512.156250     414216.785
# 1       241030.593750     236263.303
# 2       205398.109375      43422.368
# 3       164675.687500       2161.744
# 4       193250.015625        944.181
# 5       187128.687500      13977.643
# 6       258888.562500      24795.001
# 7       316622.031250     168828.990
# 8       479956.281250     461098.498
# 9       586815.125000     591635.798
# 10      627220.375000     598360.298
# 11      463793.687500     531742.038
# 12      299990.562500     302131.004
# 13      150286.656250      57748.135
# 14      138637.781250       3054.962
# 15      102737.742188        442.539
# 16      151108.234375       8541.643
# 17      171688.812500     121335.125
# 18      274340.125000     360205.990
# 19      431517.062500     651717.220
# 20      541874.875000     779385.402
# 21      550023.625000     710314.085
# 22      485377.718750     578635.421
# 23      361972.750000     199031.792
# 24      186096.046875      43795.314
# 25      139368.156250       3015.211
# 26      115251.125000       1206.623
# 27      142171.156250       8506.979
# 28      219954.359375      41065.748
# 29      342990.312500     169363.165
# 30      490333.031250     531698.544
# 31      559318.187500     631496.345
# 32      568578.625000     612860.407
# 33      433742.281250     552903.799
# 34      275106.468750     317377.493
# 35       93499.023438      39601.476
# 36       73859.875000      16935.702
# 37       66568.039062       1305.744
# 38      105931.593750      12255.644

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 15/15 [==============================] - 0s 3ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
