# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bell_Amundsen_Extent = pd.read_excel(filepath, sheet_name='Bell-Amundsen-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Bell_Amundsen_Extent)
fp.date_time(Bell_Amundsen_Extent)
# Out:
#           Extent       Date
# 0    1179855.894 1979-01-01
# 1     879585.254 1979-02-01
# 2     791619.096 1979-03-01
# 3    1254912.071 1979-04-01
# 4    1620142.247 1979-05-01
# ..           ...        ...
# 533  1556568.455 2023-06-01
# 534  1917507.979 2023-07-01
# 535  2601630.327 2023-08-01
# 536  2534223.780 2023-09-01
# 537  2373004.525 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bell_Amundsen_Extent['Extent'] = scaler.fit_transform(Bell_Amundsen_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 8
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bell_Amundsen_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((519, 12, 1), (519,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Bell_Amund_model_LT8/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.2397 - root_mean_squared_error: 0.4896
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 8s 103ms/step - loss: 0.2365 - root_mean_squared_error: 0.4863 - val_loss: 0.2362 - val_root_mean_squared_error: 0.4861
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1854 - root_mean_squared_error: 0.4306
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.1854 - root_mean_squared_error: 0.4306 - val_loss: 0.2147 - val_root_mean_squared_error: 0.4633
# Epoch 3/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.1546 - root_mean_squared_error: 0.3932
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.1520 - root_mean_squared_error: 0.3899 - val_loss: 0.1809 - val_root_mean_squared_error: 0.4254
# Epoch 4/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1268 - root_mean_squared_error: 0.3561
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 4s 76ms/step - loss: 0.1243 - root_mean_squared_error: 0.3525 - val_loss: 0.1635 - val_root_mean_squared_error: 0.4043
# Epoch 5/50
# 40/53 [=====================>........] - ETA: 0s - loss: 0.1055 - root_mean_squared_error: 0.3249
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0977 - root_mean_squared_error: 0.3125 - val_loss: 0.1394 - val_root_mean_squared_error: 0.3733
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0769 - root_mean_squared_error: 0.2774
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 4s 75ms/step - loss: 0.0769 - root_mean_squared_error: 0.2774 - val_loss: 0.1115 - val_root_mean_squared_error: 0.3339
# Epoch 7/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0619 - root_mean_squared_error: 0.2489
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0586 - root_mean_squared_error: 0.2421 - val_loss: 0.0910 - val_root_mean_squared_error: 0.3017
# Epoch 8/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0458 - root_mean_squared_error: 0.2139
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0457 - root_mean_squared_error: 0.2137 - val_loss: 0.0764 - val_root_mean_squared_error: 0.2764
# Epoch 9/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0361 - root_mean_squared_error: 0.1900
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0362 - root_mean_squared_error: 0.1902 - val_loss: 0.0530 - val_root_mean_squared_error: 0.2303
# Epoch 10/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0276 - root_mean_squared_error: 0.1660
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0285 - root_mean_squared_error: 0.1689 - val_loss: 0.0489 - val_root_mean_squared_error: 0.2212
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0240 - root_mean_squared_error: 0.1550
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 4s 80ms/step - loss: 0.0240 - root_mean_squared_error: 0.1550 - val_loss: 0.0435 - val_root_mean_squared_error: 0.2085
# Epoch 12/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0183 - root_mean_squared_error: 0.1353
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0178 - root_mean_squared_error: 0.1333 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1450
# Epoch 13/50
# 43/53 [=======================>......] - ETA: 0s - loss: 0.0153 - root_mean_squared_error: 0.1236
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0155 - root_mean_squared_error: 0.1244 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1447
# Epoch 14/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0123 - root_mean_squared_error: 0.1108
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0124 - root_mean_squared_error: 0.1113 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1207
# Epoch 15/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0171 - root_mean_squared_error: 0.1306 - val_loss: 0.0191 - val_root_mean_squared_error: 0.1383
# Epoch 16/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1231
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0156 - root_mean_squared_error: 0.1251 - val_loss: 0.0195 - val_root_mean_squared_error: 0.1396
# Epoch 18/50
# 43/53 [=======================>......] - ETA: 0s - loss: 0.0158 - root_mean_squared_error: 0.1258
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0146 - root_mean_squared_error: 0.1207 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1158
# Epoch 19/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0109 - root_mean_squared_error: 0.1046 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1177
# Epoch 20/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1194
# Epoch 21/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0127 - root_mean_squared_error: 0.1127 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1416
# Epoch 22/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0113 - root_mean_squared_error: 0.1064 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1393
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0132 - root_mean_squared_error: 0.1147 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1218
# Epoch 24/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0115 - root_mean_squared_error: 0.1071
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1143
# Epoch 25/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0122 - root_mean_squared_error: 0.1103
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0119 - root_mean_squared_error: 0.1092 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1123
# Epoch 26/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0130 - root_mean_squared_error: 0.1141
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0130 - root_mean_squared_error: 0.1140 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1123
# Epoch 27/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 28/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0125 - root_mean_squared_error: 0.1118 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1152
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0120 - root_mean_squared_error: 0.1093 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 30/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0114 - root_mean_squared_error: 0.1070
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0115 - root_mean_squared_error: 0.1073 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1099
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0124 - root_mean_squared_error: 0.1113 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1175
# Epoch 32/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0099 - root_mean_squared_error: 0.0993 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2032
# Epoch 33/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0126 - root_mean_squared_error: 0.1121 - val_loss: 0.0226 - val_root_mean_squared_error: 0.1503
# Epoch 34/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0126 - root_mean_squared_error: 0.1122
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0127 - root_mean_squared_error: 0.1126 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1079
# Epoch 35/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0125 - root_mean_squared_error: 0.1117 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1141
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1152
# Epoch 37/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0126 - root_mean_squared_error: 0.1124 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1108
# Epoch 38/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0277 - val_root_mean_squared_error: 0.1664
# Epoch 39/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1282
# Epoch 40/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0132 - root_mean_squared_error: 0.1151 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1132
# Epoch 41/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0128 - root_mean_squared_error: 0.1129
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT8\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0125 - root_mean_squared_error: 0.1118 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1075
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0091 - root_mean_squared_error: 0.0955 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1314
# Epoch 43/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0140 - root_mean_squared_error: 0.1181 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1170
# Epoch 44/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1127
# Epoch 45/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0126 - root_mean_squared_error: 0.1120 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1100
# Epoch 46/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0125 - root_mean_squared_error: 0.1120 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1369
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0120 - root_mean_squared_error: 0.1095 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1118
# Epoch 48/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0114 - root_mean_squared_error: 0.1066 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1085
# Epoch 49/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0104 - root_mean_squared_error: 0.1019 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1096
# Epoch 50/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0103 - root_mean_squared_error: 0.1015 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1496

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.7964015483856202 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bell_Amund_model_LT8/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 0s/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.08078034016934128
# MAE : 0.06476082330363604

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.396522e+06    1202791.069
# 1        7.406622e+05     752834.272
# 2        5.487367e+05     451914.219
# 3        5.229703e+05     439855.813
# 4        7.951170e+05     807857.307
# 5        1.073594e+06    1184280.145
# 6        1.424091e+06    1468308.405
# 7        1.735606e+06    1540851.607
# 8        2.002260e+06    1989099.836
# 9        1.973650e+06    2096990.761
# 10       1.940973e+06    2080961.032
# 11       1.680224e+06    1695704.661
# 12       1.212171e+06    1533888.370
# 13       7.403161e+05    1038332.675
# 14       5.256749e+05     602954.621
# 15       6.136190e+05     895484.288
# 16       7.120289e+05    1070622.700
# 17       1.139345e+06    1532457.922
# 18       1.412450e+06    1703762.123
# 19       1.905378e+06    1855079.122
# 20       2.097472e+06    2291960.639
# 21       2.087100e+06    2114120.417
# 22       1.994055e+06    1995818.759
# 23       1.604057e+06    1653379.997
# 24       1.222887e+06    1070814.995
# 25       8.823775e+05     689443.815
# 26       7.639379e+05     401148.663
# 27       7.692369e+05     346558.057
# 28       9.559872e+05     599477.678
# 29       1.161208e+06     765764.905
# 30       1.489454e+06    1304133.179
# 31       1.801074e+06    1598436.099
# 32       1.967530e+06    1763844.414
# 33       2.021004e+06    1979139.524
# 34       1.856617e+06    1937348.663
# 35       1.716532e+06    1833093.342
# 36       1.254579e+06    1089676.114
# 37       8.608050e+05     453484.731
# 38       3.756949e+05     251559.554
# 39       3.893843e+05     351294.657
# 40       5.649326e+05     702389.714
# 41       9.705014e+05    1185169.054
# 42       1.386117e+06    1556568.455
# 43       1.895012e+06    1917507.979
# 44       2.083947e+06    2601630.327
# 45       2.149992e+06    2534223.780
# 46       2.148895e+06    2373004.525

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
