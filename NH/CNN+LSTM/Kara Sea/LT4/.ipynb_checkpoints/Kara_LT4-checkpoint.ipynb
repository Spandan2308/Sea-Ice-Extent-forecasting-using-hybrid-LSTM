# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Kara = pd.read_excel(filepath, sheet_name='Kara-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Kara)
fp.date_time(Kara)
# Out:
#          Extent       Date
# 0    917992.880 1979-01-01
# 1    917992.880 1979-02-01
# 2    917992.880 1979-03-01
# 3    917992.880 1979-04-01
# 4    917992.880 1979-05-01
# ..          ...        ...
# 533  728642.743 2023-06-01
# 534  437024.646 2023-07-01
# 535  202260.789 2023-08-01
# 536   98103.856 2023-09-01
# 537  260413.272 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Kara['Extent'] = scaler.fit_transform(Kara['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 4
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Kara['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((523, 12, 1), (523,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Kara_model_LT4/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.6823 - root_mean_squared_error: 0.8260
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 7s 81ms/step - loss: 0.6716 - root_mean_squared_error: 0.8195 - val_loss: 0.5056 - val_root_mean_squared_error: 0.7111
# Epoch 2/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.5937 - root_mean_squared_error: 0.7705
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 50ms/step - loss: 0.5878 - root_mean_squared_error: 0.7667 - val_loss: 0.4345 - val_root_mean_squared_error: 0.6592
# Epoch 3/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.5146 - root_mean_squared_error: 0.7174
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 64ms/step - loss: 0.5174 - root_mean_squared_error: 0.7193 - val_loss: 0.3731 - val_root_mean_squared_error: 0.6108
# Epoch 4/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.4607 - root_mean_squared_error: 0.6788
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 55ms/step - loss: 0.4565 - root_mean_squared_error: 0.6756 - val_loss: 0.3359 - val_root_mean_squared_error: 0.5796
# Epoch 5/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.3939 - root_mean_squared_error: 0.6276
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 55ms/step - loss: 0.3958 - root_mean_squared_error: 0.6291 - val_loss: 0.2995 - val_root_mean_squared_error: 0.5472
# Epoch 6/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.3402 - root_mean_squared_error: 0.5832
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 61ms/step - loss: 0.3435 - root_mean_squared_error: 0.5860 - val_loss: 0.2638 - val_root_mean_squared_error: 0.5136
# Epoch 7/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.3003 - root_mean_squared_error: 0.5480
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.2963 - root_mean_squared_error: 0.5444 - val_loss: 0.2283 - val_root_mean_squared_error: 0.4778
# Epoch 8/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.2581 - root_mean_squared_error: 0.5080
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 48ms/step - loss: 0.2521 - root_mean_squared_error: 0.5021 - val_loss: 0.2050 - val_root_mean_squared_error: 0.4528
# Epoch 9/50
# 42/53 [======================>.......] - ETA: 0s - loss: 0.2078 - root_mean_squared_error: 0.4558
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 60ms/step - loss: 0.2065 - root_mean_squared_error: 0.4544 - val_loss: 0.1584 - val_root_mean_squared_error: 0.3980
# Epoch 10/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.1730 - root_mean_squared_error: 0.4159
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 56ms/step - loss: 0.1719 - root_mean_squared_error: 0.4146 - val_loss: 0.1470 - val_root_mean_squared_error: 0.3835
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1418 - root_mean_squared_error: 0.3766
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 52ms/step - loss: 0.1410 - root_mean_squared_error: 0.3755 - val_loss: 0.1209 - val_root_mean_squared_error: 0.3477
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1142 - root_mean_squared_error: 0.3380
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 66ms/step - loss: 0.1142 - root_mean_squared_error: 0.3380 - val_loss: 0.0884 - val_root_mean_squared_error: 0.2973
# Epoch 13/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0940 - root_mean_squared_error: 0.3067 - val_loss: 0.1000 - val_root_mean_squared_error: 0.3162
# Epoch 14/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0755 - root_mean_squared_error: 0.2747 - val_loss: 0.0967 - val_root_mean_squared_error: 0.3109
# Epoch 15/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0646 - root_mean_squared_error: 0.2542 - val_loss: 0.1035 - val_root_mean_squared_error: 0.3217
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0548 - root_mean_squared_error: 0.2341
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0548 - root_mean_squared_error: 0.2341 - val_loss: 0.0623 - val_root_mean_squared_error: 0.2496
# Epoch 17/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0499 - root_mean_squared_error: 0.2235
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0490 - root_mean_squared_error: 0.2213 - val_loss: 0.0372 - val_root_mean_squared_error: 0.1930
# Epoch 18/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0418 - root_mean_squared_error: 0.2044 - val_loss: 0.0970 - val_root_mean_squared_error: 0.3115
# Epoch 19/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0383 - root_mean_squared_error: 0.1956
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0378 - root_mean_squared_error: 0.1944 - val_loss: 0.0297 - val_root_mean_squared_error: 0.1724
# Epoch 20/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0326 - root_mean_squared_error: 0.1807
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0314 - root_mean_squared_error: 0.1773 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1481
# Epoch 21/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0304 - root_mean_squared_error: 0.1743 - val_loss: 0.0281 - val_root_mean_squared_error: 0.1676
# Epoch 22/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0262 - root_mean_squared_error: 0.1618 - val_loss: 0.0272 - val_root_mean_squared_error: 0.1650
# Epoch 23/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0293 - root_mean_squared_error: 0.1711 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1621
# Epoch 24/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0256 - root_mean_squared_error: 0.1601
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0263 - root_mean_squared_error: 0.1621 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1456
# Epoch 25/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0279 - root_mean_squared_error: 0.1669 - val_loss: 0.0291 - val_root_mean_squared_error: 0.1707
# Epoch 26/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0238 - root_mean_squared_error: 0.1544
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0241 - root_mean_squared_error: 0.1552 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1351
# Epoch 27/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0230 - root_mean_squared_error: 0.1517 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1371
# Epoch 28/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0199 - root_mean_squared_error: 0.1411 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1522
# Epoch 29/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0248 - root_mean_squared_error: 0.1574
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0244 - root_mean_squared_error: 0.1561 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1333
# Epoch 30/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0234 - root_mean_squared_error: 0.1529 - val_loss: 0.0220 - val_root_mean_squared_error: 0.1483
# Epoch 31/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0244 - root_mean_squared_error: 0.1561 - val_loss: 0.0380 - val_root_mean_squared_error: 0.1949
# Epoch 32/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0246 - root_mean_squared_error: 0.1568 - val_loss: 0.0223 - val_root_mean_squared_error: 0.1493
# Epoch 33/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0244 - root_mean_squared_error: 0.1562
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0246 - root_mean_squared_error: 0.1570 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1313
# Epoch 34/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0229 - root_mean_squared_error: 0.1513 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1350
# Epoch 35/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0235 - root_mean_squared_error: 0.1532 - val_loss: 0.0378 - val_root_mean_squared_error: 0.1945
# Epoch 36/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0248 - root_mean_squared_error: 0.1575 - val_loss: 0.0549 - val_root_mean_squared_error: 0.2343
# Epoch 37/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0261 - root_mean_squared_error: 0.1615 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1622
# Epoch 38/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0222 - root_mean_squared_error: 0.1489 - val_loss: 0.0285 - val_root_mean_squared_error: 0.1689
# Epoch 39/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0194 - root_mean_squared_error: 0.1394 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1470
# Epoch 40/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0249 - root_mean_squared_error: 0.1578 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1603
# Epoch 41/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0229 - root_mean_squared_error: 0.1514 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1615
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0235 - root_mean_squared_error: 0.1534 - val_loss: 0.0431 - val_root_mean_squared_error: 0.2077
# Epoch 43/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0233 - root_mean_squared_error: 0.1527 - val_loss: 0.0267 - val_root_mean_squared_error: 0.1635
# Epoch 44/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0217 - root_mean_squared_error: 0.1474 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1326
# Epoch 45/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0234 - root_mean_squared_error: 0.1530 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1356
# Epoch 46/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0199 - root_mean_squared_error: 0.1412
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0199 - root_mean_squared_error: 0.1412 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1308
# Epoch 47/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0244 - root_mean_squared_error: 0.1561
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# INFO:tensorflow:Assets written to: Kara_model_LT4\assets
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0239 - root_mean_squared_error: 0.1546 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1291
# Epoch 48/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0212 - root_mean_squared_error: 0.1456 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1319
# Epoch 49/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0229 - root_mean_squared_error: 0.1514 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1313
# Epoch 50/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0225 - root_mean_squared_error: 0.1499 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1303

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.3325034896532695 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Kara_model_LT4/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 17ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.1342130883221361
# MAE : 0.11148393966261053

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        10658.314453      71897.386
# 1       -12328.879883      60592.380
# 2       190551.046875     131973.043
# 3       611662.875000     753595.099
# 4       727163.437500     909176.475
# 5       817776.687500     917006.278
# 6       838816.562500     906368.363
# 7       871289.437500     917403.622
# 8       834146.625000     910653.838
# 9       801694.000000     822319.125
# 10      591979.687500     557314.102
# 11      342783.812500     197129.525
# 12       -8386.026367      75730.217
# 13       44117.148438      59608.479
# 14      284716.343750      88785.283
# 15      658007.000000     396883.400
# 16      771425.875000     662542.207
# 17      859328.500000     871431.414
# 18      838944.250000     917876.960
# 19      858581.875000     917992.880
# 20      860075.937500     912733.060
# 21      799000.812500     910536.463
# 22      521778.156250     760170.733
# 23      233545.671875     383812.645
# 24       25035.025391     201024.515
# 25       76173.945312     121904.059
# 26      218084.640625     283554.493
# 27      542080.250000     702176.823
# 28      633623.937500     893690.080
# 29      789588.875000     910117.941
# 30      818675.875000     889204.715
# 31      838850.687500     905311.611
# 32      834947.625000     917930.089
# 33      789734.375000     912089.899
# 34      630888.625000     743951.228
# 35      313080.468750     307180.895
# 36       42680.972656     104402.284
# 37       78742.820312      73177.670
# 38      343495.687500     127085.610
# 39      657277.687500     650570.950
# 40      770956.750000     789062.385
# 41      813073.000000     897053.619
# 42      828638.750000     904024.315
# 43      822244.250000     911832.551
# 44      844697.625000     917992.880
# 45      791277.000000     894286.938
# 46      624222.437500     728642.743
# 47      293159.093750     437024.646
# 48        5278.106445     202260.789
# 49       22771.863281      98103.856
# 50      234370.578125     260413.272

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
