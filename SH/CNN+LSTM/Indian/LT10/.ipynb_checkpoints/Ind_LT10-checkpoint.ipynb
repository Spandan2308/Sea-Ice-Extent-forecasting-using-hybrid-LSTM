# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Indian_Extent = pd.read_excel(filepath, sheet_name='Indian-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Indian_Extent)
fp.date_time(Indian_Extent)
# Out:
#           Extent       Date
# 0     376618.799 1979-01-01
# 1     211788.726 1979-02-01
# 2     262868.141 1979-03-01
# 3     698377.304 1979-04-01
# 4    1252407.727 1979-05-01
# ..           ...        ...
# 533  1520776.003 2023-06-01
# 534  2076164.165 2023-07-01
# 535  2731799.027 2023-08-01
# 536  3179384.692 2023-09-01
# 537  3301335.210 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Indian_Extent['Extent'] = scaler.fit_transform(Indian_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 10
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Indian_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((517, 12, 1), (517,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Indian_model_LT10/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.2161 - root_mean_squared_error: 0.4649
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# 53/53 [==============================] - 11s 122ms/step - loss: 0.2117 - root_mean_squared_error: 0.4601 - val_loss: 0.1920 - val_root_mean_squared_error: 0.4382
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1630 - root_mean_squared_error: 0.4037
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# 53/53 [==============================] - 5s 105ms/step - loss: 0.1628 - root_mean_squared_error: 0.4035 - val_loss: 0.1712 - val_root_mean_squared_error: 0.4137
# Epoch 3/50
# 42/53 [======================>.......] - ETA: 0s - loss: 0.1341 - root_mean_squared_error: 0.3662
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# 53/53 [==============================] - 6s 107ms/step - loss: 0.1335 - root_mean_squared_error: 0.3654 - val_loss: 0.1534 - val_root_mean_squared_error: 0.3916
# Epoch 4/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.1057 - root_mean_squared_error: 0.3251
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# 53/53 [==============================] - 5s 102ms/step - loss: 0.1057 - root_mean_squared_error: 0.3252 - val_loss: 0.1342 - val_root_mean_squared_error: 0.3664
# Epoch 5/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0913 - root_mean_squared_error: 0.3022
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# 53/53 [==============================] - 4s 81ms/step - loss: 0.0905 - root_mean_squared_error: 0.3008 - val_loss: 0.1150 - val_root_mean_squared_error: 0.3392
# Epoch 6/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0730 - root_mean_squared_error: 0.2702
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0737 - root_mean_squared_error: 0.2715 - val_loss: 0.0970 - val_root_mean_squared_error: 0.3115
# Epoch 7/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0544 - root_mean_squared_error: 0.2331
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0550 - root_mean_squared_error: 0.2344 - val_loss: 0.0854 - val_root_mean_squared_error: 0.2923
# Epoch 8/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0485 - root_mean_squared_error: 0.2203
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# 53/53 [==============================] - 6s 107ms/step - loss: 0.0462 - root_mean_squared_error: 0.2150 - val_loss: 0.0669 - val_root_mean_squared_error: 0.2587
# Epoch 9/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0308 - root_mean_squared_error: 0.1755
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# 53/53 [==============================] - 6s 113ms/step - loss: 0.0298 - root_mean_squared_error: 0.1727 - val_loss: 0.0530 - val_root_mean_squared_error: 0.2303
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0263 - root_mean_squared_error: 0.1623
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# 53/53 [==============================] - 6s 124ms/step - loss: 0.0263 - root_mean_squared_error: 0.1623 - val_loss: 0.0398 - val_root_mean_squared_error: 0.1995
# Epoch 11/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0245 - root_mean_squared_error: 0.1566
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# 53/53 [==============================] - 5s 103ms/step - loss: 0.0237 - root_mean_squared_error: 0.1540 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1584
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0211 - root_mean_squared_error: 0.1453
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# 53/53 [==============================] - 11s 211ms/step - loss: 0.0211 - root_mean_squared_error: 0.1453 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1351
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0152 - root_mean_squared_error: 0.1232
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# 53/53 [==============================] - 11s 217ms/step - loss: 0.0152 - root_mean_squared_error: 0.1232 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0921
# Epoch 14/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0110 - root_mean_squared_error: 0.1048 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0955
# Epoch 15/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0135 - root_mean_squared_error: 0.1161
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# 53/53 [==============================] - 6s 113ms/step - loss: 0.0137 - root_mean_squared_error: 0.1172 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0615
# Epoch 16/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0152 - root_mean_squared_error: 0.1235
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# 53/53 [==============================] - 7s 125ms/step - loss: 0.0151 - root_mean_squared_error: 0.1228 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0450
# Epoch 17/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0125 - root_mean_squared_error: 0.1119
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# INFO:tensorflow:Assets written to: Indian_model_LT10\assets
# 53/53 [==============================] - 6s 121ms/step - loss: 0.0129 - root_mean_squared_error: 0.1137 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0420
# Epoch 18/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0175 - root_mean_squared_error: 0.1325 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0450
# Epoch 19/50
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0126 - root_mean_squared_error: 0.1124 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0426
# Epoch 20/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0152 - root_mean_squared_error: 0.1235 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 21/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0140 - root_mean_squared_error: 0.1183 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0450
# Epoch 22/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0164 - root_mean_squared_error: 0.1279 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0543
# Epoch 23/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0119 - root_mean_squared_error: 0.1093 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0519
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0111 - root_mean_squared_error: 0.1055 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0428
# Epoch 25/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0206 - root_mean_squared_error: 0.1437 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0514
# Epoch 26/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0444
# Epoch 27/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0125 - root_mean_squared_error: 0.1119 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0593
# Epoch 28/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0132 - root_mean_squared_error: 0.1147 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0882
# Epoch 29/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0171 - root_mean_squared_error: 0.1308 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0628
# Epoch 30/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0157 - root_mean_squared_error: 0.1251 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0692
# Epoch 31/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0120 - root_mean_squared_error: 0.1097 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0682
# Epoch 32/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0162 - root_mean_squared_error: 0.1274 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0778
# Epoch 33/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0151 - root_mean_squared_error: 0.1230 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0498
# Epoch 34/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0103 - root_mean_squared_error: 0.1016 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1050
# Epoch 35/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0200 - root_mean_squared_error: 0.1413 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0582
# Epoch 36/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0145 - root_mean_squared_error: 0.1205 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0432
# Epoch 37/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0139 - root_mean_squared_error: 0.1179 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0783
# Epoch 38/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0106 - root_mean_squared_error: 0.1028 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0510
# Epoch 39/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0694
# Epoch 40/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0137 - root_mean_squared_error: 0.1169 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0426
# Epoch 41/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0141 - root_mean_squared_error: 0.1189 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0905
# Epoch 42/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0191 - root_mean_squared_error: 0.1383 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0457
# Epoch 43/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0114 - root_mean_squared_error: 0.1068 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0532
# Epoch 44/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0093 - root_mean_squared_error: 0.0963 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0565
# Epoch 45/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0764
# Epoch 46/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0169 - root_mean_squared_error: 0.1300 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0851
# Epoch 47/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0551
# Epoch 48/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0525
# Epoch 49/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0177 - root_mean_squared_error: 0.1332 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0785
# Epoch 50/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0514

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 2.015463634332021 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Indian_model_LT10/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 13ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.04586206165375245
# MAE : 0.03794240759248228

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.273580e+05     346601.304
# 1        1.757099e+05     444914.605
# 2        5.748940e+05     827036.916
# 3        1.070288e+06    1142021.216
# 4        1.696588e+06    1885693.654
# 5        2.502930e+06    2542569.663
# 6        2.997220e+06    3107373.845
# 7        3.337734e+06    3488175.444
# 8        3.339372e+06    3746306.528
# 9        2.617026e+06    2942322.822
# 10       1.268419e+06    1507212.955
# 11       5.193764e+05     648507.437
# 12       2.468175e+05     352564.010
# 13       4.769607e+05     453587.503
# 14       6.424664e+05     841043.793
# 15       1.301220e+06    1433155.266
# 16       1.934038e+06    2163687.646
# 17       2.674348e+06    2848863.133
# 18       3.179025e+06    3420877.229
# 19       3.517273e+06    3752886.938
# 20       3.530909e+06    3778951.818
# 21       2.817399e+06    2892177.223
# 22       1.498876e+06    1467610.428
# 23       5.491508e+05     377930.941
# 24       2.809199e+05     146440.376
# 25       4.038078e+05     244356.473
# 26       7.427457e+05     612217.566
# 27       1.345605e+06    1261627.075
# 28       2.090102e+06    1720565.225
# 29       2.622303e+06    2564005.541
# 30       3.214225e+06    2983773.529
# 31       3.427498e+06    3372645.223
# 32       3.486170e+06    3589687.043
# 33       2.823180e+06    2669385.189
# 34       1.194965e+06    1095398.946
# 35       3.314559e+05     319828.826
# 36       1.379334e+05     162541.182
# 37       1.697892e+05     179564.232
# 38       6.070791e+05     593196.107
# 39       1.101384e+06    1053508.835
# 40       1.850698e+06    1520776.003
# 41       2.375202e+06    2076164.165
# 42       3.119172e+06    2731799.027
# 43       3.191398e+06    3179384.692
# 44       3.451318e+06    3301335.210

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
