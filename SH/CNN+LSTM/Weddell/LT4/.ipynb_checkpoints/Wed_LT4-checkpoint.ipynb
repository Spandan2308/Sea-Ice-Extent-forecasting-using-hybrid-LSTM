# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Weddell_Extent = pd.read_excel(filepath, sheet_name='Weddell-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Weddell_Extent)
fp.date_time(Weddell_Extent)
# Out:
#           Extent       Date
# 0    2136510.859 1979-01-01
# 1    1243495.891 1979-02-01
# 2    1699053.449 1979-03-01
# 3    2617442.085 1979-04-01
# 4    3852934.206 1979-05-01
# ..           ...        ...
# 533  3668127.143 2023-06-01
# 534  4805519.784 2023-07-01
# 535  5524445.234 2023-08-01
# 536  6006669.861 2023-09-01
# 537  5507961.583 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Weddell_Extent['Extent'] = scaler.fit_transform(Weddell_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 4
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Weddell_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((523, 12, 1), (523,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Weddell_model_LT4/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.2813 - root_mean_squared_error: 0.5304
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 8s 103ms/step - loss: 0.2757 - root_mean_squared_error: 0.5251 - val_loss: 0.3077 - val_root_mean_squared_error: 0.5547
# Epoch 2/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.2193 - root_mean_squared_error: 0.4683
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.2211 - root_mean_squared_error: 0.4702 - val_loss: 0.2485 - val_root_mean_squared_error: 0.4985
# Epoch 3/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.1838 - root_mean_squared_error: 0.4288
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 4s 80ms/step - loss: 0.1809 - root_mean_squared_error: 0.4254 - val_loss: 0.2066 - val_root_mean_squared_error: 0.4545
# Epoch 4/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.1577 - root_mean_squared_error: 0.3971
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.1513 - root_mean_squared_error: 0.3890 - val_loss: 0.1670 - val_root_mean_squared_error: 0.4087
# Epoch 5/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.1213 - root_mean_squared_error: 0.3483
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.1218 - root_mean_squared_error: 0.3491 - val_loss: 0.1373 - val_root_mean_squared_error: 0.3706
# Epoch 6/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0942 - root_mean_squared_error: 0.3069
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0977 - root_mean_squared_error: 0.3126 - val_loss: 0.1036 - val_root_mean_squared_error: 0.3219
# Epoch 7/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0764 - root_mean_squared_error: 0.2764
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0741 - root_mean_squared_error: 0.2723 - val_loss: 0.0815 - val_root_mean_squared_error: 0.2855
# Epoch 8/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0656 - root_mean_squared_error: 0.2560
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.0640 - root_mean_squared_error: 0.2531 - val_loss: 0.0645 - val_root_mean_squared_error: 0.2540
# Epoch 9/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0478 - root_mean_squared_error: 0.2187
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0472 - root_mean_squared_error: 0.2174 - val_loss: 0.0489 - val_root_mean_squared_error: 0.2211
# Epoch 10/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0350 - root_mean_squared_error: 0.1870
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0371 - root_mean_squared_error: 0.1925 - val_loss: 0.0384 - val_root_mean_squared_error: 0.1960
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0268 - root_mean_squared_error: 0.1638
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.0268 - root_mean_squared_error: 0.1638 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1537
# Epoch 12/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0262 - root_mean_squared_error: 0.1620
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0260 - root_mean_squared_error: 0.1613 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1238
# Epoch 13/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0195 - root_mean_squared_error: 0.1395
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0200 - root_mean_squared_error: 0.1413 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1056
# Epoch 14/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0148 - root_mean_squared_error: 0.1218
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0165 - root_mean_squared_error: 0.1285 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0976
# Epoch 15/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0142 - root_mean_squared_error: 0.1192
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0146 - root_mean_squared_error: 0.1209 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0806
# Epoch 16/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0124 - root_mean_squared_error: 0.1116
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0699
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0168 - root_mean_squared_error: 0.1298 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0701
# Epoch 18/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0122 - root_mean_squared_error: 0.1106 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0736
# Epoch 19/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0185 - root_mean_squared_error: 0.1361 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0943
# Epoch 20/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0784
# Epoch 21/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0149 - root_mean_squared_error: 0.1220
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0146 - root_mean_squared_error: 0.1207 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0658
# Epoch 22/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0112 - root_mean_squared_error: 0.1057 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0702
# Epoch 23/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0135 - root_mean_squared_error: 0.1162 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0970
# Epoch 24/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0103 - root_mean_squared_error: 0.1016 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0741
# Epoch 25/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0123 - root_mean_squared_error: 0.1111
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0126 - root_mean_squared_error: 0.1123 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0643
# Epoch 26/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0163 - root_mean_squared_error: 0.1278 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0849
# Epoch 27/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0148 - root_mean_squared_error: 0.1215 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0721
# Epoch 28/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0103 - root_mean_squared_error: 0.1015 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0762
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0124 - root_mean_squared_error: 0.1114 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1028
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0172 - root_mean_squared_error: 0.1313 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0954
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0148 - root_mean_squared_error: 0.1218 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1119
# Epoch 32/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0975
# Epoch 33/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0144 - root_mean_squared_error: 0.1202 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0669
# Epoch 34/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0151 - root_mean_squared_error: 0.1229
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT4\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0147 - root_mean_squared_error: 0.1212 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0592
# Epoch 35/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0746
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0159 - root_mean_squared_error: 0.1261 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0677
# Epoch 37/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1108
# Epoch 38/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0174 - root_mean_squared_error: 0.1319 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0719
# Epoch 39/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0120 - root_mean_squared_error: 0.1095 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0632
# Epoch 40/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0197 - root_mean_squared_error: 0.1404 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0684
# Epoch 41/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0148 - root_mean_squared_error: 0.1215 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0648
# Epoch 42/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0172 - root_mean_squared_error: 0.1310 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0932
# Epoch 43/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0627
# Epoch 44/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0153 - root_mean_squared_error: 0.1235 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0673
# Epoch 45/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0108 - root_mean_squared_error: 0.1038 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0681
# Epoch 46/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0991
# Epoch 47/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0117 - root_mean_squared_error: 0.1084 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0784
# Epoch 48/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0109 - root_mean_squared_error: 0.1045 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0660
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1200 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0703
# Epoch 50/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1019

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.7195093989372254 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Weddell_model_LT4/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 0s/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.0655294140411452
# MAE : 0.05736729380135077

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        6.048740e+06    6574288.749
# 1        6.391116e+06    6669726.076
# 2        6.343425e+06    6516136.854
# 3        5.589633e+06    5902163.675
# 4        4.059182e+06    3498103.449
# 5        1.874492e+06    1633675.726
# 6        9.253724e+05    1292668.399
# 7        1.019770e+06    1527666.815
# 8        2.147650e+06    2121949.701
# 9        3.083755e+06    3562381.775
# 10       4.385417e+06    5004305.983
# 11       5.438449e+06    6176613.878
# 12       6.229238e+06    6794233.093
# 13       6.639240e+06    7024136.637
# 14       6.393852e+06    6554271.388
# 15       5.478686e+06    6172281.701
# 16       3.698019e+06    4175225.799
# 17       1.447291e+06    1748380.899
# 18       9.058422e+05    1256191.080
# 19       9.823782e+05    1347295.364
# 20       2.231729e+06    2180184.677
# 21       3.179680e+06    3419295.982
# 22       4.687732e+06    4786146.771
# 23       5.502376e+06    5968132.718
# 24       6.387232e+06    6556934.174
# 25       6.712954e+06    6614949.980
# 26       6.561568e+06    6035207.368
# 27       5.569892e+06    5274244.730
# 28       4.072403e+06    3505146.372
# 29       1.882890e+06    1478130.228
# 30       1.255565e+06    1096780.503
# 31       1.201144e+06    1387234.069
# 32       2.455772e+06    2128693.591
# 33       3.543650e+06    3313318.704
# 34       4.771443e+06    4218076.656
# 35       5.680632e+06    5257641.941
# 36       6.301656e+06    5956603.340
# 37       6.685838e+06    6256062.049
# 38       6.376324e+06    5974548.305
# 39       5.524821e+06    5569396.731
# 40       3.839192e+06    3684108.410
# 41       2.167251e+06    1451614.707
# 42       1.283785e+06    1089888.684
# 43       1.456524e+06    1255222.909
# 44       2.265232e+06    1704492.279
# 45       3.296333e+06    2563551.804
# 46       4.451650e+06    3668127.143
# 47       5.373816e+06    4805519.784
# 48       6.017354e+06    5524445.234
# 49       6.389090e+06    6006669.861
# 50       6.573792e+06    5507961.583

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
