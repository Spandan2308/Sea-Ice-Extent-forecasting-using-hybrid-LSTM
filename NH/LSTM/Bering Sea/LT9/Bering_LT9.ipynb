# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bering = pd.read_excel(filepath, sheet_name='Bering-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Bering)
fp.date_time(Bering)
# Out:
#          Extent       Date
# 0    320266.650 1979-01-01
# 1    541778.338 1979-02-01
# 2    638262.988 1979-03-01
# 3    423025.159 1979-04-01
# 4    215587.216 1979-05-01
# ..          ...        ...
# 488  317377.493 2023-05-01
# 489   39601.476 2023-06-01
# 490   16935.702 2023-07-01
# 491    1305.744 2023-09-01
# 492   12255.644 2023-10-01
#
# [493 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bering['Extent'] = scaler.fit_transform(Bering['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 9
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bering['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((473, 12, 1), (473,))

# %%
X_train, y_train = X[:384], y[:384]
X_val, y_val = X[384:432], y[384:432]
X_test, y_test = X[432:], y[432:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Bering_model_LT9/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 45/48 [===========================>..] - ETA: 0s - loss: 0.1740 - root_mean_squared_error: 0.4171INFO:tensorflow:Assets written to: Bering_model_LT9\assets
# 48/48 [==============================] - 20s 280ms/step - loss: 0.1674 - root_mean_squared_error: 0.4092 - val_loss: 0.0506 - val_root_mean_squared_error: 0.2250
# Epoch 2/50
# 45/48 [===========================>..] - ETA: 0s - loss: 0.1253 - root_mean_squared_error: 0.3540INFO:tensorflow:Assets written to: Bering_model_LT9\assets
# 48/48 [==============================] - 9s 201ms/step - loss: 0.1236 - root_mean_squared_error: 0.3516 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2026
# Epoch 3/50
# 48/48 [==============================] - 1s 16ms/step - loss: 0.0974 - root_mean_squared_error: 0.3121 - val_loss: 0.0464 - val_root_mean_squared_error: 0.2155
# Epoch 4/50
# 48/48 [==============================] - 1s 14ms/step - loss: 0.0907 - root_mean_squared_error: 0.3011 - val_loss: 0.0478 - val_root_mean_squared_error: 0.2187
# Epoch 5/50
# 48/48 [==============================] - 1s 15ms/step - loss: 0.0855 - root_mean_squared_error: 0.2925 - val_loss: 0.0490 - val_root_mean_squared_error: 0.2214
# Epoch 6/50
# 48/48 [==============================] - 1s 15ms/step - loss: 0.0787 - root_mean_squared_error: 0.2805 - val_loss: 0.0493 - val_root_mean_squared_error: 0.2221
# Epoch 7/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0661 - root_mean_squared_error: 0.2572 - val_loss: 0.0597 - val_root_mean_squared_error: 0.2444
# Epoch 8/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0450 - root_mean_squared_error: 0.2121 - val_loss: 0.0968 - val_root_mean_squared_error: 0.3112
# Epoch 9/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0289 - root_mean_squared_error: 0.1700 - val_loss: 0.1437 - val_root_mean_squared_error: 0.3791
# Epoch 10/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0218 - root_mean_squared_error: 0.1476 - val_loss: 0.1438 - val_root_mean_squared_error: 0.3791
# Epoch 11/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.2064 - val_root_mean_squared_error: 0.4543
# Epoch 12/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0167 - root_mean_squared_error: 0.1293 - val_loss: 0.1962 - val_root_mean_squared_error: 0.4429
# Epoch 13/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0167 - root_mean_squared_error: 0.1293 - val_loss: 0.1903 - val_root_mean_squared_error: 0.4363
# Epoch 14/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0167 - root_mean_squared_error: 0.1293 - val_loss: 0.1355 - val_root_mean_squared_error: 0.3681
# Epoch 15/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0175 - root_mean_squared_error: 0.1321 - val_loss: 0.2344 - val_root_mean_squared_error: 0.4842
# Epoch 16/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0170 - root_mean_squared_error: 0.1305 - val_loss: 0.1841 - val_root_mean_squared_error: 0.4291
# Epoch 17/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0166 - root_mean_squared_error: 0.1287 - val_loss: 0.1269 - val_root_mean_squared_error: 0.3562
# Epoch 18/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.1642 - val_root_mean_squared_error: 0.4052
# Epoch 19/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0207 - root_mean_squared_error: 0.1438 - val_loss: 0.1114 - val_root_mean_squared_error: 0.3337
# Epoch 20/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0172 - root_mean_squared_error: 0.1311 - val_loss: 0.1486 - val_root_mean_squared_error: 0.3855
# Epoch 21/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0155 - root_mean_squared_error: 0.1243 - val_loss: 0.1411 - val_root_mean_squared_error: 0.3756
# Epoch 22/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0141 - root_mean_squared_error: 0.1189 - val_loss: 0.1557 - val_root_mean_squared_error: 0.3946
# Epoch 23/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0167 - root_mean_squared_error: 0.1292 - val_loss: 0.1869 - val_root_mean_squared_error: 0.4323
# Epoch 24/50
# 48/48 [==============================] - 1s 16ms/step - loss: 0.0150 - root_mean_squared_error: 0.1224 - val_loss: 0.1749 - val_root_mean_squared_error: 0.4182
# Epoch 25/50
# 48/48 [==============================] - 1s 16ms/step - loss: 0.0137 - root_mean_squared_error: 0.1168 - val_loss: 0.1380 - val_root_mean_squared_error: 0.3715
# Epoch 26/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0152 - root_mean_squared_error: 0.1234 - val_loss: 0.1150 - val_root_mean_squared_error: 0.3391
# Epoch 27/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0132 - root_mean_squared_error: 0.1151 - val_loss: 0.1396 - val_root_mean_squared_error: 0.3736
# Epoch 28/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0131 - root_mean_squared_error: 0.1146 - val_loss: 0.1508 - val_root_mean_squared_error: 0.3884
# Epoch 29/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0150 - root_mean_squared_error: 0.1224 - val_loss: 0.1439 - val_root_mean_squared_error: 0.3794
# Epoch 30/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195 - val_loss: 0.1556 - val_root_mean_squared_error: 0.3945
# Epoch 31/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.1293 - val_root_mean_squared_error: 0.3596
# Epoch 32/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0136 - root_mean_squared_error: 0.1164 - val_loss: 0.1517 - val_root_mean_squared_error: 0.3895
# Epoch 33/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.1758 - val_root_mean_squared_error: 0.4193
# Epoch 34/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141 - val_loss: 0.1428 - val_root_mean_squared_error: 0.3779
# Epoch 35/50
# 48/48 [==============================] - 1s 16ms/step - loss: 0.0145 - root_mean_squared_error: 0.1204 - val_loss: 0.1437 - val_root_mean_squared_error: 0.3791
# Epoch 36/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0139 - root_mean_squared_error: 0.1180 - val_loss: 0.1080 - val_root_mean_squared_error: 0.3286
# Epoch 37/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0137 - root_mean_squared_error: 0.1171 - val_loss: 0.1133 - val_root_mean_squared_error: 0.3366
# Epoch 38/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0124 - root_mean_squared_error: 0.1115 - val_loss: 0.1100 - val_root_mean_squared_error: 0.3317
# Epoch 39/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0126 - root_mean_squared_error: 0.1124 - val_loss: 0.1256 - val_root_mean_squared_error: 0.3544
# Epoch 40/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0139 - root_mean_squared_error: 0.1179 - val_loss: 0.1188 - val_root_mean_squared_error: 0.3446
# Epoch 41/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0126 - root_mean_squared_error: 0.1123 - val_loss: 0.1415 - val_root_mean_squared_error: 0.3762
# Epoch 42/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0137 - root_mean_squared_error: 0.1171 - val_loss: 0.1562 - val_root_mean_squared_error: 0.3953
# Epoch 43/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0124 - root_mean_squared_error: 0.1115 - val_loss: 0.0979 - val_root_mean_squared_error: 0.3129
# Epoch 44/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0123 - root_mean_squared_error: 0.1108 - val_loss: 0.0949 - val_root_mean_squared_error: 0.3081
# Epoch 45/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0124 - root_mean_squared_error: 0.1113 - val_loss: 0.1428 - val_root_mean_squared_error: 0.3779
# Epoch 46/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0134 - root_mean_squared_error: 0.1157 - val_loss: 0.0844 - val_root_mean_squared_error: 0.2905
# Epoch 47/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0112 - root_mean_squared_error: 0.1060 - val_loss: 0.1139 - val_root_mean_squared_error: 0.3375
# Epoch 48/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197 - val_loss: 0.1044 - val_root_mean_squared_error: 0.3232
# Epoch 49/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0127 - root_mean_squared_error: 0.1128 - val_loss: 0.1289 - val_root_mean_squared_error: 0.3590
# Epoch 50/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0936 - val_root_mean_squared_error: 0.3059

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.1711326917012532 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bering_model_LT9/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 0s/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.27345119736332674
# MAE : 0.24237125170143292

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       182039.765625     708542.184
# 1       184238.796875     652598.000
# 2       190487.250000     414216.785
# 3       196990.156250     236263.303
# 4       203541.000000      43422.368
# 5       209575.687500       2161.744
# 6       214670.937500        944.181
# 7       219553.984375      13977.643
# 8       216859.281250      24795.001
# 9       200560.390625     168828.990
# 10      192765.781250     461098.498
# 11      191128.296875     591635.798
# 12      194957.859375     598360.298
# 13      204935.781250     531742.038
# 14      216148.890625     302131.004
# 15      228013.078125      57748.135
# 16      239222.875000       3054.962
# 17      249360.765625        442.539
# 18      257844.750000       8541.643
# 19      262528.250000     121335.125
# 20      251230.828125     360205.990
# 21      226964.765625     651717.220
# 22      206737.906250     779385.402
# 23      200064.062500     710314.085
# 24      202796.234375     578635.421
# 25      213468.187500     199031.792
# 26      225299.515625      43795.314
# 27      236549.234375       3015.211
# 28      246856.109375       1206.623
# 29      256999.171875       8506.979
# 30      262933.562500      41065.748
# 31      255051.921875     169363.165
# 32      241520.312500     531698.544
# 33      228228.937500     631496.345
# 34      219553.562500     612860.407
# 35      223019.031250     552903.799
# 36      236974.859375     317377.493
# 37      252271.671875      39601.476
# 38      266854.687500      16935.702
# 39      280119.218750       1305.744
# 40      288698.437500      12255.644

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 15/15 [==============================] - 0s 10ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
