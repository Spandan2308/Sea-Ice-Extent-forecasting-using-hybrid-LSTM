# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Kara = pd.read_excel(filepath, sheet_name='Kara-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Kara)
fp.date_time(Kara)
# Out:
#          Extent       Date
# 0    917992.880 1979-01-01
# 1    917992.880 1979-02-01
# 2    917992.880 1979-03-01
# 3    917992.880 1979-04-01
# 4    917992.880 1979-05-01
# ..          ...        ...
# 533  728642.743 2023-06-01
# 534  437024.646 2023-07-01
# 535  202260.789 2023-08-01
# 536   98103.856 2023-09-01
# 537  260413.272 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Kara['Extent'] = scaler.fit_transform(Kara['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 10
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Kara['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((517, 12, 1), (517,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Kara_model_LT10/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.5307 - root_mean_squared_error: 0.7285INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 42s 558ms/step - loss: 0.5281 - root_mean_squared_error: 0.7267 - val_loss: 0.2586 - val_root_mean_squared_error: 0.5085
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1233 - root_mean_squared_error: 0.3512INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 26s 494ms/step - loss: 0.1233 - root_mean_squared_error: 0.3512 - val_loss: 0.1404 - val_root_mean_squared_error: 0.3747
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0797 - root_mean_squared_error: 0.2822INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 25s 487ms/step - loss: 0.0797 - root_mean_squared_error: 0.2822 - val_loss: 0.1165 - val_root_mean_squared_error: 0.3413
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0676 - root_mean_squared_error: 0.2600INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 25s 487ms/step - loss: 0.0676 - root_mean_squared_error: 0.2600 - val_loss: 0.0850 - val_root_mean_squared_error: 0.2916
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0514 - root_mean_squared_error: 0.2267INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 25s 481ms/step - loss: 0.0517 - root_mean_squared_error: 0.2273 - val_loss: 0.0668 - val_root_mean_squared_error: 0.2585
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0442 - root_mean_squared_error: 0.2101INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 26s 494ms/step - loss: 0.0442 - root_mean_squared_error: 0.2101 - val_loss: 0.0520 - val_root_mean_squared_error: 0.2280
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0397 - root_mean_squared_error: 0.1992INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 26s 503ms/step - loss: 0.0397 - root_mean_squared_error: 0.1992 - val_loss: 0.0461 - val_root_mean_squared_error: 0.2148
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0365 - root_mean_squared_error: 0.1910INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 29s 562ms/step - loss: 0.0365 - root_mean_squared_error: 0.1910 - val_loss: 0.0420 - val_root_mean_squared_error: 0.2049
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0356 - root_mean_squared_error: 0.1887INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 26s 500ms/step - loss: 0.0356 - root_mean_squared_error: 0.1887 - val_loss: 0.0403 - val_root_mean_squared_error: 0.2007
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0326 - root_mean_squared_error: 0.1806INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 26s 500ms/step - loss: 0.0326 - root_mean_squared_error: 0.1806 - val_loss: 0.0395 - val_root_mean_squared_error: 0.1988
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0328 - root_mean_squared_error: 0.1812INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 27s 517ms/step - loss: 0.0329 - root_mean_squared_error: 0.1815 - val_loss: 0.0383 - val_root_mean_squared_error: 0.1957
# Epoch 12/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0342 - root_mean_squared_error: 0.1849 - val_loss: 0.0395 - val_root_mean_squared_error: 0.1987
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0308 - root_mean_squared_error: 0.1755INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 26s 493ms/step - loss: 0.0308 - root_mean_squared_error: 0.1755 - val_loss: 0.0365 - val_root_mean_squared_error: 0.1910
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0316 - root_mean_squared_error: 0.1778INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 27s 514ms/step - loss: 0.0316 - root_mean_squared_error: 0.1778 - val_loss: 0.0351 - val_root_mean_squared_error: 0.1872
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0310 - root_mean_squared_error: 0.1760INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 27s 509ms/step - loss: 0.0310 - root_mean_squared_error: 0.1760 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1856
# Epoch 16/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0320 - root_mean_squared_error: 0.1788 - val_loss: 0.0354 - val_root_mean_squared_error: 0.1881
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0287 - root_mean_squared_error: 0.1695INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 25s 489ms/step - loss: 0.0287 - root_mean_squared_error: 0.1695 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1842
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0318 - root_mean_squared_error: 0.1782INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 28s 535ms/step - loss: 0.0318 - root_mean_squared_error: 0.1782 - val_loss: 0.0327 - val_root_mean_squared_error: 0.1807
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0289 - root_mean_squared_error: 0.1700INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 26s 495ms/step - loss: 0.0289 - root_mean_squared_error: 0.1700 - val_loss: 0.0324 - val_root_mean_squared_error: 0.1799
# Epoch 20/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0292 - root_mean_squared_error: 0.1709 - val_loss: 0.0328 - val_root_mean_squared_error: 0.1810
# Epoch 21/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0288 - root_mean_squared_error: 0.1696INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 26s 492ms/step - loss: 0.0288 - root_mean_squared_error: 0.1696 - val_loss: 0.0307 - val_root_mean_squared_error: 0.1751
# Epoch 22/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0293 - root_mean_squared_error: 0.1713 - val_loss: 0.0308 - val_root_mean_squared_error: 0.1755
# Epoch 23/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0282 - root_mean_squared_error: 0.1679 - val_loss: 0.0330 - val_root_mean_squared_error: 0.1818
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0286 - root_mean_squared_error: 0.1692INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 26s 507ms/step - loss: 0.0286 - root_mean_squared_error: 0.1692 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1694
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0274 - root_mean_squared_error: 0.1655INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0274 - root_mean_squared_error: 0.1655 - val_loss: 0.0281 - val_root_mean_squared_error: 0.1677
# Epoch 26/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0281 - root_mean_squared_error: 0.1675INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 27s 511ms/step - loss: 0.0281 - root_mean_squared_error: 0.1675 - val_loss: 0.0272 - val_root_mean_squared_error: 0.1650
# Epoch 27/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0255 - root_mean_squared_error: 0.1598 - val_loss: 0.0282 - val_root_mean_squared_error: 0.1679
# Epoch 28/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0275 - root_mean_squared_error: 0.1659 - val_loss: 0.0272 - val_root_mean_squared_error: 0.1650
# Epoch 29/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0248 - root_mean_squared_error: 0.1576INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 27s 523ms/step - loss: 0.0248 - root_mean_squared_error: 0.1576 - val_loss: 0.0264 - val_root_mean_squared_error: 0.1624
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0241 - root_mean_squared_error: 0.1551INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 27s 516ms/step - loss: 0.0241 - root_mean_squared_error: 0.1551 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1554
# Epoch 31/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0237 - root_mean_squared_error: 0.1540INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 27s 513ms/step - loss: 0.0237 - root_mean_squared_error: 0.1540 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1541
# Epoch 32/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0222 - root_mean_squared_error: 0.1490INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0222 - root_mean_squared_error: 0.1490 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1473
# Epoch 33/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0247 - root_mean_squared_error: 0.1571 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1594
# Epoch 34/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0221 - root_mean_squared_error: 0.1485 - val_loss: 0.0268 - val_root_mean_squared_error: 0.1637
# Epoch 35/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0223 - root_mean_squared_error: 0.1493INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 27s 511ms/step - loss: 0.0223 - root_mean_squared_error: 0.1493 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1365
# Epoch 36/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0200 - root_mean_squared_error: 0.1413INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 27s 508ms/step - loss: 0.0200 - root_mean_squared_error: 0.1413 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1357
# Epoch 37/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0201 - root_mean_squared_error: 0.1417 - val_loss: 0.0305 - val_root_mean_squared_error: 0.1745
# Epoch 38/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0207 - root_mean_squared_error: 0.1438INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 26s 500ms/step - loss: 0.0207 - root_mean_squared_error: 0.1438 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1320
# Epoch 39/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0187 - root_mean_squared_error: 0.1367INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 26s 508ms/step - loss: 0.0187 - root_mean_squared_error: 0.1367 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1293
# Epoch 40/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0184 - root_mean_squared_error: 0.1357 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1317
# Epoch 41/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0190 - root_mean_squared_error: 0.1378 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1544
# Epoch 42/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0194 - root_mean_squared_error: 0.1393INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 26s 507ms/step - loss: 0.0194 - root_mean_squared_error: 0.1393 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1266
# Epoch 43/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0176 - root_mean_squared_error: 0.1328 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1443
# Epoch 44/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0168 - root_mean_squared_error: 0.1297INFO:tensorflow:Assets written to: Kara_model_LT10\assets
# 53/53 [==============================] - 26s 492ms/step - loss: 0.0168 - root_mean_squared_error: 0.1297 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1261
# Epoch 45/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0176 - root_mean_squared_error: 0.1328 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1350
# Epoch 46/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0163 - root_mean_squared_error: 0.1275 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1294
# Epoch 47/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0168 - root_mean_squared_error: 0.1298 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1431
# Epoch 48/50
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331 - val_loss: 0.0231 - val_root_mean_squared_error: 0.1520
# Epoch 49/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0173 - root_mean_squared_error: 0.1315 - val_loss: 0.0202 - val_root_mean_squared_error: 0.1422
# Epoch 50/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0168 - root_mean_squared_error: 0.1296 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1416

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 14.981265997886657 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Kara_model_LT10/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 23ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.14420404738429785
# MAE : 0.0998627949634988

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 42ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
