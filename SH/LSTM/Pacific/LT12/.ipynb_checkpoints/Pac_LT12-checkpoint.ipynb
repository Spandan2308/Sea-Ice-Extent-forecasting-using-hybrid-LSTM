# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Pacific_Extent = pd.read_excel(filepath, sheet_name='Pacific-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Pacific_Extent)
fp.date_time(Pacific_Extent)
# Out:
#           Extent       Date
# 0     668714.275 1979-01-01
# 1     566930.458 1979-02-01
# 2     688420.115 1979-03-01
# 3     859963.043 1979-04-01
# 4    1127120.160 1979-05-01
# ..           ...        ...
# 533  1134056.102 2023-06-01
# 534  1484824.377 2023-07-01
# 535  1671324.717 2023-08-01
# 536  1726376.097 2023-09-01
# 537  1690631.996 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Pacific_Extent['Extent'] = scaler.fit_transform(Pacific_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 12
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Pacific_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((515, 12, 1), (515,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Pacific_model_LT12/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2355 - root_mean_squared_error: 0.4853INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 21s 259ms/step - loss: 0.2355 - root_mean_squared_error: 0.4853 - val_loss: 0.1740 - val_root_mean_squared_error: 0.4171
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1243 - root_mean_squared_error: 0.3526INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 12s 230ms/step - loss: 0.1240 - root_mean_squared_error: 0.3521 - val_loss: 0.0649 - val_root_mean_squared_error: 0.2547
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0660 - root_mean_squared_error: 0.2568INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 12s 224ms/step - loss: 0.0660 - root_mean_squared_error: 0.2568 - val_loss: 0.0608 - val_root_mean_squared_error: 0.2466
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0619 - root_mean_squared_error: 0.2487INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 12s 228ms/step - loss: 0.0615 - root_mean_squared_error: 0.2481 - val_loss: 0.0565 - val_root_mean_squared_error: 0.2378
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0566 - root_mean_squared_error: 0.2379INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 11s 216ms/step - loss: 0.0566 - root_mean_squared_error: 0.2379 - val_loss: 0.0538 - val_root_mean_squared_error: 0.2320
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0517 - root_mean_squared_error: 0.2275INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 12s 223ms/step - loss: 0.0515 - root_mean_squared_error: 0.2269 - val_loss: 0.0467 - val_root_mean_squared_error: 0.2160
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0425 - root_mean_squared_error: 0.2061INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 12s 233ms/step - loss: 0.0424 - root_mean_squared_error: 0.2059 - val_loss: 0.0327 - val_root_mean_squared_error: 0.1809
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0303 - root_mean_squared_error: 0.1742INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 11s 217ms/step - loss: 0.0303 - root_mean_squared_error: 0.1742 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1315
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0208 - root_mean_squared_error: 0.1441INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 13s 252ms/step - loss: 0.0208 - root_mean_squared_error: 0.1441 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0909
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0169 - root_mean_squared_error: 0.1298INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 12s 235ms/step - loss: 0.0169 - root_mean_squared_error: 0.1298 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0715
# Epoch 11/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0157 - root_mean_squared_error: 0.1253 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0750
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0154 - root_mean_squared_error: 0.1240INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 11s 208ms/step - loss: 0.0154 - root_mean_squared_error: 0.1240 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0675
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0145 - root_mean_squared_error: 0.1205INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 13s 242ms/step - loss: 0.0145 - root_mean_squared_error: 0.1205 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0616
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0129 - root_mean_squared_error: 0.1135INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 13s 241ms/step - loss: 0.0129 - root_mean_squared_error: 0.1135 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0570
# Epoch 15/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0147 - root_mean_squared_error: 0.1212 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606
# Epoch 16/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0134 - root_mean_squared_error: 0.1159 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0581
# Epoch 17/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0119 - root_mean_squared_error: 0.1091 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0570
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0125 - root_mean_squared_error: 0.1120INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 13s 256ms/step - loss: 0.0125 - root_mean_squared_error: 0.1120 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0560
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0124 - root_mean_squared_error: 0.1113INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 12s 231ms/step - loss: 0.0124 - root_mean_squared_error: 0.1113 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0559
# Epoch 20/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0113 - root_mean_squared_error: 0.1062INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 12s 237ms/step - loss: 0.0112 - root_mean_squared_error: 0.1057 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0527
# Epoch 21/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0124 - root_mean_squared_error: 0.1113 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0558
# Epoch 22/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0113 - root_mean_squared_error: 0.1062INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 12s 235ms/step - loss: 0.0113 - root_mean_squared_error: 0.1065 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0523
# Epoch 23/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0112 - root_mean_squared_error: 0.1058INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 11s 211ms/step - loss: 0.0112 - root_mean_squared_error: 0.1058 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0519
# Epoch 24/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0528
# Epoch 25/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0102 - root_mean_squared_error: 0.1008INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 11s 218ms/step - loss: 0.0101 - root_mean_squared_error: 0.1003 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0509
# Epoch 26/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0105 - root_mean_squared_error: 0.1024 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0538
# Epoch 27/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0101 - root_mean_squared_error: 0.1005 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0515
# Epoch 28/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0097 - root_mean_squared_error: 0.0987 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0520
# Epoch 29/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0094 - root_mean_squared_error: 0.0970 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0583
# Epoch 30/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0090 - root_mean_squared_error: 0.0948 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0541
# Epoch 31/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0098 - root_mean_squared_error: 0.0991 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0524
# Epoch 32/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0096 - root_mean_squared_error: 0.0979 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0524
# Epoch 33/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0095 - root_mean_squared_error: 0.0973 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0521
# Epoch 34/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0090 - root_mean_squared_error: 0.0951 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0597
# Epoch 35/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0096 - root_mean_squared_error: 0.0980 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0542
# Epoch 36/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0090 - root_mean_squared_error: 0.0949 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606
# Epoch 37/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0089 - root_mean_squared_error: 0.0945 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0531
# Epoch 38/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0094 - root_mean_squared_error: 0.0970 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0698
# Epoch 39/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0088 - root_mean_squared_error: 0.0937 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0534
# Epoch 40/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0087 - root_mean_squared_error: 0.0933 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0737
# Epoch 41/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0084 - root_mean_squared_error: 0.0916 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0583
# Epoch 42/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0085 - root_mean_squared_error: 0.0920 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0545
# Epoch 43/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0092 - root_mean_squared_error: 0.0959 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0617
# Epoch 44/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0089 - root_mean_squared_error: 0.0945 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0546
# Epoch 45/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0084 - root_mean_squared_error: 0.0917 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0565
# Epoch 46/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0091 - root_mean_squared_error: 0.0954 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0551
# Epoch 47/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0075 - root_mean_squared_error: 0.0864 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0622
# Epoch 48/50
# 53/53 [==============================] - 1s 27ms/step - loss: 0.0082 - root_mean_squared_error: 0.0904 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0560
# Epoch 49/50
# 53/53 [==============================] - 96s 2s/step - loss: 0.0084 - root_mean_squared_error: 0.0915 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0599
# Epoch 50/50
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0080 - root_mean_squared_error: 0.0895 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0552

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 6.429783848921458 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Pacific_model_LT12/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 11ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.08244389712710631
# MAE : 0.06751130639126707

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        8.509577e+05     819257.445
# 1        1.100721e+06    1129627.707
# 2        1.379772e+06    1463383.236
# 3        1.698821e+06    1614536.727
# 4        1.943727e+06    1862498.612
# 5        1.918196e+06    2099349.296
# 6        1.741683e+06    1981614.046
# 7        1.397706e+06    1433022.369
# 8        9.963040e+05     826739.716
# 9        6.144403e+05     477145.887
# 10       4.632382e+05     314469.289
# 11       5.957772e+05     463134.749
# 12       8.200905e+05     946522.292
# 13       1.110836e+06    1309266.570
# 14       1.443296e+06    1507947.309
# 15       1.800040e+06    1804167.937
# 16       2.070873e+06    1908002.139
# 17       1.913407e+06    1892748.521
# 18       1.669522e+06    1601079.640
# 19       1.362817e+06    1327804.521
# 20       9.533737e+05     812074.231
# 21       5.184337e+05     493355.897
# 22       4.408228e+05     317229.330
# 23       5.859747e+05     425777.624
# 24       7.973051e+05     827172.620
# 25       1.069921e+06    1162367.223
# 26       1.392307e+06    1413734.261
# 27       1.759033e+06    1574257.849
# 28       2.027005e+06    1786961.251
# 29       2.035269e+06    1857942.866
# 30       1.807306e+06    1406291.588
# 31       1.341868e+06    1025555.371
# 32       8.573398e+05     632862.782
# 33       5.140547e+05     308194.756
# 34       5.254339e+05     194921.078
# 35       6.979135e+05     245569.900
# 36       9.255022e+05     533532.424
# 37       1.186831e+06     943124.529
# 38       1.480022e+06    1134056.102
# 39       1.689078e+06    1484824.377
# 40       1.853701e+06    1671324.717
# 41       1.894497e+06    1726376.097
# 42       1.788043e+06    1690631.996

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 10ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
