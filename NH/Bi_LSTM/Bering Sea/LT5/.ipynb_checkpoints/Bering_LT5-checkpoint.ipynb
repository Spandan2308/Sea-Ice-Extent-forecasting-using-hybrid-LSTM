# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bering = pd.read_excel(filepath, sheet_name='Bering-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Bering)
fp.date_time(Bering)
# Out:
#          Extent       Date
# 0    320266.650 1979-01-01
# 1    541778.338 1979-02-01
# 2    638262.988 1979-03-01
# 3    423025.159 1979-04-01
# 4    215587.216 1979-05-01
# ..          ...        ...
# 488  317377.493 2023-05-01
# 489   39601.476 2023-06-01
# 490   16935.702 2023-07-01
# 491    1305.744 2023-09-01
# 492   12255.644 2023-10-01
#
# [493 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bering['Extent'] = scaler.fit_transform(Bering['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 5
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bering['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((477, 12, 1), (477,))

# %%
X_train, y_train = X[:384], y[:384]
X_val, y_val = X[384:432], y[384:432]
X_test, y_test = X[432:], y[432:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Bering_model_LT5/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 46/48 [===========================>..] - ETA: 0s - loss: 0.1613 - root_mean_squared_error: 0.4016INFO:tensorflow:Assets written to: Bering_model_LT5\assets
# 48/48 [==============================] - 42s 707ms/step - loss: 0.1580 - root_mean_squared_error: 0.3975 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2023
# Epoch 2/50
# 48/48 [==============================] - 1s 26ms/step - loss: 0.1004 - root_mean_squared_error: 0.3168 - val_loss: 0.0435 - val_root_mean_squared_error: 0.2086
# Epoch 3/50
# 46/48 [===========================>..] - ETA: 0s - loss: 0.0838 - root_mean_squared_error: 0.2895INFO:tensorflow:Assets written to: Bering_model_LT5\assets
# 48/48 [==============================] - 34s 717ms/step - loss: 0.0830 - root_mean_squared_error: 0.2882 - val_loss: 0.0377 - val_root_mean_squared_error: 0.1941
# Epoch 4/50
# 46/48 [===========================>..] - ETA: 0s - loss: 0.0764 - root_mean_squared_error: 0.2764INFO:tensorflow:Assets written to: Bering_model_LT5\assets
# 48/48 [==============================] - 34s 725ms/step - loss: 0.0771 - root_mean_squared_error: 0.2776 - val_loss: 0.0370 - val_root_mean_squared_error: 0.1924
# Epoch 5/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0705 - root_mean_squared_error: 0.2655INFO:tensorflow:Assets written to: Bering_model_LT5\assets
# 48/48 [==============================] - 25s 531ms/step - loss: 0.0705 - root_mean_squared_error: 0.2655 - val_loss: 0.0312 - val_root_mean_squared_error: 0.1767
# Epoch 6/50
# 47/48 [============================>.] - ETA: 0s - loss: 0.0568 - root_mean_squared_error: 0.2383INFO:tensorflow:Assets written to: Bering_model_LT5\assets
# 48/48 [==============================] - 18s 392ms/step - loss: 0.0568 - root_mean_squared_error: 0.2384 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1701
# Epoch 7/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0341 - root_mean_squared_error: 0.1846INFO:tensorflow:Assets written to: Bering_model_LT5\assets
# 48/48 [==============================] - 18s 388ms/step - loss: 0.0341 - root_mean_squared_error: 0.1846 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1281
# Epoch 8/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0189 - root_mean_squared_error: 0.1376INFO:tensorflow:Assets written to: Bering_model_LT5\assets
# 48/48 [==============================] - 19s 401ms/step - loss: 0.0189 - root_mean_squared_error: 0.1376 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1187
# Epoch 9/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0163 - root_mean_squared_error: 0.1277 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1289
# Epoch 10/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1351
# Epoch 11/50
# 48/48 [==============================] - 2s 52ms/step - loss: 0.0139 - root_mean_squared_error: 0.1180 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1419
# Epoch 12/50
# 48/48 [==============================] - 2s 49ms/step - loss: 0.0154 - root_mean_squared_error: 0.1241 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1378
# Epoch 13/50
# 48/48 [==============================] - 3s 60ms/step - loss: 0.0127 - root_mean_squared_error: 0.1128 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1514
# Epoch 14/50
# 48/48 [==============================] - 3s 58ms/step - loss: 0.0136 - root_mean_squared_error: 0.1165 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1507
# Epoch 15/50
# 48/48 [==============================] - 2s 50ms/step - loss: 0.0132 - root_mean_squared_error: 0.1149 - val_loss: 0.0313 - val_root_mean_squared_error: 0.1768
# Epoch 16/50
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0118 - root_mean_squared_error: 0.1088 - val_loss: 0.0305 - val_root_mean_squared_error: 0.1746
# Epoch 17/50
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0124 - root_mean_squared_error: 0.1114 - val_loss: 0.0332 - val_root_mean_squared_error: 0.1823
# Epoch 18/50
# 48/48 [==============================] - 2s 45ms/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.0302 - val_root_mean_squared_error: 0.1739
# Epoch 19/50
# 48/48 [==============================] - 2s 49ms/step - loss: 0.0110 - root_mean_squared_error: 0.1050 - val_loss: 0.0322 - val_root_mean_squared_error: 0.1796
# Epoch 20/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0108 - root_mean_squared_error: 0.1037 - val_loss: 0.0281 - val_root_mean_squared_error: 0.1675
# Epoch 21/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0110 - root_mean_squared_error: 0.1051 - val_loss: 0.0387 - val_root_mean_squared_error: 0.1967
# Epoch 22/50
# 48/48 [==============================] - 2s 45ms/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0315 - val_root_mean_squared_error: 0.1774
# Epoch 23/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0387 - val_root_mean_squared_error: 0.1968
# Epoch 24/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0121 - root_mean_squared_error: 0.1101 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2016
# Epoch 25/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0113 - root_mean_squared_error: 0.1061 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1833
# Epoch 26/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069 - val_loss: 0.0435 - val_root_mean_squared_error: 0.2086
# Epoch 27/50
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0111 - root_mean_squared_error: 0.1056 - val_loss: 0.0374 - val_root_mean_squared_error: 0.1935
# Epoch 28/50
# 48/48 [==============================] - 2s 44ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069 - val_loss: 0.0390 - val_root_mean_squared_error: 0.1976
# Epoch 29/50
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0110 - root_mean_squared_error: 0.1049 - val_loss: 0.0396 - val_root_mean_squared_error: 0.1990
# Epoch 30/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0101 - root_mean_squared_error: 0.1007 - val_loss: 0.0390 - val_root_mean_squared_error: 0.1974
# Epoch 31/50
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0107 - root_mean_squared_error: 0.1036 - val_loss: 0.0498 - val_root_mean_squared_error: 0.2233
# Epoch 32/50
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0106 - root_mean_squared_error: 0.1027 - val_loss: 0.0385 - val_root_mean_squared_error: 0.1962
# Epoch 33/50
# 48/48 [==============================] - 2s 44ms/step - loss: 0.0108 - root_mean_squared_error: 0.1041 - val_loss: 0.0499 - val_root_mean_squared_error: 0.2235
# Epoch 34/50
# 48/48 [==============================] - 2s 45ms/step - loss: 0.0107 - root_mean_squared_error: 0.1035 - val_loss: 0.0330 - val_root_mean_squared_error: 0.1816
# Epoch 35/50
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0104 - root_mean_squared_error: 0.1021 - val_loss: 0.0417 - val_root_mean_squared_error: 0.2042
# Epoch 36/50
# 48/48 [==============================] - 2s 49ms/step - loss: 0.0105 - root_mean_squared_error: 0.1024 - val_loss: 0.0368 - val_root_mean_squared_error: 0.1918
# Epoch 37/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0111 - root_mean_squared_error: 0.1055 - val_loss: 0.0443 - val_root_mean_squared_error: 0.2105
# Epoch 38/50
# 48/48 [==============================] - 2s 49ms/step - loss: 0.0107 - root_mean_squared_error: 0.1034 - val_loss: 0.0315 - val_root_mean_squared_error: 0.1775
# Epoch 39/50
# 48/48 [==============================] - 2s 50ms/step - loss: 0.0110 - root_mean_squared_error: 0.1050 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2014
# Epoch 40/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0100 - root_mean_squared_error: 0.0999 - val_loss: 0.0331 - val_root_mean_squared_error: 0.1820
# Epoch 41/50
# 48/48 [==============================] - 3s 52ms/step - loss: 0.0102 - root_mean_squared_error: 0.1012 - val_loss: 0.0433 - val_root_mean_squared_error: 0.2080
# Epoch 42/50
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0104 - root_mean_squared_error: 0.1020 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2026
# Epoch 43/50
# 48/48 [==============================] - 2s 44ms/step - loss: 0.0105 - root_mean_squared_error: 0.1023 - val_loss: 0.0460 - val_root_mean_squared_error: 0.2145
# Epoch 44/50
# 48/48 [==============================] - 2s 45ms/step - loss: 0.0108 - root_mean_squared_error: 0.1040 - val_loss: 0.0496 - val_root_mean_squared_error: 0.2226
# Epoch 45/50
# 48/48 [==============================] - 2s 45ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0360 - val_root_mean_squared_error: 0.1896
# Epoch 46/50
# 48/48 [==============================] - 2s 44ms/step - loss: 0.0099 - root_mean_squared_error: 0.0993 - val_loss: 0.0563 - val_root_mean_squared_error: 0.2373
# Epoch 47/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0110 - root_mean_squared_error: 0.1048 - val_loss: 0.0372 - val_root_mean_squared_error: 0.1928
# Epoch 48/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0106 - root_mean_squared_error: 0.1028 - val_loss: 0.0515 - val_root_mean_squared_error: 0.2270
# Epoch 49/50
# 48/48 [==============================] - 3s 58ms/step - loss: 0.0101 - root_mean_squared_error: 0.1005 - val_loss: 0.0342 - val_root_mean_squared_error: 0.1848
# Epoch 50/50
# 48/48 [==============================] - 3s 66ms/step - loss: 0.0109 - root_mean_squared_error: 0.1044 - val_loss: 0.0582 - val_root_mean_squared_error: 0.2412

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 4.771099495887756 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bering_model_LT5/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 20ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.10954718386953927
# MAE : 0.08032196849506544

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        96900.062500      11293.282
# 1       184739.125000      49957.406
# 2       269033.093750     151973.751
# 3       338183.312500     466524.938
# 4       376608.000000     708542.184
# 5       379347.281250     652598.000
# 6       331072.187500     414216.785
# 7       216904.375000     236263.303
# 8        12733.367188      43422.368
# 9       -33765.636719       2161.744
# 10       -5990.014648        944.181
# 11       61823.246094      13977.643
# 12      161283.687500      24795.001
# 13      285145.750000     168828.990
# 14      415381.437500     461098.498
# 15      511567.343750     591635.798
# 16      546870.250000     598360.298
# 17      519121.656250     531742.038
# 18      364006.000000     302131.004
# 19       94953.226562      57748.135
# 20      -40927.945312       3054.962
# 21      -34075.195312        442.539
# 22       25737.574219       8541.643
# 23      121453.265625     121335.125
# 24      255071.421875     360205.990
# 25      386635.312500     651717.220
# 26      492310.781250     779385.402
# 27      546104.125000     710314.085
# 28      479264.843750     578635.421
# 29      261613.078125     199031.792
# 30        3633.987305      43795.314
# 31      -50098.773438       3015.211
# 32      -25025.437500       1206.623
# 33       52068.218750       8506.979
# 34      196557.546875      41065.748
# 35      373827.125000     169363.165
# 36      529853.375000     531698.544
# 37      640592.000000     631496.345
# 38      675504.687500     612860.407
# 39      609869.750000     552903.799
# 40      415282.750000     317377.493
# 41       91371.250000      39601.476
# 42      -46108.316406      16935.702
# 43      -40377.351562       1305.744
# 44       21328.447266      12255.644

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 15/15 [==============================] - 0s 28ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
