# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Kara = pd.read_excel(filepath, sheet_name='Kara-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Kara)
fp.date_time(Kara)
# Out:
#          Extent       Date
# 0    917992.880 1979-01-01
# 1    917992.880 1979-02-01
# 2    917992.880 1979-03-01
# 3    917992.880 1979-04-01
# 4    917992.880 1979-05-01
# ..          ...        ...
# 533  728642.743 2023-06-01
# 534  437024.646 2023-07-01
# 535  202260.789 2023-08-01
# 536   98103.856 2023-09-01
# 537  260413.272 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Kara['Extent'] = scaler.fit_transform(Kara['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 12
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Kara['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((515, 12, 1), (515,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Kara_model_LT12/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.6263 - root_mean_squared_error: 0.7914INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 43s 563ms/step - loss: 0.6230 - root_mean_squared_error: 0.7893 - val_loss: 0.4167 - val_root_mean_squared_error: 0.6455
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.2145 - root_mean_squared_error: 0.4631INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 26s 495ms/step - loss: 0.2129 - root_mean_squared_error: 0.4614 - val_loss: 0.1627 - val_root_mean_squared_error: 0.4034
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0988 - root_mean_squared_error: 0.3144INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 27s 522ms/step - loss: 0.0983 - root_mean_squared_error: 0.3135 - val_loss: 0.1469 - val_root_mean_squared_error: 0.3832
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0878 - root_mean_squared_error: 0.2964INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 27s 514ms/step - loss: 0.0882 - root_mean_squared_error: 0.2969 - val_loss: 0.1258 - val_root_mean_squared_error: 0.3547
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0784 - root_mean_squared_error: 0.2799INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 27s 521ms/step - loss: 0.0784 - root_mean_squared_error: 0.2799 - val_loss: 0.1041 - val_root_mean_squared_error: 0.3226
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0585 - root_mean_squared_error: 0.2418INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 27s 527ms/step - loss: 0.0585 - root_mean_squared_error: 0.2418 - val_loss: 0.0795 - val_root_mean_squared_error: 0.2819
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0474 - root_mean_squared_error: 0.2176INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 28s 535ms/step - loss: 0.0474 - root_mean_squared_error: 0.2176 - val_loss: 0.0622 - val_root_mean_squared_error: 0.2494
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0402 - root_mean_squared_error: 0.2006INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 29s 549ms/step - loss: 0.0402 - root_mean_squared_error: 0.2006 - val_loss: 0.0500 - val_root_mean_squared_error: 0.2236
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0363 - root_mean_squared_error: 0.1906INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 28s 542ms/step - loss: 0.0363 - root_mean_squared_error: 0.1906 - val_loss: 0.0484 - val_root_mean_squared_error: 0.2201
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0349 - root_mean_squared_error: 0.1868INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 28s 546ms/step - loss: 0.0349 - root_mean_squared_error: 0.1868 - val_loss: 0.0427 - val_root_mean_squared_error: 0.2067
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0348 - root_mean_squared_error: 0.1864INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 28s 543ms/step - loss: 0.0348 - root_mean_squared_error: 0.1864 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2023
# Epoch 12/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0331 - root_mean_squared_error: 0.1819 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2025
# Epoch 13/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0355 - root_mean_squared_error: 0.1885 - val_loss: 0.0433 - val_root_mean_squared_error: 0.2080
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0348 - root_mean_squared_error: 0.1865INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 28s 535ms/step - loss: 0.0348 - root_mean_squared_error: 0.1865 - val_loss: 0.0391 - val_root_mean_squared_error: 0.1978
# Epoch 15/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0300 - root_mean_squared_error: 0.1732 - val_loss: 0.0402 - val_root_mean_squared_error: 0.2004
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0314 - root_mean_squared_error: 0.1772INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 29s 549ms/step - loss: 0.0314 - root_mean_squared_error: 0.1772 - val_loss: 0.0354 - val_root_mean_squared_error: 0.1882
# Epoch 17/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0299 - root_mean_squared_error: 0.1729INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 26s 496ms/step - loss: 0.0297 - root_mean_squared_error: 0.1725 - val_loss: 0.0347 - val_root_mean_squared_error: 0.1862
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0281 - root_mean_squared_error: 0.1677INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 25s 488ms/step - loss: 0.0281 - root_mean_squared_error: 0.1677 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1854
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0296 - root_mean_squared_error: 0.1721INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 28s 535ms/step - loss: 0.0296 - root_mean_squared_error: 0.1721 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1832
# Epoch 20/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0286 - root_mean_squared_error: 0.1691INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 26s 506ms/step - loss: 0.0286 - root_mean_squared_error: 0.1691 - val_loss: 0.0315 - val_root_mean_squared_error: 0.1775
# Epoch 21/50
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0277 - root_mean_squared_error: 0.1665 - val_loss: 0.0386 - val_root_mean_squared_error: 0.1965
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0261 - root_mean_squared_error: 0.1616INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 25s 476ms/step - loss: 0.0261 - root_mean_squared_error: 0.1616 - val_loss: 0.0307 - val_root_mean_squared_error: 0.1751
# Epoch 23/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0255 - root_mean_squared_error: 0.1598 - val_loss: 0.0377 - val_root_mean_squared_error: 0.1942
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0270 - root_mean_squared_error: 0.1642INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 27s 524ms/step - loss: 0.0270 - root_mean_squared_error: 0.1642 - val_loss: 0.0297 - val_root_mean_squared_error: 0.1724
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0236 - root_mean_squared_error: 0.1536INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 27s 527ms/step - loss: 0.0236 - root_mean_squared_error: 0.1536 - val_loss: 0.0284 - val_root_mean_squared_error: 0.1685
# Epoch 26/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0252 - root_mean_squared_error: 0.1588INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 28s 531ms/step - loss: 0.0252 - root_mean_squared_error: 0.1588 - val_loss: 0.0283 - val_root_mean_squared_error: 0.1682
# Epoch 27/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0243 - root_mean_squared_error: 0.1559INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 27s 513ms/step - loss: 0.0241 - root_mean_squared_error: 0.1552 - val_loss: 0.0276 - val_root_mean_squared_error: 0.1660
# Epoch 28/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0215 - root_mean_squared_error: 0.1466INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 25s 481ms/step - loss: 0.0215 - root_mean_squared_error: 0.1466 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1545
# Epoch 29/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0211 - root_mean_squared_error: 0.1451INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 27s 515ms/step - loss: 0.0211 - root_mean_squared_error: 0.1451 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1498
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0199 - root_mean_squared_error: 0.1411INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 27s 512ms/step - loss: 0.0199 - root_mean_squared_error: 0.1411 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1474
# Epoch 31/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0203 - root_mean_squared_error: 0.1425INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 28s 539ms/step - loss: 0.0203 - root_mean_squared_error: 0.1425 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1460
# Epoch 32/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0186 - root_mean_squared_error: 0.1365INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 28s 545ms/step - loss: 0.0186 - root_mean_squared_error: 0.1365 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1435
# Epoch 33/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0207 - root_mean_squared_error: 0.1439 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1591
# Epoch 34/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0212 - root_mean_squared_error: 0.1456INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 28s 532ms/step - loss: 0.0212 - root_mean_squared_error: 0.1456 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1373
# Epoch 35/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0201 - root_mean_squared_error: 0.1418 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1377
# Epoch 36/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0195 - root_mean_squared_error: 0.1395INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 27s 517ms/step - loss: 0.0195 - root_mean_squared_error: 0.1395 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1353
# Epoch 37/50
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0184 - root_mean_squared_error: 0.1356 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1360
# Epoch 38/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0173 - root_mean_squared_error: 0.1315INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 27s 526ms/step - loss: 0.0175 - root_mean_squared_error: 0.1323 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1300
# Epoch 39/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0168 - root_mean_squared_error: 0.1295INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 28s 529ms/step - loss: 0.0168 - root_mean_squared_error: 0.1295 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1287
# Epoch 40/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0166 - root_mean_squared_error: 0.1290INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 28s 528ms/step - loss: 0.0166 - root_mean_squared_error: 0.1290 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1283
# Epoch 41/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0170 - root_mean_squared_error: 0.1305 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1317
# Epoch 42/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0167 - root_mean_squared_error: 0.1291 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1284
# Epoch 43/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0185 - root_mean_squared_error: 0.1361 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1287
# Epoch 44/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0176 - root_mean_squared_error: 0.1325INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 28s 532ms/step - loss: 0.0176 - root_mean_squared_error: 0.1325 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1258
# Epoch 45/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0151 - root_mean_squared_error: 0.1228 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1272
# Epoch 46/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0159 - root_mean_squared_error: 0.1262 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1303
# Epoch 47/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0172 - root_mean_squared_error: 0.1312INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 28s 539ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1243
# Epoch 48/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0174 - root_mean_squared_error: 0.1318 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1404
# Epoch 49/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0158 - root_mean_squared_error: 0.1257INFO:tensorflow:Assets written to: Kara_model_LT12\assets
# 53/53 [==============================] - 28s 535ms/step - loss: 0.0158 - root_mean_squared_error: 0.1257 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1195
# Epoch 50/50
# 53/53 [==============================] - 2s 47ms/step - loss: 0.0161 - root_mean_squared_error: 0.1268 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1235

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 17.00178237358729 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Kara_model_LT12/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 32ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.11897920348644316
# MAE : 0.08222567490938419

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 36ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
