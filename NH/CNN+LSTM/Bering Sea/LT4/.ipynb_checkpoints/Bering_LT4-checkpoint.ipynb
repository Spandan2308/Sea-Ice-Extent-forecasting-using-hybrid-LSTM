# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bering = pd.read_excel(filepath, sheet_name='Bering-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Bering)
fp.date_time(Bering)
# Out:
#          Extent       Date
# 0    320266.650 1979-01-01
# 1    541778.338 1979-02-01
# 2    638262.988 1979-03-01
# 3    423025.159 1979-04-01
# 4    215587.216 1979-05-01
# ..          ...        ...
# 488  317377.493 2023-05-01
# 489   39601.476 2023-06-01
# 490   16935.702 2023-07-01
# 491    1305.744 2023-09-01
# 492   12255.644 2023-10-01
#
# [493 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bering['Extent'] = scaler.fit_transform(Bering['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 4
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]  # Adjusted for lead time
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bering['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((478, 12, 1), (478,))

# %%
X_train, y_train = X[:382], y[:382]
X_val, y_val = X[382:430], y[382:430]
X_test, y_test = X[430:], y[430:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Bering_model_LT4/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 38/48 [======================>.......] - ETA: 0s - loss: 0.1656 - root_mean_squared_error: 0.4070
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# 48/48 [==============================] - 6s 81ms/step - loss: 0.1628 - root_mean_squared_error: 0.4034 - val_loss: 0.0681 - val_root_mean_squared_error: 0.2610
# Epoch 2/50
# 41/48 [========================>.....] - ETA: 0s - loss: 0.1069 - root_mean_squared_error: 0.3270
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# 48/48 [==============================] - 3s 59ms/step - loss: 0.1026 - root_mean_squared_error: 0.3204 - val_loss: 0.0542 - val_root_mean_squared_error: 0.2328
# Epoch 3/50
# 39/48 [=======================>......] - ETA: 0s - loss: 0.0756 - root_mean_squared_error: 0.2749
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# 48/48 [==============================] - 3s 62ms/step - loss: 0.0750 - root_mean_squared_error: 0.2739 - val_loss: 0.0448 - val_root_mean_squared_error: 0.2116
# Epoch 4/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0652 - root_mean_squared_error: 0.2554
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# 48/48 [==============================] - 3s 72ms/step - loss: 0.0652 - root_mean_squared_error: 0.2554 - val_loss: 0.0386 - val_root_mean_squared_error: 0.1965
# Epoch 5/50
# 39/48 [=======================>......] - ETA: 0s - loss: 0.0503 - root_mean_squared_error: 0.2242
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# 48/48 [==============================] - 3s 68ms/step - loss: 0.0520 - root_mean_squared_error: 0.2280 - val_loss: 0.0346 - val_root_mean_squared_error: 0.1860
# Epoch 6/50
# 37/48 [======================>.......] - ETA: 0s - loss: 0.0418 - root_mean_squared_error: 0.2045
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# 48/48 [==============================] - 3s 59ms/step - loss: 0.0441 - root_mean_squared_error: 0.2099 - val_loss: 0.0319 - val_root_mean_squared_error: 0.1786
# Epoch 7/50
# 39/48 [=======================>......] - ETA: 0s - loss: 0.0348 - root_mean_squared_error: 0.1865
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# 48/48 [==============================] - 4s 76ms/step - loss: 0.0328 - root_mean_squared_error: 0.1812 - val_loss: 0.0308 - val_root_mean_squared_error: 0.1755
# Epoch 8/50
# 47/48 [============================>.] - ETA: 0s - loss: 0.0341 - root_mean_squared_error: 0.1847
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# 48/48 [==============================] - 3s 56ms/step - loss: 0.0337 - root_mean_squared_error: 0.1835 - val_loss: 0.0297 - val_root_mean_squared_error: 0.1722
# Epoch 9/50
# 46/48 [===========================>..] - ETA: 0s - loss: 0.0277 - root_mean_squared_error: 0.1666
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# 48/48 [==============================] - 3s 65ms/step - loss: 0.0273 - root_mean_squared_error: 0.1651 - val_loss: 0.0290 - val_root_mean_squared_error: 0.1704
# Epoch 10/50
# 44/48 [==========================>...] - ETA: 0s - loss: 0.0268 - root_mean_squared_error: 0.1638
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# 48/48 [==============================] - 3s 74ms/step - loss: 0.0266 - root_mean_squared_error: 0.1631 - val_loss: 0.0273 - val_root_mean_squared_error: 0.1652
# Epoch 11/50
# 44/48 [==========================>...] - ETA: 0s - loss: 0.0202 - root_mean_squared_error: 0.1421
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# 48/48 [==============================] - 3s 57ms/step - loss: 0.0204 - root_mean_squared_error: 0.1428 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1645
# Epoch 12/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0205 - root_mean_squared_error: 0.1433
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# INFO:tensorflow:Assets written to: Bering_model_LT4\assets
# 48/48 [==============================] - 3s 56ms/step - loss: 0.0205 - root_mean_squared_error: 0.1433 - val_loss: 0.0260 - val_root_mean_squared_error: 0.1611
# Epoch 13/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0233 - root_mean_squared_error: 0.1527 - val_loss: 0.0266 - val_root_mean_squared_error: 0.1632
# Epoch 14/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0189 - root_mean_squared_error: 0.1373 - val_loss: 0.0349 - val_root_mean_squared_error: 0.1868
# Epoch 15/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0202 - root_mean_squared_error: 0.1421 - val_loss: 0.0370 - val_root_mean_squared_error: 0.1925
# Epoch 16/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0230 - root_mean_squared_error: 0.1516 - val_loss: 0.0363 - val_root_mean_squared_error: 0.1904
# Epoch 17/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0203 - root_mean_squared_error: 0.1426 - val_loss: 0.0421 - val_root_mean_squared_error: 0.2053
# Epoch 18/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0198 - root_mean_squared_error: 0.1409 - val_loss: 0.0463 - val_root_mean_squared_error: 0.2153
# Epoch 19/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0186 - root_mean_squared_error: 0.1363 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2024
# Epoch 20/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0209 - root_mean_squared_error: 0.1447 - val_loss: 0.0398 - val_root_mean_squared_error: 0.1994
# Epoch 21/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0192 - root_mean_squared_error: 0.1385 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2020
# Epoch 22/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0189 - root_mean_squared_error: 0.1375 - val_loss: 0.0418 - val_root_mean_squared_error: 0.2044
# Epoch 23/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0207 - root_mean_squared_error: 0.1439 - val_loss: 0.0345 - val_root_mean_squared_error: 0.1856
# Epoch 24/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0206 - root_mean_squared_error: 0.1437 - val_loss: 0.0510 - val_root_mean_squared_error: 0.2258
# Epoch 25/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0204 - root_mean_squared_error: 0.1427 - val_loss: 0.0325 - val_root_mean_squared_error: 0.1801
# Epoch 26/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0165 - root_mean_squared_error: 0.1284 - val_loss: 0.0400 - val_root_mean_squared_error: 0.2000
# Epoch 27/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0182 - root_mean_squared_error: 0.1351 - val_loss: 0.0473 - val_root_mean_squared_error: 0.2176
# Epoch 28/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0177 - root_mean_squared_error: 0.1329 - val_loss: 0.0468 - val_root_mean_squared_error: 0.2164
# Epoch 29/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0221 - root_mean_squared_error: 0.1487 - val_loss: 0.0449 - val_root_mean_squared_error: 0.2120
# Epoch 30/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0237 - root_mean_squared_error: 0.1540 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2029
# Epoch 31/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0195 - root_mean_squared_error: 0.1398 - val_loss: 0.0442 - val_root_mean_squared_error: 0.2102
# Epoch 32/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0207 - root_mean_squared_error: 0.1438 - val_loss: 0.0537 - val_root_mean_squared_error: 0.2318
# Epoch 33/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0168 - root_mean_squared_error: 0.1294 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2034
# Epoch 34/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0192 - root_mean_squared_error: 0.1385 - val_loss: 0.0424 - val_root_mean_squared_error: 0.2059
# Epoch 35/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0178 - root_mean_squared_error: 0.1334 - val_loss: 0.0470 - val_root_mean_squared_error: 0.2167
# Epoch 36/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0187 - root_mean_squared_error: 0.1369 - val_loss: 0.0469 - val_root_mean_squared_error: 0.2165
# Epoch 37/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0180 - root_mean_squared_error: 0.1342 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2013
# Epoch 38/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0190 - root_mean_squared_error: 0.1379 - val_loss: 0.0443 - val_root_mean_squared_error: 0.2104
# Epoch 39/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0173 - root_mean_squared_error: 0.1316 - val_loss: 0.0512 - val_root_mean_squared_error: 0.2262
# Epoch 40/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0171 - root_mean_squared_error: 0.1308 - val_loss: 0.0460 - val_root_mean_squared_error: 0.2144
# Epoch 41/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0188 - root_mean_squared_error: 0.1372 - val_loss: 0.0474 - val_root_mean_squared_error: 0.2178
# Epoch 42/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0177 - root_mean_squared_error: 0.1332 - val_loss: 0.0481 - val_root_mean_squared_error: 0.2194
# Epoch 43/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0187 - root_mean_squared_error: 0.1366 - val_loss: 0.0476 - val_root_mean_squared_error: 0.2181
# Epoch 44/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0167 - root_mean_squared_error: 0.1294 - val_loss: 0.0483 - val_root_mean_squared_error: 0.2197
# Epoch 45/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0184 - root_mean_squared_error: 0.1357 - val_loss: 0.0493 - val_root_mean_squared_error: 0.2221
# Epoch 46/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0178 - root_mean_squared_error: 0.1336 - val_loss: 0.0367 - val_root_mean_squared_error: 0.1914
# Epoch 47/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0189 - root_mean_squared_error: 0.1376 - val_loss: 0.0553 - val_root_mean_squared_error: 0.2351
# Epoch 48/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0174 - root_mean_squared_error: 0.1318 - val_loss: 0.0400 - val_root_mean_squared_error: 0.2000
# Epoch 49/50
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0160 - root_mean_squared_error: 0.1264 - val_loss: 0.0498 - val_root_mean_squared_error: 0.2231
# Epoch 50/50
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0192 - root_mean_squared_error: 0.1385 - val_loss: 0.0502 - val_root_mean_squared_error: 0.2240

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 0.8275724569956462 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bering_model_LT4/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 14ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.14450044532046546
# MAE : 0.1285152888704737

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       209279.687500      32185.203
# 1       224311.203125       2490.551
# 2       183831.203125       1707.377
# 3       235239.562500      11293.282
# 4       249224.265625      49957.406
# 5       351554.968750     151973.751
# 6       365471.531250     466524.938
# 7       446656.750000     708542.184
# 8       414800.593750     652598.000
# 9       397906.531250     414216.785
# 10      271870.250000     236263.303
# 11      207091.765625      43422.368
# 12      113733.937500       2161.744
# 13      123669.046875        944.181
# 14      109954.523438      13977.643
# 15      180835.281250      24795.001
# 16      258990.921875     168828.990
# 17      384514.312500     461098.498
# 18      433925.156250     591635.798
# 19      490717.187500     598360.298
# 20      447231.281250     531742.038
# 21      338620.062500     302131.004
# 22      206515.296875      57748.135
# 23      134040.796875       3054.962
# 24      130787.281250        442.539
# 25      126016.937500       8541.643
# 26      151777.484375     121335.125
# 27      249994.609375     360205.990
# 28      361775.031250     651717.220
# 29      432067.843750     779385.402
# 30      457263.125000     710314.085
# 31      381792.406250     578635.421
# 32      266265.843750     199031.792
# 33      148032.453125      43795.314
# 34       91441.312500       3015.211
# 35       93914.937500       1206.623
# 36       95299.250000       8506.979
# 37      185053.937500      41065.748
# 38      322474.500000     169363.165
# 39      409153.750000     531698.544
# 40      492917.625000     631496.345
# 41      510762.031250     612860.407
# 42      479468.875000     552903.799
# 43      331023.031250     317377.493
# 44      214303.187500      39601.476
# 45      124727.382812      16935.702
# 46      143672.078125       1305.744
# 47      127260.851562      12255.644

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 15/15 [==============================] - 0s 3ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
