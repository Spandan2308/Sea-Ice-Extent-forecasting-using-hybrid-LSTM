# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bering = pd.read_excel(filepath, sheet_name='Bering-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Bering)
fp.date_time(Bering)
# Out:
#          Extent       Date
# 0    320266.650 1979-01-01
# 1    541778.338 1979-02-01
# 2    638262.988 1979-03-01
# 3    423025.159 1979-04-01
# 4    215587.216 1979-05-01
# ..          ...        ...
# 488  317377.493 2023-05-01
# 489   39601.476 2023-06-01
# 490   16935.702 2023-07-01
# 491    1305.744 2023-09-01
# 492   12255.644 2023-10-01
#
# [493 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bering['Extent'] = scaler.fit_transform(Bering['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 7
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bering['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((475, 12, 1), (475,))

# %%
X_train, y_train = X[:384], y[:384]
X_val, y_val = X[384:432], y[384:432]
X_test, y_test = X[432:], y[432:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Bering_model_LT7/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 46/48 [===========================>..] - ETA: 0s - loss: 0.1529 - root_mean_squared_error: 0.3911INFO:tensorflow:Assets written to: Bering_model_LT7\assets
# 48/48 [==============================] - 34s 497ms/step - loss: 0.1492 - root_mean_squared_error: 0.3862 - val_loss: 0.0371 - val_root_mean_squared_error: 0.1926
# Epoch 2/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0870 - root_mean_squared_error: 0.2949 - val_loss: 0.0457 - val_root_mean_squared_error: 0.2138
# Epoch 3/50
# 47/48 [============================>.] - ETA: 0s - loss: 0.0738 - root_mean_squared_error: 0.2716INFO:tensorflow:Assets written to: Bering_model_LT7\assets
# 48/48 [==============================] - 22s 478ms/step - loss: 0.0732 - root_mean_squared_error: 0.2706 - val_loss: 0.0325 - val_root_mean_squared_error: 0.1803
# Epoch 4/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0628 - root_mean_squared_error: 0.2505INFO:tensorflow:Assets written to: Bering_model_LT7\assets
# 48/48 [==============================] - 22s 476ms/step - loss: 0.0628 - root_mean_squared_error: 0.2505 - val_loss: 0.0312 - val_root_mean_squared_error: 0.1766
# Epoch 5/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0461 - root_mean_squared_error: 0.2146INFO:tensorflow:Assets written to: Bering_model_LT7\assets
# 48/48 [==============================] - 28s 598ms/step - loss: 0.0461 - root_mean_squared_error: 0.2146 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1552
# Epoch 6/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0275 - root_mean_squared_error: 0.1659INFO:tensorflow:Assets written to: Bering_model_LT7\assets
# 48/48 [==============================] - 34s 732ms/step - loss: 0.0275 - root_mean_squared_error: 0.1659 - val_loss: 0.0199 - val_root_mean_squared_error: 0.1412
# Epoch 7/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0171 - root_mean_squared_error: 0.1307 - val_loss: 0.0305 - val_root_mean_squared_error: 0.1748
# Epoch 8/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0159 - root_mean_squared_error: 0.1262INFO:tensorflow:Assets written to: Bering_model_LT7\assets
# 48/48 [==============================] - 32s 688ms/step - loss: 0.0159 - root_mean_squared_error: 0.1262 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1403
# Epoch 9/50
# 48/48 [==============================] - 2s 33ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197 - val_loss: 0.0397 - val_root_mean_squared_error: 0.1992
# Epoch 10/50
# 48/48 [==============================] - 2s 32ms/step - loss: 0.0145 - root_mean_squared_error: 0.1206 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1470
# Epoch 11/50
# 48/48 [==============================] - 2s 35ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197 - val_loss: 0.0348 - val_root_mean_squared_error: 0.1865
# Epoch 12/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0134 - root_mean_squared_error: 0.1159 - val_loss: 0.0273 - val_root_mean_squared_error: 0.1654
# Epoch 13/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186 - val_loss: 0.0322 - val_root_mean_squared_error: 0.1796
# Epoch 14/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0133 - root_mean_squared_error: 0.1155 - val_loss: 0.0445 - val_root_mean_squared_error: 0.2110
# Epoch 15/50
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0129 - root_mean_squared_error: 0.1136 - val_loss: 0.0383 - val_root_mean_squared_error: 0.1957
# Epoch 16/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0129 - root_mean_squared_error: 0.1134 - val_loss: 0.0463 - val_root_mean_squared_error: 0.2152
# Epoch 17/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0125 - root_mean_squared_error: 0.1117 - val_loss: 0.0493 - val_root_mean_squared_error: 0.2221
# Epoch 18/50
# 48/48 [==============================] - 2s 49ms/step - loss: 0.0123 - root_mean_squared_error: 0.1109 - val_loss: 0.0430 - val_root_mean_squared_error: 0.2075
# Epoch 19/50
# 48/48 [==============================] - 2s 44ms/step - loss: 0.0122 - root_mean_squared_error: 0.1106 - val_loss: 0.0417 - val_root_mean_squared_error: 0.2042
# Epoch 20/50
# 48/48 [==============================] - 2s 44ms/step - loss: 0.0113 - root_mean_squared_error: 0.1063 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2122
# Epoch 21/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0121 - root_mean_squared_error: 0.1101 - val_loss: 0.0508 - val_root_mean_squared_error: 0.2255
# Epoch 22/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0122 - root_mean_squared_error: 0.1103 - val_loss: 0.0354 - val_root_mean_squared_error: 0.1881
# Epoch 23/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0459 - val_root_mean_squared_error: 0.2143
# Epoch 24/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0115 - root_mean_squared_error: 0.1073 - val_loss: 0.0513 - val_root_mean_squared_error: 0.2265
# Epoch 25/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0109 - root_mean_squared_error: 0.1045 - val_loss: 0.0394 - val_root_mean_squared_error: 0.1984
# Epoch 26/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0115 - root_mean_squared_error: 0.1074 - val_loss: 0.0479 - val_root_mean_squared_error: 0.2190
# Epoch 27/50
# 48/48 [==============================] - 2s 52ms/step - loss: 0.0109 - root_mean_squared_error: 0.1044 - val_loss: 0.0471 - val_root_mean_squared_error: 0.2171
# Epoch 28/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0112 - root_mean_squared_error: 0.1056 - val_loss: 0.0563 - val_root_mean_squared_error: 0.2372
# Epoch 29/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2022
# Epoch 30/50
# 48/48 [==============================] - 3s 53ms/step - loss: 0.0114 - root_mean_squared_error: 0.1070 - val_loss: 0.0440 - val_root_mean_squared_error: 0.2097
# Epoch 31/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0113 - root_mean_squared_error: 0.1063 - val_loss: 0.0382 - val_root_mean_squared_error: 0.1956
# Epoch 32/50
# 48/48 [==============================] - 3s 67ms/step - loss: 0.0105 - root_mean_squared_error: 0.1023 - val_loss: 0.0424 - val_root_mean_squared_error: 0.2060
# Epoch 33/50
# 48/48 [==============================] - 2s 45ms/step - loss: 0.0105 - root_mean_squared_error: 0.1024 - val_loss: 0.0466 - val_root_mean_squared_error: 0.2159
# Epoch 34/50
# 48/48 [==============================] - 3s 57ms/step - loss: 0.0103 - root_mean_squared_error: 0.1013 - val_loss: 0.0491 - val_root_mean_squared_error: 0.2217
# Epoch 35/50
# 48/48 [==============================] - 3s 59ms/step - loss: 0.0105 - root_mean_squared_error: 0.1022 - val_loss: 0.0488 - val_root_mean_squared_error: 0.2209
# Epoch 36/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0099 - root_mean_squared_error: 0.0996 - val_loss: 0.0448 - val_root_mean_squared_error: 0.2117
# Epoch 37/50
# 48/48 [==============================] - 2s 35ms/step - loss: 0.0096 - root_mean_squared_error: 0.0979 - val_loss: 0.0423 - val_root_mean_squared_error: 0.2056
# Epoch 38/50
# 48/48 [==============================] - 2s 45ms/step - loss: 0.0102 - root_mean_squared_error: 0.1010 - val_loss: 0.0481 - val_root_mean_squared_error: 0.2194
# Epoch 39/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0099 - root_mean_squared_error: 0.0997 - val_loss: 0.0391 - val_root_mean_squared_error: 0.1977
# Epoch 40/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0100 - root_mean_squared_error: 0.1001 - val_loss: 0.0434 - val_root_mean_squared_error: 0.2084
# Epoch 41/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0097 - root_mean_squared_error: 0.0987 - val_loss: 0.0482 - val_root_mean_squared_error: 0.2194
# Epoch 42/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0093 - root_mean_squared_error: 0.0965 - val_loss: 0.0389 - val_root_mean_squared_error: 0.1973
# Epoch 43/50
# 48/48 [==============================] - 2s 44ms/step - loss: 0.0101 - root_mean_squared_error: 0.1006 - val_loss: 0.0421 - val_root_mean_squared_error: 0.2051
# Epoch 44/50
# 48/48 [==============================] - 2s 52ms/step - loss: 0.0098 - root_mean_squared_error: 0.0991 - val_loss: 0.0527 - val_root_mean_squared_error: 0.2296
# Epoch 45/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0094 - root_mean_squared_error: 0.0968 - val_loss: 0.0368 - val_root_mean_squared_error: 0.1919
# Epoch 46/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0104 - root_mean_squared_error: 0.1022 - val_loss: 0.0510 - val_root_mean_squared_error: 0.2258
# Epoch 47/50
# 48/48 [==============================] - 3s 60ms/step - loss: 0.0099 - root_mean_squared_error: 0.0996 - val_loss: 0.0422 - val_root_mean_squared_error: 0.2055
# Epoch 48/50
# 48/48 [==============================] - 2s 45ms/step - loss: 0.0093 - root_mean_squared_error: 0.0964 - val_loss: 0.0458 - val_root_mean_squared_error: 0.2139
# Epoch 49/50
# 48/48 [==============================] - 3s 68ms/step - loss: 0.0095 - root_mean_squared_error: 0.0972 - val_loss: 0.0376 - val_root_mean_squared_error: 0.1939
# Epoch 50/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0102 - root_mean_squared_error: 0.1008 - val_loss: 0.0473 - val_root_mean_squared_error: 0.2175

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 4.454598879814148 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bering_model_LT7/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 15ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.1257940512325407
# MAE : 0.08990707289005467

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       512728.687500     151973.751
# 1       553569.937500     466524.938
# 2       512157.093750     708542.184
# 3       442620.437500     652598.000
# 4       347715.125000     414216.785
# 5       232391.609375     236263.303
# 6       123688.851562      43422.368
# 7        36057.753906       2161.744
# 8        10725.692383        944.181
# 9       157291.515625      13977.643
# 10      381109.937500      24795.001
# 11      558419.812500     168828.990
# 12      660196.562500     461098.498
# 13      631372.562500     591635.798
# 14      552247.687500     598360.298
# 15      431107.031250     531742.038
# 16      288018.593750     302131.004
# 17      152075.281250      57748.135
# 18       50220.609375       3054.962
# 19       -9653.106445        442.539
# 20      -20224.068359       8541.643
# 21       34433.640625     121335.125
# 22      337393.406250     360205.990
# 23      557463.062500     651717.220
# 24      636369.500000     779385.402
# 25      568094.687500     710314.085
# 26      450489.468750     578635.421
# 27      307503.875000     199031.792
# 28      172876.187500      43795.314
# 29       63386.972656       3015.211
# 30        6229.555664       1206.623
# 31        3180.985107       8506.979
# 32       68794.359375      41065.748
# 33      318636.031250     169363.165
# 34      574580.937500     531698.544
# 35      660837.000000     631496.345
# 36      562277.625000     612860.407
# 37      406515.875000     552903.799
# 38      242569.328125     317377.493
# 39      100119.875000      39601.476
# 40       11395.599609      16935.702
# 41      -27522.472656       1305.744
# 42      -28174.986328      12255.644

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 15/15 [==============================] - 0s 22ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
