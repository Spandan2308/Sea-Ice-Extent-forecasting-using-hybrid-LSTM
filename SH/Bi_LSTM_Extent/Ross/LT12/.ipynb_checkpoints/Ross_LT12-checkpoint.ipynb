# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Ross_Extent = pd.read_excel(filepath, sheet_name='Ross-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Ross_Extent)
fp.date_time(Ross_Extent)
# Out:
#           Extent       Date
# 0    1040455.516 1979-01-01
# 1     239334.118 1979-02-01
# 2     557365.154 1979-03-01
# 3    2054855.924 1979-04-01
# 4    2973925.625 1979-05-01
# ..           ...        ...
# 533  3137598.938 2023-06-01
# 534  3201783.453 2023-07-01
# 535  2973294.266 2023-08-01
# 536  3354839.711 2023-09-01
# 537  3325613.245 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Ross_Extent['Extent'] = scaler.fit_transform(Ross_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 12
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Ross_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((515, 12, 1), (515,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Ross_model_LT12/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.3475 - root_mean_squared_error: 0.5895INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 38s 508ms/step - loss: 0.3475 - root_mean_squared_error: 0.5895 - val_loss: 0.1981 - val_root_mean_squared_error: 0.4451
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1136 - root_mean_squared_error: 0.3370INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 25s 481ms/step - loss: 0.1131 - root_mean_squared_error: 0.3364 - val_loss: 0.0910 - val_root_mean_squared_error: 0.3016
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0668 - root_mean_squared_error: 0.2584INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 25s 475ms/step - loss: 0.0668 - root_mean_squared_error: 0.2584 - val_loss: 0.0815 - val_root_mean_squared_error: 0.2854
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0540 - root_mean_squared_error: 0.2323INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 25s 489ms/step - loss: 0.0538 - root_mean_squared_error: 0.2319 - val_loss: 0.0684 - val_root_mean_squared_error: 0.2615
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0453 - root_mean_squared_error: 0.2128INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 498ms/step - loss: 0.0453 - root_mean_squared_error: 0.2128 - val_loss: 0.0570 - val_root_mean_squared_error: 0.2388
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0358 - root_mean_squared_error: 0.1892INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 503ms/step - loss: 0.0358 - root_mean_squared_error: 0.1892 - val_loss: 0.0462 - val_root_mean_squared_error: 0.2150
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0278 - root_mean_squared_error: 0.1666INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 27s 508ms/step - loss: 0.0278 - root_mean_squared_error: 0.1666 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1854
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0204 - root_mean_squared_error: 0.1428INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 27s 509ms/step - loss: 0.0204 - root_mean_squared_error: 0.1428 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1564
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0168 - root_mean_squared_error: 0.1296INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0168 - root_mean_squared_error: 0.1296 - val_loss: 0.0244 - val_root_mean_squared_error: 0.1562
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0148 - root_mean_squared_error: 0.1218INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0148 - root_mean_squared_error: 0.1218 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1416
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0135 - root_mean_squared_error: 0.1160INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 498ms/step - loss: 0.0135 - root_mean_squared_error: 0.1162 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1362
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0137 - root_mean_squared_error: 0.1170INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 495ms/step - loss: 0.0137 - root_mean_squared_error: 0.1169 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1271
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0145 - root_mean_squared_error: 0.1204INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 497ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1248
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0136 - root_mean_squared_error: 0.1165INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0136 - root_mean_squared_error: 0.1165 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1242
# Epoch 15/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0134 - root_mean_squared_error: 0.1158 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1496
# Epoch 16/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0132 - root_mean_squared_error: 0.1150 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1534
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0121 - root_mean_squared_error: 0.1098INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 499ms/step - loss: 0.0121 - root_mean_squared_error: 0.1098 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1222
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0116 - root_mean_squared_error: 0.1075INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 27s 511ms/step - loss: 0.0116 - root_mean_squared_error: 0.1075 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1211
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0108 - root_mean_squared_error: 0.1039INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 499ms/step - loss: 0.0108 - root_mean_squared_error: 0.1039 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1195
# Epoch 20/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0132 - root_mean_squared_error: 0.1150 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1449
# Epoch 21/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0124 - root_mean_squared_error: 0.1111INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 500ms/step - loss: 0.0124 - root_mean_squared_error: 0.1111 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1191
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0109 - root_mean_squared_error: 0.1044INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 499ms/step - loss: 0.0109 - root_mean_squared_error: 0.1044 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1159
# Epoch 23/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0096 - root_mean_squared_error: 0.0980INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0096 - root_mean_squared_error: 0.0980 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1134
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0100 - root_mean_squared_error: 0.1001INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0100 - root_mean_squared_error: 0.1001 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133
# Epoch 25/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0096 - root_mean_squared_error: 0.0980 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1177
# Epoch 26/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0093 - root_mean_squared_error: 0.0964INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 506ms/step - loss: 0.0093 - root_mean_squared_error: 0.0964 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1025
# Epoch 27/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0094 - root_mean_squared_error: 0.0971 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1162
# Epoch 28/50
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0086 - root_mean_squared_error: 0.0927 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1256
# Epoch 29/50
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0096 - root_mean_squared_error: 0.0981 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1288
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0087 - root_mean_squared_error: 0.0934INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 505ms/step - loss: 0.0087 - root_mean_squared_error: 0.0934 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1023
# Epoch 31/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0085 - root_mean_squared_error: 0.0920 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1429
# Epoch 32/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0080 - root_mean_squared_error: 0.0897 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1102
# Epoch 33/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1153
# Epoch 34/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0075 - root_mean_squared_error: 0.0866 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1287
# Epoch 35/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0084 - root_mean_squared_error: 0.0914 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1257
# Epoch 36/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0076 - root_mean_squared_error: 0.0870INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 508ms/step - loss: 0.0076 - root_mean_squared_error: 0.0870 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0962
# Epoch 37/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0074 - root_mean_squared_error: 0.0862 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1258
# Epoch 38/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0070 - root_mean_squared_error: 0.0836 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1119
# Epoch 39/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0068 - root_mean_squared_error: 0.0826 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0974
# Epoch 40/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0071 - root_mean_squared_error: 0.0844 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1192
# Epoch 41/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0059 - root_mean_squared_error: 0.0768 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0973
# Epoch 42/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0072 - root_mean_squared_error: 0.0851INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 505ms/step - loss: 0.0072 - root_mean_squared_error: 0.0851 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0914
# Epoch 43/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0062 - root_mean_squared_error: 0.0790 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0922
# Epoch 44/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0068 - root_mean_squared_error: 0.0823 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0953
# Epoch 45/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0062 - root_mean_squared_error: 0.0788 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0973
# Epoch 46/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0064 - root_mean_squared_error: 0.0800 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1111
# Epoch 47/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0062 - root_mean_squared_error: 0.0784 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1134
# Epoch 48/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0065 - root_mean_squared_error: 0.0808INFO:tensorflow:Assets written to: Ross_model_LT12\assets
# 53/53 [==============================] - 26s 502ms/step - loss: 0.0065 - root_mean_squared_error: 0.0808 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0912
# Epoch 49/50
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0067 - root_mean_squared_error: 0.0817 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0941
# Epoch 50/50
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0064 - root_mean_squared_error: 0.0799 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0962

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 12.997747739156088 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Ross_model_LT12/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 34ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.09626982988097327
# MAE : 0.07418984368190096

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        2.176624e+06    2086269.569
# 1        2.875084e+06    2852731.016
# 2        3.325255e+06    3452823.613
# 3        3.707551e+06    3846843.974
# 4        3.939770e+06    4005222.451
# 5        4.028088e+06    4129684.505
# 6        3.902100e+06    4130311.577
# 7        3.569480e+06    3987590.376
# 8        2.820638e+06    2531664.630
# 9        1.663100e+06     864796.598
# 10       8.376528e+05     366098.623
# 11       1.069366e+06    1324063.884
# 12       2.187422e+06    2094086.684
# 13       2.854888e+06    2706708.526
# 14       3.358631e+06    3380172.167
# 15       3.742752e+06    3975727.475
# 16       3.948690e+06    4016497.161
# 17       4.035042e+06    4134594.766
# 18       3.953100e+06    4278165.933
# 19       3.733850e+06    3893945.909
# 20       2.627921e+06    2389171.083
# 21       1.278682e+06     896425.932
# 22       7.391066e+05     251374.224
# 23       1.178037e+06     455056.048
# 24       2.153908e+06    1780625.872
# 25       2.814494e+06    2914989.101
# 26       3.326153e+06    3561620.245
# 27       3.802703e+06    3991717.506
# 28       4.083646e+06    4559070.778
# 29       4.161168e+06    4596327.081
# 30       4.037678e+06    4565650.139
# 31       3.707586e+06    4061902.846
# 32       2.563370e+06    2336900.967
# 33       1.190884e+06     696917.659
# 34       6.895416e+05     213657.789
# 35       9.884664e+05     765773.883
# 36       2.054199e+06    1951730.202
# 37       2.911858e+06    2610971.814
# 38       3.480468e+06    3137598.938
# 39       3.910387e+06    3201783.453
# 40       4.277523e+06    2973294.266
# 41       4.468174e+06    3354839.711
# 42       4.316909e+06    3325613.245

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 37ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
