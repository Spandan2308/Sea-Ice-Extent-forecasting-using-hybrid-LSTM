# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Greenland = pd.read_excel(filepath, sheet_name='Greenland-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Greenland)
fp.date_time(Greenland)
# Out:
#           Extent       Date
# 0    1076123.146 1979-01-01
# 1    1099248.063 1979-02-01
# 2    1036964.901 1979-03-01
# 3     958927.937 1979-04-01
# 4     823812.694 1979-05-01
# ..           ...        ...
# 533   721350.515 2023-06-01
# 534   459033.164 2023-07-01
# 535   282045.909 2023-08-01
# 536   270397.608 2023-09-01
# 537   449910.973 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Greenland['Extent'] = scaler.fit_transform(Greenland['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 4
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Greenland['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((523, 12, 1), (523,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Greenland_LT4/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2790 - root_mean_squared_error: 0.5282INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 48s 629ms/step - loss: 0.2790 - root_mean_squared_error: 0.5282 - val_loss: 0.1062 - val_root_mean_squared_error: 0.3259
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0798 - root_mean_squared_error: 0.2825INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 30s 569ms/step - loss: 0.0794 - root_mean_squared_error: 0.2817 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1622
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0331 - root_mean_squared_error: 0.1818INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 31s 588ms/step - loss: 0.0330 - root_mean_squared_error: 0.1817 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1585
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0291 - root_mean_squared_error: 0.1706INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 30s 580ms/step - loss: 0.0291 - root_mean_squared_error: 0.1706 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1512
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0265 - root_mean_squared_error: 0.1627INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 30s 582ms/step - loss: 0.0265 - root_mean_squared_error: 0.1627 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1449
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0240 - root_mean_squared_error: 0.1550INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 31s 591ms/step - loss: 0.0240 - root_mean_squared_error: 0.1550 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1434
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0202 - root_mean_squared_error: 0.1421INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 30s 571ms/step - loss: 0.0203 - root_mean_squared_error: 0.1425 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1333
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0198 - root_mean_squared_error: 0.1409INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 30s 583ms/step - loss: 0.0198 - root_mean_squared_error: 0.1409 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1300
# Epoch 9/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0193 - root_mean_squared_error: 0.1391 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1331
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0186 - root_mean_squared_error: 0.1365INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 30s 585ms/step - loss: 0.0186 - root_mean_squared_error: 0.1365 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1233
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0176 - root_mean_squared_error: 0.1328INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 31s 596ms/step - loss: 0.0176 - root_mean_squared_error: 0.1328 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1203
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0183 - root_mean_squared_error: 0.1351INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 31s 604ms/step - loss: 0.0182 - root_mean_squared_error: 0.1348 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1195
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0167 - root_mean_squared_error: 0.1294INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 32s 609ms/step - loss: 0.0166 - root_mean_squared_error: 0.1289 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1175
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0157 - root_mean_squared_error: 0.1255INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 32s 605ms/step - loss: 0.0157 - root_mean_squared_error: 0.1255 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1154
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0156 - root_mean_squared_error: 0.1248INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 33s 634ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1137
# Epoch 16/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0147 - root_mean_squared_error: 0.1214 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1315
# Epoch 17/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0160 - root_mean_squared_error: 0.1263 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1152
# Epoch 18/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0151 - root_mean_squared_error: 0.1230 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1204
# Epoch 19/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0143 - root_mean_squared_error: 0.1198 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1192
# Epoch 20/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0148 - root_mean_squared_error: 0.1216 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1183
# Epoch 21/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1165
# Epoch 22/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1216
# Epoch 23/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1163
# Epoch 24/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0137 - root_mean_squared_error: 0.1170INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 36s 683ms/step - loss: 0.0137 - root_mean_squared_error: 0.1169 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1092
# Epoch 25/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0147 - root_mean_squared_error: 0.1213 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1105
# Epoch 26/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0139 - root_mean_squared_error: 0.1179 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1157
# Epoch 27/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0148 - root_mean_squared_error: 0.1217INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 31s 603ms/step - loss: 0.0147 - root_mean_squared_error: 0.1213 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1084
# Epoch 28/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0137 - root_mean_squared_error: 0.1170 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1219
# Epoch 29/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0136 - root_mean_squared_error: 0.1165 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1282
# Epoch 30/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0150 - root_mean_squared_error: 0.1226 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1166
# Epoch 31/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0131 - root_mean_squared_error: 0.1143 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1088
# Epoch 32/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1160
# Epoch 33/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0127 - root_mean_squared_error: 0.1125 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1121
# Epoch 34/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1151
# Epoch 35/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0139 - root_mean_squared_error: 0.1180 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1206
# Epoch 36/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0126 - root_mean_squared_error: 0.1124 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1193
# Epoch 37/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0135 - root_mean_squared_error: 0.1163INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 32s 616ms/step - loss: 0.0135 - root_mean_squared_error: 0.1160 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1083
# Epoch 38/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0130 - root_mean_squared_error: 0.1141INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 42s 809ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1050
# Epoch 39/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0138 - root_mean_squared_error: 0.1177INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 28s 542ms/step - loss: 0.0138 - root_mean_squared_error: 0.1177 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1045
# Epoch 40/50
# 53/53 [==============================] - 2s 43ms/step - loss: 0.0124 - root_mean_squared_error: 0.1114 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1212
# Epoch 41/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0120 - root_mean_squared_error: 0.1095 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1260
# Epoch 42/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0123 - root_mean_squared_error: 0.1109 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1161
# Epoch 43/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0123 - root_mean_squared_error: 0.1108 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 44/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0112 - root_mean_squared_error: 0.1060 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1147
# Epoch 45/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0114 - root_mean_squared_error: 0.1069INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 27s 517ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1037
# Epoch 46/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0120 - root_mean_squared_error: 0.1095 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1122
# Epoch 47/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1369
# Epoch 48/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0122 - root_mean_squared_error: 0.1106INFO:tensorflow:Assets written to: Greenland_LT4\assets
# 53/53 [==============================] - 26s 495ms/step - loss: 0.0122 - root_mean_squared_error: 0.1106 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1013
# Epoch 49/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0120 - root_mean_squared_error: 0.1098 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1033
# Epoch 50/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0123 - root_mean_squared_error: 0.1108 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1063

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 12.843520033359528 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Greenland_LT4/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 33ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.09767095724515948
# MAE : 0.07722087221062725

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       229203.390625     283162.646
# 1       244417.171875     212475.431
# 2       299010.718750     386546.857
# 3       384456.031250     547183.986
# 4       491552.281250     584596.262
# 5       589673.250000     584830.109
# 6       641421.625000     641562.292
# 7       657822.625000     734946.437
# 8       644508.312500     777596.225
# 9       605687.062500     687087.673
# 10      541952.500000     622337.816
# 11      426265.093750     467232.074
# 12      305467.625000     297495.641
# 13      277550.875000     268909.854
# 14      325284.656250     408072.791
# 15      409883.031250     552314.148
# 16      513758.125000     651062.408
# 17      608381.375000     695022.674
# 18      661771.500000     670974.305
# 19      678586.125000     710035.543
# 20      662444.687500     699672.538
# 21      621016.062500     730897.021
# 22      551819.312500     588598.988
# 23      432207.062500     281754.041
# 24      327168.437500     117830.266
# 25      307987.312500      81838.250
# 26      364963.156250     291418.462
# 27      469879.250000     452417.079
# 28      580332.812500     576361.148
# 29      661696.812500     676218.054
# 30      697795.875000     698410.066
# 31      697437.562500     696094.179
# 32      659843.750000     751102.742
# 33      592962.312500     765802.952
# 34      501568.500000     597649.311
# 35      355278.218750     376029.266
# 36      233201.781250     278536.574
# 37      222139.859375     285351.521
# 38      286804.968750     365256.138
# 39      387654.625000     488293.212
# 40      504232.218750     635073.900
# 41      611421.562500     684651.888
# 42      677242.875000     698053.275
# 43      699379.937500     846211.943
# 44      680229.875000     831596.370
# 45      626262.250000     834849.724
# 46      545131.812500     721350.515
# 47      395392.312500     459033.164
# 48      265834.781250     282045.909
# 49      250950.656250     270397.608
# 50      310301.593750     449910.973

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 39ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
