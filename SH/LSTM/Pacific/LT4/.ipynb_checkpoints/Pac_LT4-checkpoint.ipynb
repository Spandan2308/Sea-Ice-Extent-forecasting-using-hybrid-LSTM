# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Pacific_Extent = pd.read_excel(filepath, sheet_name='Pacific-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Pacific_Extent)
fp.date_time(Pacific_Extent)
# Out:
#           Extent       Date
# 0     668714.275 1979-01-01
# 1     566930.458 1979-02-01
# 2     688420.115 1979-03-01
# 3     859963.043 1979-04-01
# 4    1127120.160 1979-05-01
# ..           ...        ...
# 533  1134056.102 2023-06-01
# 534  1484824.377 2023-07-01
# 535  1671324.717 2023-08-01
# 536  1726376.097 2023-09-01
# 537  1690631.996 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Pacific_Extent['Extent'] = scaler.fit_transform(Pacific_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 4
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Pacific_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((523, 12, 1), (523,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Pacific_model_LT4/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2143 - root_mean_squared_error: 0.4629INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 21s 261ms/step - loss: 0.2143 - root_mean_squared_error: 0.4629 - val_loss: 0.1526 - val_root_mean_squared_error: 0.3907
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0804 - root_mean_squared_error: 0.2835INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 12s 230ms/step - loss: 0.0798 - root_mean_squared_error: 0.2825 - val_loss: 0.0294 - val_root_mean_squared_error: 0.1714
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0354 - root_mean_squared_error: 0.1882INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 12s 231ms/step - loss: 0.0354 - root_mean_squared_error: 0.1882 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1646
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0307 - root_mean_squared_error: 0.1753INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 13s 251ms/step - loss: 0.0307 - root_mean_squared_error: 0.1753 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1512
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0287 - root_mean_squared_error: 0.1693INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 12s 234ms/step - loss: 0.0287 - root_mean_squared_error: 0.1693 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1380
# Epoch 6/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0251 - root_mean_squared_error: 0.1585INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 13s 246ms/step - loss: 0.0247 - root_mean_squared_error: 0.1572 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1282
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0239 - root_mean_squared_error: 0.1546INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 13s 240ms/step - loss: 0.0239 - root_mean_squared_error: 0.1546 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1198
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0218 - root_mean_squared_error: 0.1478INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 11s 218ms/step - loss: 0.0218 - root_mean_squared_error: 0.1477 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1145
# Epoch 9/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0213 - root_mean_squared_error: 0.1458INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 13s 251ms/step - loss: 0.0212 - root_mean_squared_error: 0.1455 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1144
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0203 - root_mean_squared_error: 0.1425INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 12s 233ms/step - loss: 0.0203 - root_mean_squared_error: 0.1425 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1081
# Epoch 11/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0190 - root_mean_squared_error: 0.1377 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1094
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0216 - root_mean_squared_error: 0.1471INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 12s 230ms/step - loss: 0.0216 - root_mean_squared_error: 0.1468 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1053
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0200 - root_mean_squared_error: 0.1415INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 13s 258ms/step - loss: 0.0201 - root_mean_squared_error: 0.1418 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1028
# Epoch 14/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0197 - root_mean_squared_error: 0.1405INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 12s 227ms/step - loss: 0.0199 - root_mean_squared_error: 0.1410 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1023
# Epoch 15/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0181 - root_mean_squared_error: 0.1347INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 13s 245ms/step - loss: 0.0187 - root_mean_squared_error: 0.1367 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0999
# Epoch 16/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0186 - root_mean_squared_error: 0.1364INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 13s 249ms/step - loss: 0.0185 - root_mean_squared_error: 0.1359 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0998
# Epoch 17/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0167 - root_mean_squared_error: 0.1293INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 13s 256ms/step - loss: 0.0171 - root_mean_squared_error: 0.1307 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0981
# Epoch 18/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0180 - root_mean_squared_error: 0.1341 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 19/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0171 - root_mean_squared_error: 0.1309 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1009
# Epoch 20/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0171 - root_mean_squared_error: 0.1308INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 13s 254ms/step - loss: 0.0170 - root_mean_squared_error: 0.1303 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0933
# Epoch 21/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0159 - root_mean_squared_error: 0.1261 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0946
# Epoch 22/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0183 - root_mean_squared_error: 0.1352 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1038
# Epoch 23/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0165 - root_mean_squared_error: 0.1286INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 11s 210ms/step - loss: 0.0168 - root_mean_squared_error: 0.1298 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0904
# Epoch 24/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0150 - root_mean_squared_error: 0.1225 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0924
# Epoch 25/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0165 - root_mean_squared_error: 0.1285INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 13s 241ms/step - loss: 0.0165 - root_mean_squared_error: 0.1283 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0871
# Epoch 26/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0154 - root_mean_squared_error: 0.1240INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 12s 235ms/step - loss: 0.0156 - root_mean_squared_error: 0.1249 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0863
# Epoch 27/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0154 - root_mean_squared_error: 0.1240INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 13s 246ms/step - loss: 0.0154 - root_mean_squared_error: 0.1240 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0851
# Epoch 28/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0150 - root_mean_squared_error: 0.1223 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1005
# Epoch 29/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0148 - root_mean_squared_error: 0.1217INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 13s 255ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0824
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0129 - root_mean_squared_error: 0.1135INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 12s 223ms/step - loss: 0.0129 - root_mean_squared_error: 0.1135 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0813
# Epoch 31/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0129 - root_mean_squared_error: 0.1136 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0969
# Epoch 32/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0139 - root_mean_squared_error: 0.1178 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0879
# Epoch 33/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0132 - root_mean_squared_error: 0.1148INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 13s 249ms/step - loss: 0.0131 - root_mean_squared_error: 0.1147 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0790
# Epoch 34/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0122 - root_mean_squared_error: 0.1104INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 12s 226ms/step - loss: 0.0122 - root_mean_squared_error: 0.1104 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0776
# Epoch 35/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0121 - root_mean_squared_error: 0.1099 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0841
# Epoch 36/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0120 - root_mean_squared_error: 0.1093INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 10s 197ms/step - loss: 0.0120 - root_mean_squared_error: 0.1093 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0761
# Epoch 37/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0124 - root_mean_squared_error: 0.1113 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0761
# Epoch 38/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0115 - root_mean_squared_error: 0.1074INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0115 - root_mean_squared_error: 0.1072 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0748
# Epoch 39/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0118 - root_mean_squared_error: 0.1086INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 11s 202ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0739
# Epoch 40/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0114 - root_mean_squared_error: 0.1067INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0735
# Epoch 41/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0107 - root_mean_squared_error: 0.1032 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0749
# Epoch 42/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0100 - root_mean_squared_error: 0.1000INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 10s 188ms/step - loss: 0.0100 - root_mean_squared_error: 0.1000 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0724
# Epoch 43/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0116 - root_mean_squared_error: 0.1078 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0733
# Epoch 44/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0101 - root_mean_squared_error: 0.1006 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0820
# Epoch 45/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0106 - root_mean_squared_error: 0.1030INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 10s 197ms/step - loss: 0.0104 - root_mean_squared_error: 0.1020 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0716
# Epoch 46/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0103 - root_mean_squared_error: 0.1017INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 10s 187ms/step - loss: 0.0103 - root_mean_squared_error: 0.1017 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0708
# Epoch 47/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0097 - root_mean_squared_error: 0.0987INFO:tensorflow:Assets written to: Pacific_model_LT4\assets
# 53/53 [==============================] - 10s 186ms/step - loss: 0.0098 - root_mean_squared_error: 0.0992 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0701
# Epoch 48/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0109 - root_mean_squared_error: 0.1046 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0709
# Epoch 49/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0095 - root_mean_squared_error: 0.0975 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0737
# Epoch 50/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0092 - root_mean_squared_error: 0.0960 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0709

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 7.17690513531367 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Pacific_model_LT4/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 16ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.07367846747235768
# MAE : 0.058487407672915784

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.674153e+06    1890231.668
# 1        1.670454e+06    2203401.829
# 2        1.526791e+06    1960480.542
# 3        1.241274e+06    1264318.504
# 4        8.406186e+05     863206.294
# 5        5.081459e+05     635624.004
# 6        3.695652e+05     460009.672
# 7        4.596729e+05     610848.036
# 8        7.211744e+05     819257.445
# 9        1.066944e+06    1129627.707
# 10       1.396407e+06    1463383.236
# 11       1.677889e+06    1614536.727
# 12       1.859947e+06    1862498.612
# 13       1.902209e+06    2099349.296
# 14       1.729907e+06    1981614.046
# 15       1.428683e+06    1433022.369
# 16       9.386220e+05     826739.716
# 17       5.570442e+05     477145.887
# 18       4.321740e+05     314469.289
# 19       4.954120e+05     463134.749
# 20       7.367995e+05     946522.292
# 21       1.076517e+06    1309266.570
# 22       1.408312e+06    1507947.309
# 23       1.669147e+06    1804167.937
# 24       1.858511e+06    1908002.139
# 25       1.867335e+06    1892748.521
# 26       1.711142e+06    1601079.640
# 27       1.412403e+06    1327804.521
# 28       9.320894e+05     812074.231
# 29       5.593022e+05     493355.897
# 30       4.156215e+05     317229.330
# 31       5.357329e+05     425777.624
# 32       8.592929e+05     827172.620
# 33       1.216763e+06    1162367.223
# 34       1.507918e+06    1413734.261
# 35       1.716328e+06    1574257.849
# 36       1.827079e+06    1786961.251
# 37       1.776262e+06    1857942.866
# 38       1.565702e+06    1406291.588
# 39       1.241709e+06    1025555.371
# 40       8.297472e+05     632862.782
# 41       5.381819e+05     308194.756
# 42       4.031749e+05     194921.078
# 43       5.070022e+05     245569.900
# 44       7.963695e+05     533532.424
# 45       1.124892e+06     943124.529
# 46       1.375980e+06    1134056.102
# 47       1.552584e+06    1484824.377
# 48       1.648598e+06    1671324.717
# 49       1.577578e+06    1726376.097
# 50       1.377808e+06    1690631.996

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 16ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
