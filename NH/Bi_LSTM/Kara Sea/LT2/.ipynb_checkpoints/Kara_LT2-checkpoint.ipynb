# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Kara = pd.read_excel(filepath, sheet_name='Kara-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Kara)
fp.date_time(Kara)
# Out:
#          Extent       Date
# 0    917992.880 1979-01-01
# 1    917992.880 1979-02-01
# 2    917992.880 1979-03-01
# 3    917992.880 1979-04-01
# 4    917992.880 1979-05-01
# ..          ...        ...
# 533  728642.743 2023-06-01
# 534  437024.646 2023-07-01
# 535  202260.789 2023-08-01
# 536   98103.856 2023-09-01
# 537  260413.272 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Kara['Extent'] = scaler.fit_transform(Kara['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 2
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Kara['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((525, 12, 1), (525,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Kara_model_LT2/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.5063 - root_mean_squared_error: 0.7115INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 41s 535ms/step - loss: 0.5063 - root_mean_squared_error: 0.7115 - val_loss: 0.2276 - val_root_mean_squared_error: 0.4770
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0976 - root_mean_squared_error: 0.3124INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 34s 650ms/step - loss: 0.0976 - root_mean_squared_error: 0.3124 - val_loss: 0.1369 - val_root_mean_squared_error: 0.3700
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0756 - root_mean_squared_error: 0.2750INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 33s 638ms/step - loss: 0.0753 - root_mean_squared_error: 0.2743 - val_loss: 0.1145 - val_root_mean_squared_error: 0.3384
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0618 - root_mean_squared_error: 0.2487INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 33s 637ms/step - loss: 0.0618 - root_mean_squared_error: 0.2487 - val_loss: 0.0821 - val_root_mean_squared_error: 0.2866
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0455 - root_mean_squared_error: 0.2133INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 30s 579ms/step - loss: 0.0452 - root_mean_squared_error: 0.2126 - val_loss: 0.0632 - val_root_mean_squared_error: 0.2515
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0358 - root_mean_squared_error: 0.1891INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 32s 617ms/step - loss: 0.0358 - root_mean_squared_error: 0.1891 - val_loss: 0.0455 - val_root_mean_squared_error: 0.2134
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0291 - root_mean_squared_error: 0.1705INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 34s 657ms/step - loss: 0.0292 - root_mean_squared_error: 0.1709 - val_loss: 0.0371 - val_root_mean_squared_error: 0.1926
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0297 - root_mean_squared_error: 0.1723INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 35s 669ms/step - loss: 0.0295 - root_mean_squared_error: 0.1717 - val_loss: 0.0349 - val_root_mean_squared_error: 0.1869
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0282 - root_mean_squared_error: 0.1680INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 36s 696ms/step - loss: 0.0282 - root_mean_squared_error: 0.1680 - val_loss: 0.0317 - val_root_mean_squared_error: 0.1782
# Epoch 10/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0295 - root_mean_squared_error: 0.1718 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1833
# Epoch 11/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0280 - root_mean_squared_error: 0.1674 - val_loss: 0.0320 - val_root_mean_squared_error: 0.1788
# Epoch 12/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0267 - root_mean_squared_error: 0.1633 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1914
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0253 - root_mean_squared_error: 0.1591INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 36s 690ms/step - loss: 0.0253 - root_mean_squared_error: 0.1591 - val_loss: 0.0281 - val_root_mean_squared_error: 0.1675
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0250 - root_mean_squared_error: 0.1580INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 35s 667ms/step - loss: 0.0250 - root_mean_squared_error: 0.1580 - val_loss: 0.0276 - val_root_mean_squared_error: 0.1662
# Epoch 15/50
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0237 - root_mean_squared_error: 0.1540 - val_loss: 0.0304 - val_root_mean_squared_error: 0.1745
# Epoch 16/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0225 - root_mean_squared_error: 0.1501 - val_loss: 0.0276 - val_root_mean_squared_error: 0.1662
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0239 - root_mean_squared_error: 0.1545INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 37s 716ms/step - loss: 0.0239 - root_mean_squared_error: 0.1545 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1593
# Epoch 18/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0224 - root_mean_squared_error: 0.1497 - val_loss: 0.0262 - val_root_mean_squared_error: 0.1620
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0214 - root_mean_squared_error: 0.1462INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 46s 877ms/step - loss: 0.0214 - root_mean_squared_error: 0.1462 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1592
# Epoch 20/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0212 - root_mean_squared_error: 0.1457 - val_loss: 0.0264 - val_root_mean_squared_error: 0.1626
# Epoch 21/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0232 - root_mean_squared_error: 0.1524INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 38s 725ms/step - loss: 0.0232 - root_mean_squared_error: 0.1524 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1528
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0215 - root_mean_squared_error: 0.1465INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 40s 758ms/step - loss: 0.0215 - root_mean_squared_error: 0.1465 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1500
# Epoch 23/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0205 - root_mean_squared_error: 0.1433INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 37s 711ms/step - loss: 0.0205 - root_mean_squared_error: 0.1433 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1496
# Epoch 24/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0204 - root_mean_squared_error: 0.1427 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1527
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0204 - root_mean_squared_error: 0.1428INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 40s 759ms/step - loss: 0.0204 - root_mean_squared_error: 0.1428 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1467
# Epoch 26/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0195 - root_mean_squared_error: 0.1395INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 36s 696ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1463
# Epoch 27/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0194 - root_mean_squared_error: 0.1393 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1586
# Epoch 28/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0206 - root_mean_squared_error: 0.1436INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 36s 683ms/step - loss: 0.0206 - root_mean_squared_error: 0.1436 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1424
# Epoch 29/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0194 - root_mean_squared_error: 0.1394 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1448
# Epoch 30/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0187 - root_mean_squared_error: 0.1366 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1457
# Epoch 31/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0184 - root_mean_squared_error: 0.1355 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1573
# Epoch 32/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0185 - root_mean_squared_error: 0.1359INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 36s 696ms/step - loss: 0.0185 - root_mean_squared_error: 0.1359 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1378
# Epoch 33/50
# 53/53 [==============================] - 4s 78ms/step - loss: 0.0173 - root_mean_squared_error: 0.1317 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1432
# Epoch 34/50
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0177 - root_mean_squared_error: 0.1329 - val_loss: 0.0191 - val_root_mean_squared_error: 0.1382
# Epoch 35/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0170 - root_mean_squared_error: 0.1302INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 35s 680ms/step - loss: 0.0170 - root_mean_squared_error: 0.1302 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1359
# Epoch 36/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0168 - root_mean_squared_error: 0.1297 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1385
# Epoch 37/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0174 - root_mean_squared_error: 0.1321 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1645
# Epoch 38/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0172 - root_mean_squared_error: 0.1310INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 37s 712ms/step - loss: 0.0172 - root_mean_squared_error: 0.1310 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1348
# Epoch 39/50
# 53/53 [==============================] - 4s 81ms/step - loss: 0.0167 - root_mean_squared_error: 0.1291 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1380
# Epoch 40/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0174 - root_mean_squared_error: 0.1321INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 35s 670ms/step - loss: 0.0174 - root_mean_squared_error: 0.1321 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1340
# Epoch 41/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0160 - root_mean_squared_error: 0.1263INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 37s 715ms/step - loss: 0.0160 - root_mean_squared_error: 0.1263 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1316
# Epoch 42/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0155 - root_mean_squared_error: 0.1243 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1403
# Epoch 43/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0155 - root_mean_squared_error: 0.1244INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 44s 848ms/step - loss: 0.0156 - root_mean_squared_error: 0.1251 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1306
# Epoch 44/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0158 - root_mean_squared_error: 0.1256INFO:tensorflow:Assets written to: Kara_model_LT2\assets
# 53/53 [==============================] - 42s 804ms/step - loss: 0.0158 - root_mean_squared_error: 0.1256 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1299
# Epoch 45/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0159 - root_mean_squared_error: 0.1260 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1343
# Epoch 46/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0168 - root_mean_squared_error: 0.1298 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1430
# Epoch 47/50
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1365
# Epoch 48/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0162 - root_mean_squared_error: 0.1272 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1344
# Epoch 49/50
# 53/53 [==============================] - 4s 75ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1306
# Epoch 50/50
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0167 - root_mean_squared_error: 0.1293 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1327

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 17.460202236970265 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Kara_model_LT2/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 29ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.1406000279577773
# MAE : 0.10254848886121007

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 41ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
