# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Barents = pd.read_excel(filepath, sheet_name='Barents-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Barents)
fp.date_time(Barents)
# Out:
#           Extent       Date
# 0    1107873.946 1979-01-01
# 1    1211101.473 1979-02-01
# 2    1215128.770 1979-03-01
# 3    1233940.811 1979-04-01
# 4    1193061.566 1979-05-01
# ..           ...        ...
# 533   124025.343 2023-06-01
# 534    53107.426 2023-07-01
# 535    11242.827 2023-08-01
# 536     3272.024 2023-09-01
# 537    35079.225 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Barents['Extent'] = scaler.fit_transform(Barents['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 5
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Barents['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((522, 12, 1), (522,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Barents_model_LT5/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1750 - root_mean_squared_error: 0.4184INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 27s 313ms/step - loss: 0.1747 - root_mean_squared_error: 0.4180 - val_loss: 0.0391 - val_root_mean_squared_error: 0.1977
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0760 - root_mean_squared_error: 0.2757INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 15s 285ms/step - loss: 0.0757 - root_mean_squared_error: 0.2751 - val_loss: 0.0381 - val_root_mean_squared_error: 0.1952
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0507 - root_mean_squared_error: 0.2252INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 13s 249ms/step - loss: 0.0507 - root_mean_squared_error: 0.2252 - val_loss: 0.0330 - val_root_mean_squared_error: 0.1815
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0469 - root_mean_squared_error: 0.2166INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 13s 256ms/step - loss: 0.0474 - root_mean_squared_error: 0.2178 - val_loss: 0.0303 - val_root_mean_squared_error: 0.1740
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0449 - root_mean_squared_error: 0.2119INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 13s 251ms/step - loss: 0.0449 - root_mean_squared_error: 0.2119 - val_loss: 0.0278 - val_root_mean_squared_error: 0.1668
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0422 - root_mean_squared_error: 0.2054INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 12s 236ms/step - loss: 0.0424 - root_mean_squared_error: 0.2058 - val_loss: 0.0259 - val_root_mean_squared_error: 0.1609
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0410 - root_mean_squared_error: 0.2026INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 14s 264ms/step - loss: 0.0410 - root_mean_squared_error: 0.2026 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1567
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0390 - root_mean_squared_error: 0.1975INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 13s 250ms/step - loss: 0.0390 - root_mean_squared_error: 0.1975 - val_loss: 0.0231 - val_root_mean_squared_error: 0.1519
# Epoch 9/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0329 - root_mean_squared_error: 0.1813INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 11s 211ms/step - loss: 0.0333 - root_mean_squared_error: 0.1824 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1479
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0306 - root_mean_squared_error: 0.1748INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 11s 213ms/step - loss: 0.0306 - root_mean_squared_error: 0.1748 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1438
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0297 - root_mean_squared_error: 0.1722INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 13s 242ms/step - loss: 0.0299 - root_mean_squared_error: 0.1729 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1403
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0269 - root_mean_squared_error: 0.1640INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 12s 233ms/step - loss: 0.0269 - root_mean_squared_error: 0.1640 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1367
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0245 - root_mean_squared_error: 0.1566INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 13s 249ms/step - loss: 0.0245 - root_mean_squared_error: 0.1566 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1350
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0239 - root_mean_squared_error: 0.1545INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 14s 269ms/step - loss: 0.0239 - root_mean_squared_error: 0.1545 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1320
# Epoch 15/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0227 - root_mean_squared_error: 0.1508INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 13s 253ms/step - loss: 0.0226 - root_mean_squared_error: 0.1504 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1300
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0218 - root_mean_squared_error: 0.1476INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 12s 233ms/step - loss: 0.0218 - root_mean_squared_error: 0.1476 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1281
# Epoch 17/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0207 - root_mean_squared_error: 0.1437INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 15s 282ms/step - loss: 0.0208 - root_mean_squared_error: 0.1443 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1248
# Epoch 18/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0226 - root_mean_squared_error: 0.1503 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1252
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0201 - root_mean_squared_error: 0.1416INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 15s 292ms/step - loss: 0.0201 - root_mean_squared_error: 0.1416 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1214
# Epoch 20/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0194 - root_mean_squared_error: 0.1393INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 17s 322ms/step - loss: 0.0194 - root_mean_squared_error: 0.1392 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1201
# Epoch 21/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0198 - root_mean_squared_error: 0.1409INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 14s 273ms/step - loss: 0.0198 - root_mean_squared_error: 0.1409 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1198
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0205 - root_mean_squared_error: 0.1433INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 13s 251ms/step - loss: 0.0205 - root_mean_squared_error: 0.1433 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1181
# Epoch 23/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0188 - root_mean_squared_error: 0.1371 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1182
# Epoch 24/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0191 - root_mean_squared_error: 0.1383INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 10s 201ms/step - loss: 0.0188 - root_mean_squared_error: 0.1372 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1143
# Epoch 25/50
# 53/53 [==============================] - 1s 27ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1150
# Epoch 26/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0177 - root_mean_squared_error: 0.1331INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 12s 237ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1123
# Epoch 27/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0170 - root_mean_squared_error: 0.1304INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 11s 218ms/step - loss: 0.0170 - root_mean_squared_error: 0.1303 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1107
# Epoch 28/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0167 - root_mean_squared_error: 0.1291INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 12s 235ms/step - loss: 0.0166 - root_mean_squared_error: 0.1289 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 29/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0166 - root_mean_squared_error: 0.1288INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 13s 253ms/step - loss: 0.0166 - root_mean_squared_error: 0.1288 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1065
# Epoch 30/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0161 - root_mean_squared_error: 0.1267INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 13s 255ms/step - loss: 0.0163 - root_mean_squared_error: 0.1275 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1060
# Epoch 31/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0162 - root_mean_squared_error: 0.1273 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1118
# Epoch 32/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0157 - root_mean_squared_error: 0.1254INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 12s 229ms/step - loss: 0.0157 - root_mean_squared_error: 0.1254 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1034
# Epoch 33/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0162 - root_mean_squared_error: 0.1271INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 13s 254ms/step - loss: 0.0162 - root_mean_squared_error: 0.1271 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1022
# Epoch 34/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0154 - root_mean_squared_error: 0.1243INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 14s 261ms/step - loss: 0.0154 - root_mean_squared_error: 0.1243 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1016
# Epoch 35/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0155 - root_mean_squared_error: 0.1244 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1030
# Epoch 36/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0150 - root_mean_squared_error: 0.1226INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 13s 241ms/step - loss: 0.0150 - root_mean_squared_error: 0.1226 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1015
# Epoch 37/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0160 - root_mean_squared_error: 0.1264INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 14s 271ms/step - loss: 0.0160 - root_mean_squared_error: 0.1264 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1006
# Epoch 38/50
# 53/53 [==============================] - 2s 38ms/step - loss: 0.0154 - root_mean_squared_error: 0.1241 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1016
# Epoch 39/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0144 - root_mean_squared_error: 0.1201INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 13s 258ms/step - loss: 0.0145 - root_mean_squared_error: 0.1204 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1003
# Epoch 40/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0146 - root_mean_squared_error: 0.1210INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 13s 252ms/step - loss: 0.0146 - root_mean_squared_error: 0.1210 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0997
# Epoch 41/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0152 - root_mean_squared_error: 0.1233 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1061
# Epoch 42/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 43/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0143 - root_mean_squared_error: 0.1194INFO:tensorflow:Assets written to: Barents_model_LT5\assets
# 53/53 [==============================] - 14s 262ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0986
# Epoch 44/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0987
# Epoch 45/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0146 - root_mean_squared_error: 0.1210 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0994
# Epoch 46/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0146 - root_mean_squared_error: 0.1210 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0992
# Epoch 47/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1001
# Epoch 48/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0132 - root_mean_squared_error: 0.1151 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1019
# Epoch 49/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1066
# Epoch 50/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0988

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 8.306652120749156 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Barents_model_LT5/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 31ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.1012477252543522
# MAE : 0.08255108230452254

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       -19933.988281      14909.156
# 1        33385.265625      54595.378
# 2       155541.156250     242829.930
# 3       280469.750000     406860.687
# 4       403017.843750     605897.837
# 5       502648.000000     654073.790
# 6       550275.812500     701143.910
# 7       522282.718750     657891.340
# 8       412126.468750     432215.421
# 9       281355.437500     201834.787
# 10      150108.671875      55041.511
# 11       57026.394531       5387.468
# 12        7234.041504       1576.813
# 13       91462.617188      21681.895
# 14      272350.312500      37772.681
# 15      426586.843750     239568.531
# 16      547486.000000     427703.330
# 17      618102.125000     753043.012
# 18      619713.937500     764554.603
# 19      538278.000000     563799.961
# 20      417561.468750     444109.886
# 21      280715.937500     189669.492
# 22      141270.671875      63664.521
# 23       39339.886719       5984.539
# 24      -10718.060547       1192.062
# 25       34603.976562      25987.740
# 26      170670.328125     227374.130
# 27      312140.718750     498316.637
# 28      434328.093750     666292.874
# 29      527429.375000     673348.837
# 30      564470.187500     635756.948
# 31      531186.687500     673503.693
# 32      397871.843750     550922.786
# 33      254865.093750     116554.569
# 34      124252.171875      12012.356
# 35       30818.312500       5446.433
# 36      -13535.745117       2183.701
# 37      120283.000000      31883.576
# 38      296918.812500      98802.296
# 39      443638.062500     224779.107
# 40      553899.562500     287476.263
# 41      620837.625000     376683.928
# 42      625117.750000     571055.966
# 43      534936.312500     581039.946
# 44      424585.250000     376525.530
# 45      288330.562500     124025.343
# 46      145980.187500      53107.426
# 47       22273.828125      11242.827
# 48      -34248.246094       3272.024
# 49       23842.679688      35079.225

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 16ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
