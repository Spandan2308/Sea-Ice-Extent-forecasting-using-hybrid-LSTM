# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Baffin = pd.read_excel(filepath, sheet_name='Baffin-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Baffin)
fp.date_time(Baffin)
# Out:
#           Extent       Date
# 0    1090625.815 1979-01-01
# 1    1157634.866 1979-02-01
# 2    1299583.477 1979-03-01
# 3    1137194.680 1979-04-01
# 4     983083.453 1979-05-01
# ..           ...        ...
# 533   781460.891 2023-06-01
# 534   331845.048 2023-07-01
# 535    99334.625 2023-08-01
# 536    49359.723 2023-09-01
# 537    85693.282 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Baffin['Extent'] = scaler.fit_transform(Baffin['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 12
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Baffin['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((515, 12, 1), (515,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Baffin_model_LT12/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2121 - root_mean_squared_error: 0.4605INFO:tensorflow:Assets written to: Baffin_model_LT12\assets
# 53/53 [==============================] - 35s 449ms/step - loss: 0.2096 - root_mean_squared_error: 0.4578 - val_loss: 0.1256 - val_root_mean_squared_error: 0.3544
# Epoch 2/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0911 - root_mean_squared_error: 0.3019INFO:tensorflow:Assets written to: Baffin_model_LT12\assets
# 53/53 [==============================] - 23s 433ms/step - loss: 0.0903 - root_mean_squared_error: 0.3006 - val_loss: 0.0702 - val_root_mean_squared_error: 0.2650
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0727 - root_mean_squared_error: 0.2697INFO:tensorflow:Assets written to: Baffin_model_LT12\assets
# 53/53 [==============================] - 22s 415ms/step - loss: 0.0727 - root_mean_squared_error: 0.2697 - val_loss: 0.0613 - val_root_mean_squared_error: 0.2475
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0602 - root_mean_squared_error: 0.2454INFO:tensorflow:Assets written to: Baffin_model_LT12\assets
# 53/53 [==============================] - 22s 418ms/step - loss: 0.0598 - root_mean_squared_error: 0.2446 - val_loss: 0.0507 - val_root_mean_squared_error: 0.2251
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0422 - root_mean_squared_error: 0.2055INFO:tensorflow:Assets written to: Baffin_model_LT12\assets
# 53/53 [==============================] - 22s 429ms/step - loss: 0.0420 - root_mean_squared_error: 0.2049 - val_loss: 0.0316 - val_root_mean_squared_error: 0.1779
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0238 - root_mean_squared_error: 0.1543INFO:tensorflow:Assets written to: Baffin_model_LT12\assets
# 53/53 [==============================] - 22s 427ms/step - loss: 0.0238 - root_mean_squared_error: 0.1543 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0987
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0141 - root_mean_squared_error: 0.1189INFO:tensorflow:Assets written to: Baffin_model_LT12\assets
# 53/53 [==============================] - 22s 426ms/step - loss: 0.0141 - root_mean_squared_error: 0.1189 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0752
# Epoch 8/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0136 - root_mean_squared_error: 0.1166 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 9/50
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0122 - root_mean_squared_error: 0.1103 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0843
# Epoch 10/50
# 53/53 [==============================] - 2s 41ms/step - loss: 0.0100 - root_mean_squared_error: 0.1001 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0804
# Epoch 11/50
# 53/53 [==============================] - 2s 40ms/step - loss: 0.0112 - root_mean_squared_error: 0.1056 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1059
# Epoch 12/50
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0099 - root_mean_squared_error: 0.0993 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1354
# Epoch 13/50
# 53/53 [==============================] - 2s 40ms/step - loss: 0.0096 - root_mean_squared_error: 0.0979 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0853
# Epoch 14/50
# 53/53 [==============================] - 2s 42ms/step - loss: 0.0097 - root_mean_squared_error: 0.0983 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1295
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0101 - root_mean_squared_error: 0.1007INFO:tensorflow:Assets written to: Baffin_model_LT12\assets
# 53/53 [==============================] - 25s 488ms/step - loss: 0.0101 - root_mean_squared_error: 0.1007 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0730
# Epoch 16/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0089 - root_mean_squared_error: 0.0945 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1083
# Epoch 17/50
# 53/53 [==============================] - 2s 38ms/step - loss: 0.0089 - root_mean_squared_error: 0.0941 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1056
# Epoch 18/50
# 53/53 [==============================] - 2s 41ms/step - loss: 0.0092 - root_mean_squared_error: 0.0961 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0813
# Epoch 19/50
# 53/53 [==============================] - 2s 41ms/step - loss: 0.0092 - root_mean_squared_error: 0.0959 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0970
# Epoch 20/50
# 53/53 [==============================] - 2s 47ms/step - loss: 0.0085 - root_mean_squared_error: 0.0921 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0913
# Epoch 21/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0075 - root_mean_squared_error: 0.0866INFO:tensorflow:Assets written to: Baffin_model_LT12\assets
# 53/53 [==============================] - 36s 693ms/step - loss: 0.0075 - root_mean_squared_error: 0.0864 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0551
# Epoch 22/50
# 53/53 [==============================] - 2s 41ms/step - loss: 0.0091 - root_mean_squared_error: 0.0955 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0922
# Epoch 23/50
# 53/53 [==============================] - 2s 47ms/step - loss: 0.0077 - root_mean_squared_error: 0.0877 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0905
# Epoch 24/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0079 - root_mean_squared_error: 0.0888 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1099
# Epoch 25/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0079 - root_mean_squared_error: 0.0887 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0842
# Epoch 26/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0079 - root_mean_squared_error: 0.0890 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0862
# Epoch 27/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.0072 - root_mean_squared_error: 0.0851 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1126
# Epoch 28/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0068 - root_mean_squared_error: 0.0826 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0697
# Epoch 29/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0079 - root_mean_squared_error: 0.0890 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1056
# Epoch 30/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.0073 - root_mean_squared_error: 0.0853 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0709
# Epoch 31/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0067 - root_mean_squared_error: 0.0819 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613
# Epoch 32/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0067 - root_mean_squared_error: 0.0821 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0960
# Epoch 33/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0072 - root_mean_squared_error: 0.0849 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1306
# Epoch 34/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0074 - root_mean_squared_error: 0.0859INFO:tensorflow:Assets written to: Baffin_model_LT12\assets
# 53/53 [==============================] - 37s 705ms/step - loss: 0.0073 - root_mean_squared_error: 0.0856 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0530
# Epoch 35/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0067 - root_mean_squared_error: 0.0817 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0839
# Epoch 36/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0070 - root_mean_squared_error: 0.0837 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0817
# Epoch 37/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0066 - root_mean_squared_error: 0.0810 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0713
# Epoch 38/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0069 - root_mean_squared_error: 0.0830 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0801
# Epoch 39/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0057 - root_mean_squared_error: 0.0758 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0777
# Epoch 40/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0061 - root_mean_squared_error: 0.0782 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0553
# Epoch 41/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0063 - root_mean_squared_error: 0.0791 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0717
# Epoch 42/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0071 - root_mean_squared_error: 0.0840 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0538
# Epoch 43/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0070 - root_mean_squared_error: 0.0834 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0697
# Epoch 44/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0067 - root_mean_squared_error: 0.0820 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0595
# Epoch 45/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0059 - root_mean_squared_error: 0.0771INFO:tensorflow:Assets written to: Baffin_model_LT12\assets
# 53/53 [==============================] - 28s 537ms/step - loss: 0.0059 - root_mean_squared_error: 0.0770 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0517
# Epoch 46/50
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0064 - root_mean_squared_error: 0.0799 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0634
# Epoch 47/50
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0065 - root_mean_squared_error: 0.0803 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0884
# Epoch 48/50
# 53/53 [==============================] - 2s 47ms/step - loss: 0.0059 - root_mean_squared_error: 0.0767 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0686
# Epoch 49/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.0066 - root_mean_squared_error: 0.0811 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0782
# Epoch 50/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0057 - root_mean_squared_error: 0.0754 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0717

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 6.5583018859227495 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Baffin_model_LT12/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 16ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.055394960082627086
# MAE : 0.043323212172922024

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.145903e+06    1036981.003
# 1        9.600506e+05     847489.150
# 2        5.970238e+05     619129.338
# 3        2.295474e+05     195688.491
# 4        5.550082e+04      36670.811
# 5        3.927605e+04      31777.310
# 6        1.637147e+05      82762.022
# 7        4.450649e+05     400043.823
# 8        7.906858e+05     733089.555
# 9        1.022165e+06     917362.266
# 10       1.181198e+06    1040584.040
# 11       1.226948e+06    1147997.675
# 12       1.142128e+06    1074255.327
# 13       9.274519e+05     875527.315
# 14       5.847186e+05     629820.756
# 15       2.766947e+05     204308.900
# 16       7.752848e+04      45059.062
# 17       2.309502e+04      33770.277
# 18       1.148733e+05      64135.631
# 19       5.063642e+05     400581.715
# 20       8.156259e+05     698631.451
# 21       1.018668e+06     973313.225
# 22       1.113094e+06    1335339.087
# 23       1.138290e+06    1429096.704
# 24       1.086399e+06    1206542.314
# 25       9.273046e+05    1079292.433
# 26       6.034775e+05     788101.638
# 27       2.884011e+05     397326.270
# 28       8.730425e+04      97802.348
# 29       3.299463e+04      62212.219
# 30       1.287946e+05     154051.600
# 31       4.900615e+05     610663.893
# 32       7.756010e+05     756679.164
# 33       1.002069e+06     962270.215
# 34       1.205404e+06    1235154.518
# 35       1.300987e+06    1161744.519
# 36       1.229972e+06    1136918.669
# 37       1.042772e+06     995852.026
# 38       6.963739e+05     781460.891
# 39       3.758518e+05     331845.048
# 40       1.191482e+05      99334.625
# 41       9.183018e+03      49359.723
# 42       7.993358e+04      85693.282

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 22ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
