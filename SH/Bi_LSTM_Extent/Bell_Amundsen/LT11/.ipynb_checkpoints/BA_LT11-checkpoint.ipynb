# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bell_Amundsen_Extent = pd.read_excel(filepath, sheet_name='Bell-Amundsen-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Bell_Amundsen_Extent)
fp.date_time(Bell_Amundsen_Extent)
# Out:
#           Extent       Date
# 0    1179855.894 1979-01-01
# 1     879585.254 1979-02-01
# 2     791619.096 1979-03-01
# 3    1254912.071 1979-04-01
# 4    1620142.247 1979-05-01
# ..           ...        ...
# 533  1556568.455 2023-06-01
# 534  1917507.979 2023-07-01
# 535  2601630.327 2023-08-01
# 536  2534223.780 2023-09-01
# 537  2373004.525 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bell_Amundsen_Extent['Extent'] = scaler.fit_transform(Bell_Amundsen_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 11
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bell_Amundsen_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((516, 12, 1), (516,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Bell_Amund_model_LT11/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2101 - root_mean_squared_error: 0.4583INFO:tensorflow:Assets written to: Bell_Amund_model_LT11\assets
# 53/53 [==============================] - 48s 637ms/step - loss: 0.2101 - root_mean_squared_error: 0.4583 - val_loss: 0.1080 - val_root_mean_squared_error: 0.3286
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0632 - root_mean_squared_error: 0.2515INFO:tensorflow:Assets written to: Bell_Amund_model_LT11\assets
# 53/53 [==============================] - 32s 609ms/step - loss: 0.0632 - root_mean_squared_error: 0.2515 - val_loss: 0.0593 - val_root_mean_squared_error: 0.2436
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0480 - root_mean_squared_error: 0.2190INFO:tensorflow:Assets written to: Bell_Amund_model_LT11\assets
# 53/53 [==============================] - 25s 474ms/step - loss: 0.0480 - root_mean_squared_error: 0.2190 - val_loss: 0.0490 - val_root_mean_squared_error: 0.2213
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0382 - root_mean_squared_error: 0.1955INFO:tensorflow:Assets written to: Bell_Amund_model_LT11\assets
# 53/53 [==============================] - 25s 488ms/step - loss: 0.0383 - root_mean_squared_error: 0.1957 - val_loss: 0.0398 - val_root_mean_squared_error: 0.1994
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0293 - root_mean_squared_error: 0.1711INFO:tensorflow:Assets written to: Bell_Amund_model_LT11\assets
# 53/53 [==============================] - 26s 494ms/step - loss: 0.0293 - root_mean_squared_error: 0.1711 - val_loss: 0.0302 - val_root_mean_squared_error: 0.1739
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0231 - root_mean_squared_error: 0.1519INFO:tensorflow:Assets written to: Bell_Amund_model_LT11\assets
# 53/53 [==============================] - 27s 515ms/step - loss: 0.0231 - root_mean_squared_error: 0.1519 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1617
# Epoch 7/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0167 - root_mean_squared_error: 0.1293 - val_loss: 0.0365 - val_root_mean_squared_error: 0.1910
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0169 - root_mean_squared_error: 0.1301INFO:tensorflow:Assets written to: Bell_Amund_model_LT11\assets
# 53/53 [==============================] - 26s 499ms/step - loss: 0.0169 - root_mean_squared_error: 0.1301 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1433
# Epoch 9/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0139 - root_mean_squared_error: 0.1180 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1491
# Epoch 10/50
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0139 - root_mean_squared_error: 0.1179 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1451
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0117 - root_mean_squared_error: 0.1080INFO:tensorflow:Assets written to: Bell_Amund_model_LT11\assets
# 53/53 [==============================] - 27s 515ms/step - loss: 0.0117 - root_mean_squared_error: 0.1080 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1279
# Epoch 12/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0120 - root_mean_squared_error: 0.1094 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1604
# Epoch 13/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0132 - root_mean_squared_error: 0.1148 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1281
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0107 - root_mean_squared_error: 0.1033INFO:tensorflow:Assets written to: Bell_Amund_model_LT11\assets
# 53/53 [==============================] - 26s 501ms/step - loss: 0.0107 - root_mean_squared_error: 0.1033 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1234
# Epoch 15/50
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0108 - root_mean_squared_error: 0.1038 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1263
# Epoch 16/50
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0110 - root_mean_squared_error: 0.1049 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1297
# Epoch 17/50
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0101 - root_mean_squared_error: 0.1006 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1547
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0101 - root_mean_squared_error: 0.1004INFO:tensorflow:Assets written to: Bell_Amund_model_LT11\assets
# 53/53 [==============================] - 28s 534ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1216
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0106 - root_mean_squared_error: 0.1029INFO:tensorflow:Assets written to: Bell_Amund_model_LT11\assets
# 53/53 [==============================] - 25s 487ms/step - loss: 0.0106 - root_mean_squared_error: 0.1029 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1156
# Epoch 20/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0098 - root_mean_squared_error: 0.0990 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1161
# Epoch 21/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0093 - root_mean_squared_error: 0.0962 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1427
# Epoch 22/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0096 - root_mean_squared_error: 0.0982 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1206
# Epoch 23/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0102 - root_mean_squared_error: 0.1010INFO:tensorflow:Assets written to: Bell_Amund_model_LT11\assets
# 53/53 [==============================] - 23s 433ms/step - loss: 0.0101 - root_mean_squared_error: 0.1007 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1145
# Epoch 24/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0099 - root_mean_squared_error: 0.0993 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1164
# Epoch 25/50
# 53/53 [==============================] - 2s 40ms/step - loss: 0.0091 - root_mean_squared_error: 0.0956 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1245
# Epoch 26/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0096 - root_mean_squared_error: 0.0980INFO:tensorflow:Assets written to: Bell_Amund_model_LT11\assets
# 53/53 [==============================] - 24s 453ms/step - loss: 0.0096 - root_mean_squared_error: 0.0980 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1092
# Epoch 27/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0097 - root_mean_squared_error: 0.0983 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1143
# Epoch 28/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0094 - root_mean_squared_error: 0.0971 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1258
# Epoch 29/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0084 - root_mean_squared_error: 0.0918INFO:tensorflow:Assets written to: Bell_Amund_model_LT11\assets
# 53/53 [==============================] - 26s 503ms/step - loss: 0.0084 - root_mean_squared_error: 0.0918 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1090
# Epoch 30/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0099 - root_mean_squared_error: 0.0996 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1161
# Epoch 31/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0092 - root_mean_squared_error: 0.0960 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1249
# Epoch 32/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0095 - root_mean_squared_error: 0.0974 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1092
# Epoch 33/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0093 - root_mean_squared_error: 0.0964 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1319
# Epoch 34/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0093 - root_mean_squared_error: 0.0964 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1152
# Epoch 35/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0086 - root_mean_squared_error: 0.0925 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1208
# Epoch 36/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0092 - root_mean_squared_error: 0.0961INFO:tensorflow:Assets written to: Bell_Amund_model_LT11\assets
# 53/53 [==============================] - 26s 495ms/step - loss: 0.0092 - root_mean_squared_error: 0.0961 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1087
# Epoch 37/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0085 - root_mean_squared_error: 0.0924 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1169
# Epoch 38/50
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0088 - root_mean_squared_error: 0.0938 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1240
# Epoch 39/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0092 - root_mean_squared_error: 0.0959 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133
# Epoch 40/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0091 - root_mean_squared_error: 0.0952 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 41/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0081 - root_mean_squared_error: 0.0901 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1095
# Epoch 42/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0087 - root_mean_squared_error: 0.0934 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1100
# Epoch 43/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0091 - root_mean_squared_error: 0.0951 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1295
# Epoch 44/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0089 - root_mean_squared_error: 0.0944 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1097
# Epoch 45/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0088 - root_mean_squared_error: 0.0936INFO:tensorflow:Assets written to: Bell_Amund_model_LT11\assets
# 53/53 [==============================] - 27s 510ms/step - loss: 0.0088 - root_mean_squared_error: 0.0936 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1073
# Epoch 46/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0086 - root_mean_squared_error: 0.0930 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1076
# Epoch 47/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0088 - root_mean_squared_error: 0.0940 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1226
# Epoch 48/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0086 - root_mean_squared_error: 0.0929 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1137
# Epoch 49/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0089 - root_mean_squared_error: 0.0942 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1085
# Epoch 50/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0081 - root_mean_squared_error: 0.0898 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1103

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 9.317673500378927 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bell_Amund_model_LT11/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 32ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.09149696474739247
# MAE : 0.07400220311981032

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        3.225554e+05     439855.813
# 1        6.355088e+05     807857.307
# 2        1.182184e+06    1184280.145
# 3        1.567731e+06    1468308.405
# 4        1.918669e+06    1540851.607
# 5        2.064598e+06    1989099.836
# 6        2.118572e+06    2096990.761
# 7        2.034876e+06    2080961.032
# 8        1.724728e+06    1695704.661
# 9        1.318891e+06    1533888.370
# 10       8.836681e+05    1038332.675
# 11       5.386834e+05     602954.621
# 12       5.168831e+05     895484.288
# 13       8.162604e+05    1070622.700
# 14       1.252031e+06    1532457.922
# 15       1.547002e+06    1703762.123
# 16       1.873779e+06    1855079.122
# 17       2.118996e+06    2291960.639
# 18       2.246924e+06    2114120.417
# 19       2.113516e+06    1995818.759
# 20       1.880935e+06    1653379.997
# 21       1.498946e+06    1070814.995
# 22       1.046207e+06     689443.815
# 23       7.498329e+05     401148.663
# 24       7.036888e+05     346558.057
# 25       1.029778e+06     599477.678
# 26       1.389559e+06     765764.905
# 27       1.661343e+06    1304133.179
# 28       1.963600e+06    1598436.099
# 29       2.091124e+06    1763844.414
# 30       2.078899e+06    1979139.524
# 31       1.897702e+06    1937348.663
# 32       1.497490e+06    1833093.342
# 33       1.056290e+06    1089676.114
# 34       6.286128e+05     453484.731
# 35       3.682751e+05     251559.554
# 36       3.358362e+05     351294.657
# 37       4.903171e+05     702389.714
# 38       9.851887e+05    1185169.054
# 39       1.505124e+06    1556568.455
# 40       1.845029e+06    1917507.979
# 41       2.091735e+06    2601630.327
# 42       2.208462e+06    2534223.780
# 43       2.172758e+06    2373004.525

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 35ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
