# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Pacific_Extent = pd.read_excel(filepath, sheet_name='Pacific-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Pacific_Extent)
fp.date_time(Pacific_Extent)
# Out:
#           Extent       Date
# 0     668714.275 1979-01-01
# 1     566930.458 1979-02-01
# 2     688420.115 1979-03-01
# 3     859963.043 1979-04-01
# 4    1127120.160 1979-05-01
# ..           ...        ...
# 533  1134056.102 2023-06-01
# 534  1484824.377 2023-07-01
# 535  1671324.717 2023-08-01
# 536  1726376.097 2023-09-01
# 537  1690631.996 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Pacific_Extent['Extent'] = scaler.fit_transform(Pacific_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 6
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Pacific_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((521, 12, 1), (521,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Pacific_model_LT6/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2309 - root_mean_squared_error: 0.4805INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 17s 212ms/step - loss: 0.2312 - root_mean_squared_error: 0.4808 - val_loss: 0.2023 - val_root_mean_squared_error: 0.4498
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1053 - root_mean_squared_error: 0.3245INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 192ms/step - loss: 0.1053 - root_mean_squared_error: 0.3245 - val_loss: 0.0552 - val_root_mean_squared_error: 0.2350
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0562 - root_mean_squared_error: 0.2371INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0560 - root_mean_squared_error: 0.2367 - val_loss: 0.0492 - val_root_mean_squared_error: 0.2219
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0532 - root_mean_squared_error: 0.2306INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 191ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300 - val_loss: 0.0476 - val_root_mean_squared_error: 0.2181
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0497 - root_mean_squared_error: 0.2228INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 192ms/step - loss: 0.0497 - root_mean_squared_error: 0.2228 - val_loss: 0.0464 - val_root_mean_squared_error: 0.2154
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0468 - root_mean_squared_error: 0.2163INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 186ms/step - loss: 0.0468 - root_mean_squared_error: 0.2163 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2010
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0421 - root_mean_squared_error: 0.2052INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 197ms/step - loss: 0.0419 - root_mean_squared_error: 0.2047 - val_loss: 0.0372 - val_root_mean_squared_error: 0.1928
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0378 - root_mean_squared_error: 0.1945INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 187ms/step - loss: 0.0378 - root_mean_squared_error: 0.1945 - val_loss: 0.0310 - val_root_mean_squared_error: 0.1760
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0330 - root_mean_squared_error: 0.1815INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 200ms/step - loss: 0.0330 - root_mean_squared_error: 0.1815 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1551
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0249 - root_mean_squared_error: 0.1579INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 190ms/step - loss: 0.0249 - root_mean_squared_error: 0.1579 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1295
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0193 - root_mean_squared_error: 0.1389INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 190ms/step - loss: 0.0192 - root_mean_squared_error: 0.1386 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1156
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0156 - root_mean_squared_error: 0.1250INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 187ms/step - loss: 0.0156 - root_mean_squared_error: 0.1250 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1113
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0152 - root_mean_squared_error: 0.1232INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0151 - root_mean_squared_error: 0.1230 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1017
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0142 - root_mean_squared_error: 0.1193INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 192ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0998
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0145 - root_mean_squared_error: 0.1205INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 188ms/step - loss: 0.0145 - root_mean_squared_error: 0.1205 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0976
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0138 - root_mean_squared_error: 0.1176INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 195ms/step - loss: 0.0138 - root_mean_squared_error: 0.1176 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0971
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0128 - root_mean_squared_error: 0.1133INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 190ms/step - loss: 0.0128 - root_mean_squared_error: 0.1133 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0947
# Epoch 18/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0132 - root_mean_squared_error: 0.1150 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0960
# Epoch 19/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0126 - root_mean_squared_error: 0.1122INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 184ms/step - loss: 0.0125 - root_mean_squared_error: 0.1118 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0927
# Epoch 20/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0110 - root_mean_squared_error: 0.1047INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0917
# Epoch 21/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0115 - root_mean_squared_error: 0.1073 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0923
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0117 - root_mean_squared_error: 0.1082INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0117 - root_mean_squared_error: 0.1082 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0873
# Epoch 23/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0108 - root_mean_squared_error: 0.1038 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0964
# Epoch 24/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0117 - root_mean_squared_error: 0.1084 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0997
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0105 - root_mean_squared_error: 0.1025INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 187ms/step - loss: 0.0105 - root_mean_squared_error: 0.1025 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 26/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0106 - root_mean_squared_error: 0.1028 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 27/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0094 - root_mean_squared_error: 0.0969 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0891
# Epoch 28/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0098 - root_mean_squared_error: 0.0992 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0958
# Epoch 29/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0090 - root_mean_squared_error: 0.0950INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 194ms/step - loss: 0.0090 - root_mean_squared_error: 0.0950 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0846
# Epoch 30/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0101 - root_mean_squared_error: 0.1003 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0863
# Epoch 31/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0090 - root_mean_squared_error: 0.0951 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0952
# Epoch 32/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0095 - root_mean_squared_error: 0.0974INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 192ms/step - loss: 0.0095 - root_mean_squared_error: 0.0974 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0827
# Epoch 33/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0092 - root_mean_squared_error: 0.0958 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0880
# Epoch 34/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0095 - root_mean_squared_error: 0.0975 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0841
# Epoch 35/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0088 - root_mean_squared_error: 0.0938 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0850
# Epoch 36/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0090 - root_mean_squared_error: 0.0948 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0858
# Epoch 37/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0084 - root_mean_squared_error: 0.0917INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 186ms/step - loss: 0.0084 - root_mean_squared_error: 0.0917 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0804
# Epoch 38/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0087 - root_mean_squared_error: 0.0931 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0814
# Epoch 39/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0091 - root_mean_squared_error: 0.0952 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0815
# Epoch 40/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0087 - root_mean_squared_error: 0.0935INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 198ms/step - loss: 0.0087 - root_mean_squared_error: 0.0935 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0795
# Epoch 41/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0085 - root_mean_squared_error: 0.0920 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0811
# Epoch 42/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0087 - root_mean_squared_error: 0.0932 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0808
# Epoch 43/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0085 - root_mean_squared_error: 0.0920INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0085 - root_mean_squared_error: 0.0920 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0775
# Epoch 44/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0080 - root_mean_squared_error: 0.0894 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0804
# Epoch 45/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0084 - root_mean_squared_error: 0.0917 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 46/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0081 - root_mean_squared_error: 0.0897 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0795
# Epoch 47/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0077 - root_mean_squared_error: 0.0876 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0783
# Epoch 48/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0084 - root_mean_squared_error: 0.0917 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0847
# Epoch 49/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0073 - root_mean_squared_error: 0.0855 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0785
# Epoch 50/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0077 - root_mean_squared_error: 0.0877INFO:tensorflow:Assets written to: Pacific_model_LT6\assets
# 53/53 [==============================] - 10s 186ms/step - loss: 0.0077 - root_mean_squared_error: 0.0877 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0771

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 5.269987098375956 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Pacific_model_LT6/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 24ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.059775833754956875
# MAE : 0.046070001110494314

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.680598e+06    1960480.542
# 1        1.356362e+06    1264318.504
# 2        9.470212e+05     863206.294
# 3        5.918892e+05     635624.004
# 4        4.198906e+05     460009.672
# 5        4.827388e+05     610848.036
# 6        9.003569e+05     819257.445
# 7        1.230278e+06    1129627.707
# 8        1.429086e+06    1463383.236
# 9        1.623108e+06    1614536.727
# 10       1.815813e+06    1862498.612
# 11       1.931143e+06    2099349.296
# 12       1.784456e+06    1981614.046
# 13       1.360359e+06    1433022.369
# 14       8.575937e+05     826739.716
# 15       5.229122e+05     477145.887
# 16       3.543657e+05     314469.289
# 17       4.733618e+05     463134.749
# 18       9.759589e+05     946522.292
# 19       1.287437e+06    1309266.570
# 20       1.512653e+06    1507947.309
# 21       1.713373e+06    1804167.937
# 22       1.895386e+06    1908002.139
# 23       1.953309e+06    1892748.521
# 24       1.784035e+06    1601079.640
# 25       1.397654e+06    1327804.521
# 26       9.185046e+05     812074.231
# 27       5.396266e+05     493355.897
# 28       3.561265e+05     317229.330
# 29       3.865502e+05     425777.624
# 30       8.634343e+05     827172.620
# 31       1.307008e+06    1162367.223
# 32       1.506000e+06    1413734.261
# 33       1.687454e+06    1574257.849
# 34       1.860468e+06    1786961.251
# 35       1.885782e+06    1857942.866
# 36       1.631151e+06    1406291.588
# 37       1.235760e+06    1025555.371
# 38       8.175889e+05     632862.782
# 39       5.767034e+05     308194.756
# 40       4.543719e+05     194921.078
# 41       5.342539e+05     245569.900
# 42       8.487051e+05     533532.424
# 43       1.219320e+06     943124.529
# 44       1.403285e+06    1134056.102
# 45       1.561766e+06    1484824.377
# 46       1.711465e+06    1671324.717
# 47       1.752060e+06    1726376.097
# 48       1.541226e+06    1690631.996

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 16ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
