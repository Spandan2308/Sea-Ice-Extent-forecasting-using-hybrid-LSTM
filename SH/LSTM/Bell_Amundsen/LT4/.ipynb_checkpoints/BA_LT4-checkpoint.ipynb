# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bell_Amundsen_Extent = pd.read_excel(filepath, sheet_name='Bell-Amundsen-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Bell_Amundsen_Extent)
fp.date_time(Bell_Amundsen_Extent)
# Out:
#           Extent       Date
# 0    1179855.894 1979-01-01
# 1     879585.254 1979-02-01
# 2     791619.096 1979-03-01
# 3    1254912.071 1979-04-01
# 4    1620142.247 1979-05-01
# ..           ...        ...
# 533  1556568.455 2023-06-01
# 534  1917507.979 2023-07-01
# 535  2601630.327 2023-08-01
# 536  2534223.780 2023-09-01
# 537  2373004.525 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bell_Amundsen_Extent['Extent'] = scaler.fit_transform(Bell_Amundsen_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 4
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bell_Amundsen_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((523, 12, 1), (523,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Bell_Amund_model_LT4/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.2300 - root_mean_squared_error: 0.4795INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 13s 165ms/step - loss: 0.2288 - root_mean_squared_error: 0.4783 - val_loss: 0.1840 - val_root_mean_squared_error: 0.4289
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0774 - root_mean_squared_error: 0.2782INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 155ms/step - loss: 0.0774 - root_mean_squared_error: 0.2782 - val_loss: 0.0510 - val_root_mean_squared_error: 0.2258
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0376 - root_mean_squared_error: 0.1938INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 156ms/step - loss: 0.0376 - root_mean_squared_error: 0.1939 - val_loss: 0.0463 - val_root_mean_squared_error: 0.2151
# Epoch 4/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0345 - root_mean_squared_error: 0.1858INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 152ms/step - loss: 0.0349 - root_mean_squared_error: 0.1868 - val_loss: 0.0431 - val_root_mean_squared_error: 0.2076
# Epoch 5/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0313 - root_mean_squared_error: 0.1769INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 148ms/step - loss: 0.0313 - root_mean_squared_error: 0.1769 - val_loss: 0.0397 - val_root_mean_squared_error: 0.1993
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0289 - root_mean_squared_error: 0.1701INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 7s 137ms/step - loss: 0.0289 - root_mean_squared_error: 0.1701 - val_loss: 0.0371 - val_root_mean_squared_error: 0.1925
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0272 - root_mean_squared_error: 0.1650INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 152ms/step - loss: 0.0271 - root_mean_squared_error: 0.1646 - val_loss: 0.0362 - val_root_mean_squared_error: 0.1903
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0252 - root_mean_squared_error: 0.1587INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 146ms/step - loss: 0.0252 - root_mean_squared_error: 0.1586 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1832
# Epoch 9/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0243 - root_mean_squared_error: 0.1558INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 7s 143ms/step - loss: 0.0244 - root_mean_squared_error: 0.1562 - val_loss: 0.0326 - val_root_mean_squared_error: 0.1805
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0229 - root_mean_squared_error: 0.1514INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 147ms/step - loss: 0.0229 - root_mean_squared_error: 0.1513 - val_loss: 0.0322 - val_root_mean_squared_error: 0.1795
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0237 - root_mean_squared_error: 0.1539INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 145ms/step - loss: 0.0237 - root_mean_squared_error: 0.1539 - val_loss: 0.0319 - val_root_mean_squared_error: 0.1785
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0235 - root_mean_squared_error: 0.1533INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 7s 141ms/step - loss: 0.0235 - root_mean_squared_error: 0.1533 - val_loss: 0.0307 - val_root_mean_squared_error: 0.1751
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0209 - root_mean_squared_error: 0.1445INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 146ms/step - loss: 0.0211 - root_mean_squared_error: 0.1451 - val_loss: 0.0300 - val_root_mean_squared_error: 0.1732
# Epoch 14/50
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0209 - root_mean_squared_error: 0.1446 - val_loss: 0.0321 - val_root_mean_squared_error: 0.1792
# Epoch 15/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0200 - root_mean_squared_error: 0.1414INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 147ms/step - loss: 0.0199 - root_mean_squared_error: 0.1410 - val_loss: 0.0291 - val_root_mean_squared_error: 0.1705
# Epoch 16/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0202 - root_mean_squared_error: 0.1423INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 7s 138ms/step - loss: 0.0202 - root_mean_squared_error: 0.1420 - val_loss: 0.0285 - val_root_mean_squared_error: 0.1687
# Epoch 17/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0198 - root_mean_squared_error: 0.1406INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 149ms/step - loss: 0.0197 - root_mean_squared_error: 0.1402 - val_loss: 0.0277 - val_root_mean_squared_error: 0.1666
# Epoch 18/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0193 - root_mean_squared_error: 0.1390 - val_loss: 0.0278 - val_root_mean_squared_error: 0.1668
# Epoch 19/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0175 - root_mean_squared_error: 0.1323INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 149ms/step - loss: 0.0176 - root_mean_squared_error: 0.1325 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1645
# Epoch 20/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0185 - root_mean_squared_error: 0.1359INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 144ms/step - loss: 0.0182 - root_mean_squared_error: 0.1349 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1617
# Epoch 21/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0189 - root_mean_squared_error: 0.1376INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 152ms/step - loss: 0.0188 - root_mean_squared_error: 0.1373 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1603
# Epoch 22/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0187 - root_mean_squared_error: 0.1369INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 145ms/step - loss: 0.0187 - root_mean_squared_error: 0.1367 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1591
# Epoch 23/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0176 - root_mean_squared_error: 0.1325INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 7s 139ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1578
# Epoch 24/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0159 - root_mean_squared_error: 0.1260INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 149ms/step - loss: 0.0159 - root_mean_squared_error: 0.1262 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1577
# Epoch 25/50
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0166 - root_mean_squared_error: 0.1290 - val_loss: 0.0259 - val_root_mean_squared_error: 0.1608
# Epoch 26/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0164 - root_mean_squared_error: 0.1282INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 146ms/step - loss: 0.0163 - root_mean_squared_error: 0.1278 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1544
# Epoch 27/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0152 - root_mean_squared_error: 0.1233INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 7s 141ms/step - loss: 0.0152 - root_mean_squared_error: 0.1235 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1533
# Epoch 28/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0170 - root_mean_squared_error: 0.1302INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 156ms/step - loss: 0.0170 - root_mean_squared_error: 0.1302 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1530
# Epoch 29/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0161 - root_mean_squared_error: 0.1271 - val_loss: 0.0265 - val_root_mean_squared_error: 0.1628
# Epoch 30/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0157 - root_mean_squared_error: 0.1254INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 153ms/step - loss: 0.0160 - root_mean_squared_error: 0.1264 - val_loss: 0.0226 - val_root_mean_squared_error: 0.1504
# Epoch 31/50
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248 - val_loss: 0.0226 - val_root_mean_squared_error: 0.1505
# Epoch 32/50
# 53/53 [==============================] - 2s 28ms/step - loss: 0.0155 - root_mean_squared_error: 0.1245 - val_loss: 0.0226 - val_root_mean_squared_error: 0.1505
# Epoch 33/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0155 - root_mean_squared_error: 0.1245INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 148ms/step - loss: 0.0154 - root_mean_squared_error: 0.1243 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1475
# Epoch 34/50
# 53/53 [==============================] - 1s 27ms/step - loss: 0.0148 - root_mean_squared_error: 0.1215 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1490
# Epoch 35/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0136 - root_mean_squared_error: 0.1165INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 155ms/step - loss: 0.0136 - root_mean_squared_error: 0.1165 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1462
# Epoch 36/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211 - val_loss: 0.0226 - val_root_mean_squared_error: 0.1504
# Epoch 37/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0136 - root_mean_squared_error: 0.1166INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 154ms/step - loss: 0.0136 - root_mean_squared_error: 0.1166 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1433
# Epoch 38/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0139 - root_mean_squared_error: 0.1180INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 150ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1424
# Epoch 39/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0137 - root_mean_squared_error: 0.1172INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 155ms/step - loss: 0.0139 - root_mean_squared_error: 0.1178 - val_loss: 0.0202 - val_root_mean_squared_error: 0.1420
# Epoch 40/50
# 53/53 [==============================] - 1s 27ms/step - loss: 0.0133 - root_mean_squared_error: 0.1151 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1445
# Epoch 41/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0133 - root_mean_squared_error: 0.1152INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 158ms/step - loss: 0.0132 - root_mean_squared_error: 0.1149 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1402
# Epoch 42/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0132 - root_mean_squared_error: 0.1147INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 7s 140ms/step - loss: 0.0132 - root_mean_squared_error: 0.1147 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1394
# Epoch 43/50
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0136 - root_mean_squared_error: 0.1164 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1408
# Epoch 44/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0125 - root_mean_squared_error: 0.1117INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 148ms/step - loss: 0.0126 - root_mean_squared_error: 0.1122 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1377
# Epoch 45/50
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0133 - root_mean_squared_error: 0.1154 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1407
# Epoch 46/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0130 - root_mean_squared_error: 0.1139INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 7s 142ms/step - loss: 0.0128 - root_mean_squared_error: 0.1129 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1374
# Epoch 47/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0122 - root_mean_squared_error: 0.1106INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 145ms/step - loss: 0.0122 - root_mean_squared_error: 0.1104 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1356
# Epoch 48/50
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0128 - root_mean_squared_error: 0.1129 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1359
# Epoch 49/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0127 - root_mean_squared_error: 0.1126INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 7s 141ms/step - loss: 0.0126 - root_mean_squared_error: 0.1123 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1346
# Epoch 50/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0129 - root_mean_squared_error: 0.1134INFO:tensorflow:Assets written to: Bell_Amund_model_LT4\assets
# 53/53 [==============================] - 8s 146ms/step - loss: 0.0129 - root_mean_squared_error: 0.1137 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1344

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 5.221338637669882 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bell_Amund_model_LT4/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 12ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.11158130295242454
# MAE : 0.0925468693347261

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        2.218378e+06    2067343.547
# 1        2.209230e+06    1856673.675
# 2        2.037324e+06    1914289.680
# 3        1.727175e+06    1802244.842
# 4        1.312669e+06    1202791.069
# 5        9.152122e+05     752834.272
# 6        6.161494e+05     451914.219
# 7        5.593354e+05     439855.813
# 8        8.009442e+05     807857.307
# 9        1.147168e+06    1184280.145
# 10       1.481474e+06    1468308.405
# 11       1.733355e+06    1540851.607
# 12       1.835812e+06    1989099.836
# 13       1.860610e+06    2096990.761
# 14       1.773995e+06    2080961.032
# 15       1.547313e+06    1695704.661
# 16       1.224900e+06    1533888.370
# 17       8.792789e+05    1038332.675
# 18       5.830830e+05     602954.621
# 19       5.237818e+05     895484.288
# 20       7.239159e+05    1070622.700
# 21       1.050032e+06    1532457.922
# 22       1.395886e+06    1703762.123
# 23       1.664419e+06    1855079.122
# 24       1.812830e+06    2291960.639
# 25       1.842082e+06    2114120.417
# 26       1.769585e+06    1995818.759
# 27       1.553855e+06    1653379.997
# 28       1.251795e+06    1070814.995
# 29       9.153445e+05     689443.815
# 30       6.698055e+05     401148.663
# 31       7.127050e+05     346558.057
# 32       1.022505e+06     599477.678
# 33       1.414507e+06     765764.905
# 34       1.720594e+06    1304133.179
# 35       1.929251e+06    1598436.099
# 36       2.029362e+06    1763844.414
# 37       2.026109e+06    1979139.524
# 38       1.893338e+06    1937348.663
# 39       1.620433e+06    1833093.342
# 40       1.263168e+06    1089676.114
# 41       8.929764e+05     453484.731
# 42       5.939166e+05     251559.554
# 43       4.874077e+05     351294.657
# 44       6.002581e+05     702389.714
# 45       9.048686e+05    1185169.054
# 46       1.277796e+06    1556568.455
# 47       1.604050e+06    1917507.979
# 48       1.816522e+06    2601630.327
# 49       1.852424e+06    2534223.780
# 50       1.765898e+06    2373004.525

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 11ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
