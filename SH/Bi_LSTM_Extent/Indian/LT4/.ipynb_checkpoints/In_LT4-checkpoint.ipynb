# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Indian_Extent = pd.read_excel(filepath, sheet_name='Indian-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Indian_Extent)
fp.date_time(Indian_Extent)
# Out:
#           Extent       Date
# 0     376618.799 1979-01-01
# 1     211788.726 1979-02-01
# 2     262868.141 1979-03-01
# 3     698377.304 1979-04-01
# 4    1252407.727 1979-05-01
# ..           ...        ...
# 533  1520776.003 2023-06-01
# 534  2076164.165 2023-07-01
# 535  2731799.027 2023-08-01
# 536  3179384.692 2023-09-01
# 537  3301335.210 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Indian_Extent['Extent'] = scaler.fit_transform(Indian_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 4
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Indian_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((523, 12, 1), (523,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Indian_model_LT4/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.2465 - root_mean_squared_error: 0.4965INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 33s 385ms/step - loss: 0.2444 - root_mean_squared_error: 0.4944 - val_loss: 0.1431 - val_root_mean_squared_error: 0.3782
# Epoch 2/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.1138 - root_mean_squared_error: 0.3373INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 25s 473ms/step - loss: 0.1128 - root_mean_squared_error: 0.3359 - val_loss: 0.0642 - val_root_mean_squared_error: 0.2535
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0617 - root_mean_squared_error: 0.2484INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 24s 470ms/step - loss: 0.0617 - root_mean_squared_error: 0.2484 - val_loss: 0.0361 - val_root_mean_squared_error: 0.1899
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0331 - root_mean_squared_error: 0.1821INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 26s 500ms/step - loss: 0.0329 - root_mean_squared_error: 0.1814 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1262
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0165 - root_mean_squared_error: 0.1283INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 25s 482ms/step - loss: 0.0165 - root_mean_squared_error: 0.1284 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0966
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0127 - root_mean_squared_error: 0.1128INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 26s 496ms/step - loss: 0.0126 - root_mean_squared_error: 0.1124 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0950
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0104 - root_mean_squared_error: 0.1020INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 26s 502ms/step - loss: 0.0104 - root_mean_squared_error: 0.1020 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0841
# Epoch 8/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0103 - root_mean_squared_error: 0.1016 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0898
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0103 - root_mean_squared_error: 0.1014INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 26s 507ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0795
# Epoch 10/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0101 - root_mean_squared_error: 0.1005 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0832
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0084 - root_mean_squared_error: 0.0916INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 26s 498ms/step - loss: 0.0084 - root_mean_squared_error: 0.0916 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0725
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0906INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 26s 508ms/step - loss: 0.0082 - root_mean_squared_error: 0.0906 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0718
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0080 - root_mean_squared_error: 0.0896INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0080 - root_mean_squared_error: 0.0896 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0717
# Epoch 14/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0076 - root_mean_squared_error: 0.0872INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 26s 502ms/step - loss: 0.0077 - root_mean_squared_error: 0.0879 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0669
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0067 - root_mean_squared_error: 0.0819INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 26s 501ms/step - loss: 0.0067 - root_mean_squared_error: 0.0819 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0657
# Epoch 16/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0073 - root_mean_squared_error: 0.0855 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0712
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0071 - root_mean_squared_error: 0.0845INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 27s 509ms/step - loss: 0.0071 - root_mean_squared_error: 0.0845 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0641
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0066 - root_mean_squared_error: 0.0812INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 26s 500ms/step - loss: 0.0066 - root_mean_squared_error: 0.0812 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0621
# Epoch 19/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0071 - root_mean_squared_error: 0.0841 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0627
# Epoch 20/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0076 - root_mean_squared_error: 0.0870 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0636
# Epoch 21/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0065 - root_mean_squared_error: 0.0805 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0664
# Epoch 22/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0066 - root_mean_squared_error: 0.0811 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0641
# Epoch 23/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0060 - root_mean_squared_error: 0.0778 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0645
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0062 - root_mean_squared_error: 0.0787INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 27s 512ms/step - loss: 0.0062 - root_mean_squared_error: 0.0787 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0066 - root_mean_squared_error: 0.0810INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 26s 500ms/step - loss: 0.0066 - root_mean_squared_error: 0.0810 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0569
# Epoch 26/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0056 - root_mean_squared_error: 0.0748 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0647
# Epoch 27/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0069 - root_mean_squared_error: 0.0828 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0617
# Epoch 28/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0064 - root_mean_squared_error: 0.0801 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611
# Epoch 29/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0061 - root_mean_squared_error: 0.0783INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 26s 503ms/step - loss: 0.0061 - root_mean_squared_error: 0.0783 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0545
# Epoch 30/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0063 - root_mean_squared_error: 0.0792 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0565
# Epoch 31/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0060 - root_mean_squared_error: 0.0773INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 26s 496ms/step - loss: 0.0060 - root_mean_squared_error: 0.0773 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0543
# Epoch 32/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0062 - root_mean_squared_error: 0.0785INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 26s 502ms/step - loss: 0.0061 - root_mean_squared_error: 0.0783 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0529
# Epoch 33/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0058 - root_mean_squared_error: 0.0762 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0632
# Epoch 34/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0060 - root_mean_squared_error: 0.0777 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610
# Epoch 35/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0062 - root_mean_squared_error: 0.0789 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0574
# Epoch 36/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0059 - root_mean_squared_error: 0.0765 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0566
# Epoch 37/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0056 - root_mean_squared_error: 0.0751INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 26s 501ms/step - loss: 0.0056 - root_mean_squared_error: 0.0751 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0524
# Epoch 38/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0057 - root_mean_squared_error: 0.0755 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0699
# Epoch 39/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0060 - root_mean_squared_error: 0.0772 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0824
# Epoch 40/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0062 - root_mean_squared_error: 0.0789 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0619
# Epoch 41/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0050 - root_mean_squared_error: 0.0707 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0688
# Epoch 42/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0057 - root_mean_squared_error: 0.0757 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 43/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0055 - root_mean_squared_error: 0.0739 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0592
# Epoch 44/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0053 - root_mean_squared_error: 0.0729 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0593
# Epoch 45/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0054 - root_mean_squared_error: 0.0736 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0559
# Epoch 46/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0055 - root_mean_squared_error: 0.0744 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0751
# Epoch 47/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0054 - root_mean_squared_error: 0.0732INFO:tensorflow:Assets written to: Indian_model_LT4\assets
# 53/53 [==============================] - 27s 512ms/step - loss: 0.0054 - root_mean_squared_error: 0.0732 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0507
# Epoch 48/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0056 - root_mean_squared_error: 0.0748 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0534
# Epoch 49/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0051 - root_mean_squared_error: 0.0712 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0618
# Epoch 50/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0059 - root_mean_squared_error: 0.0771 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0627

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 11.313959228992463 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Indian_model_LT4/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 21ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.07128025352994341
# MAE : 0.057582338418714706

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        3.127108e+06    3151724.833
# 1        3.505427e+06    3719188.531
# 2        3.584584e+06    3636501.241
# 3        3.191471e+06    2526913.818
# 4        1.799527e+06    1128752.378
# 5        3.061329e+05     522831.371
# 6        1.323647e+05     346601.304
# 7        2.459717e+05     444914.605
# 8        5.766438e+05     827036.916
# 9        1.117797e+06    1142021.216
# 10       1.761648e+06    1885693.654
# 11       2.420346e+06    2542569.663
# 12       2.961024e+06    3107373.845
# 13       3.315490e+06    3488175.444
# 14       3.383425e+06    3746306.528
# 15       2.890075e+06    2942322.822
# 16       1.289436e+06    1507212.955
# 17       2.649579e+05     648507.437
# 18       1.529122e+05     352564.010
# 19       2.413485e+05     453587.503
# 20       5.336189e+05     841043.793
# 21       1.061788e+06    1433155.266
# 22       1.734591e+06    2163687.646
# 23       2.414310e+06    2848863.133
# 24       2.970445e+06    3420877.229
# 25       3.329998e+06    3752886.938
# 26       3.306648e+06    3778951.818
# 27       2.557952e+06    2892177.223
# 28       9.486459e+05    1467610.428
# 29       2.295845e+05     377930.941
# 30       1.633567e+05     146440.376
# 31       2.776082e+05     244356.473
# 32       6.013932e+05     612217.566
# 33       1.209574e+06    1261627.075
# 34       1.944810e+06    1720565.225
# 35       2.681408e+06    2564005.541
# 36       3.284705e+06    2983773.529
# 37       3.634921e+06    3372645.223
# 38       3.655706e+06    3589687.043
# 39       3.126236e+06    2669385.189
# 40       1.643718e+06    1095398.946
# 41       3.483497e+05     319828.826
# 42       1.656003e+05     162541.182
# 43       2.584724e+05     179564.232
# 44       5.941726e+05     593196.107
# 45       1.170849e+06    1053508.835
# 46       1.842202e+06    1520776.003
# 47       2.523832e+06    2076164.165
# 48       3.083140e+06    2731799.027
# 49       3.413315e+06    3179384.692
# 50       3.484175e+06    3301335.210

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 36ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
