# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Baffin = pd.read_excel(filepath, sheet_name='Baffin-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Baffin)
fp.date_time(Baffin)
# Out:
#           Extent       Date
# 0    1090625.815 1979-01-01
# 1    1157634.866 1979-02-01
# 2    1299583.477 1979-03-01
# 3    1137194.680 1979-04-01
# 4     983083.453 1979-05-01
# ..           ...        ...
# 533   781460.891 2023-06-01
# 534   331845.048 2023-07-01
# 535    99334.625 2023-08-01
# 536    49359.723 2023-09-01
# 537    85693.282 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Baffin['Extent'] = scaler.fit_transform(Baffin['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 10
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Baffin['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((517, 12, 1), (517,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Baffin_model_LT10/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2362 - root_mean_squared_error: 0.4860INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 21s 265ms/step - loss: 0.2332 - root_mean_squared_error: 0.4829 - val_loss: 0.1659 - val_root_mean_squared_error: 0.4074
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1482 - root_mean_squared_error: 0.3849INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 13s 243ms/step - loss: 0.1474 - root_mean_squared_error: 0.3839 - val_loss: 0.0937 - val_root_mean_squared_error: 0.3062
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1010 - root_mean_squared_error: 0.3178INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 15s 290ms/step - loss: 0.1010 - root_mean_squared_error: 0.3178 - val_loss: 0.0849 - val_root_mean_squared_error: 0.2914
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0912 - root_mean_squared_error: 0.3020INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 16s 298ms/step - loss: 0.0910 - root_mean_squared_error: 0.3017 - val_loss: 0.0791 - val_root_mean_squared_error: 0.2812
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0824 - root_mean_squared_error: 0.2871INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 14s 270ms/step - loss: 0.0824 - root_mean_squared_error: 0.2871 - val_loss: 0.0650 - val_root_mean_squared_error: 0.2550
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0675 - root_mean_squared_error: 0.2599INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 13s 249ms/step - loss: 0.0673 - root_mean_squared_error: 0.2595 - val_loss: 0.0535 - val_root_mean_squared_error: 0.2312
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0509 - root_mean_squared_error: 0.2257INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 14s 267ms/step - loss: 0.0506 - root_mean_squared_error: 0.2249 - val_loss: 0.0313 - val_root_mean_squared_error: 0.1770
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0355 - root_mean_squared_error: 0.1885INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 15s 281ms/step - loss: 0.0355 - root_mean_squared_error: 0.1885 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1394
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0252 - root_mean_squared_error: 0.1589INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 16s 298ms/step - loss: 0.0252 - root_mean_squared_error: 0.1589 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1114
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0233 - root_mean_squared_error: 0.1527INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 12s 232ms/step - loss: 0.0233 - root_mean_squared_error: 0.1527 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0874
# Epoch 11/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0219 - root_mean_squared_error: 0.1479INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 12s 232ms/step - loss: 0.0221 - root_mean_squared_error: 0.1487 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0830
# Epoch 12/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0203 - root_mean_squared_error: 0.1426 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1014
# Epoch 13/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0204 - root_mean_squared_error: 0.1428 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1065
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0184 - root_mean_squared_error: 0.1357INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 12s 236ms/step - loss: 0.0184 - root_mean_squared_error: 0.1357 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0699
# Epoch 15/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0169 - root_mean_squared_error: 0.1301 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0715
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0164 - root_mean_squared_error: 0.1281INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 11s 211ms/step - loss: 0.0164 - root_mean_squared_error: 0.1281 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0628
# Epoch 17/50
# 53/53 [==============================] - 1s 28ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0739
# Epoch 18/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0137 - root_mean_squared_error: 0.1169 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0645
# Epoch 19/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0153 - root_mean_squared_error: 0.1239 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0645
# Epoch 20/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0149 - root_mean_squared_error: 0.1219 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0673
# Epoch 21/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0147 - root_mean_squared_error: 0.1212INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 10s 187ms/step - loss: 0.0146 - root_mean_squared_error: 0.1209 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0147 - root_mean_squared_error: 0.1211INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 12s 225ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0582
# Epoch 23/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0129 - root_mean_squared_error: 0.1136 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0647
# Epoch 24/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0601
# Epoch 25/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0121 - root_mean_squared_error: 0.1099 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0594
# Epoch 26/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0128 - root_mean_squared_error: 0.1132INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 12s 226ms/step - loss: 0.0127 - root_mean_squared_error: 0.1128 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0575
# Epoch 27/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0114 - root_mean_squared_error: 0.1070INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 13s 242ms/step - loss: 0.0114 - root_mean_squared_error: 0.1070 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0560
# Epoch 28/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0112 - root_mean_squared_error: 0.1056 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0621
# Epoch 29/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0122 - root_mean_squared_error: 0.1104INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 11s 209ms/step - loss: 0.0122 - root_mean_squared_error: 0.1104 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0548
# Epoch 30/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0111 - root_mean_squared_error: 0.1055 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0587
# Epoch 31/50
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0113 - root_mean_squared_error: 0.1063 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0594
# Epoch 32/50
# 53/53 [==============================] - 1s 28ms/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0585
# Epoch 33/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0102 - root_mean_squared_error: 0.1011 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0709
# Epoch 34/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0103 - root_mean_squared_error: 0.1015INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 10s 187ms/step - loss: 0.0103 - root_mean_squared_error: 0.1015 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0546
# Epoch 35/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0108 - root_mean_squared_error: 0.1041INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 9s 176ms/step - loss: 0.0108 - root_mean_squared_error: 0.1041 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0540
# Epoch 36/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0107 - root_mean_squared_error: 0.1037 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0573
# Epoch 37/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0110 - root_mean_squared_error: 0.1048 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0574
# Epoch 38/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0095 - root_mean_squared_error: 0.0972 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0557
# Epoch 39/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0110 - root_mean_squared_error: 0.1049 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0706
# Epoch 40/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0094 - root_mean_squared_error: 0.0970INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 10s 196ms/step - loss: 0.0093 - root_mean_squared_error: 0.0965 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0532
# Epoch 41/50
# 53/53 [==============================] - 1s 27ms/step - loss: 0.0090 - root_mean_squared_error: 0.0950 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0560
# Epoch 42/50
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0097 - root_mean_squared_error: 0.0985 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0550
# Epoch 43/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0093 - root_mean_squared_error: 0.0966INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 10s 195ms/step - loss: 0.0093 - root_mean_squared_error: 0.0965 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0526
# Epoch 44/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0101 - root_mean_squared_error: 0.1005 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0669
# Epoch 45/50
# 53/53 [==============================] - 1s 26ms/step - loss: 0.0093 - root_mean_squared_error: 0.0963 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610
# Epoch 46/50
# 53/53 [==============================] - 1s 26ms/step - loss: 0.0087 - root_mean_squared_error: 0.0934 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0553
# Epoch 47/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0093 - root_mean_squared_error: 0.0967 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0637
# Epoch 48/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0084 - root_mean_squared_error: 0.0915 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0529
# Epoch 49/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0093 - root_mean_squared_error: 0.0965INFO:tensorflow:Assets written to: Baffin_model_LT10\assets
# 53/53 [==============================] - 12s 221ms/step - loss: 0.0093 - root_mean_squared_error: 0.0965 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0513
# Epoch 50/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0080 - root_mean_squared_error: 0.0895 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0552

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 5.547677544752757 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Baffin_model_LT10/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 14ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.05392662006872654
# MAE : 0.045670979443077096

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.279683e+06    1181121.087
# 1        1.285913e+06    1236299.254
# 2        1.134581e+06    1036981.003
# 3        8.871114e+05     847489.150
# 4        5.337244e+05     619129.338
# 5        2.232137e+05     195688.491
# 6        4.360968e+04      36670.811
# 7        3.432627e+04      31777.310
# 8        1.895407e+05      82762.022
# 9        4.767282e+05     400043.823
# 10       7.870599e+05     733089.555
# 11       1.052133e+06     917362.266
# 12       1.222250e+06    1040584.040
# 13       1.247548e+06    1147997.675
# 14       1.190374e+06    1074255.327
# 15       1.009358e+06     875527.315
# 16       6.866546e+05     629820.756
# 17       3.385406e+05     204308.900
# 18       1.124752e+05      45059.062
# 19       7.719098e+04      33770.277
# 20       2.368714e+05      64135.631
# 21       5.156348e+05     400581.715
# 22       7.954291e+05     698631.451
# 23       1.017280e+06     973313.225
# 24       1.183700e+06    1335339.087
# 25       1.238814e+06    1429096.704
# 26       1.176304e+06    1206542.314
# 27       1.001621e+06    1079292.433
# 28       6.726167e+05     788101.638
# 29       3.228867e+05     397326.270
# 30       1.056936e+05      97802.348
# 31       7.505999e+04      62212.219
# 32       2.201982e+05     154051.600
# 33       4.886048e+05     610663.893
# 34       7.951666e+05     756679.164
# 35       1.060337e+06     962270.215
# 36       1.249289e+06    1235154.518
# 37       1.318887e+06    1161744.519
# 38       1.259158e+06    1136918.669
# 39       1.078347e+06     995852.026
# 40       7.460972e+05     781460.891
# 41       3.823297e+05     331845.048
# 42       1.135245e+05      99334.625
# 43       3.164186e+04      49359.723
# 44       1.371045e+05      85693.282

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 15ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
