# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Pacific_Extent = pd.read_excel(filepath, sheet_name='Pacific-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Pacific_Extent)
fp.date_time(Pacific_Extent)
# Out:
#           Extent       Date
# 0     668714.275 1979-01-01
# 1     566930.458 1979-02-01
# 2     688420.115 1979-03-01
# 3     859963.043 1979-04-01
# 4    1127120.160 1979-05-01
# ..           ...        ...
# 533  1134056.102 2023-06-01
# 534  1484824.377 2023-07-01
# 535  1671324.717 2023-08-01
# 536  1726376.097 2023-09-01
# 537  1690631.996 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Pacific_Extent['Extent'] = scaler.fit_transform(Pacific_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 3
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Pacific_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((524, 12, 1), (524,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Pacific_model_LT3/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1925 - root_mean_squared_error: 0.4388INFO:tensorflow:Assets written to: Pacific_model_LT3\assets
# 53/53 [==============================] - 28s 363ms/step - loss: 0.1925 - root_mean_squared_error: 0.4388 - val_loss: 0.0908 - val_root_mean_squared_error: 0.3013
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0678 - root_mean_squared_error: 0.2603INFO:tensorflow:Assets written to: Pacific_model_LT3\assets
# 53/53 [==============================] - 19s 356ms/step - loss: 0.0678 - root_mean_squared_error: 0.2604 - val_loss: 0.0467 - val_root_mean_squared_error: 0.2161
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0488 - root_mean_squared_error: 0.2209INFO:tensorflow:Assets written to: Pacific_model_LT3\assets
# 53/53 [==============================] - 18s 349ms/step - loss: 0.0486 - root_mean_squared_error: 0.2204 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1837
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0338 - root_mean_squared_error: 0.1839INFO:tensorflow:Assets written to: Pacific_model_LT3\assets
# 53/53 [==============================] - 19s 358ms/step - loss: 0.0338 - root_mean_squared_error: 0.1839 - val_loss: 0.0195 - val_root_mean_squared_error: 0.1396
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0214 - root_mean_squared_error: 0.1462INFO:tensorflow:Assets written to: Pacific_model_LT3\assets
# 53/53 [==============================] - 20s 386ms/step - loss: 0.0214 - root_mean_squared_error: 0.1462 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0996
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0144 - root_mean_squared_error: 0.1202INFO:tensorflow:Assets written to: Pacific_model_LT3\assets
# 53/53 [==============================] - 21s 399ms/step - loss: 0.0144 - root_mean_squared_error: 0.1202 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0800
# Epoch 7/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0119 - root_mean_squared_error: 0.1093 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0852
# Epoch 8/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0110 - root_mean_squared_error: 0.1049 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0999
# Epoch 9/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0119 - root_mean_squared_error: 0.1092 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0815
# Epoch 10/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0116 - root_mean_squared_error: 0.1075 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0815
# Epoch 11/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0117 - root_mean_squared_error: 0.1082 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0851
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0104 - root_mean_squared_error: 0.1020INFO:tensorflow:Assets written to: Pacific_model_LT3\assets
# 53/53 [==============================] - 20s 384ms/step - loss: 0.0104 - root_mean_squared_error: 0.1020 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0734
# Epoch 13/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0097 - root_mean_squared_error: 0.0984 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0737
# Epoch 14/50
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0098 - root_mean_squared_error: 0.0988 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0862
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0096 - root_mean_squared_error: 0.0978INFO:tensorflow:Assets written to: Pacific_model_LT3\assets
# 53/53 [==============================] - 20s 384ms/step - loss: 0.0096 - root_mean_squared_error: 0.0978 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0714
# Epoch 16/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0097 - root_mean_squared_error: 0.0984 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0908
# Epoch 17/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0094 - root_mean_squared_error: 0.0970 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0729
# Epoch 18/50
# 53/53 [==============================] - 2s 40ms/step - loss: 0.0098 - root_mean_squared_error: 0.0992 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0762
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0091 - root_mean_squared_error: 0.0956INFO:tensorflow:Assets written to: Pacific_model_LT3\assets
# 53/53 [==============================] - 19s 365ms/step - loss: 0.0091 - root_mean_squared_error: 0.0956 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0698
# Epoch 20/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0088 - root_mean_squared_error: 0.0938 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0736
# Epoch 21/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0086 - root_mean_squared_error: 0.0928 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0725
# Epoch 22/50
# 53/53 [==============================] - 4s 81ms/step - loss: 0.0090 - root_mean_squared_error: 0.0946 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0774
# Epoch 23/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0090 - root_mean_squared_error: 0.0950 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0759
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0084 - root_mean_squared_error: 0.0918INFO:tensorflow:Assets written to: Pacific_model_LT3\assets
# 53/53 [==============================] - 21s 394ms/step - loss: 0.0084 - root_mean_squared_error: 0.0918 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0682
# Epoch 25/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0084 - root_mean_squared_error: 0.0917 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0701
# Epoch 26/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0085 - root_mean_squared_error: 0.0920 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0830
# Epoch 27/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0084 - root_mean_squared_error: 0.0915 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0707
# Epoch 28/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0079 - root_mean_squared_error: 0.0888INFO:tensorflow:Assets written to: Pacific_model_LT3\assets
# 53/53 [==============================] - 22s 415ms/step - loss: 0.0079 - root_mean_squared_error: 0.0888 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0674
# Epoch 29/50
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0084 - root_mean_squared_error: 0.0917 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0695
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0085 - root_mean_squared_error: 0.0922INFO:tensorflow:Assets written to: Pacific_model_LT3\assets
# 53/53 [==============================] - 19s 368ms/step - loss: 0.0085 - root_mean_squared_error: 0.0922 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0673
# Epoch 31/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0079 - root_mean_squared_error: 0.0886 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0689
# Epoch 32/50
# 53/53 [==============================] - 4s 75ms/step - loss: 0.0080 - root_mean_squared_error: 0.0895 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0730
# Epoch 33/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0076 - root_mean_squared_error: 0.0872 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0689
# Epoch 34/50
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0081 - root_mean_squared_error: 0.0902 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0721
# Epoch 35/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0079 - root_mean_squared_error: 0.0888 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0696
# Epoch 36/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0081 - root_mean_squared_error: 0.0900 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0756
# Epoch 37/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0079 - root_mean_squared_error: 0.0890 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0686
# Epoch 38/50
# 53/53 [==============================] - 2s 47ms/step - loss: 0.0076 - root_mean_squared_error: 0.0872 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0678
# Epoch 39/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0078 - root_mean_squared_error: 0.0882 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0700
# Epoch 40/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0075 - root_mean_squared_error: 0.0868INFO:tensorflow:Assets written to: Pacific_model_LT3\assets
# 53/53 [==============================] - 20s 384ms/step - loss: 0.0075 - root_mean_squared_error: 0.0868 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0651
# Epoch 41/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0080 - root_mean_squared_error: 0.0893INFO:tensorflow:Assets written to: Pacific_model_LT3\assets
# 53/53 [==============================] - 21s 399ms/step - loss: 0.0080 - root_mean_squared_error: 0.0893 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0639
# Epoch 42/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0073 - root_mean_squared_error: 0.0854 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0670
# Epoch 43/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0070 - root_mean_squared_error: 0.0835 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0666
# Epoch 44/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0075 - root_mean_squared_error: 0.0864 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0648
# Epoch 45/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0072 - root_mean_squared_error: 0.0846 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0671
# Epoch 46/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0077 - root_mean_squared_error: 0.0879 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0646
# Epoch 47/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0073 - root_mean_squared_error: 0.0852 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0650
# Epoch 48/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0075 - root_mean_squared_error: 0.0867 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0718
# Epoch 49/50
# 53/53 [==============================] - 4s 75ms/step - loss: 0.0069 - root_mean_squared_error: 0.0829 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0741
# Epoch 50/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0070 - root_mean_squared_error: 0.0837 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0641

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 6.693173432350159 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Pacific_model_LT3/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 22ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.07123110734718857
# MAE : 0.057903686991329625

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.610380e+06    1701391.499
# 1        1.761746e+06    1890231.668
# 2        1.793114e+06    2203401.829
# 3        1.675903e+06    1960480.542
# 4        1.344229e+06    1264318.504
# 5        7.515398e+05     863206.294
# 6        3.382520e+05     635624.004
# 7        3.362657e+05     460009.672
# 8        4.766689e+05     610848.036
# 9        7.102601e+05     819257.445
# 10       1.022142e+06    1129627.707
# 11       1.360325e+06    1463383.236
# 12       1.658165e+06    1614536.727
# 13       1.867295e+06    1862498.612
# 14       1.931598e+06    2099349.296
# 15       1.830351e+06    1981614.046
# 16       1.527347e+06    1433022.369
# 17       8.793136e+05     826739.716
# 18       3.999353e+05     477145.887
# 19       3.770930e+05     314469.289
# 20       5.167996e+05     463134.749
# 21       7.606944e+05     946522.292
# 22       1.071000e+06    1309266.570
# 23       1.386290e+06    1507947.309
# 24       1.661562e+06    1804167.937
# 25       1.839940e+06    1908002.139
# 26       1.875256e+06    1892748.521
# 27       1.772227e+06    1601079.640
# 28       1.445076e+06    1327804.521
# 29       8.461639e+05     812074.231
# 30       4.412322e+05     493355.897
# 31       4.069038e+05     317229.330
# 32       5.593776e+05     425777.624
# 33       8.235211e+05     827172.620
# 34       1.156575e+06    1162367.223
# 35       1.495510e+06    1413734.261
# 36       1.732768e+06    1574257.849
# 37       1.849042e+06    1786961.251
# 38       1.852422e+06    1857942.866
# 39       1.691919e+06    1406291.588
# 40       1.348061e+06    1025555.371
# 41       8.084813e+05     632862.782
# 42       4.731464e+05     308194.756
# 43       4.399130e+05     194921.078
# 44       5.935271e+05     245569.900
# 45       8.373536e+05     533532.424
# 46       1.131883e+06     943124.529
# 47       1.424024e+06    1134056.102
# 48       1.637699e+06    1484824.377
# 49       1.742648e+06    1671324.717
# 50       1.724402e+06    1726376.097
# 51       1.570538e+06    1690631.996

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 27ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
