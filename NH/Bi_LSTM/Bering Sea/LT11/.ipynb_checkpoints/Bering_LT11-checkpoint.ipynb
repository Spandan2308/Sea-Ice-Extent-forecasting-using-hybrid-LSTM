# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bering = pd.read_excel(filepath, sheet_name='Bering-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Bering)
fp.date_time(Bering)
# Out:
#          Extent       Date
# 0    320266.650 1979-01-01
# 1    541778.338 1979-02-01
# 2    638262.988 1979-03-01
# 3    423025.159 1979-04-01
# 4    215587.216 1979-05-01
# ..          ...        ...
# 488  317377.493 2023-05-01
# 489   39601.476 2023-06-01
# 490   16935.702 2023-07-01
# 491    1305.744 2023-09-01
# 492   12255.644 2023-10-01
#
# [493 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bering['Extent'] = scaler.fit_transform(Bering['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 11
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bering['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((471, 12, 1), (471,))

# %%
X_train, y_train = X[:390], y[:390]
X_val, y_val = X[390:440], y[390:440]
X_test, y_test = X[440:], y[440:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Bering_model_LT11/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 49/49 [==============================] - ETA: 0s - loss: 0.1560 - root_mean_squared_error: 0.3950INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 49/49 [==============================] - 29s 423ms/step - loss: 0.1560 - root_mean_squared_error: 0.3950 - val_loss: 0.0382 - val_root_mean_squared_error: 0.1956
# Epoch 2/50
# 49/49 [==============================] - 1s 27ms/step - loss: 0.0924 - root_mean_squared_error: 0.3040 - val_loss: 0.0448 - val_root_mean_squared_error: 0.2116
# Epoch 3/50
# 49/49 [==============================] - 1s 25ms/step - loss: 0.0782 - root_mean_squared_error: 0.2796 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2023
# Epoch 4/50
# 47/49 [===========================>..] - ETA: 0s - loss: 0.0679 - root_mean_squared_error: 0.2607INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 49/49 [==============================] - 20s 412ms/step - loss: 0.0679 - root_mean_squared_error: 0.2607 - val_loss: 0.0373 - val_root_mean_squared_error: 0.1930
# Epoch 5/50
# 48/49 [============================>.] - ETA: 0s - loss: 0.0486 - root_mean_squared_error: 0.2205INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 49/49 [==============================] - 25s 523ms/step - loss: 0.0485 - root_mean_squared_error: 0.2202 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1531
# Epoch 6/50
# 47/49 [===========================>..] - ETA: 0s - loss: 0.0237 - root_mean_squared_error: 0.1540INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 49/49 [==============================] - 22s 455ms/step - loss: 0.0238 - root_mean_squared_error: 0.1544 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1443
# Epoch 7/50
# 49/49 [==============================] - ETA: 0s - loss: 0.0159 - root_mean_squared_error: 0.1260INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 49/49 [==============================] - 23s 481ms/step - loss: 0.0159 - root_mean_squared_error: 0.1260 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1361
# Epoch 8/50
# 49/49 [==============================] - 2s 36ms/step - loss: 0.0149 - root_mean_squared_error: 0.1222 - val_loss: 0.0303 - val_root_mean_squared_error: 0.1742
# Epoch 9/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0137 - root_mean_squared_error: 0.1170 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1523
# Epoch 10/50
# 49/49 [==============================] - 1s 27ms/step - loss: 0.0145 - root_mean_squared_error: 0.1206 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1558
# Epoch 11/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1432
# Epoch 12/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0126 - root_mean_squared_error: 0.1122 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1643
# Epoch 13/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.0122 - root_mean_squared_error: 0.1103 - val_loss: 0.0351 - val_root_mean_squared_error: 0.1873
# Epoch 14/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0133 - root_mean_squared_error: 0.1153 - val_loss: 0.0347 - val_root_mean_squared_error: 0.1863
# Epoch 15/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0111 - root_mean_squared_error: 0.1053 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1548
# Epoch 16/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0128 - root_mean_squared_error: 0.1134 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1435
# Epoch 17/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0118 - root_mean_squared_error: 0.1088 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1366
# Epoch 18/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0117 - root_mean_squared_error: 0.1084 - val_loss: 0.0311 - val_root_mean_squared_error: 0.1762
# Epoch 19/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0123 - root_mean_squared_error: 0.1107 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1580
# Epoch 20/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0113 - root_mean_squared_error: 0.1062 - val_loss: 0.0298 - val_root_mean_squared_error: 0.1726
# Epoch 21/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0113 - root_mean_squared_error: 0.1061 - val_loss: 0.0195 - val_root_mean_squared_error: 0.1396
# Epoch 22/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.0111 - root_mean_squared_error: 0.1053 - val_loss: 0.0269 - val_root_mean_squared_error: 0.1641
# Epoch 23/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0112 - root_mean_squared_error: 0.1056 - val_loss: 0.0390 - val_root_mean_squared_error: 0.1974
# Epoch 24/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0112 - root_mean_squared_error: 0.1060 - val_loss: 0.0280 - val_root_mean_squared_error: 0.1674
# Epoch 25/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0119 - root_mean_squared_error: 0.1090 - val_loss: 0.0226 - val_root_mean_squared_error: 0.1504
# Epoch 26/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0109 - root_mean_squared_error: 0.1045 - val_loss: 0.0325 - val_root_mean_squared_error: 0.1802
# Epoch 27/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0100 - root_mean_squared_error: 0.1001 - val_loss: 0.0290 - val_root_mean_squared_error: 0.1703
# Epoch 28/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.0099 - root_mean_squared_error: 0.0996 - val_loss: 0.0321 - val_root_mean_squared_error: 0.1792
# Epoch 29/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0106 - root_mean_squared_error: 0.1028 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1840
# Epoch 30/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.0103 - root_mean_squared_error: 0.1013 - val_loss: 0.0357 - val_root_mean_squared_error: 0.1890
# Epoch 31/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.0102 - root_mean_squared_error: 0.1009 - val_loss: 0.0300 - val_root_mean_squared_error: 0.1733
# Epoch 32/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0104 - root_mean_squared_error: 0.1019 - val_loss: 0.0342 - val_root_mean_squared_error: 0.1850
# Epoch 33/50
# 49/49 [==============================] - 2s 31ms/step - loss: 0.0099 - root_mean_squared_error: 0.0997 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1476
# Epoch 34/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.0101 - root_mean_squared_error: 0.1003 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1603
# Epoch 35/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.0102 - root_mean_squared_error: 0.1009 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1466
# Epoch 36/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0106 - root_mean_squared_error: 0.1028 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1559
# Epoch 37/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0283 - val_root_mean_squared_error: 0.1683
# Epoch 38/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0297 - val_root_mean_squared_error: 0.1724
# Epoch 39/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0093 - root_mean_squared_error: 0.0966 - val_loss: 0.0283 - val_root_mean_squared_error: 0.1684
# Epoch 40/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.0098 - root_mean_squared_error: 0.0988 - val_loss: 0.0311 - val_root_mean_squared_error: 0.1763
# Epoch 41/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0094 - root_mean_squared_error: 0.0971 - val_loss: 0.0342 - val_root_mean_squared_error: 0.1848
# Epoch 42/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.0109 - root_mean_squared_error: 0.1042 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1531
# Epoch 43/50
# 49/49 [==============================] - 2s 31ms/step - loss: 0.0094 - root_mean_squared_error: 0.0969 - val_loss: 0.0231 - val_root_mean_squared_error: 0.1519
# Epoch 44/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.0098 - root_mean_squared_error: 0.0990 - val_loss: 0.0306 - val_root_mean_squared_error: 0.1751
# Epoch 45/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.0101 - root_mean_squared_error: 0.1007 - val_loss: 0.0284 - val_root_mean_squared_error: 0.1686
# Epoch 46/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0098 - root_mean_squared_error: 0.0989 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1446
# Epoch 47/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.0094 - root_mean_squared_error: 0.0972 - val_loss: 0.0351 - val_root_mean_squared_error: 0.1875
# Epoch 48/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0094 - root_mean_squared_error: 0.0969 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1558
# Epoch 49/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0094 - root_mean_squared_error: 0.0970 - val_loss: 0.0370 - val_root_mean_squared_error: 0.1924
# Epoch 50/50
# 49/49 [==============================] - 2s 31ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0323 - val_root_mean_squared_error: 0.1798

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 3.2201052069664002 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bering_model_LT11/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.07681646775277408
# MAE : 0.06521547833031131

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       440615.343750     461098.498
# 1       521633.343750     591635.798
# 2       490865.906250     598360.298
# 3       379540.437500     531742.038
# 4       240314.500000     302131.004
# 5       135463.781250      57748.135
# 6        67923.812500       3054.962
# 7        43278.683594        442.539
# 8        56566.031250       8541.643
# 9       104189.140625     121335.125
# 10      220804.546875     360205.990
# 11      461947.687500     651717.220
# 12      644305.250000     779385.402
# 13      624689.437500     710314.085
# 14      477322.875000     578635.421
# 15      307659.500000     199031.792
# 16      150591.171875      43795.314
# 17       72752.101562       3015.211
# 18       39735.273438       1206.623
# 19       45295.386719       8506.979
# 20       98380.718750      41065.748
# 21      255695.046875     169363.165
# 22      508509.468750     531698.544
# 23      674833.062500     631496.345
# 24      675554.875000     612860.407
# 25      516006.468750     552903.799
# 26      265150.375000     317377.493
# 27       88449.445312      39601.476
# 28       27642.871094      16935.702
# 29       17052.833984       1305.744
# 30       44591.152344      12255.644

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 15/15 [==============================] - 0s 25ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
