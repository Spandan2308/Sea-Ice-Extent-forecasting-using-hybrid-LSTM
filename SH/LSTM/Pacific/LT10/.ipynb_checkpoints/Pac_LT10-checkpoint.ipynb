# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Pacific_Extent = pd.read_excel(filepath, sheet_name='Pacific-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Pacific_Extent)
fp.date_time(Pacific_Extent)
# Out:
#           Extent       Date
# 0     668714.275 1979-01-01
# 1     566930.458 1979-02-01
# 2     688420.115 1979-03-01
# 3     859963.043 1979-04-01
# 4    1127120.160 1979-05-01
# ..           ...        ...
# 533  1134056.102 2023-06-01
# 534  1484824.377 2023-07-01
# 535  1671324.717 2023-08-01
# 536  1726376.097 2023-09-01
# 537  1690631.996 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Pacific_Extent['Extent'] = scaler.fit_transform(Pacific_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 10
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Pacific_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((517, 12, 1), (517,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Pacific_model_LT10/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2171 - root_mean_squared_error: 0.4659INFO:tensorflow:Assets written to: Pacific_model_LT10\assets
# 53/53 [==============================] - 17s 210ms/step - loss: 0.2139 - root_mean_squared_error: 0.4625 - val_loss: 0.1576 - val_root_mean_squared_error: 0.3970
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1013 - root_mean_squared_error: 0.3182INFO:tensorflow:Assets written to: Pacific_model_LT10\assets
# 53/53 [==============================] - 10s 189ms/step - loss: 0.1019 - root_mean_squared_error: 0.3192 - val_loss: 0.0756 - val_root_mean_squared_error: 0.2749
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0760 - root_mean_squared_error: 0.2757INFO:tensorflow:Assets written to: Pacific_model_LT10\assets
# 53/53 [==============================] - 10s 185ms/step - loss: 0.0761 - root_mean_squared_error: 0.2758 - val_loss: 0.0697 - val_root_mean_squared_error: 0.2640
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0705 - root_mean_squared_error: 0.2656INFO:tensorflow:Assets written to: Pacific_model_LT10\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0705 - root_mean_squared_error: 0.2656 - val_loss: 0.0640 - val_root_mean_squared_error: 0.2530
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0642 - root_mean_squared_error: 0.2533INFO:tensorflow:Assets written to: Pacific_model_LT10\assets
# 53/53 [==============================] - 10s 191ms/step - loss: 0.0639 - root_mean_squared_error: 0.2528 - val_loss: 0.0577 - val_root_mean_squared_error: 0.2403
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0550 - root_mean_squared_error: 0.2344INFO:tensorflow:Assets written to: Pacific_model_LT10\assets
# 53/53 [==============================] - 10s 182ms/step - loss: 0.0550 - root_mean_squared_error: 0.2344 - val_loss: 0.0441 - val_root_mean_squared_error: 0.2100
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0416 - root_mean_squared_error: 0.2039INFO:tensorflow:Assets written to: Pacific_model_LT10\assets
# 53/53 [==============================] - 10s 195ms/step - loss: 0.0415 - root_mean_squared_error: 0.2036 - val_loss: 0.0278 - val_root_mean_squared_error: 0.1666
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0288 - root_mean_squared_error: 0.1696INFO:tensorflow:Assets written to: Pacific_model_LT10\assets
# 53/53 [==============================] - 10s 189ms/step - loss: 0.0288 - root_mean_squared_error: 0.1696 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133
# Epoch 9/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0193 - root_mean_squared_error: 0.1390 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1513
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0179 - root_mean_squared_error: 0.1340INFO:tensorflow:Assets written to: Pacific_model_LT10\assets
# 53/53 [==============================] - 10s 200ms/step - loss: 0.0181 - root_mean_squared_error: 0.1347 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0947
# Epoch 11/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0166 - root_mean_squared_error: 0.1290 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0981
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0153 - root_mean_squared_error: 0.1237INFO:tensorflow:Assets written to: Pacific_model_LT10\assets
# 53/53 [==============================] - 10s 192ms/step - loss: 0.0153 - root_mean_squared_error: 0.1237 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0837
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0136 - root_mean_squared_error: 0.1166INFO:tensorflow:Assets written to: Pacific_model_LT10\assets
# 53/53 [==============================] - 10s 191ms/step - loss: 0.0137 - root_mean_squared_error: 0.1169 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0792
# Epoch 14/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0139 - root_mean_squared_error: 0.1178 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0803
# Epoch 15/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0152 - root_mean_squared_error: 0.1232 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 16/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0146 - root_mean_squared_error: 0.1209 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0827
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0143 - root_mean_squared_error: 0.1197INFO:tensorflow:Assets written to: Pacific_model_LT10\assets
# 53/53 [==============================] - 10s 187ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0759
# Epoch 18/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0127 - root_mean_squared_error: 0.1126 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0848
# Epoch 19/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0119 - root_mean_squared_error: 0.1093 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0762
# Epoch 20/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0127 - root_mean_squared_error: 0.1125 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0873
# Epoch 21/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0124 - root_mean_squared_error: 0.1113 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0804
# Epoch 22/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0131 - root_mean_squared_error: 0.1142 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0838
# Epoch 23/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0124 - root_mean_squared_error: 0.1114 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 24/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0108 - root_mean_squared_error: 0.1041 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 25/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0111 - root_mean_squared_error: 0.1056 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0865
# Epoch 26/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0111 - root_mean_squared_error: 0.1052INFO:tensorflow:Assets written to: Pacific_model_LT10\assets
# 53/53 [==============================] - 10s 197ms/step - loss: 0.0111 - root_mean_squared_error: 0.1052 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0749
# Epoch 27/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0103 - root_mean_squared_error: 0.1017 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0807
# Epoch 28/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0115 - root_mean_squared_error: 0.1075 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0778
# Epoch 29/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0109 - root_mean_squared_error: 0.1046INFO:tensorflow:Assets written to: Pacific_model_LT10\assets
# 53/53 [==============================] - 10s 189ms/step - loss: 0.0109 - root_mean_squared_error: 0.1046 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0733
# Epoch 30/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0107 - root_mean_squared_error: 0.1036 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0805
# Epoch 31/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0759
# Epoch 32/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0113 - root_mean_squared_error: 0.1061 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0758
# Epoch 33/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0105 - root_mean_squared_error: 0.1024 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0827
# Epoch 34/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0105 - root_mean_squared_error: 0.1024 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 35/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0093 - root_mean_squared_error: 0.0966 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0771
# Epoch 36/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0097 - root_mean_squared_error: 0.0986 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0851
# Epoch 37/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0096 - root_mean_squared_error: 0.0980 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0754
# Epoch 38/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0094 - root_mean_squared_error: 0.0970 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0815
# Epoch 39/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0093 - root_mean_squared_error: 0.0966 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0815
# Epoch 40/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0099 - root_mean_squared_error: 0.0995 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0736
# Epoch 41/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0101 - root_mean_squared_error: 0.1003 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0755
# Epoch 42/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0106 - root_mean_squared_error: 0.1028 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0763
# Epoch 43/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0089 - root_mean_squared_error: 0.0943 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0738
# Epoch 44/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0090 - root_mean_squared_error: 0.0950 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0745
# Epoch 45/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0097 - root_mean_squared_error: 0.0985INFO:tensorflow:Assets written to: Pacific_model_LT10\assets
# 53/53 [==============================] - 10s 188ms/step - loss: 0.0097 - root_mean_squared_error: 0.0985 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0716
# Epoch 46/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0095 - root_mean_squared_error: 0.0977 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0746
# Epoch 47/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0092 - root_mean_squared_error: 0.0957 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0792
# Epoch 48/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0090 - root_mean_squared_error: 0.0949 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0811
# Epoch 49/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0087 - root_mean_squared_error: 0.0932 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0845
# Epoch 50/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0085 - root_mean_squared_error: 0.0920 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0745

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 3.5727278153101603 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Pacific_model_LT10/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 16ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.07088710396929129
# MAE : 0.055767592121366526

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        4.836707e+05     460009.672
# 1        6.037930e+05     610848.036
# 2        8.521881e+05     819257.445
# 3        1.168721e+06    1129627.707
# 4        1.497964e+06    1463383.236
# 5        1.752239e+06    1614536.727
# 6        1.893901e+06    1862498.612
# 7        1.949582e+06    2099349.296
# 8        1.883444e+06    1981614.046
# 9        1.557164e+06    1433022.369
# 10       9.550854e+05     826739.716
# 11       5.407473e+05     477145.887
# 12       4.684791e+05     314469.289
# 13       5.616827e+05     463134.749
# 14       8.253125e+05     946522.292
# 15       1.175552e+06    1309266.570
# 16       1.522002e+06    1507947.309
# 17       1.763634e+06    1804167.937
# 18       1.892229e+06    1908002.139
# 19       1.937239e+06    1892748.521
# 20       1.856891e+06    1601079.640
# 21       1.439466e+06    1327804.521
# 22       8.179504e+05     812074.231
# 23       5.136691e+05     493355.897
# 24       4.526290e+05     317229.330
# 25       5.344699e+05     425777.624
# 26       7.913345e+05     827172.620
# 27       1.139397e+06    1162367.223
# 28       1.493158e+06    1413734.261
# 29       1.757512e+06    1574257.849
# 30       1.923506e+06    1786961.251
# 31       1.925446e+06    1857942.866
# 32       1.792756e+06    1406291.588
# 33       1.329837e+06    1025555.371
# 34       6.929119e+05     632862.782
# 35       4.742364e+05     308194.756
# 36       4.658493e+05     194921.078
# 37       6.084470e+05     245569.900
# 38       8.720642e+05     533532.424
# 39       1.172401e+06     943124.529
# 40       1.457678e+06    1134056.102
# 41       1.706355e+06    1484824.377
# 42       1.882132e+06    1671324.717
# 43       1.913266e+06    1726376.097
# 44       1.847677e+06    1690631.996

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 14ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
