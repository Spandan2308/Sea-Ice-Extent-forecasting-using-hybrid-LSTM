# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bell_Amundsen_Extent = pd.read_excel(filepath, sheet_name='Bell-Amundsen-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Bell_Amundsen_Extent)
fp.date_time(Bell_Amundsen_Extent)
# Out:
#           Extent       Date
# 0    1179855.894 1979-01-01
# 1     879585.254 1979-02-01
# 2     791619.096 1979-03-01
# 3    1254912.071 1979-04-01
# 4    1620142.247 1979-05-01
# ..           ...        ...
# 533  1556568.455 2023-06-01
# 534  1917507.979 2023-07-01
# 535  2601630.327 2023-08-01
# 536  2534223.780 2023-09-01
# 537  2373004.525 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bell_Amundsen_Extent['Extent'] = scaler.fit_transform(Bell_Amundsen_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 5
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bell_Amundsen_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((522, 12, 1), (522,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Bell_Amund_model_LT5/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2181 - root_mean_squared_error: 0.4670INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 30s 395ms/step - loss: 0.2181 - root_mean_squared_error: 0.4670 - val_loss: 0.1523 - val_root_mean_squared_error: 0.3903
# Epoch 2/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0672 - root_mean_squared_error: 0.2593INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 18s 351ms/step - loss: 0.0673 - root_mean_squared_error: 0.2594 - val_loss: 0.0672 - val_root_mean_squared_error: 0.2593
# Epoch 3/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0479 - root_mean_squared_error: 0.2188INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 18s 336ms/step - loss: 0.0476 - root_mean_squared_error: 0.2181 - val_loss: 0.0582 - val_root_mean_squared_error: 0.2412
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0415 - root_mean_squared_error: 0.2037INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 18s 351ms/step - loss: 0.0413 - root_mean_squared_error: 0.2032 - val_loss: 0.0509 - val_root_mean_squared_error: 0.2256
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0352 - root_mean_squared_error: 0.1875INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 19s 360ms/step - loss: 0.0352 - root_mean_squared_error: 0.1875 - val_loss: 0.0455 - val_root_mean_squared_error: 0.2133
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0295 - root_mean_squared_error: 0.1717INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 19s 374ms/step - loss: 0.0295 - root_mean_squared_error: 0.1717 - val_loss: 0.0383 - val_root_mean_squared_error: 0.1957
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0226 - root_mean_squared_error: 0.1504INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 20s 377ms/step - loss: 0.0226 - root_mean_squared_error: 0.1504 - val_loss: 0.0269 - val_root_mean_squared_error: 0.1639
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0180 - root_mean_squared_error: 0.1340INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 20s 376ms/step - loss: 0.0180 - root_mean_squared_error: 0.1340 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1529
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0153 - root_mean_squared_error: 0.1235INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 20s 376ms/step - loss: 0.0153 - root_mean_squared_error: 0.1235 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1415
# Epoch 10/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0131 - root_mean_squared_error: 0.1142 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1449
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0140 - root_mean_squared_error: 0.1183INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 20s 386ms/step - loss: 0.0139 - root_mean_squared_error: 0.1180 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1309
# Epoch 12/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0116 - root_mean_squared_error: 0.1079 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1315
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0119 - root_mean_squared_error: 0.1089INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 20s 375ms/step - loss: 0.0119 - root_mean_squared_error: 0.1090 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1273
# Epoch 14/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0114 - root_mean_squared_error: 0.1070 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1280
# Epoch 15/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0115 - root_mean_squared_error: 0.1074INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 20s 384ms/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1268
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0118 - root_mean_squared_error: 0.1085INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 19s 365ms/step - loss: 0.0118 - root_mean_squared_error: 0.1085 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1233
# Epoch 17/50
# 53/53 [==============================] - 4s 81ms/step - loss: 0.0113 - root_mean_squared_error: 0.1064 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1250
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0112 - root_mean_squared_error: 0.1057INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 19s 370ms/step - loss: 0.0112 - root_mean_squared_error: 0.1057 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1208
# Epoch 19/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0102 - root_mean_squared_error: 0.1010INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 22s 417ms/step - loss: 0.0104 - root_mean_squared_error: 0.1019 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1203
# Epoch 20/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0101 - root_mean_squared_error: 0.1007 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1217
# Epoch 21/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1216
# Epoch 22/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0101 - root_mean_squared_error: 0.1004INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 19s 369ms/step - loss: 0.0101 - root_mean_squared_error: 0.1006 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1196
# Epoch 23/50
# 53/53 [==============================] - 2s 46ms/step - loss: 0.0094 - root_mean_squared_error: 0.0970 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1222
# Epoch 24/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0101 - root_mean_squared_error: 0.1004INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 20s 376ms/step - loss: 0.0100 - root_mean_squared_error: 0.1001 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1195
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0094 - root_mean_squared_error: 0.0970INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 18s 346ms/step - loss: 0.0094 - root_mean_squared_error: 0.0970 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1193
# Epoch 26/50
# 53/53 [==============================] - 2s 41ms/step - loss: 0.0093 - root_mean_squared_error: 0.0965 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1221
# Epoch 27/50
# 53/53 [==============================] - 2s 42ms/step - loss: 0.0093 - root_mean_squared_error: 0.0965 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1195
# Epoch 28/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0093 - root_mean_squared_error: 0.0964INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 19s 360ms/step - loss: 0.0093 - root_mean_squared_error: 0.0964 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1191
# Epoch 29/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0091 - root_mean_squared_error: 0.0954 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1208
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0096 - root_mean_squared_error: 0.0978INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 15s 282ms/step - loss: 0.0096 - root_mean_squared_error: 0.0978 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1188
# Epoch 31/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0090 - root_mean_squared_error: 0.0951INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 19s 364ms/step - loss: 0.0090 - root_mean_squared_error: 0.0951 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1185
# Epoch 32/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0092 - root_mean_squared_error: 0.0958INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 18s 345ms/step - loss: 0.0091 - root_mean_squared_error: 0.0956 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1183
# Epoch 33/50
# 53/53 [==============================] - 4s 75ms/step - loss: 0.0095 - root_mean_squared_error: 0.0976 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1194
# Epoch 34/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.0092 - root_mean_squared_error: 0.0958 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1203
# Epoch 35/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0090 - root_mean_squared_error: 0.0946INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 18s 344ms/step - loss: 0.0090 - root_mean_squared_error: 0.0946 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1183
# Epoch 36/50
# 53/53 [==============================] - 4s 78ms/step - loss: 0.0092 - root_mean_squared_error: 0.0960 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1208
# Epoch 37/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0088 - root_mean_squared_error: 0.0939 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1204
# Epoch 38/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0089 - root_mean_squared_error: 0.0946 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1190
# Epoch 39/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0089 - root_mean_squared_error: 0.0943INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 18s 346ms/step - loss: 0.0089 - root_mean_squared_error: 0.0941 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1180
# Epoch 40/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0083 - root_mean_squared_error: 0.0912INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 18s 343ms/step - loss: 0.0083 - root_mean_squared_error: 0.0911 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1167
# Epoch 41/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0091 - root_mean_squared_error: 0.0955 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1173
# Epoch 42/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0086 - root_mean_squared_error: 0.0928 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1172
# Epoch 43/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0087 - root_mean_squared_error: 0.0932 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1181
# Epoch 44/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0086 - root_mean_squared_error: 0.0926INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 18s 340ms/step - loss: 0.0085 - root_mean_squared_error: 0.0923 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1161
# Epoch 45/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0084 - root_mean_squared_error: 0.0915 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1164
# Epoch 46/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0082 - root_mean_squared_error: 0.0905 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1187
# Epoch 47/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0093 - root_mean_squared_error: 0.0963INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 19s 373ms/step - loss: 0.0092 - root_mean_squared_error: 0.0959 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1158
# Epoch 48/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0090 - root_mean_squared_error: 0.0951 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1163
# Epoch 49/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0083 - root_mean_squared_error: 0.0909INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 23s 436ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1156
# Epoch 50/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0086 - root_mean_squared_error: 0.0925 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1161

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 10.159025923411052 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bell_Amund_model_LT5/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 26ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.09643025410874138
# MAE : 0.07767530906236743

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        2.217212e+06    1856673.675
# 1        2.085233e+06    1914289.680
# 2        1.765011e+06    1802244.842
# 3        1.331054e+06    1202791.069
# 4        7.675278e+05     752834.272
# 5        4.321072e+05     451914.219
# 6        4.814752e+05     439855.813
# 7        7.135900e+05     807857.307
# 8        1.098739e+06    1184280.145
# 9        1.492616e+06    1468308.405
# 10       1.815947e+06    1540851.607
# 11       1.986372e+06    1989099.836
# 12       2.012791e+06    2096990.761
# 13       1.914656e+06    2080961.032
# 14       1.658898e+06    1695704.661
# 15       1.317405e+06    1533888.370
# 16       8.121510e+05    1038332.675
# 17       3.949963e+05     602954.621
# 18       4.283073e+05     895484.288
# 19       6.868188e+05    1070622.700
# 20       1.017086e+06    1532457.922
# 21       1.372868e+06    1703762.123
# 22       1.686968e+06    1855079.122
# 23       1.842371e+06    2291960.639
# 24       1.885866e+06    2114120.417
# 25       1.765201e+06    1995818.759
# 26       1.490051e+06    1653379.997
# 27       1.122398e+06    1070814.995
# 28       6.250010e+05     689443.815
# 29       4.616473e+05     401148.663
# 30       5.734854e+05     346558.057
# 31       8.396392e+05     599477.678
# 32       1.257154e+06     765764.905
# 33       1.675254e+06    1304133.179
# 34       1.931911e+06    1598436.099
# 35       2.095148e+06    1763844.414
# 36       2.142377e+06    1979139.524
# 37       2.075217e+06    1937348.663
# 38       1.840877e+06    1833093.342
# 39       1.446607e+06    1089676.114
# 40       9.580188e+05     453484.731
# 41       4.451228e+05     251559.554
# 42       3.888821e+05     351294.657
# 43       6.040242e+05     702389.714
# 44       9.672319e+05    1185169.054
# 45       1.400690e+06    1556568.455
# 46       1.762822e+06    1917507.979
# 47       2.001643e+06    2601630.327
# 48       2.053880e+06    2534223.780
# 49       1.932115e+06    2373004.525

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 27ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
