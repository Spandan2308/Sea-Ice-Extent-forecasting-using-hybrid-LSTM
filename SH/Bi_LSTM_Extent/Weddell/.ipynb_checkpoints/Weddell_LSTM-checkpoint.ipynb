# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Weddell_Extent = pd.read_excel(filepath, sheet_name='Weddell-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Weddell_Extent)
fp.date_time(Weddell_Extent)
# Out:
#           Extent       Date
# 0    2136510.859 1979-01-01
# 1    1243495.891 1979-02-01
# 2    1699053.449 1979-03-01
# 3    2617442.085 1979-04-01
# 4    3852934.206 1979-05-01
# ..           ...        ...
# 533  3668127.143 2023-06-01
# 534  4805519.784 2023-07-01
# 535  5524445.234 2023-08-01
# 536  6006669.861 2023-09-01
# 537  5507961.583 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Weddell_Extent['Extent'] = scaler.fit_transform(Weddell_Extent['Extent'].values.reshape(-1, 1))

# %%
extent = Weddell_Extent['Extent']
W_S=12
X,y = fp.df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((526, 12, 1), (526,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Weddell_model/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.2988 - root_mean_squared_error: 0.5466INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 39s 524ms/step - loss: 0.2987 - root_mean_squared_error: 0.5465 - val_loss: 0.2002 - val_root_mean_squared_error: 0.4474
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1298 - root_mean_squared_error: 0.3603INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 28s 541ms/step - loss: 0.1298 - root_mean_squared_error: 0.3603 - val_loss: 0.0948 - val_root_mean_squared_error: 0.3079
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0878 - root_mean_squared_error: 0.2964INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 27s 519ms/step - loss: 0.0878 - root_mean_squared_error: 0.2964 - val_loss: 0.0786 - val_root_mean_squared_error: 0.2804
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0762 - root_mean_squared_error: 0.2760INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0761 - root_mean_squared_error: 0.2758 - val_loss: 0.0720 - val_root_mean_squared_error: 0.2683
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0596 - root_mean_squared_error: 0.2441INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 26s 506ms/step - loss: 0.0596 - root_mean_squared_error: 0.2441 - val_loss: 0.0484 - val_root_mean_squared_error: 0.2200
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0396 - root_mean_squared_error: 0.1991INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 27s 511ms/step - loss: 0.0393 - root_mean_squared_error: 0.1983 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1643
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0230 - root_mean_squared_error: 0.1518INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 25s 475ms/step - loss: 0.0230 - root_mean_squared_error: 0.1515 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1137
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0163 - root_mean_squared_error: 0.1278INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 25s 476ms/step - loss: 0.0163 - root_mean_squared_error: 0.1278 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1060
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0133 - root_mean_squared_error: 0.1151INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 27s 512ms/step - loss: 0.0133 - root_mean_squared_error: 0.1151 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0948
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0126 - root_mean_squared_error: 0.1125INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 27s 523ms/step - loss: 0.0126 - root_mean_squared_error: 0.1125 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0942
# Epoch 11/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0113 - root_mean_squared_error: 0.1062 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1021
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0105 - root_mean_squared_error: 0.1024INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 27s 511ms/step - loss: 0.0105 - root_mean_squared_error: 0.1024 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0782
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0102 - root_mean_squared_error: 0.1009INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 27s 523ms/step - loss: 0.0102 - root_mean_squared_error: 0.1009 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0755
# Epoch 14/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0086 - root_mean_squared_error: 0.0925 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0828
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0088 - root_mean_squared_error: 0.0939INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 27s 519ms/step - loss: 0.0088 - root_mean_squared_error: 0.0939 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0699
# Epoch 16/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0079 - root_mean_squared_error: 0.0888 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1152
# Epoch 17/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0078 - root_mean_squared_error: 0.0885 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0880
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0065 - root_mean_squared_error: 0.0805INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 27s 525ms/step - loss: 0.0065 - root_mean_squared_error: 0.0805 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0667
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0068 - root_mean_squared_error: 0.0824INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 27s 524ms/step - loss: 0.0068 - root_mean_squared_error: 0.0824 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0641
# Epoch 20/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0065 - root_mean_squared_error: 0.0808INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 26s 507ms/step - loss: 0.0065 - root_mean_squared_error: 0.0805 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609
# Epoch 21/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0063 - root_mean_squared_error: 0.0794 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0695
# Epoch 22/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0058 - root_mean_squared_error: 0.0762 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0630
# Epoch 23/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0063 - root_mean_squared_error: 0.0792INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 27s 520ms/step - loss: 0.0063 - root_mean_squared_error: 0.0792 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0600
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0052 - root_mean_squared_error: 0.0720INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 28s 533ms/step - loss: 0.0052 - root_mean_squared_error: 0.0720 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0593
# Epoch 25/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0062 - root_mean_squared_error: 0.0790 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0784
# Epoch 26/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0053 - root_mean_squared_error: 0.0728INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 27s 516ms/step - loss: 0.0053 - root_mean_squared_error: 0.0728 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0592
# Epoch 27/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0057 - root_mean_squared_error: 0.0753 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0646
# Epoch 28/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0045 - root_mean_squared_error: 0.0672INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 28s 534ms/step - loss: 0.0045 - root_mean_squared_error: 0.0672 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0577
# Epoch 29/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0051 - root_mean_squared_error: 0.0712 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0646
# Epoch 30/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0045 - root_mean_squared_error: 0.0672 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0579
# Epoch 31/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0055 - root_mean_squared_error: 0.0740INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 27s 516ms/step - loss: 0.0055 - root_mean_squared_error: 0.0740 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0572
# Epoch 32/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0045 - root_mean_squared_error: 0.0671 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0628
# Epoch 33/50
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0048 - root_mean_squared_error: 0.0696 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610
# Epoch 34/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0046 - root_mean_squared_error: 0.0680INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 28s 529ms/step - loss: 0.0046 - root_mean_squared_error: 0.0680 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0558
# Epoch 35/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0045 - root_mean_squared_error: 0.0674INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 27s 525ms/step - loss: 0.0045 - root_mean_squared_error: 0.0673 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0533
# Epoch 36/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0046 - root_mean_squared_error: 0.0681 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0579
# Epoch 37/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0046 - root_mean_squared_error: 0.0677 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0718
# Epoch 38/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0045 - root_mean_squared_error: 0.0672 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0754
# Epoch 39/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0044 - root_mean_squared_error: 0.0660 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0600
# Epoch 40/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0040 - root_mean_squared_error: 0.0629INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 27s 519ms/step - loss: 0.0040 - root_mean_squared_error: 0.0629 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0523
# Epoch 41/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0042 - root_mean_squared_error: 0.0650 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0599
# Epoch 42/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0043 - root_mean_squared_error: 0.0658 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0528
# Epoch 43/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0037 - root_mean_squared_error: 0.0612 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0639
# Epoch 44/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0039 - root_mean_squared_error: 0.0622 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0588
# Epoch 45/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0037 - root_mean_squared_error: 0.0607 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0595
# Epoch 46/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0039 - root_mean_squared_error: 0.0628 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0557
# Epoch 47/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0038 - root_mean_squared_error: 0.0620 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0650
# Epoch 48/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0040 - root_mean_squared_error: 0.0632 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0583
# Epoch 49/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0041 - root_mean_squared_error: 0.0641INFO:tensorflow:Assets written to: Weddell_model\assets
# 53/53 [==============================] - 27s 510ms/step - loss: 0.0041 - root_mean_squared_error: 0.0641 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0489
# Epoch 50/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0041 - root_mean_squared_error: 0.0641 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0524

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 12.889965105056763 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Weddell_model/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 24ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.043150048931041414
# MAE : 0.035747597367023154

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        3.210875e+06    2787848.748
# 1        4.299675e+06    4544849.638
# 2        5.419746e+06    5882741.038
# 3        6.081028e+06    6574288.749
# 4        6.411759e+06    6669726.076
# 5        6.322817e+06    6516136.854
# 6        5.622343e+06    5902163.675
# 7        3.647983e+06    3498103.449
# 8        1.514723e+06    1633675.726
# 9        9.365024e+05    1292668.399
# 10       1.115266e+06    1527666.815
# 11       1.980256e+06    2121949.701
# 12       3.305786e+06    3562381.775
# 13       4.782615e+06    5004305.983
# 14       5.830504e+06    6176613.878
# 15       6.443588e+06    6794233.093
# 16       6.694684e+06    7024136.637
# 17       6.551880e+06    6554271.388
# 18       5.775428e+06    6172281.701
# 19       3.572528e+06    4175225.799
# 20       1.540292e+06    1748380.899
# 21       1.012744e+06    1256191.080
# 22       1.218281e+06    1347295.364
# 23       2.084533e+06    2180184.677
# 24       3.465692e+06    3419295.982
# 25       4.824434e+06    4786146.771
# 26       5.848144e+06    5968132.718
# 27       6.433217e+06    6556934.174
# 28       6.688277e+06    6614949.980
# 29       6.498437e+06    6035207.368
# 30       5.790150e+06    5274244.730
# 31       3.951965e+06    3505146.372
# 32       1.440824e+06    1478130.228
# 33       9.463384e+05    1096780.503
# 34       1.246710e+06    1387234.069
# 35       2.267481e+06    2128693.591
# 36       3.577377e+06    3313318.704
# 37       4.769280e+06    4218076.656
# 38       5.588692e+06    5257641.941
# 39       6.035988e+06    5956603.340
# 40       6.193012e+06    6256062.049
# 41       6.035298e+06    5974548.305
# 42       5.376238e+06    5569396.731
# 43       3.711974e+06    3684108.410
# 44       1.556828e+06    1451614.707
# 45       9.886231e+05    1089888.684
# 46       1.190944e+06    1255222.909
# 47       2.036120e+06    1704492.279
# 48       3.148556e+06    2563551.804
# 49       4.138651e+06    3668127.143
# 50       5.072495e+06    4805519.784
# 51       5.714889e+06    5524445.234
# 52       5.985054e+06    6006669.861
# 53       5.980740e+06    5507961.583

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 16ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
