# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Baffin = pd.read_excel(filepath, sheet_name='Baffin-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Baffin)
fp.date_time(Baffin)
# Out:
#           Extent       Date
# 0    1090625.815 1979-01-01
# 1    1157634.866 1979-02-01
# 2    1299583.477 1979-03-01
# 3    1137194.680 1979-04-01
# 4     983083.453 1979-05-01
# ..           ...        ...
# 533   781460.891 2023-06-01
# 534   331845.048 2023-07-01
# 535    99334.625 2023-08-01
# 536    49359.723 2023-09-01
# 537    85693.282 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Baffin['Extent'] = scaler.fit_transform(Baffin['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 5
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Baffin['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((522, 12, 1), (522,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Baffin_model_LT5/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2023 - root_mean_squared_error: 0.4498INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 34s 466ms/step - loss: 0.2023 - root_mean_squared_error: 0.4498 - val_loss: 0.1025 - val_root_mean_squared_error: 0.3202
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0803 - root_mean_squared_error: 0.2835INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 24s 460ms/step - loss: 0.0803 - root_mean_squared_error: 0.2835 - val_loss: 0.0595 - val_root_mean_squared_error: 0.2439
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0597 - root_mean_squared_error: 0.2444INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 23s 438ms/step - loss: 0.0599 - root_mean_squared_error: 0.2448 - val_loss: 0.0482 - val_root_mean_squared_error: 0.2196
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0468 - root_mean_squared_error: 0.2163INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 24s 468ms/step - loss: 0.0470 - root_mean_squared_error: 0.2169 - val_loss: 0.0352 - val_root_mean_squared_error: 0.1876
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0329 - root_mean_squared_error: 0.1815INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 24s 463ms/step - loss: 0.0329 - root_mean_squared_error: 0.1815 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1415
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0231 - root_mean_squared_error: 0.1519INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 23s 442ms/step - loss: 0.0231 - root_mean_squared_error: 0.1519 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1189
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0163 - root_mean_squared_error: 0.1276INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 23s 439ms/step - loss: 0.0163 - root_mean_squared_error: 0.1276 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0801
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0132 - root_mean_squared_error: 0.1148INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 29s 564ms/step - loss: 0.0133 - root_mean_squared_error: 0.1152 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0706
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0110 - root_mean_squared_error: 0.1047INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 25s 474ms/step - loss: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0621
# Epoch 10/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0645
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0090 - root_mean_squared_error: 0.0949INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 27s 522ms/step - loss: 0.0090 - root_mean_squared_error: 0.0949 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0529
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0089 - root_mean_squared_error: 0.0944INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 25s 483ms/step - loss: 0.0089 - root_mean_squared_error: 0.0944 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0517
# Epoch 13/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0075 - root_mean_squared_error: 0.0863 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0521
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0906INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 25s 480ms/step - loss: 0.0082 - root_mean_squared_error: 0.0906 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0510
# Epoch 15/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0076 - root_mean_squared_error: 0.0870INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 26s 496ms/step - loss: 0.0075 - root_mean_squared_error: 0.0868 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0485
# Epoch 16/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0077 - root_mean_squared_error: 0.0878 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0520
# Epoch 17/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0074 - root_mean_squared_error: 0.0862INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 25s 481ms/step - loss: 0.0076 - root_mean_squared_error: 0.0870 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0481
# Epoch 18/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0074 - root_mean_squared_error: 0.0858 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0511
# Epoch 19/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0073 - root_mean_squared_error: 0.0852 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0498
# Epoch 20/50
# 53/53 [==============================] - 4s 77ms/step - loss: 0.0071 - root_mean_squared_error: 0.0841 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0507
# Epoch 21/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0063 - root_mean_squared_error: 0.0793 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0501
# Epoch 22/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0060 - root_mean_squared_error: 0.0774 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0506
# Epoch 23/50
# 53/53 [==============================] - 4s 78ms/step - loss: 0.0065 - root_mean_squared_error: 0.0804 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0535
# Epoch 24/50
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0066 - root_mean_squared_error: 0.0813 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0543
# Epoch 25/50
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0069 - root_mean_squared_error: 0.0833 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0486
# Epoch 26/50
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0069 - root_mean_squared_error: 0.0831 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0555
# Epoch 27/50
# 53/53 [==============================] - 4s 78ms/step - loss: 0.0068 - root_mean_squared_error: 0.0824 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0500
# Epoch 28/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0062 - root_mean_squared_error: 0.0790 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0534
# Epoch 29/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0064 - root_mean_squared_error: 0.0800 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0495
# Epoch 30/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0063 - root_mean_squared_error: 0.0792 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0490
# Epoch 31/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0064 - root_mean_squared_error: 0.0797 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0504
# Epoch 32/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0061 - root_mean_squared_error: 0.0783 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0490
# Epoch 33/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0066 - root_mean_squared_error: 0.0814 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0534
# Epoch 34/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0060 - root_mean_squared_error: 0.0773 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0513
# Epoch 35/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0063 - root_mean_squared_error: 0.0792 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0521
# Epoch 36/50
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0064 - root_mean_squared_error: 0.0798 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0540
# Epoch 37/50
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0067 - root_mean_squared_error: 0.0815 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0488
# Epoch 38/50
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0061 - root_mean_squared_error: 0.0781 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0556
# Epoch 39/50
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0064 - root_mean_squared_error: 0.0798 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0506
# Epoch 40/50
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0063 - root_mean_squared_error: 0.0795 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0490
# Epoch 41/50
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0059 - root_mean_squared_error: 0.0770 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0532
# Epoch 42/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0060 - root_mean_squared_error: 0.0772INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 40s 769ms/step - loss: 0.0060 - root_mean_squared_error: 0.0772 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0466
# Epoch 43/50
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0059 - root_mean_squared_error: 0.0771 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0512
# Epoch 44/50
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0063 - root_mean_squared_error: 0.0792 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0546
# Epoch 45/50
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0058 - root_mean_squared_error: 0.0760 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0519
# Epoch 46/50
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0062 - root_mean_squared_error: 0.0787 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0471
# Epoch 47/50
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0062 - root_mean_squared_error: 0.0785 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0480
# Epoch 48/50
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0061 - root_mean_squared_error: 0.0783 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0533
# Epoch 49/50
# 53/53 [==============================] - 5s 85ms/step - loss: 0.0064 - root_mean_squared_error: 0.0801 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0509
# Epoch 50/50
# 53/53 [==============================] - 4s 78ms/step - loss: 0.0057 - root_mean_squared_error: 0.0754 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0483

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 8.978936370213827 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Baffin_model_LT5/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 54ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.062442363473002624
# MAE : 0.04599865084484188

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        3.126697e+04      27600.624
# 1        2.118326e+05      61057.940
# 2        5.607783e+05     291275.949
# 3        8.988574e+05     678576.504
# 4        1.102466e+06     974461.347
# 5        1.205625e+06    1181121.087
# 6        1.214540e+06    1236299.254
# 7        1.129150e+06    1036981.003
# 8        9.498162e+05     847489.150
# 9        6.928885e+05     619129.338
# 10       3.473629e+05     195688.491
# 11       3.029316e+04      36670.811
# 12      -6.330532e+03      31777.310
# 13       1.389910e+05      82762.022
# 14       4.294130e+05     400043.823
# 15       7.464791e+05     733089.555
# 16       9.759721e+05     917362.266
# 17       1.106498e+06    1040584.040
# 18       1.147227e+06    1147997.675
# 19       1.074996e+06    1074255.327
# 20       9.063530e+05     875527.315
# 21       6.637528e+05     629820.756
# 22       3.541928e+05     204308.900
# 23       5.123473e+04      45059.062
# 24       7.979983e+03      33770.277
# 25       1.410651e+05      64135.631
# 26       4.293775e+05     400581.715
# 27       7.407910e+05     698631.451
# 28       9.653697e+05     973313.225
# 29       1.090122e+06    1335339.087
# 30       1.126553e+06    1429096.704
# 31       1.056518e+06    1206542.314
# 32       9.022062e+05    1079292.433
# 33       6.603852e+05     788101.638
# 34       2.911404e+05     397326.270
# 35      -9.240526e+03      97802.348
# 36      -2.038613e+04      62212.219
# 37       1.212433e+05     154051.600
# 38       4.330127e+05     610663.893
# 39       7.741887e+05     756679.164
# 40       1.052840e+06     962270.215
# 41       1.216717e+06    1235154.518
# 42       1.278077e+06    1161744.519
# 43       1.187481e+06    1136918.669
# 44       1.022313e+06     995852.026
# 45       7.922528e+05     781460.891
# 46       4.596568e+05     331845.048
# 47       1.168761e+05      99334.625
# 48       2.242391e+04      49359.723
# 49       1.609463e+05      85693.282

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 44ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
