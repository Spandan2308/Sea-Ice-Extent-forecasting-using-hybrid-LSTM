# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Indian_Extent = pd.read_excel(filepath, sheet_name='Indian-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Indian_Extent)
fp.date_time(Indian_Extent)
# Out:
#           Extent       Date
# 0     376618.799 1979-01-01
# 1     211788.726 1979-02-01
# 2     262868.141 1979-03-01
# 3     698377.304 1979-04-01
# 4    1252407.727 1979-05-01
# ..           ...        ...
# 533  1520776.003 2023-06-01
# 534  2076164.165 2023-07-01
# 535  2731799.027 2023-08-01
# 536  3179384.692 2023-09-01
# 537  3301335.210 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Indian_Extent['Extent'] = scaler.fit_transform(Indian_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 6
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Indian_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((521, 12, 1), (521,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Indian_model_LT6/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.2315 - root_mean_squared_error: 0.4812
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 8s 92ms/step - loss: 0.2279 - root_mean_squared_error: 0.4774 - val_loss: 0.2217 - val_root_mean_squared_error: 0.4708
# Epoch 2/50
# 40/53 [=====================>........] - ETA: 0s - loss: 0.1714 - root_mean_squared_error: 0.4140
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.1736 - root_mean_squared_error: 0.4166 - val_loss: 0.1931 - val_root_mean_squared_error: 0.4394
# Epoch 3/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.1472 - root_mean_squared_error: 0.3836
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.1455 - root_mean_squared_error: 0.3814 - val_loss: 0.1710 - val_root_mean_squared_error: 0.4135
# Epoch 4/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.1218 - root_mean_squared_error: 0.3490
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.1280 - root_mean_squared_error: 0.3578 - val_loss: 0.1499 - val_root_mean_squared_error: 0.3872
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1022 - root_mean_squared_error: 0.3197
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.1023 - root_mean_squared_error: 0.3198 - val_loss: 0.1315 - val_root_mean_squared_error: 0.3626
# Epoch 6/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0865 - root_mean_squared_error: 0.2941
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 5s 86ms/step - loss: 0.0861 - root_mean_squared_error: 0.2935 - val_loss: 0.1108 - val_root_mean_squared_error: 0.3328
# Epoch 7/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0712 - root_mean_squared_error: 0.2668
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0712 - root_mean_squared_error: 0.2668 - val_loss: 0.0938 - val_root_mean_squared_error: 0.3063
# Epoch 8/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0525 - root_mean_squared_error: 0.2291
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0562 - root_mean_squared_error: 0.2370 - val_loss: 0.0749 - val_root_mean_squared_error: 0.2737
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0466 - root_mean_squared_error: 0.2158
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0466 - root_mean_squared_error: 0.2158 - val_loss: 0.0587 - val_root_mean_squared_error: 0.2423
# Epoch 10/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0371 - root_mean_squared_error: 0.1927
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0350 - root_mean_squared_error: 0.1870 - val_loss: 0.0443 - val_root_mean_squared_error: 0.2106
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0303 - root_mean_squared_error: 0.1739
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0300 - root_mean_squared_error: 0.1732 - val_loss: 0.0295 - val_root_mean_squared_error: 0.1718
# Epoch 12/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0253 - root_mean_squared_error: 0.1590
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 4s 81ms/step - loss: 0.0234 - root_mean_squared_error: 0.1530 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1499
# Epoch 13/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0225 - root_mean_squared_error: 0.1499
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0227 - root_mean_squared_error: 0.1508 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1141
# Epoch 14/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0214 - root_mean_squared_error: 0.1462
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0226 - root_mean_squared_error: 0.1503 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0848
# Epoch 15/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0173 - root_mean_squared_error: 0.1314
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0173 - root_mean_squared_error: 0.1315 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0682
# Epoch 16/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0179 - root_mean_squared_error: 0.1337
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 5s 99ms/step - loss: 0.0190 - root_mean_squared_error: 0.1380 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0660
# Epoch 17/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0147 - root_mean_squared_error: 0.1214
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 5s 104ms/step - loss: 0.0144 - root_mean_squared_error: 0.1200 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0585
# Epoch 18/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0162 - root_mean_squared_error: 0.1271
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0164 - root_mean_squared_error: 0.1281 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0556
# Epoch 19/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0192 - root_mean_squared_error: 0.1387 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0640
# Epoch 20/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0149 - root_mean_squared_error: 0.1222 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0636
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0595
# Epoch 22/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0152 - root_mean_squared_error: 0.1234 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0651
# Epoch 23/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0141 - root_mean_squared_error: 0.1189
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 4s 81ms/step - loss: 0.0159 - root_mean_squared_error: 0.1261 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0529
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0175 - root_mean_squared_error: 0.1322 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0562
# Epoch 25/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0198 - root_mean_squared_error: 0.1407
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0193 - root_mean_squared_error: 0.1388 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0527
# Epoch 26/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0154 - root_mean_squared_error: 0.1241 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0545
# Epoch 27/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0132 - root_mean_squared_error: 0.1151 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0567
# Epoch 28/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0189 - root_mean_squared_error: 0.1375 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0594
# Epoch 29/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0137 - root_mean_squared_error: 0.1170 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0718
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0155 - root_mean_squared_error: 0.1245 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0629
# Epoch 31/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0149 - root_mean_squared_error: 0.1223 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0531
# Epoch 32/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0168 - root_mean_squared_error: 0.1298 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0568
# Epoch 33/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0147 - root_mean_squared_error: 0.1212 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0603
# Epoch 34/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0139 - root_mean_squared_error: 0.1180 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0669
# Epoch 35/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0550
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0147 - root_mean_squared_error: 0.1212 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0758
# Epoch 37/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0117 - root_mean_squared_error: 0.1080 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0585
# Epoch 38/50
# 53/53 [==============================] - 0s 4ms/step - loss: 0.0159 - root_mean_squared_error: 0.1262 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0639
# Epoch 39/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0723
# Epoch 40/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0159 - root_mean_squared_error: 0.1261
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 5s 105ms/step - loss: 0.0155 - root_mean_squared_error: 0.1245 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0521
# Epoch 41/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0151 - root_mean_squared_error: 0.1228 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0585
# Epoch 42/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0155 - root_mean_squared_error: 0.1246 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0762
# Epoch 43/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0152 - root_mean_squared_error: 0.1235 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0535
# Epoch 44/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0641
# Epoch 45/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0153 - root_mean_squared_error: 0.1239 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0581
# Epoch 46/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0111 - root_mean_squared_error: 0.1055
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# INFO:tensorflow:Assets written to: Indian_model_LT6\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0111 - root_mean_squared_error: 0.1055 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0493
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0111 - root_mean_squared_error: 0.1054 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0627
# Epoch 48/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0138 - root_mean_squared_error: 0.1173 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0685
# Epoch 49/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0110 - root_mean_squared_error: 0.1049 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0557
# Epoch 50/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0108 - root_mean_squared_error: 0.1040 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0676

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.9270726323127747 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Indian_model_LT6/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 16ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.07669242845776404
# MAE : 0.06689216128016653

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        3.549456e+06    3636501.241
# 1        3.082246e+06    2526913.818
# 2        1.630932e+06    1128752.378
# 3        6.930058e+05     522831.371
# 4       -8.556746e+03     346601.304
# 5        1.055050e+05     444914.605
# 6        4.169830e+05     827036.916
# 7        1.258749e+06    1142021.216
# 8        1.700248e+06    1885693.654
# 9        2.414833e+06    2542569.663
# 10       2.833570e+06    3107373.845
# 11       3.217836e+06    3488175.444
# 12       3.101146e+06    3746306.528
# 13       2.498333e+06    2942322.822
# 14       1.307039e+06    1507212.955
# 15       4.056941e+05     648507.437
# 16       8.478872e+04     352564.010
# 17       2.365297e+05     453587.503
# 18       5.126488e+05     841043.793
# 19       1.156366e+06    1433155.266
# 20       1.755312e+06    2163687.646
# 21       2.333019e+06    2848863.133
# 22       2.898499e+06    3420877.229
# 23       3.410157e+06    3752886.938
# 24       3.266156e+06    3778951.818
# 25       2.604289e+06    2892177.223
# 26       1.176924e+06    1467610.428
# 27       4.452866e+05     377930.941
# 28       2.354618e+05     146440.376
# 29       2.737022e+05     244356.473
# 30       6.772863e+05     612217.566
# 31       1.230210e+06    1261627.075
# 32       1.873561e+06    1720565.225
# 33       2.452633e+06    2564005.541
# 34       3.304714e+06    2983773.529
# 35       3.776705e+06    3372645.223
# 36       3.846809e+06    3589687.043
# 37       3.128800e+06    2669385.189
# 38       1.704497e+06    1095398.946
# 39       6.038283e+05     319828.826
# 40       3.025505e+05     162541.182
# 41       3.198969e+05     179564.232
# 42       6.173327e+05     593196.107
# 43       1.229028e+06    1053508.835
# 44       1.854799e+06    1520776.003
# 45       2.389248e+06    2076164.165
# 46       3.045028e+06    2731799.027
# 47       3.438919e+06    3179384.692
# 48       3.517124e+06    3301335.210

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 5ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
