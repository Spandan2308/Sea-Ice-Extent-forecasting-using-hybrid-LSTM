# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'

Bell_Amundsen_Extent = pd.read_excel(filepath, sheet_name='Bell-Amundsen-Extent-km^2')
Indian_Extent = pd.read_excel(filepath, sheet_name='Indian-Extent-km^2')
Pacific_Extent = pd.read_excel(filepath, sheet_name='Pacific-Extent-km^2')
Ross_Extent = pd.read_excel(filepath, sheet_name='Ross-Extent-km^2')
Weddell_Extent = pd.read_excel(filepath, sheet_name='Weddell-Extent-km^2')

# %%
import Function as fp

# %%
fp.month_mapping(Bell_Amundsen_Extent)
fp.date_time(Bell_Amundsen_Extent)

fp.month_mapping(Indian_Extent)
fp.date_time(Indian_Extent)

fp.month_mapping(Pacific_Extent)
fp.date_time(Pacific_Extent)

fp.month_mapping(Ross_Extent)
fp.date_time(Ross_Extent)

fp.month_mapping(Weddell_Extent)
fp.date_time(Weddell_Extent)
# Out:
#           Extent       Date
# 0    2136510.859 1979-01-01
# 1    1243495.891 1979-02-01
# 2    1699053.449 1979-03-01
# 3    2617442.085 1979-04-01
# 4    3852934.206 1979-05-01
# ..           ...        ...
# 533  3668127.143 2023-06-01
# 534  4805519.784 2023-07-01
# 535  5524445.234 2023-08-01
# 536  6006669.861 2023-09-01
# 537  5507961.583 2023-10-01
#
# [538 rows x 2 columns]

# %%
ba_mar = Bell_Amundsen_Extent[Bell_Amundsen_Extent['Date'].dt.month == 3]['Extent']
ind_mar = Indian_Extent[Indian_Extent['Date'].dt.month == 3]['Extent']
pac_mar = Pacific_Extent[Pacific_Extent['Date'].dt.month == 3]['Extent']
ross_mar = Ross_Extent[Ross_Extent['Date'].dt.month == 3]['Extent']
wed_mar = Weddell_Extent[Weddell_Extent['Date'].dt.month == 3]['Extent']

# %%
fig, axs = plt.subplots(2, 3, figsize=(16, 10))

axs[0, 0].plot(Bell_Amundsen_Extent['Date'].dt.year.unique(), ba_mar, label='March')
axs[0, 0].plot(Bell_Amundsen_Extent['Date'].dt.year.unique(), ba_sept, label='September')

axs[0, 1].plot(Bell_Amundsen_Extent['Date'].dt.year.unique(), ind_mar, label='March')
axs[0, 1].plot(Bell_Amundsen_Extent['Date'].dt.year.unique(), ind_sept, label='September')

axs[0, 2].plot(Bell_Amundsen_Extent['Date'].dt.year.unique(), pac_mar, label='March')
axs[0, 2].plot(Bell_Amundsen_Extent['Date'].dt.year.unique(), pac_sept, label='September')

axs[1, 0].plot(Bell_Amundsen_Extent['Date'].dt.year.unique(), ross_mar, label='March')
axs[1, 0].plot(Bell_Amundsen_Extent['Date'].dt.year.unique(), ross_sept, label='September')

axs[1, 1].plot(Bell_Amundsen_Extent['Date'].dt.year.unique(), wed_mar, label='March')
axs[1, 1].plot(Bell_Amundsen_Extent['Date'].dt.year.unique(), wed_sept, label='September')
axs[1, 2].axis('off')

axs[0,0].set_title('Bell Amundsen Sea')
axs[0,1].set_title('Indian Sea')
axs[0,2].set_title('Pacific Sea')
axs[1,0].set_title('Ross Sea')
axs[1,1].set_title('Weddell Sea')

fig.suptitle('Trend in March')
for ax in axs.flat:
    ax.set(xlabel='Year', ylabel='Extent')

axs[0,0].legend()
plt.tight_layout(rect=[0, 0, 1, 0.96])

plt.show()

# %%
ba_sept = Bell_Amundsen_Extent[Bell_Amundsen_Extent['Date'].dt.month == 9]['Extent']
ind_sept = Indian_Extent[Indian_Extent['Date'].dt.month == 9]['Extent']
pac_sept = Pacific_Extent[Pacific_Extent['Date'].dt.month == 9]['Extent']
ross_sept = Ross_Extent[Ross_Extent['Date'].dt.month == 9]['Extent']
wed_sept = Weddell_Extent[Weddell_Extent['Date'].dt.month == 9]['Extent']

# %%
fig, axs = plt.subplots(2, 3, figsize=(16, 10))

axs[0, 0].plot(Bell_Amundsen_Extent['Date'].dt.year.unique(), ba_sept)
axs[0, 1].plot(Bell_Amundsen_Extent['Date'].dt.year.unique(), ind_sept)
axs[0, 2].plot(Bell_Amundsen_Extent['Date'].dt.year.unique(), pac_sept)
axs[1, 0].plot(Bell_Amundsen_Extent['Date'].dt.year.unique(), ross_sept)
axs[1, 1].plot(Bell_Amundsen_Extent['Date'].dt.year.unique(), wed_sept)
axs[1, 2].axis('off')

axs[0,0].set_title('Bell Amundsen Sea')
axs[0,1].set_title('Indian Sea')
axs[0,2].set_title('Pacific Sea')
axs[1,0].set_title('Ross Sea')
axs[1,1].set_title('Weddell Sea')

fig.suptitle('Trend in September')
for ax in axs.flat:
    ax.set(xlabel='Year', ylabel='Extent')

plt.tight_layout(rect=[0, 0, 1, 0.96])

plt.show()

# %%
df1 = Bell_Amundsen_Extent[Bell_Amundsen_Extent['Date'].dt.year == 2022]
df2 = Indian_Extent[Indian_Extent['Date'].dt.year == 2022]
df3 = Pacific_Extent[Pacific_Extent['Date'].dt.year == 2022]
df4 = Ross_Extent[Ross_Extent['Date'].dt.year == 2022]
df5 = Weddell_Extent[Weddell_Extent['Date'].dt.year == 2022]

# %%
dfs = [df1, df2, df3, df4, df5]

combined_df = pd.DataFrame()

area_names = ['Bell_Amundsen', 'Indian', 'Pacific', 'Ross', 'Weddell']

# %%
for i, (df, area_name) in enumerate(zip(dfs, area_names), start=1):
    df['Area'] = area_name
    combined_df = pd.concat([combined_df, df], ignore_index=True)
# Out:
# C:\Users\ss230\AppData\Local\Temp\ipykernel_13016\4019152727.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Area'] = area_name
# C:\Users\ss230\AppData\Local\Temp\ipykernel_13016\4019152727.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Area'] = area_name
# C:\Users\ss230\AppData\Local\Temp\ipykernel_13016\4019152727.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %%
combined_df
# Out:
#          Extent       Date           Area
# 0    689443.815 2022-01-01  Bell_Amundsen
# 1    401148.663 2022-02-01  Bell_Amundsen
# 2    346558.057 2022-03-01  Bell_Amundsen
# 3    599477.678 2022-04-01  Bell_Amundsen
# 4    765764.905 2022-05-01  Bell_Amundsen
# 5   1304133.179 2022-06-01  Bell_Amundsen
# 6   1598436.099 2022-07-01  Bell_Amundsen
# 7   1763844.414 2022-08-01  Bell_Amundsen
# 8   1979139.524 2022-09-01  Bell_Amundsen
# 9   1937348.663 2022-10-01  Bell_Amundsen
# 10  1833093.342 2022-11-01  Bell_Amundsen
# 11  1089676.114 2022-12-01  Bell_Amundsen
# 12   377930.941 2022-01-01         Indian
# 13   146440.376 2022-02-01         Indian
# 14   244356.473 2022-03-01         Indian
# 15   612217.566 2022-04-01         Indian
# 16  1261627.075 2022-05-01         Indian
# 17  1720565.225 2022-06-01         Indian
# 18  2564005.541 2022-07-01         Indian
# 19  2983773.529 2022-08-01         Indian
# 20  3372645.223 2022-09-01         Indian
# ...

# %%
pivot_df = combined_df.pivot(index='Date', columns='Area', values='Extent')

# %%
pivot_df
# Out:
# Area        Bell_Amundsen       Indian      Pacific         Ross      Weddell
# Date
# 2022-01-01     689443.815   377930.941   493355.897   896425.932  1478130.228
# 2022-02-01     401148.663   146440.376   317229.330   251374.224  1096780.503
# 2022-03-01     346558.057   244356.473   425777.624   455056.048  1387234.069
# 2022-04-01     599477.678   612217.566   827172.620  1780625.872  2128693.591
# 2022-05-01     765764.905  1261627.075  1162367.223  2914989.101  3313318.704
# 2022-06-01    1304133.179  1720565.225  1413734.261  3561620.245  4218076.656
# 2022-07-01    1598436.099  2564005.541  1574257.849  3991717.506  5257641.941
# 2022-08-01    1763844.414  2983773.529  1786961.251  4559070.778  5956603.340
# 2022-09-01    1979139.524  3372645.223  1857942.866  4596327.081  6256062.049
# 2022-10-01    1937348.663  3589687.043  1406291.588  4565650.139  5974548.305
# 2022-11-01    1833093.342  2669385.189  1025555.371  4061902.846  5569396.731
# ...

# %%
pivot_df.plot(kind='area', stacked=True, figsize=(15, 6), colormap='cividis')

plt.title('Extent Values for Different Areas in 2022')
plt.xlabel('Date')
plt.ylabel('Extent Values')

plt.show()

# %%
df1
# Out:
#           Extent       Date           Area
# 516   689443.815 2022-01-01  Bell_Amundsen
# 517   401148.663 2022-02-01  Bell_Amundsen
# 518   346558.057 2022-03-01  Bell_Amundsen
# 519   599477.678 2022-04-01  Bell_Amundsen
# 520   765764.905 2022-05-01  Bell_Amundsen
# 521  1304133.179 2022-06-01  Bell_Amundsen
# 522  1598436.099 2022-07-01  Bell_Amundsen
# 523  1763844.414 2022-08-01  Bell_Amundsen
# 524  1979139.524 2022-09-01  Bell_Amundsen
# 525  1937348.663 2022-10-01  Bell_Amundsen
# 526  1833093.342 2022-11-01  Bell_Amundsen
# 527  1089676.114 2022-12-01  Bell_Amundsen

# %%
plt.figure(figsize=(15,6))
plt.plot(df1['Date'], df1['Extent'], label='Bell_Amundsen')
plt.plot(df2['Date'], df2['Extent'], label='Indian')
plt.plot(df3['Date'], df3['Extent'], label='Pacific')
plt.plot(df4['Date'], df4['Extent'], label='Ross')
plt.plot(df5['Date'], df5['Extent'], label='Weddell')

plt.xlabel('Date')    
plt.ylabel('Extent')
plt.title('Extent Values in 2022')
plt.legend()

plt.show()

# %%
mse = [0.01289361327357528, 0.005860527545756184, 0.004689084236602795, 0.011257094359469342, 0.010341266886775339]
rmse = [0.11355004743977556, 0.07655408248915392, 0.06847688833907974, 0.10609945503851254, 0.1016920197792105]

# %%
MSE = pd.DataFrame(data={'Area': area_names, 'MSE': mse})

# %%
MSE
# Out:
#             Area       MSE
# 0  Bell_Amundsen  0.012894
# 1         Indian  0.005861
# 2        Pacific  0.004689
# 3           Ross  0.011257
# 4        Weddell  0.010341

# %%
plt.bar(MSE['Area'], MSE['MSE'])
plt.xlabel('Area')
plt.ylabel('MSE')
plt.title('Bar Plot of MSE by Area')
plt.show()

# %%
RMSE = pd.DataFrame(data={'Area': area_names, 'RMSE': rmse})

# %%
plt.bar(RMSE['Area'], RMSE['RMSE'])
plt.xlabel('Area')
plt.ylabel('RMSE')
plt.title('Bar Plot of RMSE by Area (Extent)')
plt.show()

# %%
df_bell3 = Bell_Amundsen_Extent[Bell_Amundsen_Extent['Date'].dt.month == 3]
df_indian3 = Indian_Extent[Indian_Extent['Date'].dt.month == 3]
df_pacific3 = Pacific_Extent[Pacific_Extent['Date'].dt.month == 3]
df_ross3 = Ross_Extent[Ross_Extent['Date'].dt.month == 3]
df_weddell3 = Weddell_Extent[Weddell_Extent['Date'].dt.month == 3]

# %%
plt.figure(figsize=(15,6))

plt.plot(df_bell3['Date'], df_bell3['Extent'], label='Bell_Amundsen')
plt.plot(df_indian3['Date'], df_indian3['Extent'], label='Indian')
plt.plot(df_pacific3['Date'], df_pacific3['Extent'], label='Pacific')
plt.plot(df_ross3['Date'], df_ross3['Extent'], label='Ross')
plt.plot(df_weddell3['Date'], df_weddell3['Extent'], label='Weddell')

plt.xlabel('Date')    
plt.ylabel('Extent')
plt.title('Extent Values of March')
plt.legend()

plt.show()
