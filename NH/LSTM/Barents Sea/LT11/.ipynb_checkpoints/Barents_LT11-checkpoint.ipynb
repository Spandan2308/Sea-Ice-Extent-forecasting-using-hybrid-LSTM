# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Barents = pd.read_excel(filepath, sheet_name='Barents-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Barents)
fp.date_time(Barents)
# Out:
#           Extent       Date
# 0    1107873.946 1979-01-01
# 1    1211101.473 1979-02-01
# 2    1215128.770 1979-03-01
# 3    1233940.811 1979-04-01
# 4    1193061.566 1979-05-01
# ..           ...        ...
# 533   124025.343 2023-06-01
# 534    53107.426 2023-07-01
# 535    11242.827 2023-08-01
# 536     3272.024 2023-09-01
# 537    35079.225 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Barents['Extent'] = scaler.fit_transform(Barents['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 11
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Barents['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((516, 12, 1), (516,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Barents_model_LT11/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1981 - root_mean_squared_error: 0.4451INFO:tensorflow:Assets written to: Barents_model_LT11\assets
# 53/53 [==============================] - 17s 204ms/step - loss: 0.1994 - root_mean_squared_error: 0.4465 - val_loss: 0.0648 - val_root_mean_squared_error: 0.2546
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1524 - root_mean_squared_error: 0.3904INFO:tensorflow:Assets written to: Barents_model_LT11\assets
# 53/53 [==============================] - 11s 204ms/step - loss: 0.1511 - root_mean_squared_error: 0.3887 - val_loss: 0.0379 - val_root_mean_squared_error: 0.1946
# Epoch 3/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0823 - root_mean_squared_error: 0.2869 - val_loss: 0.0460 - val_root_mean_squared_error: 0.2145
# Epoch 4/50
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0739 - root_mean_squared_error: 0.2718 - val_loss: 0.0462 - val_root_mean_squared_error: 0.2150
# Epoch 5/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0703 - root_mean_squared_error: 0.2651 - val_loss: 0.0547 - val_root_mean_squared_error: 0.2339
# Epoch 6/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0660 - root_mean_squared_error: 0.2570 - val_loss: 0.0563 - val_root_mean_squared_error: 0.2372
# Epoch 7/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0608 - root_mean_squared_error: 0.2466 - val_loss: 0.0573 - val_root_mean_squared_error: 0.2394
# Epoch 8/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0552 - root_mean_squared_error: 0.2350 - val_loss: 0.0684 - val_root_mean_squared_error: 0.2616
# Epoch 9/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0490 - root_mean_squared_error: 0.2213 - val_loss: 0.0587 - val_root_mean_squared_error: 0.2423
# Epoch 10/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0455 - root_mean_squared_error: 0.2132 - val_loss: 0.0767 - val_root_mean_squared_error: 0.2770
# Epoch 11/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0429 - root_mean_squared_error: 0.2071 - val_loss: 0.0608 - val_root_mean_squared_error: 0.2465
# Epoch 12/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0400 - root_mean_squared_error: 0.2001 - val_loss: 0.0728 - val_root_mean_squared_error: 0.2699
# Epoch 13/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0386 - root_mean_squared_error: 0.1966 - val_loss: 0.0459 - val_root_mean_squared_error: 0.2143
# Epoch 14/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0398 - root_mean_squared_error: 0.1994 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2032
# Epoch 15/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0391 - root_mean_squared_error: 0.1978INFO:tensorflow:Assets written to: Barents_model_LT11\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0391 - root_mean_squared_error: 0.1976 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1853
# Epoch 16/50
# 53/53 [==============================] - 1s 26ms/step - loss: 0.0349 - root_mean_squared_error: 0.1869 - val_loss: 0.0509 - val_root_mean_squared_error: 0.2256
# Epoch 17/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0348 - root_mean_squared_error: 0.1865 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2013
# Epoch 18/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0335 - root_mean_squared_error: 0.1830 - val_loss: 0.0452 - val_root_mean_squared_error: 0.2126
# Epoch 19/50
# 53/53 [==============================] - 1s 28ms/step - loss: 0.0322 - root_mean_squared_error: 0.1796 - val_loss: 0.0644 - val_root_mean_squared_error: 0.2538
# Epoch 20/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0372 - root_mean_squared_error: 0.1929 - val_loss: 0.0542 - val_root_mean_squared_error: 0.2329
# Epoch 21/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0326 - root_mean_squared_error: 0.1806 - val_loss: 0.0457 - val_root_mean_squared_error: 0.2138
# Epoch 22/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0319 - root_mean_squared_error: 0.1785 - val_loss: 0.0418 - val_root_mean_squared_error: 0.2045
# Epoch 23/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0322 - root_mean_squared_error: 0.1795 - val_loss: 0.0503 - val_root_mean_squared_error: 0.2242
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0292 - root_mean_squared_error: 0.1708INFO:tensorflow:Assets written to: Barents_model_LT11\assets
# 53/53 [==============================] - 10s 192ms/step - loss: 0.0292 - root_mean_squared_error: 0.1708 - val_loss: 0.0333 - val_root_mean_squared_error: 0.1825
# Epoch 25/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0314 - root_mean_squared_error: 0.1772 - val_loss: 0.0380 - val_root_mean_squared_error: 0.1950
# Epoch 26/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0288 - root_mean_squared_error: 0.1698 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2010
# Epoch 27/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0284 - root_mean_squared_error: 0.1686 - val_loss: 0.0419 - val_root_mean_squared_error: 0.2046
# Epoch 28/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0294 - root_mean_squared_error: 0.1716 - val_loss: 0.0373 - val_root_mean_squared_error: 0.1931
# Epoch 29/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0285 - root_mean_squared_error: 0.1687INFO:tensorflow:Assets written to: Barents_model_LT11\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0285 - root_mean_squared_error: 0.1687 - val_loss: 0.0296 - val_root_mean_squared_error: 0.1720
# Epoch 30/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0279 - root_mean_squared_error: 0.1671 - val_loss: 0.0343 - val_root_mean_squared_error: 0.1852
# Epoch 31/50
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0293 - root_mean_squared_error: 0.1711 - val_loss: 0.0363 - val_root_mean_squared_error: 0.1906
# Epoch 32/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0266 - root_mean_squared_error: 0.1630 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2037
# Epoch 33/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0256 - root_mean_squared_error: 0.1600INFO:tensorflow:Assets written to: Barents_model_LT11\assets
# 53/53 [==============================] - 10s 185ms/step - loss: 0.0258 - root_mean_squared_error: 0.1606 - val_loss: 0.0290 - val_root_mean_squared_error: 0.1703
# Epoch 34/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0283 - root_mean_squared_error: 0.1682INFO:tensorflow:Assets written to: Barents_model_LT11\assets
# 53/53 [==============================] - 10s 199ms/step - loss: 0.0283 - root_mean_squared_error: 0.1682 - val_loss: 0.0278 - val_root_mean_squared_error: 0.1667
# Epoch 35/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0270 - root_mean_squared_error: 0.1643 - val_loss: 0.0427 - val_root_mean_squared_error: 0.2067
# Epoch 36/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0266 - root_mean_squared_error: 0.1632 - val_loss: 0.0321 - val_root_mean_squared_error: 0.1792
# Epoch 37/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0263 - root_mean_squared_error: 0.1620 - val_loss: 0.0330 - val_root_mean_squared_error: 0.1816
# Epoch 38/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0266 - root_mean_squared_error: 0.1631 - val_loss: 0.0352 - val_root_mean_squared_error: 0.1876
# Epoch 39/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0274 - root_mean_squared_error: 0.1655 - val_loss: 0.0430 - val_root_mean_squared_error: 0.2073
# Epoch 40/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0265 - root_mean_squared_error: 0.1627 - val_loss: 0.0343 - val_root_mean_squared_error: 0.1852
# Epoch 41/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0259 - root_mean_squared_error: 0.1610 - val_loss: 0.0316 - val_root_mean_squared_error: 0.1776
# Epoch 42/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0252 - root_mean_squared_error: 0.1586 - val_loss: 0.0293 - val_root_mean_squared_error: 0.1711
# Epoch 43/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0253 - root_mean_squared_error: 0.1591 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1841
# Epoch 44/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0267 - root_mean_squared_error: 0.1634 - val_loss: 0.0312 - val_root_mean_squared_error: 0.1766
# Epoch 45/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0272 - root_mean_squared_error: 0.1650 - val_loss: 0.0361 - val_root_mean_squared_error: 0.1900
# Epoch 46/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0257 - root_mean_squared_error: 0.1602 - val_loss: 0.0329 - val_root_mean_squared_error: 0.1815
# Epoch 47/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0266 - root_mean_squared_error: 0.1632 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2026
# Epoch 48/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0233 - root_mean_squared_error: 0.1528 - val_loss: 0.0284 - val_root_mean_squared_error: 0.1685
# Epoch 49/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0233 - root_mean_squared_error: 0.1527 - val_loss: 0.0319 - val_root_mean_squared_error: 0.1786
# Epoch 50/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0237 - root_mean_squared_error: 0.1541 - val_loss: 0.0400 - val_root_mean_squared_error: 0.2001

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 2.37498304049174 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Barents_model_LT11/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 16ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.16467368950026767
# MAE : 0.14548909701398463

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       585013.875000     701143.910
# 1       529295.437500     657891.340
# 2       531945.125000     432215.421
# 3       503221.687500     201834.787
# 4       427556.062500      55041.511
# 5       316530.218750       5387.468
# 6       210433.843750       1576.813
# 7       171679.953125      21681.895
# 8       264418.500000      37772.681
# 9       405373.312500     239568.531
# 10      499943.000000     427703.330
# 11      539138.875000     753043.012
# 12      574657.062500     764554.603
# 13      555835.937500     563799.961
# 14      523324.531250     444109.886
# 15      446772.500000     189669.492
# 16      321999.687500      63664.521
# 17      188911.109375       5984.539
# 18      139632.125000       1192.062
# 19      201284.812500      25987.740
# 20      283705.468750     227374.130
# 21      377229.812500     498316.637
# 22      483712.625000     666292.874
# 23      566567.125000     673348.837
# 24      571646.562500     635756.948
# 25      542070.375000     673503.693
# 26      537530.250000     550922.786
# 27      495207.343750     116554.569
# 28      407737.031250      12012.356
# 29      288635.593750       5446.433
# 30      181261.562500       2183.701
# 31      181895.171875      31883.576
# 32      305300.125000      98802.296
# 33      466059.031250     224779.107
# 34      532239.750000     287476.263
# 35      556345.375000     376683.928
# 36      613506.812500     571055.966
# 37      556804.000000     581039.946
# 38      531386.312500     376525.530
# 39      444267.343750     124025.343
# 40      310968.562500      53107.426
# 41      170784.375000      11242.827
# 42      150019.828125       3272.024
# 43      229902.796875      35079.225

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 12ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
