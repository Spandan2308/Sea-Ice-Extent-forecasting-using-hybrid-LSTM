# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Barents = pd.read_excel(filepath, sheet_name='Barents-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Barents)
fp.date_time(Barents)
# Out:
#           Extent       Date
# 0    1107873.946 1979-01-01
# 1    1211101.473 1979-02-01
# 2    1215128.770 1979-03-01
# 3    1233940.811 1979-04-01
# 4    1193061.566 1979-05-01
# ..           ...        ...
# 533   124025.343 2023-06-01
# 534    53107.426 2023-07-01
# 535    11242.827 2023-08-01
# 536     3272.024 2023-09-01
# 537    35079.225 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Barents['Extent'] = scaler.fit_transform(Barents['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 10
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Barents['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((517, 12, 1), (517,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Barents_model_LT10/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.1882 - root_mean_squared_error: 0.4338INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 27s 331ms/step - loss: 0.1897 - root_mean_squared_error: 0.4356 - val_loss: 0.0536 - val_root_mean_squared_error: 0.2315
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1177 - root_mean_squared_error: 0.3431INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 15s 280ms/step - loss: 0.1177 - root_mean_squared_error: 0.3431 - val_loss: 0.0445 - val_root_mean_squared_error: 0.2110
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0829 - root_mean_squared_error: 0.2880INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 14s 275ms/step - loss: 0.0829 - root_mean_squared_error: 0.2880 - val_loss: 0.0407 - val_root_mean_squared_error: 0.2017
# Epoch 4/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0770 - root_mean_squared_error: 0.2775 - val_loss: 0.0433 - val_root_mean_squared_error: 0.2080
# Epoch 5/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0693 - root_mean_squared_error: 0.2632 - val_loss: 0.0452 - val_root_mean_squared_error: 0.2126
# Epoch 6/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0646 - root_mean_squared_error: 0.2542 - val_loss: 0.0519 - val_root_mean_squared_error: 0.2279
# Epoch 7/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0569 - root_mean_squared_error: 0.2386 - val_loss: 0.0522 - val_root_mean_squared_error: 0.2284
# Epoch 8/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0518 - root_mean_squared_error: 0.2275 - val_loss: 0.0632 - val_root_mean_squared_error: 0.2513
# Epoch 9/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0468 - root_mean_squared_error: 0.2164 - val_loss: 0.0645 - val_root_mean_squared_error: 0.2539
# Epoch 10/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0446 - root_mean_squared_error: 0.2111 - val_loss: 0.0763 - val_root_mean_squared_error: 0.2762
# Epoch 11/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0404 - root_mean_squared_error: 0.2010 - val_loss: 0.0775 - val_root_mean_squared_error: 0.2785
# Epoch 12/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0365 - root_mean_squared_error: 0.1911 - val_loss: 0.0930 - val_root_mean_squared_error: 0.3049
# Epoch 13/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0342 - root_mean_squared_error: 0.1850 - val_loss: 0.0538 - val_root_mean_squared_error: 0.2320
# Epoch 14/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0326 - root_mean_squared_error: 0.1805 - val_loss: 0.0419 - val_root_mean_squared_error: 0.2046
# Epoch 15/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0305 - root_mean_squared_error: 0.1746 - val_loss: 0.0476 - val_root_mean_squared_error: 0.2181
# Epoch 16/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0298 - root_mean_squared_error: 0.1726 - val_loss: 0.0462 - val_root_mean_squared_error: 0.2150
# Epoch 17/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0263 - root_mean_squared_error: 0.1623 - val_loss: 0.0547 - val_root_mean_squared_error: 0.2338
# Epoch 18/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0255 - root_mean_squared_error: 0.1596INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 15s 285ms/step - loss: 0.0256 - root_mean_squared_error: 0.1600 - val_loss: 0.0321 - val_root_mean_squared_error: 0.1791
# Epoch 19/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0233 - root_mean_squared_error: 0.1527INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 17s 318ms/step - loss: 0.0233 - root_mean_squared_error: 0.1527 - val_loss: 0.0302 - val_root_mean_squared_error: 0.1739
# Epoch 20/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0259 - root_mean_squared_error: 0.1609INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 15s 295ms/step - loss: 0.0258 - root_mean_squared_error: 0.1607 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1513
# Epoch 21/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0242 - root_mean_squared_error: 0.1555 - val_loss: 0.0282 - val_root_mean_squared_error: 0.1680
# Epoch 22/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0227 - root_mean_squared_error: 0.1507 - val_loss: 0.0299 - val_root_mean_squared_error: 0.1728
# Epoch 23/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0234 - root_mean_squared_error: 0.1528INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 13s 246ms/step - loss: 0.0232 - root_mean_squared_error: 0.1522 - val_loss: 0.0228 - val_root_mean_squared_error: 0.1509
# Epoch 24/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0245 - root_mean_squared_error: 0.1565 - val_loss: 0.0259 - val_root_mean_squared_error: 0.1610
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0212 - root_mean_squared_error: 0.1457INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 10s 200ms/step - loss: 0.0212 - root_mean_squared_error: 0.1457 - val_loss: 0.0220 - val_root_mean_squared_error: 0.1484
# Epoch 26/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0214 - root_mean_squared_error: 0.1462 - val_loss: 0.0303 - val_root_mean_squared_error: 0.1741
# Epoch 27/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0229 - root_mean_squared_error: 0.1512 - val_loss: 0.0275 - val_root_mean_squared_error: 0.1657
# Epoch 28/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0210 - root_mean_squared_error: 0.1449INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 10s 191ms/step - loss: 0.0210 - root_mean_squared_error: 0.1450 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1302
# Epoch 29/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0204 - root_mean_squared_error: 0.1428 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1582
# Epoch 30/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0230 - root_mean_squared_error: 0.1516 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1341
# Epoch 31/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0206 - root_mean_squared_error: 0.1437 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1414
# Epoch 32/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0213 - root_mean_squared_error: 0.1459 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1694
# Epoch 33/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0211 - root_mean_squared_error: 0.1452 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1387
# Epoch 34/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0199 - root_mean_squared_error: 0.1410INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 10s 186ms/step - loss: 0.0198 - root_mean_squared_error: 0.1407 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1211
# Epoch 35/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0182 - root_mean_squared_error: 0.1349 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1413
# Epoch 36/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0186 - root_mean_squared_error: 0.1365 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1476
# Epoch 37/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0188 - root_mean_squared_error: 0.1369 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1327
# Epoch 38/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0194 - root_mean_squared_error: 0.1393 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1302
# Epoch 39/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0181 - root_mean_squared_error: 0.1346 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1276
# Epoch 40/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0179 - root_mean_squared_error: 0.1337 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1303
# Epoch 41/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0170 - root_mean_squared_error: 0.1302INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 10s 194ms/step - loss: 0.0170 - root_mean_squared_error: 0.1302 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1155
# Epoch 42/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0178 - root_mean_squared_error: 0.1336 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1270
# Epoch 43/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0179 - root_mean_squared_error: 0.1337 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1335
# Epoch 44/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0182 - root_mean_squared_error: 0.1350INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 10s 195ms/step - loss: 0.0181 - root_mean_squared_error: 0.1345 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1141
# Epoch 45/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0180 - root_mean_squared_error: 0.1343 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1429
# Epoch 46/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0163 - root_mean_squared_error: 0.1278 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1552
# Epoch 47/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0180 - root_mean_squared_error: 0.1343 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1222
# Epoch 48/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0187 - root_mean_squared_error: 0.1367 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1221
# Epoch 49/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0172 - root_mean_squared_error: 0.1312INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 10s 189ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1097
# Epoch 50/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0167 - root_mean_squared_error: 0.1293 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1187

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 3.9547864238421124 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Barents_model_LT10/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 18ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.1181844266128079
# MAE : 0.09834048298529038

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       553166.750000     654073.790
# 1       632135.625000     701143.910
# 2       648542.187500     657891.340
# 3       576720.062500     432215.421
# 4       448947.531250     201834.787
# 5       298852.281250      55041.511
# 6       161797.906250       5387.468
# 7        92264.500000       1576.813
# 8       110831.820312      21681.895
# 9       220404.500000      37772.681
# 10      368351.656250     239568.531
# 11      520659.906250     427703.330
# 12      636993.562500     753043.012
# 13      689789.000000     764554.603
# 14      654065.375000     563799.961
# 15      526350.500000     444109.886
# 16      353226.343750     189669.492
# 17      177982.890625      63664.521
# 18       55798.710938       5984.539
# 19       20818.496094       1192.062
# 20       52007.574219      25987.740
# 21      135895.000000     227374.130
# 22      275974.593750     498316.637
# 23      449036.625000     666292.874
# 24      576489.125000     673348.837
# 25      655658.312500     635756.948
# 26      654728.437500     673503.693
# 27      566199.812500     550922.786
# 28      419706.093750     116554.569
# 29      261172.312500      12012.356
# 30      125153.429688       5446.433
# 31       58738.492188       2183.701
# 32      106792.187500      31883.576
# 33      238360.109375      98802.296
# 34      401143.812500     224779.107
# 35      548566.625000     287476.263
# 36      665298.125000     376683.928
# 37      721768.750000     571055.966
# 38      686888.812500     581039.946
# 39      543946.687500     376525.530
# 40      352934.718750     124025.343
# 41      164514.468750      53107.426
# 42       36181.312500      11242.827
# 43       11808.323242       3272.024
# 44       49646.296875      35079.225

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 15ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
