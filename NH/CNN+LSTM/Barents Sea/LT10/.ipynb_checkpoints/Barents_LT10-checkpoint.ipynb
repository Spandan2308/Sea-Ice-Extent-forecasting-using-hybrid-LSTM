# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Barents = pd.read_excel(filepath, sheet_name='Barents-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Barents)
fp.date_time(Barents)
# Out:
#           Extent       Date
# 0    1107873.946 1979-01-01
# 1    1211101.473 1979-02-01
# 2    1215128.770 1979-03-01
# 3    1233940.811 1979-04-01
# 4    1193061.566 1979-05-01
# ..           ...        ...
# 533   124025.343 2023-06-01
# 534    53107.426 2023-07-01
# 535    11242.827 2023-08-01
# 536     3272.024 2023-09-01
# 537    35079.225 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Barents['Extent'] = scaler.fit_transform(Barents['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 10
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]  # Adjusted for lead time
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Barents['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((517, 12, 1), (517,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Barents_model_LT10/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1485 - root_mean_squared_error: 0.3854
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 8s 104ms/step - loss: 0.1485 - root_mean_squared_error: 0.3854 - val_loss: 0.0540 - val_root_mean_squared_error: 0.2324
# Epoch 2/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.1164 - root_mean_squared_error: 0.3412
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 4s 67ms/step - loss: 0.1180 - root_mean_squared_error: 0.3435 - val_loss: 0.0426 - val_root_mean_squared_error: 0.2064
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0901 - root_mean_squared_error: 0.3001
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0907 - root_mean_squared_error: 0.3012 - val_loss: 0.0347 - val_root_mean_squared_error: 0.1862
# Epoch 4/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0706 - root_mean_squared_error: 0.2656
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0710 - root_mean_squared_error: 0.2665 - val_loss: 0.0294 - val_root_mean_squared_error: 0.1714
# Epoch 5/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0559 - root_mean_squared_error: 0.2365
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0547 - root_mean_squared_error: 0.2338 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1622
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0429 - root_mean_squared_error: 0.2072
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0429 - root_mean_squared_error: 0.2072 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1566
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0326 - root_mean_squared_error: 0.1804
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 4s 78ms/step - loss: 0.0325 - root_mean_squared_error: 0.1804 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1525
# Epoch 8/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0296 - root_mean_squared_error: 0.1721
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0296 - root_mean_squared_error: 0.1721 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1522
# Epoch 9/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0228 - root_mean_squared_error: 0.1510
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 6s 106ms/step - loss: 0.0225 - root_mean_squared_error: 0.1500 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1470
# Epoch 10/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0239 - root_mean_squared_error: 0.1547
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0228 - root_mean_squared_error: 0.1511 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1439
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0181 - root_mean_squared_error: 0.1344
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0181 - root_mean_squared_error: 0.1344 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1240
# Epoch 12/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0183 - root_mean_squared_error: 0.1354 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1251
# Epoch 13/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0158 - root_mean_squared_error: 0.1258
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0172 - root_mean_squared_error: 0.1311 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1198
# Epoch 14/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0166 - root_mean_squared_error: 0.1287 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1210
# Epoch 15/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0174 - root_mean_squared_error: 0.1319
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 5s 97ms/step - loss: 0.0173 - root_mean_squared_error: 0.1314 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0919
# Epoch 16/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0189 - root_mean_squared_error: 0.1375 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0949
# Epoch 17/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0195 - root_mean_squared_error: 0.1397
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# INFO:tensorflow:Assets written to: Barents_model_LT10\assets
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0199 - root_mean_squared_error: 0.1409 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0896
# Epoch 18/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0162 - root_mean_squared_error: 0.1273 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0960
# Epoch 19/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0164 - root_mean_squared_error: 0.1282 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0956
# Epoch 20/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0183 - root_mean_squared_error: 0.1354 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0923
# Epoch 21/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0216 - root_mean_squared_error: 0.1471 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1009
# Epoch 22/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0181 - root_mean_squared_error: 0.1345 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0999
# Epoch 23/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0156 - root_mean_squared_error: 0.1247 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0918
# Epoch 24/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0155 - root_mean_squared_error: 0.1246 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0952
# Epoch 25/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0172 - root_mean_squared_error: 0.1310 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0975
# Epoch 26/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0138 - root_mean_squared_error: 0.1177 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0959
# Epoch 27/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0191 - root_mean_squared_error: 0.1381 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0990
# Epoch 28/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0955
# Epoch 29/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0170 - root_mean_squared_error: 0.1303 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1226
# Epoch 30/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0185 - root_mean_squared_error: 0.1359 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1032
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0170 - root_mean_squared_error: 0.1305 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0964
# Epoch 32/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0192 - root_mean_squared_error: 0.1387 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0909
# Epoch 33/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0186 - root_mean_squared_error: 0.1364 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1058
# Epoch 34/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0168 - root_mean_squared_error: 0.1297 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0917
# Epoch 35/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0165 - root_mean_squared_error: 0.1284 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0956
# Epoch 36/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0157 - root_mean_squared_error: 0.1253 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0901
# Epoch 37/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0154 - root_mean_squared_error: 0.1242 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1222
# Epoch 38/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0170 - root_mean_squared_error: 0.1304 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1038
# Epoch 39/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0919
# Epoch 40/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0919
# Epoch 41/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0185 - root_mean_squared_error: 0.1360 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0917
# Epoch 42/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0170 - root_mean_squared_error: 0.1305 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0977
# Epoch 43/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0175 - root_mean_squared_error: 0.1322 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0910
# Epoch 44/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0901
# Epoch 45/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0177 - root_mean_squared_error: 0.1329 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0930
# Epoch 46/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0186 - root_mean_squared_error: 0.1362 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0930
# Epoch 47/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0153 - root_mean_squared_error: 0.1236 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0942
# Epoch 48/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0154 - root_mean_squared_error: 0.1241 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1152
# Epoch 49/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0169 - root_mean_squared_error: 0.1299 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0925
# Epoch 50/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0153 - root_mean_squared_error: 0.1238 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0927

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.3086688955624899 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %% [markdown]
# Test Predictions

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Barents_model_LT10/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.09269908350286833
# MAE : 0.06992638872127009

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       603865.875000     654073.790
# 1       624477.875000     701143.910
# 2       576682.250000     657891.340
# 3       471598.218750     432215.421
# 4       283268.812500     201834.787
# 5       157253.015625      55041.511
# 6        33438.070312       5387.468
# 7        61385.511719       1576.813
# 8        82214.250000      21681.895
# 9       301851.562500      37772.681
# 10      415314.687500     239568.531
# 11      557297.875000     427703.330
# 12      633532.000000     753043.012
# 13      662008.687500     764554.603
# 14      577708.625000     563799.961
# 15      405063.062500     444109.886
# 16      222095.390625     189669.492
# 17       66626.468750      63664.521
# 18      -20835.162109       5984.539
# 19      -66872.820312       1192.062
# 20        9068.088867      25987.740
# 21      118531.507812     227374.130
# 22      397199.656250     498316.637
# 23      499808.375000     666292.874
# 24      642816.375000     673348.837
# 25      630329.937500     635756.948
# 26      585593.250000     673503.693
# 27      412270.000000     550922.786
# 28      236744.390625     116554.569
# 29      116011.250000      12012.356
# 30         -42.227684       5446.433
# 31       35004.777344       2183.701
# 32      113866.289062      31883.576
# 33      320039.843750      98802.296
# 34      453233.468750     224779.107
# 35      576382.562500     287476.263
# 36      653366.375000     376683.928
# 37      664637.000000     571055.966
# 38      635182.812500     581039.946
# 39      367030.781250     376525.530
# 40      224510.984375     124025.343
# 41       53020.886719      53107.426
# 42        7436.886719      11242.827
# 43      -34339.121094       3272.024
# 44       45090.789062      35079.225

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
