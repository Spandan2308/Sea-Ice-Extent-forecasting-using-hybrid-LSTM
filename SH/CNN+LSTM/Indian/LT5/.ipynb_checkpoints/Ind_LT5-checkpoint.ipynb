# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Indian_Extent = pd.read_excel(filepath, sheet_name='Indian-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Indian_Extent)
fp.date_time(Indian_Extent)
# Out:
#           Extent       Date
# 0     376618.799 1979-01-01
# 1     211788.726 1979-02-01
# 2     262868.141 1979-03-01
# 3     698377.304 1979-04-01
# 4    1252407.727 1979-05-01
# ..           ...        ...
# 533  1520776.003 2023-06-01
# 534  2076164.165 2023-07-01
# 535  2731799.027 2023-08-01
# 536  3179384.692 2023-09-01
# 537  3301335.210 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Indian_Extent['Extent'] = scaler.fit_transform(Indian_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 5
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Indian_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((522, 12, 1), (522,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Indian_model_LT5/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.2146 - root_mean_squared_error: 0.4633
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 8s 98ms/step - loss: 0.2168 - root_mean_squared_error: 0.4657 - val_loss: 0.1902 - val_root_mean_squared_error: 0.4361
# Epoch 2/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1621 - root_mean_squared_error: 0.4026
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.1621 - root_mean_squared_error: 0.4026 - val_loss: 0.1710 - val_root_mean_squared_error: 0.4135
# Epoch 3/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.1353 - root_mean_squared_error: 0.3679
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.1320 - root_mean_squared_error: 0.3633 - val_loss: 0.1512 - val_root_mean_squared_error: 0.3888
# Epoch 4/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.1086 - root_mean_squared_error: 0.3295
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 5s 88ms/step - loss: 0.1099 - root_mean_squared_error: 0.3315 - val_loss: 0.1318 - val_root_mean_squared_error: 0.3630
# Epoch 5/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0940 - root_mean_squared_error: 0.3066
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0903 - root_mean_squared_error: 0.3005 - val_loss: 0.1132 - val_root_mean_squared_error: 0.3364
# Epoch 6/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0748 - root_mean_squared_error: 0.2735
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0717 - root_mean_squared_error: 0.2677 - val_loss: 0.0964 - val_root_mean_squared_error: 0.3105
# Epoch 7/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0544 - root_mean_squared_error: 0.2332
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0546 - root_mean_squared_error: 0.2337 - val_loss: 0.0801 - val_root_mean_squared_error: 0.2831
# Epoch 8/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0408 - root_mean_squared_error: 0.2020
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.0416 - root_mean_squared_error: 0.2039 - val_loss: 0.0624 - val_root_mean_squared_error: 0.2499
# Epoch 9/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0347 - root_mean_squared_error: 0.1862
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0339 - root_mean_squared_error: 0.1841 - val_loss: 0.0481 - val_root_mean_squared_error: 0.2192
# Epoch 10/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0270 - root_mean_squared_error: 0.1642
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0268 - root_mean_squared_error: 0.1638 - val_loss: 0.0381 - val_root_mean_squared_error: 0.1952
# Epoch 11/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0243 - root_mean_squared_error: 0.1559
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0239 - root_mean_squared_error: 0.1544 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1565
# Epoch 12/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0243 - root_mean_squared_error: 0.1560
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0239 - root_mean_squared_error: 0.1546 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1298
# Epoch 13/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0224 - root_mean_squared_error: 0.1497
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0209 - root_mean_squared_error: 0.1447 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0985
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0176 - root_mean_squared_error: 0.1325
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0176 - root_mean_squared_error: 0.1325 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0788
# Epoch 15/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0161 - root_mean_squared_error: 0.1269
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0160 - root_mean_squared_error: 0.1264 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0774
# Epoch 16/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0152 - root_mean_squared_error: 0.1233
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0151 - root_mean_squared_error: 0.1231 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0618
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0203 - root_mean_squared_error: 0.1424 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0630
# Epoch 18/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0160 - root_mean_squared_error: 0.1263
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0155 - root_mean_squared_error: 0.1244 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0559
# Epoch 19/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0152 - root_mean_squared_error: 0.1233 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0620
# Epoch 20/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0136 - root_mean_squared_error: 0.1167
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0138 - root_mean_squared_error: 0.1173 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0542
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0180 - root_mean_squared_error: 0.1340 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0549
# Epoch 22/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0149 - root_mean_squared_error: 0.1220
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 4s 78ms/step - loss: 0.0145 - root_mean_squared_error: 0.1204 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0526
# Epoch 23/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0104 - root_mean_squared_error: 0.1019 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0650
# Epoch 24/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0154 - root_mean_squared_error: 0.1241 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0594
# Epoch 25/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0154 - root_mean_squared_error: 0.1240 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0573
# Epoch 26/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0174 - root_mean_squared_error: 0.1320
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0178 - root_mean_squared_error: 0.1333 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0526
# Epoch 27/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0119 - root_mean_squared_error: 0.1090 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0656
# Epoch 28/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0183 - root_mean_squared_error: 0.1353 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0658
# Epoch 29/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0551
# Epoch 30/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0181 - root_mean_squared_error: 0.1347 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0705
# Epoch 31/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0156 - root_mean_squared_error: 0.1250
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0156 - root_mean_squared_error: 0.1250 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0517
# Epoch 32/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0139 - root_mean_squared_error: 0.1178 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0533
# Epoch 33/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0177 - root_mean_squared_error: 0.1329
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0178 - root_mean_squared_error: 0.1333 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0490
# Epoch 34/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0169 - root_mean_squared_error: 0.1299 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0776
# Epoch 35/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0168 - root_mean_squared_error: 0.1297 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0768
# Epoch 36/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0172 - root_mean_squared_error: 0.1311 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0778
# Epoch 37/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0171 - root_mean_squared_error: 0.1307 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0573
# Epoch 38/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0175 - root_mean_squared_error: 0.1323 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0674
# Epoch 39/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0155 - root_mean_squared_error: 0.1245 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0686
# Epoch 40/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0615
# Epoch 41/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0583
# Epoch 42/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0160 - root_mean_squared_error: 0.1264 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0634
# Epoch 43/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0156 - root_mean_squared_error: 0.1247 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0592
# Epoch 44/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0109 - root_mean_squared_error: 0.1044 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0617
# Epoch 45/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0543
# Epoch 46/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0104 - root_mean_squared_error: 0.1021 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0682
# Epoch 47/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0158 - root_mean_squared_error: 0.1255 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0895
# Epoch 48/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0175 - root_mean_squared_error: 0.1323 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0745
# Epoch 49/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0155 - root_mean_squared_error: 0.1243 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0573
# Epoch 50/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0131 - root_mean_squared_error: 0.1144 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0535

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.9024385452270507 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Indian_model_LT5/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 20ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.07924458666673886
# MAE : 0.06792057714056578

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        3.531902e+06    3719188.531
# 1        3.536750e+06    3636501.241
# 2        3.008578e+06    2526913.818
# 3        1.583210e+06    1128752.378
# 4        5.705471e+05     522831.371
# 5       -2.587504e+05     346601.304
# 6        1.309505e+05     444914.605
# 7        4.305637e+05     827036.916
# 8        1.132328e+06    1142021.216
# 9        1.635378e+06    1885693.654
# 10       2.314049e+06    2542569.663
# 11       2.759998e+06    3107373.845
# 12       3.256941e+06    3488175.444
# 13       3.136758e+06    3746306.528
# 14       2.463668e+06    2942322.822
# 15       1.232414e+06    1507212.955
# 16       1.967769e+05     648507.437
# 17       2.120629e+04     352564.010
# 18       3.767586e+03     453587.503
# 19       6.091129e+05     841043.793
# 20       1.065295e+06    1433155.266
# 21       1.749732e+06    2163687.646
# 22       2.284929e+06    2848863.133
# 23       2.880324e+06    3420877.229
# 24       3.315434e+06    3752886.938
# 25       3.227239e+06    3778951.818
# 26       2.596156e+06    2892177.223
# 27       1.167412e+06    1467610.428
# 28       3.104617e+05     377930.941
# 29       1.054984e+05     146440.376
# 30       2.902821e+05     244356.473
# 31       6.969331e+05     612217.566
# 32       1.219367e+06    1261627.075
# 33       1.933040e+06    1720565.225
# 34       2.689162e+06    2564005.541
# 35       3.404472e+06    2983773.529
# 36       3.759397e+06    3372645.223
# 37       3.852939e+06    3589687.043
# 38       3.039992e+06    2669385.189
# 39       1.547183e+06    1095398.946
# 40       4.695708e+05     319828.826
# 41       1.685266e+05     162541.182
# 42       1.021879e+05     179564.232
# 43       6.437096e+05     593196.107
# 44       1.133492e+06    1053508.835
# 45       1.735640e+06    1520776.003
# 46       2.471962e+06    2076164.165
# 47       3.003730e+06    2731799.027
# 48       3.458270e+06    3179384.692
# 49       3.498278e+06    3301335.210

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
