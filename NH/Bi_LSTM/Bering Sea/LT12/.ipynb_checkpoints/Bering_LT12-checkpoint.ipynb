# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bering = pd.read_excel(filepath, sheet_name='Bering-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Bering)
fp.date_time(Bering)
# Out:
#          Extent       Date
# 0    320266.650 1979-01-01
# 1    541778.338 1979-02-01
# 2    638262.988 1979-03-01
# 3    423025.159 1979-04-01
# 4    215587.216 1979-05-01
# ..          ...        ...
# 488  317377.493 2023-05-01
# 489   39601.476 2023-06-01
# 490   16935.702 2023-07-01
# 491    1305.744 2023-09-01
# 492   12255.644 2023-10-01
#
# [493 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bering['Extent'] = scaler.fit_transform(Bering['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 12
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bering['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((470, 12, 1), (470,))

# %%
X_train, y_train = X[:390], y[:390]
X_val, y_val = X[390:440], y[390:440]
X_test, y_test = X[440:], y[440:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Bering_model_LT12/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 49/49 [==============================] - ETA: 0s - loss: 0.1567 - root_mean_squared_error: 0.3958INFO:tensorflow:Assets written to: Bering_model_LT12\assets
# 49/49 [==============================] - 35s 489ms/step - loss: 0.1567 - root_mean_squared_error: 0.3958 - val_loss: 0.0421 - val_root_mean_squared_error: 0.2052
# Epoch 2/50
# 49/49 [==============================] - 1s 25ms/step - loss: 0.0906 - root_mean_squared_error: 0.3010 - val_loss: 0.0528 - val_root_mean_squared_error: 0.2298
# Epoch 3/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0728 - root_mean_squared_error: 0.2698 - val_loss: 0.0444 - val_root_mean_squared_error: 0.2108
# Epoch 4/50
# 48/49 [============================>.] - ETA: 0s - loss: 0.0511 - root_mean_squared_error: 0.2260INFO:tensorflow:Assets written to: Bering_model_LT12\assets
# 49/49 [==============================] - 23s 482ms/step - loss: 0.0510 - root_mean_squared_error: 0.2258 - val_loss: 0.0354 - val_root_mean_squared_error: 0.1882
# Epoch 5/50
# 49/49 [==============================] - ETA: 0s - loss: 0.0350 - root_mean_squared_error: 0.1871INFO:tensorflow:Assets written to: Bering_model_LT12\assets
# 49/49 [==============================] - 38s 792ms/step - loss: 0.0350 - root_mean_squared_error: 0.1871 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1498
# Epoch 6/50
# 49/49 [==============================] - ETA: 0s - loss: 0.0244 - root_mean_squared_error: 0.1564INFO:tensorflow:Assets written to: Bering_model_LT12\assets
# 49/49 [==============================] - 35s 733ms/step - loss: 0.0244 - root_mean_squared_error: 0.1564 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1434
# Epoch 7/50
# 49/49 [==============================] - 1s 28ms/step - loss: 0.0203 - root_mean_squared_error: 0.1423 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1507
# Epoch 8/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0176 - root_mean_squared_error: 0.1326 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1473
# Epoch 9/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0195 - root_mean_squared_error: 0.1395 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1488
# Epoch 10/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0184 - root_mean_squared_error: 0.1356 - val_loss: 0.0332 - val_root_mean_squared_error: 0.1823
# Epoch 11/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.0164 - root_mean_squared_error: 0.1281 - val_loss: 0.0273 - val_root_mean_squared_error: 0.1652
# Epoch 12/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211 - val_loss: 0.0280 - val_root_mean_squared_error: 0.1675
# Epoch 13/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0148 - root_mean_squared_error: 0.1216 - val_loss: 0.0316 - val_root_mean_squared_error: 0.1776
# Epoch 14/50
# 49/49 [==============================] - 2s 35ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248 - val_loss: 0.0309 - val_root_mean_squared_error: 0.1757
# Epoch 15/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1604
# Epoch 16/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0128 - root_mean_squared_error: 0.1132 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1594
# Epoch 17/50
# 49/49 [==============================] - 2s 34ms/step - loss: 0.0147 - root_mean_squared_error: 0.1214 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1839
# Epoch 18/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0124 - root_mean_squared_error: 0.1116 - val_loss: 0.0327 - val_root_mean_squared_error: 0.1808
# Epoch 19/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0132 - root_mean_squared_error: 0.1148 - val_loss: 0.0356 - val_root_mean_squared_error: 0.1887
# Epoch 20/50
# 49/49 [==============================] - 2s 31ms/step - loss: 0.0126 - root_mean_squared_error: 0.1122 - val_loss: 0.0312 - val_root_mean_squared_error: 0.1767
# Epoch 21/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0126 - root_mean_squared_error: 0.1121 - val_loss: 0.0323 - val_root_mean_squared_error: 0.1796
# Epoch 22/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0128 - root_mean_squared_error: 0.1130 - val_loss: 0.0369 - val_root_mean_squared_error: 0.1921
# Epoch 23/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0381 - val_root_mean_squared_error: 0.1953
# Epoch 24/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0118 - root_mean_squared_error: 0.1085 - val_loss: 0.0322 - val_root_mean_squared_error: 0.1795
# Epoch 25/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0117 - root_mean_squared_error: 0.1080 - val_loss: 0.0424 - val_root_mean_squared_error: 0.2058
# Epoch 26/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0113 - root_mean_squared_error: 0.1062 - val_loss: 0.0480 - val_root_mean_squared_error: 0.2191
# Epoch 27/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069 - val_loss: 0.0324 - val_root_mean_squared_error: 0.1800
# Epoch 28/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0109 - root_mean_squared_error: 0.1045 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2122
# Epoch 29/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0112 - root_mean_squared_error: 0.1057 - val_loss: 0.0514 - val_root_mean_squared_error: 0.2266
# Epoch 30/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0114 - root_mean_squared_error: 0.1068 - val_loss: 0.0433 - val_root_mean_squared_error: 0.2081
# Epoch 31/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0115 - root_mean_squared_error: 0.1073 - val_loss: 0.0428 - val_root_mean_squared_error: 0.2069
# Epoch 32/50
# 49/49 [==============================] - 2s 31ms/step - loss: 0.0111 - root_mean_squared_error: 0.1056 - val_loss: 0.0472 - val_root_mean_squared_error: 0.2173
# Epoch 33/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0107 - root_mean_squared_error: 0.1036 - val_loss: 0.0396 - val_root_mean_squared_error: 0.1991
# Epoch 34/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0108 - root_mean_squared_error: 0.1041 - val_loss: 0.0433 - val_root_mean_squared_error: 0.2080
# Epoch 35/50
# 49/49 [==============================] - 2s 31ms/step - loss: 0.0110 - root_mean_squared_error: 0.1049 - val_loss: 0.0437 - val_root_mean_squared_error: 0.2090
# Epoch 36/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0105 - root_mean_squared_error: 0.1025 - val_loss: 0.0535 - val_root_mean_squared_error: 0.2314
# Epoch 37/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0099 - root_mean_squared_error: 0.0996 - val_loss: 0.0439 - val_root_mean_squared_error: 0.2095
# Epoch 38/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0109 - root_mean_squared_error: 0.1046 - val_loss: 0.0422 - val_root_mean_squared_error: 0.2054
# Epoch 39/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0108 - root_mean_squared_error: 0.1041 - val_loss: 0.0496 - val_root_mean_squared_error: 0.2227
# Epoch 40/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0365 - val_root_mean_squared_error: 0.1912
# Epoch 41/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0104 - root_mean_squared_error: 0.1021 - val_loss: 0.0345 - val_root_mean_squared_error: 0.1858
# Epoch 42/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069 - val_loss: 0.0434 - val_root_mean_squared_error: 0.2084
# Epoch 43/50
# 49/49 [==============================] - 2s 31ms/step - loss: 0.0097 - root_mean_squared_error: 0.0984 - val_loss: 0.0505 - val_root_mean_squared_error: 0.2247
# Epoch 44/50
# 49/49 [==============================] - 1s 30ms/step - loss: 0.0102 - root_mean_squared_error: 0.1012 - val_loss: 0.0487 - val_root_mean_squared_error: 0.2208
# Epoch 45/50
# 49/49 [==============================] - 2s 33ms/step - loss: 0.0100 - root_mean_squared_error: 0.1002 - val_loss: 0.0332 - val_root_mean_squared_error: 0.1821
# Epoch 46/50
# 49/49 [==============================] - 2s 31ms/step - loss: 0.0104 - root_mean_squared_error: 0.1020 - val_loss: 0.0460 - val_root_mean_squared_error: 0.2144
# Epoch 47/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0104 - root_mean_squared_error: 0.1022 - val_loss: 0.0397 - val_root_mean_squared_error: 0.1992
# Epoch 48/50
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0100 - root_mean_squared_error: 0.1001 - val_loss: 0.0564 - val_root_mean_squared_error: 0.2375
# Epoch 49/50
# 49/49 [==============================] - 2s 32ms/step - loss: 0.0096 - root_mean_squared_error: 0.0979 - val_loss: 0.0419 - val_root_mean_squared_error: 0.2048
# Epoch 50/50
# 49/49 [==============================] - 2s 31ms/step - loss: 0.0099 - root_mean_squared_error: 0.0996 - val_loss: 0.0489 - val_root_mean_squared_error: 0.2212

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 3.3954883853594464 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bering_model_LT12/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.13986191284823832
# MAE : 0.10905026399206677

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       369495.250000     591635.798
# 1       272316.843750     598360.298
# 2       169148.250000     531742.038
# 3        78352.562500     302131.004
# 4        24239.767578      57748.135
# 5        26487.509766       3054.962
# 6        48810.773438        442.539
# 7        93099.328125       8541.643
# 8       162009.906250     121335.125
# 9       261057.781250     360205.990
# 10      393143.093750     651717.220
# 11      539973.500000     779385.402
# 12      556522.500000     710314.085
# 13      409377.718750     578635.421
# 14      205364.968750     199031.792
# 15       76324.726562      43795.314
# 16       24129.660156       3015.211
# 17       41267.855469       1206.623
# 18       81156.718750       8506.979
# 19      144289.890625      41065.748
# 20      235312.265625     169363.165
# 21      364791.031250     531698.544
# 22      493028.156250     631496.345
# 23      508011.625000     612860.407
# 24      413584.000000     552903.799
# 25      240607.937500     317377.493
# 26       77554.343750      39601.476
# 27       27824.474609      16935.702
# 28       58839.070312       1305.744
# 29      121684.929688      12255.644

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 15/15 [==============================] - 0s 18ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
