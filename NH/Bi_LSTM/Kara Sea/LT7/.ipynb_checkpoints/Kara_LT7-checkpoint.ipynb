# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Kara = pd.read_excel(filepath, sheet_name='Kara-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Kara)
fp.date_time(Kara)
# Out:
#          Extent       Date
# 0    917992.880 1979-01-01
# 1    917992.880 1979-02-01
# 2    917992.880 1979-03-01
# 3    917992.880 1979-04-01
# 4    917992.880 1979-05-01
# ..          ...        ...
# 533  728642.743 2023-06-01
# 534  437024.646 2023-07-01
# 535  202260.789 2023-08-01
# 536   98103.856 2023-09-01
# 537  260413.272 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Kara['Extent'] = scaler.fit_transform(Kara['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 7
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Kara['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((520, 12, 1), (520,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Kara_model_LT7/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.4669 - root_mean_squared_error: 0.6833INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 39s 510ms/step - loss: 0.4649 - root_mean_squared_error: 0.6818 - val_loss: 0.1825 - val_root_mean_squared_error: 0.4272
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0923 - root_mean_squared_error: 0.3038INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 26s 493ms/step - loss: 0.0923 - root_mean_squared_error: 0.3038 - val_loss: 0.1463 - val_root_mean_squared_error: 0.3825
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0824 - root_mean_squared_error: 0.2871INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 26s 505ms/step - loss: 0.0819 - root_mean_squared_error: 0.2862 - val_loss: 0.1439 - val_root_mean_squared_error: 0.3794
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0833 - root_mean_squared_error: 0.2886INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 25s 485ms/step - loss: 0.0827 - root_mean_squared_error: 0.2876 - val_loss: 0.1406 - val_root_mean_squared_error: 0.3750
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0785 - root_mean_squared_error: 0.2801INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 25s 488ms/step - loss: 0.0785 - root_mean_squared_error: 0.2801 - val_loss: 0.1329 - val_root_mean_squared_error: 0.3645
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0746 - root_mean_squared_error: 0.2732INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 25s 486ms/step - loss: 0.0746 - root_mean_squared_error: 0.2732 - val_loss: 0.1244 - val_root_mean_squared_error: 0.3527
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0655 - root_mean_squared_error: 0.2559INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 26s 499ms/step - loss: 0.0655 - root_mean_squared_error: 0.2559 - val_loss: 0.1165 - val_root_mean_squared_error: 0.3414
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0646 - root_mean_squared_error: 0.2541INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 26s 508ms/step - loss: 0.0646 - root_mean_squared_error: 0.2541 - val_loss: 0.0986 - val_root_mean_squared_error: 0.3140
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0543 - root_mean_squared_error: 0.2331INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 26s 501ms/step - loss: 0.0543 - root_mean_squared_error: 0.2331 - val_loss: 0.0834 - val_root_mean_squared_error: 0.2889
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0492 - root_mean_squared_error: 0.2219INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 25s 484ms/step - loss: 0.0489 - root_mean_squared_error: 0.2212 - val_loss: 0.0659 - val_root_mean_squared_error: 0.2567
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0429 - root_mean_squared_error: 0.2072INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 27s 511ms/step - loss: 0.0429 - root_mean_squared_error: 0.2072 - val_loss: 0.0544 - val_root_mean_squared_error: 0.2332
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0355 - root_mean_squared_error: 0.1883INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 26s 505ms/step - loss: 0.0355 - root_mean_squared_error: 0.1883 - val_loss: 0.0468 - val_root_mean_squared_error: 0.2164
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0319 - root_mean_squared_error: 0.1787INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 26s 503ms/step - loss: 0.0318 - root_mean_squared_error: 0.1784 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2035
# Epoch 14/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0300 - root_mean_squared_error: 0.1732INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0299 - root_mean_squared_error: 0.1729 - val_loss: 0.0342 - val_root_mean_squared_error: 0.1849
# Epoch 15/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0276 - root_mean_squared_error: 0.1661INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 29s 552ms/step - loss: 0.0276 - root_mean_squared_error: 0.1661 - val_loss: 0.0321 - val_root_mean_squared_error: 0.1791
# Epoch 16/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0278 - root_mean_squared_error: 0.1666INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 32s 610ms/step - loss: 0.0279 - root_mean_squared_error: 0.1669 - val_loss: 0.0304 - val_root_mean_squared_error: 0.1743
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0257 - root_mean_squared_error: 0.1602INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 32s 609ms/step - loss: 0.0257 - root_mean_squared_error: 0.1602 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1700
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0265 - root_mean_squared_error: 0.1628INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 31s 598ms/step - loss: 0.0265 - root_mean_squared_error: 0.1628 - val_loss: 0.0284 - val_root_mean_squared_error: 0.1686
# Epoch 19/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0247 - root_mean_squared_error: 0.1570 - val_loss: 0.0286 - val_root_mean_squared_error: 0.1690
# Epoch 20/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0235 - root_mean_squared_error: 0.1532INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 31s 601ms/step - loss: 0.0235 - root_mean_squared_error: 0.1532 - val_loss: 0.0266 - val_root_mean_squared_error: 0.1630
# Epoch 21/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0244 - root_mean_squared_error: 0.1563 - val_loss: 0.0286 - val_root_mean_squared_error: 0.1690
# Epoch 22/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0224 - root_mean_squared_error: 0.1495 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1646
# Epoch 23/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0227 - root_mean_squared_error: 0.1506INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 30s 566ms/step - loss: 0.0227 - root_mean_squared_error: 0.1506 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1583
# Epoch 24/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0215 - root_mean_squared_error: 0.1466 - val_loss: 0.0266 - val_root_mean_squared_error: 0.1630
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0221 - root_mean_squared_error: 0.1488INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 26s 503ms/step - loss: 0.0221 - root_mean_squared_error: 0.1488 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1573
# Epoch 26/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0211 - root_mean_squared_error: 0.1453 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1579
# Epoch 27/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0206 - root_mean_squared_error: 0.1434INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 26s 507ms/step - loss: 0.0206 - root_mean_squared_error: 0.1434 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1566
# Epoch 28/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0219 - root_mean_squared_error: 0.1480 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1572
# Epoch 29/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0206 - root_mean_squared_error: 0.1437 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1566
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0203 - root_mean_squared_error: 0.1426INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0203 - root_mean_squared_error: 0.1426 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1536
# Epoch 31/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0200 - root_mean_squared_error: 0.1415INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 27s 516ms/step - loss: 0.0200 - root_mean_squared_error: 0.1415 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1516
# Epoch 32/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0191 - root_mean_squared_error: 0.1381 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1527
# Epoch 33/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0202 - root_mean_squared_error: 0.1420INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0202 - root_mean_squared_error: 0.1420 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1476
# Epoch 34/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0179 - root_mean_squared_error: 0.1337INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 26s 503ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1438
# Epoch 35/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0185 - root_mean_squared_error: 0.1361 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1585
# Epoch 36/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0194 - root_mean_squared_error: 0.1393 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1490
# Epoch 37/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0206 - root_mean_squared_error: 0.1437 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1486
# Epoch 38/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0181 - root_mean_squared_error: 0.1344 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1479
# Epoch 39/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0175 - root_mean_squared_error: 0.1325 - val_loss: 0.0220 - val_root_mean_squared_error: 0.1483
# Epoch 40/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0178 - root_mean_squared_error: 0.1335 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1465
# Epoch 41/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0184 - root_mean_squared_error: 0.1357 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1452
# Epoch 42/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0178 - root_mean_squared_error: 0.1333INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 26s 501ms/step - loss: 0.0176 - root_mean_squared_error: 0.1328 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1427
# Epoch 43/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0179 - root_mean_squared_error: 0.1339 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1463
# Epoch 44/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0179 - root_mean_squared_error: 0.1339 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1454
# Epoch 45/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0175 - root_mean_squared_error: 0.1323 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1449
# Epoch 46/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0173 - root_mean_squared_error: 0.1315INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 26s 501ms/step - loss: 0.0172 - root_mean_squared_error: 0.1313 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1405
# Epoch 47/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0174 - root_mean_squared_error: 0.1320 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1428
# Epoch 48/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0168 - root_mean_squared_error: 0.1298 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1489
# Epoch 49/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0175 - root_mean_squared_error: 0.1321INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0175 - root_mean_squared_error: 0.1321 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1377
# Epoch 50/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0174 - root_mean_squared_error: 0.1319INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 27s 513ms/step - loss: 0.0174 - root_mean_squared_error: 0.1319 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1367

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 14.852968351046245 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Kara_model_LT7/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 41ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.12647501019027058
# MAE : 0.09294884905066199

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 43ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
