# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Pacific_Extent = pd.read_excel(filepath, sheet_name='Pacific-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Pacific_Extent)
fp.date_time(Pacific_Extent)
# Out:
#           Extent       Date
# 0     668714.275 1979-01-01
# 1     566930.458 1979-02-01
# 2     688420.115 1979-03-01
# 3     859963.043 1979-04-01
# 4    1127120.160 1979-05-01
# ..           ...        ...
# 533  1134056.102 2023-06-01
# 534  1484824.377 2023-07-01
# 535  1671324.717 2023-08-01
# 536  1726376.097 2023-09-01
# 537  1690631.996 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Pacific_Extent['Extent'] = scaler.fit_transform(Pacific_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 11
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Pacific_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((516, 12, 1), (516,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Pacific_model_LT11/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2057 - root_mean_squared_error: 0.4536INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 31s 466ms/step - loss: 0.2037 - root_mean_squared_error: 0.4514 - val_loss: 0.1155 - val_root_mean_squared_error: 0.3398
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0748 - root_mean_squared_error: 0.2735INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 25s 480ms/step - loss: 0.0749 - root_mean_squared_error: 0.2737 - val_loss: 0.0558 - val_root_mean_squared_error: 0.2362
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0528 - root_mean_squared_error: 0.2298INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 25s 476ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300 - val_loss: 0.0473 - val_root_mean_squared_error: 0.2174
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0418 - root_mean_squared_error: 0.2045INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 26s 506ms/step - loss: 0.0418 - root_mean_squared_error: 0.2045 - val_loss: 0.0346 - val_root_mean_squared_error: 0.1860
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0300 - root_mean_squared_error: 0.1731INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 26s 494ms/step - loss: 0.0300 - root_mean_squared_error: 0.1731 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1472
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0219 - root_mean_squared_error: 0.1479INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 26s 500ms/step - loss: 0.0219 - root_mean_squared_error: 0.1479 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1101
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0182 - root_mean_squared_error: 0.1348INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 26s 497ms/step - loss: 0.0182 - root_mean_squared_error: 0.1348 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1014
# Epoch 8/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0161 - root_mean_squared_error: 0.1269 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1085
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0134 - root_mean_squared_error: 0.1155INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 27s 518ms/step - loss: 0.0134 - root_mean_squared_error: 0.1155 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0870
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0112 - root_mean_squared_error: 0.1060INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 26s 500ms/step - loss: 0.0112 - root_mean_squared_error: 0.1060 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0839
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0114 - root_mean_squared_error: 0.1067INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 26s 496ms/step - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0745
# Epoch 12/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0106 - root_mean_squared_error: 0.1030 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0863
# Epoch 13/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0099 - root_mean_squared_error: 0.0994 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0786
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0097 - root_mean_squared_error: 0.0986INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 26s 498ms/step - loss: 0.0097 - root_mean_squared_error: 0.0986 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0713
# Epoch 15/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0087 - root_mean_squared_error: 0.0934 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0776
# Epoch 16/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0089 - root_mean_squared_error: 0.0943 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0769
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0090 - root_mean_squared_error: 0.0947INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 26s 500ms/step - loss: 0.0090 - root_mean_squared_error: 0.0947 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0711
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0092 - root_mean_squared_error: 0.0960INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 26s 503ms/step - loss: 0.0092 - root_mean_squared_error: 0.0960 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0709
# Epoch 19/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0079 - root_mean_squared_error: 0.0886 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0764
# Epoch 20/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0085 - root_mean_squared_error: 0.0922 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0783
# Epoch 21/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0085 - root_mean_squared_error: 0.0921INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 27s 509ms/step - loss: 0.0085 - root_mean_squared_error: 0.0921 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0698
# Epoch 22/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0078 - root_mean_squared_error: 0.0881 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0784
# Epoch 23/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0081 - root_mean_squared_error: 0.0902INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 26s 496ms/step - loss: 0.0081 - root_mean_squared_error: 0.0902 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0084 - root_mean_squared_error: 0.0918INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 27s 512ms/step - loss: 0.0084 - root_mean_squared_error: 0.0918 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0686
# Epoch 25/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0083 - root_mean_squared_error: 0.0913 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0773
# Epoch 26/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0077 - root_mean_squared_error: 0.0878 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0688
# Epoch 27/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0073 - root_mean_squared_error: 0.0855 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0721
# Epoch 28/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0085 - root_mean_squared_error: 0.0919 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0699
# Epoch 29/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0076 - root_mean_squared_error: 0.0869 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0691
# Epoch 30/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0075 - root_mean_squared_error: 0.0868 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0721
# Epoch 31/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0071 - root_mean_squared_error: 0.0842 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0768
# Epoch 32/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0079 - root_mean_squared_error: 0.0887 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0768
# Epoch 33/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0072 - root_mean_squared_error: 0.0851 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0700
# Epoch 34/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0069 - root_mean_squared_error: 0.0834 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0686
# Epoch 35/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0074 - root_mean_squared_error: 0.0858INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 25s 487ms/step - loss: 0.0076 - root_mean_squared_error: 0.0871 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0683
# Epoch 36/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0070 - root_mean_squared_error: 0.0838 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0702
# Epoch 37/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0068 - root_mean_squared_error: 0.0825 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0688
# Epoch 38/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0072 - root_mean_squared_error: 0.0847INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 26s 503ms/step - loss: 0.0072 - root_mean_squared_error: 0.0847 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0677
# Epoch 39/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0071 - root_mean_squared_error: 0.0844 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0710
# Epoch 40/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0070 - root_mean_squared_error: 0.0836 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0723
# Epoch 41/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0070 - root_mean_squared_error: 0.0838 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0710
# Epoch 42/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0066 - root_mean_squared_error: 0.0814 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0683
# Epoch 43/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0067 - root_mean_squared_error: 0.0820 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0690
# Epoch 44/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0067 - root_mean_squared_error: 0.0819INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 26s 503ms/step - loss: 0.0067 - root_mean_squared_error: 0.0819 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0672
# Epoch 45/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0071 - root_mean_squared_error: 0.0842 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0710
# Epoch 46/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0072 - root_mean_squared_error: 0.0848 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0731
# Epoch 47/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0063 - root_mean_squared_error: 0.0796INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 27s 512ms/step - loss: 0.0063 - root_mean_squared_error: 0.0796 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0664
# Epoch 48/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0068 - root_mean_squared_error: 0.0822 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0670
# Epoch 49/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0067 - root_mean_squared_error: 0.0817 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0741
# Epoch 50/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0071 - root_mean_squared_error: 0.0843 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0701

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 10.585157831509909 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Pacific_model_LT11/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 28ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.06289635051562786
# MAE : 0.05196288996472935

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        4.625769e+05     610848.036
# 1        7.902704e+05     819257.445
# 2        1.189463e+06    1129627.707
# 3        1.476617e+06    1463383.236
# 4        1.716705e+06    1614536.727
# 5        1.952197e+06    1862498.612
# 6        2.023761e+06    2099349.296
# 7        1.811857e+06    1981614.046
# 8        1.435329e+06    1433022.369
# 9        9.934449e+05     826739.716
# 10       5.856900e+05     477145.887
# 11       4.140860e+05     314469.289
# 12       5.041693e+05     463134.749
# 13       8.427944e+05     946522.292
# 14       1.231536e+06    1309266.570
# 15       1.473523e+06    1507947.309
# 16       1.698014e+06    1804167.937
# 17       1.896815e+06    1908002.139
# 18       1.971803e+06    1892748.521
# 19       1.806790e+06    1601079.640
# 20       1.398913e+06    1327804.521
# 21       9.102529e+05     812074.231
# 22       5.121533e+05     493355.897
# 23       3.339897e+05     317229.330
# 24       5.194165e+05     425777.624
# 25       9.417726e+05     827172.620
# 26       1.284349e+06    1162367.223
# 27       1.551079e+06    1413734.261
# 28       1.770197e+06    1574257.849
# 29       1.895647e+06    1786961.251
# 30       1.862026e+06    1857942.866
# 31       1.658604e+06    1406291.588
# 32       1.281057e+06    1025555.371
# 33       8.198491e+05     632862.782
# 34       4.568327e+05     308194.756
# 35       3.074725e+05     194921.078
# 36       4.821126e+05     245569.900
# 37       8.676707e+05     533532.424
# 38       1.229752e+06     943124.529
# 39       1.452931e+06    1134056.102
# 40       1.660752e+06    1484824.377
# 41       1.816390e+06    1671324.717
# 42       1.785062e+06    1726376.097
# 43       1.555333e+06    1690631.996

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 35ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
