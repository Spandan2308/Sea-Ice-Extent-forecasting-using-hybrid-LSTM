# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Weddell_Extent = pd.read_excel(filepath, sheet_name='Weddell-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Weddell_Extent)
fp.date_time(Weddell_Extent)
# Out:
#           Extent       Date
# 0    2136510.859 1979-01-01
# 1    1243495.891 1979-02-01
# 2    1699053.449 1979-03-01
# 3    2617442.085 1979-04-01
# 4    3852934.206 1979-05-01
# ..           ...        ...
# 533  3668127.143 2023-06-01
# 534  4805519.784 2023-07-01
# 535  5524445.234 2023-08-01
# 536  6006669.861 2023-09-01
# 537  5507961.583 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Weddell_Extent['Extent'] = scaler.fit_transform(Weddell_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 12
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Weddell_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((515, 12, 1), (515,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Weddell_model_LT12/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.2596 - root_mean_squared_error: 0.5096
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 8s 100ms/step - loss: 0.2489 - root_mean_squared_error: 0.4989 - val_loss: 0.2553 - val_root_mean_squared_error: 0.5052
# Epoch 2/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2077 - root_mean_squared_error: 0.4557
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 5s 88ms/step - loss: 0.2091 - root_mean_squared_error: 0.4573 - val_loss: 0.2141 - val_root_mean_squared_error: 0.4627
# Epoch 3/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1760 - root_mean_squared_error: 0.4195
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.1738 - root_mean_squared_error: 0.4169 - val_loss: 0.1781 - val_root_mean_squared_error: 0.4220
# Epoch 4/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.1408 - root_mean_squared_error: 0.3753
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 5s 88ms/step - loss: 0.1382 - root_mean_squared_error: 0.3717 - val_loss: 0.1498 - val_root_mean_squared_error: 0.3871
# Epoch 5/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1098 - root_mean_squared_error: 0.3313
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.1097 - root_mean_squared_error: 0.3312 - val_loss: 0.1212 - val_root_mean_squared_error: 0.3482
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0861 - root_mean_squared_error: 0.2934
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0863 - root_mean_squared_error: 0.2937 - val_loss: 0.0981 - val_root_mean_squared_error: 0.3133
# Epoch 7/50
# 43/53 [=======================>......] - ETA: 0s - loss: 0.0638 - root_mean_squared_error: 0.2526
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0706 - root_mean_squared_error: 0.2658 - val_loss: 0.0813 - val_root_mean_squared_error: 0.2851
# Epoch 8/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0509 - root_mean_squared_error: 0.2255
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0504 - root_mean_squared_error: 0.2245 - val_loss: 0.0625 - val_root_mean_squared_error: 0.2499
# Epoch 9/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0378 - root_mean_squared_error: 0.1944
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0359 - root_mean_squared_error: 0.1894 - val_loss: 0.0471 - val_root_mean_squared_error: 0.2171
# Epoch 10/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0314 - root_mean_squared_error: 0.1772
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 5s 97ms/step - loss: 0.0306 - root_mean_squared_error: 0.1749 - val_loss: 0.0365 - val_root_mean_squared_error: 0.1911
# Epoch 11/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0272 - root_mean_squared_error: 0.1648
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0271 - root_mean_squared_error: 0.1648 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1616
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0192 - root_mean_squared_error: 0.1384
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0190 - root_mean_squared_error: 0.1378 - val_loss: 0.0191 - val_root_mean_squared_error: 0.1383
# Epoch 13/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0137 - root_mean_squared_error: 0.1172
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0138 - root_mean_squared_error: 0.1177 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1124
# Epoch 14/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0125 - root_mean_squared_error: 0.1120
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0928
# Epoch 15/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0123 - root_mean_squared_error: 0.1107
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0122 - root_mean_squared_error: 0.1104 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0927
# Epoch 16/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0132 - root_mean_squared_error: 0.1149
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 4s 78ms/step - loss: 0.0150 - root_mean_squared_error: 0.1224 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679
# Epoch 17/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0105 - root_mean_squared_error: 0.1026 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0845
# Epoch 18/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0152 - root_mean_squared_error: 0.1231 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0688
# Epoch 19/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0123 - root_mean_squared_error: 0.1108 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0857
# Epoch 20/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0095 - root_mean_squared_error: 0.0972 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1416
# Epoch 21/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0126 - root_mean_squared_error: 0.1122 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0694
# Epoch 22/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0119 - root_mean_squared_error: 0.1090 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0988
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0115 - root_mean_squared_error: 0.1073 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0900
# Epoch 24/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0124 - root_mean_squared_error: 0.1113 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0708
# Epoch 25/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0112 - root_mean_squared_error: 0.1059
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0108 - root_mean_squared_error: 0.1040 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0586
# Epoch 26/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1264
# Epoch 27/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0109 - root_mean_squared_error: 0.1043 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1005
# Epoch 28/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0125 - root_mean_squared_error: 0.1119 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0648
# Epoch 29/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0143 - root_mean_squared_error: 0.1198 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0726
# Epoch 30/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0112 - root_mean_squared_error: 0.1058 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0743
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0120 - root_mean_squared_error: 0.1095 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0779
# Epoch 32/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1198 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0662
# Epoch 33/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0157 - root_mean_squared_error: 0.1254 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0996
# Epoch 34/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0170 - root_mean_squared_error: 0.1305 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 35/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0108 - root_mean_squared_error: 0.1037 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0665
# Epoch 36/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0142 - root_mean_squared_error: 0.1192
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0138 - root_mean_squared_error: 0.1176 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0585
# Epoch 37/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0112 - root_mean_squared_error: 0.1060 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0786
# Epoch 38/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0124 - root_mean_squared_error: 0.1115 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0749
# Epoch 39/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0111 - root_mean_squared_error: 0.1051 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0701
# Epoch 40/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0123 - root_mean_squared_error: 0.1111 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0741
# Epoch 41/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0107 - root_mean_squared_error: 0.1032 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0625
# Epoch 42/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0126 - root_mean_squared_error: 0.1122 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 43/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0128 - root_mean_squared_error: 0.1132 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0934
# Epoch 44/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0160 - root_mean_squared_error: 0.1265 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0688
# Epoch 45/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0168 - root_mean_squared_error: 0.1297 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0792
# Epoch 46/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0171 - root_mean_squared_error: 0.1306 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0703
# Epoch 47/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0119 - root_mean_squared_error: 0.1092 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1080
# Epoch 48/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0143 - root_mean_squared_error: 0.1194 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0603
# Epoch 49/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0117 - root_mean_squared_error: 0.1082 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0840
# Epoch 50/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0094 - root_mean_squared_error: 0.0967 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0724

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.6309449553489686 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Weddell_model_LT12/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 0s/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.06065051969504994
# MAE : 0.04799051824720627

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        2.411645e+06    2121949.701
# 1        3.425341e+06    3562381.775
# 2        4.549948e+06    5004305.983
# 3        5.946924e+06    6176613.878
# 4        6.267468e+06    6794233.093
# 5        6.551562e+06    7024136.637
# 6        6.137093e+06    6554271.388
# 7        5.552793e+06    6172281.701
# 8        3.186939e+06    4175225.799
# 9        1.604508e+06    1748380.899
# 10       1.105269e+06    1256191.080
# 11       1.468047e+06    1347295.364
# 12       2.361141e+06    2180184.677
# 13       3.483691e+06    3419295.982
# 14       4.831814e+06    4786146.771
# 15       5.871060e+06    5968132.718
# 16       6.356580e+06    6556934.174
# 17       6.444246e+06    6614949.980
# 18       6.205736e+06    6035207.368
# 19       5.452476e+06    5274244.730
# 20       3.496092e+06    3505146.372
# 21       1.223099e+06    1478130.228
# 22       7.861481e+05    1096780.503
# 23       1.029498e+06    1387234.069
# 24       1.970550e+06    2128693.591
# 25       3.197290e+06    3313318.704
# 26       4.487661e+06    4218076.656
# 27       5.697192e+06    5257641.941
# 28       6.186237e+06    5956603.340
# 29       6.359665e+06    6256062.049
# 30       5.954482e+06    5974548.305
# 31       5.101886e+06    5569396.731
# 32       3.300136e+06    3684108.410
# 33       1.677444e+06    1451614.707
# 34       1.066066e+06    1089888.684
# 35       1.530960e+06    1255222.909
# 36       2.326812e+06    1704492.279
# 37       3.560907e+06    2563551.804
# 38       4.549946e+06    3668127.143
# 39       5.589400e+06    4805519.784
# 40       6.165581e+06    5524445.234
# 41       6.306244e+06    6006669.861
# 42       6.080130e+06    5507961.583

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
