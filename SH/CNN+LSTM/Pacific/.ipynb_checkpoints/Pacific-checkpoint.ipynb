# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Pacific_Extent = pd.read_excel(filepath, sheet_name='Pacific-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Pacific_Extent)
fp.date_time(Pacific_Extent)
# Out:
#           Extent       Date
# 0     668714.275 1979-01-01
# 1     566930.458 1979-02-01
# 2     688420.115 1979-03-01
# 3     859963.043 1979-04-01
# 4    1127120.160 1979-05-01
# ..           ...        ...
# 533  1134056.102 2023-06-01
# 534  1484824.377 2023-07-01
# 535  1671324.717 2023-08-01
# 536  1726376.097 2023-09-01
# 537  1690631.996 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Pacific_Extent['Extent'] = scaler.fit_transform(Pacific_Extent['Extent'].values.reshape(-1, 1))

# %%
extent = Pacific_Extent['Extent']
W_S=12
X,y = fp.df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((526, 12, 1), (526,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Pacific_model/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.2410 - root_mean_squared_error: 0.4909
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 9s 106ms/step - loss: 0.2374 - root_mean_squared_error: 0.4872 - val_loss: 0.2284 - val_root_mean_squared_error: 0.4779
# Epoch 2/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.1908 - root_mean_squared_error: 0.4368
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.1861 - root_mean_squared_error: 0.4314 - val_loss: 0.1893 - val_root_mean_squared_error: 0.4351
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1508 - root_mean_squared_error: 0.3883
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.1510 - root_mean_squared_error: 0.3886 - val_loss: 0.1563 - val_root_mean_squared_error: 0.3954
# Epoch 4/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.1195 - root_mean_squared_error: 0.3457
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 5s 88ms/step - loss: 0.1224 - root_mean_squared_error: 0.3498 - val_loss: 0.1278 - val_root_mean_squared_error: 0.3575
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0988 - root_mean_squared_error: 0.3143
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0988 - root_mean_squared_error: 0.3143 - val_loss: 0.1022 - val_root_mean_squared_error: 0.3198
# Epoch 6/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0834 - root_mean_squared_error: 0.2888
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0811 - root_mean_squared_error: 0.2849 - val_loss: 0.0801 - val_root_mean_squared_error: 0.2831
# Epoch 7/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0606 - root_mean_squared_error: 0.2462
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0619 - root_mean_squared_error: 0.2488 - val_loss: 0.0619 - val_root_mean_squared_error: 0.2488
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0478 - root_mean_squared_error: 0.2187
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0478 - root_mean_squared_error: 0.2187 - val_loss: 0.0521 - val_root_mean_squared_error: 0.2283
# Epoch 9/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0408 - root_mean_squared_error: 0.2020
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0370 - root_mean_squared_error: 0.1922 - val_loss: 0.0365 - val_root_mean_squared_error: 0.1910
# Epoch 10/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0301 - root_mean_squared_error: 0.1735
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0277 - root_mean_squared_error: 0.1664 - val_loss: 0.0327 - val_root_mean_squared_error: 0.1808
# Epoch 11/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0218 - root_mean_squared_error: 0.1477
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.0225 - root_mean_squared_error: 0.1501 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1286
# Epoch 12/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0205 - root_mean_squared_error: 0.1432 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1386
# Epoch 13/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0148 - root_mean_squared_error: 0.1216
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0913
# Epoch 14/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0136 - root_mean_squared_error: 0.1164 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0956
# Epoch 15/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0096 - root_mean_squared_error: 0.0978
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0091 - root_mean_squared_error: 0.0951 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0661
# Epoch 16/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0131 - root_mean_squared_error: 0.1144 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0770
# Epoch 17/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0105 - root_mean_squared_error: 0.1024
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0099 - root_mean_squared_error: 0.0997 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0650
# Epoch 18/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0109 - root_mean_squared_error: 0.1044
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0568
# Epoch 19/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0088 - root_mean_squared_error: 0.0938
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0094 - root_mean_squared_error: 0.0969 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0551
# Epoch 20/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0110 - root_mean_squared_error: 0.1048 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0665
# Epoch 21/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0087 - root_mean_squared_error: 0.0930
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0083 - root_mean_squared_error: 0.0912 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0539
# Epoch 22/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0083 - root_mean_squared_error: 0.0913 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0677
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0091 - root_mean_squared_error: 0.0955 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0568
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0091 - root_mean_squared_error: 0.0954 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0987
# Epoch 25/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0090 - root_mean_squared_error: 0.0948 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0913
# Epoch 26/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0095 - root_mean_squared_error: 0.0974 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0567
# Epoch 27/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0125 - root_mean_squared_error: 0.1119 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0567
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0088 - root_mean_squared_error: 0.0937 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0928
# Epoch 29/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0106 - root_mean_squared_error: 0.1030
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0100 - root_mean_squared_error: 0.1001 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0537
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0089 - root_mean_squared_error: 0.0945 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0948
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0088 - root_mean_squared_error: 0.0937 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0733
# Epoch 32/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0092 - root_mean_squared_error: 0.0957 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0570
# Epoch 33/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0097 - root_mean_squared_error: 0.0984 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0599
# Epoch 34/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0107 - root_mean_squared_error: 0.1036 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0717
# Epoch 35/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0101 - root_mean_squared_error: 0.1006
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0101 - root_mean_squared_error: 0.1006 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0508
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0093 - root_mean_squared_error: 0.0966 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0644
# Epoch 37/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0097 - root_mean_squared_error: 0.0984 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0570
# Epoch 38/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0115 - root_mean_squared_error: 0.1070 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0739
# Epoch 39/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0710
# Epoch 40/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0117 - root_mean_squared_error: 0.1080 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0712
# Epoch 41/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0111 - root_mean_squared_error: 0.1052 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0577
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0133 - root_mean_squared_error: 0.1153 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0925
# Epoch 43/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0086 - root_mean_squared_error: 0.0929 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0778
# Epoch 44/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0091 - root_mean_squared_error: 0.0956
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 4s 81ms/step - loss: 0.0091 - root_mean_squared_error: 0.0952 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0503
# Epoch 45/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0104 - root_mean_squared_error: 0.1021 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0582
# Epoch 46/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0094 - root_mean_squared_error: 0.0971 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0520
# Epoch 47/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0093 - root_mean_squared_error: 0.0962 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0860
# Epoch 48/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0099 - root_mean_squared_error: 0.0997 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0530
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0081 - root_mean_squared_error: 0.0902 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0680
# Epoch 50/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0107 - root_mean_squared_error: 0.1033
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model\assets
# INFO:tensorflow:Assets written to: Pacific_model\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0114 - root_mean_squared_error: 0.1070 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0494

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.8418330748875935 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Pacific_model/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 34ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.04659573599606537
# MAE : 0.034584534921385496

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.067547e+06    1044555.651
# 1        1.398910e+06    1400934.040
# 2        1.596511e+06    1701391.499
# 3        1.869112e+06    1890231.668
# 4        1.935938e+06    2203401.829
# 5        2.009331e+06    1960480.542
# 6        1.481604e+06    1264318.504
# 7        7.637168e+05     863206.294
# 8        4.790126e+05     635624.004
# 9        4.264203e+05     460009.672
# 10       6.318356e+05     610848.036
# 11       8.885558e+05     819257.445
# 12       1.210710e+06    1129627.707
# 13       1.474814e+06    1463383.236
# 14       1.755056e+06    1614536.727
# 15       1.873448e+06    1862498.612
# 16       1.986939e+06    2099349.296
# 17       1.978356e+06    1981614.046
# 18       1.485947e+06    1433022.369
# 19       8.004064e+05     826739.716
# 20       4.903854e+05     477145.887
# 21       2.699117e+05     314469.289
# 22       4.622875e+05     463134.749
# 23       7.617271e+05     946522.292
# 24       1.306333e+06    1309266.570
# 25       1.567741e+06    1507947.309
# 26       1.816358e+06    1804167.937
# 27       1.966240e+06    1908002.139
# 28       2.028857e+06    1892748.521
# 29       1.746465e+06    1601079.640
# 30       1.196687e+06    1327804.521
# 31       7.029588e+05     812074.231
# 32       4.725753e+05     493355.897
# 33       4.030655e+05     317229.330
# 34       4.723111e+05     425777.624
# 35       8.073794e+05     827172.620
# 36       1.169209e+06    1162367.223
# 37       1.455902e+06    1413734.261
# 38       1.664220e+06    1574257.849
# 39       1.797064e+06    1786961.251
# 40       1.833567e+06    1857942.866
# 41       1.677825e+06    1406291.588
# 42       1.132932e+06    1025555.371
# 43       6.536120e+05     632862.782
# 44       4.589265e+05     308194.756
# 45       3.911926e+05     194921.078
# 46       4.783505e+05     245569.900
# 47       6.856599e+05     533532.424
# 48       9.559002e+05     943124.529
# 49       1.334507e+06    1134056.102
# 50       1.440881e+06    1484824.377
# 51       1.740686e+06    1671324.717
# 52       1.705452e+06    1726376.097
# 53       1.546212e+06    1690631.996

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
