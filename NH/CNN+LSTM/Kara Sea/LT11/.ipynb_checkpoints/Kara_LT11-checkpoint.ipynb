# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Kara = pd.read_excel(filepath, sheet_name='Kara-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Kara)
fp.date_time(Kara)
# Out:
#          Extent       Date
# 0    917992.880 1979-01-01
# 1    917992.880 1979-02-01
# 2    917992.880 1979-03-01
# 3    917992.880 1979-04-01
# 4    917992.880 1979-05-01
# ..          ...        ...
# 533  728642.743 2023-06-01
# 534  437024.646 2023-07-01
# 535  202260.789 2023-08-01
# 536   98103.856 2023-09-01
# 537  260413.272 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Kara['Extent'] = scaler.fit_transform(Kara['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 11
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Kara['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((516, 12, 1), (516,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Kara_model_LT11/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.6442 - root_mean_squared_error: 0.8026
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 8s 105ms/step - loss: 0.6465 - root_mean_squared_error: 0.8041 - val_loss: 0.5056 - val_root_mean_squared_error: 0.7110
# Epoch 2/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.5598 - root_mean_squared_error: 0.7482
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.5483 - root_mean_squared_error: 0.7405 - val_loss: 0.4545 - val_root_mean_squared_error: 0.6741
# Epoch 3/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.4793 - root_mean_squared_error: 0.6923
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 3s 66ms/step - loss: 0.4820 - root_mean_squared_error: 0.6943 - val_loss: 0.4132 - val_root_mean_squared_error: 0.6428
# Epoch 4/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.4315 - root_mean_squared_error: 0.6569
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.4233 - root_mean_squared_error: 0.6506 - val_loss: 0.3683 - val_root_mean_squared_error: 0.6069
# Epoch 5/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.3721 - root_mean_squared_error: 0.6100
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.3714 - root_mean_squared_error: 0.6094 - val_loss: 0.3218 - val_root_mean_squared_error: 0.5673
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.3137 - root_mean_squared_error: 0.5601
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 5s 95ms/step - loss: 0.3159 - root_mean_squared_error: 0.5621 - val_loss: 0.2758 - val_root_mean_squared_error: 0.5252
# Epoch 7/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2649 - root_mean_squared_error: 0.5147
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 5s 104ms/step - loss: 0.2641 - root_mean_squared_error: 0.5139 - val_loss: 0.2262 - val_root_mean_squared_error: 0.4756
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2202 - root_mean_squared_error: 0.4693
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.2202 - root_mean_squared_error: 0.4693 - val_loss: 0.1863 - val_root_mean_squared_error: 0.4317
# Epoch 9/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.1843 - root_mean_squared_error: 0.4293
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 4s 74ms/step - loss: 0.1853 - root_mean_squared_error: 0.4305 - val_loss: 0.1557 - val_root_mean_squared_error: 0.3946
# Epoch 10/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.1560 - root_mean_squared_error: 0.3950
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.1504 - root_mean_squared_error: 0.3879 - val_loss: 0.1431 - val_root_mean_squared_error: 0.3782
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1182 - root_mean_squared_error: 0.3438
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.1182 - root_mean_squared_error: 0.3438 - val_loss: 0.0923 - val_root_mean_squared_error: 0.3039
# Epoch 12/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0968 - root_mean_squared_error: 0.3111
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0948 - root_mean_squared_error: 0.3078 - val_loss: 0.0665 - val_root_mean_squared_error: 0.2580
# Epoch 13/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0756 - root_mean_squared_error: 0.2750 - val_loss: 0.0757 - val_root_mean_squared_error: 0.2752
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0625 - root_mean_squared_error: 0.2500
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0625 - root_mean_squared_error: 0.2500 - val_loss: 0.0374 - val_root_mean_squared_error: 0.1933
# Epoch 15/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0489 - root_mean_squared_error: 0.2212
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0480 - root_mean_squared_error: 0.2191 - val_loss: 0.0272 - val_root_mean_squared_error: 0.1649
# Epoch 16/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0442 - root_mean_squared_error: 0.2101
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 5s 99ms/step - loss: 0.0436 - root_mean_squared_error: 0.2088 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1429
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0387 - root_mean_squared_error: 0.1967 - val_loss: 0.0357 - val_root_mean_squared_error: 0.1889
# Epoch 18/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0290 - root_mean_squared_error: 0.1704 - val_loss: 0.0244 - val_root_mean_squared_error: 0.1562
# Epoch 19/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0326 - root_mean_squared_error: 0.1806 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1536
# Epoch 20/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0240 - root_mean_squared_error: 0.1548
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0241 - root_mean_squared_error: 0.1552 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1379
# Epoch 21/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0242 - root_mean_squared_error: 0.1555
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0236 - root_mean_squared_error: 0.1537 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1241
# Epoch 22/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0218 - root_mean_squared_error: 0.1475 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1303
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0252 - root_mean_squared_error: 0.1588 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1393
# Epoch 24/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0259 - root_mean_squared_error: 0.1611 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1430
# Epoch 25/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0244 - root_mean_squared_error: 0.1563 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1362
# Epoch 26/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0272 - root_mean_squared_error: 0.1649 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1253
# Epoch 27/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0217 - root_mean_squared_error: 0.1472
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0221 - root_mean_squared_error: 0.1487 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1216
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0238 - root_mean_squared_error: 0.1543 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1251
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0242 - root_mean_squared_error: 0.1557 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1265
# Epoch 30/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0250 - root_mean_squared_error: 0.1582 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1288
# Epoch 31/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0237 - root_mean_squared_error: 0.1540 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1238
# Epoch 32/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0249 - root_mean_squared_error: 0.1579 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1343
# Epoch 33/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0242 - root_mean_squared_error: 0.1555 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1226
# Epoch 34/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0252 - root_mean_squared_error: 0.1588 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1291
# Epoch 35/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0201 - root_mean_squared_error: 0.1416 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1259
# Epoch 36/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0231 - root_mean_squared_error: 0.1521 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1285
# Epoch 37/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0222 - root_mean_squared_error: 0.1489
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0216 - root_mean_squared_error: 0.1469 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1215
# Epoch 38/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0222 - root_mean_squared_error: 0.1489 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1321
# Epoch 39/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0225 - root_mean_squared_error: 0.1500 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1354
# Epoch 40/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0237 - root_mean_squared_error: 0.1541 - val_loss: 0.0231 - val_root_mean_squared_error: 0.1521
# Epoch 41/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0244 - root_mean_squared_error: 0.1563 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1287
# Epoch 42/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0200 - root_mean_squared_error: 0.1413
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0209 - root_mean_squared_error: 0.1446 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1204
# Epoch 43/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0208 - root_mean_squared_error: 0.1442 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1260
# Epoch 44/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0211 - root_mean_squared_error: 0.1451 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1357
# Epoch 45/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0231 - root_mean_squared_error: 0.1518 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1284
# Epoch 46/50
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0217 - root_mean_squared_error: 0.1474 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1378
# Epoch 47/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0218 - root_mean_squared_error: 0.1476
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# INFO:tensorflow:Assets written to: Kara_model_LT11\assets
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0219 - root_mean_squared_error: 0.1480 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1192
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0266 - root_mean_squared_error: 0.1630 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1400
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0187 - root_mean_squared_error: 0.1369 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1224
# Epoch 50/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0200 - root_mean_squared_error: 0.1415 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1295

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.917464292049408 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Kara_model_LT11/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.12107704166466962
# MAE : 0.09047343840733725

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        8.900546e+05     917403.622
# 1        8.984969e+05     910653.838
# 2        8.826037e+05     822319.125
# 3        6.819492e+05     557314.102
# 4        3.457934e+05     197129.525
# 5        1.797655e+05      75730.217
# 6        1.315210e+05      59608.479
# 7        2.700357e+05      88785.283
# 8        6.929925e+05     396883.400
# 9        8.718710e+05     662542.207
# 10       9.079238e+05     871431.414
# 11       8.802970e+05     917876.960
# 12       9.022569e+05     917992.880
# 13       8.764263e+05     912733.060
# 14       7.970343e+05     910536.463
# 15       5.385617e+05     760170.733
# 16       2.449038e+05     383812.645
# 17       1.336961e+05     201024.515
# 18       1.366224e+05     121904.059
# 19       2.157033e+05     283554.493
# 20       4.868663e+05     702176.823
# 21       7.677040e+05     893690.080
# 22       8.674966e+05     910117.941
# 23       9.808589e+05     889204.715
# 24       9.141269e+05     905311.611
# 25       1.001239e+06     917930.089
# 26       8.992544e+05     912089.899
# 27       7.512519e+05     743951.228
# 28       3.838427e+05     307180.895
# 29       2.074743e+05     104402.284
# 30       1.463484e+05      73177.670
# 31       3.390009e+05     127085.610
# 32       6.687023e+05     650570.950
# 33       8.189588e+05     789062.385
# 34       9.026969e+05     897053.619
# 35       8.414313e+05     904024.315
# 36       9.048800e+05     911832.551
# 37       8.759442e+05     917992.880
# 38       8.973941e+05     894286.938
# 39       6.526185e+05     728642.743
# 40       3.469194e+05     437024.646
# 41       1.552953e+05     202260.789
# 42       1.130615e+05      98103.856
# 43       2.326848e+05     260413.272

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
