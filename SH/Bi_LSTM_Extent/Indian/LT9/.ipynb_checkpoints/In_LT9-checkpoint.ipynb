# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Indian_Extent = pd.read_excel(filepath, sheet_name='Indian-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Indian_Extent)
fp.date_time(Indian_Extent)
# Out:
#           Extent       Date
# 0     376618.799 1979-01-01
# 1     211788.726 1979-02-01
# 2     262868.141 1979-03-01
# 3     698377.304 1979-04-01
# 4    1252407.727 1979-05-01
# ..           ...        ...
# 533  1520776.003 2023-06-01
# 534  2076164.165 2023-07-01
# 535  2731799.027 2023-08-01
# 536  3179384.692 2023-09-01
# 537  3301335.210 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Indian_Extent['Extent'] = scaler.fit_transform(Indian_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 9
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Indian_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((518, 12, 1), (518,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Indian_model_LT9/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.2596 - root_mean_squared_error: 0.5095INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 36s 441ms/step - loss: 0.2589 - root_mean_squared_error: 0.5089 - val_loss: 0.1916 - val_root_mean_squared_error: 0.4377
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1344 - root_mean_squared_error: 0.3667INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 14s 263ms/step - loss: 0.1344 - root_mean_squared_error: 0.3667 - val_loss: 0.0760 - val_root_mean_squared_error: 0.2757
# Epoch 3/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0700 - root_mean_squared_error: 0.2647INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 17s 329ms/step - loss: 0.0699 - root_mean_squared_error: 0.2644 - val_loss: 0.0485 - val_root_mean_squared_error: 0.2203
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0440 - root_mean_squared_error: 0.2099INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 21s 401ms/step - loss: 0.0439 - root_mean_squared_error: 0.2095 - val_loss: 0.0301 - val_root_mean_squared_error: 0.1735
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0308 - root_mean_squared_error: 0.1755INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 24s 460ms/step - loss: 0.0307 - root_mean_squared_error: 0.1751 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1486
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0267 - root_mean_squared_error: 0.1635INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 18s 348ms/step - loss: 0.0266 - root_mean_squared_error: 0.1632 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1399
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0226 - root_mean_squared_error: 0.1503INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 20s 387ms/step - loss: 0.0226 - root_mean_squared_error: 0.1503 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1307
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0198 - root_mean_squared_error: 0.1409INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 19s 371ms/step - loss: 0.0198 - root_mean_squared_error: 0.1409 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1194
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0172 - root_mean_squared_error: 0.1310INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 20s 381ms/step - loss: 0.0172 - root_mean_squared_error: 0.1310 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1109
# Epoch 10/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0163 - root_mean_squared_error: 0.1277 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1168
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0150 - root_mean_squared_error: 0.1223INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 19s 370ms/step - loss: 0.0149 - root_mean_squared_error: 0.1222 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1077
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0136 - root_mean_squared_error: 0.1166INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 21s 410ms/step - loss: 0.0136 - root_mean_squared_error: 0.1166 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0996
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0120 - root_mean_squared_error: 0.1096INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 22s 423ms/step - loss: 0.0121 - root_mean_squared_error: 0.1098 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0897
# Epoch 14/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0112 - root_mean_squared_error: 0.1061 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0915
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0107 - root_mean_squared_error: 0.1036INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 19s 370ms/step - loss: 0.0107 - root_mean_squared_error: 0.1036 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0833
# Epoch 16/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0105 - root_mean_squared_error: 0.1022 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0886
# Epoch 17/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0102 - root_mean_squared_error: 0.1008INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 19s 370ms/step - loss: 0.0102 - root_mean_squared_error: 0.1008 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0764
# Epoch 18/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0084 - root_mean_squared_error: 0.0918INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 20s 382ms/step - loss: 0.0084 - root_mean_squared_error: 0.0916 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0712
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0084 - root_mean_squared_error: 0.0916INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 22s 422ms/step - loss: 0.0084 - root_mean_squared_error: 0.0916 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0686
# Epoch 20/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0077 - root_mean_squared_error: 0.0879INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 20s 389ms/step - loss: 0.0077 - root_mean_squared_error: 0.0877 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0664
# Epoch 21/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0075 - root_mean_squared_error: 0.0865INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 21s 395ms/step - loss: 0.0075 - root_mean_squared_error: 0.0864 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0642
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0065 - root_mean_squared_error: 0.0803INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 21s 400ms/step - loss: 0.0065 - root_mean_squared_error: 0.0803 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0622
# Epoch 23/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0070 - root_mean_squared_error: 0.0835INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 21s 406ms/step - loss: 0.0070 - root_mean_squared_error: 0.0835 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0616
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0066 - root_mean_squared_error: 0.0813INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 19s 358ms/step - loss: 0.0066 - root_mean_squared_error: 0.0813 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0543
# Epoch 25/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0064 - root_mean_squared_error: 0.0798 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0581
# Epoch 26/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0057 - root_mean_squared_error: 0.0754INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 18s 353ms/step - loss: 0.0056 - root_mean_squared_error: 0.0751 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0518
# Epoch 27/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0063 - root_mean_squared_error: 0.0796INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 19s 369ms/step - loss: 0.0063 - root_mean_squared_error: 0.0796 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0494
# Epoch 28/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0048 - root_mean_squared_error: 0.0696 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0497
# Epoch 29/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0055 - root_mean_squared_error: 0.0743 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0628
# Epoch 30/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0050 - root_mean_squared_error: 0.0707 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0555
# Epoch 31/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0046 - root_mean_squared_error: 0.0675INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 19s 371ms/step - loss: 0.0046 - root_mean_squared_error: 0.0675 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0478
# Epoch 32/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0046 - root_mean_squared_error: 0.0678 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609
# Epoch 33/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0053 - root_mean_squared_error: 0.0728 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0509
# Epoch 34/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0046 - root_mean_squared_error: 0.0679INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 19s 362ms/step - loss: 0.0046 - root_mean_squared_error: 0.0679 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0449
# Epoch 35/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0052 - root_mean_squared_error: 0.0721 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0571
# Epoch 36/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0049 - root_mean_squared_error: 0.0697INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 23s 442ms/step - loss: 0.0048 - root_mean_squared_error: 0.0695 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0445
# Epoch 37/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0046 - root_mean_squared_error: 0.0678 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0683
# Epoch 38/50
# 53/53 [==============================] - 4s 77ms/step - loss: 0.0041 - root_mean_squared_error: 0.0637 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0563
# Epoch 39/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0044 - root_mean_squared_error: 0.0664 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0496
# Epoch 40/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0041 - root_mean_squared_error: 0.0639INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 20s 382ms/step - loss: 0.0041 - root_mean_squared_error: 0.0639 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0432
# Epoch 41/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0044 - root_mean_squared_error: 0.0661INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 19s 363ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0432
# Epoch 42/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0042 - root_mean_squared_error: 0.0645 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0476
# Epoch 43/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0041 - root_mean_squared_error: 0.0638 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0636
# Epoch 44/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0040 - root_mean_squared_error: 0.0636 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0495
# Epoch 45/50
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0039 - root_mean_squared_error: 0.0621 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0545
# Epoch 46/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.0042 - root_mean_squared_error: 0.0645 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0665
# Epoch 47/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0042 - root_mean_squared_error: 0.0650INFO:tensorflow:Assets written to: Indian_model_LT9\assets
# 53/53 [==============================] - 19s 357ms/step - loss: 0.0042 - root_mean_squared_error: 0.0650 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0425
# Epoch 48/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0039 - root_mean_squared_error: 0.0623 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0548
# Epoch 49/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0039 - root_mean_squared_error: 0.0626 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0593
# Epoch 50/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0035 - root_mean_squared_error: 0.0592 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0508

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 11.114407241344452 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Indian_model_LT9/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 16ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.04695779938146899
# MAE : 0.03907779648394741

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        3.664179e+05     522831.371
# 1        1.024833e+05     346601.304
# 2        1.340164e+05     444914.605
# 3        4.383095e+05     827036.916
# 4        1.096181e+06    1142021.216
# 5        1.767550e+06    1885693.654
# 6        2.498049e+06    2542569.663
# 7        3.110117e+06    3107373.845
# 8        3.422488e+06    3488175.444
# 9        3.500079e+06    3746306.528
# 10       3.209407e+06    2942322.822
# 11       1.532611e+06    1507212.955
# 12       5.289164e+05     648507.437
# 13       2.145861e+05     352564.010
# 14       2.337684e+05     453587.503
# 15       5.718298e+05     841043.793
# 16       1.259989e+06    1433155.266
# 17       1.925965e+06    2163687.646
# 18       2.649740e+06    2848863.133
# 19       3.207102e+06    3420877.229
# 20       3.492188e+06    3752886.938
# 21       3.570244e+06    3778951.818
# 22       3.093060e+06    2892177.223
# 23       1.327455e+06    1467610.428
# 24       4.763565e+05     377930.941
# 25       1.743854e+05     146440.376
# 26       2.393031e+05     244356.473
# 27       5.933460e+05     612217.566
# 28       1.271100e+06    1261627.075
# 29       1.932755e+06    1720565.225
# 30       2.658797e+06    2564005.541
# 31       3.256563e+06    2983773.529
# 32       3.588401e+06    3372645.223
# 33       3.615350e+06    3589687.043
# 34       2.604952e+06    2669385.189
# 35       9.402322e+05    1095398.946
# 36       2.453855e+05     319828.826
# 37       4.859892e+04     162541.182
# 38       1.157413e+05     179564.232
# 39       4.488845e+05     593196.107
# 40       1.114050e+06    1053508.835
# 41       1.797642e+06    1520776.003
# 42       2.521422e+06    2076164.165
# 43       3.110172e+06    2731799.027
# 44       3.442364e+06    3179384.692
# 45       3.493246e+06    3301335.210

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 25ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
