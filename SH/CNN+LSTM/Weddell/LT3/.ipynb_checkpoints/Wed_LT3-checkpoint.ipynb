# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Weddell_Extent = pd.read_excel(filepath, sheet_name='Weddell-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Weddell_Extent)
fp.date_time(Weddell_Extent)
# Out:
#           Extent       Date
# 0    2136510.859 1979-01-01
# 1    1243495.891 1979-02-01
# 2    1699053.449 1979-03-01
# 3    2617442.085 1979-04-01
# 4    3852934.206 1979-05-01
# ..           ...        ...
# 533  3668127.143 2023-06-01
# 534  4805519.784 2023-07-01
# 535  5524445.234 2023-08-01
# 536  6006669.861 2023-09-01
# 537  5507961.583 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Weddell_Extent['Extent'] = scaler.fit_transform(Weddell_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 3
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Weddell_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((524, 12, 1), (524,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Weddell_model_LT3/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.2837 - root_mean_squared_error: 0.5327
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 9s 107ms/step - loss: 0.2813 - root_mean_squared_error: 0.5304 - val_loss: 0.2732 - val_root_mean_squared_error: 0.5227
# Epoch 2/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.2206 - root_mean_squared_error: 0.4697
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 4s 77ms/step - loss: 0.2170 - root_mean_squared_error: 0.4658 - val_loss: 0.2260 - val_root_mean_squared_error: 0.4754
# Epoch 3/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.1734 - root_mean_squared_error: 0.4164
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.1740 - root_mean_squared_error: 0.4171 - val_loss: 0.1857 - val_root_mean_squared_error: 0.4310
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1370 - root_mean_squared_error: 0.3701
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 5s 88ms/step - loss: 0.1370 - root_mean_squared_error: 0.3701 - val_loss: 0.1507 - val_root_mean_squared_error: 0.3882
# Epoch 5/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1095 - root_mean_squared_error: 0.3308
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.1090 - root_mean_squared_error: 0.3301 - val_loss: 0.1208 - val_root_mean_squared_error: 0.3476
# Epoch 6/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0869 - root_mean_squared_error: 0.2949
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0875 - root_mean_squared_error: 0.2959 - val_loss: 0.0979 - val_root_mean_squared_error: 0.3129
# Epoch 7/50
# 43/53 [=======================>......] - ETA: 0s - loss: 0.0675 - root_mean_squared_error: 0.2598
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0674 - root_mean_squared_error: 0.2596 - val_loss: 0.0771 - val_root_mean_squared_error: 0.2776
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0499 - root_mean_squared_error: 0.2233
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0499 - root_mean_squared_error: 0.2233 - val_loss: 0.0601 - val_root_mean_squared_error: 0.2451
# Epoch 9/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0394 - root_mean_squared_error: 0.1985
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0385 - root_mean_squared_error: 0.1962 - val_loss: 0.0456 - val_root_mean_squared_error: 0.2134
# Epoch 10/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0277 - root_mean_squared_error: 0.1665
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0280 - root_mean_squared_error: 0.1674 - val_loss: 0.0343 - val_root_mean_squared_error: 0.1851
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0227 - root_mean_squared_error: 0.1506
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0226 - root_mean_squared_error: 0.1502 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1570
# Epoch 12/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0180 - root_mean_squared_error: 0.1341
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1314
# Epoch 13/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0196 - root_mean_squared_error: 0.1399
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0188 - root_mean_squared_error: 0.1372 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1072
# Epoch 14/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0180 - root_mean_squared_error: 0.1342
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0180 - root_mean_squared_error: 0.1342 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0927
# Epoch 15/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0150 - root_mean_squared_error: 0.1224
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0152 - root_mean_squared_error: 0.1231 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0842
# Epoch 16/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0145 - root_mean_squared_error: 0.1204
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0796
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0174 - root_mean_squared_error: 0.1319 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0911
# Epoch 18/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1200 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0815
# Epoch 19/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0135 - root_mean_squared_error: 0.1162
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0129 - root_mean_squared_error: 0.1136 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0725
# Epoch 20/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0779
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0129 - root_mean_squared_error: 0.1138 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0819
# Epoch 22/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0163 - root_mean_squared_error: 0.1277 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0733
# Epoch 23/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0129 - root_mean_squared_error: 0.1134 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0747
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0157 - root_mean_squared_error: 0.1254 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0764
# Epoch 25/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0133 - root_mean_squared_error: 0.1155 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0805
# Epoch 26/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0126 - root_mean_squared_error: 0.1124 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0813
# Epoch 27/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0132 - root_mean_squared_error: 0.1149
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0134 - root_mean_squared_error: 0.1158 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0712
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0121 - root_mean_squared_error: 0.1100 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0847
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0136 - root_mean_squared_error: 0.1166 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0723
# Epoch 30/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0137 - root_mean_squared_error: 0.1169 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0938
# Epoch 31/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0109 - root_mean_squared_error: 0.1043
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 4s 80ms/step - loss: 0.0106 - root_mean_squared_error: 0.1031 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 32/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0847
# Epoch 33/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0141 - root_mean_squared_error: 0.1188
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0668
# Epoch 34/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0150 - root_mean_squared_error: 0.1226 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0673
# Epoch 35/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0173 - root_mean_squared_error: 0.1315
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 5s 97ms/step - loss: 0.0172 - root_mean_squared_error: 0.1311 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0656
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0131 - root_mean_squared_error: 0.1144 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0760
# Epoch 37/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0115 - root_mean_squared_error: 0.1072
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0122 - root_mean_squared_error: 0.1106 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0648
# Epoch 38/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0127 - root_mean_squared_error: 0.1125 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0779
# Epoch 39/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0126 - root_mean_squared_error: 0.1120 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0653
# Epoch 40/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0161 - root_mean_squared_error: 0.1269 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0798
# Epoch 41/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0184 - root_mean_squared_error: 0.1358 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0715
# Epoch 42/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0136 - root_mean_squared_error: 0.1166 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0725
# Epoch 43/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0137 - root_mean_squared_error: 0.1170 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0666
# Epoch 44/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0682
# Epoch 45/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0149 - root_mean_squared_error: 0.1221
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT3\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0629
# Epoch 46/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0137 - root_mean_squared_error: 0.1170 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0688
# Epoch 47/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0105 - root_mean_squared_error: 0.1022 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0634
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0122 - root_mean_squared_error: 0.1106 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0943
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0128 - root_mean_squared_error: 0.1130 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0712
# Epoch 50/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0795

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.9859061400095621 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Weddell_model_LT3/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 15ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.05324367671623323
# MAE : 0.04286331501690664

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0         5314403.000    5882741.038
# 1         5706735.500    6574288.749
# 2         6599219.500    6669726.076
# 3         6514252.000    6516136.854
# 4         5726816.500    5902163.675
# 5         4029278.750    3498103.449
# 6         1652087.875    1633675.726
# 7         1096446.750    1292668.399
# 8         1428776.000    1527666.815
# 9         2085768.125    2121949.701
# 10        3401725.250    3562381.775
# 11        4743603.500    5004305.983
# 12        5571958.500    6176613.878
# 13        6469489.500    6794233.093
# 14        6652393.500    7024136.637
# 15        6750224.000    6554271.388
# 16        5641383.500    6172281.701
# 17        3978941.000    4175225.799
# 18        1417450.375    1748380.899
# 19        1111997.750    1256191.080
# 20        1252630.125    1347295.364
# 21        2100856.250    2180184.677
# 22        3270877.500    3419295.982
# 23        4849835.000    4786146.771
# 24        5640373.000    5968132.718
# 25        6377968.000    6556934.174
# 26        6645678.000    6614949.980
# 27        6653843.500    6035207.368
# 28        5671683.000    5274244.730
# 29        4030304.750    3505146.372
# 30        1718888.250    1478130.228
# 31        1234125.125    1096780.503
# 32        1439788.500    1387234.069
# 33        2470688.000    2128693.591
# 34        3552693.750    3313318.704
# 35        4853901.000    4218076.656
# 36        5570635.000    5257641.941
# 37        6155137.500    5956603.340
# 38        6157113.500    6256062.049
# 39        6201642.000    5974548.305
# 40        5380616.500    5569396.731
# 41        4030770.500    3684108.410
# 42        1878927.875    1451614.707
# 43        1257981.625    1089888.684
# 44        1546187.625    1255222.909
# 45        2169680.750    1704492.279
# 46        3270785.000    2563551.804
# 47        4527412.000    3668127.143
# 48        5245801.000    4805519.784
# 49        5677785.000    5524445.234
# 50        6037121.000    6006669.861
# 51        6027285.000    5507961.583

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
