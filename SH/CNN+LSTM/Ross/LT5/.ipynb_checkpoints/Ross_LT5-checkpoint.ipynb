# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Ross_Extent = pd.read_excel(filepath, sheet_name='Ross-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Ross_Extent)
fp.date_time(Ross_Extent)
# Out:
#           Extent       Date
# 0    1040455.516 1979-01-01
# 1     239334.118 1979-02-01
# 2     557365.154 1979-03-01
# 3    2054855.924 1979-04-01
# 4    2973925.625 1979-05-01
# ..           ...        ...
# 533  3137598.938 2023-06-01
# 534  3201783.453 2023-07-01
# 535  2973294.266 2023-08-01
# 536  3354839.711 2023-09-01
# 537  3325613.245 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Ross_Extent['Extent'] = scaler.fit_transform(Ross_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 5
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Ross_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((522, 12, 1), (522,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Ross_model_LT5/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.4294 - root_mean_squared_error: 0.6553
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 7s 92ms/step - loss: 0.4245 - root_mean_squared_error: 0.6515 - val_loss: 0.3123 - val_root_mean_squared_error: 0.5588
# Epoch 2/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.3191 - root_mean_squared_error: 0.5649
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.3183 - root_mean_squared_error: 0.5642 - val_loss: 0.2808 - val_root_mean_squared_error: 0.5299
# Epoch 3/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.2716 - root_mean_squared_error: 0.5212
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 4s 72ms/step - loss: 0.2670 - root_mean_squared_error: 0.5167 - val_loss: 0.2426 - val_root_mean_squared_error: 0.4926
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2267 - root_mean_squared_error: 0.4761
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 4s 74ms/step - loss: 0.2267 - root_mean_squared_error: 0.4761 - val_loss: 0.2134 - val_root_mean_squared_error: 0.4620
# Epoch 5/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.1964 - root_mean_squared_error: 0.4432
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 3s 66ms/step - loss: 0.1923 - root_mean_squared_error: 0.4385 - val_loss: 0.1825 - val_root_mean_squared_error: 0.4272
# Epoch 6/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.1681 - root_mean_squared_error: 0.4100
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 3s 67ms/step - loss: 0.1596 - root_mean_squared_error: 0.3995 - val_loss: 0.1576 - val_root_mean_squared_error: 0.3970
# Epoch 7/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1303 - root_mean_squared_error: 0.3610
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 4s 75ms/step - loss: 0.1300 - root_mean_squared_error: 0.3606 - val_loss: 0.1362 - val_root_mean_squared_error: 0.3691
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1033 - root_mean_squared_error: 0.3214
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.1033 - root_mean_squared_error: 0.3214 - val_loss: 0.1219 - val_root_mean_squared_error: 0.3491
# Epoch 9/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0882 - root_mean_squared_error: 0.2970
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0859 - root_mean_squared_error: 0.2931 - val_loss: 0.0919 - val_root_mean_squared_error: 0.3032
# Epoch 10/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0680 - root_mean_squared_error: 0.2607
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0678 - root_mean_squared_error: 0.2605 - val_loss: 0.0740 - val_root_mean_squared_error: 0.2720
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0503 - root_mean_squared_error: 0.2242
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0506 - root_mean_squared_error: 0.2249 - val_loss: 0.0648 - val_root_mean_squared_error: 0.2545
# Epoch 12/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0405 - root_mean_squared_error: 0.2012
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0383 - root_mean_squared_error: 0.1956 - val_loss: 0.0490 - val_root_mean_squared_error: 0.2213
# Epoch 13/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0329 - root_mean_squared_error: 0.1814
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0304 - root_mean_squared_error: 0.1744 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1700
# Epoch 14/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0223 - root_mean_squared_error: 0.1494
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0231 - root_mean_squared_error: 0.1520 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1374
# Epoch 15/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0190 - root_mean_squared_error: 0.1380
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0187 - root_mean_squared_error: 0.1369 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1264
# Epoch 16/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0159 - root_mean_squared_error: 0.1262
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0160 - root_mean_squared_error: 0.1266 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1131
# Epoch 17/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0147 - root_mean_squared_error: 0.1213
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0163 - root_mean_squared_error: 0.1276 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1027
# Epoch 18/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0153 - root_mean_squared_error: 0.1237
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0163 - root_mean_squared_error: 0.1278 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0945
# Epoch 19/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0110 - root_mean_squared_error: 0.1047
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0104 - root_mean_squared_error: 0.1022 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0940
# Epoch 20/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0129 - root_mean_squared_error: 0.1134
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0128 - root_mean_squared_error: 0.1132 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0889
# Epoch 21/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0122 - root_mean_squared_error: 0.1106 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0926
# Epoch 22/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0122 - root_mean_squared_error: 0.1106
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0130 - root_mean_squared_error: 0.1140 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 23/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0134 - root_mean_squared_error: 0.1158 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0975
# Epoch 24/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0113 - root_mean_squared_error: 0.1065 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0922
# Epoch 25/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0126 - root_mean_squared_error: 0.1123 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0958
# Epoch 26/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190 - val_loss: 0.0353 - val_root_mean_squared_error: 0.1878
# Epoch 27/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0112 - root_mean_squared_error: 0.1060 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1204
# Epoch 28/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0937
# Epoch 29/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0129 - root_mean_squared_error: 0.1135 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1018
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0128 - root_mean_squared_error: 0.1130 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0926
# Epoch 31/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0108 - root_mean_squared_error: 0.1041 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1110
# Epoch 32/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0124 - root_mean_squared_error: 0.1114 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0929
# Epoch 33/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0128 - root_mean_squared_error: 0.1133 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1231
# Epoch 34/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0095 - root_mean_squared_error: 0.0973 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0873
# Epoch 35/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0120 - root_mean_squared_error: 0.1097 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0951
# Epoch 36/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0140 - root_mean_squared_error: 0.1184 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1601
# Epoch 37/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0102 - root_mean_squared_error: 0.1009 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0902
# Epoch 38/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0100 - root_mean_squared_error: 0.1000 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0898
# Epoch 39/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0165 - root_mean_squared_error: 0.1286 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0936
# Epoch 40/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0931
# Epoch 41/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0096 - root_mean_squared_error: 0.0981 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1151
# Epoch 42/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0113 - root_mean_squared_error: 0.1064 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0973
# Epoch 43/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0108 - root_mean_squared_error: 0.1039 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0944
# Epoch 44/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0112 - root_mean_squared_error: 0.1061 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1347
# Epoch 45/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0887
# Epoch 46/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0107 - root_mean_squared_error: 0.1033 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0899
# Epoch 47/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0117 - root_mean_squared_error: 0.1081 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1030
# Epoch 48/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0137 - root_mean_squared_error: 0.1170 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1000
# Epoch 49/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0115 - root_mean_squared_error: 0.1074 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1177
# Epoch 50/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0077 - root_mean_squared_error: 0.0878 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0884

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.4851675987243653 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Ross_model_LT5/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 5ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.08856777555313299
# MAE : 0.07067709189382552

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        4.027596e+06    3885746.442
# 1        3.785100e+06    3909211.179
# 2        3.413256e+06    3499167.351
# 3        2.170044e+06    2715890.297
# 4        1.264885e+06    1053272.694
# 5        3.968892e+05     368862.123
# 6        1.122593e+06     979418.298
# 7        1.830797e+06    2086269.569
# 8        2.619525e+06    2852731.016
# 9        3.110103e+06    3452823.613
# 10       3.166534e+06    3846843.974
# 11       3.620892e+06    4005222.451
# 12       3.980858e+06    4129684.505
# 13       3.816660e+06    4130311.577
# 14       3.323243e+06    3987590.376
# 15       2.232642e+06    2531664.630
# 16       1.257098e+06     864796.598
# 17       6.057649e+05     366098.623
# 18       9.904319e+05    1324063.884
# 19       1.849219e+06    2094086.684
# 20       2.651612e+06    2706708.526
# 21       3.134062e+06    3380172.167
# 22       3.561124e+06    3975727.475
# 23       3.738591e+06    4016497.161
# 24       4.343506e+06    4134594.766
# 25       3.889091e+06    4278165.933
# 26       3.343316e+06    3893945.909
# 27       2.249209e+06    2389171.083
# 28       1.295405e+06     896425.932
# 29       3.775927e+05     251374.224
# 30       1.054097e+06     455056.048
# 31       1.867827e+06    1780625.872
# 32       2.773364e+06    2914989.101
# 33       3.120872e+06    3561620.245
# 34       3.695260e+06    3991717.506
# 35       3.671005e+06    4559070.778
# 36       4.131006e+06    4596327.081
# 37       4.059510e+06    4565650.139
# 38       3.708362e+06    4061902.846
# 39       2.386507e+06    2336900.967
# 40       1.112903e+06     696917.659
# 41       3.116889e+05     213657.789
# 42       7.475620e+05     765773.883
# 43       1.765088e+06    1951730.202
# 44       2.603083e+06    2610971.814
# 45       3.144734e+06    3137598.938
# 46       3.816474e+06    3201783.453
# 47       3.837683e+06    2973294.266
# 48       4.539245e+06    3354839.711
# 49       4.052454e+06    3325613.245

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 2ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
