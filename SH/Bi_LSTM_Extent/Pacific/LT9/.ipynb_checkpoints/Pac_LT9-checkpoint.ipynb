# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Pacific_Extent = pd.read_excel(filepath, sheet_name='Pacific-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Pacific_Extent)
fp.date_time(Pacific_Extent)
# Out:
#           Extent       Date
# 0     668714.275 1979-01-01
# 1     566930.458 1979-02-01
# 2     688420.115 1979-03-01
# 3     859963.043 1979-04-01
# 4    1127120.160 1979-05-01
# ..           ...        ...
# 533  1134056.102 2023-06-01
# 534  1484824.377 2023-07-01
# 535  1671324.717 2023-08-01
# 536  1726376.097 2023-09-01
# 537  1690631.996 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Pacific_Extent['Extent'] = scaler.fit_transform(Pacific_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 9
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Pacific_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((518, 12, 1), (518,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Pacific_model_LT9/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.2015 - root_mean_squared_error: 0.4489INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 38s 520ms/step - loss: 0.2011 - root_mean_squared_error: 0.4484 - val_loss: 0.1224 - val_root_mean_squared_error: 0.3499
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0636 - root_mean_squared_error: 0.2521INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 25s 487ms/step - loss: 0.0636 - root_mean_squared_error: 0.2521 - val_loss: 0.0504 - val_root_mean_squared_error: 0.2245
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0471 - root_mean_squared_error: 0.2169INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 24s 469ms/step - loss: 0.0469 - root_mean_squared_error: 0.2166 - val_loss: 0.0395 - val_root_mean_squared_error: 0.1986
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0346 - root_mean_squared_error: 0.1861INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 25s 480ms/step - loss: 0.0346 - root_mean_squared_error: 0.1861 - val_loss: 0.0285 - val_root_mean_squared_error: 0.1687
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0254 - root_mean_squared_error: 0.1595INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 26s 496ms/step - loss: 0.0254 - root_mean_squared_error: 0.1595 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1345
# Epoch 6/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0203 - root_mean_squared_error: 0.1425 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1536
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0201 - root_mean_squared_error: 0.1418INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 27s 527ms/step - loss: 0.0201 - root_mean_squared_error: 0.1418 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0165 - root_mean_squared_error: 0.1285INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 27s 519ms/step - loss: 0.0165 - root_mean_squared_error: 0.1285 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1066
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0161 - root_mean_squared_error: 0.1270INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 27s 520ms/step - loss: 0.0161 - root_mean_squared_error: 0.1270 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1010
# Epoch 10/50
# 53/53 [==============================] - 4s 77ms/step - loss: 0.0139 - root_mean_squared_error: 0.1177 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1124
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0133 - root_mean_squared_error: 0.1153INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 27s 510ms/step - loss: 0.0133 - root_mean_squared_error: 0.1153 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0968
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0115 - root_mean_squared_error: 0.1074INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 27s 511ms/step - loss: 0.0115 - root_mean_squared_error: 0.1074 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0956
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0124 - root_mean_squared_error: 0.1113INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 26s 507ms/step - loss: 0.0124 - root_mean_squared_error: 0.1113 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0881
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0112 - root_mean_squared_error: 0.1058INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 27s 519ms/step - loss: 0.0112 - root_mean_squared_error: 0.1058 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0827
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0110 - root_mean_squared_error: 0.1047INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 26s 506ms/step - loss: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0797
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0095 - root_mean_squared_error: 0.0975INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 27s 520ms/step - loss: 0.0095 - root_mean_squared_error: 0.0975 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0789
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0094 - root_mean_squared_error: 0.0970INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 26s 507ms/step - loss: 0.0094 - root_mean_squared_error: 0.0970 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0763
# Epoch 18/50
# 53/53 [==============================] - 4s 75ms/step - loss: 0.0095 - root_mean_squared_error: 0.0976 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0771
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0090 - root_mean_squared_error: 0.0948INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 26s 507ms/step - loss: 0.0090 - root_mean_squared_error: 0.0948 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0747
# Epoch 20/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0085 - root_mean_squared_error: 0.0923 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0756
# Epoch 21/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0083 - root_mean_squared_error: 0.0912 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0815
# Epoch 22/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0087 - root_mean_squared_error: 0.0934 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0794
# Epoch 23/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0080 - root_mean_squared_error: 0.0895INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 26s 503ms/step - loss: 0.0080 - root_mean_squared_error: 0.0895 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0720
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0081 - root_mean_squared_error: 0.0898INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 26s 499ms/step - loss: 0.0081 - root_mean_squared_error: 0.0898 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0702
# Epoch 25/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0076 - root_mean_squared_error: 0.0873 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0711
# Epoch 26/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0077 - root_mean_squared_error: 0.0880INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 26s 501ms/step - loss: 0.0077 - root_mean_squared_error: 0.0880 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 27/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0077 - root_mean_squared_error: 0.0876 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0768
# Epoch 28/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0075 - root_mean_squared_error: 0.0865 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0703
# Epoch 29/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0075 - root_mean_squared_error: 0.0864 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 30/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0071 - root_mean_squared_error: 0.0843 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0697
# Epoch 31/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0072 - root_mean_squared_error: 0.0847 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0759
# Epoch 32/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0074 - root_mean_squared_error: 0.0861INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 26s 497ms/step - loss: 0.0074 - root_mean_squared_error: 0.0861 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0667
# Epoch 33/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0076 - root_mean_squared_error: 0.0870 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0746
# Epoch 34/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0071 - root_mean_squared_error: 0.0844 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0731
# Epoch 35/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0072 - root_mean_squared_error: 0.0846INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 26s 498ms/step - loss: 0.0072 - root_mean_squared_error: 0.0846 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0666
# Epoch 36/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0071 - root_mean_squared_error: 0.0840 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0724
# Epoch 37/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0065 - root_mean_squared_error: 0.0805 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0680
# Epoch 38/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0070 - root_mean_squared_error: 0.0834 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0690
# Epoch 39/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0071 - root_mean_squared_error: 0.0843 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0685
# Epoch 40/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0071 - root_mean_squared_error: 0.0841 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0674
# Epoch 41/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0064 - root_mean_squared_error: 0.0799 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0756
# Epoch 42/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0065 - root_mean_squared_error: 0.0808INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 26s 505ms/step - loss: 0.0065 - root_mean_squared_error: 0.0808 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0644
# Epoch 43/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0068 - root_mean_squared_error: 0.0823 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0720
# Epoch 44/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0068 - root_mean_squared_error: 0.0826 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0673
# Epoch 45/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0061 - root_mean_squared_error: 0.0782 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0701
# Epoch 46/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0072 - root_mean_squared_error: 0.0847 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0664
# Epoch 47/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0065 - root_mean_squared_error: 0.0804 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0647
# Epoch 48/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0065 - root_mean_squared_error: 0.0808 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0722
# Epoch 49/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0067 - root_mean_squared_error: 0.0820 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0652
# Epoch 50/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0065 - root_mean_squared_error: 0.0806INFO:tensorflow:Assets written to: Pacific_model_LT9\assets
# 53/53 [==============================] - 27s 509ms/step - loss: 0.0065 - root_mean_squared_error: 0.0806 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0639

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 11.994781426588695 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Pacific_model_LT9/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 19ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.05893143511959822
# MAE : 0.04777522620257518

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        5.120447e+05     635624.004
# 1        3.821388e+05     460009.672
# 2        4.973116e+05     610848.036
# 3        8.543534e+05     819257.445
# 4        1.192909e+06    1129627.707
# 5        1.461447e+06    1463383.236
# 6        1.733140e+06    1614536.727
# 7        1.908452e+06    1862498.612
# 8        1.949378e+06    2099349.296
# 9        1.863010e+06    1981614.046
# 10       1.529070e+06    1433022.369
# 11       9.713356e+05     826739.716
# 12       5.851222e+05     477145.887
# 13       4.014211e+05     314469.289
# 14       4.656930e+05     463134.749
# 15       7.854255e+05     946522.292
# 16       1.168641e+06    1309266.570
# 17       1.458236e+06    1507947.309
# 18       1.732880e+06    1804167.937
# 19       1.911272e+06    1908002.139
# 20       1.941086e+06    1892748.521
# 21       1.819471e+06    1601079.640
# 22       1.381217e+06    1327804.521
# 23       8.745119e+05     812074.231
# 24       5.407289e+05     493355.897
# 25       4.175465e+05     317229.330
# 26       5.287751e+05     425777.624
# 27       8.795605e+05     827172.620
# 28       1.216409e+06    1162367.223
# 29       1.468278e+06    1413734.261
# 30       1.709139e+06    1574257.849
# 31       1.893999e+06    1786961.251
# 32       1.921695e+06    1857942.866
# 33       1.773597e+06    1406291.588
# 34       1.259013e+06    1025555.371
# 35       7.001535e+05     632862.782
# 36       4.246299e+05     308194.756
# 37       3.414808e+05     194921.078
# 38       4.745476e+05     245569.900
# 39       8.417143e+05     533532.424
# 40       1.189833e+06     943124.529
# 41       1.427943e+06    1134056.102
# 42       1.623402e+06    1484824.377
# 43       1.775181e+06    1671324.717
# 44       1.794998e+06    1726376.097
# 45       1.678599e+06    1690631.996

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 31ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
