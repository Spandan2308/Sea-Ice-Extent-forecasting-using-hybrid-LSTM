# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bell_Amundsen_Extent = pd.read_excel(filepath, sheet_name='Bell-Amundsen-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Bell_Amundsen_Extent)
fp.date_time(Bell_Amundsen_Extent)
# Out:
#           Extent       Date
# 0    1179855.894 1979-01-01
# 1     879585.254 1979-02-01
# 2     791619.096 1979-03-01
# 3    1254912.071 1979-04-01
# 4    1620142.247 1979-05-01
# ..           ...        ...
# 533  1556568.455 2023-06-01
# 534  1917507.979 2023-07-01
# 535  2601630.327 2023-08-01
# 536  2534223.780 2023-09-01
# 537  2373004.525 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bell_Amundsen_Extent['Extent'] = scaler.fit_transform(Bell_Amundsen_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 7
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bell_Amundsen_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((520, 12, 1), (520,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Bell_Amund_model_LT7/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2390 - root_mean_squared_error: 0.4889
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 8s 102ms/step - loss: 0.2390 - root_mean_squared_error: 0.4889 - val_loss: 0.2470 - val_root_mean_squared_error: 0.4970
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1856 - root_mean_squared_error: 0.4308
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.1856 - root_mean_squared_error: 0.4308 - val_loss: 0.2119 - val_root_mean_squared_error: 0.4603
# Epoch 3/50
# 41/53 [======================>.......] - ETA: 0s - loss: 0.1504 - root_mean_squared_error: 0.3878
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.1486 - root_mean_squared_error: 0.3855 - val_loss: 0.1852 - val_root_mean_squared_error: 0.4303
# Epoch 4/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1156 - root_mean_squared_error: 0.3400
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 4s 75ms/step - loss: 0.1180 - root_mean_squared_error: 0.3435 - val_loss: 0.1570 - val_root_mean_squared_error: 0.3963
# Epoch 5/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0907 - root_mean_squared_error: 0.3012
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0897 - root_mean_squared_error: 0.2995 - val_loss: 0.1350 - val_root_mean_squared_error: 0.3674
# Epoch 6/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0728 - root_mean_squared_error: 0.2698
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0717 - root_mean_squared_error: 0.2677 - val_loss: 0.1088 - val_root_mean_squared_error: 0.3299
# Epoch 7/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0532 - root_mean_squared_error: 0.2307
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0528 - root_mean_squared_error: 0.2299 - val_loss: 0.0953 - val_root_mean_squared_error: 0.3087
# Epoch 8/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0414 - root_mean_squared_error: 0.2034
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.0399 - root_mean_squared_error: 0.1998 - val_loss: 0.0767 - val_root_mean_squared_error: 0.2769
# Epoch 9/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0278 - root_mean_squared_error: 0.1667
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0280 - root_mean_squared_error: 0.1673 - val_loss: 0.0548 - val_root_mean_squared_error: 0.2341
# Epoch 10/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0230 - root_mean_squared_error: 0.1516
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0251 - root_mean_squared_error: 0.1583 - val_loss: 0.0484 - val_root_mean_squared_error: 0.2200
# Epoch 11/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0194 - root_mean_squared_error: 0.1392
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0215 - root_mean_squared_error: 0.1467 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2019
# Epoch 12/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0156 - root_mean_squared_error: 0.1250
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0153 - root_mean_squared_error: 0.1236 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1513
# Epoch 13/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0141 - root_mean_squared_error: 0.1185
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1355
# Epoch 14/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0114 - root_mean_squared_error: 0.1068
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 4s 81ms/step - loss: 0.0122 - root_mean_squared_error: 0.1105 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1262
# Epoch 15/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0133 - root_mean_squared_error: 0.1154
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.0129 - root_mean_squared_error: 0.1138 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1106
# Epoch 16/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0114 - root_mean_squared_error: 0.1067
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1101
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0101 - root_mean_squared_error: 0.1003 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1389
# Epoch 18/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0112 - root_mean_squared_error: 0.1057 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1106
# Epoch 19/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0117 - root_mean_squared_error: 0.1080
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0119 - root_mean_squared_error: 0.1092 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1096
# Epoch 20/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0122 - root_mean_squared_error: 0.1105 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1121
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0111 - root_mean_squared_error: 0.1052 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1144
# Epoch 22/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0147 - root_mean_squared_error: 0.1212
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1060
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0102 - root_mean_squared_error: 0.1011 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1239
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1209
# Epoch 25/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0107 - root_mean_squared_error: 0.1034 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1066
# Epoch 26/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0127 - root_mean_squared_error: 0.1129
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 4s 81ms/step - loss: 0.0127 - root_mean_squared_error: 0.1125 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1039
# Epoch 27/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0137 - root_mean_squared_error: 0.1171 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1063
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0106 - root_mean_squared_error: 0.1032 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1058
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0122 - root_mean_squared_error: 0.1106 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1202
# Epoch 30/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0141 - root_mean_squared_error: 0.1190
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 4s 81ms/step - loss: 0.0136 - root_mean_squared_error: 0.1167 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1035
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1063
# Epoch 32/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0102 - root_mean_squared_error: 0.1012 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1169
# Epoch 33/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0095 - root_mean_squared_error: 0.0977
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0107 - root_mean_squared_error: 0.1034 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1032
# Epoch 34/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0118 - root_mean_squared_error: 0.1088 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1079
# Epoch 35/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0127 - root_mean_squared_error: 0.1126 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1206
# Epoch 36/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0120 - root_mean_squared_error: 0.1097 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1248
# Epoch 37/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0113 - root_mean_squared_error: 0.1063 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1123
# Epoch 38/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0085 - root_mean_squared_error: 0.0923 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1226
# Epoch 39/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0113 - root_mean_squared_error: 0.1062 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1171
# Epoch 40/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0121 - root_mean_squared_error: 0.1101 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1037
# Epoch 41/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0110 - root_mean_squared_error: 0.1049
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0110 - root_mean_squared_error: 0.1051 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1014
# Epoch 42/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0107 - root_mean_squared_error: 0.1034 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1144
# Epoch 43/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0108 - root_mean_squared_error: 0.1041 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1047
# Epoch 44/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0108 - root_mean_squared_error: 0.1038 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1055
# Epoch 45/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0123 - root_mean_squared_error: 0.1107 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1187
# Epoch 46/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0094 - root_mean_squared_error: 0.0969 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1228
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0125 - root_mean_squared_error: 0.1119 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1043
# Epoch 48/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1027
# Epoch 49/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0134 - root_mean_squared_error: 0.1158 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1158
# Epoch 50/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1303

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.8705668012301127 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bell_Amund_model_LT7/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 0s/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.08693812890606142
# MAE : 0.06863993841690418

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.781021e+06    1802244.842
# 1        1.246022e+06    1202791.069
# 2        8.142784e+05     752834.272
# 3        5.565720e+05     451914.219
# 4        4.900104e+05     439855.813
# 5        7.588829e+05     807857.307
# 6        1.061080e+06    1184280.145
# 7        1.386657e+06    1468308.405
# 8        1.832634e+06    1540851.607
# 9        1.963104e+06    1989099.836
# 10       2.040515e+06    2096990.761
# 11       1.957672e+06    2080961.032
# 12       1.642637e+06    1695704.661
# 13       1.137043e+06    1533888.370
# 14       7.810992e+05    1038332.675
# 15       5.465911e+05     602954.621
# 16       4.908195e+05     895484.288
# 17       6.344965e+05    1070622.700
# 18       1.011882e+06    1532457.922
# 19       1.515126e+06    1703762.123
# 20       1.776551e+06    1855079.122
# 21       1.888555e+06    2291960.639
# 22       1.963936e+06    2114120.417
# 23       1.729396e+06    1995818.759
# 24       1.414630e+06    1653379.997
# 25       1.070296e+06    1070814.995
# 26       8.069113e+05     689443.815
# 27       7.643778e+05     401148.663
# 28       5.791596e+05     346558.057
# 29       7.798975e+05     599477.678
# 30       1.140536e+06     765764.905
# 31       1.384243e+06    1304133.179
# 32       1.847448e+06    1598436.099
# 33       1.963208e+06    1763844.414
# 34       2.105452e+06    1979139.524
# 35       1.988207e+06    1937348.663
# 36       1.804511e+06    1833093.342
# 37       1.350844e+06    1089676.114
# 38       8.016554e+05     453484.731
# 39       4.164833e+05     251559.554
# 40       4.017513e+05     351294.657
# 41       6.646390e+05     702389.714
# 42       8.995988e+05    1185169.054
# 43       1.536688e+06    1556568.455
# 44       1.740370e+06    1917507.979
# 45       2.078109e+06    2601630.327
# 46       2.062320e+06    2534223.780
# 47       1.994708e+06    2373004.525

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
