# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Ross_Extent = pd.read_excel(filepath, sheet_name='Ross-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Ross_Extent)
fp.date_time(Ross_Extent)
# Out:
#           Extent       Date
# 0    1040455.516 1979-01-01
# 1     239334.118 1979-02-01
# 2     557365.154 1979-03-01
# 3    2054855.924 1979-04-01
# 4    2973925.625 1979-05-01
# ..           ...        ...
# 533  3137598.938 2023-06-01
# 534  3201783.453 2023-07-01
# 535  2973294.266 2023-08-01
# 536  3354839.711 2023-09-01
# 537  3325613.245 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Ross_Extent['Extent'] = scaler.fit_transform(Ross_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 8
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Ross_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((519, 12, 1), (519,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Ross_model_LT8/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.3160 - root_mean_squared_error: 0.5621INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 25s 324ms/step - loss: 0.3157 - root_mean_squared_error: 0.5619 - val_loss: 0.1763 - val_root_mean_squared_error: 0.4199
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0862 - root_mean_squared_error: 0.2935INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 16s 305ms/step - loss: 0.0862 - root_mean_squared_error: 0.2935 - val_loss: 0.0708 - val_root_mean_squared_error: 0.2661
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0570 - root_mean_squared_error: 0.2388INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 16s 302ms/step - loss: 0.0570 - root_mean_squared_error: 0.2388 - val_loss: 0.0644 - val_root_mean_squared_error: 0.2537
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0494 - root_mean_squared_error: 0.2223INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 16s 315ms/step - loss: 0.0495 - root_mean_squared_error: 0.2224 - val_loss: 0.0565 - val_root_mean_squared_error: 0.2377
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0426 - root_mean_squared_error: 0.2065INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 17s 329ms/step - loss: 0.0423 - root_mean_squared_error: 0.2056 - val_loss: 0.0475 - val_root_mean_squared_error: 0.2180
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0336 - root_mean_squared_error: 0.1833INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 18s 344ms/step - loss: 0.0336 - root_mean_squared_error: 0.1833 - val_loss: 0.0375 - val_root_mean_squared_error: 0.1935
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0282 - root_mean_squared_error: 0.1679INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 17s 317ms/step - loss: 0.0281 - root_mean_squared_error: 0.1676 - val_loss: 0.0328 - val_root_mean_squared_error: 0.1810
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0231 - root_mean_squared_error: 0.1519INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 17s 326ms/step - loss: 0.0231 - root_mean_squared_error: 0.1519 - val_loss: 0.0260 - val_root_mean_squared_error: 0.1613
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0201 - root_mean_squared_error: 0.1419INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 18s 343ms/step - loss: 0.0201 - root_mean_squared_error: 0.1419 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1531
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0200 - root_mean_squared_error: 0.1414INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 18s 345ms/step - loss: 0.0200 - root_mean_squared_error: 0.1414 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1437
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0182 - root_mean_squared_error: 0.1348INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 19s 355ms/step - loss: 0.0182 - root_mean_squared_error: 0.1348 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1378
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0167 - root_mean_squared_error: 0.1294INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 18s 342ms/step - loss: 0.0167 - root_mean_squared_error: 0.1291 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1309
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0148 - root_mean_squared_error: 0.1215INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 18s 345ms/step - loss: 0.0148 - root_mean_squared_error: 0.1215 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1249
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0133 - root_mean_squared_error: 0.1153INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 19s 367ms/step - loss: 0.0133 - root_mean_squared_error: 0.1153 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1159
# Epoch 15/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0121 - root_mean_squared_error: 0.1099INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 17s 329ms/step - loss: 0.0120 - root_mean_squared_error: 0.1095 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1110
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0114 - root_mean_squared_error: 0.1066INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 19s 364ms/step - loss: 0.0114 - root_mean_squared_error: 0.1066 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1104
# Epoch 17/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0114 - root_mean_squared_error: 0.1070 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1106
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0100 - root_mean_squared_error: 0.1000INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 17s 332ms/step - loss: 0.0100 - root_mean_squared_error: 0.1000 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0927
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0091 - root_mean_squared_error: 0.0952INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 19s 361ms/step - loss: 0.0091 - root_mean_squared_error: 0.0952 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0863
# Epoch 20/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0085 - root_mean_squared_error: 0.0923INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 18s 344ms/step - loss: 0.0085 - root_mean_squared_error: 0.0923 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0801
# Epoch 21/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0083 - root_mean_squared_error: 0.0911INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 18s 348ms/step - loss: 0.0083 - root_mean_squared_error: 0.0911 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0791
# Epoch 22/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0069 - root_mean_squared_error: 0.0831INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 18s 352ms/step - loss: 0.0069 - root_mean_squared_error: 0.0831 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0727
# Epoch 23/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0065 - root_mean_squared_error: 0.0807 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0763
# Epoch 24/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.0069 - root_mean_squared_error: 0.0828 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 25/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0064 - root_mean_squared_error: 0.0798 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0850
# Epoch 26/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0061 - root_mean_squared_error: 0.0783INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 18s 340ms/step - loss: 0.0062 - root_mean_squared_error: 0.0785 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0688
# Epoch 27/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0061 - root_mean_squared_error: 0.0783 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0757
# Epoch 28/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0057 - root_mean_squared_error: 0.0753 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0715
# Epoch 29/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0056 - root_mean_squared_error: 0.0748 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0714
# Epoch 30/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0058 - root_mean_squared_error: 0.0759 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0717
# Epoch 31/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0057 - root_mean_squared_error: 0.0753 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0715
# Epoch 32/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0057 - root_mean_squared_error: 0.0756 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0774
# Epoch 33/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0060 - root_mean_squared_error: 0.0777INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 17s 335ms/step - loss: 0.0060 - root_mean_squared_error: 0.0775 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0672
# Epoch 34/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0052 - root_mean_squared_error: 0.0718INFO:tensorflow:Assets written to: Ross_model_LT8\assets
# 53/53 [==============================] - 18s 352ms/step - loss: 0.0052 - root_mean_squared_error: 0.0718 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0669
# Epoch 35/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0053 - root_mean_squared_error: 0.0730 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0707
# Epoch 36/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0058 - root_mean_squared_error: 0.0763 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0774
# Epoch 37/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0051 - root_mean_squared_error: 0.0717 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0738
# Epoch 38/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0058 - root_mean_squared_error: 0.0764 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0819
# Epoch 39/50
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0052 - root_mean_squared_error: 0.0720 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0793
# Epoch 40/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0058 - root_mean_squared_error: 0.0762 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0721
# Epoch 41/50
# 53/53 [==============================] - 2s 46ms/step - loss: 0.0053 - root_mean_squared_error: 0.0729 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0686
# Epoch 42/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0051 - root_mean_squared_error: 0.0717 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0768
# Epoch 43/50
# 53/53 [==============================] - 2s 45ms/step - loss: 0.0050 - root_mean_squared_error: 0.0709 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0770
# Epoch 44/50
# 53/53 [==============================] - 3s 47ms/step - loss: 0.0055 - root_mean_squared_error: 0.0739 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0844
# Epoch 45/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0053 - root_mean_squared_error: 0.0730 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0754
# Epoch 46/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0054 - root_mean_squared_error: 0.0733 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0706
# Epoch 47/50
# 53/53 [==============================] - 2s 47ms/step - loss: 0.0050 - root_mean_squared_error: 0.0708 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0735
# Epoch 48/50
# 53/53 [==============================] - 2s 45ms/step - loss: 0.0054 - root_mean_squared_error: 0.0735 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0726
# Epoch 49/50
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0051 - root_mean_squared_error: 0.0715 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0675
# Epoch 50/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0054 - root_mean_squared_error: 0.0732 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0692

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 8.420658683776855 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Ross_model_LT8/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 21ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.08885486843993914
# MAE : 0.06025720802821963

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        2.542506e+06    2715890.297
# 1        9.946468e+05    1053272.694
# 2        1.319448e+05     368862.123
# 3        6.553039e+05     979418.298
# 4        1.792754e+06    2086269.569
# 5        2.666675e+06    2852731.016
# 6        3.289094e+06    3452823.613
# 7        3.694902e+06    3846843.974
# 8        3.906370e+06    4005222.451
# 9        3.983348e+06    4129684.505
# 10       3.922949e+06    4130311.577
# 11       3.579538e+06    3987590.376
# 12       2.537680e+06    2531664.630
# 13       1.057699e+06     864796.598
# 14       3.082543e+05     366098.623
# 15       9.506801e+05    1324063.884
# 16       2.007673e+06    2094086.684
# 17       2.833444e+06    2706708.526
# 18       3.436060e+06    3380172.167
# 19       3.841815e+06    3975727.475
# 20       4.070095e+06    4016497.161
# 21       4.167410e+06    4134594.766
# 22       4.102626e+06    4278165.933
# 23       3.669949e+06    3893945.909
# 24       2.575790e+06    2389171.083
# 25       1.078103e+06     896425.932
# 26       2.287202e+05     251374.224
# 27       7.653146e+05     455056.048
# 28       1.851928e+06    1780625.872
# 29       2.777485e+06    2914989.101
# 30       3.428728e+06    3561620.245
# 31       3.871858e+06    3991717.506
# 32       4.106557e+06    4559070.778
# 33       4.200634e+06    4596327.081
# 34       4.125122e+06    4565650.139
# 35       3.831334e+06    4061902.846
# 36       2.799228e+06    2336900.967
# 37       1.101184e+06     696917.659
# 38       8.590442e+04     213657.789
# 39       6.494708e+05     765773.883
# 40       1.887110e+06    1951730.202
# 41       2.861140e+06    2610971.814
# 42       3.620191e+06    3137598.938
# 43       4.133890e+06    3201783.453
# 44       4.417044e+06    2973294.266
# 45       4.548690e+06    3354839.711
# 46       4.479222e+06    3325613.245

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 24ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
