# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Kara = pd.read_excel(filepath, sheet_name='Kara-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Kara)
fp.date_time(Kara)
# Out:
#          Extent       Date
# 0    917992.880 1979-01-01
# 1    917992.880 1979-02-01
# 2    917992.880 1979-03-01
# 3    917992.880 1979-04-01
# 4    917992.880 1979-05-01
# ..          ...        ...
# 533  728642.743 2023-06-01
# 534  437024.646 2023-07-01
# 535  202260.789 2023-08-01
# 536   98103.856 2023-09-01
# 537  260413.272 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Kara['Extent'] = scaler.fit_transform(Kara['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 8
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Kara['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((519, 12, 1), (519,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Kara_model_LT8/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.6851 - root_mean_squared_error: 0.8277
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 8s 103ms/step - loss: 0.6847 - root_mean_squared_error: 0.8275 - val_loss: 0.4686 - val_root_mean_squared_error: 0.6845
# Epoch 2/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.5521 - root_mean_squared_error: 0.7430
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 4s 69ms/step - loss: 0.5469 - root_mean_squared_error: 0.7396 - val_loss: 0.4158 - val_root_mean_squared_error: 0.6448
# Epoch 3/50
# 40/53 [=====================>........] - ETA: 0s - loss: 0.5065 - root_mean_squared_error: 0.7117
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 3s 62ms/step - loss: 0.4822 - root_mean_squared_error: 0.6944 - val_loss: 0.3627 - val_root_mean_squared_error: 0.6022
# Epoch 4/50
# 43/53 [=======================>......] - ETA: 0s - loss: 0.4224 - root_mean_squared_error: 0.6499
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 5s 100ms/step - loss: 0.4206 - root_mean_squared_error: 0.6485 - val_loss: 0.3170 - val_root_mean_squared_error: 0.5631
# Epoch 5/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.3647 - root_mean_squared_error: 0.6039
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 4s 79ms/step - loss: 0.3601 - root_mean_squared_error: 0.6001 - val_loss: 0.2800 - val_root_mean_squared_error: 0.5291
# Epoch 6/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.3111 - root_mean_squared_error: 0.5577
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 3s 63ms/step - loss: 0.3039 - root_mean_squared_error: 0.5513 - val_loss: 0.2399 - val_root_mean_squared_error: 0.4898
# Epoch 7/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.2638 - root_mean_squared_error: 0.5136
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 4s 80ms/step - loss: 0.2577 - root_mean_squared_error: 0.5076 - val_loss: 0.1895 - val_root_mean_squared_error: 0.4353
# Epoch 8/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2198 - root_mean_squared_error: 0.4689
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 5s 96ms/step - loss: 0.2176 - root_mean_squared_error: 0.4665 - val_loss: 0.1608 - val_root_mean_squared_error: 0.4010
# Epoch 9/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.1794 - root_mean_squared_error: 0.4235
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 5s 95ms/step - loss: 0.1791 - root_mean_squared_error: 0.4232 - val_loss: 0.1352 - val_root_mean_squared_error: 0.3677
# Epoch 10/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.1462 - root_mean_squared_error: 0.3824
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.1427 - root_mean_squared_error: 0.3777 - val_loss: 0.0946 - val_root_mean_squared_error: 0.3076
# Epoch 11/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.1202 - root_mean_squared_error: 0.3467
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.1174 - root_mean_squared_error: 0.3427 - val_loss: 0.0658 - val_root_mean_squared_error: 0.2564
# Epoch 12/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.1003 - root_mean_squared_error: 0.3167
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0973 - root_mean_squared_error: 0.3120 - val_loss: 0.0567 - val_root_mean_squared_error: 0.2380
# Epoch 13/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0789 - root_mean_squared_error: 0.2810
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0780 - root_mean_squared_error: 0.2793 - val_loss: 0.0468 - val_root_mean_squared_error: 0.2164
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0663 - root_mean_squared_error: 0.2575
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0663 - root_mean_squared_error: 0.2575 - val_loss: 0.0320 - val_root_mean_squared_error: 0.1789
# Epoch 15/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0542 - root_mean_squared_error: 0.2327
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0526 - root_mean_squared_error: 0.2294 - val_loss: 0.0291 - val_root_mean_squared_error: 0.1706
# Epoch 16/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0486 - root_mean_squared_error: 0.2204 - val_loss: 0.0359 - val_root_mean_squared_error: 0.1896
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0412 - root_mean_squared_error: 0.2029 - val_loss: 0.0435 - val_root_mean_squared_error: 0.2085
# Epoch 18/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0300 - root_mean_squared_error: 0.1733
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0310 - root_mean_squared_error: 0.1760 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1349
# Epoch 19/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0344 - root_mean_squared_error: 0.1855 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1647
# Epoch 20/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0306 - root_mean_squared_error: 0.1748 - val_loss: 0.0306 - val_root_mean_squared_error: 0.1749
# Epoch 21/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0287 - root_mean_squared_error: 0.1695 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1587
# Epoch 22/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0260 - root_mean_squared_error: 0.1612 - val_loss: 0.0361 - val_root_mean_squared_error: 0.1901
# Epoch 23/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0281 - root_mean_squared_error: 0.1677 - val_loss: 0.0858 - val_root_mean_squared_error: 0.2929
# Epoch 24/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0290 - root_mean_squared_error: 0.1704 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1647
# Epoch 25/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0259 - root_mean_squared_error: 0.1611 - val_loss: 0.0262 - val_root_mean_squared_error: 0.1618
# Epoch 26/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0268 - root_mean_squared_error: 0.1637 - val_loss: 0.0387 - val_root_mean_squared_error: 0.1966
# Epoch 27/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0251 - root_mean_squared_error: 0.1584
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0257 - root_mean_squared_error: 0.1602 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1279
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0275 - root_mean_squared_error: 0.1659 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1583
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0272 - root_mean_squared_error: 0.1648 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1434
# Epoch 30/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0252 - root_mean_squared_error: 0.1589 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1323
# Epoch 31/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0294 - root_mean_squared_error: 0.1715 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1621
# Epoch 32/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0274 - root_mean_squared_error: 0.1655 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1514
# Epoch 33/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0266 - root_mean_squared_error: 0.1632 - val_loss: 0.0320 - val_root_mean_squared_error: 0.1789
# Epoch 34/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0259 - root_mean_squared_error: 0.1610 - val_loss: 0.0554 - val_root_mean_squared_error: 0.2354
# Epoch 35/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0228 - root_mean_squared_error: 0.1510 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1280
# Epoch 36/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0231 - root_mean_squared_error: 0.1521
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# INFO:tensorflow:Assets written to: Kara_model_LT8\assets
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0234 - root_mean_squared_error: 0.1531 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1152
# Epoch 37/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0239 - root_mean_squared_error: 0.1545 - val_loss: 0.0407 - val_root_mean_squared_error: 0.2018
# Epoch 38/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0263 - root_mean_squared_error: 0.1620 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1298
# Epoch 39/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0240 - root_mean_squared_error: 0.1549 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1284
# Epoch 40/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0275 - root_mean_squared_error: 0.1658 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1368
# Epoch 41/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0257 - root_mean_squared_error: 0.1603 - val_loss: 0.0510 - val_root_mean_squared_error: 0.2257
# Epoch 42/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0271 - root_mean_squared_error: 0.1645 - val_loss: 0.0342 - val_root_mean_squared_error: 0.1849
# Epoch 43/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0247 - root_mean_squared_error: 0.1572 - val_loss: 0.0643 - val_root_mean_squared_error: 0.2537
# Epoch 44/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0258 - root_mean_squared_error: 0.1607 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1419
# Epoch 45/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0232 - root_mean_squared_error: 0.1522 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1700
# Epoch 46/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0252 - root_mean_squared_error: 0.1586 - val_loss: 0.0228 - val_root_mean_squared_error: 0.1510
# Epoch 47/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0221 - root_mean_squared_error: 0.1488 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1696
# Epoch 48/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0264 - root_mean_squared_error: 0.1624 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1230
# Epoch 49/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0229 - root_mean_squared_error: 0.1513 - val_loss: 0.0904 - val_root_mean_squared_error: 0.3007
# Epoch 50/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0234 - root_mean_squared_error: 0.1529 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1297

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.6623556335767111 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Kara_model_LT8/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 13ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.11884094616099966
# MAE : 0.08925789276105892

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       735266.250000     909176.475
# 1       854256.437500     917006.278
# 2       879109.687500     906368.363
# 3       855384.625000     917403.622
# 4       909619.000000     910653.838
# 5       889940.125000     822319.125
# 6       727983.562500     557314.102
# 7       377201.468750     197129.525
# 8        80140.484375      75730.217
# 9        23173.406250      59608.479
# 10      320003.281250      88785.283
# 11      612211.437500     396883.400
# 12      785399.562500     662542.207
# 13      861319.937500     871431.414
# 14      864026.750000     917876.960
# 15      888861.875000     917992.880
# 16      881807.687500     912733.060
# 17      809124.187500     910536.463
# 18      616641.875000     760170.733
# 19      325664.906250     383812.645
# 20      111641.937500     201024.515
# 21       42317.613281     121904.059
# 22      199113.718750     283554.493
# 23      443852.812500     702176.823
# 24      672705.062500     893690.080
# 25      795053.812500     910117.941
# 26      858561.250000     889204.715
# 27      855452.562500     905311.611
# 28      898017.937500     917930.089
# 29      880896.312500     912089.899
# 30      759987.500000     743951.228
# 31      441310.031250     307180.895
# 32      147759.296875     104402.284
# 33       70599.351562      73177.670
# 34      318313.281250     127085.610
# 35      582052.750000     650570.950
# 36      791121.062500     789062.385
# 37      829492.687500     897053.619
# 38      880122.062500     904024.315
# 39      832453.125000     911832.551
# 40      883691.562500     917992.880
# 41      859252.375000     894286.938
# 42      732498.125000     728642.743
# 43      388704.031250     437024.646
# 44      118397.875000     202260.789
# 45       50623.312500      98103.856
# 46      255142.593750     260413.272

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
