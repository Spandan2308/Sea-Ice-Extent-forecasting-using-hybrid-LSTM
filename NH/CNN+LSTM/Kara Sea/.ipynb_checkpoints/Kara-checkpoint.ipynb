# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Kara = pd.read_excel(filepath, sheet_name='Kara-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Kara)
fp.date_time(Kara)
# Out:
#          Extent       Date
# 0    917992.880 1979-01-01
# 1    917992.880 1979-02-01
# 2    917992.880 1979-03-01
# 3    917992.880 1979-04-01
# 4    917992.880 1979-05-01
# ..          ...        ...
# 533  728642.743 2023-06-01
# 534  437024.646 2023-07-01
# 535  202260.789 2023-08-01
# 536   98103.856 2023-09-01
# 537  260413.272 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Kara['Extent'] = scaler.fit_transform(Kara['Extent'].values.reshape(-1, 1))

# %%
extent = Kara['Extent']
W_S=12
X,y = fp.df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((526, 12, 1), (526,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
#model.add(LSTM(64, kernel_constraint=MaxNorm(1.0), activation='relu', return_sequences=True))
#model.add(Dropout(0.2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Kara_model/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.7084 - root_mean_squared_error: 0.8417
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 8s 105ms/step - loss: 0.6963 - root_mean_squared_error: 0.8345 - val_loss: 0.5500 - val_root_mean_squared_error: 0.7416
# Epoch 2/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.5955 - root_mean_squared_error: 0.7717
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.5944 - root_mean_squared_error: 0.7710 - val_loss: 0.4877 - val_root_mean_squared_error: 0.6984
# Epoch 3/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.5292 - root_mean_squared_error: 0.7275
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.5254 - root_mean_squared_error: 0.7249 - val_loss: 0.4252 - val_root_mean_squared_error: 0.6521
# Epoch 4/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.4613 - root_mean_squared_error: 0.6792
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 98ms/step - loss: 0.4648 - root_mean_squared_error: 0.6818 - val_loss: 0.3671 - val_root_mean_squared_error: 0.6058
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.4040 - root_mean_squared_error: 0.6356
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.4039 - root_mean_squared_error: 0.6355 - val_loss: 0.3319 - val_root_mean_squared_error: 0.5761
# Epoch 6/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.3462 - root_mean_squared_error: 0.5884
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.3485 - root_mean_squared_error: 0.5903 - val_loss: 0.2843 - val_root_mean_squared_error: 0.5332
# Epoch 7/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.2965 - root_mean_squared_error: 0.5445
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 97ms/step - loss: 0.2981 - root_mean_squared_error: 0.5460 - val_loss: 0.2432 - val_root_mean_squared_error: 0.4931
# Epoch 8/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.2553 - root_mean_squared_error: 0.5053
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 95ms/step - loss: 0.2509 - root_mean_squared_error: 0.5009 - val_loss: 0.2032 - val_root_mean_squared_error: 0.4508
# Epoch 9/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.2116 - root_mean_squared_error: 0.4600
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 99ms/step - loss: 0.2097 - root_mean_squared_error: 0.4579 - val_loss: 0.1555 - val_root_mean_squared_error: 0.3943
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1753 - root_mean_squared_error: 0.4187
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.1753 - root_mean_squared_error: 0.4187 - val_loss: 0.1309 - val_root_mean_squared_error: 0.3618
# Epoch 11/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.1354 - root_mean_squared_error: 0.3680
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.1357 - root_mean_squared_error: 0.3683 - val_loss: 0.0837 - val_root_mean_squared_error: 0.2893
# Epoch 12/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.1150 - root_mean_squared_error: 0.3391
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 96ms/step - loss: 0.1124 - root_mean_squared_error: 0.3353 - val_loss: 0.0679 - val_root_mean_squared_error: 0.2605
# Epoch 13/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0914 - root_mean_squared_error: 0.3023
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0877 - root_mean_squared_error: 0.2962 - val_loss: 0.0539 - val_root_mean_squared_error: 0.2322
# Epoch 14/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0693 - root_mean_squared_error: 0.2633
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0684 - root_mean_squared_error: 0.2615 - val_loss: 0.0445 - val_root_mean_squared_error: 0.2109
# Epoch 15/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0615 - root_mean_squared_error: 0.2479
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 102ms/step - loss: 0.0578 - root_mean_squared_error: 0.2404 - val_loss: 0.0389 - val_root_mean_squared_error: 0.1972
# Epoch 16/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0484 - root_mean_squared_error: 0.2201
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0482 - root_mean_squared_error: 0.2196 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1265
# Epoch 17/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0391 - root_mean_squared_error: 0.1976 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1375
# Epoch 18/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0317 - root_mean_squared_error: 0.1782
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0317 - root_mean_squared_error: 0.1779 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1219
# Epoch 19/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0259 - root_mean_squared_error: 0.1610
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0262 - root_mean_squared_error: 0.1618 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1194
# Epoch 20/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0207 - root_mean_squared_error: 0.1437
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0207 - root_mean_squared_error: 0.1437 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1040
# Epoch 21/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0232 - root_mean_squared_error: 0.1524 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1286
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0201 - root_mean_squared_error: 0.1418
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0201 - root_mean_squared_error: 0.1418 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1005
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0191 - root_mean_squared_error: 0.1381 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1117
# Epoch 24/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0188 - root_mean_squared_error: 0.1372 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1078
# Epoch 25/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0192 - root_mean_squared_error: 0.1387 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1127
# Epoch 26/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0183 - root_mean_squared_error: 0.1352 - val_loss: 0.0202 - val_root_mean_squared_error: 0.1422
# Epoch 27/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0180 - root_mean_squared_error: 0.1341 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1413
# Epoch 28/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0185 - root_mean_squared_error: 0.1360 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1019
# Epoch 29/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0156 - root_mean_squared_error: 0.1249
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0169 - root_mean_squared_error: 0.1301 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0999
# Epoch 30/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0200 - root_mean_squared_error: 0.1416 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1338
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0203 - root_mean_squared_error: 0.1424 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1290
# Epoch 32/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0156 - root_mean_squared_error: 0.1251 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1259
# Epoch 33/50
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0203 - root_mean_squared_error: 0.1424 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1191
# Epoch 34/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0170 - root_mean_squared_error: 0.1305 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 35/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0166 - root_mean_squared_error: 0.1288 - val_loss: 0.0264 - val_root_mean_squared_error: 0.1624
# Epoch 36/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0178 - root_mean_squared_error: 0.1334 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1058
# Epoch 37/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0185 - root_mean_squared_error: 0.1361 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1318
# Epoch 38/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0218 - root_mean_squared_error: 0.1476
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0215 - root_mean_squared_error: 0.1466 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0934
# Epoch 39/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0211 - root_mean_squared_error: 0.1454
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model\assets
# INFO:tensorflow:Assets written to: Kara_model\assets
# 53/53 [==============================] - 5s 99ms/step - loss: 0.0221 - root_mean_squared_error: 0.1485 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0924
# Epoch 40/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0163 - root_mean_squared_error: 0.1279 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0977
# Epoch 41/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0180 - root_mean_squared_error: 0.1341 - val_loss: 0.0326 - val_root_mean_squared_error: 0.1806
# Epoch 42/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0175 - root_mean_squared_error: 0.1322 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0958
# Epoch 43/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0225 - root_mean_squared_error: 0.1499 - val_loss: 0.0267 - val_root_mean_squared_error: 0.1633
# Epoch 44/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0169 - root_mean_squared_error: 0.1299 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0973
# Epoch 45/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0169 - root_mean_squared_error: 0.1302 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0972
# Epoch 46/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0189 - root_mean_squared_error: 0.1376 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0931
# Epoch 47/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0183 - root_mean_squared_error: 0.1353 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1257
# Epoch 48/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0206 - root_mean_squared_error: 0.1434 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0948
# Epoch 49/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0145 - root_mean_squared_error: 0.1206 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0956
# Epoch 50/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0146 - root_mean_squared_error: 0.1208 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1102

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 2.1280749917030333 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Kara_model/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 5ms/step

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       901708.750000     893583.864
# 1       761005.000000     763496.585
# 2       460877.812500     282691.615
# 3        18132.820312      71897.386
# 4        42834.382812      60592.380
# 5       161611.062500     131973.043
# 6       500446.312500     753595.099
# 7       753320.437500     909176.475
# 8       817208.312500     917006.278
# 9       828739.437500     906368.363
# 10      893987.187500     917403.622
# 11      839819.437500     910653.838
# 12      881277.937500     822319.125
# 13      629521.500000     557314.102
# 14      291446.468750     197129.525
# 15       15762.825195      75730.217
# 16      101360.929688      59608.479
# 17      241958.875000      88785.283
# 18      529659.500000     396883.400
# 19      792966.625000     662542.207
# 20      908157.937500     871431.414
# 21      883657.062500     917876.960
# 22      958428.062500     917992.880
# 23      912198.187500     912733.060
# 24      853512.875000     910536.463
# 25      634417.375000     760170.733
# 26      377564.312500     383812.645
# 27      116031.664062     201024.515
# 28      149371.062500     121904.059
# 29      239165.203125     283554.493
# 30      596272.687500     702176.823
# 31      841777.562500     893690.080
# 32      904956.625000     910117.941
# 33      914822.062500     889204.715
# 34      928374.062500     905311.611
# 35      889864.000000     917930.089
# 36      896921.500000     912089.899
# 37      721305.125000     743951.228
# 38      434498.500000     307180.895
# 39       36593.078125     104402.284
# 40       95312.796875      73177.670
# 41      223777.546875     127085.610
# 42      538379.437500     650570.950
# 43      823144.937500     789062.385
# 44      858464.250000     897053.619
# 45      853453.875000     904024.315
# 46      944220.062500     911832.551
# 47      885409.312500     917992.880
# 48      916885.125000     894286.938
# 49      693867.437500     728642.743
# 50      427028.687500     437024.646
# 51      139330.343750     202260.789
# 52      185401.828125      98103.856
# 53      243597.265625     260413.272

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 4ms/step

# %%
mse = mean_squared_error(y, predictions)
print(mse)
# Out:
# 0.007956346032358383

# %%
mae = mean_absolute_error(y, predictions)
print(mae)
# Out:
# 0.06720889081647315

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
