# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bell_Amundsen_Extent = pd.read_excel(filepath, sheet_name='Bell-Amundsen-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Bell_Amundsen_Extent)
fp.date_time(Bell_Amundsen_Extent)
# Out:
#           Extent       Date
# 0    1179855.894 1979-01-01
# 1     879585.254 1979-02-01
# 2     791619.096 1979-03-01
# 3    1254912.071 1979-04-01
# 4    1620142.247 1979-05-01
# ..           ...        ...
# 533  1556568.455 2023-06-01
# 534  1917507.979 2023-07-01
# 535  2601630.327 2023-08-01
# 536  2534223.780 2023-09-01
# 537  2373004.525 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bell_Amundsen_Extent['Extent'] = scaler.fit_transform(Bell_Amundsen_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 7
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bell_Amundsen_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((520, 12, 1), (520,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Bell_Amund_model_LT7/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1817 - root_mean_squared_error: 0.4262INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 27s 348ms/step - loss: 0.1804 - root_mean_squared_error: 0.4247 - val_loss: 0.1045 - val_root_mean_squared_error: 0.3233
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0538 - root_mean_squared_error: 0.2320INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 17s 329ms/step - loss: 0.0538 - root_mean_squared_error: 0.2320 - val_loss: 0.0646 - val_root_mean_squared_error: 0.2541
# Epoch 3/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0474 - root_mean_squared_error: 0.2177 - val_loss: 0.0648 - val_root_mean_squared_error: 0.2545
# Epoch 4/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0467 - root_mean_squared_error: 0.2162INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 17s 330ms/step - loss: 0.0466 - root_mean_squared_error: 0.2158 - val_loss: 0.0615 - val_root_mean_squared_error: 0.2479
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0412 - root_mean_squared_error: 0.2031INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 353ms/step - loss: 0.0412 - root_mean_squared_error: 0.2031 - val_loss: 0.0518 - val_root_mean_squared_error: 0.2276
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0354 - root_mean_squared_error: 0.1881INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 337ms/step - loss: 0.0354 - root_mean_squared_error: 0.1881 - val_loss: 0.0428 - val_root_mean_squared_error: 0.2070
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0271 - root_mean_squared_error: 0.1648INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 345ms/step - loss: 0.0269 - root_mean_squared_error: 0.1642 - val_loss: 0.0321 - val_root_mean_squared_error: 0.1792
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0199 - root_mean_squared_error: 0.1412INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 19s 368ms/step - loss: 0.0199 - root_mean_squared_error: 0.1412 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1537
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0155 - root_mean_squared_error: 0.1245INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 352ms/step - loss: 0.0155 - root_mean_squared_error: 0.1245 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1445
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0132 - root_mean_squared_error: 0.1149INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 351ms/step - loss: 0.0132 - root_mean_squared_error: 0.1149 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1402
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0120 - root_mean_squared_error: 0.1097INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 352ms/step - loss: 0.0120 - root_mean_squared_error: 0.1095 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1352
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0114 - root_mean_squared_error: 0.1066INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 19s 355ms/step - loss: 0.0114 - root_mean_squared_error: 0.1066 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1317
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0108 - root_mean_squared_error: 0.1037INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 349ms/step - loss: 0.0108 - root_mean_squared_error: 0.1037 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1289
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0096 - root_mean_squared_error: 0.0981INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 17s 330ms/step - loss: 0.0096 - root_mean_squared_error: 0.0981 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1261
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0088 - root_mean_squared_error: 0.0940INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 350ms/step - loss: 0.0088 - root_mean_squared_error: 0.0940 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1234
# Epoch 16/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0092 - root_mean_squared_error: 0.0957INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 19s 358ms/step - loss: 0.0091 - root_mean_squared_error: 0.0953 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1212
# Epoch 17/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0083 - root_mean_squared_error: 0.0912INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 355ms/step - loss: 0.0083 - root_mean_squared_error: 0.0911 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1204
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0085 - root_mean_squared_error: 0.0922INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 19s 363ms/step - loss: 0.0085 - root_mean_squared_error: 0.0922 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1181
# Epoch 19/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0084 - root_mean_squared_error: 0.0917INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 344ms/step - loss: 0.0085 - root_mean_squared_error: 0.0922 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1166
# Epoch 20/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0081 - root_mean_squared_error: 0.0901INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 341ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1157
# Epoch 21/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0083 - root_mean_squared_error: 0.0912INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 352ms/step - loss: 0.0083 - root_mean_squared_error: 0.0912 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1154
# Epoch 22/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0080 - root_mean_squared_error: 0.0892 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1181
# Epoch 23/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0092 - root_mean_squared_error: 0.0959 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1160
# Epoch 24/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0084 - root_mean_squared_error: 0.0918INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 19s 359ms/step - loss: 0.0084 - root_mean_squared_error: 0.0914 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 25/50
# 53/53 [==============================] - 3s 47ms/step - loss: 0.0085 - root_mean_squared_error: 0.0920 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1162
# Epoch 26/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0077 - root_mean_squared_error: 0.0877INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 19s 357ms/step - loss: 0.0077 - root_mean_squared_error: 0.0877 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1143
# Epoch 27/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0083 - root_mean_squared_error: 0.0911 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1301
# Epoch 28/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0088 - root_mean_squared_error: 0.0939INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 19s 372ms/step - loss: 0.0088 - root_mean_squared_error: 0.0939 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133
# Epoch 29/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0080 - root_mean_squared_error: 0.0896INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 20s 380ms/step - loss: 0.0080 - root_mean_squared_error: 0.0896 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1130
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0075 - root_mean_squared_error: 0.0864INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 354ms/step - loss: 0.0075 - root_mean_squared_error: 0.0864 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1128
# Epoch 31/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0080 - root_mean_squared_error: 0.0895 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1140
# Epoch 32/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0080 - root_mean_squared_error: 0.0893INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 19s 361ms/step - loss: 0.0080 - root_mean_squared_error: 0.0893 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1114
# Epoch 33/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0084 - root_mean_squared_error: 0.0916INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 343ms/step - loss: 0.0084 - root_mean_squared_error: 0.0916 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1112
# Epoch 34/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0072 - root_mean_squared_error: 0.0846 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1117
# Epoch 35/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0076 - root_mean_squared_error: 0.0874 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1115
# Epoch 36/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0078 - root_mean_squared_error: 0.0885 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1182
# Epoch 37/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0082 - root_mean_squared_error: 0.0905 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1140
# Epoch 38/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0075 - root_mean_squared_error: 0.0864INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 19s 365ms/step - loss: 0.0075 - root_mean_squared_error: 0.0866 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1101
# Epoch 39/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0075 - root_mean_squared_error: 0.0863 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1176
# Epoch 40/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0079 - root_mean_squared_error: 0.0890 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1108
# Epoch 41/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0073 - root_mean_squared_error: 0.0853 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1101
# Epoch 42/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0072 - root_mean_squared_error: 0.0846INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 19s 362ms/step - loss: 0.0072 - root_mean_squared_error: 0.0846 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1099
# Epoch 43/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0075 - root_mean_squared_error: 0.0864INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 19s 364ms/step - loss: 0.0075 - root_mean_squared_error: 0.0864 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1088
# Epoch 44/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0074 - root_mean_squared_error: 0.0860 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1101
# Epoch 45/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0075 - root_mean_squared_error: 0.0867INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 354ms/step - loss: 0.0075 - root_mean_squared_error: 0.0868 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1088
# Epoch 46/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0071 - root_mean_squared_error: 0.0845INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 352ms/step - loss: 0.0071 - root_mean_squared_error: 0.0845 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1084
# Epoch 47/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0074 - root_mean_squared_error: 0.0859INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 19s 368ms/step - loss: 0.0074 - root_mean_squared_error: 0.0859 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1081
# Epoch 48/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0076 - root_mean_squared_error: 0.0871INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 351ms/step - loss: 0.0076 - root_mean_squared_error: 0.0871 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1077
# Epoch 49/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0075 - root_mean_squared_error: 0.0868INFO:tensorflow:Assets written to: Bell_Amund_model_LT7\assets
# 53/53 [==============================] - 18s 347ms/step - loss: 0.0075 - root_mean_squared_error: 0.0868 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1077
# Epoch 50/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0068 - root_mean_squared_error: 0.0827 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1130

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 11.651200032234192 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bell_Amund_model_LT7/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 20ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.08628833409309145
# MAE : 0.06701814923066628

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.789706e+06    1802244.842
# 1        1.216246e+06    1202791.069
# 2        6.420172e+05     752834.272
# 3        3.761288e+05     451914.219
# 4        3.764185e+05     439855.813
# 5        6.646932e+05     807857.307
# 6        1.057807e+06    1184280.145
# 7        1.475170e+06    1468308.405
# 8        1.837849e+06    1540851.607
# 9        2.009335e+06    1989099.836
# 10       2.060638e+06    2096990.761
# 11       1.990776e+06    2080961.032
# 12       1.707716e+06    1695704.661
# 13       1.229989e+06    1533888.370
# 14       7.300772e+05    1038332.675
# 15       4.638345e+05     602954.621
# 16       4.479233e+05     895484.288
# 17       6.290228e+05    1070622.700
# 18       1.024978e+06    1532457.922
# 19       1.502690e+06    1703762.123
# 20       1.825002e+06    1855079.122
# 21       1.992330e+06    2291960.639
# 22       2.052196e+06    2114120.417
# 23       1.928215e+06    1995818.759
# 24       1.650069e+06    1653379.997
# 25       1.159848e+06    1070814.995
# 26       7.527655e+05     689443.815
# 27       5.385543e+05     401148.663
# 28       5.725315e+05     346558.057
# 29       8.232806e+05     599477.678
# 30       1.178976e+06     765764.905
# 31       1.575282e+06    1304133.179
# 32       1.938499e+06    1598436.099
# 33       2.063962e+06    1763844.414
# 34       2.063918e+06    1979139.524
# 35       1.996628e+06    1937348.663
# 36       1.772032e+06    1833093.342
# 37       1.432299e+06    1089676.114
# 38       8.407043e+05     453484.731
# 39       3.937402e+05     251559.554
# 40       3.378915e+05     351294.657
# 41       5.401666e+05     702389.714
# 42       9.659424e+05    1185169.054
# 43       1.411939e+06    1556568.455
# 44       1.754502e+06    1917507.979
# 45       2.008398e+06    2601630.327
# 46       2.103411e+06    2534223.780
# 47       2.073185e+06    2373004.525

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 17ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
