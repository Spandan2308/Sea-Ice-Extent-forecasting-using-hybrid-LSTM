# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Greenland = pd.read_excel(filepath, sheet_name='Greenland-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Greenland)
fp.date_time(Greenland)
# Out:
#           Extent       Date
# 0    1076123.146 1979-01-01
# 1    1099248.063 1979-02-01
# 2    1036964.901 1979-03-01
# 3     958927.937 1979-04-01
# 4     823812.694 1979-05-01
# ..           ...        ...
# 533   721350.515 2023-06-01
# 534   459033.164 2023-07-01
# 535   282045.909 2023-08-01
# 536   270397.608 2023-09-01
# 537   449910.973 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Greenland['Extent'] = scaler.fit_transform(Greenland['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 6
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]  # Adjusted for lead time
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Greenland['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((521, 12, 1), (521,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Greenland_model_LT6/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2909 - root_mean_squared_error: 0.5393
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# 53/53 [==============================] - 6s 77ms/step - loss: 0.2925 - root_mean_squared_error: 0.5409 - val_loss: 0.1392 - val_root_mean_squared_error: 0.3731
# Epoch 2/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.2393 - root_mean_squared_error: 0.4891
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# 53/53 [==============================] - 3s 59ms/step - loss: 0.2385 - root_mean_squared_error: 0.4884 - val_loss: 0.1121 - val_root_mean_squared_error: 0.3348
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1967 - root_mean_squared_error: 0.4435
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# 53/53 [==============================] - 3s 58ms/step - loss: 0.1967 - root_mean_squared_error: 0.4435 - val_loss: 0.0882 - val_root_mean_squared_error: 0.2970
# Epoch 4/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.1606 - root_mean_squared_error: 0.4007
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# 53/53 [==============================] - 3s 63ms/step - loss: 0.1611 - root_mean_squared_error: 0.4014 - val_loss: 0.0708 - val_root_mean_squared_error: 0.2661
# Epoch 5/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1308 - root_mean_squared_error: 0.3616
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# 53/53 [==============================] - 4s 69ms/step - loss: 0.1286 - root_mean_squared_error: 0.3586 - val_loss: 0.0524 - val_root_mean_squared_error: 0.2289
# Epoch 6/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1041 - root_mean_squared_error: 0.3226
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# 53/53 [==============================] - 3s 66ms/step - loss: 0.1035 - root_mean_squared_error: 0.3216 - val_loss: 0.0422 - val_root_mean_squared_error: 0.2055
# Epoch 7/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0828 - root_mean_squared_error: 0.2878
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0813 - root_mean_squared_error: 0.2852 - val_loss: 0.0319 - val_root_mean_squared_error: 0.1787
# Epoch 8/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0628 - root_mean_squared_error: 0.2505
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0629 - root_mean_squared_error: 0.2509 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1498
# Epoch 9/50
# 40/53 [=====================>........] - ETA: 0s - loss: 0.0536 - root_mean_squared_error: 0.2316
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0496 - root_mean_squared_error: 0.2227 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1355
# Epoch 10/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0374 - root_mean_squared_error: 0.1934
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0371 - root_mean_squared_error: 0.1927 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1251
# Epoch 11/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0288 - root_mean_squared_error: 0.1697 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1468
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0223 - root_mean_squared_error: 0.1494
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0221 - root_mean_squared_error: 0.1488 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1062
# Epoch 13/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0180 - root_mean_squared_error: 0.1343 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1543
# Epoch 14/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0178 - root_mean_squared_error: 0.1332 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1233
# Epoch 15/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0139 - root_mean_squared_error: 0.1181 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1313
# Epoch 16/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0141 - root_mean_squared_error: 0.1188
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0139 - root_mean_squared_error: 0.1178 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1046
# Epoch 17/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0110 - root_mean_squared_error: 0.1050
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1012
# Epoch 18/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0121 - root_mean_squared_error: 0.1101
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT6\assets
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0119 - root_mean_squared_error: 0.1089 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1011
# Epoch 19/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0128 - root_mean_squared_error: 0.1132 - val_loss: 0.0353 - val_root_mean_squared_error: 0.1879
# Epoch 20/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0125 - root_mean_squared_error: 0.1118 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1914
# Epoch 21/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1372
# Epoch 22/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0106 - root_mean_squared_error: 0.1029 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1238
# Epoch 23/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0128 - root_mean_squared_error: 0.1134 - val_loss: 0.0384 - val_root_mean_squared_error: 0.1960
# Epoch 24/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0132 - root_mean_squared_error: 0.1151 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1172
# Epoch 25/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0119 - root_mean_squared_error: 0.1092 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1301
# Epoch 26/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0132 - root_mean_squared_error: 0.1150 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1258
# Epoch 27/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0121 - root_mean_squared_error: 0.1101 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1266
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0097 - root_mean_squared_error: 0.0987 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1182
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0111 - root_mean_squared_error: 0.1053 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1447
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0130 - root_mean_squared_error: 0.1140 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1187
# Epoch 31/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0123 - root_mean_squared_error: 0.1111 - val_loss: 0.0393 - val_root_mean_squared_error: 0.1982
# Epoch 32/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0122 - root_mean_squared_error: 0.1104 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1441
# Epoch 33/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0116 - root_mean_squared_error: 0.1075 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1062
# Epoch 34/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0119 - root_mean_squared_error: 0.1089 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1114
# Epoch 35/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0106 - root_mean_squared_error: 0.1027 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1295
# Epoch 36/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0104 - root_mean_squared_error: 0.1020 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1332
# Epoch 37/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0111 - root_mean_squared_error: 0.1054 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1337
# Epoch 38/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0112 - root_mean_squared_error: 0.1056 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1106
# Epoch 39/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0129 - root_mean_squared_error: 0.1135 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1286
# Epoch 40/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0114 - root_mean_squared_error: 0.1066 - val_loss: 0.0265 - val_root_mean_squared_error: 0.1627
# Epoch 41/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0114 - root_mean_squared_error: 0.1068 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1031
# Epoch 42/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1501
# Epoch 43/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0112 - root_mean_squared_error: 0.1057 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1153
# Epoch 44/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0127 - root_mean_squared_error: 0.1127 - val_loss: 0.0202 - val_root_mean_squared_error: 0.1421
# Epoch 45/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0103 - root_mean_squared_error: 0.1013 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1149
# Epoch 46/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0098 - root_mean_squared_error: 0.0989 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1522
# Epoch 47/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0095 - root_mean_squared_error: 0.0976 - val_loss: 0.0292 - val_root_mean_squared_error: 0.1708
# Epoch 48/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1205
# Epoch 49/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0106 - root_mean_squared_error: 0.1029 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1202
# Epoch 50/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0097 - root_mean_squared_error: 0.0987 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1334

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 0.9875435749689738 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Greenland_model_LT6/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 15ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.09783219073839057
# MAE : 0.08130678306448776

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       410022.875000     386546.857
# 1       425940.218750     547183.986
# 2       544032.187500     584596.262
# 3       590901.187500     584830.109
# 4       606649.437500     641562.292
# 5       648939.312500     734946.437
# 6       657322.312500     777596.225
# 7       644908.750000     687087.673
# 8       497207.156250     622337.816
# 9       416102.937500     467232.074
# 10      297490.656250     297495.641
# 11      316407.156250     268909.854
# 12      321563.718750     408072.791
# 13      407880.156250     552314.148
# 14      526887.562500     651062.408
# 15      655295.312500     695022.674
# 16      619529.812500     670974.305
# 17      668898.125000     710035.543
# 18      668851.750000     699672.538
# 19      657968.875000     730897.021
# 20      542003.375000     588598.988
# 21      400762.968750     281754.041
# 22      286613.375000     117830.266
# 23      318964.125000      81838.250
# 24      360717.031250     291418.462
# 25      457076.812500     452417.079
# 26      551489.375000     576361.148
# 27      630364.937500     676218.054
# 28      615867.937500     698410.066
# 29      641198.312500     696094.179
# 30      628154.687500     751102.742
# 31      569294.250000     765802.952
# 32      447541.156250     597649.311
# 33      344991.500000     376029.266
# 34      217504.046875     278536.574
# 35      197653.890625     285351.521
# 36      298632.343750     365256.138
# 37      431246.250000     488293.212
# 38      492457.812500     635073.900
# 39      639373.562500     684651.888
# 40      607849.500000     698053.275
# 41      698396.812500     846211.943
# 42      663749.875000     831596.370
# 43      645589.062500     834849.724
# 44      539682.000000     721350.515
# 45      398642.312500     459033.164
# 46      306707.437500     282045.909
# 47      316522.968750     270397.608
# 48      364775.937500     449910.973

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 2ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
