# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Greenland = pd.read_excel(filepath, sheet_name='Greenland-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Greenland)
fp.date_time(Greenland)
# Out:
#           Extent       Date
# 0    1076123.146 1979-01-01
# 1    1099248.063 1979-02-01
# 2    1036964.901 1979-03-01
# 3     958927.937 1979-04-01
# 4     823812.694 1979-05-01
# ..           ...        ...
# 533   721350.515 2023-06-01
# 534   459033.164 2023-07-01
# 535   282045.909 2023-08-01
# 536   270397.608 2023-09-01
# 537   449910.973 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Greenland['Extent'] = scaler.fit_transform(Greenland['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 5
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Greenland['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((522, 12, 1), (522,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Greenland_LT5/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.2676 - root_mean_squared_error: 0.5173INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 39s 512ms/step - loss: 0.2667 - root_mean_squared_error: 0.5164 - val_loss: 0.0915 - val_root_mean_squared_error: 0.3025
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0700 - root_mean_squared_error: 0.2645INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 31s 598ms/step - loss: 0.0698 - root_mean_squared_error: 0.2642 - val_loss: 0.0273 - val_root_mean_squared_error: 0.1652
# Epoch 3/50
# 53/53 [==============================] - 2s 45ms/step - loss: 0.0347 - root_mean_squared_error: 0.1862 - val_loss: 0.0273 - val_root_mean_squared_error: 0.1653
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0326 - root_mean_squared_error: 0.1805INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 29s 558ms/step - loss: 0.0323 - root_mean_squared_error: 0.1797 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1566
# Epoch 5/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0296 - root_mean_squared_error: 0.1721INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 29s 554ms/step - loss: 0.0294 - root_mean_squared_error: 0.1716 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1526
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0283 - root_mean_squared_error: 0.1681INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 30s 581ms/step - loss: 0.0281 - root_mean_squared_error: 0.1676 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1470
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0245 - root_mean_squared_error: 0.1566INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 31s 595ms/step - loss: 0.0245 - root_mean_squared_error: 0.1566 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1447
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0236 - root_mean_squared_error: 0.1537INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 31s 601ms/step - loss: 0.0236 - root_mean_squared_error: 0.1537 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1367
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0209 - root_mean_squared_error: 0.1446INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 32s 607ms/step - loss: 0.0209 - root_mean_squared_error: 0.1446 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1310
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0188 - root_mean_squared_error: 0.1372INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 30s 585ms/step - loss: 0.0188 - root_mean_squared_error: 0.1372 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1272
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0174 - root_mean_squared_error: 0.1319INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 30s 583ms/step - loss: 0.0174 - root_mean_squared_error: 0.1319 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1238
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0175 - root_mean_squared_error: 0.1322INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 32s 604ms/step - loss: 0.0175 - root_mean_squared_error: 0.1322 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1223
# Epoch 13/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0163 - root_mean_squared_error: 0.1275 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1255
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0171 - root_mean_squared_error: 0.1309INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 31s 604ms/step - loss: 0.0171 - root_mean_squared_error: 0.1309 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1169
# Epoch 15/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0162 - root_mean_squared_error: 0.1273INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 33s 624ms/step - loss: 0.0162 - root_mean_squared_error: 0.1274 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1152
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0148 - root_mean_squared_error: 0.1219INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 25s 475ms/step - loss: 0.0148 - root_mean_squared_error: 0.1219 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 17/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0154 - root_mean_squared_error: 0.1239INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 32s 611ms/step - loss: 0.0153 - root_mean_squared_error: 0.1238 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1121
# Epoch 18/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0150 - root_mean_squared_error: 0.1223 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1158
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0141 - root_mean_squared_error: 0.1185INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 32s 612ms/step - loss: 0.0141 - root_mean_squared_error: 0.1185 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1096
# Epoch 20/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0124 - root_mean_squared_error: 0.1114INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 33s 626ms/step - loss: 0.0124 - root_mean_squared_error: 0.1114 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1087
# Epoch 21/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1148
# Epoch 22/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0127 - root_mean_squared_error: 0.1128 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1158
# Epoch 23/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0125 - root_mean_squared_error: 0.1120 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1100
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0120 - root_mean_squared_error: 0.1093INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 32s 621ms/step - loss: 0.0120 - root_mean_squared_error: 0.1093 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1051
# Epoch 25/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0121 - root_mean_squared_error: 0.1100 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1134
# Epoch 26/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0120 - root_mean_squared_error: 0.1097 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1059
# Epoch 27/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0111 - root_mean_squared_error: 0.1053 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1075
# Epoch 28/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0113 - root_mean_squared_error: 0.1064 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1074
# Epoch 29/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0116 - root_mean_squared_error: 0.1078 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1074
# Epoch 30/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0116 - root_mean_squared_error: 0.1075 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1185
# Epoch 31/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0110 - root_mean_squared_error: 0.1051 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1114
# Epoch 32/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0113 - root_mean_squared_error: 0.1063 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1179
# Epoch 33/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0111 - root_mean_squared_error: 0.1052 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1077
# Epoch 34/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0104 - root_mean_squared_error: 0.1017INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 33s 624ms/step - loss: 0.0104 - root_mean_squared_error: 0.1017 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1045
# Epoch 35/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0114 - root_mean_squared_error: 0.1066INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 34s 647ms/step - loss: 0.0114 - root_mean_squared_error: 0.1066 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1038
# Epoch 36/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0109 - root_mean_squared_error: 0.1046INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 35s 674ms/step - loss: 0.0109 - root_mean_squared_error: 0.1046 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1031
# Epoch 37/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0099 - root_mean_squared_error: 0.0996 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1121
# Epoch 38/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1143
# Epoch 39/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0100 - root_mean_squared_error: 0.1001 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1139
# Epoch 40/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0103 - root_mean_squared_error: 0.1016INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 40s 765ms/step - loss: 0.0103 - root_mean_squared_error: 0.1016 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1016
# Epoch 41/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0116 - root_mean_squared_error: 0.1078 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1074
# Epoch 42/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0106 - root_mean_squared_error: 0.1030 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1040
# Epoch 43/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0106 - root_mean_squared_error: 0.1028 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 44/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0108 - root_mean_squared_error: 0.1037INFO:tensorflow:Assets written to: Greenland_LT5\assets
# 53/53 [==============================] - 39s 756ms/step - loss: 0.0108 - root_mean_squared_error: 0.1037 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1013
# Epoch 45/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0102 - root_mean_squared_error: 0.1012 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1035
# Epoch 46/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0097 - root_mean_squared_error: 0.0983 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1115
# Epoch 47/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0103 - root_mean_squared_error: 0.1013 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1224
# Epoch 48/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1129
# Epoch 49/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0102 - root_mean_squared_error: 0.1009 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1112
# Epoch 50/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1134

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 13.868613815307617 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Greenland_LT5/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 29ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.08551138019956447
# MAE : 0.06562074204793998

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        271476.84375     212475.431
# 1        357768.40625     386546.857
# 2        458709.46875     547183.986
# 3        548929.12500     584596.262
# 4        613603.81250     584830.109
# 5        658618.81250     641562.292
# 6        675151.75000     734946.437
# 7        659779.87500     777596.225
# 8        610386.81250     687087.673
# 9        538589.06250     622337.816
# 10       446296.71875     467232.074
# 11       346457.37500     297495.641
# 12       283069.28125     268909.854
# 13       349322.00000     408072.791
# 14       469364.28125     552314.148
# 15       564540.62500     651062.408
# 16       629290.06250     695022.674
# 17       675195.87500     670974.305
# 18       703567.31250     710035.543
# 19       688315.31250     699672.538
# 20       629186.81250     730897.021
# 21       545935.06250     588598.988
# 22       447572.87500     281754.041
# 23       350959.78125     117830.266
# 24       305243.34375      81838.250
# 25       381667.50000     291418.462
# 26       511940.15625     452417.079
# 27       616250.68750     576361.148
# 28       671052.56250     676218.054
# 29       703248.68750     698410.066
# 30       709819.00000     696094.179
# 31       687581.31250     751102.742
# 32       623089.87500     765802.952
# 33       525179.25000     597649.311
# 34       409833.93750     376029.266
# 35       296039.21875     278536.574
# 36       227396.62500     285351.521
# 37       306135.00000     365256.138
# 38       449808.87500     488293.212
# 39       556637.50000     635073.900
# 40       637543.87500     684651.888
# 41       696220.00000     698053.275
# 42       712675.62500     846211.943
# 43       698076.12500     831596.370
# 44       642640.18750     834849.724
# 45       551834.62500     721350.515
# 46       437654.43750     459033.164
# 47       320466.50000     282045.909
# 48       262254.18750     270397.608
# 49       361251.46875     449910.973

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 27ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
