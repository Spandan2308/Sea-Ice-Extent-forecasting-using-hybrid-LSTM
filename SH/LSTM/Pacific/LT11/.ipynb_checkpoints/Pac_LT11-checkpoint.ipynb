# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Pacific_Extent = pd.read_excel(filepath, sheet_name='Pacific-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Pacific_Extent)
fp.date_time(Pacific_Extent)
# Out:
#           Extent       Date
# 0     668714.275 1979-01-01
# 1     566930.458 1979-02-01
# 2     688420.115 1979-03-01
# 3     859963.043 1979-04-01
# 4    1127120.160 1979-05-01
# ..           ...        ...
# 533  1134056.102 2023-06-01
# 534  1484824.377 2023-07-01
# 535  1671324.717 2023-08-01
# 536  1726376.097 2023-09-01
# 537  1690631.996 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Pacific_Extent['Extent'] = scaler.fit_transform(Pacific_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 11
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Pacific_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((516, 12, 1), (516,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Pacific_model_LT11/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2384 - root_mean_squared_error: 0.4883INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 10s 136ms/step - loss: 0.2393 - root_mean_squared_error: 0.4892 - val_loss: 0.1949 - val_root_mean_squared_error: 0.4415
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1459 - root_mean_squared_error: 0.3820INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 5s 95ms/step - loss: 0.1459 - root_mean_squared_error: 0.3820 - val_loss: 0.0733 - val_root_mean_squared_error: 0.2708
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0730 - root_mean_squared_error: 0.2702INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0726 - root_mean_squared_error: 0.2695 - val_loss: 0.0674 - val_root_mean_squared_error: 0.2595
# Epoch 4/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0678 - root_mean_squared_error: 0.2605INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0678 - root_mean_squared_error: 0.2603 - val_loss: 0.0588 - val_root_mean_squared_error: 0.2425
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0577 - root_mean_squared_error: 0.2401INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0578 - root_mean_squared_error: 0.2403 - val_loss: 0.0497 - val_root_mean_squared_error: 0.2229
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0477 - root_mean_squared_error: 0.2183INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0477 - root_mean_squared_error: 0.2183 - val_loss: 0.0402 - val_root_mean_squared_error: 0.2004
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0369 - root_mean_squared_error: 0.1921INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 5s 105ms/step - loss: 0.0369 - root_mean_squared_error: 0.1921 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1538
# Epoch 8/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0245 - root_mean_squared_error: 0.1565INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0242 - root_mean_squared_error: 0.1555 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1093
# Epoch 9/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0193 - root_mean_squared_error: 0.1390INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0194 - root_mean_squared_error: 0.1394 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1027
# Epoch 10/50
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0183 - root_mean_squared_error: 0.1353 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1542
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0169 - root_mean_squared_error: 0.1301INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 11s 208ms/step - loss: 0.0170 - root_mean_squared_error: 0.1304 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0795
# Epoch 12/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0155 - root_mean_squared_error: 0.1244 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0948
# Epoch 13/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0988
# Epoch 14/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0158 - root_mean_squared_error: 0.1257 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0914
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0151 - root_mean_squared_error: 0.1228INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 10s 196ms/step - loss: 0.0151 - root_mean_squared_error: 0.1228 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0739
# Epoch 16/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0801
# Epoch 17/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0147 - root_mean_squared_error: 0.1212 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1161
# Epoch 18/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0139 - root_mean_squared_error: 0.1179 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0974
# Epoch 19/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0133 - root_mean_squared_error: 0.1155 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0745
# Epoch 20/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0130 - root_mean_squared_error: 0.1140INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 10s 188ms/step - loss: 0.0129 - root_mean_squared_error: 0.1135 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0724
# Epoch 21/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0120 - root_mean_squared_error: 0.1095INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 10s 196ms/step - loss: 0.0120 - root_mean_squared_error: 0.1095 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0712
# Epoch 22/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0125 - root_mean_squared_error: 0.1119 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0720
# Epoch 23/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0121 - root_mean_squared_error: 0.1099 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0714
# Epoch 24/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0712
# Epoch 25/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0119 - root_mean_squared_error: 0.1090 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0935
# Epoch 26/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0116 - root_mean_squared_error: 0.1078INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 9s 173ms/step - loss: 0.0116 - root_mean_squared_error: 0.1078 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0670
# Epoch 27/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0121 - root_mean_squared_error: 0.1099INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 10s 196ms/step - loss: 0.0121 - root_mean_squared_error: 0.1099 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0655
# Epoch 28/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0839
# Epoch 29/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0115 - root_mean_squared_error: 0.1072 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0744
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0118 - root_mean_squared_error: 0.1084INFO:tensorflow:Assets written to: Pacific_model_LT11\assets
# 53/53 [==============================] - 10s 187ms/step - loss: 0.0118 - root_mean_squared_error: 0.1084 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0647
# Epoch 31/50
# 53/53 [==============================] - 1s 26ms/step - loss: 0.0120 - root_mean_squared_error: 0.1096 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0689
# Epoch 32/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0718
# Epoch 33/50
# 53/53 [==============================] - 1s 28ms/step - loss: 0.0114 - root_mean_squared_error: 0.1068 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0798
# Epoch 34/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0805
# Epoch 35/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0109 - root_mean_squared_error: 0.1044 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0833
# Epoch 36/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0108 - root_mean_squared_error: 0.1040 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0827
# Epoch 37/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0101 - root_mean_squared_error: 0.1003 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0751
# Epoch 38/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0102 - root_mean_squared_error: 0.1011 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0710
# Epoch 39/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0112 - root_mean_squared_error: 0.1057 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0649
# Epoch 40/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0118 - root_mean_squared_error: 0.1085 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0654
# Epoch 41/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0103 - root_mean_squared_error: 0.1016 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0689
# Epoch 42/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0705
# Epoch 43/50
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0673
# Epoch 44/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0654
# Epoch 45/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0100 - root_mean_squared_error: 0.1001 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0657
# Epoch 46/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0093 - root_mean_squared_error: 0.0962 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0715
# Epoch 47/50
# 53/53 [==============================] - 2s 28ms/step - loss: 0.0099 - root_mean_squared_error: 0.0997 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0657
# Epoch 48/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0103 - root_mean_squared_error: 0.1015 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0656
# Epoch 49/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0098 - root_mean_squared_error: 0.0992 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0674
# Epoch 50/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0096 - root_mean_squared_error: 0.0977 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0683

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 2.8905592441558836 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Pacific_model_LT11/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 20ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.08449623194995493
# MAE : 0.06909083041234915

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        6.748863e+05     610848.036
# 1        8.742078e+05     819257.445
# 2        1.138022e+06    1129627.707
# 3        1.476386e+06    1463383.236
# 4        1.794696e+06    1614536.727
# 5        1.942530e+06    1862498.612
# 6        2.004256e+06    2099349.296
# 7        1.849399e+06    1981614.046
# 8        1.534648e+06    1433022.369
# 9        1.050138e+06     826739.716
# 10       5.698974e+05     477145.887
# 11       5.110856e+05     314469.289
# 12       6.418796e+05     463134.749
# 13       8.660779e+05     946522.292
# 14       1.155650e+06    1309266.570
# 15       1.527285e+06    1507947.309
# 16       1.866558e+06    1804167.937
# 17       1.930079e+06    1908002.139
# 18       1.945405e+06    1892748.521
# 19       1.791438e+06    1601079.640
# 20       1.401298e+06    1327804.521
# 21       9.015898e+05     812074.231
# 22       5.019208e+05     493355.897
# 23       4.813962e+05     317229.330
# 24       6.101401e+05     425777.624
# 25       8.239861e+05     827172.620
# 26       1.113127e+06    1162367.223
# 27       1.486550e+06    1413734.261
# 28       1.823102e+06    1574257.849
# 29       2.006833e+06    1786961.251
# 30       2.060118e+06    1857942.866
# 31       1.766993e+06    1406291.588
# 32       1.352850e+06    1025555.371
# 33       8.426151e+05     632862.782
# 34       5.175664e+05     308194.756
# 35       5.495484e+05     194921.078
# 36       7.083059e+05     245569.900
# 37       9.239694e+05     533532.424
# 38       1.205286e+06     943124.529
# 39       1.457727e+06    1134056.102
# 40       1.716680e+06    1484824.377
# 41       1.896230e+06    1671324.717
# 42       2.016580e+06    1726376.097
# 43       1.840900e+06    1690631.996

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 16ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
