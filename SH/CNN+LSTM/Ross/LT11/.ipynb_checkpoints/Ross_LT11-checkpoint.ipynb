# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Ross_Extent = pd.read_excel(filepath, sheet_name='Ross-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Ross_Extent)
fp.date_time(Ross_Extent)
# Out:
#           Extent       Date
# 0    1040455.516 1979-01-01
# 1     239334.118 1979-02-01
# 2     557365.154 1979-03-01
# 3    2054855.924 1979-04-01
# 4    2973925.625 1979-05-01
# ..           ...        ...
# 533  3137598.938 2023-06-01
# 534  3201783.453 2023-07-01
# 535  2973294.266 2023-08-01
# 536  3354839.711 2023-09-01
# 537  3325613.245 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Ross_Extent['Extent'] = scaler.fit_transform(Ross_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 11
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Ross_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((516, 12, 1), (516,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Ross_model_LT11/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.3594 - root_mean_squared_error: 0.5995
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 6s 77ms/step - loss: 0.3552 - root_mean_squared_error: 0.5960 - val_loss: 0.2960 - val_root_mean_squared_error: 0.5441
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2925 - root_mean_squared_error: 0.5409
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 4s 80ms/step - loss: 0.2925 - root_mean_squared_error: 0.5409 - val_loss: 0.2647 - val_root_mean_squared_error: 0.5145
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.2493 - root_mean_squared_error: 0.4993
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 3s 66ms/step - loss: 0.2502 - root_mean_squared_error: 0.5002 - val_loss: 0.2276 - val_root_mean_squared_error: 0.4770
# Epoch 4/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.2200 - root_mean_squared_error: 0.4690
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 4s 69ms/step - loss: 0.2136 - root_mean_squared_error: 0.4622 - val_loss: 0.1950 - val_root_mean_squared_error: 0.4416
# Epoch 5/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.1702 - root_mean_squared_error: 0.4125
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 3s 65ms/step - loss: 0.1724 - root_mean_squared_error: 0.4152 - val_loss: 0.1648 - val_root_mean_squared_error: 0.4059
# Epoch 6/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.1404 - root_mean_squared_error: 0.3747
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 3s 64ms/step - loss: 0.1396 - root_mean_squared_error: 0.3736 - val_loss: 0.1414 - val_root_mean_squared_error: 0.3761
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1122 - root_mean_squared_error: 0.3349
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 4s 68ms/step - loss: 0.1122 - root_mean_squared_error: 0.3349 - val_loss: 0.1112 - val_root_mean_squared_error: 0.3335
# Epoch 8/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0873 - root_mean_squared_error: 0.2955
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0859 - root_mean_squared_error: 0.2930 - val_loss: 0.0805 - val_root_mean_squared_error: 0.2837
# Epoch 9/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0701 - root_mean_squared_error: 0.2648
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 3s 67ms/step - loss: 0.0654 - root_mean_squared_error: 0.2557 - val_loss: 0.0719 - val_root_mean_squared_error: 0.2682
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0473 - root_mean_squared_error: 0.2174
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0483 - root_mean_squared_error: 0.2199 - val_loss: 0.0559 - val_root_mean_squared_error: 0.2365
# Epoch 11/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0381 - root_mean_squared_error: 0.1951
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0378 - root_mean_squared_error: 0.1943 - val_loss: 0.0448 - val_root_mean_squared_error: 0.2118
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0264 - root_mean_squared_error: 0.1623
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0263 - root_mean_squared_error: 0.1623 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1529
# Epoch 13/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0257 - root_mean_squared_error: 0.1603
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0253 - root_mean_squared_error: 0.1591 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1391
# Epoch 14/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0187 - root_mean_squared_error: 0.1367
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0186 - root_mean_squared_error: 0.1363 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1033
# Epoch 15/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1053
# Epoch 16/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0111 - root_mean_squared_error: 0.1056
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0108 - root_mean_squared_error: 0.1040 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0925
# Epoch 17/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0128 - root_mean_squared_error: 0.1133
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0133 - root_mean_squared_error: 0.1152 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 18/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0113 - root_mean_squared_error: 0.1063
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0814
# Epoch 19/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0848
# Epoch 20/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0128 - root_mean_squared_error: 0.1132 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0845
# Epoch 21/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0099 - root_mean_squared_error: 0.0993 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0879
# Epoch 22/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1163
# Epoch 23/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0984
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0092 - root_mean_squared_error: 0.0959 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0884
# Epoch 25/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0098 - root_mean_squared_error: 0.0989 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1274
# Epoch 26/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0120 - root_mean_squared_error: 0.1096 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0852
# Epoch 27/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0128 - root_mean_squared_error: 0.1133 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0858
# Epoch 28/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0137 - root_mean_squared_error: 0.1170 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0847
# Epoch 29/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0129 - root_mean_squared_error: 0.1137 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0821
# Epoch 30/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0148 - root_mean_squared_error: 0.1218 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0132 - root_mean_squared_error: 0.1150 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0929
# Epoch 32/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0970
# Epoch 33/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0134 - root_mean_squared_error: 0.1159 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1030
# Epoch 34/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0137 - root_mean_squared_error: 0.1170 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1189
# Epoch 35/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0139 - root_mean_squared_error: 0.1179 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1095
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0088 - root_mean_squared_error: 0.0938 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0978
# Epoch 37/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0105 - root_mean_squared_error: 0.1023 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1160
# Epoch 38/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0819
# Epoch 39/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0933
# Epoch 40/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0101 - root_mean_squared_error: 0.1007 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1077
# Epoch 41/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0097 - root_mean_squared_error: 0.0987 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1050
# Epoch 42/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0108 - root_mean_squared_error: 0.1041 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0958
# Epoch 43/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0096 - root_mean_squared_error: 0.0978 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1261
# Epoch 44/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0110 - root_mean_squared_error: 0.1049 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0889
# Epoch 45/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0131 - root_mean_squared_error: 0.1146 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1374
# Epoch 46/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0088 - root_mean_squared_error: 0.0940 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1066
# Epoch 47/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0107 - root_mean_squared_error: 0.1033 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1103
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0117 - root_mean_squared_error: 0.1082 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1244
# Epoch 49/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0108 - root_mean_squared_error: 0.1038
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0109 - root_mean_squared_error: 0.1045 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0809
# Epoch 50/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0102 - root_mean_squared_error: 0.1009 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0830

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.3049935976664224 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Ross_model_LT11/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.0858082771228634
# MAE : 0.06506006481187498

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        9.441389e+05     979418.298
# 1        1.847307e+06    2086269.569
# 2        2.641200e+06    2852731.016
# 3        3.254568e+06    3452823.613
# 4        3.585061e+06    3846843.974
# 5        3.685180e+06    4005222.451
# 6        3.902576e+06    4129684.505
# 7        3.842453e+06    4130311.577
# 8        3.689527e+06    3987590.376
# 9        2.530446e+06    2531664.630
# 10       1.319903e+06     864796.598
# 11       5.691536e+05     366098.623
# 12       1.029901e+06    1324063.884
# 13       2.025367e+06    2094086.684
# 14       2.673588e+06    2706708.526
# 15       3.353312e+06    3380172.167
# 16       3.508381e+06    3975727.475
# 17       3.835018e+06    4016497.161
# 18       3.872539e+06    4134594.766
# 19       3.988636e+06    4278165.933
# 20       3.515173e+06    3893945.909
# 21       2.303838e+06    2389171.083
# 22       1.015472e+06     896425.932
# 23       4.612948e+05     251374.224
# 24       1.274143e+06     455056.048
# 25       2.013645e+06    1780625.872
# 26       2.878323e+06    2914989.101
# 27       3.536200e+06    3561620.245
# 28       3.713462e+06    3991717.506
# 29       3.921250e+06    4559070.778
# 30       4.094304e+06    4596327.081
# 31       3.922368e+06    4565650.139
# 32       3.615077e+06    4061902.846
# 33       2.132198e+06    2336900.967
# 34       1.020672e+06     696917.659
# 35       3.564311e+05     213657.789
# 36       7.501576e+05     765773.883
# 37       1.701042e+06    1951730.202
# 38       2.646493e+06    2610971.814
# 39       3.195788e+06    3137598.938
# 40       3.923589e+06    3201783.453
# 41       4.001494e+06    2973294.266
# 42       4.322726e+06    3354839.711
# 43       4.224098e+06    3325613.245

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
