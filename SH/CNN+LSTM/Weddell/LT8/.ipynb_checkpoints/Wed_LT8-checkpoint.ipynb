# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Weddell_Extent = pd.read_excel(filepath, sheet_name='Weddell-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Weddell_Extent)
fp.date_time(Weddell_Extent)
# Out:
#           Extent       Date
# 0    2136510.859 1979-01-01
# 1    1243495.891 1979-02-01
# 2    1699053.449 1979-03-01
# 3    2617442.085 1979-04-01
# 4    3852934.206 1979-05-01
# ..           ...        ...
# 533  3668127.143 2023-06-01
# 534  4805519.784 2023-07-01
# 535  5524445.234 2023-08-01
# 536  6006669.861 2023-09-01
# 537  5507961.583 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Weddell_Extent['Extent'] = scaler.fit_transform(Weddell_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 8
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Weddell_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((519, 12, 1), (519,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Weddell_model_LT8/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.3478 - root_mean_squared_error: 0.5898
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 8s 96ms/step - loss: 0.3389 - root_mean_squared_error: 0.5822 - val_loss: 0.2773 - val_root_mean_squared_error: 0.5266
# Epoch 2/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.2202 - root_mean_squared_error: 0.4693
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.2192 - root_mean_squared_error: 0.4682 - val_loss: 0.2244 - val_root_mean_squared_error: 0.4738
# Epoch 3/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.1708 - root_mean_squared_error: 0.4132
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.1723 - root_mean_squared_error: 0.4150 - val_loss: 0.1986 - val_root_mean_squared_error: 0.4456
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1382 - root_mean_squared_error: 0.3718
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.1387 - root_mean_squared_error: 0.3725 - val_loss: 0.1776 - val_root_mean_squared_error: 0.4214
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1117 - root_mean_squared_error: 0.3342
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.1117 - root_mean_squared_error: 0.3342 - val_loss: 0.1554 - val_root_mean_squared_error: 0.3942
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0881 - root_mean_squared_error: 0.2969
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.0874 - root_mean_squared_error: 0.2956 - val_loss: 0.1313 - val_root_mean_squared_error: 0.3624
# Epoch 7/50
# 43/53 [=======================>......] - ETA: 0s - loss: 0.0668 - root_mean_squared_error: 0.2585
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0681 - root_mean_squared_error: 0.2609 - val_loss: 0.1129 - val_root_mean_squared_error: 0.3360
# Epoch 8/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0500 - root_mean_squared_error: 0.2235
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0507 - root_mean_squared_error: 0.2253 - val_loss: 0.0950 - val_root_mean_squared_error: 0.3082
# Epoch 9/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0402 - root_mean_squared_error: 0.2005
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.0421 - root_mean_squared_error: 0.2052 - val_loss: 0.0700 - val_root_mean_squared_error: 0.2646
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0295 - root_mean_squared_error: 0.1719
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0295 - root_mean_squared_error: 0.1719 - val_loss: 0.0589 - val_root_mean_squared_error: 0.2427
# Epoch 11/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0253 - root_mean_squared_error: 0.1590
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0262 - root_mean_squared_error: 0.1618 - val_loss: 0.0438 - val_root_mean_squared_error: 0.2093
# Epoch 12/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0215 - root_mean_squared_error: 0.1465
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0197 - root_mean_squared_error: 0.1404 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1621
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0186 - root_mean_squared_error: 0.1365
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0185 - root_mean_squared_error: 0.1361 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1447
# Epoch 14/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0139 - root_mean_squared_error: 0.1177
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0147 - root_mean_squared_error: 0.1214 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0935
# Epoch 15/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0117 - root_mean_squared_error: 0.1082
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0715
# Epoch 16/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0146 - root_mean_squared_error: 0.1206 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0821
# Epoch 17/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0158 - root_mean_squared_error: 0.1258 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0755
# Epoch 18/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0132 - root_mean_squared_error: 0.1151
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0128 - root_mean_squared_error: 0.1134 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0586
# Epoch 19/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0129 - root_mean_squared_error: 0.1134 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613
# Epoch 20/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0191 - root_mean_squared_error: 0.1383 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0620
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0126 - root_mean_squared_error: 0.1122 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0607
# Epoch 22/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0123 - root_mean_squared_error: 0.1110 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0635
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0136 - root_mean_squared_error: 0.1164 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0612
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0137 - root_mean_squared_error: 0.1168 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0602
# Epoch 25/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0595
# Epoch 26/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0180 - root_mean_squared_error: 0.1343 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0627
# Epoch 27/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0120 - root_mean_squared_error: 0.1096 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1171
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0109 - root_mean_squared_error: 0.1046 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0758
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0180 - root_mean_squared_error: 0.1341 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0650
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0100 - root_mean_squared_error: 0.0997 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0638
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0112 - root_mean_squared_error: 0.1058 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1235
# Epoch 32/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0147 - root_mean_squared_error: 0.1213 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0653
# Epoch 33/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0106 - root_mean_squared_error: 0.1028 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0737
# Epoch 34/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0678
# Epoch 35/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0119 - root_mean_squared_error: 0.1089 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1244
# Epoch 37/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0114 - root_mean_squared_error: 0.1066 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1154
# Epoch 38/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0149 - root_mean_squared_error: 0.1222
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0565
# Epoch 39/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0111 - root_mean_squared_error: 0.1055 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0759
# Epoch 40/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0134 - root_mean_squared_error: 0.1159 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0616
# Epoch 41/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0177 - root_mean_squared_error: 0.1330 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0755
# Epoch 42/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0129 - root_mean_squared_error: 0.1136 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0624
# Epoch 43/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0102 - root_mean_squared_error: 0.1008 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1010
# Epoch 44/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0140 - root_mean_squared_error: 0.1181 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0621
# Epoch 45/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0710
# Epoch 46/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0111 - root_mean_squared_error: 0.1056 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0584
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0123 - root_mean_squared_error: 0.1108 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0720
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0119 - root_mean_squared_error: 0.1089 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0965
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0152 - root_mean_squared_error: 0.1232 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0962
# Epoch 50/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0105 - root_mean_squared_error: 0.1024 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0586

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.532998518149058 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Weddell_model_LT8/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 2ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.065335128420009
# MAE : 0.05354386706898394

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        4.213048e+06    3498103.449
# 1        2.659552e+06    1633675.726
# 2        1.359904e+06    1292668.399
# 3        1.189258e+06    1527666.815
# 4        1.892710e+06    2121949.701
# 5        3.300206e+06    3562381.775
# 6        4.513518e+06    5004305.983
# 7        5.465984e+06    6176613.878
# 8        6.158496e+06    6794233.093
# 9        6.355146e+06    7024136.637
# 10       6.314006e+06    6554271.388
# 11       5.399102e+06    6172281.701
# 12       4.122368e+06    4175225.799
# 13       2.106711e+06    1748380.899
# 14       1.022439e+06    1256191.080
# 15       1.163196e+06    1347295.364
# 16       1.995498e+06    2180184.677
# 17       3.389287e+06    3419295.982
# 18       4.683993e+06    4786146.771
# 19       5.592975e+06    5968132.718
# 20       6.270405e+06    6556934.174
# 21       6.417204e+06    6614949.980
# 22       6.432265e+06    6035207.368
# 23       5.664544e+06    5274244.730
# 24       4.127568e+06    3505146.372
# 25       2.022693e+06    1478130.228
# 26       9.498596e+05    1096780.503
# 27       1.002350e+06    1387234.069
# 28       1.827678e+06    2128693.591
# 29       3.239218e+06    3313318.704
# 30       4.392736e+06    4218076.656
# 31       5.376032e+06    5257641.941
# 32       5.937802e+06    5956603.340
# 33       6.342698e+06    6256062.049
# 34       6.133850e+06    5974548.305
# 35       5.401994e+06    5569396.731
# 36       3.871128e+06    3684108.410
# 37       1.941911e+06    1451614.707
# 38       1.287248e+06    1089888.684
# 39       1.382618e+06    1255222.909
# 40       2.171476e+06    1704492.279
# 41       3.382240e+06    2563551.804
# 42       4.520036e+06    3668127.143
# 43       5.462153e+06    4805519.784
# 44       6.079344e+06    5524445.234
# 45       6.296655e+06    6006669.861
# 46       6.315888e+06    5507961.583

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
