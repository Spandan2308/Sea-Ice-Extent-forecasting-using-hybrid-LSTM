# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Indian_Extent = pd.read_excel(filepath, sheet_name='Indian-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Indian_Extent)
fp.date_time(Indian_Extent)
# Out:
#           Extent       Date
# 0     376618.799 1979-01-01
# 1     211788.726 1979-02-01
# 2     262868.141 1979-03-01
# 3     698377.304 1979-04-01
# 4    1252407.727 1979-05-01
# ..           ...        ...
# 533  1520776.003 2023-06-01
# 534  2076164.165 2023-07-01
# 535  2731799.027 2023-08-01
# 536  3179384.692 2023-09-01
# 537  3301335.210 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Indian_Extent['Extent'] = scaler.fit_transform(Indian_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 8
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Indian_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((519, 12, 1), (519,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Indian_model_LT8/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2610 - root_mean_squared_error: 0.5109INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 17s 211ms/step - loss: 0.2610 - root_mean_squared_error: 0.5109 - val_loss: 0.2074 - val_root_mean_squared_error: 0.4554
# Epoch 2/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.1722 - root_mean_squared_error: 0.4150INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 10s 196ms/step - loss: 0.1696 - root_mean_squared_error: 0.4118 - val_loss: 0.1094 - val_root_mean_squared_error: 0.3307
# Epoch 3/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.1172 - root_mean_squared_error: 0.3424INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 10s 194ms/step - loss: 0.1178 - root_mean_squared_error: 0.3432 - val_loss: 0.0984 - val_root_mean_squared_error: 0.3137
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1049 - root_mean_squared_error: 0.3238INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 10s 197ms/step - loss: 0.1054 - root_mean_squared_error: 0.3247 - val_loss: 0.0890 - val_root_mean_squared_error: 0.2983
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0932 - root_mean_squared_error: 0.3053INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 10s 191ms/step - loss: 0.0935 - root_mean_squared_error: 0.3057 - val_loss: 0.0755 - val_root_mean_squared_error: 0.2749
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0757 - root_mean_squared_error: 0.2752INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 11s 212ms/step - loss: 0.0757 - root_mean_squared_error: 0.2752 - val_loss: 0.0516 - val_root_mean_squared_error: 0.2271
# Epoch 7/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0425 - root_mean_squared_error: 0.2062INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 12s 234ms/step - loss: 0.0419 - root_mean_squared_error: 0.2046 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1358
# Epoch 8/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0178 - root_mean_squared_error: 0.1333INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 12s 232ms/step - loss: 0.0182 - root_mean_squared_error: 0.1348 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0955
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0130 - root_mean_squared_error: 0.1140INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 12s 233ms/step - loss: 0.0130 - root_mean_squared_error: 0.1140 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0813
# Epoch 10/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0115 - root_mean_squared_error: 0.1072 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0849
# Epoch 11/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0108 - root_mean_squared_error: 0.1038 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 12/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0087 - root_mean_squared_error: 0.0935 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0850
# Epoch 13/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0086 - root_mean_squared_error: 0.0930 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0882
# Epoch 14/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0080 - root_mean_squared_error: 0.0895INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 12s 226ms/step - loss: 0.0080 - root_mean_squared_error: 0.0893 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0785
# Epoch 15/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0089 - root_mean_squared_error: 0.0944INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 11s 215ms/step - loss: 0.0088 - root_mean_squared_error: 0.0939 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0721
# Epoch 16/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0079 - root_mean_squared_error: 0.0887 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0736
# Epoch 17/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0076 - root_mean_squared_error: 0.0872INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 11s 210ms/step - loss: 0.0076 - root_mean_squared_error: 0.0871 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0676
# Epoch 18/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0081 - root_mean_squared_error: 0.0900 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0891
# Epoch 19/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0073 - root_mean_squared_error: 0.0857 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0720
# Epoch 20/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0077 - root_mean_squared_error: 0.0878 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0756
# Epoch 21/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0072 - root_mean_squared_error: 0.0850 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0698
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0066 - root_mean_squared_error: 0.0811INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 12s 230ms/step - loss: 0.0066 - root_mean_squared_error: 0.0811 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0664
# Epoch 23/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0067 - root_mean_squared_error: 0.0819 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0899
# Epoch 24/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0068 - root_mean_squared_error: 0.0822 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0839
# Epoch 25/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0071 - root_mean_squared_error: 0.0840 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0731
# Epoch 26/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0065 - root_mean_squared_error: 0.0807 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0717
# Epoch 27/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0062 - root_mean_squared_error: 0.0789 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0757
# Epoch 28/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0064 - root_mean_squared_error: 0.0800 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0831
# Epoch 29/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0055 - root_mean_squared_error: 0.0740 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0860
# Epoch 30/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0058 - root_mean_squared_error: 0.0764 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0776
# Epoch 31/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0059 - root_mean_squared_error: 0.0771 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0665
# Epoch 32/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0061 - root_mean_squared_error: 0.0781 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0665
# Epoch 33/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0057 - root_mean_squared_error: 0.0756 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0684
# Epoch 34/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0061 - root_mean_squared_error: 0.0779 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0833
# Epoch 35/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0061 - root_mean_squared_error: 0.0781 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0713
# Epoch 36/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0060 - root_mean_squared_error: 0.0778 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0734
# Epoch 37/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0052 - root_mean_squared_error: 0.0722 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0765
# Epoch 38/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0058 - root_mean_squared_error: 0.0759 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0705
# Epoch 39/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0052 - root_mean_squared_error: 0.0724 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0702
# Epoch 40/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0058 - root_mean_squared_error: 0.0760 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0715
# Epoch 41/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0053 - root_mean_squared_error: 0.0725INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 12s 224ms/step - loss: 0.0053 - root_mean_squared_error: 0.0725 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0660
# Epoch 42/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0057 - root_mean_squared_error: 0.0755 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0699
# Epoch 43/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0052 - root_mean_squared_error: 0.0721 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0853
# Epoch 44/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0057 - root_mean_squared_error: 0.0755 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0735
# Epoch 45/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0054 - root_mean_squared_error: 0.0735INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 11s 210ms/step - loss: 0.0054 - root_mean_squared_error: 0.0735 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613
# Epoch 46/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0049 - root_mean_squared_error: 0.0702 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0737
# Epoch 47/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0051 - root_mean_squared_error: 0.0714 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0714
# Epoch 48/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0051 - root_mean_squared_error: 0.0713INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 13s 249ms/step - loss: 0.0051 - root_mean_squared_error: 0.0712 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0557
# Epoch 49/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0054 - root_mean_squared_error: 0.0733 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0653
# Epoch 50/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0052 - root_mean_squared_error: 0.0718 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0816

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 4.055018536249796 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Indian_model_LT8/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 11ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.04931320374579103
# MAE : 0.03857690201659854

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.268972e+06    1128752.378
# 1        4.158172e+05     522831.371
# 2        2.286651e+05     346601.304
# 3        2.310030e+05     444914.605
# 4        4.353343e+05     827036.916
# 5        1.051083e+06    1142021.216
# 6        1.845206e+06    1885693.654
# 7        2.533501e+06    2542569.663
# 8        2.976682e+06    3107373.845
# 9        3.214806e+06    3488175.444
# 10       3.309614e+06    3746306.528
# 11       3.011900e+06    2942322.822
# 12       1.772515e+06    1507212.955
# 13       6.212463e+05     648507.437
# 14       2.749038e+05     352564.010
# 15       2.588483e+05     453587.503
# 16       5.730405e+05     841043.793
# 17       1.320669e+06    1433155.266
# 18       2.065346e+06    2163687.646
# 19       2.673738e+06    2848863.133
# 20       3.067952e+06    3420877.229
# 21       3.318166e+06    3752886.938
# 22       3.386578e+06    3778951.818
# 23       2.920340e+06    2892177.223
# 24       1.495675e+06    1467610.428
# 25       4.647271e+05     377930.941
# 26       2.525317e+05     146440.376
# 27       2.473612e+05     244356.473
# 28       4.936730e+05     612217.566
# 29       1.176616e+06    1261627.075
# 30       2.004994e+06    1720565.225
# 31       2.699979e+06    2564005.541
# 32       3.172590e+06    2983773.529
# 33       3.428258e+06    3372645.223
# 34       3.407385e+06    3589687.043
# 35       2.503050e+06    2669385.189
# 36       8.136806e+05    1095398.946
# 37       3.034785e+05     319828.826
# 38       1.832921e+05     162541.182
# 39       1.902640e+05     179564.232
# 40       4.204841e+05     593196.107
# 41       1.102291e+06    1053508.835
# 42       1.877298e+06    1520776.003
# 43       2.511208e+06    2076164.165
# 44       3.001434e+06    2731799.027
# 45       3.238032e+06    3179384.692
# 46       3.315323e+06    3301335.210

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 15ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
