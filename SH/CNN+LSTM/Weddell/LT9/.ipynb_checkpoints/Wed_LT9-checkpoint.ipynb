# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Weddell_Extent = pd.read_excel(filepath, sheet_name='Weddell-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Weddell_Extent)
fp.date_time(Weddell_Extent)
# Out:
#           Extent       Date
# 0    2136510.859 1979-01-01
# 1    1243495.891 1979-02-01
# 2    1699053.449 1979-03-01
# 3    2617442.085 1979-04-01
# 4    3852934.206 1979-05-01
# ..           ...        ...
# 533  3668127.143 2023-06-01
# 534  4805519.784 2023-07-01
# 535  5524445.234 2023-08-01
# 536  6006669.861 2023-09-01
# 537  5507961.583 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Weddell_Extent['Extent'] = scaler.fit_transform(Weddell_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 9
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Weddell_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((518, 12, 1), (518,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Weddell_model_LT9/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2776 - root_mean_squared_error: 0.5269
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 8s 99ms/step - loss: 0.2747 - root_mean_squared_error: 0.5242 - val_loss: 0.2510 - val_root_mean_squared_error: 0.5010
# Epoch 2/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.2123 - root_mean_squared_error: 0.4608
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 5s 88ms/step - loss: 0.2101 - root_mean_squared_error: 0.4584 - val_loss: 0.2295 - val_root_mean_squared_error: 0.4791
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1706 - root_mean_squared_error: 0.4131
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.1700 - root_mean_squared_error: 0.4123 - val_loss: 0.2068 - val_root_mean_squared_error: 0.4548
# Epoch 4/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.1407 - root_mean_squared_error: 0.3751
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.1387 - root_mean_squared_error: 0.3724 - val_loss: 0.1813 - val_root_mean_squared_error: 0.4258
# Epoch 5/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.1149 - root_mean_squared_error: 0.3390
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.1107 - root_mean_squared_error: 0.3327 - val_loss: 0.1610 - val_root_mean_squared_error: 0.4013
# Epoch 6/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0908 - root_mean_squared_error: 0.3014
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.0897 - root_mean_squared_error: 0.2994 - val_loss: 0.1335 - val_root_mean_squared_error: 0.3654
# Epoch 7/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0683 - root_mean_squared_error: 0.2613
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0675 - root_mean_squared_error: 0.2599 - val_loss: 0.1136 - val_root_mean_squared_error: 0.3371
# Epoch 8/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0526 - root_mean_squared_error: 0.2293
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 4s 81ms/step - loss: 0.0525 - root_mean_squared_error: 0.2292 - val_loss: 0.0854 - val_root_mean_squared_error: 0.2923
# Epoch 9/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0414 - root_mean_squared_error: 0.2035
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0412 - root_mean_squared_error: 0.2029 - val_loss: 0.0735 - val_root_mean_squared_error: 0.2711
# Epoch 10/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0337 - root_mean_squared_error: 0.1836
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0338 - root_mean_squared_error: 0.1838 - val_loss: 0.0475 - val_root_mean_squared_error: 0.2179
# Epoch 11/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0216 - root_mean_squared_error: 0.1469
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0232 - root_mean_squared_error: 0.1524 - val_loss: 0.0356 - val_root_mean_squared_error: 0.1888
# Epoch 12/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0184 - root_mean_squared_error: 0.1356
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0198 - root_mean_squared_error: 0.1405 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1436
# Epoch 13/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0160 - root_mean_squared_error: 0.1266
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0162 - root_mean_squared_error: 0.1272 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1359
# Epoch 14/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0135 - root_mean_squared_error: 0.1160
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0936
# Epoch 15/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0175 - root_mean_squared_error: 0.1323
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0190 - root_mean_squared_error: 0.1378 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0689
# Epoch 16/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0163 - root_mean_squared_error: 0.1275
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0188 - root_mean_squared_error: 0.1371 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0655
# Epoch 17/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0148 - root_mean_squared_error: 0.1215
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0150 - root_mean_squared_error: 0.1227 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0653
# Epoch 18/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0114 - root_mean_squared_error: 0.1068
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0586
# Epoch 19/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0133 - root_mean_squared_error: 0.1152 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0810
# Epoch 20/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0138 - root_mean_squared_error: 0.1176 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0596
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0119 - root_mean_squared_error: 0.1092 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0829
# Epoch 22/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0122 - root_mean_squared_error: 0.1106 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0586
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0173 - root_mean_squared_error: 0.1317 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0665
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0097 - root_mean_squared_error: 0.0983 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1092
# Epoch 25/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0127 - root_mean_squared_error: 0.1128 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0634
# Epoch 26/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0091 - root_mean_squared_error: 0.0955 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0593
# Epoch 27/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0121 - root_mean_squared_error: 0.1102 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0631
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0113 - root_mean_squared_error: 0.1061 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0905
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0101 - root_mean_squared_error: 0.1007 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0926
# Epoch 30/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0124 - root_mean_squared_error: 0.1114
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT9\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0129 - root_mean_squared_error: 0.1135 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0543
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0109 - root_mean_squared_error: 0.1045 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0567
# Epoch 32/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0147 - root_mean_squared_error: 0.1212 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0680
# Epoch 33/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0125 - root_mean_squared_error: 0.1116 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0607
# Epoch 34/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0118 - root_mean_squared_error: 0.1085 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0821
# Epoch 35/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0164 - root_mean_squared_error: 0.1279 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0991
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0131 - root_mean_squared_error: 0.1146 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0731
# Epoch 37/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0094 - root_mean_squared_error: 0.0971 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0593
# Epoch 38/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0108 - root_mean_squared_error: 0.1038 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0579
# Epoch 39/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0804
# Epoch 40/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0162 - root_mean_squared_error: 0.1272 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0927
# Epoch 41/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0155 - root_mean_squared_error: 0.1246 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0561
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0125 - root_mean_squared_error: 0.1118 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0593
# Epoch 43/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0695
# Epoch 44/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0119 - root_mean_squared_error: 0.1091 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0678
# Epoch 45/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0131 - root_mean_squared_error: 0.1144 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0908
# Epoch 46/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0134 - root_mean_squared_error: 0.1158 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0889
# Epoch 47/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0096 - root_mean_squared_error: 0.0981 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0555
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0109 - root_mean_squared_error: 0.1042 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0669
# Epoch 49/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0122 - root_mean_squared_error: 0.1105 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0582
# Epoch 50/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0097 - root_mean_squared_error: 0.0986 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0563

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.6744584282239279 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Weddell_model_LT9/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 16ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.07197016039258329
# MAE : 0.057958814956371944

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        2.162874e+06    1633675.726
# 1        1.627707e+06    1292668.399
# 2        1.477844e+06    1527666.815
# 3        1.980819e+06    2121949.701
# 4        3.077128e+06    3562381.775
# 5        4.620312e+06    5004305.983
# 6        5.674446e+06    6176613.878
# 7        6.395160e+06    6794233.093
# 8        6.455537e+06    7024136.637
# 9        6.412465e+06    6554271.388
# 10       5.418238e+06    6172281.701
# 11       3.845652e+06    4175225.799
# 12       1.905715e+06    1748380.899
# 13       1.170562e+06    1256191.080
# 14       1.041836e+06    1347295.364
# 15       2.244898e+06    2180184.677
# 16       3.216899e+06    3419295.982
# 17       4.975659e+06    4786146.771
# 18       5.641456e+06    5968132.718
# 19       6.648541e+06    6556934.174
# 20       6.526713e+06    6614949.980
# 21       6.638437e+06    6035207.368
# 22       5.700442e+06    5274244.730
# 23       4.180930e+06    3505146.372
# 24       1.739701e+06    1478130.228
# 25       1.071396e+06    1096780.503
# 26       1.009805e+06    1387234.069
# 27       2.009603e+06    2128693.591
# 28       3.162040e+06    3313318.704
# 29       4.718923e+06    4218076.656
# 30       5.491888e+06    5257641.941
# 31       6.298876e+06    5956603.340
# 32       6.492452e+06    6256062.049
# 33       6.235888e+06    5974548.305
# 34       5.490582e+06    5569396.731
# 35       3.927595e+06    3684108.410
# 36       1.999405e+06    1451614.707
# 37       1.314019e+06    1089888.684
# 38       1.657125e+06    1255222.909
# 39       2.491104e+06    1704492.279
# 40       3.651247e+06    2563551.804
# 41       4.952798e+06    3668127.143
# 42       5.748202e+06    4805519.784
# 43       6.418528e+06    5524445.234
# 44       6.475834e+06    6006669.861
# 45       6.420938e+06    5507961.583

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
