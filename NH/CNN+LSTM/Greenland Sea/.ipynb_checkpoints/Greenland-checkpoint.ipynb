# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Greenland = pd.read_excel(filepath, sheet_name='Greenland-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Greenland)
fp.date_time(Greenland)
# Out:
#           Extent       Date
# 0    1076123.146 1979-01-01
# 1    1099248.063 1979-02-01
# 2    1036964.901 1979-03-01
# 3     958927.937 1979-04-01
# 4     823812.694 1979-05-01
# ..           ...        ...
# 533   721350.515 2023-06-01
# 534   459033.164 2023-07-01
# 535   282045.909 2023-08-01
# 536   270397.608 2023-09-01
# 537   449910.973 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Greenland['Extent'] = scaler.fit_transform(Greenland['Extent'].values.reshape(-1, 1))

# %%
extent = Greenland['Extent']
W_S=12
X,y = fp.df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((526, 12, 1), (526,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
#model.add(LSTM(64, kernel_constraint=MaxNorm(1.0), activation='relu', return_sequences=True))
#model.add(Dropout(0.2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Greenland_model/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.3369 - root_mean_squared_error: 0.5805
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 9s 105ms/step - loss: 0.3311 - root_mean_squared_error: 0.5754 - val_loss: 0.1577 - val_root_mean_squared_error: 0.3971
# Epoch 2/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.2632 - root_mean_squared_error: 0.5131
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 3s 65ms/step - loss: 0.2648 - root_mean_squared_error: 0.5146 - val_loss: 0.1266 - val_root_mean_squared_error: 0.3558
# Epoch 3/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.2240 - root_mean_squared_error: 0.4733
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 93ms/step - loss: 0.2199 - root_mean_squared_error: 0.4690 - val_loss: 0.1044 - val_root_mean_squared_error: 0.3231
# Epoch 4/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.1798 - root_mean_squared_error: 0.4241
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.1801 - root_mean_squared_error: 0.4243 - val_loss: 0.0832 - val_root_mean_squared_error: 0.2884
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1472 - root_mean_squared_error: 0.3837
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 99ms/step - loss: 0.1464 - root_mean_squared_error: 0.3826 - val_loss: 0.0640 - val_root_mean_squared_error: 0.2530
# Epoch 6/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.1157 - root_mean_squared_error: 0.3402
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 95ms/step - loss: 0.1159 - root_mean_squared_error: 0.3404 - val_loss: 0.0519 - val_root_mean_squared_error: 0.2279
# Epoch 7/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0962 - root_mean_squared_error: 0.3102
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 97ms/step - loss: 0.0928 - root_mean_squared_error: 0.3047 - val_loss: 0.0397 - val_root_mean_squared_error: 0.1993
# Epoch 8/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0722 - root_mean_squared_error: 0.2687
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0720 - root_mean_squared_error: 0.2683 - val_loss: 0.0305 - val_root_mean_squared_error: 0.1746
# Epoch 9/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0541 - root_mean_squared_error: 0.2326
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 97ms/step - loss: 0.0548 - root_mean_squared_error: 0.2340 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1539
# Epoch 10/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0440 - root_mean_squared_error: 0.2098
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0444 - root_mean_squared_error: 0.2106 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1378
# Epoch 11/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0327 - root_mean_squared_error: 0.1810
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0324 - root_mean_squared_error: 0.1800 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1221
# Epoch 12/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0236 - root_mean_squared_error: 0.1538
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 103ms/step - loss: 0.0233 - root_mean_squared_error: 0.1527 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0940
# Epoch 13/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0194 - root_mean_squared_error: 0.1391
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0192 - root_mean_squared_error: 0.1384 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0820
# Epoch 14/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0156 - root_mean_squared_error: 0.1249 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 15/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0124 - root_mean_squared_error: 0.1115 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0886
# Epoch 16/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0109 - root_mean_squared_error: 0.1045
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0108 - root_mean_squared_error: 0.1041 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0684
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0108 - root_mean_squared_error: 0.1040 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0755
# Epoch 18/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0107 - root_mean_squared_error: 0.1033 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0709
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0103 - root_mean_squared_error: 0.1014
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0654
# Epoch 20/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0096 - root_mean_squared_error: 0.0977 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0698
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0089 - root_mean_squared_error: 0.0944 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0803
# Epoch 22/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0084 - root_mean_squared_error: 0.0915 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1054
# Epoch 23/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0092 - root_mean_squared_error: 0.0960
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0092 - root_mean_squared_error: 0.0960 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0647
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0083 - root_mean_squared_error: 0.0911 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0842
# Epoch 25/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0099 - root_mean_squared_error: 0.0993 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0690
# Epoch 26/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0085 - root_mean_squared_error: 0.0924
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0085 - root_mean_squared_error: 0.0922 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0579
# Epoch 27/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0096 - root_mean_squared_error: 0.0979 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0636
# Epoch 28/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0069 - root_mean_squared_error: 0.0833
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0069 - root_mean_squared_error: 0.0833 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0568
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0730
# Epoch 30/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0077 - root_mean_squared_error: 0.0879 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0811
# Epoch 31/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0083 - root_mean_squared_error: 0.0909
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0083 - root_mean_squared_error: 0.0913 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0559
# Epoch 32/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0084 - root_mean_squared_error: 0.0918
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model\assets
# INFO:tensorflow:Assets written to: Greenland_model\assets
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0085 - root_mean_squared_error: 0.0925 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0558
# Epoch 33/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0104 - root_mean_squared_error: 0.1020 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0582
# Epoch 34/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0077 - root_mean_squared_error: 0.0875 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0847
# Epoch 35/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0083 - root_mean_squared_error: 0.0909 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613
# Epoch 36/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0075 - root_mean_squared_error: 0.0867 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0567
# Epoch 37/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0093 - root_mean_squared_error: 0.0967 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679
# Epoch 38/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0087 - root_mean_squared_error: 0.0931 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0853
# Epoch 39/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0087 - root_mean_squared_error: 0.0935 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0686
# Epoch 40/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0087 - root_mean_squared_error: 0.0935 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0619
# Epoch 41/50
# 53/53 [==============================] - 1s 9ms/step - loss: 0.0073 - root_mean_squared_error: 0.0853 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0698
# Epoch 42/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0086 - root_mean_squared_error: 0.0928 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0565
# Epoch 43/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0085 - root_mean_squared_error: 0.0922 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0662
# Epoch 44/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0082 - root_mean_squared_error: 0.0905 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0669
# Epoch 45/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0087 - root_mean_squared_error: 0.0934 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0709
# Epoch 46/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0085 - root_mean_squared_error: 0.0919 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0693
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0100 - root_mean_squared_error: 0.1002 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0858
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0073 - root_mean_squared_error: 0.0852 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0664
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0094 - root_mean_squared_error: 0.0969 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610
# Epoch 50/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0083 - root_mean_squared_error: 0.0910 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0600

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.8897616426150003 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Greenland_model/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 7ms/step

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       563857.375000     656631.502
# 1       470639.093750     604702.636
# 2       370274.375000     436530.907
# 3       210676.875000     283162.646
# 4       227473.015625     212475.431
# 5       318823.625000     386546.857
# 6       435675.937500     547183.986
# 7       613875.500000     584596.262
# 8       613309.250000     584830.109
# 9       632974.250000     641562.292
# 10      638607.000000     734946.437
# 11      695642.500000     777596.225
# 12      684322.687500     687087.673
# 13      551971.000000     622337.816
# 14      414195.812500     467232.074
# 15      250215.390625     297495.641
# 16      243508.656250     268909.854
# 17      338207.218750     408072.791
# 18      482338.406250     552314.148
# 19      600748.687500     651062.408
# 20      651656.250000     695022.674
# 21      713565.812500     670974.305
# 22      680594.750000     710035.543
# 23      690190.562500     699672.538
# 24      654653.687500     730897.021
# 25      607897.812500     588598.988
# 26      431062.781250     281754.041
# 27      150753.984375     117830.266
# 28      178565.343750      81838.250
# 29      271305.187500     291418.462
# 30      454332.781250     452417.079
# 31      563355.500000     576361.148
# 32      639161.187500     676218.054
# 33      698892.750000     698410.066
# 34      703181.812500     696094.179
# 35      672043.125000     751102.742
# 36      643896.750000     765802.952
# 37      555488.437500     597649.311
# 38      328012.093750     376029.266
# 39      134181.734375     278536.574
# 40      219221.828125     285351.521
# 41      340848.843750     365256.138
# 42      488338.625000     488293.212
# 43      601387.250000     635073.900
# 44      706976.625000     684651.888
# 45      709500.250000     698053.275
# 46      721326.875000     846211.943
# 47      765899.625000     831596.370
# 48      699063.187500     834849.724
# 49      637686.500000     721350.515
# 50      430879.843750     459033.164
# 51      211563.109375     282045.909
# 52      203329.765625     270397.608
# 53      324009.593750     449910.973

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 4ms/step

# %%
mse = mean_squared_error(y, predictions)
print(mse)
# Out:
# 0.005153421539269742

# %%
mae = mean_absolute_error(y, predictions)
print(mae)
# Out:
# 0.057585256094846375

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
