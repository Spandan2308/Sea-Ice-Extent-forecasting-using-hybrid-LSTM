# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Ross_Extent = pd.read_excel(filepath, sheet_name='Ross-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Ross_Extent)
fp.date_time(Ross_Extent)
# Out:
#           Extent       Date
# 0    1040455.516 1979-01-01
# 1     239334.118 1979-02-01
# 2     557365.154 1979-03-01
# 3    2054855.924 1979-04-01
# 4    2973925.625 1979-05-01
# ..           ...        ...
# 533  3137598.938 2023-06-01
# 534  3201783.453 2023-07-01
# 535  2973294.266 2023-08-01
# 536  3354839.711 2023-09-01
# 537  3325613.245 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Ross_Extent['Extent'] = scaler.fit_transform(Ross_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 5
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Ross_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((522, 12, 1), (522,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Ross_model_LT5/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.3693 - root_mean_squared_error: 0.6077INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 17s 213ms/step - loss: 0.3691 - root_mean_squared_error: 0.6075 - val_loss: 0.2793 - val_root_mean_squared_error: 0.5285
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1891 - root_mean_squared_error: 0.4349INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 190ms/step - loss: 0.1876 - root_mean_squared_error: 0.4331 - val_loss: 0.0574 - val_root_mean_squared_error: 0.2396
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0500 - root_mean_squared_error: 0.2236INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 185ms/step - loss: 0.0500 - root_mean_squared_error: 0.2236 - val_loss: 0.0552 - val_root_mean_squared_error: 0.2349
# Epoch 4/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0468 - root_mean_squared_error: 0.2163INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 196ms/step - loss: 0.0476 - root_mean_squared_error: 0.2181 - val_loss: 0.0545 - val_root_mean_squared_error: 0.2334
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0460 - root_mean_squared_error: 0.2145INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 187ms/step - loss: 0.0460 - root_mean_squared_error: 0.2145 - val_loss: 0.0527 - val_root_mean_squared_error: 0.2295
# Epoch 6/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0435 - root_mean_squared_error: 0.2087INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 183ms/step - loss: 0.0434 - root_mean_squared_error: 0.2084 - val_loss: 0.0505 - val_root_mean_squared_error: 0.2247
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0417 - root_mean_squared_error: 0.2043INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 192ms/step - loss: 0.0417 - root_mean_squared_error: 0.2043 - val_loss: 0.0488 - val_root_mean_squared_error: 0.2210
# Epoch 8/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0401 - root_mean_squared_error: 0.2001INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 183ms/step - loss: 0.0399 - root_mean_squared_error: 0.1998 - val_loss: 0.0459 - val_root_mean_squared_error: 0.2142
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0348 - root_mean_squared_error: 0.1864INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 195ms/step - loss: 0.0348 - root_mean_squared_error: 0.1864 - val_loss: 0.0428 - val_root_mean_squared_error: 0.2070
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0322 - root_mean_squared_error: 0.1795INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 189ms/step - loss: 0.0321 - root_mean_squared_error: 0.1793 - val_loss: 0.0391 - val_root_mean_squared_error: 0.1978
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0293 - root_mean_squared_error: 0.1711INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 189ms/step - loss: 0.0292 - root_mean_squared_error: 0.1708 - val_loss: 0.0358 - val_root_mean_squared_error: 0.1891
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0270 - root_mean_squared_error: 0.1643INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 185ms/step - loss: 0.0269 - root_mean_squared_error: 0.1641 - val_loss: 0.0329 - val_root_mean_squared_error: 0.1813
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0241 - root_mean_squared_error: 0.1552INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 192ms/step - loss: 0.0243 - root_mean_squared_error: 0.1560 - val_loss: 0.0318 - val_root_mean_squared_error: 0.1783
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0226 - root_mean_squared_error: 0.1505INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 189ms/step - loss: 0.0226 - root_mean_squared_error: 0.1505 - val_loss: 0.0273 - val_root_mean_squared_error: 0.1651
# Epoch 15/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0221 - root_mean_squared_error: 0.1488INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 184ms/step - loss: 0.0221 - root_mean_squared_error: 0.1486 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1578
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0204 - root_mean_squared_error: 0.1429INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0204 - root_mean_squared_error: 0.1429 - val_loss: 0.0231 - val_root_mean_squared_error: 0.1521
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0181 - root_mean_squared_error: 0.1345INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 190ms/step - loss: 0.0181 - root_mean_squared_error: 0.1345 - val_loss: 0.0220 - val_root_mean_squared_error: 0.1485
# Epoch 18/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0173 - root_mean_squared_error: 0.1316 - val_loss: 0.0223 - val_root_mean_squared_error: 0.1494
# Epoch 19/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0172 - root_mean_squared_error: 0.1313INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 184ms/step - loss: 0.0172 - root_mean_squared_error: 0.1313 - val_loss: 0.0195 - val_root_mean_squared_error: 0.1398
# Epoch 20/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0159 - root_mean_squared_error: 0.1260 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1415
# Epoch 21/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0172 - root_mean_squared_error: 0.1312INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 13s 243ms/step - loss: 0.0174 - root_mean_squared_error: 0.1321 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1369
# Epoch 22/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0154 - root_mean_squared_error: 0.1242INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 14s 261ms/step - loss: 0.0154 - root_mean_squared_error: 0.1242 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1343
# Epoch 23/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0156 - root_mean_squared_error: 0.1249INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 13s 249ms/step - loss: 0.0157 - root_mean_squared_error: 0.1251 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1327
# Epoch 24/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0140 - root_mean_squared_error: 0.1183 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1358
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0136 - root_mean_squared_error: 0.1167INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0136 - root_mean_squared_error: 0.1167 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1298
# Epoch 26/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0158 - root_mean_squared_error: 0.1255 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1305
# Epoch 27/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0125 - root_mean_squared_error: 0.1116INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 190ms/step - loss: 0.0126 - root_mean_squared_error: 0.1122 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1250
# Epoch 28/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0129 - root_mean_squared_error: 0.1135 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1263
# Epoch 29/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0135 - root_mean_squared_error: 0.1163INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 183ms/step - loss: 0.0135 - root_mean_squared_error: 0.1163 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1234
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0130 - root_mean_squared_error: 0.1141INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 192ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1221
# Epoch 31/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0133 - root_mean_squared_error: 0.1154 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1254
# Epoch 32/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0137 - root_mean_squared_error: 0.1171 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1241
# Epoch 33/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0121 - root_mean_squared_error: 0.1099 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1272
# Epoch 34/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0134 - root_mean_squared_error: 0.1158 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1280
# Epoch 35/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0120 - root_mean_squared_error: 0.1094INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 188ms/step - loss: 0.0119 - root_mean_squared_error: 0.1091 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1187
# Epoch 36/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0126 - root_mean_squared_error: 0.1121 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1192
# Epoch 37/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0120 - root_mean_squared_error: 0.1097INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 183ms/step - loss: 0.0120 - root_mean_squared_error: 0.1097 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1175
# Epoch 38/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0120 - root_mean_squared_error: 0.1097INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0121 - root_mean_squared_error: 0.1098 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1172
# Epoch 39/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0119 - root_mean_squared_error: 0.1089 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1177
# Epoch 40/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0116 - root_mean_squared_error: 0.1078INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0116 - root_mean_squared_error: 0.1078 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1165
# Epoch 41/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0110 - root_mean_squared_error: 0.1048 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1317
# Epoch 42/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0117 - root_mean_squared_error: 0.1079INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 184ms/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1153
# Epoch 43/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0111 - root_mean_squared_error: 0.1056 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1159
# Epoch 44/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0111 - root_mean_squared_error: 0.1056 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1155
# Epoch 45/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0113 - root_mean_squared_error: 0.1063 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1162
# Epoch 46/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0110 - root_mean_squared_error: 0.1047INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 194ms/step - loss: 0.0109 - root_mean_squared_error: 0.1045 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133
# Epoch 47/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0104 - root_mean_squared_error: 0.1019INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 190ms/step - loss: 0.0105 - root_mean_squared_error: 0.1022 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1124
# Epoch 48/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0107 - root_mean_squared_error: 0.1032INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 184ms/step - loss: 0.0107 - root_mean_squared_error: 0.1034 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1110
# Epoch 49/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0099 - root_mean_squared_error: 0.0994 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1124
# Epoch 50/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0106 - root_mean_squared_error: 0.1028INFO:tensorflow:Assets written to: Ross_model_LT5\assets
# 53/53 [==============================] - 10s 192ms/step - loss: 0.0106 - root_mean_squared_error: 0.1028 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1074

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 6.308743047714233 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Ross_model_LT5/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 25ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.12440542157859696
# MAE : 0.09978914143813032

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        3.830590e+06    3885746.442
# 1        3.661390e+06    3909211.179
# 2        3.132512e+06    3499167.351
# 3        2.305746e+06    2715890.297
# 4        1.483970e+06    1053272.694
# 5        8.676951e+05     368862.123
# 6        1.031035e+06     979418.298
# 7        1.927110e+06    2086269.569
# 8        2.728818e+06    2852731.016
# 9        3.112860e+06    3452823.613
# 10       3.387507e+06    3846843.974
# 11       3.557421e+06    4005222.451
# 12       3.572778e+06    4129684.505
# 13       3.463674e+06    4130311.577
# 14       3.034842e+06    3987590.376
# 15       2.329908e+06    2531664.630
# 16       1.547026e+06     864796.598
# 17       9.630716e+05     366098.623
# 18       1.141617e+06    1324063.884
# 19       2.042020e+06    2094086.684
# 20       2.973462e+06    2706708.526
# 21       3.414962e+06    3380172.167
# 22       3.712510e+06    3975727.475
# 23       3.916295e+06    4016497.161
# 24       3.982278e+06    4134594.766
# 25       3.877446e+06    4278165.933
# 26       3.362832e+06    3893945.909
# 27       2.533192e+06    2389171.083
# 28       1.635614e+06     896425.932
# 29       9.485589e+05     251374.224
# 30       1.119752e+06     455056.048
# 31       2.130990e+06    1780625.872
# 32       3.039334e+06    2914989.101
# 33       3.452205e+06    3561620.245
# 34       3.794617e+06    3991717.506
# 35       4.025276e+06    4559070.778
# 36       4.056835e+06    4596327.081
# 37       3.968348e+06    4565650.139
# 38       3.460734e+06    4061902.846
# 39       2.567776e+06    2336900.967
# 40       1.648135e+06     696917.659
# 41       9.529903e+05     213657.789
# 42       1.090297e+06     765773.883
# 43       2.158327e+06    1951730.202
# 44       3.143266e+06    2610971.814
# 45       3.730302e+06    3137598.938
# 46       4.234796e+06    3201783.453
# 47       4.613846e+06    2973294.266
# 48       4.760338e+06    3354839.711
# 49       4.537488e+06    3325613.245

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 16ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
