# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Kara = pd.read_excel(filepath, sheet_name='Kara-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Kara)
fp.date_time(Kara)
# Out:
#          Extent       Date
# 0    917992.880 1979-01-01
# 1    917992.880 1979-02-01
# 2    917992.880 1979-03-01
# 3    917992.880 1979-04-01
# 4    917992.880 1979-05-01
# ..          ...        ...
# 533  728642.743 2023-06-01
# 534  437024.646 2023-07-01
# 535  202260.789 2023-08-01
# 536   98103.856 2023-09-01
# 537  260413.272 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Kara['Extent'] = scaler.fit_transform(Kara['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 5
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Kara['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((522, 12, 1), (522,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Kara_model_LT5/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.6271 - root_mean_squared_error: 0.7919INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 39s 506ms/step - loss: 0.6271 - root_mean_squared_error: 0.7919 - val_loss: 0.3833 - val_root_mean_squared_error: 0.6191
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2179 - root_mean_squared_error: 0.4668INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 24s 459ms/step - loss: 0.2179 - root_mean_squared_error: 0.4668 - val_loss: 0.1548 - val_root_mean_squared_error: 0.3934
# Epoch 3/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0880 - root_mean_squared_error: 0.2967INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 25s 483ms/step - loss: 0.0897 - root_mean_squared_error: 0.2996 - val_loss: 0.1433 - val_root_mean_squared_error: 0.3786
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0835 - root_mean_squared_error: 0.2890INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 27s 526ms/step - loss: 0.0833 - root_mean_squared_error: 0.2885 - val_loss: 0.1327 - val_root_mean_squared_error: 0.3643
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0766 - root_mean_squared_error: 0.2768INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 29s 557ms/step - loss: 0.0766 - root_mean_squared_error: 0.2768 - val_loss: 0.1218 - val_root_mean_squared_error: 0.3491
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0751 - root_mean_squared_error: 0.2741INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 25s 489ms/step - loss: 0.0746 - root_mean_squared_error: 0.2732 - val_loss: 0.1142 - val_root_mean_squared_error: 0.3380
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0680 - root_mean_squared_error: 0.2608INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 25s 489ms/step - loss: 0.0680 - root_mean_squared_error: 0.2608 - val_loss: 0.1061 - val_root_mean_squared_error: 0.3258
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0630 - root_mean_squared_error: 0.2510INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 20s 374ms/step - loss: 0.0630 - root_mean_squared_error: 0.2510 - val_loss: 0.0933 - val_root_mean_squared_error: 0.3055
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0577 - root_mean_squared_error: 0.2403INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 16s 309ms/step - loss: 0.0577 - root_mean_squared_error: 0.2403 - val_loss: 0.0833 - val_root_mean_squared_error: 0.2887
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0541 - root_mean_squared_error: 0.2325INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 26s 491ms/step - loss: 0.0541 - root_mean_squared_error: 0.2325 - val_loss: 0.0747 - val_root_mean_squared_error: 0.2734
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0522 - root_mean_squared_error: 0.2286INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 26s 490ms/step - loss: 0.0525 - root_mean_squared_error: 0.2291 - val_loss: 0.0678 - val_root_mean_squared_error: 0.2604
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0474 - root_mean_squared_error: 0.2177INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 26s 499ms/step - loss: 0.0474 - root_mean_squared_error: 0.2177 - val_loss: 0.0608 - val_root_mean_squared_error: 0.2466
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0421 - root_mean_squared_error: 0.2052INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 27s 516ms/step - loss: 0.0419 - root_mean_squared_error: 0.2047 - val_loss: 0.0543 - val_root_mean_squared_error: 0.2331
# Epoch 14/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0392 - root_mean_squared_error: 0.1980INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 26s 494ms/step - loss: 0.0392 - root_mean_squared_error: 0.1979 - val_loss: 0.0496 - val_root_mean_squared_error: 0.2227
# Epoch 15/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0410 - root_mean_squared_error: 0.2024INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 26s 495ms/step - loss: 0.0408 - root_mean_squared_error: 0.2020 - val_loss: 0.0461 - val_root_mean_squared_error: 0.2147
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0357 - root_mean_squared_error: 0.1890INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 26s 507ms/step - loss: 0.0357 - root_mean_squared_error: 0.1890 - val_loss: 0.0432 - val_root_mean_squared_error: 0.2077
# Epoch 17/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0329 - root_mean_squared_error: 0.1815INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 23s 435ms/step - loss: 0.0328 - root_mean_squared_error: 0.1812 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2026
# Epoch 18/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0313 - root_mean_squared_error: 0.1768INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 24s 464ms/step - loss: 0.0312 - root_mean_squared_error: 0.1766 - val_loss: 0.0371 - val_root_mean_squared_error: 0.1925
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0297 - root_mean_squared_error: 0.1724INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 24s 459ms/step - loss: 0.0297 - root_mean_squared_error: 0.1724 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1912
# Epoch 20/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0275 - root_mean_squared_error: 0.1659INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 22s 427ms/step - loss: 0.0275 - root_mean_squared_error: 0.1659 - val_loss: 0.0353 - val_root_mean_squared_error: 0.1878
# Epoch 21/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0285 - root_mean_squared_error: 0.1688 - val_loss: 0.0362 - val_root_mean_squared_error: 0.1902
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0283 - root_mean_squared_error: 0.1684INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 23s 445ms/step - loss: 0.0283 - root_mean_squared_error: 0.1684 - val_loss: 0.0327 - val_root_mean_squared_error: 0.1810
# Epoch 23/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0258 - root_mean_squared_error: 0.1606INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 23s 449ms/step - loss: 0.0259 - root_mean_squared_error: 0.1608 - val_loss: 0.0322 - val_root_mean_squared_error: 0.1794
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0257 - root_mean_squared_error: 0.1602INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 24s 456ms/step - loss: 0.0257 - root_mean_squared_error: 0.1602 - val_loss: 0.0316 - val_root_mean_squared_error: 0.1777
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0246 - root_mean_squared_error: 0.1570INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 27s 512ms/step - loss: 0.0246 - root_mean_squared_error: 0.1570 - val_loss: 0.0304 - val_root_mean_squared_error: 0.1744
# Epoch 26/50
# 53/53 [==============================] - 2s 38ms/step - loss: 0.0240 - root_mean_squared_error: 0.1550 - val_loss: 0.0307 - val_root_mean_squared_error: 0.1751
# Epoch 27/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0248 - root_mean_squared_error: 0.1576INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 26s 492ms/step - loss: 0.0248 - root_mean_squared_error: 0.1576 - val_loss: 0.0297 - val_root_mean_squared_error: 0.1723
# Epoch 28/50
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0237 - root_mean_squared_error: 0.1540 - val_loss: 0.0386 - val_root_mean_squared_error: 0.1965
# Epoch 29/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0234 - root_mean_squared_error: 0.1529 - val_loss: 0.0318 - val_root_mean_squared_error: 0.1784
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0202 - root_mean_squared_error: 0.1421INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 23s 446ms/step - loss: 0.0202 - root_mean_squared_error: 0.1421 - val_loss: 0.0274 - val_root_mean_squared_error: 0.1654
# Epoch 31/50
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0217 - root_mean_squared_error: 0.1474 - val_loss: 0.0310 - val_root_mean_squared_error: 0.1761
# Epoch 32/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0209 - root_mean_squared_error: 0.1446 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1700
# Epoch 33/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0232 - root_mean_squared_error: 0.1524 - val_loss: 0.0280 - val_root_mean_squared_error: 0.1673
# Epoch 34/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0199 - root_mean_squared_error: 0.1411 - val_loss: 0.0275 - val_root_mean_squared_error: 0.1659
# Epoch 35/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0209 - root_mean_squared_error: 0.1446 - val_loss: 0.0275 - val_root_mean_squared_error: 0.1658
# Epoch 36/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0200 - root_mean_squared_error: 0.1415INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 26s 490ms/step - loss: 0.0200 - root_mean_squared_error: 0.1415 - val_loss: 0.0272 - val_root_mean_squared_error: 0.1648
# Epoch 37/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0186 - root_mean_squared_error: 0.1364INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 23s 450ms/step - loss: 0.0185 - root_mean_squared_error: 0.1361 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1570
# Epoch 38/50
# 53/53 [==============================] - 2s 40ms/step - loss: 0.0195 - root_mean_squared_error: 0.1395 - val_loss: 0.0322 - val_root_mean_squared_error: 0.1795
# Epoch 39/50
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0192 - root_mean_squared_error: 0.1386 - val_loss: 0.0268 - val_root_mean_squared_error: 0.1637
# Epoch 40/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0187 - root_mean_squared_error: 0.1367 - val_loss: 0.0262 - val_root_mean_squared_error: 0.1620
# Epoch 41/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0181 - root_mean_squared_error: 0.1344 - val_loss: 0.0264 - val_root_mean_squared_error: 0.1625
# Epoch 42/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0181 - root_mean_squared_error: 0.1344 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1587
# Epoch 43/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0181 - root_mean_squared_error: 0.1346 - val_loss: 0.0267 - val_root_mean_squared_error: 0.1633
# Epoch 44/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0182 - root_mean_squared_error: 0.1349INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 23s 441ms/step - loss: 0.0182 - root_mean_squared_error: 0.1349 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1570
# Epoch 45/50
# 53/53 [==============================] - 2s 40ms/step - loss: 0.0171 - root_mean_squared_error: 0.1306 - val_loss: 0.0248 - val_root_mean_squared_error: 0.1575
# Epoch 46/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0170 - root_mean_squared_error: 0.1302 - val_loss: 0.0264 - val_root_mean_squared_error: 0.1624
# Epoch 47/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0176 - root_mean_squared_error: 0.1326INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 25s 489ms/step - loss: 0.0176 - root_mean_squared_error: 0.1326 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1558
# Epoch 48/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0173 - root_mean_squared_error: 0.1316 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1564
# Epoch 49/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0163 - root_mean_squared_error: 0.1276INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 26s 497ms/step - loss: 0.0163 - root_mean_squared_error: 0.1276 - val_loss: 0.0226 - val_root_mean_squared_error: 0.1503
# Epoch 50/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0161 - root_mean_squared_error: 0.1267INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 27s 511ms/step - loss: 0.0161 - root_mean_squared_error: 0.1267 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1451

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 14.236800082524617 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Kara_model_LT5/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 15ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.12750445820616943
# MAE : 0.0993552611373085

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 34ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
