# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bell_Amundsen_Extent = pd.read_excel(filepath, sheet_name='Bell-Amundsen-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Bell_Amundsen_Extent)
fp.date_time(Bell_Amundsen_Extent)
# Out:
#           Extent       Date
# 0    1179855.894 1979-01-01
# 1     879585.254 1979-02-01
# 2     791619.096 1979-03-01
# 3    1254912.071 1979-04-01
# 4    1620142.247 1979-05-01
# ..           ...        ...
# 533  1556568.455 2023-06-01
# 534  1917507.979 2023-07-01
# 535  2601630.327 2023-08-01
# 536  2534223.780 2023-09-01
# 537  2373004.525 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bell_Amundsen_Extent['Extent'] = scaler.fit_transform(Bell_Amundsen_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 12
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bell_Amundsen_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((515, 12, 1), (515,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Bell_Amund_model_LT12/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2040 - root_mean_squared_error: 0.4517INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 17s 221ms/step - loss: 0.2034 - root_mean_squared_error: 0.4510 - val_loss: 0.0990 - val_root_mean_squared_error: 0.3147
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0719 - root_mean_squared_error: 0.2681INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 11s 205ms/step - loss: 0.0716 - root_mean_squared_error: 0.2676 - val_loss: 0.0701 - val_root_mean_squared_error: 0.2648
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0600 - root_mean_squared_error: 0.2449INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 13s 256ms/step - loss: 0.0600 - root_mean_squared_error: 0.2449 - val_loss: 0.0663 - val_root_mean_squared_error: 0.2576
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0539 - root_mean_squared_error: 0.2322INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 26s 494ms/step - loss: 0.0539 - root_mean_squared_error: 0.2322 - val_loss: 0.0612 - val_root_mean_squared_error: 0.2474
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0473 - root_mean_squared_error: 0.2175INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 26s 500ms/step - loss: 0.0471 - root_mean_squared_error: 0.2170 - val_loss: 0.0528 - val_root_mean_squared_error: 0.2298
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0373 - root_mean_squared_error: 0.1932INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 40s 774ms/step - loss: 0.0373 - root_mean_squared_error: 0.1932 - val_loss: 0.0389 - val_root_mean_squared_error: 0.1973
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0261 - root_mean_squared_error: 0.1615INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 39s 745ms/step - loss: 0.0261 - root_mean_squared_error: 0.1615 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1577
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0166 - root_mean_squared_error: 0.1288INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 37s 711ms/step - loss: 0.0166 - root_mean_squared_error: 0.1288 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1469
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0125 - root_mean_squared_error: 0.1117INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 34s 649ms/step - loss: 0.0125 - root_mean_squared_error: 0.1117 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1263
# Epoch 10/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0136 - root_mean_squared_error: 0.1165 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1842
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0140 - root_mean_squared_error: 0.1185INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 38s 721ms/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1211
# Epoch 12/50
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0118 - root_mean_squared_error: 0.1085 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1415
# Epoch 13/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0130 - root_mean_squared_error: 0.1142 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1218
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0115 - root_mean_squared_error: 0.1074INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 38s 721ms/step - loss: 0.0115 - root_mean_squared_error: 0.1074 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1184
# Epoch 15/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.0117 - root_mean_squared_error: 0.1080 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1269
# Epoch 16/50
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0109 - root_mean_squared_error: 0.1046 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1349
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0108 - root_mean_squared_error: 0.1041INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 37s 704ms/step - loss: 0.0108 - root_mean_squared_error: 0.1041 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1178
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0109 - root_mean_squared_error: 0.1043INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 36s 694ms/step - loss: 0.0109 - root_mean_squared_error: 0.1043 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1105
# Epoch 19/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0108 - root_mean_squared_error: 0.1039 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1287
# Epoch 20/50
# 53/53 [==============================] - 4s 78ms/step - loss: 0.0107 - root_mean_squared_error: 0.1032 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1167
# Epoch 21/50
# 53/53 [==============================] - 4s 77ms/step - loss: 0.0100 - root_mean_squared_error: 0.0998 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1323
# Epoch 22/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0101 - root_mean_squared_error: 0.1005 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1300
# Epoch 23/50
# 53/53 [==============================] - 4s 78ms/step - loss: 0.0105 - root_mean_squared_error: 0.1024 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1139
# Epoch 24/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0105 - root_mean_squared_error: 0.1026 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1282
# Epoch 25/50
# 53/53 [==============================] - 4s 75ms/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1122
# Epoch 26/50
# 53/53 [==============================] - 4s 77ms/step - loss: 0.0092 - root_mean_squared_error: 0.0961 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1202
# Epoch 27/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0096 - root_mean_squared_error: 0.0981 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1136
# Epoch 28/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0097 - root_mean_squared_error: 0.0983 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1116
# Epoch 29/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0092 - root_mean_squared_error: 0.0959INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 36s 697ms/step - loss: 0.0092 - root_mean_squared_error: 0.0959 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1052
# Epoch 30/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.0095 - root_mean_squared_error: 0.0976 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1282
# Epoch 31/50
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0105 - root_mean_squared_error: 0.1026 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 32/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0091 - root_mean_squared_error: 0.0952 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1176
# Epoch 33/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0095 - root_mean_squared_error: 0.0973 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1139
# Epoch 34/50
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0090 - root_mean_squared_error: 0.0947 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1199
# Epoch 35/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0091 - root_mean_squared_error: 0.0954 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1138
# Epoch 36/50
# 53/53 [==============================] - 4s 81ms/step - loss: 0.0091 - root_mean_squared_error: 0.0955 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1088
# Epoch 37/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0088 - root_mean_squared_error: 0.0936INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 36s 698ms/step - loss: 0.0088 - root_mean_squared_error: 0.0936 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1027
# Epoch 38/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0090 - root_mean_squared_error: 0.0949INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 36s 698ms/step - loss: 0.0090 - root_mean_squared_error: 0.0949 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1024
# Epoch 39/50
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0088 - root_mean_squared_error: 0.0936 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1111
# Epoch 40/50
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0091 - root_mean_squared_error: 0.0952 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1190
# Epoch 41/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0087 - root_mean_squared_error: 0.0930 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1105
# Epoch 42/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0089 - root_mean_squared_error: 0.0944 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1034
# Epoch 43/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0090 - root_mean_squared_error: 0.0950INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 35s 672ms/step - loss: 0.0090 - root_mean_squared_error: 0.0950 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1015
# Epoch 44/50
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0090 - root_mean_squared_error: 0.0947 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1043
# Epoch 45/50
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0084 - root_mean_squared_error: 0.0918 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1034
# Epoch 46/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.0091 - root_mean_squared_error: 0.0953 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 47/50
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0087 - root_mean_squared_error: 0.0934 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1055
# Epoch 48/50
# 53/53 [==============================] - 4s 75ms/step - loss: 0.0093 - root_mean_squared_error: 0.0962 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1093
# Epoch 49/50
# 53/53 [==============================] - 4s 77ms/step - loss: 0.0094 - root_mean_squared_error: 0.0968 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1071
# Epoch 50/50
# 53/53 [==============================] - 4s 78ms/step - loss: 0.0089 - root_mean_squared_error: 0.0942 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1036

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 11.171014416217805 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bell_Amund_model_LT12/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 3s 35ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.08753368905101094
# MAE : 0.07112001214091564

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        5.661942e+05     807857.307
# 1        1.056988e+06    1184280.145
# 2        1.575551e+06    1468308.405
# 3        1.854666e+06    1540851.607
# 4        2.003137e+06    1989099.836
# 5        1.986943e+06    2096990.761
# 6        1.910251e+06    2080961.032
# 7        1.699714e+06    1695704.661
# 8        1.162228e+06    1533888.370
# 9        7.272960e+05    1038332.675
# 10       4.803401e+05     602954.621
# 11       4.751142e+05     895484.288
# 12       7.036137e+05    1070622.700
# 13       1.125721e+06    1532457.922
# 14       1.535826e+06    1703762.123
# 15       1.746660e+06    1855079.122
# 16       1.918649e+06    2291960.639
# 17       2.045828e+06    2114120.417
# 18       2.010868e+06    1995818.759
# 19       1.738601e+06    1653379.997
# 20       1.241876e+06    1070814.995
# 21       8.186148e+05     689443.815
# 22       5.401144e+05     401148.663
# 23       5.388284e+05     346558.057
# 24       7.196218e+05     599477.678
# 25       1.178306e+06     765764.905
# 26       1.554768e+06    1304133.179
# 27       1.772747e+06    1598436.099
# 28       1.944397e+06    1763844.414
# 29       1.963308e+06    1979139.524
# 30       1.863226e+06    1937348.663
# 31       1.579847e+06    1833093.342
# 32       1.044380e+06    1089676.114
# 33       5.603899e+05     453484.731
# 34       4.400798e+05     251559.554
# 35       4.502401e+05     351294.657
# 36       6.211801e+05     702389.714
# 37       9.095036e+05    1185169.054
# 38       1.422243e+06    1556568.455
# 39       1.818727e+06    1917507.979
# 40       1.975218e+06    2601630.327
# 41       2.044860e+06    2534223.780
# 42       1.993746e+06    2373004.525

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 44ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
