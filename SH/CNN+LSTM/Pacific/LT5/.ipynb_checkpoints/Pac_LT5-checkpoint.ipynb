# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Pacific_Extent = pd.read_excel(filepath, sheet_name='Pacific-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Pacific_Extent)
fp.date_time(Pacific_Extent)
# Out:
#           Extent       Date
# 0     668714.275 1979-01-01
# 1     566930.458 1979-02-01
# 2     688420.115 1979-03-01
# 3     859963.043 1979-04-01
# 4    1127120.160 1979-05-01
# ..           ...        ...
# 533  1134056.102 2023-06-01
# 534  1484824.377 2023-07-01
# 535  1671324.717 2023-08-01
# 536  1726376.097 2023-09-01
# 537  1690631.996 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Pacific_Extent['Extent'] = scaler.fit_transform(Pacific_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 5
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Pacific_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((522, 12, 1), (522,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Pacific_model_LT5/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.3102 - root_mean_squared_error: 0.5569
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 6s 73ms/step - loss: 0.3076 - root_mean_squared_error: 0.5547 - val_loss: 0.2587 - val_root_mean_squared_error: 0.5086
# Epoch 2/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.2030 - root_mean_squared_error: 0.4506
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 3s 62ms/step - loss: 0.1972 - root_mean_squared_error: 0.4441 - val_loss: 0.1938 - val_root_mean_squared_error: 0.4402
# Epoch 3/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.1421 - root_mean_squared_error: 0.3769
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 3s 67ms/step - loss: 0.1389 - root_mean_squared_error: 0.3726 - val_loss: 0.1524 - val_root_mean_squared_error: 0.3904
# Epoch 4/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.1024 - root_mean_squared_error: 0.3199
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.1074 - root_mean_squared_error: 0.3278 - val_loss: 0.1229 - val_root_mean_squared_error: 0.3505
# Epoch 5/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0887 - root_mean_squared_error: 0.2979
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0848 - root_mean_squared_error: 0.2911 - val_loss: 0.0967 - val_root_mean_squared_error: 0.3110
# Epoch 6/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0607 - root_mean_squared_error: 0.2463
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0629 - root_mean_squared_error: 0.2508 - val_loss: 0.0754 - val_root_mean_squared_error: 0.2745
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0470 - root_mean_squared_error: 0.2168
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0470 - root_mean_squared_error: 0.2168 - val_loss: 0.0599 - val_root_mean_squared_error: 0.2447
# Epoch 8/50
# 43/53 [=======================>......] - ETA: 0s - loss: 0.0385 - root_mean_squared_error: 0.1963
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0368 - root_mean_squared_error: 0.1918 - val_loss: 0.0442 - val_root_mean_squared_error: 0.2102
# Epoch 9/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0271 - root_mean_squared_error: 0.1646
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0284 - root_mean_squared_error: 0.1686 - val_loss: 0.0345 - val_root_mean_squared_error: 0.1857
# Epoch 10/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0236 - root_mean_squared_error: 0.1537
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0223 - root_mean_squared_error: 0.1493 - val_loss: 0.0265 - val_root_mean_squared_error: 0.1627
# Epoch 11/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0167 - root_mean_squared_error: 0.1294
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0165 - root_mean_squared_error: 0.1285 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1362
# Epoch 12/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0164 - root_mean_squared_error: 0.1283
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 3s 67ms/step - loss: 0.0164 - root_mean_squared_error: 0.1281 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1116
# Epoch 13/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0122 - root_mean_squared_error: 0.1103
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0126 - root_mean_squared_error: 0.1122 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0902
# Epoch 14/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0124 - root_mean_squared_error: 0.1115
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0125 - root_mean_squared_error: 0.1119 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0778
# Epoch 15/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0099 - root_mean_squared_error: 0.0994
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0112 - root_mean_squared_error: 0.1059 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0710
# Epoch 16/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0139 - root_mean_squared_error: 0.1179 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0722
# Epoch 17/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0150 - root_mean_squared_error: 0.1226 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0733
# Epoch 18/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0098 - root_mean_squared_error: 0.0992 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0724
# Epoch 19/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0109 - root_mean_squared_error: 0.1046
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0661
# Epoch 20/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0138 - root_mean_squared_error: 0.1174
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 3s 67ms/step - loss: 0.0135 - root_mean_squared_error: 0.1163 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0659
# Epoch 21/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0109 - root_mean_squared_error: 0.1042 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0718
# Epoch 22/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0785
# Epoch 23/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0117 - root_mean_squared_error: 0.1080 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0698
# Epoch 24/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0107 - root_mean_squared_error: 0.1033 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0770
# Epoch 25/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0755
# Epoch 26/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0662
# Epoch 27/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0109 - root_mean_squared_error: 0.1043
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT5\assets
# 53/53 [==============================] - 4s 80ms/step - loss: 0.0105 - root_mean_squared_error: 0.1027 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0658
# Epoch 28/50
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0128 - root_mean_squared_error: 0.1133 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0689
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0119 - root_mean_squared_error: 0.1093 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0736
# Epoch 30/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0102 - root_mean_squared_error: 0.1012 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0676
# Epoch 31/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0123 - root_mean_squared_error: 0.1110 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0671
# Epoch 32/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0122 - root_mean_squared_error: 0.1106 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0701
# Epoch 33/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0099 - root_mean_squared_error: 0.0995 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0698
# Epoch 34/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0980
# Epoch 35/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0089 - root_mean_squared_error: 0.0941 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0683
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0130 - root_mean_squared_error: 0.1140 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0671
# Epoch 37/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0102 - root_mean_squared_error: 0.1010 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0663
# Epoch 38/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0670
# Epoch 39/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0119 - root_mean_squared_error: 0.1089 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0689
# Epoch 40/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0106 - root_mean_squared_error: 0.1029 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0697
# Epoch 41/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0087 - root_mean_squared_error: 0.0934 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0707
# Epoch 42/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0123 - root_mean_squared_error: 0.1109 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0825
# Epoch 43/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0667
# Epoch 44/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0127 - root_mean_squared_error: 0.1128 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0662
# Epoch 45/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0080 - root_mean_squared_error: 0.0897 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0684
# Epoch 46/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0103 - root_mean_squared_error: 0.1013 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0660
# Epoch 47/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0097 - root_mean_squared_error: 0.0985 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0685
# Epoch 48/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0120 - root_mean_squared_error: 0.1094 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0677
# Epoch 49/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0098 - root_mean_squared_error: 0.0988 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0675
# Epoch 50/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0105 - root_mean_squared_error: 0.1025 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0778

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.2735514084498087 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Pacific_model_LT5/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.08192423074100362
# MAE : 0.06434908915965101

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.886528e+06    2203401.829
# 1        1.753484e+06    1960480.542
# 2        1.352310e+06    1264318.504
# 3        8.632566e+05     863206.294
# 4        4.290007e+05     635624.004
# 5        2.056354e+05     460009.672
# 6        4.444368e+05     610848.036
# 7        9.444029e+05     819257.445
# 8        1.072986e+06    1129627.707
# 9        1.500030e+06    1463383.236
# 10       1.649693e+06    1614536.727
# 11       1.965918e+06    1862498.612
# 12       1.915336e+06    2099349.296
# 13       1.890537e+06    1981614.046
# 14       1.339570e+06    1433022.369
# 15       9.307689e+05     826739.716
# 16       4.476838e+05     477145.887
# 17       2.589596e+05     314469.289
# 18       4.831112e+05     463134.749
# 19       8.858528e+05     946522.292
# 20       1.145904e+06    1309266.570
# 21       1.454033e+06    1507947.309
# 22       1.660033e+06    1804167.937
# 23       1.972391e+06    1908002.139
# 24       2.106258e+06    1892748.521
# 25       2.000769e+06    1601079.640
# 26       1.406314e+06    1327804.521
# 27       8.847859e+05     812074.231
# 28       5.023721e+05     493355.897
# 29       4.139498e+05     317229.330
# 30       6.196367e+05     425777.624
# 31       9.117476e+05     827172.620
# 32       1.155610e+06    1162367.223
# 33       1.560740e+06    1413734.261
# 34       1.678516e+06    1574257.849
# 35       1.929130e+06    1786961.251
# 36       1.984838e+06    1857942.866
# 37       1.850654e+06    1406291.588
# 38       1.325171e+06    1025555.371
# 39       8.166337e+05     632862.782
# 40       5.103615e+05     308194.756
# 41       4.096006e+05     194921.078
# 42       7.016130e+05     245569.900
# 43       9.381062e+05     533532.424
# 44       1.253857e+06     943124.529
# 45       1.502407e+06    1134056.102
# 46       1.681073e+06    1484824.377
# 47       1.725534e+06    1671324.717
# 48       1.730636e+06    1726376.097
# 49       1.634120e+06    1690631.996

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
