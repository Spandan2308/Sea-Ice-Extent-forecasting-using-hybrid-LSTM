# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bell_Amundsen_Extent = pd.read_excel(filepath, sheet_name='Bell-Amundsen-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Bell_Amundsen_Extent)
fp.date_time(Bell_Amundsen_Extent)
# Out:
#           Extent       Date
# 0    1179855.894 1979-01-01
# 1     879585.254 1979-02-01
# 2     791619.096 1979-03-01
# 3    1254912.071 1979-04-01
# 4    1620142.247 1979-05-01
# ..           ...        ...
# 533  1556568.455 2023-06-01
# 534  1917507.979 2023-07-01
# 535  2601630.327 2023-08-01
# 536  2534223.780 2023-09-01
# 537  2373004.525 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bell_Amundsen_Extent['Extent'] = scaler.fit_transform(Bell_Amundsen_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 5
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bell_Amundsen_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((522, 12, 1), (522,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Bell_Amund_model_LT5/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.2506 - root_mean_squared_error: 0.5006
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 8s 94ms/step - loss: 0.2504 - root_mean_squared_error: 0.5004 - val_loss: 0.2668 - val_root_mean_squared_error: 0.5165
# Epoch 2/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.1904 - root_mean_squared_error: 0.4364
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.1892 - root_mean_squared_error: 0.4349 - val_loss: 0.2290 - val_root_mean_squared_error: 0.4785
# Epoch 3/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.1527 - root_mean_squared_error: 0.3907
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.1526 - root_mean_squared_error: 0.3906 - val_loss: 0.1914 - val_root_mean_squared_error: 0.4375
# Epoch 4/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.1251 - root_mean_squared_error: 0.3538
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 5s 93ms/step - loss: 0.1258 - root_mean_squared_error: 0.3546 - val_loss: 0.1639 - val_root_mean_squared_error: 0.4049
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1008 - root_mean_squared_error: 0.3175
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.1008 - root_mean_squared_error: 0.3175 - val_loss: 0.1401 - val_root_mean_squared_error: 0.3743
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0779 - root_mean_squared_error: 0.2791
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.0779 - root_mean_squared_error: 0.2791 - val_loss: 0.1127 - val_root_mean_squared_error: 0.3357
# Epoch 7/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0652 - root_mean_squared_error: 0.2553
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0610 - root_mean_squared_error: 0.2469 - val_loss: 0.0916 - val_root_mean_squared_error: 0.3026
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0467 - root_mean_squared_error: 0.2160
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0470 - root_mean_squared_error: 0.2169 - val_loss: 0.0676 - val_root_mean_squared_error: 0.2600
# Epoch 9/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0379 - root_mean_squared_error: 0.1948
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0382 - root_mean_squared_error: 0.1955 - val_loss: 0.0517 - val_root_mean_squared_error: 0.2274
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0298 - root_mean_squared_error: 0.1726
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0299 - root_mean_squared_error: 0.1730 - val_loss: 0.0441 - val_root_mean_squared_error: 0.2101
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0245 - root_mean_squared_error: 0.1565
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0246 - root_mean_squared_error: 0.1570 - val_loss: 0.0322 - val_root_mean_squared_error: 0.1794
# Epoch 12/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0202 - root_mean_squared_error: 0.1423
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0201 - root_mean_squared_error: 0.1416 - val_loss: 0.0281 - val_root_mean_squared_error: 0.1675
# Epoch 13/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0176 - root_mean_squared_error: 0.1328
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0186 - root_mean_squared_error: 0.1363 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1407
# Epoch 14/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0148 - root_mean_squared_error: 0.1215
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0148 - root_mean_squared_error: 0.1217 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1274
# Epoch 15/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0184 - root_mean_squared_error: 0.1355 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1292
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0144 - root_mean_squared_error: 0.1201
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1218
# Epoch 17/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0128 - root_mean_squared_error: 0.1133 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1220
# Epoch 18/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0125 - root_mean_squared_error: 0.1120
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0132 - root_mean_squared_error: 0.1150 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1132
# Epoch 19/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0148 - root_mean_squared_error: 0.1217 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1260
# Epoch 20/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0128 - root_mean_squared_error: 0.1132
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0125 - root_mean_squared_error: 0.1116 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1110
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0137 - root_mean_squared_error: 0.1172 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1113
# Epoch 22/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0136 - root_mean_squared_error: 0.1166
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1090
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0126 - root_mean_squared_error: 0.1124 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1505
# Epoch 24/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1607
# Epoch 25/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0153 - root_mean_squared_error: 0.1237
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 4s 81ms/step - loss: 0.0150 - root_mean_squared_error: 0.1225 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1072
# Epoch 26/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0115 - root_mean_squared_error: 0.1074
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 4s 81ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1056
# Epoch 27/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1114
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0147 - root_mean_squared_error: 0.1214 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1061
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0129 - root_mean_squared_error: 0.1134 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1605
# Epoch 30/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0122 - root_mean_squared_error: 0.1107
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 5s 88ms/step - loss: 0.0117 - root_mean_squared_error: 0.1081 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1029
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0133 - root_mean_squared_error: 0.1153 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1087
# Epoch 32/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0131 - root_mean_squared_error: 0.1144 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1066
# Epoch 33/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0125 - root_mean_squared_error: 0.1119 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1153
# Epoch 34/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1153
# Epoch 35/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0125 - root_mean_squared_error: 0.1118 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1057
# Epoch 36/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0123 - root_mean_squared_error: 0.1109 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1161
# Epoch 37/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0119 - root_mean_squared_error: 0.1092 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1044
# Epoch 38/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0115 - root_mean_squared_error: 0.1073 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1044
# Epoch 39/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0155 - root_mean_squared_error: 0.1246 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1425
# Epoch 40/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0129 - root_mean_squared_error: 0.1137
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT5\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1002
# Epoch 41/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1010
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0140 - root_mean_squared_error: 0.1184 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1042
# Epoch 43/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0126 - root_mean_squared_error: 0.1125 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1304
# Epoch 44/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1004
# Epoch 45/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0121 - root_mean_squared_error: 0.1100 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1035
# Epoch 46/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0135 - root_mean_squared_error: 0.1164 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1034
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0121 - root_mean_squared_error: 0.1099 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1073
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0106 - root_mean_squared_error: 0.1030 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1016
# Epoch 50/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1219

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.8878617405891418 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bell_Amund_model_LT5/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 11ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.09563327441110021
# MAE : 0.07864189925375221

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        2.293442e+06    1856673.675
# 1        2.162058e+06    1914289.680
# 2        1.760088e+06    1802244.842
# 3        1.243252e+06    1202791.069
# 4        8.358459e+05     752834.272
# 5        5.196405e+05     451914.219
# 6        4.178397e+05     439855.813
# 7        6.208144e+05     807857.307
# 8        1.112979e+06    1184280.145
# 9        1.499842e+06    1468308.405
# 10       1.770931e+06    1540851.607
# 11       2.000593e+06    1989099.836
# 12       2.155991e+06    2096990.761
# 13       1.987232e+06    2080961.032
# 14       1.682984e+06    1695704.661
# 15       1.228664e+06    1533888.370
# 16       8.903856e+05    1038332.675
# 17       4.193110e+05     602954.621
# 18       3.910451e+05     895484.288
# 19       6.469234e+05    1070622.700
# 20       1.043586e+06    1532457.922
# 21       1.340975e+06    1703762.123
# 22       1.686338e+06    1855079.122
# 23       1.847168e+06    2291960.639
# 24       1.849568e+06    2114120.417
# 25       1.815894e+06    1995818.759
# 26       1.452505e+06    1653379.997
# 27       1.125335e+06    1070814.995
# 28       7.791012e+05     689443.815
# 29       5.234238e+05     401148.663
# 30       4.859122e+05     346558.057
# 31       8.179736e+05     599477.678
# 32       1.297746e+06     765764.905
# 33       1.679492e+06    1304133.179
# 34       1.933861e+06    1598436.099
# 35       2.153431e+06    1763844.414
# 36       2.295760e+06    1979139.524
# 37       2.107438e+06    1937348.663
# 38       1.916766e+06    1833093.342
# 39       1.335914e+06    1089676.114
# 40       9.055243e+05     453484.731
# 41       4.771825e+05     251559.554
# 42       4.266185e+05     351294.657
# 43       4.957693e+05     702389.714
# 44       1.025281e+06    1185169.054
# 45       1.473924e+06    1556568.455
# 46       1.762189e+06    1917507.979
# 47       2.096506e+06    2601630.327
# 48       2.104070e+06    2534223.780
# 49       2.065683e+06    2373004.525

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
