# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Ross_Extent = pd.read_excel(filepath, sheet_name='Ross-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Ross_Extent)
fp.date_time(Ross_Extent)
# Out:
#           Extent       Date
# 0    1040455.516 1979-01-01
# 1     239334.118 1979-02-01
# 2     557365.154 1979-03-01
# 3    2054855.924 1979-04-01
# 4    2973925.625 1979-05-01
# ..           ...        ...
# 533  3137598.938 2023-06-01
# 534  3201783.453 2023-07-01
# 535  2973294.266 2023-08-01
# 536  3354839.711 2023-09-01
# 537  3325613.245 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Ross_Extent['Extent'] = scaler.fit_transform(Ross_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 4
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Ross_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((523, 12, 1), (523,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Ross_model_LT4/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.3173 - root_mean_squared_error: 0.5633INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 17s 211ms/step - loss: 0.3170 - root_mean_squared_error: 0.5630 - val_loss: 0.1912 - val_root_mean_squared_error: 0.4372
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0884 - root_mean_squared_error: 0.2974INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 188ms/step - loss: 0.0878 - root_mean_squared_error: 0.2964 - val_loss: 0.0502 - val_root_mean_squared_error: 0.2240
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0400 - root_mean_squared_error: 0.2000INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 184ms/step - loss: 0.0404 - root_mean_squared_error: 0.2010 - val_loss: 0.0477 - val_root_mean_squared_error: 0.2183
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0378 - root_mean_squared_error: 0.1943INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 194ms/step - loss: 0.0375 - root_mean_squared_error: 0.1938 - val_loss: 0.0436 - val_root_mean_squared_error: 0.2089
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0349 - root_mean_squared_error: 0.1868INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 190ms/step - loss: 0.0349 - root_mean_squared_error: 0.1868 - val_loss: 0.0396 - val_root_mean_squared_error: 0.1990
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0299 - root_mean_squared_error: 0.1729INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 186ms/step - loss: 0.0297 - root_mean_squared_error: 0.1725 - val_loss: 0.0370 - val_root_mean_squared_error: 0.1922
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0282 - root_mean_squared_error: 0.1680INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0281 - root_mean_squared_error: 0.1678 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1833
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0259 - root_mean_squared_error: 0.1610INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 187ms/step - loss: 0.0259 - root_mean_squared_error: 0.1610 - val_loss: 0.0329 - val_root_mean_squared_error: 0.1815
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0235 - root_mean_squared_error: 0.1534INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 197ms/step - loss: 0.0235 - root_mean_squared_error: 0.1534 - val_loss: 0.0305 - val_root_mean_squared_error: 0.1746
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0240 - root_mean_squared_error: 0.1548INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 188ms/step - loss: 0.0238 - root_mean_squared_error: 0.1542 - val_loss: 0.0294 - val_root_mean_squared_error: 0.1715
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0235 - root_mean_squared_error: 0.1533INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 189ms/step - loss: 0.0235 - root_mean_squared_error: 0.1533 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1696
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0232 - root_mean_squared_error: 0.1523INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 183ms/step - loss: 0.0233 - root_mean_squared_error: 0.1526 - val_loss: 0.0284 - val_root_mean_squared_error: 0.1684
# Epoch 13/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0226 - root_mean_squared_error: 0.1502 - val_loss: 0.0284 - val_root_mean_squared_error: 0.1684
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0231 - root_mean_squared_error: 0.1519INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 191ms/step - loss: 0.0231 - root_mean_squared_error: 0.1519 - val_loss: 0.0274 - val_root_mean_squared_error: 0.1656
# Epoch 15/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0209 - root_mean_squared_error: 0.1444 - val_loss: 0.0286 - val_root_mean_squared_error: 0.1690
# Epoch 16/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0224 - root_mean_squared_error: 0.1498INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 190ms/step - loss: 0.0224 - root_mean_squared_error: 0.1497 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1646
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0199 - root_mean_squared_error: 0.1410INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 189ms/step - loss: 0.0199 - root_mean_squared_error: 0.1410 - val_loss: 0.0265 - val_root_mean_squared_error: 0.1628
# Epoch 18/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0200 - root_mean_squared_error: 0.1415 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1644
# Epoch 19/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0204 - root_mean_squared_error: 0.1428INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 191ms/step - loss: 0.0204 - root_mean_squared_error: 0.1427 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1606
# Epoch 20/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0225 - root_mean_squared_error: 0.1502 - val_loss: 0.0262 - val_root_mean_squared_error: 0.1620
# Epoch 21/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0192 - root_mean_squared_error: 0.1385 - val_loss: 0.0267 - val_root_mean_squared_error: 0.1635
# Epoch 22/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0186 - root_mean_squared_error: 0.1362 - val_loss: 0.0298 - val_root_mean_squared_error: 0.1727
# Epoch 23/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0195 - root_mean_squared_error: 0.1398INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 191ms/step - loss: 0.0195 - root_mean_squared_error: 0.1398 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1571
# Epoch 24/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0193 - root_mean_squared_error: 0.1389INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 186ms/step - loss: 0.0191 - root_mean_squared_error: 0.1384 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1554
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0194 - root_mean_squared_error: 0.1392INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 191ms/step - loss: 0.0194 - root_mean_squared_error: 0.1392 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1539
# Epoch 26/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0182 - root_mean_squared_error: 0.1348INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 192ms/step - loss: 0.0182 - root_mean_squared_error: 0.1350 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1531
# Epoch 27/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0182 - root_mean_squared_error: 0.1349INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 190ms/step - loss: 0.0182 - root_mean_squared_error: 0.1349 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1526
# Epoch 28/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0176 - root_mean_squared_error: 0.1326 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1535
# Epoch 29/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0190 - root_mean_squared_error: 0.1378INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 199ms/step - loss: 0.0190 - root_mean_squared_error: 0.1378 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1496
# Epoch 30/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0171 - root_mean_squared_error: 0.1308INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 194ms/step - loss: 0.0170 - root_mean_squared_error: 0.1306 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1489
# Epoch 31/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0175 - root_mean_squared_error: 0.1324INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 188ms/step - loss: 0.0175 - root_mean_squared_error: 0.1324 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1472
# Epoch 32/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0175 - root_mean_squared_error: 0.1325 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1569
# Epoch 33/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0172 - root_mean_squared_error: 0.1310INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 197ms/step - loss: 0.0171 - root_mean_squared_error: 0.1306 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1469
# Epoch 34/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0159 - root_mean_squared_error: 0.1261INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 190ms/step - loss: 0.0159 - root_mean_squared_error: 0.1259 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1436
# Epoch 35/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0151 - root_mean_squared_error: 0.1231 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1437
# Epoch 36/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0149 - root_mean_squared_error: 0.1223INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 189ms/step - loss: 0.0149 - root_mean_squared_error: 0.1223 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1401
# Epoch 37/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0153 - root_mean_squared_error: 0.1237 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1427
# Epoch 38/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0149 - root_mean_squared_error: 0.1221INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 196ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1351
# Epoch 39/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0146 - root_mean_squared_error: 0.1209 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1353
# Epoch 40/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0145 - root_mean_squared_error: 0.1204INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 192ms/step - loss: 0.0145 - root_mean_squared_error: 0.1204 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1338
# Epoch 41/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0152 - root_mean_squared_error: 0.1233 - val_loss: 0.0191 - val_root_mean_squared_error: 0.1382
# Epoch 42/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0131 - root_mean_squared_error: 0.1145INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 189ms/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1273
# Epoch 43/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0132 - root_mean_squared_error: 0.1150 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1277
# Epoch 44/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0128 - root_mean_squared_error: 0.1130INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 196ms/step - loss: 0.0128 - root_mean_squared_error: 0.1130 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1253
# Epoch 45/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0124 - root_mean_squared_error: 0.1113 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1255
# Epoch 46/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0120 - root_mean_squared_error: 0.1097INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 197ms/step - loss: 0.0120 - root_mean_squared_error: 0.1097 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1204
# Epoch 47/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0123 - root_mean_squared_error: 0.1109INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 186ms/step - loss: 0.0123 - root_mean_squared_error: 0.1109 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1168
# Epoch 48/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0127 - root_mean_squared_error: 0.1129INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 199ms/step - loss: 0.0127 - root_mean_squared_error: 0.1129 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1168
# Epoch 49/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0114 - root_mean_squared_error: 0.1067INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 192ms/step - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1142
# Epoch 50/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0109 - root_mean_squared_error: 0.1042INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 10s 187ms/step - loss: 0.0109 - root_mean_squared_error: 0.1042 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1102

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 6.493095914522807 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Ross_model_LT4/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 15ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.11904765970507271
# MAE : 0.09628400048431945

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        3.912578e+06    3794128.369
# 1        3.955101e+06    3885746.442
# 2        3.680859e+06    3909211.179
# 3        3.108230e+06    3499167.351
# 4        2.261890e+06    2715890.297
# 5        1.306512e+06    1053272.694
# 6        8.077394e+05     368862.123
# 7        1.092841e+06     979418.298
# 8        1.622414e+06    2086269.569
# 9        2.174644e+06    2852731.016
# 10       2.784252e+06    3452823.613
# 11       3.313998e+06    3846843.974
# 12       3.641928e+06    4005222.451
# 13       3.719693e+06    4129684.505
# 14       3.542546e+06    4130311.577
# 15       3.074998e+06    3987590.376
# 16       2.324779e+06    2531664.630
# 17       1.414707e+06     864796.598
# 18       9.238036e+05     366098.623
# 19       1.245294e+06    1324063.884
# 20       1.850742e+06    2094086.684
# 21       2.470497e+06    2706708.526
# 22       3.131857e+06    3380172.167
# 23       3.675310e+06    3975727.475
# 24       4.009800e+06    4016497.161
# 25       4.111455e+06    4134594.766
# 26       3.895469e+06    4278165.933
# 27       3.371602e+06    3893945.909
# 28       2.532344e+06    2389171.083
# 29       1.491163e+06     896425.932
# 30       9.118634e+05     251374.224
# 31       1.276486e+06     455056.048
# 32       1.886046e+06    1780625.872
# 33       2.516523e+06    2914989.101
# 34       3.190348e+06    3561620.245
# 35       3.718927e+06    3991717.506
# 36       4.060010e+06    4559070.778
# 37       4.174805e+06    4596327.081
# 38       3.959791e+06    4565650.139
# 39       3.372133e+06    4061902.846
# 40       2.512999e+06    2336900.967
# 41       1.482159e+06     696917.659
# 42       9.029901e+05     213657.789
# 43       1.219987e+06     765773.883
# 44       1.883661e+06    1951730.202
# 45       2.603325e+06    2610971.814
# 46       3.403256e+06    3137598.938
# 47       4.140462e+06    3201783.453
# 48       4.599902e+06    2973294.266
# 49       4.678190e+06    3354839.711
# 50       4.394835e+06    3325613.245

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 16ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
