# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Baffin = pd.read_excel(filepath, sheet_name='Baffin-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Baffin)
fp.date_time(Baffin)
# Out:
#           Extent       Date
# 0    1090625.815 1979-01-01
# 1    1157634.866 1979-02-01
# 2    1299583.477 1979-03-01
# 3    1137194.680 1979-04-01
# 4     983083.453 1979-05-01
# ..           ...        ...
# 533   781460.891 2023-06-01
# 534   331845.048 2023-07-01
# 535    99334.625 2023-08-01
# 536    49359.723 2023-09-01
# 537    85693.282 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Baffin['Extent'] = scaler.fit_transform(Baffin['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 5
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Baffin['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((522, 12, 1), (522,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Baffin_model_LT5/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.2249 - root_mean_squared_error: 0.4743INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 22s 280ms/step - loss: 0.2262 - root_mean_squared_error: 0.4756 - val_loss: 0.1608 - val_root_mean_squared_error: 0.4010
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1195 - root_mean_squared_error: 0.3457INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 12s 227ms/step - loss: 0.1195 - root_mean_squared_error: 0.3457 - val_loss: 0.0524 - val_root_mean_squared_error: 0.2289
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0548 - root_mean_squared_error: 0.2340INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 12s 227ms/step - loss: 0.0548 - root_mean_squared_error: 0.2341 - val_loss: 0.0476 - val_root_mean_squared_error: 0.2181
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0499 - root_mean_squared_error: 0.2234INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 12s 234ms/step - loss: 0.0499 - root_mean_squared_error: 0.2234 - val_loss: 0.0439 - val_root_mean_squared_error: 0.2096
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0454 - root_mean_squared_error: 0.2130INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 12s 233ms/step - loss: 0.0454 - root_mean_squared_error: 0.2130 - val_loss: 0.0385 - val_root_mean_squared_error: 0.1963
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0425 - root_mean_squared_error: 0.2060INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 11s 214ms/step - loss: 0.0423 - root_mean_squared_error: 0.2056 - val_loss: 0.0335 - val_root_mean_squared_error: 0.1830
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0371 - root_mean_squared_error: 0.1927INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 13s 243ms/step - loss: 0.0371 - root_mean_squared_error: 0.1927 - val_loss: 0.0284 - val_root_mean_squared_error: 0.1685
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0301 - root_mean_squared_error: 0.1734INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 13s 250ms/step - loss: 0.0301 - root_mean_squared_error: 0.1734 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1433
# Epoch 9/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0275 - root_mean_squared_error: 0.1658INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 13s 243ms/step - loss: 0.0275 - root_mean_squared_error: 0.1659 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1339
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0228 - root_mean_squared_error: 0.1511INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 15s 280ms/step - loss: 0.0228 - root_mean_squared_error: 0.1511 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1301
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0212 - root_mean_squared_error: 0.1456INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 13s 241ms/step - loss: 0.0216 - root_mean_squared_error: 0.1470 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 12/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0209 - root_mean_squared_error: 0.1446 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1093
# Epoch 13/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0184 - root_mean_squared_error: 0.1357 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1098
# Epoch 14/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0166 - root_mean_squared_error: 0.1290INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 13s 247ms/step - loss: 0.0166 - root_mean_squared_error: 0.1287 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0898
# Epoch 15/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0168 - root_mean_squared_error: 0.1296 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0948
# Epoch 16/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0163 - root_mean_squared_error: 0.1276INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0163 - root_mean_squared_error: 0.1278 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0137 - root_mean_squared_error: 0.1171INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 9s 181ms/step - loss: 0.0137 - root_mean_squared_error: 0.1171 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0823
# Epoch 18/50
# 53/53 [==============================] - 1s 28ms/step - loss: 0.0135 - root_mean_squared_error: 0.1162 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1022
# Epoch 19/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0151 - root_mean_squared_error: 0.1228INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 9s 175ms/step - loss: 0.0151 - root_mean_squared_error: 0.1227 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0680
# Epoch 20/50
# 53/53 [==============================] - 1s 27ms/step - loss: 0.0126 - root_mean_squared_error: 0.1124 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0748
# Epoch 21/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0135 - root_mean_squared_error: 0.1162 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0702
# Epoch 22/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0125 - root_mean_squared_error: 0.1118INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 12s 236ms/step - loss: 0.0125 - root_mean_squared_error: 0.1120 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606
# Epoch 23/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0125 - root_mean_squared_error: 0.1120 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0631
# Epoch 24/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0659
# Epoch 25/50
# 53/53 [==============================] - 1s 28ms/step - loss: 0.0115 - root_mean_squared_error: 0.1074 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0617
# Epoch 26/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0111 - root_mean_squared_error: 0.1054INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 12s 225ms/step - loss: 0.0110 - root_mean_squared_error: 0.1050 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0573
# Epoch 27/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0099 - root_mean_squared_error: 0.0997 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0577
# Epoch 28/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0099 - root_mean_squared_error: 0.0995 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0619
# Epoch 29/50
# 53/53 [==============================] - 1s 28ms/step - loss: 0.0103 - root_mean_squared_error: 0.1015 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0584
# Epoch 30/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0098 - root_mean_squared_error: 0.0992INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 15s 279ms/step - loss: 0.0099 - root_mean_squared_error: 0.0994 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0545
# Epoch 31/50
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0097 - root_mean_squared_error: 0.0984 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0591
# Epoch 32/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0099 - root_mean_squared_error: 0.0995 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0592
# Epoch 33/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0092 - root_mean_squared_error: 0.0957INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 13s 250ms/step - loss: 0.0091 - root_mean_squared_error: 0.0955 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0528
# Epoch 34/50
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0094 - root_mean_squared_error: 0.0969 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614
# Epoch 35/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0093 - root_mean_squared_error: 0.0962INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 13s 254ms/step - loss: 0.0093 - root_mean_squared_error: 0.0962 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0519
# Epoch 36/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0087 - root_mean_squared_error: 0.0932 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0577
# Epoch 37/50
# 53/53 [==============================] - 2s 42ms/step - loss: 0.0094 - root_mean_squared_error: 0.0968 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0529
# Epoch 38/50
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0532
# Epoch 39/50
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0080 - root_mean_squared_error: 0.0895 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0531
# Epoch 40/50
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0090 - root_mean_squared_error: 0.0949 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0567
# Epoch 41/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0089 - root_mean_squared_error: 0.0943 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0528
# Epoch 42/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0077 - root_mean_squared_error: 0.0877 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0524
# Epoch 43/50
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0078 - root_mean_squared_error: 0.0884 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0520
# Epoch 44/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0077 - root_mean_squared_error: 0.0878 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0590
# Epoch 45/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0079 - root_mean_squared_error: 0.0892 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0548
# Epoch 46/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0076 - root_mean_squared_error: 0.0873INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 13s 250ms/step - loss: 0.0076 - root_mean_squared_error: 0.0873 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0507
# Epoch 47/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0071 - root_mean_squared_error: 0.0843INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 12s 224ms/step - loss: 0.0071 - root_mean_squared_error: 0.0841 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0502
# Epoch 48/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0078 - root_mean_squared_error: 0.0882INFO:tensorflow:Assets written to: Baffin_model_LT5\assets
# 53/53 [==============================] - 14s 266ms/step - loss: 0.0077 - root_mean_squared_error: 0.0880 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0500
# Epoch 49/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0072 - root_mean_squared_error: 0.0847 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0585
# Epoch 50/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0067 - root_mean_squared_error: 0.0817 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0548

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 5.637786694367727 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Baffin_model_LT5/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 10ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.06395456505434481
# MAE : 0.04524793914588493

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       -1.464506e+04      27600.624
# 1        1.326882e+05      61057.940
# 2        6.055362e+05     291275.949
# 3        8.689371e+05     678576.504
# 4        1.079947e+06     974461.347
# 5        1.212323e+06    1181121.087
# 6        1.211442e+06    1236299.254
# 7        1.067865e+06    1036981.003
# 8        8.555483e+05     847489.150
# 9        5.902750e+05     619129.338
# 10       2.935139e+05     195688.491
# 11       4.958147e+04      36670.811
# 12      -4.005298e+04      31777.310
# 13       5.328203e+04      82762.022
# 14       3.897606e+05     400043.823
# 15       6.503296e+05     733089.555
# 16       8.723039e+05     917362.266
# 17       1.050631e+06    1040584.040
# 18       1.118613e+06    1147997.675
# 19       1.011537e+06    1074255.327
# 20       8.030196e+05     875527.315
# 21       5.513719e+05     629820.756
# 22       2.776956e+05     204308.900
# 23       5.858954e+04      45059.062
# 24      -2.836780e+04      33770.277
# 25       5.110795e+04      64135.631
# 26       4.145556e+05     400581.715
# 27       6.765039e+05     698631.451
# 28       8.998462e+05     973313.225
# 29       1.068905e+06    1335339.087
# 30       1.122355e+06    1429096.704
# 31       1.010274e+06    1206542.314
# 32       8.133560e+05    1079292.433
# 33       5.702587e+05     788101.638
# 34       2.912598e+05     397326.270
# 35       6.168154e+04      97802.348
# 36      -2.811608e+04      62212.219
# 37       8.528850e+04     154051.600
# 38       4.812833e+05     610663.893
# 39       7.480448e+05     756679.164
# 40       9.985615e+05     962270.215
# 41       1.202372e+06    1235154.518
# 42       1.294097e+06    1161744.519
# 43       1.188752e+06    1136918.669
# 44       9.868265e+05     995852.026
# 45       7.399067e+05     781460.891
# 46       4.342690e+05     331845.048
# 47       1.494137e+05      99334.625
# 48      -6.484387e+03      49359.723
# 49       8.093425e+04      85693.282

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 16ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
