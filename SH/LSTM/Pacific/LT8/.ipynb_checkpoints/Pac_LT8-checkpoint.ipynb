# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Pacific_Extent = pd.read_excel(filepath, sheet_name='Pacific-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Pacific_Extent)
fp.date_time(Pacific_Extent)
# Out:
#           Extent       Date
# 0     668714.275 1979-01-01
# 1     566930.458 1979-02-01
# 2     688420.115 1979-03-01
# 3     859963.043 1979-04-01
# 4    1127120.160 1979-05-01
# ..           ...        ...
# 533  1134056.102 2023-06-01
# 534  1484824.377 2023-07-01
# 535  1671324.717 2023-08-01
# 536  1726376.097 2023-09-01
# 537  1690631.996 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Pacific_Extent['Extent'] = scaler.fit_transform(Pacific_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 8
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Pacific_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((519, 12, 1), (519,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Pacific_model_LT8/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2148 - root_mean_squared_error: 0.4635INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 17s 215ms/step - loss: 0.2148 - root_mean_squared_error: 0.4635 - val_loss: 0.1733 - val_root_mean_squared_error: 0.4163
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0994 - root_mean_squared_error: 0.3153INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 10s 197ms/step - loss: 0.0994 - root_mean_squared_error: 0.3153 - val_loss: 0.0717 - val_root_mean_squared_error: 0.2679
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0713 - root_mean_squared_error: 0.2671INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 10s 185ms/step - loss: 0.0713 - root_mean_squared_error: 0.2670 - val_loss: 0.0625 - val_root_mean_squared_error: 0.2500
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0604 - root_mean_squared_error: 0.2458INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 14s 266ms/step - loss: 0.0604 - root_mean_squared_error: 0.2458 - val_loss: 0.0527 - val_root_mean_squared_error: 0.2297
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0511 - root_mean_squared_error: 0.2260INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 12s 237ms/step - loss: 0.0508 - root_mean_squared_error: 0.2254 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2023
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0383 - root_mean_squared_error: 0.1958INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 12s 221ms/step - loss: 0.0384 - root_mean_squared_error: 0.1959 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1605
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0248 - root_mean_squared_error: 0.1576INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 13s 242ms/step - loss: 0.0248 - root_mean_squared_error: 0.1575 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1208
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0164 - root_mean_squared_error: 0.1281INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 12s 229ms/step - loss: 0.0164 - root_mean_squared_error: 0.1281 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0991
# Epoch 9/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0148 - root_mean_squared_error: 0.1215INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 13s 244ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0927
# Epoch 10/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0143 - root_mean_squared_error: 0.1194 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0942
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0132 - root_mean_squared_error: 0.1147INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 12s 238ms/step - loss: 0.0132 - root_mean_squared_error: 0.1147 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0131 - root_mean_squared_error: 0.1143INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 12s 231ms/step - loss: 0.0131 - root_mean_squared_error: 0.1143 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0858
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0113 - root_mean_squared_error: 0.1065INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 12s 224ms/step - loss: 0.0113 - root_mean_squared_error: 0.1065 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0855
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0112 - root_mean_squared_error: 0.1057INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 12s 227ms/step - loss: 0.0112 - root_mean_squared_error: 0.1057 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 15/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0121 - root_mean_squared_error: 0.1099 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0860
# Epoch 16/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0101 - root_mean_squared_error: 0.1007INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 13s 245ms/step - loss: 0.0103 - root_mean_squared_error: 0.1017 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0780
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0108 - root_mean_squared_error: 0.1041INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 11s 218ms/step - loss: 0.0108 - root_mean_squared_error: 0.1041 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0767
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0100 - root_mean_squared_error: 0.1000INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 12s 230ms/step - loss: 0.0100 - root_mean_squared_error: 0.1000 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0762
# Epoch 19/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0100 - root_mean_squared_error: 0.0999 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0767
# Epoch 20/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0104 - root_mean_squared_error: 0.1018INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 12s 239ms/step - loss: 0.0103 - root_mean_squared_error: 0.1015 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0760
# Epoch 21/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0098 - root_mean_squared_error: 0.0988INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 12s 232ms/step - loss: 0.0099 - root_mean_squared_error: 0.0995 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0737
# Epoch 22/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0106 - root_mean_squared_error: 0.1028 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0749
# Epoch 23/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0096 - root_mean_squared_error: 0.0980INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 12s 235ms/step - loss: 0.0096 - root_mean_squared_error: 0.0982 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0728
# Epoch 24/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0094 - root_mean_squared_error: 0.0970 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0774
# Epoch 25/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0092 - root_mean_squared_error: 0.0960 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0736
# Epoch 26/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0087 - root_mean_squared_error: 0.0930 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0740
# Epoch 27/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0092 - root_mean_squared_error: 0.0957 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0736
# Epoch 28/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0099 - root_mean_squared_error: 0.0994INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 12s 237ms/step - loss: 0.0098 - root_mean_squared_error: 0.0991 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0727
# Epoch 29/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0089 - root_mean_squared_error: 0.0945INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 13s 243ms/step - loss: 0.0089 - root_mean_squared_error: 0.0945 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0716
# Epoch 30/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0093 - root_mean_squared_error: 0.0962 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0889
# Epoch 31/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0094 - root_mean_squared_error: 0.0972 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0723
# Epoch 32/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0088 - root_mean_squared_error: 0.0938INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 12s 230ms/step - loss: 0.0088 - root_mean_squared_error: 0.0938 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0710
# Epoch 33/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0755
# Epoch 34/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0089 - root_mean_squared_error: 0.0942 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0776
# Epoch 35/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0084 - root_mean_squared_error: 0.0916 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0720
# Epoch 36/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0087 - root_mean_squared_error: 0.0933 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0723
# Epoch 37/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0086 - root_mean_squared_error: 0.0928INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 12s 239ms/step - loss: 0.0086 - root_mean_squared_error: 0.0928 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0690
# Epoch 38/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0090 - root_mean_squared_error: 0.0947 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0694
# Epoch 39/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0087 - root_mean_squared_error: 0.0935INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 12s 227ms/step - loss: 0.0087 - root_mean_squared_error: 0.0935 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0689
# Epoch 40/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0084 - root_mean_squared_error: 0.0914 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0737
# Epoch 41/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0081 - root_mean_squared_error: 0.0902INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 13s 255ms/step - loss: 0.0081 - root_mean_squared_error: 0.0902 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0682
# Epoch 42/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0078 - root_mean_squared_error: 0.0881 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 43/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0083 - root_mean_squared_error: 0.0908 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0754
# Epoch 44/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0080 - root_mean_squared_error: 0.0892 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0683
# Epoch 45/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 46/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0075 - root_mean_squared_error: 0.0865INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 12s 237ms/step - loss: 0.0075 - root_mean_squared_error: 0.0865 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679
# Epoch 47/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0074 - root_mean_squared_error: 0.0859 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0753
# Epoch 48/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0078 - root_mean_squared_error: 0.0883 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0746
# Epoch 49/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0077 - root_mean_squared_error: 0.0875INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 12s 221ms/step - loss: 0.0077 - root_mean_squared_error: 0.0875 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0676
# Epoch 50/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0079 - root_mean_squared_error: 0.0889 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 6.220268150170644 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Pacific_model_LT8/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 8ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.06233590581495661
# MAE : 0.04819006777056966

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        9.319712e+05     863206.294
# 1        6.179639e+05     635624.004
# 2        4.846153e+05     460009.672
# 3        5.545496e+05     610848.036
# 4        8.649656e+05     819257.445
# 5        1.190073e+06    1129627.707
# 6        1.500422e+06    1463383.236
# 7        1.737234e+06    1614536.727
# 8        1.879130e+06    1862498.612
# 9        1.915919e+06    2099349.296
# 10       1.827454e+06    1981614.046
# 11       1.413078e+06    1433022.369
# 12       9.135406e+05     826739.716
# 13       5.822804e+05     477145.887
# 14       4.302718e+05     314469.289
# 15       4.361373e+05     463134.749
# 16       7.552569e+05     946522.292
# 17       1.206118e+06    1309266.570
# 18       1.540253e+06    1507947.309
# 19       1.770588e+06    1804167.937
# 20       1.903943e+06    1908002.139
# 21       1.936684e+06    1892748.521
# 22       1.809472e+06    1601079.640
# 23       1.364132e+06    1327804.521
# 24       8.871234e+05     812074.231
# 25       5.739657e+05     493355.897
# 26       4.324192e+05     317229.330
# 27       4.422132e+05     425777.624
# 28       7.486284e+05     827172.620
# 29       1.160049e+06    1162367.223
# 30       1.495953e+06    1413734.261
# 31       1.758838e+06    1574257.849
# 32       1.887133e+06    1786961.251
# 33       1.889016e+06    1857942.866
# 34       1.712924e+06    1406291.588
# 35       1.196230e+06    1025555.371
# 36       7.724517e+05     632862.782
# 37       5.421098e+05     308194.756
# 38       4.314340e+05     194921.078
# 39       5.388718e+05     245569.900
# 40       8.860236e+05     533532.424
# 41       1.204116e+06     943124.529
# 42       1.457848e+06    1134056.102
# 43       1.686660e+06    1484824.377
# 44       1.799113e+06    1671324.717
# 45       1.797882e+06    1726376.097
# 46       1.669155e+06    1690631.996

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 12ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
