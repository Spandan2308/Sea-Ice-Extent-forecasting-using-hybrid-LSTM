# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Weddell_Extent = pd.read_excel(filepath, sheet_name='Weddell-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Weddell_Extent)
fp.date_time(Weddell_Extent)
# Out:
#           Extent       Date
# 0    2136510.859 1979-01-01
# 1    1243495.891 1979-02-01
# 2    1699053.449 1979-03-01
# 3    2617442.085 1979-04-01
# 4    3852934.206 1979-05-01
# ..           ...        ...
# 533  3668127.143 2023-06-01
# 534  4805519.784 2023-07-01
# 535  5524445.234 2023-08-01
# 536  6006669.861 2023-09-01
# 537  5507961.583 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Weddell_Extent['Extent'] = scaler.fit_transform(Weddell_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 11
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Weddell_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((516, 12, 1), (516,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Weddell_model_LT11/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2556 - root_mean_squared_error: 0.5055INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 38s 504ms/step - loss: 0.2520 - root_mean_squared_error: 0.5020 - val_loss: 0.1267 - val_root_mean_squared_error: 0.3559
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0929 - root_mean_squared_error: 0.3047INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 25s 481ms/step - loss: 0.0929 - root_mean_squared_error: 0.3047 - val_loss: 0.0814 - val_root_mean_squared_error: 0.2853
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0707 - root_mean_squared_error: 0.2660INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 24s 469ms/step - loss: 0.0707 - root_mean_squared_error: 0.2660 - val_loss: 0.0641 - val_root_mean_squared_error: 0.2531
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0491 - root_mean_squared_error: 0.2216INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 26s 507ms/step - loss: 0.0492 - root_mean_squared_error: 0.2218 - val_loss: 0.0393 - val_root_mean_squared_error: 0.1982
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0293 - root_mean_squared_error: 0.1712INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 26s 507ms/step - loss: 0.0293 - root_mean_squared_error: 0.1712 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1371
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0164 - root_mean_squared_error: 0.1281INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 26s 505ms/step - loss: 0.0164 - root_mean_squared_error: 0.1281 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0998
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0118 - root_mean_squared_error: 0.1087INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0798
# Epoch 8/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0103 - root_mean_squared_error: 0.1015 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0840
# Epoch 9/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0089 - root_mean_squared_error: 0.0945INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0089 - root_mean_squared_error: 0.0944 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0767
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0091 - root_mean_squared_error: 0.0956INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 27s 512ms/step - loss: 0.0091 - root_mean_squared_error: 0.0955 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0740
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0078 - root_mean_squared_error: 0.0881INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 26s 490ms/step - loss: 0.0078 - root_mean_squared_error: 0.0882 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0709
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0907INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 26s 493ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0690
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0080 - root_mean_squared_error: 0.0892INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 26s 503ms/step - loss: 0.0080 - root_mean_squared_error: 0.0892 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0675
# Epoch 14/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0080 - root_mean_squared_error: 0.0896 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0706
# Epoch 15/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0072 - root_mean_squared_error: 0.0847 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0698
# Epoch 16/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0070 - root_mean_squared_error: 0.0838INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0070 - root_mean_squared_error: 0.0836 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0670
# Epoch 17/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0067 - root_mean_squared_error: 0.0817 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679
# Epoch 18/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0062 - root_mean_squared_error: 0.0790INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 27s 514ms/step - loss: 0.0062 - root_mean_squared_error: 0.0787 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0659
# Epoch 19/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0060 - root_mean_squared_error: 0.0777 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0778
# Epoch 20/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0068 - root_mean_squared_error: 0.0822INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 26s 507ms/step - loss: 0.0068 - root_mean_squared_error: 0.0822 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0651
# Epoch 21/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0058 - root_mean_squared_error: 0.0764 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0769
# Epoch 22/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0060 - root_mean_squared_error: 0.0777 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0652
# Epoch 23/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0062 - root_mean_squared_error: 0.0786 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0652
# Epoch 24/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0065 - root_mean_squared_error: 0.0809 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0758
# Epoch 25/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0061 - root_mean_squared_error: 0.0778 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0741
# Epoch 26/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0057 - root_mean_squared_error: 0.0755 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0701
# Epoch 27/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0060 - root_mean_squared_error: 0.0777INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 27s 521ms/step - loss: 0.0060 - root_mean_squared_error: 0.0777 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0617
# Epoch 28/50
# 53/53 [==============================] - 3s 49ms/step - loss: 0.0055 - root_mean_squared_error: 0.0743 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0650
# Epoch 29/50
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0055 - root_mean_squared_error: 0.0743 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0637
# Epoch 30/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0060 - root_mean_squared_error: 0.0774 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0705
# Epoch 31/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0056 - root_mean_squared_error: 0.0749 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0648
# Epoch 32/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0054 - root_mean_squared_error: 0.0735 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0641
# Epoch 33/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0055 - root_mean_squared_error: 0.0743INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 27s 513ms/step - loss: 0.0055 - root_mean_squared_error: 0.0741 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0601
# Epoch 34/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0050 - root_mean_squared_error: 0.0704 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0646
# Epoch 35/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0051 - root_mean_squared_error: 0.0712 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0624
# Epoch 36/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0050 - root_mean_squared_error: 0.0708INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 27s 511ms/step - loss: 0.0050 - root_mean_squared_error: 0.0708 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0580
# Epoch 37/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0050 - root_mean_squared_error: 0.0708INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 27s 509ms/step - loss: 0.0050 - root_mean_squared_error: 0.0708 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0578
# Epoch 38/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0051 - root_mean_squared_error: 0.0715 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0584
# Epoch 39/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0057 - root_mean_squared_error: 0.0755INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 27s 513ms/step - loss: 0.0057 - root_mean_squared_error: 0.0755 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0573
# Epoch 40/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0050 - root_mean_squared_error: 0.0705 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0574
# Epoch 41/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0047 - root_mean_squared_error: 0.0684 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0574
# Epoch 42/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0051 - root_mean_squared_error: 0.0711INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 27s 510ms/step - loss: 0.0050 - root_mean_squared_error: 0.0709 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0559
# Epoch 43/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0047 - root_mean_squared_error: 0.0685 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0595
# Epoch 44/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0050 - root_mean_squared_error: 0.0710 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0574
# Epoch 45/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0046 - root_mean_squared_error: 0.0681 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0625
# Epoch 46/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0046 - root_mean_squared_error: 0.0679 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0584
# Epoch 47/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0043 - root_mean_squared_error: 0.0655 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0567
# Epoch 48/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0046 - root_mean_squared_error: 0.0680 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0569
# Epoch 49/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0048 - root_mean_squared_error: 0.0693 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0565
# Epoch 50/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0042 - root_mean_squared_error: 0.0649INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 27s 516ms/step - loss: 0.0042 - root_mean_squared_error: 0.0649 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0525

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 11.33319407304128 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Weddell_model_LT11/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 26ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.05362933987563563
# MAE : 0.04253722420061712

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0         1187078.750    1527666.815
# 1         1644443.375    2121949.701
# 2         3259561.750    3562381.775
# 3         4734830.500    5004305.983
# 4         5708881.000    6176613.878
# 5         6299135.000    6794233.093
# 6         6577834.500    7024136.637
# 7         6467849.000    6554271.388
# 8         5739057.500    6172281.701
# 9         4028827.750    4175225.799
# 10        1818034.125    1748380.899
# 11        1124120.125    1256191.080
# 12        1214167.000    1347295.364
# 13        2032666.250    2180184.677
# 14        3590224.000    3419295.982
# 15        4993869.500    4786146.771
# 16        5903188.500    5968132.718
# 17        6484494.500    6556934.174
# 18        6675051.500    6614949.980
# 19        6491893.000    6035207.368
# 20        5800572.500    5274244.730
# 21        3861076.500    3505146.372
# 22        1593426.375    1478130.228
# 23        1035996.375    1096780.503
# 24        1165590.750    1387234.069
# 25        1852363.625    2128693.591
# 26        3346262.000    3313318.704
# 27        4784562.000    4218076.656
# 28        5747218.000    5257641.941
# 29        6298118.500    5956603.340
# 30        6450153.000    6256062.049
# 31        6247530.000    5974548.305
# 32        5494105.500    5569396.731
# 33        3663161.000    3684108.410
# 34        1512561.500    1451614.707
# 35        1069499.625    1089888.684
# 36        1227334.625    1255222.909
# 37        1944146.750    1704492.279
# 38        3305307.500    2563551.804
# 39        4566072.500    3668127.143
# 40        5479077.000    4805519.784
# 41        6049681.500    5524445.234
# 42        6319190.500    6006669.861
# 43        6268060.500    5507961.583

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 39ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
