# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bering = pd.read_excel(filepath, sheet_name='Bering-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Bering)
fp.date_time(Bering)
# Out:
#          Extent       Date
# 0    320266.650 1979-01-01
# 1    541778.338 1979-02-01
# 2    638262.988 1979-03-01
# 3    423025.159 1979-04-01
# 4    215587.216 1979-05-01
# ..          ...        ...
# 488  317377.493 2023-05-01
# 489   39601.476 2023-06-01
# 490   16935.702 2023-07-01
# 491    1305.744 2023-09-01
# 492   12255.644 2023-10-01
#
# [493 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bering['Extent'] = scaler.fit_transform(Bering['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 9
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bering['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((473, 12, 1), (473,))

# %%
X_train, y_train = X[:384], y[:384]
X_val, y_val = X[384:432], y[384:432]
X_test, y_test = X[432:], y[432:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Bering_model_LT9/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 46/48 [===========================>..] - ETA: 0s - loss: 0.1567 - root_mean_squared_error: 0.3958INFO:tensorflow:Assets written to: Bering_model_LT9\assets
# 48/48 [==============================] - 34s 540ms/step - loss: 0.1551 - root_mean_squared_error: 0.3938 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2013
# Epoch 2/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0925 - root_mean_squared_error: 0.3042INFO:tensorflow:Assets written to: Bering_model_LT9\assets
# 48/48 [==============================] - 35s 734ms/step - loss: 0.0925 - root_mean_squared_error: 0.3042 - val_loss: 0.0386 - val_root_mean_squared_error: 0.1965
# Epoch 3/50
# 47/48 [============================>.] - ETA: 0s - loss: 0.0693 - root_mean_squared_error: 0.2633INFO:tensorflow:Assets written to: Bering_model_LT9\assets
# 48/48 [==============================] - 36s 771ms/step - loss: 0.0694 - root_mean_squared_error: 0.2635 - val_loss: 0.0323 - val_root_mean_squared_error: 0.1797
# Epoch 4/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0500 - root_mean_squared_error: 0.2237INFO:tensorflow:Assets written to: Bering_model_LT9\assets
# 48/48 [==============================] - 31s 663ms/step - loss: 0.0500 - root_mean_squared_error: 0.2237 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1584
# Epoch 5/50
# 46/48 [===========================>..] - ETA: 0s - loss: 0.0307 - root_mean_squared_error: 0.1753INFO:tensorflow:Assets written to: Bering_model_LT9\assets
# 48/48 [==============================] - 19s 413ms/step - loss: 0.0306 - root_mean_squared_error: 0.1748 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1164
# Epoch 6/50
# 47/48 [============================>.] - ETA: 0s - loss: 0.0266 - root_mean_squared_error: 0.1632INFO:tensorflow:Assets written to: Bering_model_LT9\assets
# 48/48 [==============================] - 20s 419ms/step - loss: 0.0267 - root_mean_squared_error: 0.1635 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1125
# Epoch 7/50
# 48/48 [==============================] - 2s 34ms/step - loss: 0.0268 - root_mean_squared_error: 0.1636 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1177
# Epoch 8/50
# 48/48 [==============================] - 2s 33ms/step - loss: 0.0215 - root_mean_squared_error: 0.1468 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1127
# Epoch 9/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0205 - root_mean_squared_error: 0.1433 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1203
# Epoch 10/50
# 48/48 [==============================] - 2s 36ms/step - loss: 0.0185 - root_mean_squared_error: 0.1359 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1294
# Epoch 11/50
# 48/48 [==============================] - 2s 44ms/step - loss: 0.0159 - root_mean_squared_error: 0.1263 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1256
# Epoch 12/50
# 48/48 [==============================] - 2s 37ms/step - loss: 0.0172 - root_mean_squared_error: 0.1313 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1468
# Epoch 13/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0163 - root_mean_squared_error: 0.1277 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1516
# Epoch 14/50
# 48/48 [==============================] - 2s 37ms/step - loss: 0.0160 - root_mean_squared_error: 0.1263 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1590
# Epoch 15/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0149 - root_mean_squared_error: 0.1220 - val_loss: 0.0325 - val_root_mean_squared_error: 0.1803
# Epoch 16/50
# 48/48 [==============================] - 2s 45ms/step - loss: 0.0168 - root_mean_squared_error: 0.1298 - val_loss: 0.0223 - val_root_mean_squared_error: 0.1494
# Epoch 17/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0158 - root_mean_squared_error: 0.1256 - val_loss: 0.0324 - val_root_mean_squared_error: 0.1801
# Epoch 18/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195 - val_loss: 0.0478 - val_root_mean_squared_error: 0.2186
# Epoch 19/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182 - val_loss: 0.0445 - val_root_mean_squared_error: 0.2110
# Epoch 20/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0126 - root_mean_squared_error: 0.1122 - val_loss: 0.0500 - val_root_mean_squared_error: 0.2237
# Epoch 21/50
# 48/48 [==============================] - 2s 34ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161 - val_loss: 0.0448 - val_root_mean_squared_error: 0.2116
# Epoch 22/50
# 48/48 [==============================] - 2s 35ms/step - loss: 0.0133 - root_mean_squared_error: 0.1152 - val_loss: 0.0535 - val_root_mean_squared_error: 0.2312
# Epoch 23/50
# 48/48 [==============================] - 2s 32ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087 - val_loss: 0.0569 - val_root_mean_squared_error: 0.2385
# Epoch 24/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186 - val_loss: 0.0641 - val_root_mean_squared_error: 0.2532
# Epoch 25/50
# 48/48 [==============================] - 3s 52ms/step - loss: 0.0116 - root_mean_squared_error: 0.1078 - val_loss: 0.0612 - val_root_mean_squared_error: 0.2473
# Epoch 26/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0122 - root_mean_squared_error: 0.1105 - val_loss: 0.0629 - val_root_mean_squared_error: 0.2508
# Epoch 27/50
# 48/48 [==============================] - 2s 38ms/step - loss: 0.0123 - root_mean_squared_error: 0.1111 - val_loss: 0.0570 - val_root_mean_squared_error: 0.2387
# Epoch 28/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0133 - root_mean_squared_error: 0.1155 - val_loss: 0.0603 - val_root_mean_squared_error: 0.2456
# Epoch 29/50
# 48/48 [==============================] - 2s 50ms/step - loss: 0.0118 - root_mean_squared_error: 0.1085 - val_loss: 0.0613 - val_root_mean_squared_error: 0.2476
# Epoch 30/50
# 48/48 [==============================] - 2s 40ms/step - loss: 0.0116 - root_mean_squared_error: 0.1075 - val_loss: 0.0589 - val_root_mean_squared_error: 0.2427
# Epoch 31/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0112 - root_mean_squared_error: 0.1060 - val_loss: 0.0580 - val_root_mean_squared_error: 0.2409
# Epoch 32/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0103 - root_mean_squared_error: 0.1016 - val_loss: 0.0508 - val_root_mean_squared_error: 0.2254
# Epoch 33/50
# 48/48 [==============================] - 2s 45ms/step - loss: 0.0101 - root_mean_squared_error: 0.1006 - val_loss: 0.0637 - val_root_mean_squared_error: 0.2524
# Epoch 34/50
# 48/48 [==============================] - 2s 36ms/step - loss: 0.0114 - root_mean_squared_error: 0.1068 - val_loss: 0.0667 - val_root_mean_squared_error: 0.2583
# Epoch 35/50
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0101 - root_mean_squared_error: 0.1003 - val_loss: 0.0677 - val_root_mean_squared_error: 0.2603
# Epoch 36/50
# 48/48 [==============================] - 2s 51ms/step - loss: 0.0113 - root_mean_squared_error: 0.1063 - val_loss: 0.0725 - val_root_mean_squared_error: 0.2692
# Epoch 37/50
# 48/48 [==============================] - 3s 53ms/step - loss: 0.0111 - root_mean_squared_error: 0.1056 - val_loss: 0.0463 - val_root_mean_squared_error: 0.2152
# Epoch 38/50
# 48/48 [==============================] - 2s 35ms/step - loss: 0.0103 - root_mean_squared_error: 0.1013 - val_loss: 0.0680 - val_root_mean_squared_error: 0.2607
# Epoch 39/50
# 48/48 [==============================] - 2s 45ms/step - loss: 0.0105 - root_mean_squared_error: 0.1024 - val_loss: 0.0545 - val_root_mean_squared_error: 0.2335
# Epoch 40/50
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0106 - root_mean_squared_error: 0.1029 - val_loss: 0.0563 - val_root_mean_squared_error: 0.2372
# Epoch 41/50
# 48/48 [==============================] - 2s 50ms/step - loss: 0.0096 - root_mean_squared_error: 0.0978 - val_loss: 0.0616 - val_root_mean_squared_error: 0.2482
# Epoch 42/50
# 48/48 [==============================] - 2s 36ms/step - loss: 0.0102 - root_mean_squared_error: 0.1012 - val_loss: 0.0665 - val_root_mean_squared_error: 0.2578
# Epoch 43/50
# 48/48 [==============================] - 1s 31ms/step - loss: 0.0101 - root_mean_squared_error: 0.1005 - val_loss: 0.0491 - val_root_mean_squared_error: 0.2215
# Epoch 44/50
# 48/48 [==============================] - 1s 30ms/step - loss: 0.0106 - root_mean_squared_error: 0.1030 - val_loss: 0.0604 - val_root_mean_squared_error: 0.2458
# Epoch 45/50
# 48/48 [==============================] - 2s 33ms/step - loss: 0.0109 - root_mean_squared_error: 0.1046 - val_loss: 0.0444 - val_root_mean_squared_error: 0.2107
# Epoch 46/50
# 48/48 [==============================] - 1s 29ms/step - loss: 0.0098 - root_mean_squared_error: 0.0989 - val_loss: 0.0638 - val_root_mean_squared_error: 0.2526
# Epoch 47/50
# 48/48 [==============================] - 2s 32ms/step - loss: 0.0100 - root_mean_squared_error: 0.1000 - val_loss: 0.0451 - val_root_mean_squared_error: 0.2124
# Epoch 48/50
# 48/48 [==============================] - 1s 29ms/step - loss: 0.0101 - root_mean_squared_error: 0.1007 - val_loss: 0.0613 - val_root_mean_squared_error: 0.2477
# Epoch 49/50
# 48/48 [==============================] - 1s 29ms/step - loss: 0.0101 - root_mean_squared_error: 0.1006 - val_loss: 0.0577 - val_root_mean_squared_error: 0.2401
# Epoch 50/50
# 48/48 [==============================] - 1s 29ms/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0560 - val_root_mean_squared_error: 0.2366

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 4.30672085682551 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bering_model_LT9/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 21ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.13706044424035152
# MAE : 0.1074513156026168

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       323918.968750     708542.184
# 1       275304.562500     652598.000
# 2       216391.390625     414216.785
# 3       158197.250000     236263.303
# 4       108764.117188      43422.368
# 5        71606.359375       2161.744
# 6        52449.660156        944.181
# 7        63282.273438      13977.643
# 8       165102.218750      24795.001
# 9       348238.906250     168828.990
# 10      501000.125000     461098.498
# 11      544727.125000     591635.798
# 12      498182.468750     598360.298
# 13      381700.250000     531742.038
# 14      269361.281250     302131.004
# 15      174308.296875      57748.135
# 16      101143.187500       3054.962
# 17       48191.398438        442.539
# 18       33442.523438       8541.643
# 19      107712.968750     121335.125
# 20      247852.859375     360205.990
# 21      402235.406250     651717.220
# 22      512918.718750     779385.402
# 23      506816.250000     710314.085
# 24      403019.656250     578635.421
# 25      288464.906250     199031.792
# 26      189932.750000      43795.314
# 27      112834.125000       3015.211
# 28       71049.953125       1206.623
# 29       90588.679688       8506.979
# 30      212839.687500      41065.748
# 31      405559.812500     169363.165
# 32      583513.687500     531698.544
# 33      685951.375000     631496.345
# 34      597516.812500     612860.407
# 35      447179.500000     552903.799
# 36      300816.500000     317377.493
# 37      182097.359375      39601.476
# 38       92850.492188      16935.702
# 39       33092.941406       1305.744
# 40       13420.235352      12255.644

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 15/15 [==============================] - 0s 20ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
