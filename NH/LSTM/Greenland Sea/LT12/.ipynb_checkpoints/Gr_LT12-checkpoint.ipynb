# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Greenland = pd.read_excel(filepath, sheet_name='Greenland-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Greenland)
fp.date_time(Greenland)
# Out:
#           Extent       Date
# 0    1076123.146 1979-01-01
# 1    1099248.063 1979-02-01
# 2    1036964.901 1979-03-01
# 3     958927.937 1979-04-01
# 4     823812.694 1979-05-01
# ..           ...        ...
# 533   721350.515 2023-06-01
# 534   459033.164 2023-07-01
# 535   282045.909 2023-08-01
# 536   270397.608 2023-09-01
# 537   449910.973 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Greenland['Extent'] = scaler.fit_transform(Greenland['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 12
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Greenland['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((515, 12, 1), (515,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Greenland_model_LT12/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2896 - root_mean_squared_error: 0.5382INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 17s 212ms/step - loss: 0.2890 - root_mean_squared_error: 0.5376 - val_loss: 0.1269 - val_root_mean_squared_error: 0.3562
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1234 - root_mean_squared_error: 0.3513INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 9s 167ms/step - loss: 0.1234 - root_mean_squared_error: 0.3513 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1841
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0482 - root_mean_squared_error: 0.2196INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 9s 177ms/step - loss: 0.0482 - root_mean_squared_error: 0.2196 - val_loss: 0.0303 - val_root_mean_squared_error: 0.1741
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0464 - root_mean_squared_error: 0.2153INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 10s 196ms/step - loss: 0.0464 - root_mean_squared_error: 0.2153 - val_loss: 0.0296 - val_root_mean_squared_error: 0.1721
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0444 - root_mean_squared_error: 0.2107INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 9s 169ms/step - loss: 0.0444 - root_mean_squared_error: 0.2107 - val_loss: 0.0292 - val_root_mean_squared_error: 0.1709
# Epoch 6/50
# 53/53 [==============================] - 1s 26ms/step - loss: 0.0423 - root_mean_squared_error: 0.2056 - val_loss: 0.0323 - val_root_mean_squared_error: 0.1796
# Epoch 7/50
# 53/53 [==============================] - 1s 28ms/step - loss: 0.0403 - root_mean_squared_error: 0.2008 - val_loss: 0.0306 - val_root_mean_squared_error: 0.1750
# Epoch 8/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0381 - root_mean_squared_error: 0.1952 - val_loss: 0.0318 - val_root_mean_squared_error: 0.1782
# Epoch 9/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0366 - root_mean_squared_error: 0.1913 - val_loss: 0.0304 - val_root_mean_squared_error: 0.1744
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0333 - root_mean_squared_error: 0.1824INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 10s 188ms/step - loss: 0.0331 - root_mean_squared_error: 0.1818 - val_loss: 0.0277 - val_root_mean_squared_error: 0.1663
# Epoch 11/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0306 - root_mean_squared_error: 0.1749 - val_loss: 0.0294 - val_root_mean_squared_error: 0.1716
# Epoch 12/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0268 - root_mean_squared_error: 0.1637INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 9s 179ms/step - loss: 0.0272 - root_mean_squared_error: 0.1649 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1569
# Epoch 13/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0252 - root_mean_squared_error: 0.1587 - val_loss: 0.0333 - val_root_mean_squared_error: 0.1824
# Epoch 14/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0234 - root_mean_squared_error: 0.1529 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1623
# Epoch 15/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0223 - root_mean_squared_error: 0.1492INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 10s 199ms/step - loss: 0.0222 - root_mean_squared_error: 0.1489 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1361
# Epoch 16/50
# 53/53 [==============================] - 1s 27ms/step - loss: 0.0214 - root_mean_squared_error: 0.1464 - val_loss: 0.0269 - val_root_mean_squared_error: 0.1640
# Epoch 17/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0219 - root_mean_squared_error: 0.1480 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1387
# Epoch 18/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0221 - root_mean_squared_error: 0.1485 - val_loss: 0.0292 - val_root_mean_squared_error: 0.1708
# Epoch 19/50
# 53/53 [==============================] - 1s 28ms/step - loss: 0.0213 - root_mean_squared_error: 0.1458 - val_loss: 0.0316 - val_root_mean_squared_error: 0.1777
# Epoch 20/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0212 - root_mean_squared_error: 0.1455 - val_loss: 0.0358 - val_root_mean_squared_error: 0.1892
# Epoch 21/50
# 53/53 [==============================] - 1s 26ms/step - loss: 0.0223 - root_mean_squared_error: 0.1494 - val_loss: 0.0301 - val_root_mean_squared_error: 0.1735
# Epoch 22/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0207 - root_mean_squared_error: 0.1439 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1453
# Epoch 23/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0202 - root_mean_squared_error: 0.1423 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1468
# Epoch 24/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0183 - root_mean_squared_error: 0.1354 - val_loss: 0.0259 - val_root_mean_squared_error: 0.1610
# Epoch 25/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0196 - root_mean_squared_error: 0.1401 - val_loss: 0.0403 - val_root_mean_squared_error: 0.2007
# Epoch 26/50
# 53/53 [==============================] - 2s 28ms/step - loss: 0.0205 - root_mean_squared_error: 0.1431 - val_loss: 0.0377 - val_root_mean_squared_error: 0.1941
# Epoch 27/50
# 53/53 [==============================] - 1s 27ms/step - loss: 0.0198 - root_mean_squared_error: 0.1406 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1472
# Epoch 28/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0191 - root_mean_squared_error: 0.1383 - val_loss: 0.0255 - val_root_mean_squared_error: 0.1598
# Epoch 29/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0192 - root_mean_squared_error: 0.1384 - val_loss: 0.0202 - val_root_mean_squared_error: 0.1420
# Epoch 30/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0193 - root_mean_squared_error: 0.1390 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1622
# Epoch 31/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0190 - root_mean_squared_error: 0.1379 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1434
# Epoch 32/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0189 - root_mean_squared_error: 0.1374 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1587
# Epoch 33/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0188 - root_mean_squared_error: 0.1373 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1648
# Epoch 34/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0191 - root_mean_squared_error: 0.1381 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1460
# Epoch 35/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0186 - root_mean_squared_error: 0.1365INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 10s 195ms/step - loss: 0.0186 - root_mean_squared_error: 0.1363 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1181
# Epoch 36/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0193 - root_mean_squared_error: 0.1391 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1322
# Epoch 37/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0195 - root_mean_squared_error: 0.1398 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1615
# Epoch 38/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0191 - root_mean_squared_error: 0.1381 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1246
# Epoch 39/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0190 - root_mean_squared_error: 0.1379 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1431
# Epoch 40/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0188 - root_mean_squared_error: 0.1370 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1508
# Epoch 41/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0179 - root_mean_squared_error: 0.1337 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1438
# Epoch 42/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0189 - root_mean_squared_error: 0.1373 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1251
# Epoch 43/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1402
# Epoch 44/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0182 - root_mean_squared_error: 0.1349 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1316
# Epoch 45/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0177 - root_mean_squared_error: 0.1330 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1344
# Epoch 46/50
# 53/53 [==============================] - 1s 28ms/step - loss: 0.0181 - root_mean_squared_error: 0.1346 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1526
# Epoch 47/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0170 - root_mean_squared_error: 0.1302 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1215
# Epoch 48/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0176 - root_mean_squared_error: 0.1327 - val_loss: 0.0191 - val_root_mean_squared_error: 0.1381
# Epoch 49/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0181 - root_mean_squared_error: 0.1344 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1186
# Epoch 50/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0177 - root_mean_squared_error: 0.1330 - val_loss: 0.0195 - val_root_mean_squared_error: 0.1396

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 2.608231484889984 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Greenland_model_LT12/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 13ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.11048856018413089
# MAE : 0.0881058829138374

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        657178.87500     777596.225
# 1        627474.75000     687087.673
# 2        572132.25000     622337.816
# 3        532747.12500     467232.074
# 4        449138.28125     297495.641
# 5        396274.56250     268909.854
# 6        434269.21875     408072.791
# 7        476036.18750     552314.148
# 8        510769.56250     651062.408
# 9        565917.00000     695022.674
# 10       630439.75000     670974.305
# 11       672954.37500     710035.543
# 12       688919.62500     699672.538
# 13       670648.06250     730897.021
# 14       581923.43750     588598.988
# 15       476556.65625     281754.041
# 16       411490.34375     117830.266
# 17       415659.81250      81838.250
# 18       450775.96875     291418.462
# 19       450340.37500     452417.079
# 20       501134.46875     576361.148
# 21       586043.93750     676218.054
# 22       661306.56250     698410.066
# 23       694641.43750     696094.179
# 24       689427.37500     751102.742
# 25       654060.00000     765802.952
# 26       569560.87500     597649.311
# 27       441875.75000     376029.266
# 28       378979.37500     278536.574
# 29       413079.78125     285351.521
# 30       469302.06250     365256.138
# 31       509057.68750     488293.212
# 32       540056.81250     635073.900
# 33       587620.75000     684651.888
# 34       665014.81250     698053.275
# 35       752256.75000     846211.943
# 36       776335.62500     831596.370
# 37       744790.50000     834849.724
# 38       588156.25000     721350.515
# 39       547713.31250     459033.164
# 40       454199.09375     282045.909
# 41       374625.15625     270397.608
# 42       426193.93750     449910.973

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 15ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
