# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Greenland = pd.read_excel(filepath, sheet_name='Greenland-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Greenland)
fp.date_time(Greenland)
# Out:
#           Extent       Date
# 0    1076123.146 1979-01-01
# 1    1099248.063 1979-02-01
# 2    1036964.901 1979-03-01
# 3     958927.937 1979-04-01
# 4     823812.694 1979-05-01
# ..           ...        ...
# 533   721350.515 2023-06-01
# 534   459033.164 2023-07-01
# 535   282045.909 2023-08-01
# 536   270397.608 2023-09-01
# 537   449910.973 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Greenland['Extent'] = scaler.fit_transform(Greenland['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 9
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]  # Adjusted for lead time
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Greenland['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((518, 12, 1), (518,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Greenland_model_LT9/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.2936 - root_mean_squared_error: 0.5418
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# 53/53 [==============================] - 6s 72ms/step - loss: 0.2889 - root_mean_squared_error: 0.5375 - val_loss: 0.1393 - val_root_mean_squared_error: 0.3732
# Epoch 2/50
# 43/53 [=======================>......] - ETA: 0s - loss: 0.2361 - root_mean_squared_error: 0.4859
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# 53/53 [==============================] - 3s 53ms/step - loss: 0.2306 - root_mean_squared_error: 0.4802 - val_loss: 0.1149 - val_root_mean_squared_error: 0.3390
# Epoch 3/50
# 42/53 [======================>.......] - ETA: 0s - loss: 0.1919 - root_mean_squared_error: 0.4380
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# 53/53 [==============================] - 3s 59ms/step - loss: 0.1909 - root_mean_squared_error: 0.4369 - val_loss: 0.0880 - val_root_mean_squared_error: 0.2967
# Epoch 4/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.1568 - root_mean_squared_error: 0.3960
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# 53/53 [==============================] - 3s 59ms/step - loss: 0.1536 - root_mean_squared_error: 0.3919 - val_loss: 0.0690 - val_root_mean_squared_error: 0.2628
# Epoch 5/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1241 - root_mean_squared_error: 0.3523
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# 53/53 [==============================] - 3s 52ms/step - loss: 0.1222 - root_mean_squared_error: 0.3495 - val_loss: 0.0525 - val_root_mean_squared_error: 0.2291
# Epoch 6/50
# 41/53 [======================>.......] - ETA: 0s - loss: 0.0929 - root_mean_squared_error: 0.3047
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0949 - root_mean_squared_error: 0.3080 - val_loss: 0.0399 - val_root_mean_squared_error: 0.1996
# Epoch 7/50
# 40/53 [=====================>........] - ETA: 0s - loss: 0.0776 - root_mean_squared_error: 0.2786
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# 53/53 [==============================] - 3s 67ms/step - loss: 0.0740 - root_mean_squared_error: 0.2720 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1694
# Epoch 8/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0567 - root_mean_squared_error: 0.2381
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0558 - root_mean_squared_error: 0.2362 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1557
# Epoch 9/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0439 - root_mean_squared_error: 0.2094
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0422 - root_mean_squared_error: 0.2055 - val_loss: 0.0191 - val_root_mean_squared_error: 0.1382
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0317 - root_mean_squared_error: 0.1781
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0319 - root_mean_squared_error: 0.1786 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1190
# Epoch 11/50
# 40/53 [=====================>........] - ETA: 0s - loss: 0.0276 - root_mean_squared_error: 0.1661
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0248 - root_mean_squared_error: 0.1576 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1115
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0188 - root_mean_squared_error: 0.1372
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0187 - root_mean_squared_error: 0.1369 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1075
# Epoch 13/50
# 42/53 [======================>.......] - ETA: 0s - loss: 0.0149 - root_mean_squared_error: 0.1219
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0159 - root_mean_squared_error: 0.1259 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1011
# Epoch 14/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0165 - root_mean_squared_error: 0.1285
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0156 - root_mean_squared_error: 0.1247 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0968
# Epoch 15/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1501
# Epoch 16/50
# 41/53 [======================>.......] - ETA: 0s - loss: 0.0128 - root_mean_squared_error: 0.1132
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0130 - root_mean_squared_error: 0.1139 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0934
# Epoch 17/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0153 - root_mean_squared_error: 0.1236 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1010
# Epoch 18/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0132 - root_mean_squared_error: 0.1148
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT9\assets
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0133 - root_mean_squared_error: 0.1155 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0913
# Epoch 19/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0120 - root_mean_squared_error: 0.1096 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1015
# Epoch 20/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1456
# Epoch 21/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0126 - root_mean_squared_error: 0.1122 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1027
# Epoch 22/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0115 - root_mean_squared_error: 0.1074 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1261
# Epoch 23/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0104 - root_mean_squared_error: 0.1021 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1074
# Epoch 24/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0113 - root_mean_squared_error: 0.1062 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0960
# Epoch 25/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0117 - root_mean_squared_error: 0.1084 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1313
# Epoch 26/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0119 - root_mean_squared_error: 0.1091 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1284
# Epoch 27/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0121 - root_mean_squared_error: 0.1100 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1014
# Epoch 28/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1021
# Epoch 29/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0120 - root_mean_squared_error: 0.1097 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 30/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0115 - root_mean_squared_error: 0.1073 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1066
# Epoch 31/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0121 - root_mean_squared_error: 0.1098 - val_loss: 0.0199 - val_root_mean_squared_error: 0.1412
# Epoch 32/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0105 - root_mean_squared_error: 0.1027 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1408
# Epoch 33/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0111 - root_mean_squared_error: 0.1052 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0977
# Epoch 34/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0129 - root_mean_squared_error: 0.1134 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1696
# Epoch 35/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0106 - root_mean_squared_error: 0.1031 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1538
# Epoch 36/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1065
# Epoch 37/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0098 - root_mean_squared_error: 0.0990 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1144
# Epoch 38/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0984
# Epoch 39/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0124 - root_mean_squared_error: 0.1115 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1259
# Epoch 40/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0113 - root_mean_squared_error: 0.1062 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1284
# Epoch 41/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0119 - root_mean_squared_error: 0.1091 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1084
# Epoch 42/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0108 - root_mean_squared_error: 0.1038 - val_loss: 0.0231 - val_root_mean_squared_error: 0.1519
# Epoch 43/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0115 - root_mean_squared_error: 0.1072 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1232
# Epoch 44/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0125 - root_mean_squared_error: 0.1118 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1361
# Epoch 45/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0111 - root_mean_squared_error: 0.1056 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0950
# Epoch 46/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1034
# Epoch 47/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0125 - root_mean_squared_error: 0.1120 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1148
# Epoch 48/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0129 - root_mean_squared_error: 0.1137 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1021
# Epoch 49/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1040
# Epoch 50/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0111 - root_mean_squared_error: 0.1053 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1408

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.0309351642926534 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Greenland_model_LT9/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 7ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.10326901470805676
# MAE : 0.0860918663063836

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       620350.437500     584830.109
# 1       641078.750000     641562.292
# 2       647067.875000     734946.437
# 3       620117.250000     777596.225
# 4       597889.125000     687087.673
# 5       585765.937500     622337.816
# 6       405877.406250     467232.074
# 7       285189.875000     297495.641
# 8       276826.375000     268909.854
# 9       353949.750000     408072.791
# 10      445430.906250     552314.148
# 11      509287.875000     651062.408
# 12      592926.062500     695022.674
# 13      636175.437500     670974.305
# 14      659689.062500     710035.543
# 15      645138.375000     699672.538
# 16      602374.187500     730897.021
# 17      581560.625000     588598.988
# 18      398735.656250     281754.041
# 19      280520.750000     117830.266
# 20      304309.500000      81838.250
# 21      355847.062500     291418.462
# 22      466698.562500     452417.079
# 23      554310.687500     576361.148
# 24      609649.312500     676218.054
# 25      666532.437500     698410.066
# 26      659986.687500     696094.179
# 27      600809.937500     751102.742
# 28      595868.312500     765802.952
# 29      517767.156250     597649.311
# 30      291980.843750     376029.266
# 31      161871.546875     278536.574
# 32      204139.437500     285351.521
# 33      276592.312500     365256.138
# 34      388191.062500     488293.212
# 35      494058.750000     635073.900
# 36      582375.000000     684651.888
# 37      651341.125000     698053.275
# 38      674650.750000     846211.943
# 39      625837.000000     831596.370
# 40      638196.250000     834849.724
# 41      572852.187500     721350.515
# 42      338780.281250     459033.164
# 43      278977.250000     282045.909
# 44      250081.734375     270397.608
# 45      310288.062500     449910.973

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 2ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
