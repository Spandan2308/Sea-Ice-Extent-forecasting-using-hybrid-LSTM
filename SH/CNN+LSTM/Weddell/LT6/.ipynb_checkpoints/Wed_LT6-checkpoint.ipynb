# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Weddell_Extent = pd.read_excel(filepath, sheet_name='Weddell-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Weddell_Extent)
fp.date_time(Weddell_Extent)
# Out:
#           Extent       Date
# 0    2136510.859 1979-01-01
# 1    1243495.891 1979-02-01
# 2    1699053.449 1979-03-01
# 3    2617442.085 1979-04-01
# 4    3852934.206 1979-05-01
# ..           ...        ...
# 533  3668127.143 2023-06-01
# 534  4805519.784 2023-07-01
# 535  5524445.234 2023-08-01
# 536  6006669.861 2023-09-01
# 537  5507961.583 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Weddell_Extent['Extent'] = scaler.fit_transform(Weddell_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 6
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Weddell_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((521, 12, 1), (521,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Weddell_model_LT6/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.2828 - root_mean_squared_error: 0.5318
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 8s 103ms/step - loss: 0.2792 - root_mean_squared_error: 0.5284 - val_loss: 0.2940 - val_root_mean_squared_error: 0.5422
# Epoch 2/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.2148 - root_mean_squared_error: 0.4635
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 4s 71ms/step - loss: 0.2166 - root_mean_squared_error: 0.4654 - val_loss: 0.2503 - val_root_mean_squared_error: 0.5003
# Epoch 3/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1770 - root_mean_squared_error: 0.4207
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 4s 72ms/step - loss: 0.1783 - root_mean_squared_error: 0.4223 - val_loss: 0.2113 - val_root_mean_squared_error: 0.4597
# Epoch 4/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.1478 - root_mean_squared_error: 0.3844
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.1471 - root_mean_squared_error: 0.3835 - val_loss: 0.1811 - val_root_mean_squared_error: 0.4256
# Epoch 5/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.1185 - root_mean_squared_error: 0.3442
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 5s 88ms/step - loss: 0.1162 - root_mean_squared_error: 0.3409 - val_loss: 0.1543 - val_root_mean_squared_error: 0.3928
# Epoch 6/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0890 - root_mean_squared_error: 0.2983
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0896 - root_mean_squared_error: 0.2993 - val_loss: 0.1273 - val_root_mean_squared_error: 0.3568
# Epoch 7/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0780 - root_mean_squared_error: 0.2793
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0747 - root_mean_squared_error: 0.2733 - val_loss: 0.1028 - val_root_mean_squared_error: 0.3206
# Epoch 8/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0609 - root_mean_squared_error: 0.2467
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0586 - root_mean_squared_error: 0.2421 - val_loss: 0.0844 - val_root_mean_squared_error: 0.2905
# Epoch 9/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0441 - root_mean_squared_error: 0.2099
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0436 - root_mean_squared_error: 0.2089 - val_loss: 0.0634 - val_root_mean_squared_error: 0.2517
# Epoch 10/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0312 - root_mean_squared_error: 0.1766
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0321 - root_mean_squared_error: 0.1792 - val_loss: 0.0429 - val_root_mean_squared_error: 0.2072
# Epoch 11/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0257 - root_mean_squared_error: 0.1602
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0261 - root_mean_squared_error: 0.1616 - val_loss: 0.0276 - val_root_mean_squared_error: 0.1661
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0205 - root_mean_squared_error: 0.1433
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0204 - root_mean_squared_error: 0.1429 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1508
# Epoch 13/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0167 - root_mean_squared_error: 0.1292
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1155
# Epoch 14/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0151 - root_mean_squared_error: 0.1229
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0148 - root_mean_squared_error: 0.1218 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0834
# Epoch 15/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0168 - root_mean_squared_error: 0.1297 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0844
# Epoch 16/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0135 - root_mean_squared_error: 0.1162
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0744
# Epoch 17/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0136 - root_mean_squared_error: 0.1166
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 6s 105ms/step - loss: 0.0134 - root_mean_squared_error: 0.1156 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0712
# Epoch 18/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0152 - root_mean_squared_error: 0.1231 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0843
# Epoch 19/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0159 - root_mean_squared_error: 0.1262 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0731
# Epoch 20/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0113 - root_mean_squared_error: 0.1064
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 5s 105ms/step - loss: 0.0111 - root_mean_squared_error: 0.1053 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0675
# Epoch 21/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0123 - root_mean_squared_error: 0.1110 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0724
# Epoch 22/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0168 - root_mean_squared_error: 0.1295 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0951
# Epoch 23/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0161 - root_mean_squared_error: 0.1268
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 5s 102ms/step - loss: 0.0157 - root_mean_squared_error: 0.1253 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0673
# Epoch 24/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0155 - root_mean_squared_error: 0.1246 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0847
# Epoch 25/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0115 - root_mean_squared_error: 0.1074
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 5s 104ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0623
# Epoch 26/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0152 - root_mean_squared_error: 0.1233 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0692
# Epoch 27/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0747
# Epoch 28/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0122 - root_mean_squared_error: 0.1104 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0780
# Epoch 29/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0102 - root_mean_squared_error: 0.1008
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT6\assets
# 53/53 [==============================] - 5s 102ms/step - loss: 0.0104 - root_mean_squared_error: 0.1021 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0607
# Epoch 30/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0812
# Epoch 31/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0128 - root_mean_squared_error: 0.1132 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0927
# Epoch 32/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0124 - root_mean_squared_error: 0.1112 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0780
# Epoch 33/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0176 - root_mean_squared_error: 0.1325 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0736
# Epoch 34/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0147 - root_mean_squared_error: 0.1212 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0736
# Epoch 35/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0902
# Epoch 36/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0143 - root_mean_squared_error: 0.1196 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0731
# Epoch 37/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0135 - root_mean_squared_error: 0.1160 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0771
# Epoch 38/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0116 - root_mean_squared_error: 0.1078 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0930
# Epoch 39/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0125 - root_mean_squared_error: 0.1116 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0776
# Epoch 40/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0643
# Epoch 41/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0121 - root_mean_squared_error: 0.1098 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0832
# Epoch 42/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0131 - root_mean_squared_error: 0.1143 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0815
# Epoch 43/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0108 - root_mean_squared_error: 0.1039 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0652
# Epoch 44/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0681
# Epoch 45/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0135 - root_mean_squared_error: 0.1162 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0771
# Epoch 46/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0104 - root_mean_squared_error: 0.1019 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0735
# Epoch 47/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0921
# Epoch 48/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0149 - root_mean_squared_error: 0.1222 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0723
# Epoch 49/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0160 - root_mean_squared_error: 0.1263 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0688
# Epoch 50/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0152 - root_mean_squared_error: 0.1233 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0793

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.8403539299964904 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Weddell_model_LT6/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 16ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.07330819129164462
# MAE : 0.062257279046796295

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        6.115709e+06    6516136.854
# 1        5.735784e+06    5902163.675
# 2        4.172092e+06    3498103.449
# 3        1.946906e+06    1633675.726
# 4        5.504641e+05    1292668.399
# 5        8.823004e+05    1527666.815
# 6        1.989858e+06    2121949.701
# 7        3.266659e+06    3562381.775
# 8        4.623572e+06    5004305.983
# 9        5.420462e+06    6176613.878
# 10       5.929608e+06    6794233.093
# 11       6.266488e+06    7024136.637
# 12       6.204811e+06    6554271.388
# 13       5.494310e+06    6172281.701
# 14       3.743924e+06    4175225.799
# 15       1.494406e+06    1748380.899
# 16       7.433772e+05    1256191.080
# 17       9.237251e+05    1347295.364
# 18       2.256504e+06    2180184.677
# 19       3.483155e+06    3419295.982
# 20       4.845648e+06    4786146.771
# 21       5.726524e+06    5968132.718
# 22       6.330722e+06    6556934.174
# 23       6.556022e+06    6614949.980
# 24       6.506222e+06    6035207.368
# 25       5.696788e+06    5274244.730
# 26       4.164116e+06    3505146.372
# 27       1.809790e+06    1478130.228
# 28       9.929644e+05    1096780.503
# 29       1.057435e+06    1387234.069
# 30       2.359340e+06    2128693.591
# 31       3.586878e+06    3313318.704
# 32       4.874149e+06    4218076.656
# 33       5.665174e+06    5257641.941
# 34       6.149370e+06    5956603.340
# 35       6.486432e+06    6256062.049
# 36       6.239865e+06    5974548.305
# 37       5.616054e+06    5569396.731
# 38       4.038634e+06    3684108.410
# 39       2.240716e+06    1451614.707
# 40       1.465090e+06    1089888.684
# 41       1.338935e+06    1255222.909
# 42       2.520112e+06    1704492.279
# 43       3.409730e+06    2563551.804
# 44       4.815236e+06    3668127.143
# 45       5.420594e+06    4805519.784
# 46       6.115644e+06    5524445.234
# 47       6.274062e+06    6006669.861
# 48       6.346076e+06    5507961.583

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
