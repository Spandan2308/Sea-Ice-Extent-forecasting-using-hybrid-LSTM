# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Greenland = pd.read_excel(filepath, sheet_name='Greenland-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Greenland)
fp.date_time(Greenland)
# Out:
#           Extent       Date
# 0    1076123.146 1979-01-01
# 1    1099248.063 1979-02-01
# 2    1036964.901 1979-03-01
# 3     958927.937 1979-04-01
# 4     823812.694 1979-05-01
# ..           ...        ...
# 533   721350.515 2023-06-01
# 534   459033.164 2023-07-01
# 535   282045.909 2023-08-01
# 536   270397.608 2023-09-01
# 537   449910.973 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Greenland['Extent'] = scaler.fit_transform(Greenland['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 12
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Greenland['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((515, 12, 1), (515,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Greenland_LT12/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2214 - root_mean_squared_error: 0.4705INFO:tensorflow:Assets written to: Greenland_LT12\assets
# 53/53 [==============================] - 48s 624ms/step - loss: 0.2214 - root_mean_squared_error: 0.4705 - val_loss: 0.0552 - val_root_mean_squared_error: 0.2350
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0505 - root_mean_squared_error: 0.2248INFO:tensorflow:Assets written to: Greenland_LT12\assets
# 53/53 [==============================] - 31s 592ms/step - loss: 0.0508 - root_mean_squared_error: 0.2254 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1699
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0408 - root_mean_squared_error: 0.2019INFO:tensorflow:Assets written to: Greenland_LT12\assets
# 53/53 [==============================] - 30s 581ms/step - loss: 0.0408 - root_mean_squared_error: 0.2019 - val_loss: 0.0284 - val_root_mean_squared_error: 0.1685
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0375 - root_mean_squared_error: 0.1936INFO:tensorflow:Assets written to: Greenland_LT12\assets
# 53/53 [==============================] - 30s 575ms/step - loss: 0.0375 - root_mean_squared_error: 0.1936 - val_loss: 0.0278 - val_root_mean_squared_error: 0.1667
# Epoch 5/50
# 53/53 [==============================] - 2s 47ms/step - loss: 0.0345 - root_mean_squared_error: 0.1857 - val_loss: 0.0278 - val_root_mean_squared_error: 0.1669
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0308 - root_mean_squared_error: 0.1756INFO:tensorflow:Assets written to: Greenland_LT12\assets
# 53/53 [==============================] - 32s 609ms/step - loss: 0.0308 - root_mean_squared_error: 0.1756 - val_loss: 0.0228 - val_root_mean_squared_error: 0.1510
# Epoch 7/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0269 - root_mean_squared_error: 0.1641 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1557
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0223 - root_mean_squared_error: 0.1495INFO:tensorflow:Assets written to: Greenland_LT12\assets
# 53/53 [==============================] - 31s 597ms/step - loss: 0.0226 - root_mean_squared_error: 0.1505 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1443
# Epoch 9/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0190 - root_mean_squared_error: 0.1377 - val_loss: 0.0324 - val_root_mean_squared_error: 0.1801
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0174 - root_mean_squared_error: 0.1321INFO:tensorflow:Assets written to: Greenland_LT12\assets
# 53/53 [==============================] - 32s 608ms/step - loss: 0.0174 - root_mean_squared_error: 0.1321 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1343
# Epoch 11/50
# 53/53 [==============================] - 3s 49ms/step - loss: 0.0149 - root_mean_squared_error: 0.1219 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1565
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0153 - root_mean_squared_error: 0.1236INFO:tensorflow:Assets written to: Greenland_LT12\assets
# 53/53 [==============================] - 33s 628ms/step - loss: 0.0153 - root_mean_squared_error: 0.1236 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1215
# Epoch 13/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0148 - root_mean_squared_error: 0.1218 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1309
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0149 - root_mean_squared_error: 0.1221INFO:tensorflow:Assets written to: Greenland_LT12\assets
# 53/53 [==============================] - 34s 646ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 15/50
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0146 - root_mean_squared_error: 0.1208 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1325
# Epoch 16/50
# 53/53 [==============================] - 6s 109ms/step - loss: 0.0127 - root_mean_squared_error: 0.1125 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1096
# Epoch 17/50
# 53/53 [==============================] - 5s 86ms/step - loss: 0.0140 - root_mean_squared_error: 0.1183 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1541
# Epoch 18/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0146 - root_mean_squared_error: 0.1206 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1432
# Epoch 19/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0137 - root_mean_squared_error: 0.1170 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1376
# Epoch 20/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0138 - root_mean_squared_error: 0.1176 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1290
# Epoch 21/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0137 - root_mean_squared_error: 0.1172 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1104
# Epoch 22/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0132 - root_mean_squared_error: 0.1151 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1531
# Epoch 23/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0138 - root_mean_squared_error: 0.1175 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1406
# Epoch 24/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0136 - root_mean_squared_error: 0.1166 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1460
# Epoch 25/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0130 - root_mean_squared_error: 0.1139 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1392
# Epoch 26/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0127 - root_mean_squared_error: 0.1126 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1109
# Epoch 27/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0126 - root_mean_squared_error: 0.1125 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1417
# Epoch 28/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.0125 - root_mean_squared_error: 0.1118 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1338
# Epoch 29/50
# 53/53 [==============================] - 6s 109ms/step - loss: 0.0127 - root_mean_squared_error: 0.1126 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1235
# Epoch 30/50
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0125 - root_mean_squared_error: 0.1120 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1197
# Epoch 31/50
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1101
# Epoch 32/50
# 53/53 [==============================] - 6s 108ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1295
# Epoch 33/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0119 - root_mean_squared_error: 0.1090 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1387
# Epoch 34/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0117 - root_mean_squared_error: 0.1080 - val_loss: 0.0300 - val_root_mean_squared_error: 0.1733
# Epoch 35/50
# 53/53 [==============================] - 4s 75ms/step - loss: 0.0127 - root_mean_squared_error: 0.1127 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1130
# Epoch 36/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0124 - root_mean_squared_error: 0.1115 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1100
# Epoch 37/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0117 - root_mean_squared_error: 0.1080INFO:tensorflow:Assets written to: Greenland_LT12\assets
# 53/53 [==============================] - 37s 713ms/step - loss: 0.0117 - root_mean_squared_error: 0.1080 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0997
# Epoch 38/50
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0122 - root_mean_squared_error: 0.1105 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1152
# Epoch 39/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0127 - root_mean_squared_error: 0.1128INFO:tensorflow:Assets written to: Greenland_LT12\assets
# 53/53 [==============================] - 49s 937ms/step - loss: 0.0127 - root_mean_squared_error: 0.1128 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0956
# Epoch 40/50
# 53/53 [==============================] - 2s 46ms/step - loss: 0.0106 - root_mean_squared_error: 0.1027 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1159
# Epoch 41/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0111 - root_mean_squared_error: 0.1053 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1037
# Epoch 42/50
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0113 - root_mean_squared_error: 0.1063 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1075
# Epoch 43/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0110 - root_mean_squared_error: 0.1050 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1529
# Epoch 44/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0129 - root_mean_squared_error: 0.1138 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1147
# Epoch 45/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0115 - root_mean_squared_error: 0.1074 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1167
# Epoch 46/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0106 - root_mean_squared_error: 0.1029 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 47/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0102 - root_mean_squared_error: 0.1008 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1219
# Epoch 48/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0109 - root_mean_squared_error: 0.1044INFO:tensorflow:Assets written to: Greenland_LT12\assets
# 53/53 [==============================] - 22s 426ms/step - loss: 0.0109 - root_mean_squared_error: 0.1044 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0955
# Epoch 49/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0116 - root_mean_squared_error: 0.1079INFO:tensorflow:Assets written to: Greenland_LT12\assets
# 53/53 [==============================] - 23s 434ms/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0945
# Epoch 50/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0112 - root_mean_squared_error: 0.1056 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1266

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 9.479392635822297 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Greenland_LT12/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 24ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.07419355808481021
# MAE : 0.05405694585266728

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        679770.12500     777596.225
# 1        645140.62500     687087.673
# 2        574288.12500     622337.816
# 3        462458.53125     467232.074
# 4        331904.03125     297495.641
# 5        283523.43750     268909.854
# 6        375304.25000     408072.791
# 7        505645.65625     552314.148
# 8        583643.12500     651062.408
# 9        622744.25000     695022.674
# 10       656489.12500     670974.305
# 11       706352.87500     710035.543
# 12       740484.50000     699672.538
# 13       698305.93750     730897.021
# 14       603295.81250     588598.988
# 15       456481.03125     281754.041
# 16       328976.56250     117830.266
# 17       285481.93750      81838.250
# 18       380020.53125     291418.462
# 19       501592.31250     452417.079
# 20       612793.87500     576361.148
# 21       687679.00000     676218.054
# 22       708690.00000     698410.066
# 23       708758.62500     696094.179
# 24       699710.12500     751102.742
# 25       671893.81250     765802.952
# 26       587695.43750     597649.311
# 27       399542.18750     376029.266
# 28       300912.62500     278536.574
# 29       282737.75000     285351.521
# 30       327667.56250     365256.138
# 31       453757.09375     488293.212
# 32       556541.18750     635073.900
# 33       648535.25000     684651.888
# 34       708169.87500     698053.275
# 35       722694.68750     846211.943
# 36       726401.00000     831596.370
# 37       713046.25000     834849.724
# 38       592416.37500     721350.515
# 39       454232.09375     459033.164
# 40       319167.06250     282045.909
# 41       282052.65625     270397.608
# 42       358203.31250     449910.973

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 29ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
