# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Weddell_Extent = pd.read_excel(filepath, sheet_name='Weddell-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Weddell_Extent)
fp.date_time(Weddell_Extent)
# Out:
#           Extent       Date
# 0    2136510.859 1979-01-01
# 1    1243495.891 1979-02-01
# 2    1699053.449 1979-03-01
# 3    2617442.085 1979-04-01
# 4    3852934.206 1979-05-01
# ..           ...        ...
# 533  3668127.143 2023-06-01
# 534  4805519.784 2023-07-01
# 535  5524445.234 2023-08-01
# 536  6006669.861 2023-09-01
# 537  5507961.583 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Weddell_Extent['Extent'] = scaler.fit_transform(Weddell_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 7
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Weddell_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((520, 12, 1), (520,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Weddell_model_LT7/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2806 - root_mean_squared_error: 0.5297INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 25s 326ms/step - loss: 0.2806 - root_mean_squared_error: 0.5297 - val_loss: 0.1882 - val_root_mean_squared_error: 0.4338
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0995 - root_mean_squared_error: 0.3154INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 16s 305ms/step - loss: 0.0994 - root_mean_squared_error: 0.3154 - val_loss: 0.0795 - val_root_mean_squared_error: 0.2819
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0750 - root_mean_squared_error: 0.2739INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 16s 309ms/step - loss: 0.0750 - root_mean_squared_error: 0.2739 - val_loss: 0.0729 - val_root_mean_squared_error: 0.2700
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0668 - root_mean_squared_error: 0.2584INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 17s 325ms/step - loss: 0.0669 - root_mean_squared_error: 0.2586 - val_loss: 0.0644 - val_root_mean_squared_error: 0.2538
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0575 - root_mean_squared_error: 0.2398INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 18s 341ms/step - loss: 0.0575 - root_mean_squared_error: 0.2398 - val_loss: 0.0521 - val_root_mean_squared_error: 0.2282
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0420 - root_mean_squared_error: 0.2049INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 18s 354ms/step - loss: 0.0420 - root_mean_squared_error: 0.2049 - val_loss: 0.0320 - val_root_mean_squared_error: 0.1788
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0230 - root_mean_squared_error: 0.1518INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 17s 323ms/step - loss: 0.0230 - root_mean_squared_error: 0.1518 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1118
# Epoch 8/50
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0157 - root_mean_squared_error: 0.1251 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1214
# Epoch 9/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0126 - root_mean_squared_error: 0.1123INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 17s 326ms/step - loss: 0.0126 - root_mean_squared_error: 0.1123 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1039
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0116 - root_mean_squared_error: 0.1077INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 19s 356ms/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0793
# Epoch 11/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0966
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0097 - root_mean_squared_error: 0.0986INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 18s 345ms/step - loss: 0.0097 - root_mean_squared_error: 0.0986 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0778
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0087 - root_mean_squared_error: 0.0932INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 17s 319ms/step - loss: 0.0087 - root_mean_squared_error: 0.0932 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0747
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0076 - root_mean_squared_error: 0.0873INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 18s 351ms/step - loss: 0.0076 - root_mean_squared_error: 0.0873 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0638
# Epoch 15/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0073 - root_mean_squared_error: 0.0855 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0772
# Epoch 16/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0073 - root_mean_squared_error: 0.0854 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0694
# Epoch 17/50
# 53/53 [==============================] - 2s 43ms/step - loss: 0.0078 - root_mean_squared_error: 0.0883 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0717
# Epoch 18/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0066 - root_mean_squared_error: 0.0812 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0641
# Epoch 19/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0066 - root_mean_squared_error: 0.0810INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 17s 333ms/step - loss: 0.0065 - root_mean_squared_error: 0.0807 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0623
# Epoch 20/50
# 53/53 [==============================] - 2s 46ms/step - loss: 0.0062 - root_mean_squared_error: 0.0787 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0625
# Epoch 21/50
# 53/53 [==============================] - 2s 46ms/step - loss: 0.0065 - root_mean_squared_error: 0.0806 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0653
# Epoch 22/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0062 - root_mean_squared_error: 0.0785 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0716
# Epoch 23/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0058 - root_mean_squared_error: 0.0760INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 24s 461ms/step - loss: 0.0058 - root_mean_squared_error: 0.0760 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0621
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0060 - root_mean_squared_error: 0.0773INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 19s 355ms/step - loss: 0.0060 - root_mean_squared_error: 0.0773 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0608
# Epoch 25/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0060 - root_mean_squared_error: 0.0774 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0663
# Epoch 26/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0065 - root_mean_squared_error: 0.0803 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0661
# Epoch 27/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.0058 - root_mean_squared_error: 0.0764 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0824
# Epoch 28/50
# 53/53 [==============================] - 2s 47ms/step - loss: 0.0067 - root_mean_squared_error: 0.0818 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0624
# Epoch 29/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0057 - root_mean_squared_error: 0.0755INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 19s 374ms/step - loss: 0.0058 - root_mean_squared_error: 0.0758 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606
# Epoch 30/50
# 53/53 [==============================] - 2s 43ms/step - loss: 0.0054 - root_mean_squared_error: 0.0736 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0632
# Epoch 31/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0055 - root_mean_squared_error: 0.0741INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 19s 358ms/step - loss: 0.0055 - root_mean_squared_error: 0.0744 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0602
# Epoch 32/50
# 53/53 [==============================] - 2s 40ms/step - loss: 0.0054 - root_mean_squared_error: 0.0733 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0628
# Epoch 33/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0054 - root_mean_squared_error: 0.0738INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 17s 329ms/step - loss: 0.0054 - root_mean_squared_error: 0.0738 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0589
# Epoch 34/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0052 - root_mean_squared_error: 0.0723INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 18s 346ms/step - loss: 0.0052 - root_mean_squared_error: 0.0724 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0589
# Epoch 35/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0051 - root_mean_squared_error: 0.0716 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609
# Epoch 36/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0056 - root_mean_squared_error: 0.0747 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0599
# Epoch 37/50
# 53/53 [==============================] - 3s 49ms/step - loss: 0.0051 - root_mean_squared_error: 0.0717 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0640
# Epoch 38/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0045 - root_mean_squared_error: 0.0669 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0603
# Epoch 39/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0049 - root_mean_squared_error: 0.0702 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0616
# Epoch 40/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0047 - root_mean_squared_error: 0.0684 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613
# Epoch 41/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0047 - root_mean_squared_error: 0.0683 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0621
# Epoch 42/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0048 - root_mean_squared_error: 0.0696INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 19s 363ms/step - loss: 0.0048 - root_mean_squared_error: 0.0694 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0589
# Epoch 43/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0047 - root_mean_squared_error: 0.0686INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 20s 385ms/step - loss: 0.0047 - root_mean_squared_error: 0.0686 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0586
# Epoch 44/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0046 - root_mean_squared_error: 0.0677INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 20s 391ms/step - loss: 0.0046 - root_mean_squared_error: 0.0677 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0578
# Epoch 45/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.0045 - root_mean_squared_error: 0.0672 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0597
# Epoch 46/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0050 - root_mean_squared_error: 0.0707INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 20s 381ms/step - loss: 0.0050 - root_mean_squared_error: 0.0706 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0571
# Epoch 47/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0045 - root_mean_squared_error: 0.0673 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0636
# Epoch 48/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0048 - root_mean_squared_error: 0.0691 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0596
# Epoch 49/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.0049 - root_mean_squared_error: 0.0698 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0618
# Epoch 50/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0046 - root_mean_squared_error: 0.0679INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 21s 394ms/step - loss: 0.0046 - root_mean_squared_error: 0.0679 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0567

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 8.790644586086273 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Weddell_model_LT7/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 22ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.05738913529575102
# MAE : 0.04862595613050843

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        5.545902e+06    5902163.675
# 1        4.287920e+06    3498103.449
# 2        1.908400e+06    1633675.726
# 3        8.648968e+05    1292668.399
# 4        1.144295e+06    1527666.815
# 5        2.114238e+06    2121949.701
# 6        3.420187e+06    3562381.775
# 7        4.665734e+06    5004305.983
# 8        5.623298e+06    6176613.878
# 9        6.196720e+06    6794233.093
# 10       6.461324e+06    7024136.637
# 11       6.341915e+06    6554271.388
# 12       5.683735e+06    6172281.701
# 13       3.945060e+06    4175225.799
# 14       1.505850e+06    1748380.899
# 15       8.039523e+05    1256191.080
# 16       1.162340e+06    1347295.364
# 17       2.244076e+06    2180184.677
# 18       3.644790e+06    3419295.982
# 19       4.954668e+06    4786146.771
# 20       5.846838e+06    5968132.718
# 21       6.428689e+06    6556934.174
# 22       6.680281e+06    6614949.980
# 23       6.532726e+06    6035207.368
# 24       5.804280e+06    5274244.730
# 25       4.193806e+06    3505146.372
# 26       1.737588e+06    1478130.228
# 27       7.923838e+05    1096780.503
# 28       1.022599e+06    1387234.069
# 29       1.990802e+06    2128693.591
# 30       3.337928e+06    3313318.704
# 31       4.684254e+06    4218076.656
# 32       5.668522e+06    5257641.941
# 33       6.187076e+06    5956603.340
# 34       6.370497e+06    6256062.049
# 35       6.194990e+06    5974548.305
# 36       5.468331e+06    5569396.731
# 37       3.863062e+06    3684108.410
# 38       1.708996e+06    1451614.707
# 39       8.630973e+05    1089888.684
# 40       1.126251e+06    1255222.909
# 41       2.127155e+06    1704492.279
# 42       3.363367e+06    2563551.804
# 43       4.497888e+06    3668127.143
# 44       5.377396e+06    4805519.784
# 45       5.933360e+06    5524445.234
# 46       6.187304e+06    6006669.861
# 47       6.084902e+06    5507961.583

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 27ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
