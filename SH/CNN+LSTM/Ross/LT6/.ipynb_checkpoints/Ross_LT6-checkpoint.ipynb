# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Ross_Extent = pd.read_excel(filepath, sheet_name='Ross-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Ross_Extent)
fp.date_time(Ross_Extent)
# Out:
#           Extent       Date
# 0    1040455.516 1979-01-01
# 1     239334.118 1979-02-01
# 2     557365.154 1979-03-01
# 3    2054855.924 1979-04-01
# 4    2973925.625 1979-05-01
# ..           ...        ...
# 533  3137598.938 2023-06-01
# 534  3201783.453 2023-07-01
# 535  2973294.266 2023-08-01
# 536  3354839.711 2023-09-01
# 537  3325613.245 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Ross_Extent['Extent'] = scaler.fit_transform(Ross_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 6
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Ross_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((521, 12, 1), (521,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Ross_model_LT6/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.3732 - root_mean_squared_error: 0.6109
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 7s 82ms/step - loss: 0.3786 - root_mean_squared_error: 0.6153 - val_loss: 0.3243 - val_root_mean_squared_error: 0.5695
# Epoch 2/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.3171 - root_mean_squared_error: 0.5632
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.3215 - root_mean_squared_error: 0.5670 - val_loss: 0.2906 - val_root_mean_squared_error: 0.5390
# Epoch 3/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.2884 - root_mean_squared_error: 0.5370
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 4s 77ms/step - loss: 0.2804 - root_mean_squared_error: 0.5295 - val_loss: 0.2604 - val_root_mean_squared_error: 0.5103
# Epoch 4/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.2400 - root_mean_squared_error: 0.4899
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 4s 73ms/step - loss: 0.2395 - root_mean_squared_error: 0.4894 - val_loss: 0.2274 - val_root_mean_squared_error: 0.4769
# Epoch 5/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2041 - root_mean_squared_error: 0.4518
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 3s 63ms/step - loss: 0.2030 - root_mean_squared_error: 0.4506 - val_loss: 0.2075 - val_root_mean_squared_error: 0.4555
# Epoch 6/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1689 - root_mean_squared_error: 0.4110
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 3s 63ms/step - loss: 0.1707 - root_mean_squared_error: 0.4132 - val_loss: 0.1819 - val_root_mean_squared_error: 0.4265
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1393 - root_mean_squared_error: 0.3733
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 4s 73ms/step - loss: 0.1393 - root_mean_squared_error: 0.3733 - val_loss: 0.1489 - val_root_mean_squared_error: 0.3859
# Epoch 8/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.1120 - root_mean_squared_error: 0.3346
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 3s 67ms/step - loss: 0.1092 - root_mean_squared_error: 0.3305 - val_loss: 0.1447 - val_root_mean_squared_error: 0.3804
# Epoch 9/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0843 - root_mean_squared_error: 0.2904
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0849 - root_mean_squared_error: 0.2914 - val_loss: 0.0884 - val_root_mean_squared_error: 0.2973
# Epoch 10/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0678 - root_mean_squared_error: 0.2604 - val_loss: 0.0940 - val_root_mean_squared_error: 0.3065
# Epoch 11/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0512 - root_mean_squared_error: 0.2263
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0511 - root_mean_squared_error: 0.2260 - val_loss: 0.0787 - val_root_mean_squared_error: 0.2806
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0385 - root_mean_squared_error: 0.1961
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0385 - root_mean_squared_error: 0.1961 - val_loss: 0.0600 - val_root_mean_squared_error: 0.2450
# Epoch 13/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0317 - root_mean_squared_error: 0.1781
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0305 - root_mean_squared_error: 0.1746 - val_loss: 0.0320 - val_root_mean_squared_error: 0.1789
# Epoch 14/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0250 - root_mean_squared_error: 0.1581
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0262 - root_mean_squared_error: 0.1619 - val_loss: 0.0314 - val_root_mean_squared_error: 0.1773
# Epoch 15/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0194 - root_mean_squared_error: 0.1394
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0183 - root_mean_squared_error: 0.1352 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1558
# Epoch 16/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0178 - root_mean_squared_error: 0.1336
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 3s 67ms/step - loss: 0.0174 - root_mean_squared_error: 0.1321 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1016
# Epoch 17/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0174 - root_mean_squared_error: 0.1319
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0171 - root_mean_squared_error: 0.1309 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1006
# Epoch 18/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0164 - root_mean_squared_error: 0.1282
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0171 - root_mean_squared_error: 0.1307 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0911
# Epoch 19/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0113 - root_mean_squared_error: 0.1063 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1029
# Epoch 20/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0134 - root_mean_squared_error: 0.1159 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0960
# Epoch 21/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0109 - root_mean_squared_error: 0.1043
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0113 - root_mean_squared_error: 0.1065 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0879
# Epoch 22/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0119 - root_mean_squared_error: 0.1089 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1573
# Epoch 23/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0965
# Epoch 24/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0113 - root_mean_squared_error: 0.1061 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1003
# Epoch 25/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0093 - root_mean_squared_error: 0.0964
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0094 - root_mean_squared_error: 0.0971 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0867
# Epoch 26/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0148 - root_mean_squared_error: 0.1218 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1210
# Epoch 27/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0121 - root_mean_squared_error: 0.1102 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1280
# Epoch 28/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0118 - root_mean_squared_error: 0.1084 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1140
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0125 - root_mean_squared_error: 0.1116 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1098
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0096 - root_mean_squared_error: 0.0978 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0899
# Epoch 31/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0111 - root_mean_squared_error: 0.1054 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0880
# Epoch 32/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0086 - root_mean_squared_error: 0.0926 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0875
# Epoch 33/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0121 - root_mean_squared_error: 0.1098 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1476
# Epoch 34/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0128 - root_mean_squared_error: 0.1133
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0125 - root_mean_squared_error: 0.1118 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0854
# Epoch 35/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0115 - root_mean_squared_error: 0.1074 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1016
# Epoch 36/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0138 - root_mean_squared_error: 0.1176
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# INFO:tensorflow:Assets written to: Ross_model_LT6\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0138 - root_mean_squared_error: 0.1175 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0829
# Epoch 37/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0152 - root_mean_squared_error: 0.1234 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0907
# Epoch 38/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0131 - root_mean_squared_error: 0.1147 - val_loss: 0.0195 - val_root_mean_squared_error: 0.1396
# Epoch 39/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0107 - root_mean_squared_error: 0.1037 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0916
# Epoch 40/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0117 - root_mean_squared_error: 0.1080 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1059
# Epoch 41/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0118 - root_mean_squared_error: 0.1084 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1090
# Epoch 42/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0113 - root_mean_squared_error: 0.1062 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1584
# Epoch 43/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0984
# Epoch 44/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1515
# Epoch 45/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0132 - root_mean_squared_error: 0.1151 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1003
# Epoch 46/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0109 - root_mean_squared_error: 0.1043 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0871
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0102 - root_mean_squared_error: 0.1009 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1389
# Epoch 48/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0111 - root_mean_squared_error: 0.1054 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1149
# Epoch 49/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0108 - root_mean_squared_error: 0.1039 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0881
# Epoch 50/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0123 - root_mean_squared_error: 0.1110 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0841

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.4533349633216859 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Ross_model_LT6/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 6ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.08276684629841946
# MAE : 0.06365524198644645

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        3.838997e+06    3909211.179
# 1        3.287626e+06    3499167.351
# 2        2.253152e+06    2715890.297
# 3        9.375712e+05    1053272.694
# 4        4.926903e+05     368862.123
# 5        9.746812e+05     979418.298
# 6        1.809935e+06    2086269.569
# 7        2.731256e+06    2852731.016
# 8        3.289316e+06    3452823.613
# 9        3.279480e+06    3846843.974
# 10       3.650369e+06    4005222.451
# 11       3.697188e+06    4129684.505
# 12       3.921309e+06    4130311.577
# 13       3.269537e+06    3987590.376
# 14       2.259658e+06    2531664.630
# 15       1.035460e+06     864796.598
# 16       5.723339e+05     366098.623
# 17       1.002556e+06    1324063.884
# 18       1.870365e+06    2094086.684
# 19       2.709070e+06    2706708.526
# 20       3.291436e+06    3380172.167
# 21       3.562394e+06    3975727.475
# 22       3.780821e+06    4016497.161
# 23       4.025787e+06    4134594.766
# 24       3.951694e+06    4278165.933
# 25       3.476820e+06    3893945.909
# 26       2.293135e+06    2389171.083
# 27       1.043856e+06     896425.932
# 28       4.394317e+05     251374.224
# 29       7.347553e+05     455056.048
# 30       1.934671e+06    1780625.872
# 31       2.746853e+06    2914989.101
# 32       3.465255e+06    3561620.245
# 33       3.614295e+06    3991717.506
# 34       3.793924e+06    4559070.778
# 35       4.032570e+06    4596327.081
# 36       3.923350e+06    4565650.139
# 37       3.577072e+06    4061902.846
# 38       2.321774e+06    2336900.967
# 39       9.193905e+05     696917.659
# 40       3.257885e+05     213657.789
# 41       7.396762e+05     765773.883
# 42       1.806379e+06    1951730.202
# 43       2.648719e+06    2610971.814
# 44       3.330046e+06    3137598.938
# 45       3.636455e+06    3201783.453
# 46       3.959758e+06    2973294.266
# 47       4.208578e+06    3354839.711
# 48       4.344990e+06    3325613.245

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
