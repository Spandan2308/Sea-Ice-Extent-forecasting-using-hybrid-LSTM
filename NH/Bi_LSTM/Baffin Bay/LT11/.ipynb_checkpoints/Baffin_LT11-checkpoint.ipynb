# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Baffin = pd.read_excel(filepath, sheet_name='Baffin-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Baffin)
fp.date_time(Baffin)
# Out:
#           Extent       Date
# 0    1090625.815 1979-01-01
# 1    1157634.866 1979-02-01
# 2    1299583.477 1979-03-01
# 3    1137194.680 1979-04-01
# 4     983083.453 1979-05-01
# ..           ...        ...
# 533   781460.891 2023-06-01
# 534   331845.048 2023-07-01
# 535    99334.625 2023-08-01
# 536    49359.723 2023-09-01
# 537    85693.282 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Baffin['Extent'] = scaler.fit_transform(Baffin['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 11
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Baffin['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((516, 12, 1), (516,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Baffin_model_LT11/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2002 - root_mean_squared_error: 0.4474INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 36s 464ms/step - loss: 0.2002 - root_mean_squared_error: 0.4474 - val_loss: 0.1046 - val_root_mean_squared_error: 0.3235
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0769 - root_mean_squared_error: 0.2773INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 22s 429ms/step - loss: 0.0769 - root_mean_squared_error: 0.2773 - val_loss: 0.0575 - val_root_mean_squared_error: 0.2398
# Epoch 3/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0540 - root_mean_squared_error: 0.2323INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 22s 417ms/step - loss: 0.0538 - root_mean_squared_error: 0.2319 - val_loss: 0.0363 - val_root_mean_squared_error: 0.1906
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0294 - root_mean_squared_error: 0.1716INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 22s 418ms/step - loss: 0.0293 - root_mean_squared_error: 0.1711 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1301
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0188 - root_mean_squared_error: 0.1372INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 23s 437ms/step - loss: 0.0188 - root_mean_squared_error: 0.1371 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0986
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0156 - root_mean_squared_error: 0.1249INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 23s 432ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0862
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0112 - root_mean_squared_error: 0.1058INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 23s 449ms/step - loss: 0.0112 - root_mean_squared_error: 0.1058 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0849
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0106 - root_mean_squared_error: 0.1027INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 28s 547ms/step - loss: 0.0106 - root_mean_squared_error: 0.1027 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0841
# Epoch 9/50
# 53/53 [==============================] - 2s 38ms/step - loss: 0.0088 - root_mean_squared_error: 0.0940 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0087 - root_mean_squared_error: 0.0933INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 26s 503ms/step - loss: 0.0087 - root_mean_squared_error: 0.0930 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0640
# Epoch 11/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0079 - root_mean_squared_error: 0.0891 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0707
# Epoch 12/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0073 - root_mean_squared_error: 0.0854 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0678
# Epoch 13/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0071 - root_mean_squared_error: 0.0845 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0685
# Epoch 14/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0075 - root_mean_squared_error: 0.0864 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0755
# Epoch 15/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0071 - root_mean_squared_error: 0.0841 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1020
# Epoch 16/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0067 - root_mean_squared_error: 0.0820 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1106
# Epoch 17/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0071 - root_mean_squared_error: 0.0840 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0705
# Epoch 18/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0067 - root_mean_squared_error: 0.0820 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0797
# Epoch 19/50
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0065 - root_mean_squared_error: 0.0807 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0822
# Epoch 20/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0068 - root_mean_squared_error: 0.0824 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0880
# Epoch 21/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0063 - root_mean_squared_error: 0.0791 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0814
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0061 - root_mean_squared_error: 0.0782INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 36s 682ms/step - loss: 0.0061 - root_mean_squared_error: 0.0782 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613
# Epoch 23/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0061 - root_mean_squared_error: 0.0779 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0781
# Epoch 24/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0062 - root_mean_squared_error: 0.0785 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0740
# Epoch 25/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0058 - root_mean_squared_error: 0.0762 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0641
# Epoch 26/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0061 - root_mean_squared_error: 0.0780 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0735
# Epoch 27/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0058 - root_mean_squared_error: 0.0763 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0844
# Epoch 28/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0056 - root_mean_squared_error: 0.0751 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0909
# Epoch 29/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0055 - root_mean_squared_error: 0.0741 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0794
# Epoch 30/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.0061 - root_mean_squared_error: 0.0782 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0695
# Epoch 31/50
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0053 - root_mean_squared_error: 0.0727 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0728
# Epoch 32/50
# 53/53 [==============================] - 3s 47ms/step - loss: 0.0053 - root_mean_squared_error: 0.0727 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0744
# Epoch 33/50
# 53/53 [==============================] - 3s 47ms/step - loss: 0.0060 - root_mean_squared_error: 0.0778 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0745
# Epoch 34/50
# 53/53 [==============================] - 2s 46ms/step - loss: 0.0055 - root_mean_squared_error: 0.0740 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0719
# Epoch 35/50
# 53/53 [==============================] - 2s 47ms/step - loss: 0.0052 - root_mean_squared_error: 0.0723 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0759
# Epoch 36/50
# 53/53 [==============================] - 2s 47ms/step - loss: 0.0055 - root_mean_squared_error: 0.0742 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0764
# Epoch 37/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0053 - root_mean_squared_error: 0.0726 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0759
# Epoch 38/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0054 - root_mean_squared_error: 0.0735 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0643
# Epoch 39/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0054 - root_mean_squared_error: 0.0736 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0708
# Epoch 40/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0054 - root_mean_squared_error: 0.0735 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0885
# Epoch 41/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0056 - root_mean_squared_error: 0.0746 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0820
# Epoch 42/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0053 - root_mean_squared_error: 0.0725 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0749
# Epoch 43/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0055 - root_mean_squared_error: 0.0741 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0700
# Epoch 44/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0053 - root_mean_squared_error: 0.0726 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0646
# Epoch 45/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0052 - root_mean_squared_error: 0.0722 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0616
# Epoch 46/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0050 - root_mean_squared_error: 0.0711 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0697
# Epoch 47/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0052 - root_mean_squared_error: 0.0724 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0793
# Epoch 48/50
# 53/53 [==============================] - 3s 49ms/step - loss: 0.0053 - root_mean_squared_error: 0.0727 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0621
# Epoch 49/50
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0050 - root_mean_squared_error: 0.0710 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0784
# Epoch 50/50
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0051 - root_mean_squared_error: 0.0717 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0627

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 6.292603341738383 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Baffin_model_LT11/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 20ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.06164223151571282
# MAE : 0.048414376122938

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.190035e+06    1236299.254
# 1        1.088707e+06    1036981.003
# 2        8.662743e+05     847489.150
# 3        5.514259e+05     619129.338
# 4        2.527528e+05     195688.491
# 5        4.898035e+04      36670.811
# 6       -3.036526e+04      31777.310
# 7       -1.888454e+04      82762.022
# 8        2.795302e+05     400043.823
# 9        7.825899e+05     733089.555
# 10       1.035416e+06     917362.266
# 11       1.197450e+06    1040584.040
# 12       1.210044e+06    1147997.675
# 13       1.100982e+06    1074255.327
# 14       9.137326e+05     875527.315
# 15       6.164358e+05     629820.756
# 16       3.209024e+05     204308.900
# 17       9.792854e+04      45059.062
# 18      -1.096439e+04      33770.277
# 19       1.692349e+04      64135.631
# 20       3.994737e+05     400581.715
# 21       7.859601e+05     698631.451
# 22       9.701691e+05     973313.225
# 23       1.107200e+06    1335339.087
# 24       1.148088e+06    1429096.704
# 25       1.071197e+06    1206542.314
# 26       9.043681e+05    1079292.433
# 27       6.142744e+05     788101.638
# 28       3.195487e+05     397326.270
# 29       9.578583e+04      97802.348
# 30      -1.250502e+04      62212.219
# 31       2.163474e+04     154051.600
# 32       3.732297e+05     610663.893
# 33       7.956144e+05     756679.164
# 34       1.086109e+06     962270.215
# 35       1.297958e+06    1235154.518
# 36       1.349028e+06    1161744.519
# 37       1.267536e+06    1136918.669
# 38       1.065957e+06     995852.026
# 39       7.712290e+05     781460.891
# 40       4.283658e+05     331845.048
# 41       1.543119e+05      99334.625
# 42       1.009175e+04      49359.723
# 43       1.000718e+05      85693.282

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 21ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
