# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Kara = pd.read_excel(filepath, sheet_name='Kara-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Kara)
fp.date_time(Kara)
# Out:
#          Extent       Date
# 0    917992.880 1979-01-01
# 1    917992.880 1979-02-01
# 2    917992.880 1979-03-01
# 3    917992.880 1979-04-01
# 4    917992.880 1979-05-01
# ..          ...        ...
# 533  728642.743 2023-06-01
# 534  437024.646 2023-07-01
# 535  202260.789 2023-08-01
# 536   98103.856 2023-09-01
# 537  260413.272 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Kara['Extent'] = scaler.fit_transform(Kara['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 5
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Kara['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((522, 12, 1), (522,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Kara_model_LT5/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.5880 - root_mean_squared_error: 0.7668INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 18s 215ms/step - loss: 0.5880 - root_mean_squared_error: 0.7668 - val_loss: 0.3412 - val_root_mean_squared_error: 0.5841
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.2003 - root_mean_squared_error: 0.4475INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 11s 206ms/step - loss: 0.1997 - root_mean_squared_error: 0.4469 - val_loss: 0.1164 - val_root_mean_squared_error: 0.3412
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0774 - root_mean_squared_error: 0.2782INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0771 - root_mean_squared_error: 0.2777 - val_loss: 0.1129 - val_root_mean_squared_error: 0.3360
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0718 - root_mean_squared_error: 0.2679INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 11s 203ms/step - loss: 0.0718 - root_mean_squared_error: 0.2679 - val_loss: 0.1109 - val_root_mean_squared_error: 0.3331
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0747 - root_mean_squared_error: 0.2733INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 10s 199ms/step - loss: 0.0747 - root_mean_squared_error: 0.2733 - val_loss: 0.1091 - val_root_mean_squared_error: 0.3304
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0726 - root_mean_squared_error: 0.2694INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 10s 197ms/step - loss: 0.0723 - root_mean_squared_error: 0.2688 - val_loss: 0.1072 - val_root_mean_squared_error: 0.3275
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0695 - root_mean_squared_error: 0.2637INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 11s 206ms/step - loss: 0.0695 - root_mean_squared_error: 0.2637 - val_loss: 0.1038 - val_root_mean_squared_error: 0.3222
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0676 - root_mean_squared_error: 0.2600INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 10s 199ms/step - loss: 0.0674 - root_mean_squared_error: 0.2595 - val_loss: 0.1002 - val_root_mean_squared_error: 0.3165
# Epoch 9/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0637 - root_mean_squared_error: 0.2523INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 9s 174ms/step - loss: 0.0636 - root_mean_squared_error: 0.2522 - val_loss: 0.0962 - val_root_mean_squared_error: 0.3102
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0622 - root_mean_squared_error: 0.2494INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 10s 201ms/step - loss: 0.0618 - root_mean_squared_error: 0.2487 - val_loss: 0.0923 - val_root_mean_squared_error: 0.3037
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0556 - root_mean_squared_error: 0.2358INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 10s 198ms/step - loss: 0.0554 - root_mean_squared_error: 0.2354 - val_loss: 0.0855 - val_root_mean_squared_error: 0.2924
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0520 - root_mean_squared_error: 0.2281INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 10s 197ms/step - loss: 0.0517 - root_mean_squared_error: 0.2274 - val_loss: 0.0791 - val_root_mean_squared_error: 0.2813
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0493 - root_mean_squared_error: 0.2220INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 11s 205ms/step - loss: 0.0493 - root_mean_squared_error: 0.2220 - val_loss: 0.0735 - val_root_mean_squared_error: 0.2711
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0442 - root_mean_squared_error: 0.2103INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0442 - root_mean_squared_error: 0.2103 - val_loss: 0.0638 - val_root_mean_squared_error: 0.2525
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0386 - root_mean_squared_error: 0.1965INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 11s 203ms/step - loss: 0.0386 - root_mean_squared_error: 0.1965 - val_loss: 0.0574 - val_root_mean_squared_error: 0.2396
# Epoch 16/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0379 - root_mean_squared_error: 0.1948INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 10s 195ms/step - loss: 0.0378 - root_mean_squared_error: 0.1944 - val_loss: 0.0520 - val_root_mean_squared_error: 0.2281
# Epoch 17/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0335 - root_mean_squared_error: 0.1831INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 11s 209ms/step - loss: 0.0336 - root_mean_squared_error: 0.1834 - val_loss: 0.0472 - val_root_mean_squared_error: 0.2173
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0351 - root_mean_squared_error: 0.1873INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 11s 213ms/step - loss: 0.0351 - root_mean_squared_error: 0.1873 - val_loss: 0.0459 - val_root_mean_squared_error: 0.2142
# Epoch 19/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0327 - root_mean_squared_error: 0.1810INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 10s 200ms/step - loss: 0.0327 - root_mean_squared_error: 0.1808 - val_loss: 0.0443 - val_root_mean_squared_error: 0.2106
# Epoch 20/50
# 53/53 [==============================] - 2s 28ms/step - loss: 0.0300 - root_mean_squared_error: 0.1731 - val_loss: 0.0451 - val_root_mean_squared_error: 0.2124
# Epoch 21/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0294 - root_mean_squared_error: 0.1716INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 11s 208ms/step - loss: 0.0294 - root_mean_squared_error: 0.1716 - val_loss: 0.0416 - val_root_mean_squared_error: 0.2039
# Epoch 22/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0299 - root_mean_squared_error: 0.1730INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 11s 203ms/step - loss: 0.0303 - root_mean_squared_error: 0.1740 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2015
# Epoch 23/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0291 - root_mean_squared_error: 0.1705INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 10s 194ms/step - loss: 0.0291 - root_mean_squared_error: 0.1705 - val_loss: 0.0386 - val_root_mean_squared_error: 0.1964
# Epoch 24/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0275 - root_mean_squared_error: 0.1660 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2011
# Epoch 25/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0281 - root_mean_squared_error: 0.1678 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2030
# Epoch 26/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0266 - root_mean_squared_error: 0.1632 - val_loss: 0.0401 - val_root_mean_squared_error: 0.2003
# Epoch 27/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0248 - root_mean_squared_error: 0.1574 - val_loss: 0.0398 - val_root_mean_squared_error: 0.1995
# Epoch 28/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0282 - root_mean_squared_error: 0.1679INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 10s 196ms/step - loss: 0.0284 - root_mean_squared_error: 0.1685 - val_loss: 0.0369 - val_root_mean_squared_error: 0.1921
# Epoch 29/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0260 - root_mean_squared_error: 0.1614INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 11s 202ms/step - loss: 0.0260 - root_mean_squared_error: 0.1614 - val_loss: 0.0351 - val_root_mean_squared_error: 0.1874
# Epoch 30/50
# 53/53 [==============================] - 2s 38ms/step - loss: 0.0248 - root_mean_squared_error: 0.1576 - val_loss: 0.0389 - val_root_mean_squared_error: 0.1972
# Epoch 31/50
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0250 - root_mean_squared_error: 0.1582 - val_loss: 0.0396 - val_root_mean_squared_error: 0.1990
# Epoch 32/50
# 53/53 [==============================] - 2s 43ms/step - loss: 0.0271 - root_mean_squared_error: 0.1647 - val_loss: 0.0352 - val_root_mean_squared_error: 0.1877
# Epoch 33/50
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0253 - root_mean_squared_error: 0.1591 - val_loss: 0.0356 - val_root_mean_squared_error: 0.1888
# Epoch 34/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0256 - root_mean_squared_error: 0.1601INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 13s 242ms/step - loss: 0.0256 - root_mean_squared_error: 0.1601 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1837
# Epoch 35/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0250 - root_mean_squared_error: 0.1583 - val_loss: 0.0351 - val_root_mean_squared_error: 0.1872
# Epoch 36/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0243 - root_mean_squared_error: 0.1559INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 11s 220ms/step - loss: 0.0243 - root_mean_squared_error: 0.1559 - val_loss: 0.0328 - val_root_mean_squared_error: 0.1811
# Epoch 37/50
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0239 - root_mean_squared_error: 0.1547 - val_loss: 0.0345 - val_root_mean_squared_error: 0.1858
# Epoch 38/50
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0228 - root_mean_squared_error: 0.1509 - val_loss: 0.0359 - val_root_mean_squared_error: 0.1895
# Epoch 39/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0225 - root_mean_squared_error: 0.1500INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 11s 211ms/step - loss: 0.0224 - root_mean_squared_error: 0.1496 - val_loss: 0.0328 - val_root_mean_squared_error: 0.1810
# Epoch 40/50
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0211 - root_mean_squared_error: 0.1452 - val_loss: 0.0331 - val_root_mean_squared_error: 0.1821
# Epoch 41/50
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0228 - root_mean_squared_error: 0.1511 - val_loss: 0.0347 - val_root_mean_squared_error: 0.1863
# Epoch 42/50
# 53/53 [==============================] - 2s 40ms/step - loss: 0.0229 - root_mean_squared_error: 0.1512 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1854
# Epoch 43/50
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0216 - root_mean_squared_error: 0.1470 - val_loss: 0.0330 - val_root_mean_squared_error: 0.1816
# Epoch 44/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0233 - root_mean_squared_error: 0.1528 - val_loss: 0.0333 - val_root_mean_squared_error: 0.1824
# Epoch 45/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0221 - root_mean_squared_error: 0.1485 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1839
# Epoch 46/50
# 53/53 [==============================] - 2s 38ms/step - loss: 0.0213 - root_mean_squared_error: 0.1461 - val_loss: 0.0329 - val_root_mean_squared_error: 0.1812
# Epoch 47/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0216 - root_mean_squared_error: 0.1471INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 12s 221ms/step - loss: 0.0216 - root_mean_squared_error: 0.1471 - val_loss: 0.0301 - val_root_mean_squared_error: 0.1735
# Epoch 48/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0203 - root_mean_squared_error: 0.1426INFO:tensorflow:Assets written to: Kara_model_LT5\assets
# 53/53 [==============================] - 13s 241ms/step - loss: 0.0203 - root_mean_squared_error: 0.1425 - val_loss: 0.0298 - val_root_mean_squared_error: 0.1727
# Epoch 49/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0195 - root_mean_squared_error: 0.1398 - val_loss: 0.0323 - val_root_mean_squared_error: 0.1797
# Epoch 50/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0201 - root_mean_squared_error: 0.1418 - val_loss: 0.0320 - val_root_mean_squared_error: 0.1787

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 5.936914730072021 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Kara_model_LT5/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 18ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.1562479860640704
# MAE : 0.1350182204526019

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       195376.703125      60592.380
# 1       332337.781250     131973.043
# 2       626322.812500     753595.099
# 3       770716.375000     909176.475
# 4       810698.000000     917006.278
# 5       833334.125000     906368.363
# 6       833118.125000     917403.622
# 7       824440.312500     910653.838
# 8       756863.562500     822319.125
# 9       607601.875000     557314.102
# 10      407834.968750     197129.525
# 11      250102.687500      75730.217
# 12      217587.000000      59608.479
# 13      408370.843750      88785.283
# 14      684034.375000     396883.400
# 15      784514.750000     662542.207
# 16      816109.062500     871431.414
# 17      832916.187500     917876.960
# 18      827324.562500     917992.880
# 19      798847.437500     912733.060
# 20      697874.875000     910536.463
# 21      530746.750000     760170.733
# 22      348587.718750     383812.645
# 23      223673.484375     201024.515
# 24      224011.125000     121904.059
# 25      431845.625000     283554.493
# 26      665854.250000     702176.823
# 27      765139.312500     893690.080
# 28      812864.312500     910117.941
# 29      837592.562500     889204.715
# 30      844762.812500     905311.611
# 31      816884.875000     917930.089
# 32      753579.000000     912089.899
# 33      613773.375000     743951.228
# 34      420573.625000     307180.895
# 35      264588.062500     104402.284
# 36      231245.562500      73177.670
# 37      420997.656250     127085.610
# 38      693039.687500     650570.950
# 39      804600.687500     789062.385
# 40      828292.562500     897053.619
# 41      836685.500000     904024.315
# 42      821269.562500     911832.551
# 43      821023.937500     917992.880
# 44      757074.250000     894286.938
# 45      610538.812500     728642.743
# 46      414506.812500     437024.646
# 47      253924.578125     202260.789
# 48      207795.703125      98103.856
# 49      388584.250000     260413.272

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 17ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
