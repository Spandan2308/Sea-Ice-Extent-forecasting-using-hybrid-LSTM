# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Greenland = pd.read_excel(filepath, sheet_name='Greenland-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Greenland)
fp.date_time(Greenland)
# Out:
#           Extent       Date
# 0    1076123.146 1979-01-01
# 1    1099248.063 1979-02-01
# 2    1036964.901 1979-03-01
# 3     958927.937 1979-04-01
# 4     823812.694 1979-05-01
# ..           ...        ...
# 533   721350.515 2023-06-01
# 534   459033.164 2023-07-01
# 535   282045.909 2023-08-01
# 536   270397.608 2023-09-01
# 537   449910.973 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Greenland['Extent'] = scaler.fit_transform(Greenland['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 8
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Greenland['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((519, 12, 1), (519,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Greenland_LT8/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2635 - root_mean_squared_error: 0.5133INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 36s 462ms/step - loss: 0.2635 - root_mean_squared_error: 0.5133 - val_loss: 0.0799 - val_root_mean_squared_error: 0.2826
# Epoch 2/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0667 - root_mean_squared_error: 0.2582INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 23s 433ms/step - loss: 0.0658 - root_mean_squared_error: 0.2565 - val_loss: 0.0280 - val_root_mean_squared_error: 0.1672
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0359 - root_mean_squared_error: 0.1895INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 22s 429ms/step - loss: 0.0360 - root_mean_squared_error: 0.1896 - val_loss: 0.0275 - val_root_mean_squared_error: 0.1659
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0328 - root_mean_squared_error: 0.1810INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 23s 448ms/step - loss: 0.0328 - root_mean_squared_error: 0.1810 - val_loss: 0.0260 - val_root_mean_squared_error: 0.1613
# Epoch 5/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0302 - root_mean_squared_error: 0.1738INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 23s 449ms/step - loss: 0.0306 - root_mean_squared_error: 0.1750 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1559
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0279 - root_mean_squared_error: 0.1671INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 23s 450ms/step - loss: 0.0279 - root_mean_squared_error: 0.1671 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1514
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0261 - root_mean_squared_error: 0.1617INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 23s 443ms/step - loss: 0.0264 - root_mean_squared_error: 0.1625 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1459
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0241 - root_mean_squared_error: 0.1552INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 23s 443ms/step - loss: 0.0239 - root_mean_squared_error: 0.1547 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1415
# Epoch 9/50
# 53/53 [==============================] - 2s 41ms/step - loss: 0.0213 - root_mean_squared_error: 0.1460 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1458
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0201 - root_mean_squared_error: 0.1418INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 26s 495ms/step - loss: 0.0201 - root_mean_squared_error: 0.1418 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1344
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0191 - root_mean_squared_error: 0.1382INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 24s 452ms/step - loss: 0.0191 - root_mean_squared_error: 0.1381 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1304
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0181 - root_mean_squared_error: 0.1345INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 23s 442ms/step - loss: 0.0180 - root_mean_squared_error: 0.1343 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1290
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0164 - root_mean_squared_error: 0.1281INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 26s 497ms/step - loss: 0.0164 - root_mean_squared_error: 0.1279 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1250
# Epoch 14/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0165 - root_mean_squared_error: 0.1285INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 23s 448ms/step - loss: 0.0164 - root_mean_squared_error: 0.1279 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1246
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0156 - root_mean_squared_error: 0.1249INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 37s 712ms/step - loss: 0.0156 - root_mean_squared_error: 0.1249 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1215
# Epoch 16/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0151 - root_mean_squared_error: 0.1229INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 29s 558ms/step - loss: 0.0150 - root_mean_squared_error: 0.1225 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1214
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0143 - root_mean_squared_error: 0.1198INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 26s 494ms/step - loss: 0.0143 - root_mean_squared_error: 0.1198 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1183
# Epoch 18/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.0143 - root_mean_squared_error: 0.1194 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1214
# Epoch 19/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0131 - root_mean_squared_error: 0.1146 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1189
# Epoch 20/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0127 - root_mean_squared_error: 0.1127 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1297
# Epoch 21/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0135 - root_mean_squared_error: 0.1162 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1254
# Epoch 22/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1274
# Epoch 23/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0124 - root_mean_squared_error: 0.1113INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 23s 432ms/step - loss: 0.0124 - root_mean_squared_error: 0.1112 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1157
# Epoch 24/50
# 53/53 [==============================] - 2s 42ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1206
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0120 - root_mean_squared_error: 0.1096INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 19s 356ms/step - loss: 0.0120 - root_mean_squared_error: 0.1096 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1102
# Epoch 26/50
# 53/53 [==============================] - 2s 40ms/step - loss: 0.0118 - root_mean_squared_error: 0.1084 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1187
# Epoch 27/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0120 - root_mean_squared_error: 0.1094 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1112
# Epoch 28/50
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0109 - root_mean_squared_error: 0.1045 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1152
# Epoch 29/50
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0116 - root_mean_squared_error: 0.1079 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1216
# Epoch 30/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0109 - root_mean_squared_error: 0.1043 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1151
# Epoch 31/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0112 - root_mean_squared_error: 0.1058 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1116
# Epoch 32/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0113 - root_mean_squared_error: 0.1061 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1169
# Epoch 33/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0106 - root_mean_squared_error: 0.1031INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 17s 321ms/step - loss: 0.0106 - root_mean_squared_error: 0.1031 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1044
# Epoch 34/50
# 53/53 [==============================] - 2s 40ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1293
# Epoch 35/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0107 - root_mean_squared_error: 0.1035 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1171
# Epoch 36/50
# 53/53 [==============================] - 2s 38ms/step - loss: 0.0107 - root_mean_squared_error: 0.1036 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1155
# Epoch 37/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0097 - root_mean_squared_error: 0.0985 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1286
# Epoch 38/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0107 - root_mean_squared_error: 0.1032 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1091
# Epoch 39/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0106 - root_mean_squared_error: 0.1027 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1076
# Epoch 40/50
# 53/53 [==============================] - 2s 43ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1063
# Epoch 41/50
# 53/53 [==============================] - 2s 43ms/step - loss: 0.0103 - root_mean_squared_error: 0.1017 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1185
# Epoch 42/50
# 53/53 [==============================] - 2s 40ms/step - loss: 0.0102 - root_mean_squared_error: 0.1012 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1117
# Epoch 43/50
# 53/53 [==============================] - 2s 41ms/step - loss: 0.0101 - root_mean_squared_error: 0.1003 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1138
# Epoch 44/50
# 53/53 [==============================] - 2s 38ms/step - loss: 0.0101 - root_mean_squared_error: 0.1003 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1173
# Epoch 45/50
# 53/53 [==============================] - 2s 38ms/step - loss: 0.0097 - root_mean_squared_error: 0.0983 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1137
# Epoch 46/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0097 - root_mean_squared_error: 0.0985INFO:tensorflow:Assets written to: Greenland_LT8\assets
# 53/53 [==============================] - 20s 389ms/step - loss: 0.0097 - root_mean_squared_error: 0.0987 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1006
# Epoch 47/50
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0099 - root_mean_squared_error: 0.0997 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1126
# Epoch 48/50
# 53/53 [==============================] - 2s 38ms/step - loss: 0.0098 - root_mean_squared_error: 0.0988 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1124
# Epoch 49/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0096 - root_mean_squared_error: 0.0981 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1172
# Epoch 50/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.0095 - root_mean_squared_error: 0.0973 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1171

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 9.339809477329254 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Greenland_LT8/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 26ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.0907911197088078
# MAE : 0.06884666463604837

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       566873.437500     584596.262
# 1       617544.312500     584830.109
# 2       652500.625000     641562.292
# 3       665315.000000     734946.437
# 4       651364.000000     777596.225
# 5       611162.937500     687087.673
# 6       531505.125000     622337.816
# 7       415433.843750     467232.074
# 8       321909.875000     297495.641
# 9       326076.656250     268909.854
# 10      390868.125000     408072.791
# 11      479596.781250     552314.148
# 12      564234.312500     651062.408
# 13      630095.812500     695022.674
# 14      674425.937500     670974.305
# 15      690846.187500     710035.543
# 16      676221.875000     699672.538
# 17      632957.187500     730897.021
# 18      550039.562500     588598.988
# 19      433751.250000     281754.041
# 20      330055.312500     117830.266
# 21      320948.906250      81838.250
# 22      391558.656250     291418.462
# 23      498980.406250     452417.079
# 24      593841.562500     576361.148
# 25      654978.562500     676218.054
# 26      684887.437500     698410.066
# 27      683194.500000     696094.179
# 28      648813.500000     751102.742
# 29      581353.750000     765802.952
# 30      485125.500000     597649.311
# 31      373757.375000     376029.266
# 32      270327.250000     278536.574
# 33      248110.046875     285351.521
# 34      326903.500000     365256.138
# 35      438595.656250     488293.212
# 36      544011.062500     635073.900
# 37      634596.375000     684651.888
# 38      682881.562500     698053.275
# 39      694835.500000     846211.943
# 40      679163.562500     831596.370
# 41      636532.500000     834849.724
# 42      544466.250000     721350.515
# 43      422079.968750     459033.164
# 44      307332.156250     282045.909
# 45      289918.125000     270397.608
# 46      371036.000000     449910.973

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 26ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
