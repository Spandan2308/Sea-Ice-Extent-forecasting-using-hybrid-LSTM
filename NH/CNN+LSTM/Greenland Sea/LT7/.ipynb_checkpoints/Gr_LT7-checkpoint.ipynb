# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Greenland = pd.read_excel(filepath, sheet_name='Greenland-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Greenland)
fp.date_time(Greenland)
# Out:
#           Extent       Date
# 0    1076123.146 1979-01-01
# 1    1099248.063 1979-02-01
# 2    1036964.901 1979-03-01
# 3     958927.937 1979-04-01
# 4     823812.694 1979-05-01
# ..           ...        ...
# 533   721350.515 2023-06-01
# 534   459033.164 2023-07-01
# 535   282045.909 2023-08-01
# 536   270397.608 2023-09-01
# 537   449910.973 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Greenland['Extent'] = scaler.fit_transform(Greenland['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 7
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]  # Adjusted for lead time
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Greenland['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((520, 12, 1), (520,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Greenland_model_LT7/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 43/53 [=======================>......] - ETA: 0s - loss: 0.3240 - root_mean_squared_error: 0.5692
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# 53/53 [==============================] - 6s 79ms/step - loss: 0.3145 - root_mean_squared_error: 0.5608 - val_loss: 0.1449 - val_root_mean_squared_error: 0.3807
# Epoch 2/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.2531 - root_mean_squared_error: 0.5031
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# 53/53 [==============================] - 3s 55ms/step - loss: 0.2504 - root_mean_squared_error: 0.5004 - val_loss: 0.1169 - val_root_mean_squared_error: 0.3419
# Epoch 3/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.2107 - root_mean_squared_error: 0.4590
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.2125 - root_mean_squared_error: 0.4610 - val_loss: 0.0976 - val_root_mean_squared_error: 0.3124
# Epoch 4/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1803 - root_mean_squared_error: 0.4246
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# 53/53 [==============================] - 3s 62ms/step - loss: 0.1788 - root_mean_squared_error: 0.4228 - val_loss: 0.0809 - val_root_mean_squared_error: 0.2844
# Epoch 5/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.1532 - root_mean_squared_error: 0.3914
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# 53/53 [==============================] - 3s 52ms/step - loss: 0.1506 - root_mean_squared_error: 0.3881 - val_loss: 0.0623 - val_root_mean_squared_error: 0.2496
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1231 - root_mean_squared_error: 0.3509
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# 53/53 [==============================] - 3s 57ms/step - loss: 0.1231 - root_mean_squared_error: 0.3509 - val_loss: 0.0494 - val_root_mean_squared_error: 0.2224
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1018 - root_mean_squared_error: 0.3190
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# 53/53 [==============================] - 3s 64ms/step - loss: 0.1018 - root_mean_squared_error: 0.3190 - val_loss: 0.0396 - val_root_mean_squared_error: 0.1989
# Epoch 8/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0780 - root_mean_squared_error: 0.2793
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0790 - root_mean_squared_error: 0.2811 - val_loss: 0.0315 - val_root_mean_squared_error: 0.1774
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0614 - root_mean_squared_error: 0.2477
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0614 - root_mean_squared_error: 0.2477 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1556
# Epoch 10/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0460 - root_mean_squared_error: 0.2144
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0472 - root_mean_squared_error: 0.2172 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1348
# Epoch 11/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0374 - root_mean_squared_error: 0.1935
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0372 - root_mean_squared_error: 0.1928 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1188
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0290 - root_mean_squared_error: 0.1702
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0290 - root_mean_squared_error: 0.1703 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1124
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0225 - root_mean_squared_error: 0.1501
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0225 - root_mean_squared_error: 0.1501 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1103
# Epoch 14/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0224 - root_mean_squared_error: 0.1498 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1220
# Epoch 15/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0178 - root_mean_squared_error: 0.1334 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1248
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0150 - root_mean_squared_error: 0.1225
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0150 - root_mean_squared_error: 0.1225 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1026
# Epoch 17/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0140 - root_mean_squared_error: 0.1184 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1097
# Epoch 18/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0132 - root_mean_squared_error: 0.1151 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1074
# Epoch 19/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1068
# Epoch 20/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0136 - root_mean_squared_error: 0.1165 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1075
# Epoch 21/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0159 - root_mean_squared_error: 0.1263
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0158 - root_mean_squared_error: 0.1256 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1008
# Epoch 22/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1229
# Epoch 23/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0121 - root_mean_squared_error: 0.1101 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1134
# Epoch 24/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0137 - root_mean_squared_error: 0.1171 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1431
# Epoch 25/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0126 - root_mean_squared_error: 0.1121 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1054
# Epoch 26/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0133 - root_mean_squared_error: 0.1154 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1034
# Epoch 27/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1088
# Epoch 28/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0153 - root_mean_squared_error: 0.1235 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1010
# Epoch 29/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0108 - root_mean_squared_error: 0.1039 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1251
# Epoch 30/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0123 - root_mean_squared_error: 0.1109 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1153
# Epoch 31/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0130 - root_mean_squared_error: 0.1140 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1175
# Epoch 32/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0124 - root_mean_squared_error: 0.1112 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1026
# Epoch 33/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0132 - root_mean_squared_error: 0.1150 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1280
# Epoch 34/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1442
# Epoch 35/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0113 - root_mean_squared_error: 0.1064 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1179
# Epoch 36/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0119 - root_mean_squared_error: 0.1093 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1038
# Epoch 37/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0112 - root_mean_squared_error: 0.1057 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1343
# Epoch 38/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0124 - root_mean_squared_error: 0.1112 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1268
# Epoch 39/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0123 - root_mean_squared_error: 0.1110 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1010
# Epoch 40/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0112 - root_mean_squared_error: 0.1058 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1232
# Epoch 41/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0112 - root_mean_squared_error: 0.1057 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1019
# Epoch 42/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0118 - root_mean_squared_error: 0.1088 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1127
# Epoch 43/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0113 - root_mean_squared_error: 0.1064 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1017
# Epoch 44/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0132 - root_mean_squared_error: 0.1151
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT7\assets
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0132 - root_mean_squared_error: 0.1151 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1006
# Epoch 45/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0117 - root_mean_squared_error: 0.1079 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1332
# Epoch 46/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1173
# Epoch 47/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0108 - root_mean_squared_error: 0.1040 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1359
# Epoch 48/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0108 - root_mean_squared_error: 0.1038 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1257
# Epoch 49/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 50/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0127 - root_mean_squared_error: 0.1126 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1136

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.0396785577138266 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Greenland_model_LT7/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 0s/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.09850706833155486
# MAE : 0.0791105477003496

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       439401.437500     547183.986
# 1       509506.843750     584596.262
# 2       586069.062500     584830.109
# 3       645178.500000     641562.292
# 4       647693.750000     734946.437
# 5       688387.562500     777596.225
# 6       637197.812500     687087.673
# 7       594414.187500     622337.816
# 8       415788.093750     467232.074
# 9       265303.500000     297495.641
# 10      312601.500000     268909.854
# 11      322414.187500     408072.791
# 12      413707.531250     552314.148
# 13      476518.250000     651062.408
# 14      608350.875000     695022.674
# 15      673182.500000     670974.305
# 16      676819.312500     710035.543
# 17      696260.375000     699672.538
# 18      656602.375000     730897.021
# 19      616183.125000     588598.988
# 20      452820.000000     281754.041
# 21      282905.781250     117830.266
# 22      310332.468750      81838.250
# 23      372825.937500     291418.462
# 24      482638.937500     452417.079
# 25      569096.562500     576361.148
# 26      609780.812500     676218.054
# 27      661400.250000     698410.066
# 28      650655.250000     696094.179
# 29      656651.125000     751102.742
# 30      600729.500000     765802.952
# 31      541786.500000     597649.311
# 32      354488.625000     376029.266
# 33      221634.250000     278536.574
# 34      181746.359375     285351.521
# 35      252488.312500     365256.138
# 36      399281.968750     488293.212
# 37      496146.656250     635073.900
# 38      586515.500000     684651.888
# 39      659611.250000     698053.275
# 40      677507.125000     846211.943
# 41      678970.250000     831596.370
# 42      607202.250000     834849.724
# 43      550414.687500     721350.515
# 44      415751.125000     459033.164
# 45      291302.187500     282045.909
# 46      263799.187500     270397.608
# 47      326353.437500     449910.973

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
