# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Kara = pd.read_excel(filepath, sheet_name='Kara-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Kara)
fp.date_time(Kara)
# Out:
#          Extent       Date
# 0    917992.880 1979-01-01
# 1    917992.880 1979-02-01
# 2    917992.880 1979-03-01
# 3    917992.880 1979-04-01
# 4    917992.880 1979-05-01
# ..          ...        ...
# 533  728642.743 2023-06-01
# 534  437024.646 2023-07-01
# 535  202260.789 2023-08-01
# 536   98103.856 2023-09-01
# 537  260413.272 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Kara['Extent'] = scaler.fit_transform(Kara['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 7
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Kara['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((520, 12, 1), (520,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Kara_model_LT7/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.6649 - root_mean_squared_error: 0.8154INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 16s 192ms/step - loss: 0.6650 - root_mean_squared_error: 0.8155 - val_loss: 0.4331 - val_root_mean_squared_error: 0.6581
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.4041 - root_mean_squared_error: 0.6357INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 9s 169ms/step - loss: 0.4014 - root_mean_squared_error: 0.6336 - val_loss: 0.1790 - val_root_mean_squared_error: 0.4231
# Epoch 3/50
# 53/53 [==============================] - 1s 21ms/step - loss: 0.1098 - root_mean_squared_error: 0.3314 - val_loss: 0.1797 - val_root_mean_squared_error: 0.4239
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1031 - root_mean_squared_error: 0.3211INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 9s 173ms/step - loss: 0.1032 - root_mean_squared_error: 0.3212 - val_loss: 0.1673 - val_root_mean_squared_error: 0.4090
# Epoch 5/50
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0990 - root_mean_squared_error: 0.3147 - val_loss: 0.1734 - val_root_mean_squared_error: 0.4165
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0990 - root_mean_squared_error: 0.3146INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 194ms/step - loss: 0.0985 - root_mean_squared_error: 0.3139 - val_loss: 0.1592 - val_root_mean_squared_error: 0.3990
# Epoch 7/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0922 - root_mean_squared_error: 0.3036INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 187ms/step - loss: 0.0928 - root_mean_squared_error: 0.3045 - val_loss: 0.1570 - val_root_mean_squared_error: 0.3962
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0861 - root_mean_squared_error: 0.2935INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 9s 177ms/step - loss: 0.0865 - root_mean_squared_error: 0.2940 - val_loss: 0.1492 - val_root_mean_squared_error: 0.3862
# Epoch 9/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0837 - root_mean_squared_error: 0.2892INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 187ms/step - loss: 0.0826 - root_mean_squared_error: 0.2874 - val_loss: 0.1382 - val_root_mean_squared_error: 0.3717
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0811 - root_mean_squared_error: 0.2848INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 186ms/step - loss: 0.0808 - root_mean_squared_error: 0.2843 - val_loss: 0.1286 - val_root_mean_squared_error: 0.3586
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0744 - root_mean_squared_error: 0.2728INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 9s 182ms/step - loss: 0.0746 - root_mean_squared_error: 0.2730 - val_loss: 0.1169 - val_root_mean_squared_error: 0.3419
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0653 - root_mean_squared_error: 0.2556INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 190ms/step - loss: 0.0653 - root_mean_squared_error: 0.2556 - val_loss: 0.1104 - val_root_mean_squared_error: 0.3323
# Epoch 13/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0621 - root_mean_squared_error: 0.2492INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 184ms/step - loss: 0.0625 - root_mean_squared_error: 0.2501 - val_loss: 0.1014 - val_root_mean_squared_error: 0.3185
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0565 - root_mean_squared_error: 0.2377INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 184ms/step - loss: 0.0565 - root_mean_squared_error: 0.2377 - val_loss: 0.0894 - val_root_mean_squared_error: 0.2990
# Epoch 15/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0531 - root_mean_squared_error: 0.2304INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 9s 169ms/step - loss: 0.0538 - root_mean_squared_error: 0.2320 - val_loss: 0.0847 - val_root_mean_squared_error: 0.2911
# Epoch 16/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0500 - root_mean_squared_error: 0.2237INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 189ms/step - loss: 0.0507 - root_mean_squared_error: 0.2252 - val_loss: 0.0791 - val_root_mean_squared_error: 0.2812
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0513 - root_mean_squared_error: 0.2264INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 9s 181ms/step - loss: 0.0513 - root_mean_squared_error: 0.2264 - val_loss: 0.0749 - val_root_mean_squared_error: 0.2737
# Epoch 18/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0480 - root_mean_squared_error: 0.2192INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 9s 180ms/step - loss: 0.0479 - root_mean_squared_error: 0.2189 - val_loss: 0.0716 - val_root_mean_squared_error: 0.2675
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0464 - root_mean_squared_error: 0.2154INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 189ms/step - loss: 0.0464 - root_mean_squared_error: 0.2154 - val_loss: 0.0682 - val_root_mean_squared_error: 0.2611
# Epoch 20/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0470 - root_mean_squared_error: 0.2168INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 185ms/step - loss: 0.0470 - root_mean_squared_error: 0.2168 - val_loss: 0.0651 - val_root_mean_squared_error: 0.2551
# Epoch 21/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0440 - root_mean_squared_error: 0.2098INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 184ms/step - loss: 0.0440 - root_mean_squared_error: 0.2098 - val_loss: 0.0624 - val_root_mean_squared_error: 0.2498
# Epoch 22/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0450 - root_mean_squared_error: 0.2120INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 188ms/step - loss: 0.0443 - root_mean_squared_error: 0.2104 - val_loss: 0.0589 - val_root_mean_squared_error: 0.2427
# Epoch 23/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0437 - root_mean_squared_error: 0.2092 - val_loss: 0.0589 - val_root_mean_squared_error: 0.2427
# Epoch 24/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0404 - root_mean_squared_error: 0.2011 - val_loss: 0.0609 - val_root_mean_squared_error: 0.2469
# Epoch 25/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0425 - root_mean_squared_error: 0.2062INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 185ms/step - loss: 0.0424 - root_mean_squared_error: 0.2058 - val_loss: 0.0534 - val_root_mean_squared_error: 0.2310
# Epoch 26/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0385 - root_mean_squared_error: 0.1962 - val_loss: 0.0541 - val_root_mean_squared_error: 0.2327
# Epoch 27/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0361 - root_mean_squared_error: 0.1899INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 183ms/step - loss: 0.0359 - root_mean_squared_error: 0.1896 - val_loss: 0.0484 - val_root_mean_squared_error: 0.2200
# Epoch 28/50
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0355 - root_mean_squared_error: 0.1885 - val_loss: 0.0487 - val_root_mean_squared_error: 0.2206
# Epoch 29/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0373 - root_mean_squared_error: 0.1932INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 191ms/step - loss: 0.0371 - root_mean_squared_error: 0.1926 - val_loss: 0.0452 - val_root_mean_squared_error: 0.2127
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0338 - root_mean_squared_error: 0.1838INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 9s 179ms/step - loss: 0.0338 - root_mean_squared_error: 0.1838 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2121
# Epoch 31/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0317 - root_mean_squared_error: 0.1780INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 186ms/step - loss: 0.0317 - root_mean_squared_error: 0.1780 - val_loss: 0.0442 - val_root_mean_squared_error: 0.2101
# Epoch 32/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0343 - root_mean_squared_error: 0.1851INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 9s 182ms/step - loss: 0.0343 - root_mean_squared_error: 0.1851 - val_loss: 0.0420 - val_root_mean_squared_error: 0.2050
# Epoch 33/50
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0321 - root_mean_squared_error: 0.1792 - val_loss: 0.0435 - val_root_mean_squared_error: 0.2085
# Epoch 34/50
# 53/53 [==============================] - 1s 28ms/step - loss: 0.0325 - root_mean_squared_error: 0.1802 - val_loss: 0.0454 - val_root_mean_squared_error: 0.2131
# Epoch 35/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0309 - root_mean_squared_error: 0.1758INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 9s 171ms/step - loss: 0.0309 - root_mean_squared_error: 0.1758 - val_loss: 0.0419 - val_root_mean_squared_error: 0.2048
# Epoch 36/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0315 - root_mean_squared_error: 0.1776INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 9s 180ms/step - loss: 0.0315 - root_mean_squared_error: 0.1776 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2031
# Epoch 37/50
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0295 - root_mean_squared_error: 0.1718 - val_loss: 0.0418 - val_root_mean_squared_error: 0.2044
# Epoch 38/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0282 - root_mean_squared_error: 0.1680INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 189ms/step - loss: 0.0282 - root_mean_squared_error: 0.1680 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2030
# Epoch 39/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0292 - root_mean_squared_error: 0.1708INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 185ms/step - loss: 0.0292 - root_mean_squared_error: 0.1708 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2010
# Epoch 40/50
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0267 - root_mean_squared_error: 0.1633 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2022
# Epoch 41/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0276 - root_mean_squared_error: 0.1662INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 183ms/step - loss: 0.0275 - root_mean_squared_error: 0.1660 - val_loss: 0.0382 - val_root_mean_squared_error: 0.1954
# Epoch 42/50
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0288 - root_mean_squared_error: 0.1696 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2023
# Epoch 43/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0266 - root_mean_squared_error: 0.1630 - val_loss: 0.0383 - val_root_mean_squared_error: 0.1957
# Epoch 44/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0262 - root_mean_squared_error: 0.1618INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 185ms/step - loss: 0.0263 - root_mean_squared_error: 0.1623 - val_loss: 0.0352 - val_root_mean_squared_error: 0.1877
# Epoch 45/50
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0266 - root_mean_squared_error: 0.1630 - val_loss: 0.0377 - val_root_mean_squared_error: 0.1942
# Epoch 46/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0251 - root_mean_squared_error: 0.1586INFO:tensorflow:Assets written to: Kara_model_LT7\assets
# 53/53 [==============================] - 10s 190ms/step - loss: 0.0254 - root_mean_squared_error: 0.1593 - val_loss: 0.0340 - val_root_mean_squared_error: 0.1844
# Epoch 47/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0279 - root_mean_squared_error: 0.1670 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2020
# Epoch 48/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0254 - root_mean_squared_error: 0.1593 - val_loss: 0.0362 - val_root_mean_squared_error: 0.1904
# Epoch 49/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0228 - root_mean_squared_error: 0.1511 - val_loss: 0.0361 - val_root_mean_squared_error: 0.1900
# Epoch 50/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0244 - root_mean_squared_error: 0.1561 - val_loss: 0.0368 - val_root_mean_squared_error: 0.1919

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 5.7374006072680155 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Kara_model_LT7/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 12ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.16126012935378178
# MAE : 0.13462022886274388

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       513018.750000     753595.099
# 1       710714.750000     909176.475
# 2       836995.125000     917006.278
# 3       869903.375000     906368.363
# 4       860723.750000     917403.622
# 5       807208.812500     910653.838
# 6       719281.500000     822319.125
# 7       592991.500000     557314.102
# 8       441911.468750     197129.525
# 9       307512.031250      75730.217
# 10      234871.937500      59608.479
# 11      342804.000000      88785.283
# 12      577274.937500     396883.400
# 13      764186.312500     662542.207
# 14      853172.437500     871431.414
# 15      864077.937500     917876.960
# 16      831162.812500     917992.880
# 17      760012.812500     912733.060
# 18      665061.187500     910536.463
# 19      531445.250000     760170.733
# 20      384299.593750     383812.645
# 21      285974.843750     201024.515
# 22      235209.578125     121904.059
# 23      331954.031250     283554.493
# 24      576083.750000     702176.823
# 25      738816.750000     893690.080
# 26      818683.687500     910117.941
# 27      855691.187500     889204.715
# 28      853601.000000     905311.611
# 29      805366.437500     917930.089
# 30      715738.312500     912089.899
# 31      597388.812500     743951.228
# 32      457898.250000     307180.895
# 33      328087.937500     104402.284
# 34      262578.156250      73177.670
# 35      387647.062500     127085.610
# 36      648406.312500     650570.950
# 37      810007.500000     789062.385
# 38      872630.312500     897053.619
# 39      892862.062500     904024.315
# 40      874110.250000     911832.551
# 41      818273.812500     917992.880
# 42      730637.812500     894286.938
# 43      602715.937500     728642.743
# 44      445643.468750     437024.646
# 45      313683.468750     202260.789
# 46      240453.468750      98103.856
# 47      320165.093750     260413.272

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 14ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
