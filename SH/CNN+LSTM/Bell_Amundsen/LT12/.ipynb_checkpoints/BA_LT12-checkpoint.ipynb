# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bell_Amundsen_Extent = pd.read_excel(filepath, sheet_name='Bell-Amundsen-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Bell_Amundsen_Extent)
fp.date_time(Bell_Amundsen_Extent)
# Out:
#           Extent       Date
# 0    1179855.894 1979-01-01
# 1     879585.254 1979-02-01
# 2     791619.096 1979-03-01
# 3    1254912.071 1979-04-01
# 4    1620142.247 1979-05-01
# ..           ...        ...
# 533  1556568.455 2023-06-01
# 534  1917507.979 2023-07-01
# 535  2601630.327 2023-08-01
# 536  2534223.780 2023-09-01
# 537  2373004.525 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bell_Amundsen_Extent['Extent'] = scaler.fit_transform(Bell_Amundsen_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 12
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bell_Amundsen_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((515, 12, 1), (515,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Bell_Amund_model_LT12/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.2625 - root_mean_squared_error: 0.5123
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 8s 97ms/step - loss: 0.2617 - root_mean_squared_error: 0.5116 - val_loss: 0.2255 - val_root_mean_squared_error: 0.4749
# Epoch 2/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.2045 - root_mean_squared_error: 0.4522
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 5s 87ms/step - loss: 0.2003 - root_mean_squared_error: 0.4475 - val_loss: 0.1925 - val_root_mean_squared_error: 0.4387
# Epoch 3/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.1655 - root_mean_squared_error: 0.4069
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.1643 - root_mean_squared_error: 0.4053 - val_loss: 0.1662 - val_root_mean_squared_error: 0.4076
# Epoch 4/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.1335 - root_mean_squared_error: 0.3654
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.1375 - root_mean_squared_error: 0.3707 - val_loss: 0.1379 - val_root_mean_squared_error: 0.3714
# Epoch 5/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.1134 - root_mean_squared_error: 0.3368
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.1136 - root_mean_squared_error: 0.3371 - val_loss: 0.1139 - val_root_mean_squared_error: 0.3374
# Epoch 6/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0892 - root_mean_squared_error: 0.2986
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0912 - root_mean_squared_error: 0.3020 - val_loss: 0.0922 - val_root_mean_squared_error: 0.3037
# Epoch 7/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0765 - root_mean_squared_error: 0.2766
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.0748 - root_mean_squared_error: 0.2736 - val_loss: 0.0736 - val_root_mean_squared_error: 0.2713
# Epoch 8/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0632 - root_mean_squared_error: 0.2515
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.0602 - root_mean_squared_error: 0.2453 - val_loss: 0.0583 - val_root_mean_squared_error: 0.2415
# Epoch 9/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0457 - root_mean_squared_error: 0.2137
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0460 - root_mean_squared_error: 0.2144 - val_loss: 0.0488 - val_root_mean_squared_error: 0.2209
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0371 - root_mean_squared_error: 0.1926
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0371 - root_mean_squared_error: 0.1927 - val_loss: 0.0356 - val_root_mean_squared_error: 0.1887
# Epoch 11/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0303 - root_mean_squared_error: 0.1740
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0283 - root_mean_squared_error: 0.1682 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1538
# Epoch 12/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0236 - root_mean_squared_error: 0.1538
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0237 - root_mean_squared_error: 0.1540 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1526
# Epoch 13/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0206 - root_mean_squared_error: 0.1434
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0199 - root_mean_squared_error: 0.1410 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1122
# Epoch 14/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0159 - root_mean_squared_error: 0.1262
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 4s 81ms/step - loss: 0.0161 - root_mean_squared_error: 0.1267 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1054
# Epoch 15/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0171 - root_mean_squared_error: 0.1307 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1254
# Epoch 16/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0153 - root_mean_squared_error: 0.1236 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1102
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0127 - root_mean_squared_error: 0.1126 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1126
# Epoch 18/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0129 - root_mean_squared_error: 0.1134 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1243
# Epoch 19/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0131 - root_mean_squared_error: 0.1143 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1186
# Epoch 20/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1083
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0137 - root_mean_squared_error: 0.1171 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1071
# Epoch 22/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0145 - root_mean_squared_error: 0.1206
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0143 - root_mean_squared_error: 0.1194 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1039
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1202 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1051
# Epoch 24/50
# 43/53 [=======================>......] - ETA: 0s - loss: 0.0121 - root_mean_squared_error: 0.1100
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1036
# Epoch 25/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1194 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1104
# Epoch 26/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0143 - root_mean_squared_error: 0.1194
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0144 - root_mean_squared_error: 0.1202 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1028
# Epoch 27/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0130 - root_mean_squared_error: 0.1139 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1036
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1542
# Epoch 29/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0124 - root_mean_squared_error: 0.1114
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0124 - root_mean_squared_error: 0.1113 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1020
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0157 - root_mean_squared_error: 0.1253 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1092
# Epoch 31/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0150 - root_mean_squared_error: 0.1224
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# INFO:tensorflow:Assets written to: Bell_Amund_model_LT12\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0152 - root_mean_squared_error: 0.1233 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1006
# Epoch 32/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0126 - root_mean_squared_error: 0.1123 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 33/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0112 - root_mean_squared_error: 0.1057 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1075
# Epoch 34/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0163 - root_mean_squared_error: 0.1278 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1362
# Epoch 35/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0138 - root_mean_squared_error: 0.1176 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1024
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0137 - root_mean_squared_error: 0.1172 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1046
# Epoch 37/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0149 - root_mean_squared_error: 0.1222 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1016
# Epoch 38/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0107 - root_mean_squared_error: 0.1036 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1053
# Epoch 39/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0132 - root_mean_squared_error: 0.1149 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1095
# Epoch 40/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0127 - root_mean_squared_error: 0.1129 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1037
# Epoch 41/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0132 - root_mean_squared_error: 0.1148 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1062
# Epoch 42/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1065
# Epoch 43/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1207
# Epoch 44/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1066
# Epoch 45/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0130 - root_mean_squared_error: 0.1138 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1071
# Epoch 46/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1283
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0146 - root_mean_squared_error: 0.1208 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1028
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0130 - root_mean_squared_error: 0.1140 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1034
# Epoch 49/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1151
# Epoch 50/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0146 - root_mean_squared_error: 0.1209 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1401

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.6891626318295796 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bell_Amund_model_LT12/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 0s/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.09011387375347372
# MAE : 0.07366568989666074

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        6.728201e+05     807857.307
# 1        1.129061e+06    1184280.145
# 2        1.516938e+06    1468308.405
# 3        1.850333e+06    1540851.607
# 4        2.025119e+06    1989099.836
# 5        2.013695e+06    2096990.761
# 6        1.830531e+06    2080961.032
# 7        1.693064e+06    1695704.661
# 8        1.349512e+06    1533888.370
# 9        7.908639e+05    1038332.675
# 10       5.243269e+05     602954.621
# 11       4.207119e+05     895484.288
# 12       8.369989e+05    1070622.700
# 13       1.139201e+06    1532457.922
# 14       1.533300e+06    1703762.123
# 15       1.749760e+06    1855079.122
# 16       2.000154e+06    2291960.639
# 17       2.103883e+06    2114120.417
# 18       2.046295e+06    1995818.759
# 19       1.767192e+06    1653379.997
# 20       1.335432e+06    1070814.995
# 21       1.014110e+06     689443.815
# 22       6.187034e+05     401148.663
# 23       6.064457e+05     346558.057
# 24       9.377132e+05     599477.678
# 25       1.344293e+06     765764.905
# 26       1.528217e+06    1304133.179
# 27       1.854697e+06    1598436.099
# 28       1.946164e+06    1763844.414
# 29       2.042465e+06    1979139.524
# 30       1.727573e+06    1937348.663
# 31       1.561957e+06    1833093.342
# 32       1.056091e+06    1089676.114
# 33       6.150978e+05     453484.731
# 34       3.938262e+05     251559.554
# 35       3.348188e+05     351294.657
# 36       6.675686e+05     702389.714
# 37       9.155535e+05    1185169.054
# 38       1.435950e+06    1556568.455
# 39       1.677784e+06    1917507.979
# 40       2.033120e+06    2601630.327
# 41       2.053500e+06    2534223.780
# 42       2.056506e+06    2373004.525

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
