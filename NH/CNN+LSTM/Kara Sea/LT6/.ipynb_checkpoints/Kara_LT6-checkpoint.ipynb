# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Kara = pd.read_excel(filepath, sheet_name='Kara-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Kara)
fp.date_time(Kara)
# Out:
#          Extent       Date
# 0    917992.880 1979-01-01
# 1    917992.880 1979-02-01
# 2    917992.880 1979-03-01
# 3    917992.880 1979-04-01
# 4    917992.880 1979-05-01
# ..          ...        ...
# 533  728642.743 2023-06-01
# 534  437024.646 2023-07-01
# 535  202260.789 2023-08-01
# 536   98103.856 2023-09-01
# 537  260413.272 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Kara['Extent'] = scaler.fit_transform(Kara['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 6
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Kara['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((521, 12, 1), (521,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Kara_model_LT6/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.6715 - root_mean_squared_error: 0.8195
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 8s 96ms/step - loss: 0.6572 - root_mean_squared_error: 0.8107 - val_loss: 0.4435 - val_root_mean_squared_error: 0.6660
# Epoch 2/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.6079 - root_mean_squared_error: 0.7797
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 3s 64ms/step - loss: 0.5881 - root_mean_squared_error: 0.7669 - val_loss: 0.4118 - val_root_mean_squared_error: 0.6418
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.5254 - root_mean_squared_error: 0.7248
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 4s 77ms/step - loss: 0.5227 - root_mean_squared_error: 0.7230 - val_loss: 0.3762 - val_root_mean_squared_error: 0.6133
# Epoch 4/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.4650 - root_mean_squared_error: 0.6819
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.4572 - root_mean_squared_error: 0.6761 - val_loss: 0.3286 - val_root_mean_squared_error: 0.5732
# Epoch 5/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.3995 - root_mean_squared_error: 0.6320
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 3s 65ms/step - loss: 0.4000 - root_mean_squared_error: 0.6325 - val_loss: 0.3042 - val_root_mean_squared_error: 0.5515
# Epoch 6/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.3487 - root_mean_squared_error: 0.5905
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 4s 68ms/step - loss: 0.3426 - root_mean_squared_error: 0.5853 - val_loss: 0.2703 - val_root_mean_squared_error: 0.5199
# Epoch 7/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2966 - root_mean_squared_error: 0.5446
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.2926 - root_mean_squared_error: 0.5409 - val_loss: 0.2242 - val_root_mean_squared_error: 0.4735
# Epoch 8/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.2499 - root_mean_squared_error: 0.4999
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 3s 65ms/step - loss: 0.2467 - root_mean_squared_error: 0.4967 - val_loss: 0.2215 - val_root_mean_squared_error: 0.4706
# Epoch 9/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2045 - root_mean_squared_error: 0.4522
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 4s 75ms/step - loss: 0.2029 - root_mean_squared_error: 0.4505 - val_loss: 0.1568 - val_root_mean_squared_error: 0.3960
# Epoch 10/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.1692 - root_mean_squared_error: 0.4113
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 4s 75ms/step - loss: 0.1683 - root_mean_squared_error: 0.4103 - val_loss: 0.1343 - val_root_mean_squared_error: 0.3665
# Epoch 11/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1358 - root_mean_squared_error: 0.3686
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.1348 - root_mean_squared_error: 0.3671 - val_loss: 0.0832 - val_root_mean_squared_error: 0.2884
# Epoch 12/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.1094 - root_mean_squared_error: 0.3307 - val_loss: 0.1151 - val_root_mean_squared_error: 0.3393
# Epoch 13/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0900 - root_mean_squared_error: 0.3000
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 4s 86ms/step - loss: 0.0882 - root_mean_squared_error: 0.2969 - val_loss: 0.0466 - val_root_mean_squared_error: 0.2158
# Epoch 14/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0732 - root_mean_squared_error: 0.2705 - val_loss: 0.0551 - val_root_mean_squared_error: 0.2347
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0619 - root_mean_squared_error: 0.2488
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0619 - root_mean_squared_error: 0.2488 - val_loss: 0.0417 - val_root_mean_squared_error: 0.2043
# Epoch 16/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0492 - root_mean_squared_error: 0.2219 - val_loss: 0.0437 - val_root_mean_squared_error: 0.2092
# Epoch 17/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0434 - root_mean_squared_error: 0.2084
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0421 - root_mean_squared_error: 0.2053 - val_loss: 0.0286 - val_root_mean_squared_error: 0.1691
# Epoch 18/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0356 - root_mean_squared_error: 0.1887 - val_loss: 0.0295 - val_root_mean_squared_error: 0.1717
# Epoch 19/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0324 - root_mean_squared_error: 0.1799
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0318 - root_mean_squared_error: 0.1784 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1593
# Epoch 20/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0316 - root_mean_squared_error: 0.1779 - val_loss: 0.0560 - val_root_mean_squared_error: 0.2366
# Epoch 21/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0284 - root_mean_squared_error: 0.1685 - val_loss: 0.0273 - val_root_mean_squared_error: 0.1652
# Epoch 22/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0288 - root_mean_squared_error: 0.1696 - val_loss: 0.0373 - val_root_mean_squared_error: 0.1930
# Epoch 23/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0285 - root_mean_squared_error: 0.1689
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0292 - root_mean_squared_error: 0.1709 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1589
# Epoch 24/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0260 - root_mean_squared_error: 0.1613 - val_loss: 0.0394 - val_root_mean_squared_error: 0.1986
# Epoch 25/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0271 - root_mean_squared_error: 0.1647 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1841
# Epoch 26/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0245 - root_mean_squared_error: 0.1564 - val_loss: 0.0504 - val_root_mean_squared_error: 0.2245
# Epoch 27/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0243 - root_mean_squared_error: 0.1557
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0242 - root_mean_squared_error: 0.1557 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1583
# Epoch 28/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0260 - root_mean_squared_error: 0.1612 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1623
# Epoch 29/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0232 - root_mean_squared_error: 0.1525
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0233 - root_mean_squared_error: 0.1526 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1532
# Epoch 30/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0243 - root_mean_squared_error: 0.1559 - val_loss: 0.0316 - val_root_mean_squared_error: 0.1779
# Epoch 31/50
# 53/53 [==============================] - 0s 4ms/step - loss: 0.0257 - root_mean_squared_error: 0.1605 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1836
# Epoch 32/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0254 - root_mean_squared_error: 0.1595 - val_loss: 0.0320 - val_root_mean_squared_error: 0.1788
# Epoch 33/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0233 - root_mean_squared_error: 0.1526 - val_loss: 0.0277 - val_root_mean_squared_error: 0.1666
# Epoch 34/50
# 53/53 [==============================] - 0s 4ms/step - loss: 0.0244 - root_mean_squared_error: 0.1564 - val_loss: 0.0325 - val_root_mean_squared_error: 0.1803
# Epoch 35/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0258 - root_mean_squared_error: 0.1607 - val_loss: 0.0465 - val_root_mean_squared_error: 0.2157
# Epoch 36/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0226 - root_mean_squared_error: 0.1503 - val_loss: 0.0853 - val_root_mean_squared_error: 0.2921
# Epoch 37/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0267 - root_mean_squared_error: 0.1634 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1698
# Epoch 38/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0245 - root_mean_squared_error: 0.1564 - val_loss: 0.0448 - val_root_mean_squared_error: 0.2117
# Epoch 39/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0253 - root_mean_squared_error: 0.1591 - val_loss: 0.0342 - val_root_mean_squared_error: 0.1851
# Epoch 40/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0232 - root_mean_squared_error: 0.1524 - val_loss: 0.0533 - val_root_mean_squared_error: 0.2309
# Epoch 41/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0286 - root_mean_squared_error: 0.1691
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0286 - root_mean_squared_error: 0.1691 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1478
# Epoch 42/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0232 - root_mean_squared_error: 0.1525 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1495
# Epoch 43/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0218 - root_mean_squared_error: 0.1478 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1591
# Epoch 44/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0227 - root_mean_squared_error: 0.1506 - val_loss: 0.0308 - val_root_mean_squared_error: 0.1756
# Epoch 45/50
# 43/53 [=======================>......] - ETA: 0s - loss: 0.0209 - root_mean_squared_error: 0.1446
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# INFO:tensorflow:Assets written to: Kara_model_LT6\assets
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0205 - root_mean_squared_error: 0.1431 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1456
# Epoch 46/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0232 - root_mean_squared_error: 0.1522 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1557
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0223 - root_mean_squared_error: 0.1493 - val_loss: 0.0266 - val_root_mean_squared_error: 0.1630
# Epoch 48/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0279 - root_mean_squared_error: 0.1672 - val_loss: 0.0359 - val_root_mean_squared_error: 0.1894
# Epoch 49/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0276 - root_mean_squared_error: 0.1662 - val_loss: 0.0441 - val_root_mean_squared_error: 0.2100
# Epoch 50/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0240 - root_mean_squared_error: 0.1550 - val_loss: 0.0273 - val_root_mean_squared_error: 0.1652

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.522531255086263 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Kara_model_LT6/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 0s/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.14495162936701123
# MAE : 0.11330071744608267

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       251259.265625     131973.043
# 1       608892.125000     753595.099
# 2       755140.437500     909176.475
# 3       881322.937500     917006.278
# 4       861876.250000     906368.363
# 5       879860.250000     917403.622
# 6       854233.312500     910653.838
# 7       759916.625000     822319.125
# 8       684375.625000     557314.102
# 9       433883.156250     197129.525
# 10       91552.828125      75730.217
# 11      145093.093750      59608.479
# 12      361519.281250      88785.283
# 13      702345.812500     396883.400
# 14      785682.687500     662542.207
# 15      914578.562500     871431.414
# 16      926949.562500     917876.960
# 17      904900.500000     917992.880
# 18      842588.750000     912733.060
# 19      664032.937500     910536.463
# 20      528296.812500     760170.733
# 21      305955.500000     383812.645
# 22       90732.546875     201024.515
# 23      143695.250000     121904.059
# 24      291758.250000     283554.493
# 25      553430.500000     702176.823
# 26      646895.750000     893690.080
# 27      785666.062500     910117.941
# 28      777355.187500     889204.715
# 29      843012.500000     905311.611
# 30      885343.750000     917930.089
# 31      788781.500000     912089.899
# 32      706034.375000     743951.228
# 33      416222.125000     307180.895
# 34      148415.328125     104402.284
# 35      134412.078125      73177.670
# 36      409473.156250     127085.610
# 37      659329.125000     650570.950
# 38      816076.687500     789062.385
# 39      797449.062500     897053.619
# 40      884766.937500     904024.315
# 41      854783.875000     911832.551
# 42      836001.937500     917992.880
# 43      736718.625000     894286.938
# 44      656013.937500     728642.743
# 45      376539.531250     437024.646
# 46       76930.453125     202260.789
# 47       84901.820312      98103.856
# 48      328843.468750     260413.272

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
