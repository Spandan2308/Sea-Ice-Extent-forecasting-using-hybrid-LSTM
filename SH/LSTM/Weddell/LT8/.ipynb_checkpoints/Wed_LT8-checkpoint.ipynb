# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Weddell_Extent = pd.read_excel(filepath, sheet_name='Weddell-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Weddell_Extent)
fp.date_time(Weddell_Extent)
# Out:
#           Extent       Date
# 0    2136510.859 1979-01-01
# 1    1243495.891 1979-02-01
# 2    1699053.449 1979-03-01
# 3    2617442.085 1979-04-01
# 4    3852934.206 1979-05-01
# ..           ...        ...
# 533  3668127.143 2023-06-01
# 534  4805519.784 2023-07-01
# 535  5524445.234 2023-08-01
# 536  6006669.861 2023-09-01
# 537  5507961.583 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Weddell_Extent['Extent'] = scaler.fit_transform(Weddell_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 8
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Weddell_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((519, 12, 1), (519,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Weddell_model_LT8/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.3188 - root_mean_squared_error: 0.5646INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 12s 144ms/step - loss: 0.3165 - root_mean_squared_error: 0.5626 - val_loss: 0.2808 - val_root_mean_squared_error: 0.5299
# Epoch 2/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2184 - root_mean_squared_error: 0.4673INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 7s 129ms/step - loss: 0.2166 - root_mean_squared_error: 0.4654 - val_loss: 0.1211 - val_root_mean_squared_error: 0.3480
# Epoch 3/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1096 - root_mean_squared_error: 0.3310INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 6s 119ms/step - loss: 0.1097 - root_mean_squared_error: 0.3312 - val_loss: 0.1066 - val_root_mean_squared_error: 0.3265
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0986 - root_mean_squared_error: 0.3140INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 7s 129ms/step - loss: 0.0986 - root_mean_squared_error: 0.3140 - val_loss: 0.0894 - val_root_mean_squared_error: 0.2990
# Epoch 5/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0840 - root_mean_squared_error: 0.2898INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 7s 129ms/step - loss: 0.0839 - root_mean_squared_error: 0.2896 - val_loss: 0.0733 - val_root_mean_squared_error: 0.2707
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0641 - root_mean_squared_error: 0.2531INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 6s 122ms/step - loss: 0.0639 - root_mean_squared_error: 0.2528 - val_loss: 0.0495 - val_root_mean_squared_error: 0.2224
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0397 - root_mean_squared_error: 0.1994INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 7s 130ms/step - loss: 0.0394 - root_mean_squared_error: 0.1985 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1437
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0211 - root_mean_squared_error: 0.1452INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 7s 128ms/step - loss: 0.0217 - root_mean_squared_error: 0.1473 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1165
# Epoch 9/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0169 - root_mean_squared_error: 0.1300INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 6s 122ms/step - loss: 0.0170 - root_mean_squared_error: 0.1305 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1033
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0151 - root_mean_squared_error: 0.1228INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 7s 131ms/step - loss: 0.0150 - root_mean_squared_error: 0.1226 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0963
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0137 - root_mean_squared_error: 0.1169INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 7s 125ms/step - loss: 0.0137 - root_mean_squared_error: 0.1169 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0916
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0125 - root_mean_squared_error: 0.1120INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 6s 121ms/step - loss: 0.0126 - root_mean_squared_error: 0.1122 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0858
# Epoch 13/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0104 - root_mean_squared_error: 0.1019 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0960
# Epoch 14/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0100 - root_mean_squared_error: 0.0999INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 7s 132ms/step - loss: 0.0099 - root_mean_squared_error: 0.0996 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0783
# Epoch 15/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0099 - root_mean_squared_error: 0.0997INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 7s 129ms/step - loss: 0.0099 - root_mean_squared_error: 0.0997 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0700
# Epoch 16/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0100 - root_mean_squared_error: 0.1000 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0809
# Epoch 17/50
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0086 - root_mean_squared_error: 0.0926 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0754
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0102 - root_mean_squared_error: 0.1008INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 6s 122ms/step - loss: 0.0102 - root_mean_squared_error: 0.1008 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0681
# Epoch 19/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0087 - root_mean_squared_error: 0.0934 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0714
# Epoch 20/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0083 - root_mean_squared_error: 0.0912 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0894
# Epoch 21/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0093 - root_mean_squared_error: 0.0963 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0682
# Epoch 22/50
# 53/53 [==============================] - 2s 28ms/step - loss: 0.0092 - root_mean_squared_error: 0.0960 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0737
# Epoch 23/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0082 - root_mean_squared_error: 0.0908 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0734
# Epoch 24/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0072 - root_mean_squared_error: 0.0846 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0693
# Epoch 25/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0083 - root_mean_squared_error: 0.0911 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0762
# Epoch 26/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0077 - root_mean_squared_error: 0.0879 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0785
# Epoch 27/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0075 - root_mean_squared_error: 0.0867 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0867
# Epoch 28/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0080 - root_mean_squared_error: 0.0893 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0720
# Epoch 29/50
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0073 - root_mean_squared_error: 0.0856 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0805
# Epoch 30/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0903INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 7s 136ms/step - loss: 0.0081 - root_mean_squared_error: 0.0898 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0672
# Epoch 31/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0071 - root_mean_squared_error: 0.0843INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 7s 136ms/step - loss: 0.0071 - root_mean_squared_error: 0.0843 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0666
# Epoch 32/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0072 - root_mean_squared_error: 0.0847 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0697
# Epoch 33/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0067 - root_mean_squared_error: 0.0821 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0779
# Epoch 34/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0069 - root_mean_squared_error: 0.0833 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0671
# Epoch 35/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0070 - root_mean_squared_error: 0.0835 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0724
# Epoch 36/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0071 - root_mean_squared_error: 0.0842 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0698
# Epoch 37/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0070 - root_mean_squared_error: 0.0839 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0967
# Epoch 38/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0068 - root_mean_squared_error: 0.0827 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0759
# Epoch 39/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0068 - root_mean_squared_error: 0.0827 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0684
# Epoch 40/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0065 - root_mean_squared_error: 0.0806 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0696
# Epoch 41/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0073 - root_mean_squared_error: 0.0856INFO:tensorflow:Assets written to: Weddell_model_LT8\assets
# 53/53 [==============================] - 7s 129ms/step - loss: 0.0073 - root_mean_squared_error: 0.0856 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0656
# Epoch 42/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0072 - root_mean_squared_error: 0.0846 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0686
# Epoch 43/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0067 - root_mean_squared_error: 0.0819 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0816
# Epoch 44/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0070 - root_mean_squared_error: 0.0836 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0672
# Epoch 45/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0064 - root_mean_squared_error: 0.0799 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0668
# Epoch 46/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0066 - root_mean_squared_error: 0.0811 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0704
# Epoch 47/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0068 - root_mean_squared_error: 0.0825 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0772
# Epoch 48/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0067 - root_mean_squared_error: 0.0819 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0681
# Epoch 49/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0067 - root_mean_squared_error: 0.0817 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0660
# Epoch 50/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0064 - root_mean_squared_error: 0.0799 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0689

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 2.7695066730181375 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Weddell_model_LT8/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 0s/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.07364184010637732
# MAE : 0.05573840925652797

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0         4633926.500    3498103.449
# 1         2848154.250    1633675.726
# 2         1844012.000    1292668.399
# 3         1751637.000    1527666.815
# 4         2534704.750    2121949.701
# 5         3703440.250    3562381.775
# 6         4808039.000    5004305.983
# 7         5765782.500    6176613.878
# 8         6212792.000    6794233.093
# 9         6310192.000    7024136.637
# 10        6181419.500    6554271.388
# 11        5718111.500    6172281.701
# 12        4249000.500    4175225.799
# 13        2214729.500    1748380.899
# 14        1396608.125    1256191.080
# 15        1286499.125    1347295.364
# 16        2093896.250    2180184.677
# 17        3583358.250    3419295.982
# 18        4867236.000    4786146.771
# 19        5920448.500    5968132.718
# 20        6369505.000    6556934.174
# 21        6457309.000    6614949.980
# 22        6291408.500    6035207.368
# 23        5642029.500    5274244.730
# 24        3529038.750    3505146.372
# 25        1881517.500    1478130.228
# 26        1250180.500    1096780.503
# 27        1123223.500    1387234.069
# 28        1681255.375    2128693.591
# 29        3307406.250    3313318.704
# 30        4574113.500    4218076.656
# 31        5695143.500    5257641.941
# 32        6235453.000    5956603.340
# 33        6294318.000    6256062.049
# 34        6119670.000    5974548.305
# 35        5543373.000    5569396.731
# 36        3795873.750    3684108.410
# 37        2115479.000    1451614.707
# 38        1421966.500    1089888.684
# 39        1434826.875    1255222.909
# 40        2454005.000    1704492.279
# 41        3843107.500    2563551.804
# 42        4850607.500    3668127.143
# 43        5689762.500    4805519.784
# 44        6135839.500    5524445.234
# 45        6228731.500    6006669.861
# 46        6116354.000    5507961.583

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 12ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
