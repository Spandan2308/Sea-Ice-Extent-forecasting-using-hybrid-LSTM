# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bering = pd.read_excel(filepath, sheet_name='Bering-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Bering)
fp.date_time(Bering)
# Out:
#          Extent       Date
# 0    320266.650 1979-01-01
# 1    541778.338 1979-02-01
# 2    638262.988 1979-03-01
# 3    423025.159 1979-04-01
# 4    215587.216 1979-05-01
# ..          ...        ...
# 488  317377.493 2023-05-01
# 489   39601.476 2023-06-01
# 490   16935.702 2023-07-01
# 491    1305.744 2023-09-01
# 492   12255.644 2023-10-01
#
# [493 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bering['Extent'] = scaler.fit_transform(Bering['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 11
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bering['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((471, 12, 1), (471,))

# %%
X_train, y_train = X[:384], y[:384]
X_val, y_val = X[384:432], y[384:432]
X_test, y_test = X[432:], y[432:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Bering_model_LT11/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 48/48 [==============================] - ETA: 0s - loss: 0.1689 - root_mean_squared_error: 0.4110INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 12s 172ms/step - loss: 0.1689 - root_mean_squared_error: 0.4110 - val_loss: 0.0665 - val_root_mean_squared_error: 0.2578
# Epoch 2/50
# 45/48 [===========================>..] - ETA: 0s - loss: 0.1240 - root_mean_squared_error: 0.3521INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 7s 149ms/step - loss: 0.1219 - root_mean_squared_error: 0.3492 - val_loss: 0.0425 - val_root_mean_squared_error: 0.2063
# Epoch 3/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0824 - root_mean_squared_error: 0.2870 - val_loss: 0.0444 - val_root_mean_squared_error: 0.2108
# Epoch 4/50
# 48/48 [==============================] - 1s 14ms/step - loss: 0.0775 - root_mean_squared_error: 0.2784 - val_loss: 0.0435 - val_root_mean_squared_error: 0.2085
# Epoch 5/50
# 45/48 [===========================>..] - ETA: 0s - loss: 0.0708 - root_mean_squared_error: 0.2662INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 7s 147ms/step - loss: 0.0696 - root_mean_squared_error: 0.2639 - val_loss: 0.0422 - val_root_mean_squared_error: 0.2053
# Epoch 6/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0569 - root_mean_squared_error: 0.2385 - val_loss: 0.0443 - val_root_mean_squared_error: 0.2106
# Epoch 7/50
# 47/48 [============================>.] - ETA: 0s - loss: 0.0419 - root_mean_squared_error: 0.2046INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 8s 174ms/step - loss: 0.0414 - root_mean_squared_error: 0.2035 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1622
# Epoch 8/50
# 47/48 [============================>.] - ETA: 0s - loss: 0.0297 - root_mean_squared_error: 0.1722INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 9s 195ms/step - loss: 0.0292 - root_mean_squared_error: 0.1708 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1601
# Epoch 9/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0230 - root_mean_squared_error: 0.1517 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2028
# Epoch 10/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0198 - root_mean_squared_error: 0.1409 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1645
# Epoch 11/50
# 44/48 [==========================>...] - ETA: 0s - loss: 0.0182 - root_mean_squared_error: 0.1348INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 9s 188ms/step - loss: 0.0181 - root_mean_squared_error: 0.1345 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1589
# Epoch 12/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0192 - root_mean_squared_error: 0.1384 - val_loss: 0.0363 - val_root_mean_squared_error: 0.1904
# Epoch 13/50
# 48/48 [==============================] - 1s 15ms/step - loss: 0.0176 - root_mean_squared_error: 0.1328 - val_loss: 0.0391 - val_root_mean_squared_error: 0.1976
# Epoch 14/50
# 46/48 [===========================>..] - ETA: 0s - loss: 0.0153 - root_mean_squared_error: 0.1238INFO:tensorflow:Assets written to: Bering_model_LT11\assets
# 48/48 [==============================] - 8s 171ms/step - loss: 0.0151 - root_mean_squared_error: 0.1227 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1512
# Epoch 15/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0175 - root_mean_squared_error: 0.1323 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1834
# Epoch 16/50
# 48/48 [==============================] - 1s 15ms/step - loss: 0.0170 - root_mean_squared_error: 0.1302 - val_loss: 0.0401 - val_root_mean_squared_error: 0.2003
# Epoch 17/50
# 48/48 [==============================] - 1s 15ms/step - loss: 0.0156 - root_mean_squared_error: 0.1247 - val_loss: 0.0280 - val_root_mean_squared_error: 0.1673
# Epoch 18/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0154 - root_mean_squared_error: 0.1241 - val_loss: 0.0520 - val_root_mean_squared_error: 0.2281
# Epoch 19/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0153 - root_mean_squared_error: 0.1235 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2029
# Epoch 20/50
# 48/48 [==============================] - 1s 15ms/step - loss: 0.0154 - root_mean_squared_error: 0.1239 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2013
# Epoch 21/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0131 - root_mean_squared_error: 0.1146 - val_loss: 0.0301 - val_root_mean_squared_error: 0.1734
# Epoch 22/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0157 - root_mean_squared_error: 0.1254 - val_loss: 0.0419 - val_root_mean_squared_error: 0.2048
# Epoch 23/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0140 - root_mean_squared_error: 0.1184 - val_loss: 0.0477 - val_root_mean_squared_error: 0.2184
# Epoch 24/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192 - val_loss: 0.0394 - val_root_mean_squared_error: 0.1984
# Epoch 25/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221 - val_loss: 0.0441 - val_root_mean_squared_error: 0.2101
# Epoch 26/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0151 - root_mean_squared_error: 0.1227 - val_loss: 0.0469 - val_root_mean_squared_error: 0.2166
# Epoch 27/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0151 - root_mean_squared_error: 0.1227 - val_loss: 0.0521 - val_root_mean_squared_error: 0.2283
# Epoch 28/50
# 48/48 [==============================] - 1s 15ms/step - loss: 0.0150 - root_mean_squared_error: 0.1224 - val_loss: 0.0382 - val_root_mean_squared_error: 0.1956
# Epoch 29/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0148 - root_mean_squared_error: 0.1215 - val_loss: 0.0422 - val_root_mean_squared_error: 0.2055
# Epoch 30/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188 - val_loss: 0.0386 - val_root_mean_squared_error: 0.1964
# Epoch 31/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0136 - root_mean_squared_error: 0.1164 - val_loss: 0.0508 - val_root_mean_squared_error: 0.2254
# Epoch 32/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190 - val_loss: 0.0372 - val_root_mean_squared_error: 0.1928
# Epoch 33/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0138 - root_mean_squared_error: 0.1173 - val_loss: 0.0557 - val_root_mean_squared_error: 0.2360
# Epoch 34/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0137 - root_mean_squared_error: 0.1168 - val_loss: 0.0458 - val_root_mean_squared_error: 0.2139
# Epoch 35/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0497 - val_root_mean_squared_error: 0.2229
# Epoch 36/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0135 - root_mean_squared_error: 0.1162 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2033
# Epoch 37/50
# 48/48 [==============================] - 1s 22ms/step - loss: 0.0125 - root_mean_squared_error: 0.1116 - val_loss: 0.0364 - val_root_mean_squared_error: 0.1907
# Epoch 38/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - val_loss: 0.0443 - val_root_mean_squared_error: 0.2105
# Epoch 39/50
# 48/48 [==============================] - 1s 18ms/step - loss: 0.0147 - root_mean_squared_error: 0.1214 - val_loss: 0.0485 - val_root_mean_squared_error: 0.2203
# Epoch 40/50
# 48/48 [==============================] - 1s 16ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161 - val_loss: 0.0365 - val_root_mean_squared_error: 0.1911
# Epoch 41/50
# 48/48 [==============================] - 1s 14ms/step - loss: 0.0126 - root_mean_squared_error: 0.1124 - val_loss: 0.0374 - val_root_mean_squared_error: 0.1933
# Epoch 42/50
# 48/48 [==============================] - 1s 16ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182 - val_loss: 0.0351 - val_root_mean_squared_error: 0.1874
# Epoch 43/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190 - val_loss: 0.0704 - val_root_mean_squared_error: 0.2653
# Epoch 44/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1913
# Epoch 45/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0132 - root_mean_squared_error: 0.1149 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2030
# Epoch 46/50
# 48/48 [==============================] - 1s 22ms/step - loss: 0.0113 - root_mean_squared_error: 0.1065 - val_loss: 0.0526 - val_root_mean_squared_error: 0.2294
# Epoch 47/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0129 - root_mean_squared_error: 0.1136 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2029
# Epoch 48/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0125 - root_mean_squared_error: 0.1117 - val_loss: 0.0484 - val_root_mean_squared_error: 0.2199
# Epoch 49/50
# 48/48 [==============================] - 1s 17ms/step - loss: 0.0135 - root_mean_squared_error: 0.1162 - val_loss: 0.0465 - val_root_mean_squared_error: 0.2156
# Epoch 50/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0131 - root_mean_squared_error: 0.1144 - val_loss: 0.0541 - val_root_mean_squared_error: 0.2325

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.626618707180023 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bering_model_LT11/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 10ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.10876464191593738
# MAE : 0.08859025503626318

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       282205.906250     414216.785
# 1       221026.218750     236263.303
# 2       176920.359375      43422.368
# 3       135941.500000       2161.744
# 4       120808.296875        944.181
# 5       134859.515625      13977.643
# 6       201052.031250      24795.001
# 7       321942.687500     168828.990
# 8       450472.875000     461098.498
# 9       440879.625000     591635.798
# 10      381486.750000     598360.298
# 11      297500.093750     531742.038
# 12      177497.140625     302131.004
# 13      107478.781250      57748.135
# 14       46880.691406       3054.962
# 15       29615.787109        442.539
# 16       53980.750000       8541.643
# 17      120145.875000     121335.125
# 18      250531.406250     360205.990
# 19      438811.843750     651717.220
# 20      571837.187500     779385.402
# 21      568975.937500     710314.085
# 22      440441.750000     578635.421
# 23      274297.718750     199031.792
# 24      119814.398438      43795.314
# 25       47174.601562       3015.211
# 26       17933.705078       1206.623
# 27       32240.105469       8506.979
# 28       86773.093750      41065.748
# 29      197145.812500     169363.165
# 30      353036.906250     531698.544
# 31      481407.593750     631496.345
# 32      541362.812500     612860.407
# 33      461775.187500     552903.799
# 34      225209.328125     317377.493
# 35       22265.994141      39601.476
# 36       -8883.567383      16935.702
# 37       -6236.933594       1305.744
# 38       31692.843750      12255.644

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 15/15 [==============================] - 0s 10ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
