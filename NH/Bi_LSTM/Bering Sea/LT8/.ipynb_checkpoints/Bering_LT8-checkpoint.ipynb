# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bering = pd.read_excel(filepath, sheet_name='Bering-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Bering)
fp.date_time(Bering)
# Out:
#          Extent       Date
# 0    320266.650 1979-01-01
# 1    541778.338 1979-02-01
# 2    638262.988 1979-03-01
# 3    423025.159 1979-04-01
# 4    215587.216 1979-05-01
# ..          ...        ...
# 488  317377.493 2023-05-01
# 489   39601.476 2023-06-01
# 490   16935.702 2023-07-01
# 491    1305.744 2023-09-01
# 492   12255.644 2023-10-01
#
# [493 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bering['Extent'] = scaler.fit_transform(Bering['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 8
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bering['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((474, 12, 1), (474,))

# %%
X_train, y_train = X[:384], y[:384]
X_val, y_val = X[384:432], y[384:432]
X_test, y_test = X[432:], y[432:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Bering_model_LT8/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 46/48 [===========================>..] - ETA: 0s - loss: 0.1498 - root_mean_squared_error: 0.3871INFO:tensorflow:Assets written to: Bering_model_LT8\assets
# 48/48 [==============================] - 28s 453ms/step - loss: 0.1500 - root_mean_squared_error: 0.3873 - val_loss: 0.0378 - val_root_mean_squared_error: 0.1944
# Epoch 2/50
# 48/48 [==============================] - 1s 22ms/step - loss: 0.0928 - root_mean_squared_error: 0.3046 - val_loss: 0.0396 - val_root_mean_squared_error: 0.1990
# Epoch 3/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0738 - root_mean_squared_error: 0.2717 - val_loss: 0.0385 - val_root_mean_squared_error: 0.1961
# Epoch 4/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0584 - root_mean_squared_error: 0.2418INFO:tensorflow:Assets written to: Bering_model_LT8\assets
# 48/48 [==============================] - 20s 430ms/step - loss: 0.0584 - root_mean_squared_error: 0.2418 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1647
# Epoch 5/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0403 - root_mean_squared_error: 0.2006INFO:tensorflow:Assets written to: Bering_model_LT8\assets
# 48/48 [==============================] - 24s 511ms/step - loss: 0.0403 - root_mean_squared_error: 0.2006 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1345
# Epoch 6/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0261 - root_mean_squared_error: 0.1617INFO:tensorflow:Assets written to: Bering_model_LT8\assets
# 48/48 [==============================] - 24s 517ms/step - loss: 0.0261 - root_mean_squared_error: 0.1617 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1285
# Epoch 7/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0193 - root_mean_squared_error: 0.1390 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1358
# Epoch 8/50
# 48/48 [==============================] - 2s 44ms/step - loss: 0.0168 - root_mean_squared_error: 0.1297 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1578
# Epoch 9/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0153 - root_mean_squared_error: 0.1236 - val_loss: 0.0345 - val_root_mean_squared_error: 0.1858
# Epoch 10/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0150 - root_mean_squared_error: 0.1224 - val_loss: 0.0315 - val_root_mean_squared_error: 0.1774
# Epoch 11/50
# 48/48 [==============================] - 2s 51ms/step - loss: 0.0145 - root_mean_squared_error: 0.1205 - val_loss: 0.0486 - val_root_mean_squared_error: 0.2204
# Epoch 12/50
# 48/48 [==============================] - 2s 44ms/step - loss: 0.0146 - root_mean_squared_error: 0.1210 - val_loss: 0.0476 - val_root_mean_squared_error: 0.2181
# Epoch 13/50
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199 - val_loss: 0.0485 - val_root_mean_squared_error: 0.2203
# Epoch 14/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0136 - root_mean_squared_error: 0.1165 - val_loss: 0.0565 - val_root_mean_squared_error: 0.2378
# Epoch 15/50
# 48/48 [==============================] - 2s 52ms/step - loss: 0.0135 - root_mean_squared_error: 0.1163 - val_loss: 0.0470 - val_root_mean_squared_error: 0.2168
# Epoch 16/50
# 48/48 [==============================] - 2s 44ms/step - loss: 0.0126 - root_mean_squared_error: 0.1125 - val_loss: 0.0633 - val_root_mean_squared_error: 0.2516
# Epoch 17/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0130 - root_mean_squared_error: 0.1140 - val_loss: 0.0585 - val_root_mean_squared_error: 0.2418
# Epoch 18/50
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0123 - root_mean_squared_error: 0.1108 - val_loss: 0.0548 - val_root_mean_squared_error: 0.2341
# Epoch 19/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0122 - root_mean_squared_error: 0.1106 - val_loss: 0.0561 - val_root_mean_squared_error: 0.2369
# Epoch 20/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0122 - root_mean_squared_error: 0.1105 - val_loss: 0.0600 - val_root_mean_squared_error: 0.2450
# Epoch 21/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0121 - root_mean_squared_error: 0.1102 - val_loss: 0.0642 - val_root_mean_squared_error: 0.2533
# Epoch 22/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0117 - root_mean_squared_error: 0.1081 - val_loss: 0.0604 - val_root_mean_squared_error: 0.2458
# Epoch 23/50
# 48/48 [==============================] - 2s 37ms/step - loss: 0.0114 - root_mean_squared_error: 0.1066 - val_loss: 0.0697 - val_root_mean_squared_error: 0.2640
# Epoch 24/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0127 - root_mean_squared_error: 0.1128 - val_loss: 0.0594 - val_root_mean_squared_error: 0.2438
# Epoch 25/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0113 - root_mean_squared_error: 0.1065 - val_loss: 0.0784 - val_root_mean_squared_error: 0.2800
# Epoch 26/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0114 - root_mean_squared_error: 0.1068 - val_loss: 0.0701 - val_root_mean_squared_error: 0.2647
# Epoch 27/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0127 - root_mean_squared_error: 0.1125 - val_loss: 0.0576 - val_root_mean_squared_error: 0.2399
# Epoch 28/50
# 48/48 [==============================] - 2s 50ms/step - loss: 0.0113 - root_mean_squared_error: 0.1065 - val_loss: 0.0537 - val_root_mean_squared_error: 0.2317
# Epoch 29/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0108 - root_mean_squared_error: 0.1037 - val_loss: 0.0721 - val_root_mean_squared_error: 0.2686
# Epoch 30/50
# 48/48 [==============================] - 2s 42ms/step - loss: 0.0120 - root_mean_squared_error: 0.1094 - val_loss: 0.0752 - val_root_mean_squared_error: 0.2743
# Epoch 31/50
# 48/48 [==============================] - 2s 45ms/step - loss: 0.0108 - root_mean_squared_error: 0.1040 - val_loss: 0.0596 - val_root_mean_squared_error: 0.2441
# Epoch 32/50
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0106 - root_mean_squared_error: 0.1028 - val_loss: 0.0475 - val_root_mean_squared_error: 0.2179
# Epoch 33/50
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0649 - val_root_mean_squared_error: 0.2547
# Epoch 34/50
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0117 - root_mean_squared_error: 0.1081 - val_loss: 0.0676 - val_root_mean_squared_error: 0.2600
# Epoch 35/50
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0109 - root_mean_squared_error: 0.1042 - val_loss: 0.0606 - val_root_mean_squared_error: 0.2461
# Epoch 36/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0105 - root_mean_squared_error: 0.1027 - val_loss: 0.0608 - val_root_mean_squared_error: 0.2466
# Epoch 37/50
# 48/48 [==============================] - 2s 37ms/step - loss: 0.0108 - root_mean_squared_error: 0.1042 - val_loss: 0.0596 - val_root_mean_squared_error: 0.2442
# Epoch 38/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0107 - root_mean_squared_error: 0.1034 - val_loss: 0.0567 - val_root_mean_squared_error: 0.2381
# Epoch 39/50
# 48/48 [==============================] - 2s 45ms/step - loss: 0.0101 - root_mean_squared_error: 0.1005 - val_loss: 0.0453 - val_root_mean_squared_error: 0.2128
# Epoch 40/50
# 48/48 [==============================] - 2s 43ms/step - loss: 0.0105 - root_mean_squared_error: 0.1023 - val_loss: 0.0487 - val_root_mean_squared_error: 0.2207
# Epoch 41/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0097 - root_mean_squared_error: 0.0986 - val_loss: 0.0714 - val_root_mean_squared_error: 0.2673
# Epoch 42/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0106 - root_mean_squared_error: 0.1031 - val_loss: 0.0381 - val_root_mean_squared_error: 0.1951
# Epoch 43/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0101 - root_mean_squared_error: 0.1006 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2016
# Epoch 44/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0102 - root_mean_squared_error: 0.1010 - val_loss: 0.0498 - val_root_mean_squared_error: 0.2233
# Epoch 45/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0101 - root_mean_squared_error: 0.1007 - val_loss: 0.0541 - val_root_mean_squared_error: 0.2326
# Epoch 46/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0097 - root_mean_squared_error: 0.0985 - val_loss: 0.0554 - val_root_mean_squared_error: 0.2353
# Epoch 47/50
# 48/48 [==============================] - 2s 38ms/step - loss: 0.0097 - root_mean_squared_error: 0.0984 - val_loss: 0.0530 - val_root_mean_squared_error: 0.2303
# Epoch 48/50
# 48/48 [==============================] - 2s 38ms/step - loss: 0.0099 - root_mean_squared_error: 0.0996 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2035
# Epoch 49/50
# 48/48 [==============================] - 2s 38ms/step - loss: 0.0096 - root_mean_squared_error: 0.0981 - val_loss: 0.0535 - val_root_mean_squared_error: 0.2312
# Epoch 50/50
# 48/48 [==============================] - 2s 39ms/step - loss: 0.0099 - root_mean_squared_error: 0.0995 - val_loss: 0.0701 - val_root_mean_squared_error: 0.2647

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 3.1418178121248883 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bering_model_LT8/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 11ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.13983240433472474
# MAE : 0.10828930523437591

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       425891.937500     466524.938
# 1       397249.125000     708542.184
# 2       332199.343750     652598.000
# 3       257743.515625     414216.785
# 4       184543.093750     236263.303
# 5       118442.656250      43422.368
# 6        67298.796875       2161.744
# 7        38708.925781        944.181
# 8       105596.437500      13977.643
# 9       322112.562500      24795.001
# 10      525390.125000     168828.990
# 11      638786.687500     461098.498
# 12      646989.187500     591635.798
# 13      542344.062500     598360.298
# 14      416316.812500     531742.038
# 15      292560.375000     302131.004
# 16      183471.515625      57748.135
# 17       94864.406250       3054.962
# 18       41079.281250        442.539
# 19       32884.082031       8541.643
# 20      129448.609375     121335.125
# 21      339158.000000     360205.990
# 22      544180.875000     651717.220
# 23      622951.687500     779385.402
# 24      561163.187500     710314.085
# 25      436687.968750     578635.421
# 26      310913.812500     199031.792
# 27      198882.312500      43795.314
# 28      116692.437500       3015.211
# 29       74726.039062       1206.623
# 30      106342.671875       8506.979
# 31      278310.656250      41065.748
# 32      503617.593750     169363.165
# 33      704690.875000     531698.544
# 34      733127.187500     631496.345
# 35      631018.875000     612860.407
# 36      465284.968750     552903.799
# 37      308062.968750     317377.493
# 38      175286.015625      39601.476
# 39       76830.226562      16935.702
# 40       20992.744141       1305.744
# 41       22113.472656      12255.644

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 15/15 [==============================] - 0s 16ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
