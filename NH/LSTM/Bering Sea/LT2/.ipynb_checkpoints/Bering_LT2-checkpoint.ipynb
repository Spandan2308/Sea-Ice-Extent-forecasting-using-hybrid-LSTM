# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bering = pd.read_excel(filepath, sheet_name='Bering-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Bering)
fp.date_time(Bering)
# Out:
#          Extent       Date
# 0    320266.650 1979-01-01
# 1    541778.338 1979-02-01
# 2    638262.988 1979-03-01
# 3    423025.159 1979-04-01
# 4    215587.216 1979-05-01
# ..          ...        ...
# 488  317377.493 2023-05-01
# 489   39601.476 2023-06-01
# 490   16935.702 2023-07-01
# 491    1305.744 2023-09-01
# 492   12255.644 2023-10-01
#
# [493 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bering['Extent'] = scaler.fit_transform(Bering['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 2
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bering['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((480, 12, 1), (480,))

# %%
X_train, y_train = X[:384], y[:384]
X_val, y_val = X[384:432], y[384:432]
X_test, y_test = X[432:], y[432:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Bering_model_LT2/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 45/48 [===========================>..] - ETA: 0s - loss: 0.1657 - root_mean_squared_error: 0.4071INFO:tensorflow:Assets written to: Bering_model_LT2\assets
# 48/48 [==============================] - 13s 197ms/step - loss: 0.1623 - root_mean_squared_error: 0.4029 - val_loss: 0.0553 - val_root_mean_squared_error: 0.2351
# Epoch 2/50
# 48/48 [==============================] - ETA: 0s - loss: 0.1009 - root_mean_squared_error: 0.3177INFO:tensorflow:Assets written to: Bering_model_LT2\assets
# 48/48 [==============================] - 8s 173ms/step - loss: 0.1009 - root_mean_squared_error: 0.3177 - val_loss: 0.0358 - val_root_mean_squared_error: 0.1892
# Epoch 3/50
# 46/48 [===========================>..] - ETA: 0s - loss: 0.0606 - root_mean_squared_error: 0.2462INFO:tensorflow:Assets written to: Bering_model_LT2\assets
# 48/48 [==============================] - 8s 178ms/step - loss: 0.0603 - root_mean_squared_error: 0.2455 - val_loss: 0.0334 - val_root_mean_squared_error: 0.1827
# Epoch 4/50
# 46/48 [===========================>..] - ETA: 0s - loss: 0.0507 - root_mean_squared_error: 0.2252INFO:tensorflow:Assets written to: Bering_model_LT2\assets
# 48/48 [==============================] - 8s 171ms/step - loss: 0.0504 - root_mean_squared_error: 0.2245 - val_loss: 0.0272 - val_root_mean_squared_error: 0.1648
# Epoch 5/50
# 46/48 [===========================>..] - ETA: 0s - loss: 0.0376 - root_mean_squared_error: 0.1938INFO:tensorflow:Assets written to: Bering_model_LT2\assets
# 48/48 [==============================] - 8s 167ms/step - loss: 0.0381 - root_mean_squared_error: 0.1952 - val_loss: 0.0195 - val_root_mean_squared_error: 0.1396
# Epoch 6/50
# 46/48 [===========================>..] - ETA: 0s - loss: 0.0323 - root_mean_squared_error: 0.1797INFO:tensorflow:Assets written to: Bering_model_LT2\assets
# 48/48 [==============================] - 9s 191ms/step - loss: 0.0320 - root_mean_squared_error: 0.1788 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1331
# Epoch 7/50
# 47/48 [============================>.] - ETA: 0s - loss: 0.0307 - root_mean_squared_error: 0.1752INFO:tensorflow:Assets written to: Bering_model_LT2\assets
# 48/48 [==============================] - 10s 206ms/step - loss: 0.0305 - root_mean_squared_error: 0.1748 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1234
# Epoch 8/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0297 - root_mean_squared_error: 0.1724 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1319
# Epoch 9/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0293 - root_mean_squared_error: 0.1711INFO:tensorflow:Assets written to: Bering_model_LT2\assets
# 48/48 [==============================] - 9s 199ms/step - loss: 0.0293 - root_mean_squared_error: 0.1711 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1201
# Epoch 10/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0271 - root_mean_squared_error: 0.1646 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1202
# Epoch 11/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0256 - root_mean_squared_error: 0.1600 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1217
# Epoch 12/50
# 47/48 [============================>.] - ETA: 0s - loss: 0.0250 - root_mean_squared_error: 0.1581INFO:tensorflow:Assets written to: Bering_model_LT2\assets
# 48/48 [==============================] - 9s 198ms/step - loss: 0.0250 - root_mean_squared_error: 0.1581 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1184
# Epoch 13/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0233 - root_mean_squared_error: 0.1525 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1298
# Epoch 14/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0246 - root_mean_squared_error: 0.1567 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1202
# Epoch 15/50
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0233 - root_mean_squared_error: 0.1526 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1245
# Epoch 16/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0211 - root_mean_squared_error: 0.1453 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1247
# Epoch 17/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0224 - root_mean_squared_error: 0.1495 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1222
# Epoch 18/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0214 - root_mean_squared_error: 0.1463 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1277
# Epoch 19/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0216 - root_mean_squared_error: 0.1470 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1246
# Epoch 20/50
# 48/48 [==============================] - 1s 22ms/step - loss: 0.0208 - root_mean_squared_error: 0.1442 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1229
# Epoch 21/50
# 48/48 [==============================] - 1s 25ms/step - loss: 0.0210 - root_mean_squared_error: 0.1448 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1265
# Epoch 22/50
# 48/48 [==============================] - 1s 30ms/step - loss: 0.0199 - root_mean_squared_error: 0.1410 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1241
# Epoch 23/50
# 48/48 [==============================] - 1s 24ms/step - loss: 0.0203 - root_mean_squared_error: 0.1425 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1224
# Epoch 24/50
# 48/48 [==============================] - 1s 22ms/step - loss: 0.0186 - root_mean_squared_error: 0.1362 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1268
# Epoch 25/50
# 48/48 [==============================] - 1s 25ms/step - loss: 0.0185 - root_mean_squared_error: 0.1361 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1246
# Epoch 26/50
# 48/48 [==============================] - 1s 25ms/step - loss: 0.0189 - root_mean_squared_error: 0.1375 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1243
# Epoch 27/50
# 48/48 [==============================] - 1s 22ms/step - loss: 0.0176 - root_mean_squared_error: 0.1327 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1257
# Epoch 28/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0189 - root_mean_squared_error: 0.1375 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1243
# Epoch 29/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0182 - root_mean_squared_error: 0.1348 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1240
# Epoch 30/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0175 - root_mean_squared_error: 0.1323 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1266
# Epoch 31/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0179 - root_mean_squared_error: 0.1336 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1233
# Epoch 32/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0179 - root_mean_squared_error: 0.1337 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1250
# Epoch 33/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0169 - root_mean_squared_error: 0.1299 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1352
# Epoch 34/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0169 - root_mean_squared_error: 0.1300 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1240
# Epoch 35/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0167 - root_mean_squared_error: 0.1292 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1235
# Epoch 36/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0165 - root_mean_squared_error: 0.1286 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1244
# Epoch 37/50
# 48/48 [==============================] - 1s 29ms/step - loss: 0.0158 - root_mean_squared_error: 0.1255 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1230
# Epoch 38/50
# 48/48 [==============================] - 1s 22ms/step - loss: 0.0155 - root_mean_squared_error: 0.1245 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1278
# Epoch 39/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1252
# Epoch 40/50
# 48/48 [==============================] - 1s 24ms/step - loss: 0.0173 - root_mean_squared_error: 0.1314 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1224
# Epoch 41/50
# 48/48 [==============================] - 1s 22ms/step - loss: 0.0156 - root_mean_squared_error: 0.1251 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1266
# Epoch 42/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0159 - root_mean_squared_error: 0.1259 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1232
# Epoch 43/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0145 - root_mean_squared_error: 0.1205 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1219
# Epoch 44/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0155 - root_mean_squared_error: 0.1245 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1203
# Epoch 45/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1222
# Epoch 46/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0139 - root_mean_squared_error: 0.1180 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1211
# Epoch 47/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1219
# Epoch 48/50
# 48/48 [==============================] - 1s 22ms/step - loss: 0.0136 - root_mean_squared_error: 0.1168 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1201
# Epoch 49/50
# 48/48 [==============================] - 1s 20ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1213
# Epoch 50/50
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0133 - root_mean_squared_error: 0.1155 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1196

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 2.10255446434021 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bering_model_LT2/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 11ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.13725738596567938
# MAE : 0.09173470106251887

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       -16753.892578      32185.203
# 1       -14247.382812       2490.551
# 2         4496.115723       1707.377
# 3        34396.417969      11293.282
# 4        78207.617188      49957.406
# 5       135466.171875     151973.751
# 6       200901.812500     466524.938
# 7       273105.968750     708542.184
# 8       267454.500000     652598.000
# 9       139262.359375     414216.785
# 10       51170.601562     236263.303
# 11       -2734.003418      43422.368
# 12      -13228.093750       2161.744
# 13       10665.784180        944.181
# 14       54165.890625      13977.643
# 15      122062.023438      24795.001
# 16      214291.609375     168828.990
# 17      328007.468750     461098.498
# 18      448905.375000     591635.798
# 19      537350.250000     598360.298
# 20      468573.500000     531742.038
# 21      269946.187500     302131.004
# 22       91732.953125      57748.135
# 23       11613.028320       3054.962
# 24        5790.708496        442.539
# 25       44735.558594       8541.643
# 26      108576.695312     121335.125
# 27      196783.453125     360205.990
# 28      305594.437500     651717.220
# 29      431360.468750     779385.402
# 30      512107.531250     710314.085
# 31      451428.843750     578635.421
# 32      305838.156250     199031.792
# 33      150118.593750      43795.314
# 34       46219.953125       3015.211
# 35       38980.371094       1206.623
# 36      101323.757812       8506.979
# 37      200690.703125      41065.748
# 38      335921.750000     169363.165
# 39      505457.406250     531698.544
# 40      658414.750000     631496.345
# 41      692445.312500     612860.407
# 42      558782.562500     552903.799
# 43      335039.500000     317377.493
# 44      130284.664062      39601.476
# 45        5938.044434      16935.702
# 46       10086.361328       1305.744
# 47       53056.417969      12255.644

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 15/15 [==============================] - 0s 11ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
