# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Barents = pd.read_excel(filepath, sheet_name='Barents-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Barents)
fp.date_time(Barents)
# Out:
#           Extent       Date
# 0    1107873.946 1979-01-01
# 1    1211101.473 1979-02-01
# 2    1215128.770 1979-03-01
# 3    1233940.811 1979-04-01
# 4    1193061.566 1979-05-01
# ..           ...        ...
# 533   124025.343 2023-06-01
# 534    53107.426 2023-07-01
# 535    11242.827 2023-08-01
# 536     3272.024 2023-09-01
# 537    35079.225 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Barents['Extent'] = scaler.fit_transform(Barents['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 4
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Barents['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((523, 12, 1), (523,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Barents_model_LT4/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1752 - root_mean_squared_error: 0.4186INFO:tensorflow:Assets written to: Barents_model_LT4\assets
# 53/53 [==============================] - 39s 501ms/step - loss: 0.1757 - root_mean_squared_error: 0.4191 - val_loss: 0.0382 - val_root_mean_squared_error: 0.1954
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0688 - root_mean_squared_error: 0.2623INFO:tensorflow:Assets written to: Barents_model_LT4\assets
# 53/53 [==============================] - 30s 568ms/step - loss: 0.0688 - root_mean_squared_error: 0.2623 - val_loss: 0.0340 - val_root_mean_squared_error: 0.1845
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0503 - root_mean_squared_error: 0.2242INFO:tensorflow:Assets written to: Barents_model_LT4\assets
# 53/53 [==============================] - 25s 478ms/step - loss: 0.0503 - root_mean_squared_error: 0.2243 - val_loss: 0.0307 - val_root_mean_squared_error: 0.1752
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0380 - root_mean_squared_error: 0.1948INFO:tensorflow:Assets written to: Barents_model_LT4\assets
# 53/53 [==============================] - 26s 509ms/step - loss: 0.0380 - root_mean_squared_error: 0.1948 - val_loss: 0.0223 - val_root_mean_squared_error: 0.1492
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0312 - root_mean_squared_error: 0.1765INFO:tensorflow:Assets written to: Barents_model_LT4\assets
# 53/53 [==============================] - 26s 496ms/step - loss: 0.0312 - root_mean_squared_error: 0.1765 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1315
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0263 - root_mean_squared_error: 0.1620INFO:tensorflow:Assets written to: Barents_model_LT4\assets
# 53/53 [==============================] - 34s 651ms/step - loss: 0.0262 - root_mean_squared_error: 0.1620 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1222
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0222 - root_mean_squared_error: 0.1491INFO:tensorflow:Assets written to: Barents_model_LT4\assets
# 53/53 [==============================] - 32s 614ms/step - loss: 0.0222 - root_mean_squared_error: 0.1491 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1188
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0192 - root_mean_squared_error: 0.1385INFO:tensorflow:Assets written to: Barents_model_LT4\assets
# 53/53 [==============================] - 25s 485ms/step - loss: 0.0193 - root_mean_squared_error: 0.1389 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1181
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0201 - root_mean_squared_error: 0.1418INFO:tensorflow:Assets written to: Barents_model_LT4\assets
# 53/53 [==============================] - 26s 495ms/step - loss: 0.0201 - root_mean_squared_error: 0.1418 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1172
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0197 - root_mean_squared_error: 0.1405INFO:tensorflow:Assets written to: Barents_model_LT4\assets
# 53/53 [==============================] - 25s 472ms/step - loss: 0.0197 - root_mean_squared_error: 0.1405 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1155
# Epoch 11/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0180 - root_mean_squared_error: 0.1342 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1249
# Epoch 12/50
# 53/53 [==============================] - 3s 47ms/step - loss: 0.0180 - root_mean_squared_error: 0.1343 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1301
# Epoch 13/50
# 53/53 [==============================] - 2s 45ms/step - loss: 0.0183 - root_mean_squared_error: 0.1354 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1217
# Epoch 14/50
# 53/53 [==============================] - 2s 42ms/step - loss: 0.0181 - root_mean_squared_error: 0.1344 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1193
# Epoch 15/50
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0177 - root_mean_squared_error: 0.1329 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1326
# Epoch 16/50
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0169 - root_mean_squared_error: 0.1300 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1283
# Epoch 17/50
# 53/53 [==============================] - 2s 45ms/step - loss: 0.0170 - root_mean_squared_error: 0.1305 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1377
# Epoch 18/50
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0165 - root_mean_squared_error: 0.1286 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1219
# Epoch 19/50
# 53/53 [==============================] - 2s 43ms/step - loss: 0.0169 - root_mean_squared_error: 0.1301 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1230
# Epoch 20/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1230
# Epoch 21/50
# 53/53 [==============================] - 2s 41ms/step - loss: 0.0160 - root_mean_squared_error: 0.1267 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1207
# Epoch 22/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0157 - root_mean_squared_error: 0.1254INFO:tensorflow:Assets written to: Barents_model_LT4\assets
# 53/53 [==============================] - 20s 392ms/step - loss: 0.0159 - root_mean_squared_error: 0.1260 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1136
# Epoch 23/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0158 - root_mean_squared_error: 0.1256INFO:tensorflow:Assets written to: Barents_model_LT4\assets
# 53/53 [==============================] - 20s 388ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1131
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0151 - root_mean_squared_error: 0.1227INFO:tensorflow:Assets written to: Barents_model_LT4\assets
# 53/53 [==============================] - 19s 371ms/step - loss: 0.0151 - root_mean_squared_error: 0.1227 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1094
# Epoch 25/50
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0162 - root_mean_squared_error: 0.1273 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1165
# Epoch 26/50
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0147 - root_mean_squared_error: 0.1210 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1105
# Epoch 27/50
# 53/53 [==============================] - 2s 43ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1182
# Epoch 28/50
# 53/53 [==============================] - 2s 47ms/step - loss: 0.0152 - root_mean_squared_error: 0.1234 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1243
# Epoch 29/50
# 53/53 [==============================] - 2s 45ms/step - loss: 0.0153 - root_mean_squared_error: 0.1235 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1188
# Epoch 30/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1195
# Epoch 31/50
# 53/53 [==============================] - 3s 47ms/step - loss: 0.0146 - root_mean_squared_error: 0.1210 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1104
# Epoch 32/50
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0143 - root_mean_squared_error: 0.1196 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1138
# Epoch 33/50
# 53/53 [==============================] - 2s 46ms/step - loss: 0.0146 - root_mean_squared_error: 0.1208 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1167
# Epoch 34/50
# 53/53 [==============================] - 2s 38ms/step - loss: 0.0149 - root_mean_squared_error: 0.1222 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1138
# Epoch 35/50
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1293
# Epoch 36/50
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1142
# Epoch 37/50
# 53/53 [==============================] - 2s 40ms/step - loss: 0.0140 - root_mean_squared_error: 0.1184 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1260
# Epoch 38/50
# 53/53 [==============================] - 2s 41ms/step - loss: 0.0140 - root_mean_squared_error: 0.1183 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1171
# Epoch 39/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0139 - root_mean_squared_error: 0.1179INFO:tensorflow:Assets written to: Barents_model_LT4\assets
# 53/53 [==============================] - 22s 414ms/step - loss: 0.0139 - root_mean_squared_error: 0.1179 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1068
# Epoch 40/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0145 - root_mean_squared_error: 0.1204 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1086
# Epoch 41/50
# 53/53 [==============================] - 3s 49ms/step - loss: 0.0146 - root_mean_squared_error: 0.1209 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1205
# Epoch 42/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1110
# Epoch 43/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0141 - root_mean_squared_error: 0.1189 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1313
# Epoch 44/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0134 - root_mean_squared_error: 0.1159INFO:tensorflow:Assets written to: Barents_model_LT4\assets
# 53/53 [==============================] - 21s 398ms/step - loss: 0.0135 - root_mean_squared_error: 0.1160 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1059
# Epoch 45/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0139 - root_mean_squared_error: 0.1178INFO:tensorflow:Assets written to: Barents_model_LT4\assets
# 53/53 [==============================] - 21s 410ms/step - loss: 0.0139 - root_mean_squared_error: 0.1179 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1055
# Epoch 46/50
# 53/53 [==============================] - 3s 47ms/step - loss: 0.0140 - root_mean_squared_error: 0.1183 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1113
# Epoch 47/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0132 - root_mean_squared_error: 0.1149 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1089
# Epoch 48/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0132 - root_mean_squared_error: 0.1149 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1103
# Epoch 49/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0137 - root_mean_squared_error: 0.1170 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1099
# Epoch 50/50
# 53/53 [==============================] - 2s 46ms/step - loss: 0.0134 - root_mean_squared_error: 0.1156 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1082

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 8.271660125255584 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Barents_model_LT4/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 18ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.09818113706833463
# MAE : 0.07904255044389327

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       -51043.000000      44787.893
# 1       -54763.746094      14909.156
# 2        13660.449219      54595.378
# 3       140709.093750     242829.930
# 4       298767.531250     406860.687
# 5       442394.750000     605897.837
# 6       545948.562500     654073.790
# 7       589233.250000     701143.910
# 8       579126.062500     657891.340
# 9       467005.718750     432215.421
# 10      264263.250000     201834.787
# 11       46637.496094      55041.511
# 12      -41157.769531       5387.468
# 13       -9199.135742       1576.813
# 14      100905.234375      21681.895
# 15      265352.406250      37772.681
# 16      431728.625000     239568.531
# 17      564542.187500     427703.330
# 18      648634.500000     753043.012
# 19      675678.125000     764554.603
# 20      641558.125000     563799.961
# 21      528217.625000     444109.886
# 22      296112.093750     189669.492
# 23       56917.980469      63664.521
# 24      -54025.406250       5984.539
# 25      -47097.085938       1192.062
# 26       41512.089844      25987.740
# 27      183635.296875     227374.130
# 28      345865.625000     498316.637
# 29      483286.031250     666292.874
# 30      581375.625000     673348.837
# 31      625159.937500     635756.948
# 32      594075.250000     673503.693
# 33      463920.687500     550922.786
# 34      218784.796875     116554.569
# 35       18394.994141      12012.356
# 36      -49193.386719       5446.433
# 37      -14683.180664       2183.701
# 38      115039.632812      31883.576
# 39      289539.187500      98802.296
# 40      454094.062500     224779.107
# 41      586485.000000     287476.263
# 42      670641.437500     376683.928
# 43      693992.250000     571055.966
# 44      647862.937500     581039.946
# 45      542087.562500     376525.530
# 46      360854.343750     124025.343
# 47      142397.468750      53107.426
# 48      -20276.888672      11242.827
# 49      -49435.355469       3272.024
# 50       25684.640625      35079.225

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 21ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
