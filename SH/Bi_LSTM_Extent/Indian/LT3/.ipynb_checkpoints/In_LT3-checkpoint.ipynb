# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Indian_Extent = pd.read_excel(filepath, sheet_name='Indian-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Indian_Extent)
fp.date_time(Indian_Extent)
# Out:
#           Extent       Date
# 0     376618.799 1979-01-01
# 1     211788.726 1979-02-01
# 2     262868.141 1979-03-01
# 3     698377.304 1979-04-01
# 4    1252407.727 1979-05-01
# ..           ...        ...
# 533  1520776.003 2023-06-01
# 534  2076164.165 2023-07-01
# 535  2731799.027 2023-08-01
# 536  3179384.692 2023-09-01
# 537  3301335.210 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Indian_Extent['Extent'] = scaler.fit_transform(Indian_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 3
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Indian_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((524, 12, 1), (524,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Indian_model_LT3/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2404 - root_mean_squared_error: 0.4903INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 26s 327ms/step - loss: 0.2404 - root_mean_squared_error: 0.4903 - val_loss: 0.1385 - val_root_mean_squared_error: 0.3721
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1186 - root_mean_squared_error: 0.3443INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 16s 315ms/step - loss: 0.1182 - root_mean_squared_error: 0.3438 - val_loss: 0.0708 - val_root_mean_squared_error: 0.2662
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0688 - root_mean_squared_error: 0.2624INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 16s 305ms/step - loss: 0.0688 - root_mean_squared_error: 0.2624 - val_loss: 0.0451 - val_root_mean_squared_error: 0.2125
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0322 - root_mean_squared_error: 0.1795INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 17s 319ms/step - loss: 0.0322 - root_mean_squared_error: 0.1795 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1388
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0170 - root_mean_squared_error: 0.1305INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 18s 340ms/step - loss: 0.0171 - root_mean_squared_error: 0.1307 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1115
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0154 - root_mean_squared_error: 0.1241INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 18s 340ms/step - loss: 0.0154 - root_mean_squared_error: 0.1241 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1112
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0114 - root_mean_squared_error: 0.1070INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 17s 326ms/step - loss: 0.0114 - root_mean_squared_error: 0.1070 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1035
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0111 - root_mean_squared_error: 0.1055INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 18s 338ms/step - loss: 0.0111 - root_mean_squared_error: 0.1052 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1018
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0107 - root_mean_squared_error: 0.1037INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 17s 333ms/step - loss: 0.0107 - root_mean_squared_error: 0.1037 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0862
# Epoch 10/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0099 - root_mean_squared_error: 0.0995 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0093 - root_mean_squared_error: 0.0966INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 19s 361ms/step - loss: 0.0093 - root_mean_squared_error: 0.0966 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0824
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0079 - root_mean_squared_error: 0.0891INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 18s 353ms/step - loss: 0.0079 - root_mean_squared_error: 0.0891 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0823
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0079 - root_mean_squared_error: 0.0887INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 18s 347ms/step - loss: 0.0079 - root_mean_squared_error: 0.0887 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0770
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0075 - root_mean_squared_error: 0.0869INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 19s 362ms/step - loss: 0.0075 - root_mean_squared_error: 0.0869 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0739
# Epoch 15/50
# 53/53 [==============================] - 3s 49ms/step - loss: 0.0074 - root_mean_squared_error: 0.0858 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0811
# Epoch 16/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0073 - root_mean_squared_error: 0.0852INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 23s 442ms/step - loss: 0.0072 - root_mean_squared_error: 0.0849 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0717
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0072 - root_mean_squared_error: 0.0850INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 26s 507ms/step - loss: 0.0072 - root_mean_squared_error: 0.0850 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0693
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0065 - root_mean_squared_error: 0.0805INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 27s 519ms/step - loss: 0.0065 - root_mean_squared_error: 0.0805 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0689
# Epoch 19/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0064 - root_mean_squared_error: 0.0802 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0779
# Epoch 20/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0069 - root_mean_squared_error: 0.0831 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0731
# Epoch 21/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0062 - root_mean_squared_error: 0.0787 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0751
# Epoch 22/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0059 - root_mean_squared_error: 0.0768 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0757
# Epoch 23/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0064 - root_mean_squared_error: 0.0797INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 26s 498ms/step - loss: 0.0064 - root_mean_squared_error: 0.0797 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0619
# Epoch 24/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0055 - root_mean_squared_error: 0.0742 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0695
# Epoch 25/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0056 - root_mean_squared_error: 0.0746 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0634
# Epoch 26/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0062 - root_mean_squared_error: 0.0784 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0623
# Epoch 27/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0060 - root_mean_squared_error: 0.0774INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 26s 502ms/step - loss: 0.0060 - root_mean_squared_error: 0.0774 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0607
# Epoch 28/50
# 53/53 [==============================] - 4s 74ms/step - loss: 0.0057 - root_mean_squared_error: 0.0757 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0608
# Epoch 29/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0054 - root_mean_squared_error: 0.0735INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 27s 512ms/step - loss: 0.0054 - root_mean_squared_error: 0.0735 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0562
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0051 - root_mean_squared_error: 0.0715INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 27s 509ms/step - loss: 0.0051 - root_mean_squared_error: 0.0715 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0556
# Epoch 31/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0053 - root_mean_squared_error: 0.0725 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0621
# Epoch 32/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0047 - root_mean_squared_error: 0.0686 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0645
# Epoch 33/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0051 - root_mean_squared_error: 0.0711 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0600
# Epoch 34/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0052 - root_mean_squared_error: 0.0719 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0641
# Epoch 35/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0050 - root_mean_squared_error: 0.0706 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0618
# Epoch 36/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0058 - root_mean_squared_error: 0.0759 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0647
# Epoch 37/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0051 - root_mean_squared_error: 0.0715INFO:tensorflow:Assets written to: Indian_model_LT3\assets
# 53/53 [==============================] - 26s 501ms/step - loss: 0.0051 - root_mean_squared_error: 0.0715 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0522
# Epoch 38/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0049 - root_mean_squared_error: 0.0701 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0607
# Epoch 39/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0048 - root_mean_squared_error: 0.0694 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0561
# Epoch 40/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0049 - root_mean_squared_error: 0.0698 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0628
# Epoch 41/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0048 - root_mean_squared_error: 0.0692 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0547
# Epoch 42/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0046 - root_mean_squared_error: 0.0675 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0546
# Epoch 43/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0045 - root_mean_squared_error: 0.0670 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0690
# Epoch 44/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0044 - root_mean_squared_error: 0.0660 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0574
# Epoch 45/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0045 - root_mean_squared_error: 0.0670 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0557
# Epoch 46/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0533
# Epoch 47/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0042 - root_mean_squared_error: 0.0648 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0621
# Epoch 48/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0040 - root_mean_squared_error: 0.0632 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0545
# Epoch 49/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0053 - root_mean_squared_error: 0.0728 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0721
# Epoch 50/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0046 - root_mean_squared_error: 0.0681 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0539

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 9.088269901275634 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Indian_model_LT3/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 26ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.06501222933507493
# MAE : 0.053941141167669876

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        2.558337e+06    2347500.604
# 1        3.139358e+06    3151724.833
# 2        3.500356e+06    3719188.531
# 3        3.522280e+06    3636501.241
# 4        3.083562e+06    2526913.818
# 5        1.566610e+06    1128752.378
# 6        3.193422e+05     522831.371
# 7        1.325785e+05     346601.304
# 8        2.324006e+05     444914.605
# 9        5.382952e+05     827036.916
# 10       1.048303e+06    1142021.216
# 11       1.724762e+06    1885693.654
# 12       2.382201e+06    2542569.663
# 13       2.934638e+06    3107373.845
# 14       3.332556e+06    3488175.444
# 15       3.391011e+06    3746306.528
# 16       2.808806e+06    2942322.822
# 17       1.087362e+06    1507212.955
# 18       2.342970e+05     648507.437
# 19       1.323151e+05     352564.010
# 20       2.413002e+05     453587.503
# 21       5.526406e+05     841043.793
# 22       1.075560e+06    1433155.266
# 23       1.746718e+06    2163687.646
# 24       2.399696e+06    2848863.133
# 25       2.973623e+06    3420877.229
# 26       3.315660e+06    3752886.938
# 27       3.335552e+06    3778951.818
# 28       2.807018e+06    2892177.223
# 29       1.246207e+06    1467610.428
# 30       3.110867e+05     377930.941
# 31       1.757948e+05     146440.376
# 32       2.963826e+05     244356.473
# 33       6.669704e+05     612217.566
# 34       1.262805e+06    1261627.075
# 35       2.005489e+06    1720565.225
# 36       2.729333e+06    2564005.541
# 37       3.294520e+06    2983773.529
# 38       3.616026e+06    3372645.223
# 39       3.607077e+06    3589687.043
# 40       3.076770e+06    2669385.189
# 41       1.501407e+06    1095398.946
# 42       3.235669e+05     319828.826
# 43       1.394998e+05     162541.182
# 44       2.361276e+05     179564.232
# 45       5.713084e+05     593196.107
# 46       1.125980e+06    1053508.835
# 47       1.840708e+06    1520776.003
# 48       2.530310e+06    2076164.165
# 49       3.052852e+06    2731799.027
# 50       3.403326e+06    3179384.692
# 51       3.368386e+06    3301335.210

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 30ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
