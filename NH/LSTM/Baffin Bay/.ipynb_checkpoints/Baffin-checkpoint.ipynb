# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Baffin = pd.read_excel(filepath, sheet_name='Baffin-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Baffin)
fp.date_time(Baffin)
# Out:
#           Extent       Date
# 0    1090625.815 1979-01-01
# 1    1157634.866 1979-02-01
# 2    1299583.477 1979-03-01
# 3    1137194.680 1979-04-01
# 4     983083.453 1979-05-01
# ..           ...        ...
# 533   781460.891 2023-06-01
# 534   331845.048 2023-07-01
# 535    99334.625 2023-08-01
# 536    49359.723 2023-09-01
# 537    85693.282 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Baffin['Extent'] = scaler.fit_transform(Baffin['Extent'].values.reshape(-1, 1))

# %%
extent = Baffin['Extent']
W_S=12
X,y = fp.df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((526, 12, 1), (526,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Baffin_model/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.2212 - root_mean_squared_error: 0.4704INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 17s 215ms/step - loss: 0.2202 - root_mean_squared_error: 0.4693 - val_loss: 0.1804 - val_root_mean_squared_error: 0.4247
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1172 - root_mean_squared_error: 0.3423INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 10s 194ms/step - loss: 0.1183 - root_mean_squared_error: 0.3439 - val_loss: 0.0714 - val_root_mean_squared_error: 0.2671
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0736 - root_mean_squared_error: 0.2713INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 9s 164ms/step - loss: 0.0733 - root_mean_squared_error: 0.2708 - val_loss: 0.0663 - val_root_mean_squared_error: 0.2574
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0689 - root_mean_squared_error: 0.2625INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 9s 179ms/step - loss: 0.0694 - root_mean_squared_error: 0.2635 - val_loss: 0.0595 - val_root_mean_squared_error: 0.2438
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0604 - root_mean_squared_error: 0.2458INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 11s 203ms/step - loss: 0.0604 - root_mean_squared_error: 0.2458 - val_loss: 0.0516 - val_root_mean_squared_error: 0.2273
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0511 - root_mean_squared_error: 0.2260INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 10s 194ms/step - loss: 0.0511 - root_mean_squared_error: 0.2260 - val_loss: 0.0393 - val_root_mean_squared_error: 0.1981
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0427 - root_mean_squared_error: 0.2067INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 11s 202ms/step - loss: 0.0427 - root_mean_squared_error: 0.2067 - val_loss: 0.0275 - val_root_mean_squared_error: 0.1659
# Epoch 8/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0322 - root_mean_squared_error: 0.1794INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 10s 196ms/step - loss: 0.0320 - root_mean_squared_error: 0.1788 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1315
# Epoch 9/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0244 - root_mean_squared_error: 0.1561INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 11s 202ms/step - loss: 0.0241 - root_mean_squared_error: 0.1552 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1080
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0188 - root_mean_squared_error: 0.1369INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 10s 198ms/step - loss: 0.0188 - root_mean_squared_error: 0.1369 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0164 - root_mean_squared_error: 0.1282INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 11s 202ms/step - loss: 0.0165 - root_mean_squared_error: 0.1285 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0845
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0141 - root_mean_squared_error: 0.1188INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 10s 198ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0660
# Epoch 13/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0117 - root_mean_squared_error: 0.1082 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0701
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0126 - root_mean_squared_error: 0.1123INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 10s 190ms/step - loss: 0.0126 - root_mean_squared_error: 0.1123 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0638
# Epoch 15/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0646
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0119 - root_mean_squared_error: 0.1093INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 10s 197ms/step - loss: 0.0119 - root_mean_squared_error: 0.1093 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0578
# Epoch 17/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0111 - root_mean_squared_error: 0.1052INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 11s 203ms/step - loss: 0.0109 - root_mean_squared_error: 0.1045 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0567
# Epoch 18/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0091 - root_mean_squared_error: 0.0953 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0669
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0105 - root_mean_squared_error: 0.1024INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 10s 188ms/step - loss: 0.0105 - root_mean_squared_error: 0.1024 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0556
# Epoch 20/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0097 - root_mean_squared_error: 0.0987 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609
# Epoch 21/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0092 - root_mean_squared_error: 0.0957 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0776
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0092 - root_mean_squared_error: 0.0960INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0092 - root_mean_squared_error: 0.0960 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0547
# Epoch 23/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0087 - root_mean_squared_error: 0.0932 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0568
# Epoch 24/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0084 - root_mean_squared_error: 0.0918INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 10s 195ms/step - loss: 0.0084 - root_mean_squared_error: 0.0916 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0529
# Epoch 25/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0092 - root_mean_squared_error: 0.0958 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0550
# Epoch 26/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0090 - root_mean_squared_error: 0.0950 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0660
# Epoch 27/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0094 - root_mean_squared_error: 0.0971 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0672
# Epoch 28/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0086 - root_mean_squared_error: 0.0928INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 10s 187ms/step - loss: 0.0086 - root_mean_squared_error: 0.0928 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0528
# Epoch 29/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0088 - root_mean_squared_error: 0.0937 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0542
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0086 - root_mean_squared_error: 0.0925INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 10s 197ms/step - loss: 0.0086 - root_mean_squared_error: 0.0925 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0507
# Epoch 31/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0081 - root_mean_squared_error: 0.0900 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0517
# Epoch 32/50
# 53/53 [==============================] - 1s 27ms/step - loss: 0.0073 - root_mean_squared_error: 0.0857 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0520
# Epoch 33/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0081 - root_mean_squared_error: 0.0897 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0547
# Epoch 34/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0075 - root_mean_squared_error: 0.0867 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0524
# Epoch 35/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0080 - root_mean_squared_error: 0.0895 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0507
# Epoch 36/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0083 - root_mean_squared_error: 0.0912 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0580
# Epoch 37/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0086 - root_mean_squared_error: 0.0929 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0511
# Epoch 38/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0076 - root_mean_squared_error: 0.0871 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0638
# Epoch 39/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0083 - root_mean_squared_error: 0.0909 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0605
# Epoch 40/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0081 - root_mean_squared_error: 0.0902 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613
# Epoch 41/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0085 - root_mean_squared_error: 0.0924 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0569
# Epoch 42/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0077 - root_mean_squared_error: 0.0878 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0519
# Epoch 43/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0079 - root_mean_squared_error: 0.0890 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0522
# Epoch 44/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0079 - root_mean_squared_error: 0.0888 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0560
# Epoch 45/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0075 - root_mean_squared_error: 0.0863 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0582
# Epoch 46/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0069 - root_mean_squared_error: 0.0832 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0548
# Epoch 47/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0077 - root_mean_squared_error: 0.0879 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0519
# Epoch 48/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0067 - root_mean_squared_error: 0.0819 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0540
# Epoch 49/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0068 - root_mean_squared_error: 0.0825INFO:tensorflow:Assets written to: Baffin_model\assets
# 53/53 [==============================] - 10s 192ms/step - loss: 0.0068 - root_mean_squared_error: 0.0825 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0494
# Epoch 50/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0074 - root_mean_squared_error: 0.0860 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0569

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 4.46855575243632 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Baffin_model/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 14ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.0661519124361447
# MAE : 0.050713991413825044

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.095629e+06     936648.998
# 1        8.019461e+05     587385.424
# 2        3.217905e+05     171258.094
# 3        6.699320e+04      46930.952
# 4        7.174644e+04      27600.624
# 5        2.534755e+05      61057.940
# 6        6.215887e+05     291275.949
# 7        8.634459e+05     678576.504
# 8        1.072112e+06     974461.347
# 9        1.203889e+06    1181121.087
# 10       1.219647e+06    1236299.254
# 11       1.147772e+06    1036981.003
# 12       1.005307e+06     847489.150
# 13       6.385249e+05     619129.338
# 14       2.252164e+05     195688.491
# 15       9.761505e+04      36670.811
# 16       7.249211e+04      31777.310
# 17       1.372389e+05      82762.022
# 18       3.873687e+05     400043.823
# 19       7.547829e+05     733089.555
# 20       1.015146e+06     917362.266
# 21       1.192138e+06    1040584.040
# 22       1.192885e+06    1147997.675
# 23       1.069298e+06    1074255.327
# 24       9.373086e+05     875527.315
# 25       6.689142e+05     629820.756
# 26       2.471478e+05     204308.900
# 27       1.077304e+05      45059.062
# 28       8.286635e+04      33770.277
# 29       1.441985e+05      64135.631
# 30       4.268848e+05     400581.715
# 31       7.273316e+05     698631.451
# 32       9.220042e+05     973313.225
# 33       1.081850e+06    1335339.087
# 34       1.162786e+06    1429096.704
# 35       1.098582e+06    1206542.314
# 36       9.611652e+05    1079292.433
# 37       6.769302e+05     788101.638
# 38       2.193099e+05     397326.270
# 39       5.509944e+04      97802.348
# 40       2.749486e+04      62212.219
# 41       1.060037e+05     154051.600
# 42       4.045750e+05     610663.893
# 43       7.645612e+05     756679.164
# 44       1.061514e+06     962270.215
# 45       1.304389e+06    1235154.518
# 46       1.316502e+06    1161744.519
# 47       1.214493e+06    1136918.669
# 48       1.086496e+06     995852.026
# 49       8.309553e+05     781460.891
# 50       3.799227e+05     331845.048
# 51       9.761944e+04      99334.625
# 52       5.966894e+04      49359.723
# 53       1.879083e+05      85693.282

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 12ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
