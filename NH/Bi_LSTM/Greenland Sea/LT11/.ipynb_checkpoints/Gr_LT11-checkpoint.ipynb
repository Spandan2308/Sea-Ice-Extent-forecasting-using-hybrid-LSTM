# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Greenland = pd.read_excel(filepath, sheet_name='Greenland-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Greenland)
fp.date_time(Greenland)
# Out:
#           Extent       Date
# 0    1076123.146 1979-01-01
# 1    1099248.063 1979-02-01
# 2    1036964.901 1979-03-01
# 3     958927.937 1979-04-01
# 4     823812.694 1979-05-01
# ..           ...        ...
# 533   721350.515 2023-06-01
# 534   459033.164 2023-07-01
# 535   282045.909 2023-08-01
# 536   270397.608 2023-09-01
# 537   449910.973 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Greenland['Extent'] = scaler.fit_transform(Greenland['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 11
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Greenland['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((516, 12, 1), (516,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Greenland_LT11/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.2673 - root_mean_squared_error: 0.5170INFO:tensorflow:Assets written to: Greenland_LT11\assets
# 53/53 [==============================] - 33s 426ms/step - loss: 0.2678 - root_mean_squared_error: 0.5175 - val_loss: 0.0974 - val_root_mean_squared_error: 0.3121
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0809 - root_mean_squared_error: 0.2845INFO:tensorflow:Assets written to: Greenland_LT11\assets
# 53/53 [==============================] - 22s 428ms/step - loss: 0.0805 - root_mean_squared_error: 0.2837 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1700
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0413 - root_mean_squared_error: 0.2033INFO:tensorflow:Assets written to: Greenland_LT11\assets
# 53/53 [==============================] - 31s 599ms/step - loss: 0.0411 - root_mean_squared_error: 0.2029 - val_loss: 0.0267 - val_root_mean_squared_error: 0.1634
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0351 - root_mean_squared_error: 0.1875INFO:tensorflow:Assets written to: Greenland_LT11\assets
# 53/53 [==============================] - 31s 600ms/step - loss: 0.0351 - root_mean_squared_error: 0.1875 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1585
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0304 - root_mean_squared_error: 0.1743INFO:tensorflow:Assets written to: Greenland_LT11\assets
# 53/53 [==============================] - 31s 587ms/step - loss: 0.0305 - root_mean_squared_error: 0.1747 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1456
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0255 - root_mean_squared_error: 0.1596INFO:tensorflow:Assets written to: Greenland_LT11\assets
# 53/53 [==============================] - 31s 599ms/step - loss: 0.0254 - root_mean_squared_error: 0.1595 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1427
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0204 - root_mean_squared_error: 0.1428INFO:tensorflow:Assets written to: Greenland_LT11\assets
# 53/53 [==============================] - 31s 600ms/step - loss: 0.0204 - root_mean_squared_error: 0.1428 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1320
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0195 - root_mean_squared_error: 0.1396INFO:tensorflow:Assets written to: Greenland_LT11\assets
# 53/53 [==============================] - 33s 632ms/step - loss: 0.0193 - root_mean_squared_error: 0.1391 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 9/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0166 - root_mean_squared_error: 0.1290INFO:tensorflow:Assets written to: Greenland_LT11\assets
# 53/53 [==============================] - 32s 615ms/step - loss: 0.0166 - root_mean_squared_error: 0.1288 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1192
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0151 - root_mean_squared_error: 0.1228INFO:tensorflow:Assets written to: Greenland_LT11\assets
# 53/53 [==============================] - 31s 604ms/step - loss: 0.0151 - root_mean_squared_error: 0.1228 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1182
# Epoch 11/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1251
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0149 - root_mean_squared_error: 0.1222INFO:tensorflow:Assets written to: Greenland_LT11\assets
# 53/53 [==============================] - 32s 612ms/step - loss: 0.0152 - root_mean_squared_error: 0.1233 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1138
# Epoch 13/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0136 - root_mean_squared_error: 0.1168 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1252
# Epoch 14/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0122 - root_mean_squared_error: 0.1104INFO:tensorflow:Assets written to: Greenland_LT11\assets
# 53/53 [==============================] - 32s 623ms/step - loss: 0.0125 - root_mean_squared_error: 0.1120 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1088
# Epoch 15/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0125 - root_mean_squared_error: 0.1116 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1128
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0134 - root_mean_squared_error: 0.1158INFO:tensorflow:Assets written to: Greenland_LT11\assets
# 53/53 [==============================] - 45s 864ms/step - loss: 0.0134 - root_mean_squared_error: 0.1158 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1056
# Epoch 17/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0120 - root_mean_squared_error: 0.1096 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1100
# Epoch 18/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0112 - root_mean_squared_error: 0.1058 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1180
# Epoch 19/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0113 - root_mean_squared_error: 0.1062 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1218
# Epoch 20/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1067
# Epoch 21/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0113 - root_mean_squared_error: 0.1064 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1200
# Epoch 22/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0105 - root_mean_squared_error: 0.1023 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1345
# Epoch 23/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0113 - root_mean_squared_error: 0.1062INFO:tensorflow:Assets written to: Greenland_LT11\assets
# 53/53 [==============================] - 37s 711ms/step - loss: 0.0113 - root_mean_squared_error: 0.1061 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1020
# Epoch 24/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1142
# Epoch 25/50
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0117 - root_mean_squared_error: 0.1081 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1157
# Epoch 26/50
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0105 - root_mean_squared_error: 0.1024 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1244
# Epoch 27/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 28/50
# 53/53 [==============================] - 3s 49ms/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1097
# Epoch 29/50
# 53/53 [==============================] - 3s 47ms/step - loss: 0.0100 - root_mean_squared_error: 0.1001 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1080
# Epoch 30/50
# 53/53 [==============================] - 2s 46ms/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1097
# Epoch 31/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0120 - root_mean_squared_error: 0.1097 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1022
# Epoch 32/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0107 - root_mean_squared_error: 0.1036 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1182
# Epoch 33/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0112 - root_mean_squared_error: 0.1060 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1185
# Epoch 34/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.0104 - root_mean_squared_error: 0.1022 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1130
# Epoch 35/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0105 - root_mean_squared_error: 0.1022 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1295
# Epoch 36/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0107 - root_mean_squared_error: 0.1034 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1264
# Epoch 37/50
# 53/53 [==============================] - 3s 49ms/step - loss: 0.0107 - root_mean_squared_error: 0.1036 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1115
# Epoch 38/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1209
# Epoch 39/50
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0111 - root_mean_squared_error: 0.1055 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1141
# Epoch 40/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0100 - root_mean_squared_error: 0.0998 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1200
# Epoch 41/50
# 53/53 [==============================] - 3s 49ms/step - loss: 0.0097 - root_mean_squared_error: 0.0983 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1107
# Epoch 42/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0100 - root_mean_squared_error: 0.1000 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1065
# Epoch 43/50
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0099 - root_mean_squared_error: 0.0993 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1051
# Epoch 44/50
# 53/53 [==============================] - 2s 47ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1121
# Epoch 45/50
# 53/53 [==============================] - 2s 47ms/step - loss: 0.0095 - root_mean_squared_error: 0.0972 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1099
# Epoch 46/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0097 - root_mean_squared_error: 0.0986 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1217
# Epoch 47/50
# 53/53 [==============================] - 3s 47ms/step - loss: 0.0097 - root_mean_squared_error: 0.0983 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133
# Epoch 48/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0096 - root_mean_squared_error: 0.0977 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1167
# Epoch 49/50
# 53/53 [==============================] - 2s 43ms/step - loss: 0.0097 - root_mean_squared_error: 0.0986 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 50/50
# 53/53 [==============================] - 2s 42ms/step - loss: 0.0098 - root_mean_squared_error: 0.0992 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1062

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 9.25263334910075 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Greenland_LT11/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 23ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.08252549811348031
# MAE : 0.06120677214631813

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        701970.93750     734946.437
# 1        700790.68750     777596.225
# 2        663220.75000     687087.673
# 3        572561.56250     622337.816
# 4        452423.28125     467232.074
# 5        347200.90625     297495.641
# 6        328662.71875     268909.854
# 7        400686.15625     408072.791
# 8        486807.62500     552314.148
# 9        537125.12500     651062.408
# 10       592693.12500     695022.674
# 11       662741.56250     670974.305
# 12       722952.06250     710035.543
# 13       723405.50000     699672.538
# 14       676179.12500     730897.021
# 15       581184.87500     588598.988
# 16       457135.03125     281754.041
# 17       352734.53125     117830.266
# 18       328546.81250      81838.250
# 19       398433.65625     291418.462
# 20       505726.59375     452417.079
# 21       597641.25000     576361.148
# 22       644959.87500     676218.054
# 23       675604.62500     698410.066
# 24       683699.18750     696094.179
# 25       694325.93750     751102.742
# 26       640536.00000     765802.952
# 27       511041.62500     597649.311
# 28       384024.65625     376029.266
# 29       294915.87500     278536.574
# 30       276545.56250     285351.521
# 31       329955.28125     365256.138
# 32       435178.37500     488293.212
# 33       558986.12500     635073.900
# 34       653850.25000     684651.888
# 35       703142.93750     698053.275
# 36       736741.50000     846211.943
# 37       756303.43750     831596.370
# 38       704321.56250     834849.724
# 39       581848.93750     721350.515
# 40       450791.37500     459033.164
# 41       346783.90625     282045.909
# 42       311413.78125     270397.608
# 43       360181.59375     449910.973

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 35ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
