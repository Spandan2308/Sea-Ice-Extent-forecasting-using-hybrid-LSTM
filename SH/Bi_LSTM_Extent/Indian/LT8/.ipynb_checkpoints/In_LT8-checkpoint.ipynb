# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Indian_Extent = pd.read_excel(filepath, sheet_name='Indian-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Indian_Extent)
fp.date_time(Indian_Extent)
# Out:
#           Extent       Date
# 0     376618.799 1979-01-01
# 1     211788.726 1979-02-01
# 2     262868.141 1979-03-01
# 3     698377.304 1979-04-01
# 4    1252407.727 1979-05-01
# ..           ...        ...
# 533  1520776.003 2023-06-01
# 534  2076164.165 2023-07-01
# 535  2731799.027 2023-08-01
# 536  3179384.692 2023-09-01
# 537  3301335.210 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Indian_Extent['Extent'] = scaler.fit_transform(Indian_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 8
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Indian_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((519, 12, 1), (519,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Indian_model_LT8/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2339 - root_mean_squared_error: 0.4836INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 38s 508ms/step - loss: 0.2339 - root_mean_squared_error: 0.4836 - val_loss: 0.1466 - val_root_mean_squared_error: 0.3828
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1055 - root_mean_squared_error: 0.3249INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 25s 484ms/step - loss: 0.1055 - root_mean_squared_error: 0.3249 - val_loss: 0.0770 - val_root_mean_squared_error: 0.2775
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0780 - root_mean_squared_error: 0.2793INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 26s 492ms/step - loss: 0.0782 - root_mean_squared_error: 0.2797 - val_loss: 0.0621 - val_root_mean_squared_error: 0.2491
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0618 - root_mean_squared_error: 0.2485INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 25s 487ms/step - loss: 0.0615 - root_mean_squared_error: 0.2480 - val_loss: 0.0471 - val_root_mean_squared_error: 0.2170
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0438 - root_mean_squared_error: 0.2093INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 25s 480ms/step - loss: 0.0438 - root_mean_squared_error: 0.2093 - val_loss: 0.0290 - val_root_mean_squared_error: 0.1704
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0270 - root_mean_squared_error: 0.1642INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 27s 511ms/step - loss: 0.0270 - root_mean_squared_error: 0.1642 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1338
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0190 - root_mean_squared_error: 0.1378INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 26s 499ms/step - loss: 0.0190 - root_mean_squared_error: 0.1378 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1205
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0168 - root_mean_squared_error: 0.1295INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 27s 516ms/step - loss: 0.0168 - root_mean_squared_error: 0.1295 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1109
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0136 - root_mean_squared_error: 0.1168INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 26s 506ms/step - loss: 0.0136 - root_mean_squared_error: 0.1168 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1008
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0143 - root_mean_squared_error: 0.1195INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 27s 511ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0968
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0115 - root_mean_squared_error: 0.1070INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 26s 502ms/step - loss: 0.0115 - root_mean_squared_error: 0.1070 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0924
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0090 - root_mean_squared_error: 0.0951INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 27s 517ms/step - loss: 0.0090 - root_mean_squared_error: 0.0951 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0903
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0111 - root_mean_squared_error: 0.1055INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 26s 498ms/step - loss: 0.0111 - root_mean_squared_error: 0.1055 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0838
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0094 - root_mean_squared_error: 0.0972INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 27s 521ms/step - loss: 0.0094 - root_mean_squared_error: 0.0972 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0737
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0088 - root_mean_squared_error: 0.0938INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 26s 505ms/step - loss: 0.0088 - root_mean_squared_error: 0.0938 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0731
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0085 - root_mean_squared_error: 0.0920INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 27s 511ms/step - loss: 0.0085 - root_mean_squared_error: 0.0920 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0692
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0072 - root_mean_squared_error: 0.0851INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 26s 496ms/step - loss: 0.0072 - root_mean_squared_error: 0.0851 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0668
# Epoch 18/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0075 - root_mean_squared_error: 0.0867 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 19/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0078 - root_mean_squared_error: 0.0884 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0681
# Epoch 20/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0078 - root_mean_squared_error: 0.0881 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0732
# Epoch 21/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0074 - root_mean_squared_error: 0.0858 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0740
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0078 - root_mean_squared_error: 0.0881INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 26s 501ms/step - loss: 0.0078 - root_mean_squared_error: 0.0881 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0644
# Epoch 23/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0060 - root_mean_squared_error: 0.0773 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0646
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0068 - root_mean_squared_error: 0.0827INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 26s 498ms/step - loss: 0.0068 - root_mean_squared_error: 0.0827 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606
# Epoch 25/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0066 - root_mean_squared_error: 0.0810 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0710
# Epoch 26/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0060 - root_mean_squared_error: 0.0772INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 27s 509ms/step - loss: 0.0060 - root_mean_squared_error: 0.0772 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0582
# Epoch 27/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0058 - root_mean_squared_error: 0.0764INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0058 - root_mean_squared_error: 0.0764 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0559
# Epoch 28/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0053 - root_mean_squared_error: 0.0729INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 27s 518ms/step - loss: 0.0053 - root_mean_squared_error: 0.0729 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0559
# Epoch 29/50
# 53/53 [==============================] - 3s 47ms/step - loss: 0.0056 - root_mean_squared_error: 0.0747 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0571
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0054 - root_mean_squared_error: 0.0737INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 21s 396ms/step - loss: 0.0054 - root_mean_squared_error: 0.0737 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0527
# Epoch 31/50
# 53/53 [==============================] - 4s 78ms/step - loss: 0.0054 - root_mean_squared_error: 0.0736 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0577
# Epoch 32/50
# 53/53 [==============================] - 4s 75ms/step - loss: 0.0057 - root_mean_squared_error: 0.0754 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0547
# Epoch 33/50
# 53/53 [==============================] - 4s 78ms/step - loss: 0.0048 - root_mean_squared_error: 0.0691 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0591
# Epoch 34/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0046 - root_mean_squared_error: 0.0680INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 28s 541ms/step - loss: 0.0046 - root_mean_squared_error: 0.0680 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0494
# Epoch 35/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0050 - root_mean_squared_error: 0.0705 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0512
# Epoch 36/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0046 - root_mean_squared_error: 0.0677INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 27s 511ms/step - loss: 0.0046 - root_mean_squared_error: 0.0677 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0468
# Epoch 37/50
# 53/53 [==============================] - 4s 75ms/step - loss: 0.0044 - root_mean_squared_error: 0.0666 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0475
# Epoch 38/50
# 53/53 [==============================] - 4s 75ms/step - loss: 0.0044 - root_mean_squared_error: 0.0666 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0538
# Epoch 39/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0044 - root_mean_squared_error: 0.0665INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 26s 508ms/step - loss: 0.0044 - root_mean_squared_error: 0.0665 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0459
# Epoch 40/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0044 - root_mean_squared_error: 0.0664 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0540
# Epoch 41/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0048 - root_mean_squared_error: 0.0690 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0464
# Epoch 42/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0045 - root_mean_squared_error: 0.0672 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0541
# Epoch 43/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0047 - root_mean_squared_error: 0.0689INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 27s 511ms/step - loss: 0.0047 - root_mean_squared_error: 0.0689 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0446
# Epoch 44/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0045 - root_mean_squared_error: 0.0668INFO:tensorflow:Assets written to: Indian_model_LT8\assets
# 53/53 [==============================] - 27s 519ms/step - loss: 0.0045 - root_mean_squared_error: 0.0668 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0439
# Epoch 45/50
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0045 - root_mean_squared_error: 0.0673 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0504
# Epoch 46/50
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0040 - root_mean_squared_error: 0.0635 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0537
# Epoch 47/50
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0036 - root_mean_squared_error: 0.0598 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0485
# Epoch 48/50
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0039 - root_mean_squared_error: 0.0627 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0491
# Epoch 49/50
# 53/53 [==============================] - 4s 85ms/step - loss: 0.0042 - root_mean_squared_error: 0.0649 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0560
# Epoch 50/50
# 53/53 [==============================] - 4s 84ms/step - loss: 0.0040 - root_mean_squared_error: 0.0635 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0476

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 13.858437124888102 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Indian_model_LT8/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 26ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.047066803540187656
# MAE : 0.03941841112940047

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.389690e+06    1128752.378
# 1        3.973902e+05     522831.371
# 2        8.169721e+04     346601.304
# 3        1.378260e+05     444914.605
# 4        4.996909e+05     827036.916
# 5        1.081779e+06    1142021.216
# 6        1.787273e+06    1885693.654
# 7        2.527133e+06    2542569.663
# 8        3.054758e+06    3107373.845
# 9        3.366693e+06    3488175.444
# 10       3.432049e+06    3746306.528
# 11       2.783382e+06    2942322.822
# 12       1.412101e+06    1507212.955
# 13       5.051012e+05     648507.437
# 14       1.510500e+05     352564.010
# 15       2.186069e+05     453587.503
# 16       6.361380e+05     841043.793
# 17       1.284756e+06    1433155.266
# 18       1.985913e+06    2163687.646
# 19       2.633354e+06    2848863.133
# 20       3.091248e+06    3420877.229
# 21       3.417876e+06    3752886.938
# 22       3.482220e+06    3778951.818
# 23       2.784772e+06    2892177.223
# 24       1.435326e+06    1467610.428
# 25       4.628813e+05     377930.941
# 26       1.701751e+05     146440.376
# 27       2.686596e+05     244356.473
# 28       6.873249e+05     612217.566
# 29       1.266158e+06    1261627.075
# 30       1.986035e+06    1720565.225
# 31       2.713725e+06    2564005.541
# 32       3.244876e+06    2983773.529
# 33       3.589434e+06    3372645.223
# 34       3.544567e+06    3589687.043
# 35       2.611499e+06    2669385.189
# 36       1.171203e+06    1095398.946
# 37       2.474352e+05     319828.826
# 38       8.856455e+03     162541.182
# 39       1.181112e+05     179564.232
# 40       5.231382e+05     593196.107
# 41       1.136473e+06    1053508.835
# 42       1.831294e+06    1520776.003
# 43       2.508628e+06    2076164.165
# 44       3.051916e+06    2731799.027
# 45       3.373601e+06    3179384.692
# 46       3.428944e+06    3301335.210

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 40ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
