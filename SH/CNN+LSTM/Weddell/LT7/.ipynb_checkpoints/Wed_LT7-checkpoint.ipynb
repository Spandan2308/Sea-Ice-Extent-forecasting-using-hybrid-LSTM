# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Weddell_Extent = pd.read_excel(filepath, sheet_name='Weddell-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Weddell_Extent)
fp.date_time(Weddell_Extent)
# Out:
#           Extent       Date
# 0    2136510.859 1979-01-01
# 1    1243495.891 1979-02-01
# 2    1699053.449 1979-03-01
# 3    2617442.085 1979-04-01
# 4    3852934.206 1979-05-01
# ..           ...        ...
# 533  3668127.143 2023-06-01
# 534  4805519.784 2023-07-01
# 535  5524445.234 2023-08-01
# 536  6006669.861 2023-09-01
# 537  5507961.583 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Weddell_Extent['Extent'] = scaler.fit_transform(Weddell_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 7
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Weddell_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((520, 12, 1), (520,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Weddell_model_LT7/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.3776 - root_mean_squared_error: 0.6145
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 10s 123ms/step - loss: 0.3734 - root_mean_squared_error: 0.6111 - val_loss: 0.2857 - val_root_mean_squared_error: 0.5345
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.2193 - root_mean_squared_error: 0.4683
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 5s 104ms/step - loss: 0.2210 - root_mean_squared_error: 0.4701 - val_loss: 0.2228 - val_root_mean_squared_error: 0.4720
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1712 - root_mean_squared_error: 0.4137
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.1712 - root_mean_squared_error: 0.4137 - val_loss: 0.1926 - val_root_mean_squared_error: 0.4388
# Epoch 4/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.1477 - root_mean_squared_error: 0.3843
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 6s 108ms/step - loss: 0.1433 - root_mean_squared_error: 0.3785 - val_loss: 0.1706 - val_root_mean_squared_error: 0.4131
# Epoch 5/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.1106 - root_mean_squared_error: 0.3326
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 6s 106ms/step - loss: 0.1098 - root_mean_squared_error: 0.3313 - val_loss: 0.1484 - val_root_mean_squared_error: 0.3852
# Epoch 6/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0858 - root_mean_squared_error: 0.2929
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0868 - root_mean_squared_error: 0.2946 - val_loss: 0.1303 - val_root_mean_squared_error: 0.3610
# Epoch 7/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0725 - root_mean_squared_error: 0.2693
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 6s 113ms/step - loss: 0.0677 - root_mean_squared_error: 0.2602 - val_loss: 0.1108 - val_root_mean_squared_error: 0.3328
# Epoch 8/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0498 - root_mean_squared_error: 0.2233
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 6s 107ms/step - loss: 0.0502 - root_mean_squared_error: 0.2241 - val_loss: 0.0902 - val_root_mean_squared_error: 0.3003
# Epoch 9/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0390 - root_mean_squared_error: 0.1974
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 5s 105ms/step - loss: 0.0378 - root_mean_squared_error: 0.1945 - val_loss: 0.0723 - val_root_mean_squared_error: 0.2688
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0308 - root_mean_squared_error: 0.1754
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 6s 111ms/step - loss: 0.0305 - root_mean_squared_error: 0.1746 - val_loss: 0.0509 - val_root_mean_squared_error: 0.2257
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0295 - root_mean_squared_error: 0.1718
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 6s 106ms/step - loss: 0.0293 - root_mean_squared_error: 0.1712 - val_loss: 0.0353 - val_root_mean_squared_error: 0.1879
# Epoch 12/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0205 - root_mean_squared_error: 0.1433
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 6s 109ms/step - loss: 0.0198 - root_mean_squared_error: 0.1408 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1432
# Epoch 13/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0193 - root_mean_squared_error: 0.1389
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 6s 106ms/step - loss: 0.0190 - root_mean_squared_error: 0.1380 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1114
# Epoch 14/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0156 - root_mean_squared_error: 0.1248
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 5s 102ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0951
# Epoch 15/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0164 - root_mean_squared_error: 0.1280
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 6s 107ms/step - loss: 0.0170 - root_mean_squared_error: 0.1303 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0816
# Epoch 16/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0130 - root_mean_squared_error: 0.1139 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0938
# Epoch 17/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0139 - root_mean_squared_error: 0.1179 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0834
# Epoch 18/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0136 - root_mean_squared_error: 0.1165
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0136 - root_mean_squared_error: 0.1166 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0696
# Epoch 19/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0124 - root_mean_squared_error: 0.1114 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0730
# Epoch 20/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0169 - root_mean_squared_error: 0.1299 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1143
# Epoch 21/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0137 - root_mean_squared_error: 0.1171 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0912
# Epoch 22/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0712
# Epoch 23/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0157 - root_mean_squared_error: 0.1253
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0156 - root_mean_squared_error: 0.1249 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0683
# Epoch 24/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0114 - root_mean_squared_error: 0.1068
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 6s 110ms/step - loss: 0.0112 - root_mean_squared_error: 0.1057 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0660
# Epoch 25/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0130 - root_mean_squared_error: 0.1140 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0716
# Epoch 26/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0075 - root_mean_squared_error: 0.0865 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0701
# Epoch 27/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0130 - root_mean_squared_error: 0.1142 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0752
# Epoch 28/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0761
# Epoch 29/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0115 - root_mean_squared_error: 0.1070 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0821
# Epoch 30/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0104 - root_mean_squared_error: 0.1021 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1154
# Epoch 31/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0717
# Epoch 32/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0120 - root_mean_squared_error: 0.1097 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0665
# Epoch 33/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0143 - root_mean_squared_error: 0.1198 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1290
# Epoch 34/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0146 - root_mean_squared_error: 0.1209 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0896
# Epoch 35/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0161 - root_mean_squared_error: 0.1269 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1054
# Epoch 36/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0159 - root_mean_squared_error: 0.1262 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1014
# Epoch 37/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0886
# Epoch 38/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0154 - root_mean_squared_error: 0.1240 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0676
# Epoch 39/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0135 - root_mean_squared_error: 0.1164 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0705
# Epoch 40/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0144 - root_mean_squared_error: 0.1200 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0727
# Epoch 41/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0709
# Epoch 42/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0127 - root_mean_squared_error: 0.1129 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1102
# Epoch 43/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0127 - root_mean_squared_error: 0.1127 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0768
# Epoch 44/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0148 - root_mean_squared_error: 0.1216 - val_loss: 0.0276 - val_root_mean_squared_error: 0.1660
# Epoch 45/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0118 - root_mean_squared_error: 0.1088 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0808
# Epoch 46/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0156 - root_mean_squared_error: 0.1249 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0711
# Epoch 47/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0134 - root_mean_squared_error: 0.1158 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0768
# Epoch 48/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0131 - root_mean_squared_error: 0.1146 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0733
# Epoch 49/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0155 - root_mean_squared_error: 0.1245 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0700
# Epoch 50/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0148 - root_mean_squared_error: 0.1216 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0706

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.943239192167918 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Weddell_model_LT7/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 2ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.07040863354557765
# MAE : 0.058895432726601145

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        5.492378e+06    5902163.675
# 1        4.394719e+06    3498103.449
# 2        2.371869e+06    1633675.726
# 3        9.582922e+05    1292668.399
# 4        1.000859e+06    1527666.815
# 5        2.175877e+06    2121949.701
# 6        3.418685e+06    3562381.775
# 7        4.623720e+06    5004305.983
# 8        5.464452e+06    6176613.878
# 9        6.219938e+06    6794233.093
# 10       6.383198e+06    7024136.637
# 11       6.174874e+06    6554271.388
# 12       5.433592e+06    6172281.701
# 13       3.887042e+06    4175225.799
# 14       1.644654e+06    1748380.899
# 15       1.000635e+06    1256191.080
# 16       8.699497e+05    1347295.364
# 17       2.247950e+06    2180184.677
# 18       3.507053e+06    3419295.982
# 19       5.020014e+06    4786146.771
# 20       5.623219e+06    5968132.718
# 21       6.408021e+06    6556934.174
# 22       6.501438e+06    6614949.980
# 23       6.423818e+06    6035207.368
# 24       5.713630e+06    5274244.730
# 25       4.048437e+06    3505146.372
# 26       1.994555e+06    1478130.228
# 27       1.066154e+06    1096780.503
# 28       9.840428e+05    1387234.069
# 29       2.151114e+06    2128693.591
# 30       3.257036e+06    3313318.704
# 31       4.891490e+06    4218076.656
# 32       5.676690e+06    5257641.941
# 33       6.205232e+06    5956603.340
# 34       6.333946e+06    6256062.049
# 35       6.130492e+06    5974548.305
# 36       5.307352e+06    5569396.731
# 37       3.840780e+06    3684108.410
# 38       2.205184e+06    1451614.707
# 39       1.512583e+06    1089888.684
# 40       1.513189e+06    1255222.909
# 41       2.459961e+06    1704492.279
# 42       3.508914e+06    2563551.804
# 43       4.740646e+06    3668127.143
# 44       5.444630e+06    4805519.784
# 45       6.076825e+06    5524445.234
# 46       6.243256e+06    6006669.861
# 47       6.147198e+06    5507961.583

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
