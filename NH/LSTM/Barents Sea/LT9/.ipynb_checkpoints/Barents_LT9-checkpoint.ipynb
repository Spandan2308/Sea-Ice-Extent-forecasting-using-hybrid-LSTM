# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Barents = pd.read_excel(filepath, sheet_name='Barents-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Barents)
fp.date_time(Barents)
# Out:
#           Extent       Date
# 0    1107873.946 1979-01-01
# 1    1211101.473 1979-02-01
# 2    1215128.770 1979-03-01
# 3    1233940.811 1979-04-01
# 4    1193061.566 1979-05-01
# ..           ...        ...
# 533   124025.343 2023-06-01
# 534    53107.426 2023-07-01
# 535    11242.827 2023-08-01
# 536     3272.024 2023-09-01
# 537    35079.225 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Barents['Extent'] = scaler.fit_transform(Barents['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 9
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Barents['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((518, 12, 1), (518,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Barents_model_LT9/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1877 - root_mean_squared_error: 0.4333INFO:tensorflow:Assets written to: Barents_model_LT9\assets
# 53/53 [==============================] - 26s 340ms/step - loss: 0.1877 - root_mean_squared_error: 0.4333 - val_loss: 0.0471 - val_root_mean_squared_error: 0.2170
# Epoch 2/50
# 53/53 [==============================] - 1s 22ms/step - loss: 0.1086 - root_mean_squared_error: 0.3296 - val_loss: 0.0479 - val_root_mean_squared_error: 0.2190
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0798 - root_mean_squared_error: 0.2824INFO:tensorflow:Assets written to: Barents_model_LT9\assets
# 53/53 [==============================] - 12s 234ms/step - loss: 0.0798 - root_mean_squared_error: 0.2824 - val_loss: 0.0462 - val_root_mean_squared_error: 0.2149
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0744 - root_mean_squared_error: 0.2728INFO:tensorflow:Assets written to: Barents_model_LT9\assets
# 53/53 [==============================] - 13s 254ms/step - loss: 0.0744 - root_mean_squared_error: 0.2728 - val_loss: 0.0441 - val_root_mean_squared_error: 0.2100
# Epoch 5/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0677 - root_mean_squared_error: 0.2602 - val_loss: 0.0502 - val_root_mean_squared_error: 0.2241
# Epoch 6/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0625 - root_mean_squared_error: 0.2500 - val_loss: 0.0557 - val_root_mean_squared_error: 0.2361
# Epoch 7/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0540 - root_mean_squared_error: 0.2324 - val_loss: 0.0671 - val_root_mean_squared_error: 0.2590
# Epoch 8/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0445 - root_mean_squared_error: 0.2109 - val_loss: 0.0511 - val_root_mean_squared_error: 0.2260
# Epoch 9/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0370 - root_mean_squared_error: 0.1923 - val_loss: 0.0542 - val_root_mean_squared_error: 0.2327
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0313 - root_mean_squared_error: 0.1768INFO:tensorflow:Assets written to: Barents_model_LT9\assets
# 53/53 [==============================] - 13s 253ms/step - loss: 0.0314 - root_mean_squared_error: 0.1772 - val_loss: 0.0416 - val_root_mean_squared_error: 0.2039
# Epoch 11/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0290 - root_mean_squared_error: 0.1703 - val_loss: 0.0586 - val_root_mean_squared_error: 0.2421
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0251 - root_mean_squared_error: 0.1583INFO:tensorflow:Assets written to: Barents_model_LT9\assets
# 53/53 [==============================] - 14s 269ms/step - loss: 0.0251 - root_mean_squared_error: 0.1583 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1841
# Epoch 13/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0239 - root_mean_squared_error: 0.1547INFO:tensorflow:Assets written to: Barents_model_LT9\assets
# 53/53 [==============================] - 14s 267ms/step - loss: 0.0238 - root_mean_squared_error: 0.1543 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1437
# Epoch 14/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0230 - root_mean_squared_error: 0.1515 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1854
# Epoch 15/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0220 - root_mean_squared_error: 0.1484 - val_loss: 0.0248 - val_root_mean_squared_error: 0.1573
# Epoch 16/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0203 - root_mean_squared_error: 0.1424 - val_loss: 0.0304 - val_root_mean_squared_error: 0.1743
# Epoch 17/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0209 - root_mean_squared_error: 0.1444 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1528
# Epoch 18/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0189 - root_mean_squared_error: 0.1374 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1461
# Epoch 19/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0188 - root_mean_squared_error: 0.1371INFO:tensorflow:Assets written to: Barents_model_LT9\assets
# 53/53 [==============================] - 14s 269ms/step - loss: 0.0188 - root_mean_squared_error: 0.1370 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1294
# Epoch 20/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0195 - root_mean_squared_error: 0.1395 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1334
# Epoch 21/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0198 - root_mean_squared_error: 0.1407 - val_loss: 0.0191 - val_root_mean_squared_error: 0.1383
# Epoch 22/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0181 - root_mean_squared_error: 0.1345INFO:tensorflow:Assets written to: Barents_model_LT9\assets
# 53/53 [==============================] - 15s 295ms/step - loss: 0.0179 - root_mean_squared_error: 0.1338 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1109
# Epoch 23/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0165 - root_mean_squared_error: 0.1283 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1183
# Epoch 24/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0178 - root_mean_squared_error: 0.1335 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1247
# Epoch 25/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0167 - root_mean_squared_error: 0.1292 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1424
# Epoch 26/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0173 - root_mean_squared_error: 0.1316 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1148
# Epoch 27/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0159 - root_mean_squared_error: 0.1259INFO:tensorflow:Assets written to: Barents_model_LT9\assets
# 53/53 [==============================] - 22s 426ms/step - loss: 0.0159 - root_mean_squared_error: 0.1259 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1081
# Epoch 28/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0174 - root_mean_squared_error: 0.1321 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1156
# Epoch 29/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0176 - root_mean_squared_error: 0.1327INFO:tensorflow:Assets written to: Barents_model_LT9\assets
# 53/53 [==============================] - 13s 257ms/step - loss: 0.0175 - root_mean_squared_error: 0.1323 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1033
# Epoch 30/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0162 - root_mean_squared_error: 0.1272 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1355
# Epoch 31/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0166 - root_mean_squared_error: 0.1288 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1223
# Epoch 32/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0145 - root_mean_squared_error: 0.1202 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1317
# Epoch 33/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0166 - root_mean_squared_error: 0.1290 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1182
# Epoch 34/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1120
# Epoch 35/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0164 - root_mean_squared_error: 0.1279 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1353
# Epoch 36/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0163 - root_mean_squared_error: 0.1275 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1155
# Epoch 37/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0155 - root_mean_squared_error: 0.1245 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1116
# Epoch 38/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0154 - root_mean_squared_error: 0.1242 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1089
# Epoch 39/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1206
# Epoch 40/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0152 - root_mean_squared_error: 0.1234 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1223
# Epoch 41/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0146 - root_mean_squared_error: 0.1210 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1093
# Epoch 42/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0169 - root_mean_squared_error: 0.1298 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1208
# Epoch 43/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1037
# Epoch 44/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0134 - root_mean_squared_error: 0.1159 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1259
# Epoch 45/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0148 - root_mean_squared_error: 0.1215 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1050
# Epoch 46/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1387
# Epoch 47/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0147 - root_mean_squared_error: 0.1212 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1086
# Epoch 48/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0143 - root_mean_squared_error: 0.1196 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1115
# Epoch 49/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0145 - root_mean_squared_error: 0.1205 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1136
# Epoch 50/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1060

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 3.734001803398132 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Barents_model_LT9/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 16ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.10276205658786039
# MAE : 0.08324384973953543

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       410016.125000     605897.837
# 1       569398.687500     654073.790
# 2       626895.937500     701143.910
# 3       580873.937500     657891.340
# 4       478623.218750     432215.421
# 5       348211.906250     201834.787
# 6       212464.437500      55041.511
# 7       110025.695312       5387.468
# 8        67446.929688       1576.813
# 9       103622.414062      21681.895
# 10      211580.015625      37772.681
# 11      387687.187500     239568.531
# 12      573307.125000     427703.330
# 13      684339.000000     753043.012
# 14      689935.687500     764554.603
# 15      604036.000000     563799.961
# 16      458254.937500     444109.886
# 17      286916.156250     189669.492
# 18      135482.937500      63664.521
# 19       38869.082031       5984.539
# 20       -5203.343750       1192.062
# 21        5204.774414      25987.740
# 22       90273.976562     227374.130
# 23      255999.781250     498316.637
# 24      456040.375000     666292.874
# 25      608612.687500     673348.837
# 26      644487.250000     635756.948
# 27      575534.062500     673503.693
# 28      452662.937500     550922.786
# 29      306538.750000     116554.569
# 30      164712.546875      12012.356
# 31       59733.511719       5446.433
# 32       24967.218750       2183.701
# 33       73155.000000      31883.576
# 34      213657.312500      98802.296
# 35      407764.625000     224779.107
# 36      587118.250000     287476.263
# 37      700511.625000     376683.928
# 38      703979.312500     571055.966
# 39      614070.562500     581039.946
# 40      462681.687500     376525.530
# 41      282934.000000     124025.343
# 42      118278.851562      53107.426
# 43       20277.726562      11242.827
# 44      -18531.615234       3272.024
# 45       -7811.893066      35079.225

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 14ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
