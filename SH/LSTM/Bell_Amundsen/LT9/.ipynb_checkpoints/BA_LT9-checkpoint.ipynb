# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Bell_Amundsen_Extent = pd.read_excel(filepath, sheet_name='Bell-Amundsen-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Bell_Amundsen_Extent)
fp.date_time(Bell_Amundsen_Extent)
# Out:
#           Extent       Date
# 0    1179855.894 1979-01-01
# 1     879585.254 1979-02-01
# 2     791619.096 1979-03-01
# 3    1254912.071 1979-04-01
# 4    1620142.247 1979-05-01
# ..           ...        ...
# 533  1556568.455 2023-06-01
# 534  1917507.979 2023-07-01
# 535  2601630.327 2023-08-01
# 536  2534223.780 2023-09-01
# 537  2373004.525 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Bell_Amundsen_Extent['Extent'] = scaler.fit_transform(Bell_Amundsen_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 9
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Bell_Amundsen_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((518, 12, 1), (518,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Bell_Amund_model_LT9/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.2609 - root_mean_squared_error: 0.5108INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 14s 180ms/step - loss: 0.2600 - root_mean_squared_error: 0.5099 - val_loss: 0.2434 - val_root_mean_squared_error: 0.4933
# Epoch 2/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.1870 - root_mean_squared_error: 0.4324INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 8s 157ms/step - loss: 0.1840 - root_mean_squared_error: 0.4290 - val_loss: 0.1175 - val_root_mean_squared_error: 0.3427
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0853 - root_mean_squared_error: 0.2921INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 8s 153ms/step - loss: 0.0847 - root_mean_squared_error: 0.2910 - val_loss: 0.0906 - val_root_mean_squared_error: 0.3010
# Epoch 4/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0716 - root_mean_squared_error: 0.2676INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 9s 175ms/step - loss: 0.0729 - root_mean_squared_error: 0.2701 - val_loss: 0.0835 - val_root_mean_squared_error: 0.2890
# Epoch 5/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0678 - root_mean_squared_error: 0.2603INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 8s 159ms/step - loss: 0.0685 - root_mean_squared_error: 0.2617 - val_loss: 0.0773 - val_root_mean_squared_error: 0.2781
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0638 - root_mean_squared_error: 0.2526INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 8s 157ms/step - loss: 0.0642 - root_mean_squared_error: 0.2533 - val_loss: 0.0717 - val_root_mean_squared_error: 0.2677
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0588 - root_mean_squared_error: 0.2424INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 9s 164ms/step - loss: 0.0587 - root_mean_squared_error: 0.2422 - val_loss: 0.0630 - val_root_mean_squared_error: 0.2509
# Epoch 8/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0499 - root_mean_squared_error: 0.2234INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 8s 163ms/step - loss: 0.0504 - root_mean_squared_error: 0.2246 - val_loss: 0.0498 - val_root_mean_squared_error: 0.2231
# Epoch 9/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0371 - root_mean_squared_error: 0.1926INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 8s 158ms/step - loss: 0.0368 - root_mean_squared_error: 0.1918 - val_loss: 0.0293 - val_root_mean_squared_error: 0.1710
# Epoch 10/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0234 - root_mean_squared_error: 0.1531INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 9s 167ms/step - loss: 0.0231 - root_mean_squared_error: 0.1521 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1171
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0162 - root_mean_squared_error: 0.1271INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 8s 159ms/step - loss: 0.0162 - root_mean_squared_error: 0.1272 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1010
# Epoch 12/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0160 - root_mean_squared_error: 0.1263 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1033
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0146 - root_mean_squared_error: 0.1208INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 8s 158ms/step - loss: 0.0145 - root_mean_squared_error: 0.1205 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0967
# Epoch 14/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0147 - root_mean_squared_error: 0.1212INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 9s 175ms/step - loss: 0.0146 - root_mean_squared_error: 0.1208 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0965
# Epoch 15/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1029
# Epoch 16/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0133 - root_mean_squared_error: 0.1154INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 9s 167ms/step - loss: 0.0135 - root_mean_squared_error: 0.1164 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0964
# Epoch 17/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0136 - root_mean_squared_error: 0.1164INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 8s 160ms/step - loss: 0.0135 - root_mean_squared_error: 0.1162 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0947
# Epoch 18/50
# 53/53 [==============================] - 1s 27ms/step - loss: 0.0136 - root_mean_squared_error: 0.1165 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1032
# Epoch 19/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0140 - root_mean_squared_error: 0.1183 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1000
# Epoch 20/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0138 - root_mean_squared_error: 0.1175INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 9s 176ms/step - loss: 0.0138 - root_mean_squared_error: 0.1174 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0936
# Epoch 21/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0125 - root_mean_squared_error: 0.1118 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0937
# Epoch 22/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0121 - root_mean_squared_error: 0.1099 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0943
# Epoch 23/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0124 - root_mean_squared_error: 0.1113 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0944
# Epoch 24/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0132 - root_mean_squared_error: 0.1150INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 8s 162ms/step - loss: 0.0132 - root_mean_squared_error: 0.1151 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0930
# Epoch 25/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0128 - root_mean_squared_error: 0.1130 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0937
# Epoch 26/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0124 - root_mean_squared_error: 0.1112 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0933
# Epoch 27/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0122 - root_mean_squared_error: 0.1104INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 8s 158ms/step - loss: 0.0121 - root_mean_squared_error: 0.1100 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0929
# Epoch 28/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 29/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0120 - root_mean_squared_error: 0.1095 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0943
# Epoch 30/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0124 - root_mean_squared_error: 0.1114 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0935
# Epoch 31/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0117 - root_mean_squared_error: 0.1081INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 8s 163ms/step - loss: 0.0117 - root_mean_squared_error: 0.1081 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0923
# Epoch 32/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0108 - root_mean_squared_error: 0.1041 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0928
# Epoch 33/50
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0116 - root_mean_squared_error: 0.1075 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0939
# Epoch 34/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0117 - root_mean_squared_error: 0.1084 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1017
# Epoch 35/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0115 - root_mean_squared_error: 0.1073 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0969
# Epoch 36/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0111 - root_mean_squared_error: 0.1056 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0929
# Epoch 37/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0111 - root_mean_squared_error: 0.1055 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0961
# Epoch 38/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0117 - root_mean_squared_error: 0.1080 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0944
# Epoch 39/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0108 - root_mean_squared_error: 0.1041 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0959
# Epoch 40/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0112 - root_mean_squared_error: 0.1058INFO:tensorflow:Assets written to: Bell_Amund_model_LT9\assets
# 53/53 [==============================] - 8s 144ms/step - loss: 0.0111 - root_mean_squared_error: 0.1055 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0921
# Epoch 41/50
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0109 - root_mean_squared_error: 0.1044 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0924
# Epoch 42/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0102 - root_mean_squared_error: 0.1012 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0930
# Epoch 43/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0101 - root_mean_squared_error: 0.1007 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0926
# Epoch 44/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0105 - root_mean_squared_error: 0.1023 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0929
# Epoch 45/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0110 - root_mean_squared_error: 0.1050 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0944
# Epoch 46/50
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0106 - root_mean_squared_error: 0.1031 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0931
# Epoch 47/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0108 - root_mean_squared_error: 0.1038 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0926
# Epoch 48/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0105 - root_mean_squared_error: 0.1025 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0932
# Epoch 49/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0108 - root_mean_squared_error: 0.1038 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0931
# Epoch 50/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0100 - root_mean_squared_error: 0.0998 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0925

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 3.570033037662506 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Bell_Amund_model_LT9/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 18ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.08502667590469751
# MAE : 0.07205655947914756

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        7.050903e+05     752834.272
# 1        5.671639e+05     451914.219
# 2        5.259451e+05     439855.813
# 3        6.611534e+05     807857.307
# 4        1.064964e+06    1184280.145
# 5        1.545432e+06    1468308.405
# 6        1.931573e+06    1540851.607
# 7        2.161012e+06    1989099.836
# 8        2.232676e+06    2096990.761
# 9        2.117074e+06    2080961.032
# 10       1.826852e+06    1695704.661
# 11       1.345338e+06    1533888.370
# 12       9.180941e+05    1038332.675
# 13       7.264831e+05     602954.621
# 14       7.264736e+05     895484.288
# 15       8.662155e+05    1070622.700
# 16       1.191374e+06    1532457.922
# 17       1.579439e+06    1703762.123
# 18       1.978196e+06    1855079.122
# 19       2.219612e+06    2291960.639
# 20       2.290954e+06    2114120.417
# 21       2.201640e+06    1995818.759
# 22       1.933758e+06    1653379.997
# 23       1.461057e+06    1070814.995
# 24       1.046345e+06     689443.815
# 25       8.286951e+05     401148.663
# 26       7.932178e+05     346558.057
# 27       8.973592e+05     599477.678
# 28       1.181543e+06     765764.905
# 29       1.569528e+06    1304133.179
# 30       1.899359e+06    1598436.099
# 31       2.084936e+06    1763844.414
# 32       2.105482e+06    1979139.524
# 33       1.901868e+06    1937348.663
# 34       1.419612e+06    1833093.342
# 35       1.001749e+06    1089676.114
# 36       7.215740e+05     453484.731
# 37       6.061276e+05     251559.554
# 38       5.905630e+05     351294.657
# 39       7.489863e+05     702389.714
# 40       1.121130e+06    1185169.054
# 41       1.553030e+06    1556568.455
# 42       1.959966e+06    1917507.979
# 43       2.218236e+06    2601630.327
# 44       2.295856e+06    2534223.780
# 45       2.225957e+06    2373004.525

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 12ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
