# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Weddell_Extent = pd.read_excel(filepath, sheet_name='Weddell-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Weddell_Extent)
fp.date_time(Weddell_Extent)
# Out:
#           Extent       Date
# 0    2136510.859 1979-01-01
# 1    1243495.891 1979-02-01
# 2    1699053.449 1979-03-01
# 3    2617442.085 1979-04-01
# 4    3852934.206 1979-05-01
# ..           ...        ...
# 533  3668127.143 2023-06-01
# 534  4805519.784 2023-07-01
# 535  5524445.234 2023-08-01
# 536  6006669.861 2023-09-01
# 537  5507961.583 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Weddell_Extent['Extent'] = scaler.fit_transform(Weddell_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 11
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Weddell_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((516, 12, 1), (516,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Weddell_model_LT11/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.3199 - root_mean_squared_error: 0.5656INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 14s 168ms/step - loss: 0.3199 - root_mean_squared_error: 0.5656 - val_loss: 0.2561 - val_root_mean_squared_error: 0.5060
# Epoch 2/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.2279 - root_mean_squared_error: 0.4774INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 8s 144ms/step - loss: 0.2221 - root_mean_squared_error: 0.4713 - val_loss: 0.1168 - val_root_mean_squared_error: 0.3417
# Epoch 3/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.1086 - root_mean_squared_error: 0.3295INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 7s 134ms/step - loss: 0.1089 - root_mean_squared_error: 0.3300 - val_loss: 0.1025 - val_root_mean_squared_error: 0.3202
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0982 - root_mean_squared_error: 0.3134INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 8s 147ms/step - loss: 0.0979 - root_mean_squared_error: 0.3128 - val_loss: 0.0941 - val_root_mean_squared_error: 0.3068
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0849 - root_mean_squared_error: 0.2914INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 7s 136ms/step - loss: 0.0849 - root_mean_squared_error: 0.2914 - val_loss: 0.0830 - val_root_mean_squared_error: 0.2880
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0752 - root_mean_squared_error: 0.2743INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 7s 128ms/step - loss: 0.0747 - root_mean_squared_error: 0.2733 - val_loss: 0.0700 - val_root_mean_squared_error: 0.2645
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0568 - root_mean_squared_error: 0.2383INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 7s 138ms/step - loss: 0.0568 - root_mean_squared_error: 0.2383 - val_loss: 0.0523 - val_root_mean_squared_error: 0.2286
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0360 - root_mean_squared_error: 0.1898INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 8s 149ms/step - loss: 0.0360 - root_mean_squared_error: 0.1898 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1832
# Epoch 9/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0221 - root_mean_squared_error: 0.1487INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 7s 143ms/step - loss: 0.0221 - root_mean_squared_error: 0.1487 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1586
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0196 - root_mean_squared_error: 0.1402INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 7s 139ms/step - loss: 0.0196 - root_mean_squared_error: 0.1402 - val_loss: 0.0248 - val_root_mean_squared_error: 0.1575
# Epoch 11/50
# 53/53 [==============================] - 1s 27ms/step - loss: 0.0177 - root_mean_squared_error: 0.1330 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1584
# Epoch 12/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0165 - root_mean_squared_error: 0.1283INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 7s 140ms/step - loss: 0.0165 - root_mean_squared_error: 0.1284 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1527
# Epoch 13/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0168 - root_mean_squared_error: 0.1297INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 7s 138ms/step - loss: 0.0169 - root_mean_squared_error: 0.1300 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1469
# Epoch 14/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0153 - root_mean_squared_error: 0.1239INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 8s 155ms/step - loss: 0.0153 - root_mean_squared_error: 0.1236 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1453
# Epoch 15/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0155 - root_mean_squared_error: 0.1246 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1462
# Epoch 16/50
# 53/53 [==============================] - 1s 27ms/step - loss: 0.0138 - root_mean_squared_error: 0.1176 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1463
# Epoch 17/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0138 - root_mean_squared_error: 0.1174INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 8s 156ms/step - loss: 0.0139 - root_mean_squared_error: 0.1178 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1385
# Epoch 18/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0151 - root_mean_squared_error: 0.1227 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1581
# Epoch 19/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1403
# Epoch 20/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0120 - root_mean_squared_error: 0.1097INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 8s 144ms/step - loss: 0.0127 - root_mean_squared_error: 0.1125 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1368
# Epoch 21/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0124 - root_mean_squared_error: 0.1112INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 7s 138ms/step - loss: 0.0123 - root_mean_squared_error: 0.1107 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1343
# Epoch 22/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0134 - root_mean_squared_error: 0.1159 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1367
# Epoch 23/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0128 - root_mean_squared_error: 0.1131INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 7s 142ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1320
# Epoch 24/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0126 - root_mean_squared_error: 0.1124 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1355
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0113 - root_mean_squared_error: 0.1064INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 7s 140ms/step - loss: 0.0113 - root_mean_squared_error: 0.1064 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1294
# Epoch 26/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0100 - root_mean_squared_error: 0.1001 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1311
# Epoch 27/50
# 53/53 [==============================] - 1s 26ms/step - loss: 0.0109 - root_mean_squared_error: 0.1043 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1310
# Epoch 28/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0105 - root_mean_squared_error: 0.1024 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1304
# Epoch 29/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0112 - root_mean_squared_error: 0.1058INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 8s 145ms/step - loss: 0.0112 - root_mean_squared_error: 0.1057 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1275
# Epoch 30/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0102 - root_mean_squared_error: 0.1008 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1387
# Epoch 31/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0112 - root_mean_squared_error: 0.1058INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 8s 161ms/step - loss: 0.0111 - root_mean_squared_error: 0.1054 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1272
# Epoch 32/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0099 - root_mean_squared_error: 0.0995INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 8s 152ms/step - loss: 0.0099 - root_mean_squared_error: 0.0995 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1261
# Epoch 33/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0111 - root_mean_squared_error: 0.1052INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 8s 154ms/step - loss: 0.0110 - root_mean_squared_error: 0.1050 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1253
# Epoch 34/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0105 - root_mean_squared_error: 0.1024 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1275
# Epoch 35/50
# 53/53 [==============================] - 1s 26ms/step - loss: 0.0109 - root_mean_squared_error: 0.1046 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1305
# Epoch 36/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0099 - root_mean_squared_error: 0.0996INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 8s 146ms/step - loss: 0.0099 - root_mean_squared_error: 0.0996 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1224
# Epoch 37/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0096 - root_mean_squared_error: 0.0982INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 7s 140ms/step - loss: 0.0096 - root_mean_squared_error: 0.0980 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1207
# Epoch 38/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0097 - root_mean_squared_error: 0.0983 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1222
# Epoch 39/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0098 - root_mean_squared_error: 0.0988INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 8s 155ms/step - loss: 0.0097 - root_mean_squared_error: 0.0986 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1206
# Epoch 40/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0100 - root_mean_squared_error: 0.1000 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1232
# Epoch 41/50
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0089 - root_mean_squared_error: 0.0945 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1263
# Epoch 42/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0093 - root_mean_squared_error: 0.0964INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 16s 300ms/step - loss: 0.0093 - root_mean_squared_error: 0.0964 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1198
# Epoch 43/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0082 - root_mean_squared_error: 0.0904 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1198
# Epoch 44/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0085 - root_mean_squared_error: 0.0921 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1278
# Epoch 45/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0089 - root_mean_squared_error: 0.0946 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1209
# Epoch 46/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0089 - root_mean_squared_error: 0.0941INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 8s 150ms/step - loss: 0.0089 - root_mean_squared_error: 0.0941 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1164
# Epoch 47/50
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0086 - root_mean_squared_error: 0.0925 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1182
# Epoch 48/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0089 - root_mean_squared_error: 0.0942INFO:tensorflow:Assets written to: Weddell_model_LT11\assets
# 53/53 [==============================] - 8s 158ms/step - loss: 0.0089 - root_mean_squared_error: 0.0942 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1138
# Epoch 49/50
# 53/53 [==============================] - 1s 26ms/step - loss: 0.0086 - root_mean_squared_error: 0.0926 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1217
# Epoch 50/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1194

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 4.274907223383585 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Weddell_model_LT11/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 16ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.0811890695066721
# MAE : 0.06432427654563898

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0         1845272.625    1527666.815
# 1         2596820.750    2121949.701
# 2         3573291.500    3562381.775
# 3         4640826.000    5004305.983
# 4         5608918.500    6176613.878
# 5         6472012.000    6794233.093
# 6         6711644.000    7024136.637
# 7         6323655.000    6554271.388
# 8         5865392.500    6172281.701
# 9         4887033.000    4175225.799
# 10        2947719.250    1748380.899
# 11        1530295.875    1256191.080
# 12        1615169.500    1347295.364
# 13        2400880.500    2180184.677
# 14        3490722.000    3419295.982
# 15        4679232.000    4786146.771
# 16        5721973.000    5968132.718
# 17        6620470.500    6556934.174
# 18        6760762.500    6614949.980
# 19        6227699.500    6035207.368
# 20        5568978.500    5274244.730
# 21        4141679.750    3505146.372
# 22        1819447.000    1478130.228
# 23        1099745.625    1096780.503
# 24        1342827.000    1387234.069
# 25        2188489.750    2128693.591
# 26        3270848.750    3313318.704
# 27        4447391.500    4218076.656
# 28        5569636.500    5257641.941
# 29        6482817.500    5956603.340
# 30        6695447.500    6256062.049
# 31        6426678.000    5974548.305
# 32        5708569.000    5569396.731
# 33        4587242.000    3684108.410
# 34        2481419.250    1451614.707
# 35        1466933.500    1089888.684
# 36        1811119.125    1255222.909
# 37        2724559.750    1704492.279
# 38        3778455.500    2563551.804
# 39        4759688.000    3668127.143
# 40        5696250.500    4805519.784
# 41        6401096.000    5524445.234
# 42        6633007.000    6006669.861
# 43        6336691.000    5507961.583

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 12ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
