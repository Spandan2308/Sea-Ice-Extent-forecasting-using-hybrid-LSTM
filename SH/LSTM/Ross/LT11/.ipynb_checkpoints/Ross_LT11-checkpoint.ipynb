# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Ross_Extent = pd.read_excel(filepath, sheet_name='Ross-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Ross_Extent)
fp.date_time(Ross_Extent)
# Out:
#           Extent       Date
# 0    1040455.516 1979-01-01
# 1     239334.118 1979-02-01
# 2     557365.154 1979-03-01
# 3    2054855.924 1979-04-01
# 4    2973925.625 1979-05-01
# ..           ...        ...
# 533  3137598.938 2023-06-01
# 534  3201783.453 2023-07-01
# 535  2973294.266 2023-08-01
# 536  3354839.711 2023-09-01
# 537  3325613.245 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Ross_Extent['Extent'] = scaler.fit_transform(Ross_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 11
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Ross_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((516, 12, 1), (516,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Ross_model_LT11/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.3790 - root_mean_squared_error: 0.6156INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 18s 220ms/step - loss: 0.3790 - root_mean_squared_error: 0.6156 - val_loss: 0.2736 - val_root_mean_squared_error: 0.5230
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1983 - root_mean_squared_error: 0.4454INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.1983 - root_mean_squared_error: 0.4454 - val_loss: 0.1403 - val_root_mean_squared_error: 0.3746
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0980 - root_mean_squared_error: 0.3131INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 10s 191ms/step - loss: 0.0979 - root_mean_squared_error: 0.3129 - val_loss: 0.1131 - val_root_mean_squared_error: 0.3364
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0886 - root_mean_squared_error: 0.2977INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 10s 201ms/step - loss: 0.0891 - root_mean_squared_error: 0.2986 - val_loss: 0.1072 - val_root_mean_squared_error: 0.3275
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0840 - root_mean_squared_error: 0.2898INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 10s 198ms/step - loss: 0.0840 - root_mean_squared_error: 0.2898 - val_loss: 0.0937 - val_root_mean_squared_error: 0.3060
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0777 - root_mean_squared_error: 0.2788INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 11s 203ms/step - loss: 0.0779 - root_mean_squared_error: 0.2790 - val_loss: 0.0898 - val_root_mean_squared_error: 0.2997
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0730 - root_mean_squared_error: 0.2701INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 10s 198ms/step - loss: 0.0730 - root_mean_squared_error: 0.2701 - val_loss: 0.0841 - val_root_mean_squared_error: 0.2900
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0678 - root_mean_squared_error: 0.2605INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 10s 201ms/step - loss: 0.0678 - root_mean_squared_error: 0.2605 - val_loss: 0.0811 - val_root_mean_squared_error: 0.2848
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0601 - root_mean_squared_error: 0.2451INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 10s 195ms/step - loss: 0.0601 - root_mean_squared_error: 0.2451 - val_loss: 0.0773 - val_root_mean_squared_error: 0.2781
# Epoch 10/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0548 - root_mean_squared_error: 0.2342INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 11s 203ms/step - loss: 0.0540 - root_mean_squared_error: 0.2324 - val_loss: 0.0607 - val_root_mean_squared_error: 0.2464
# Epoch 11/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0404 - root_mean_squared_error: 0.2009INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 11s 203ms/step - loss: 0.0406 - root_mean_squared_error: 0.2014 - val_loss: 0.0493 - val_root_mean_squared_error: 0.2220
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0319 - root_mean_squared_error: 0.1786INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 10s 189ms/step - loss: 0.0319 - root_mean_squared_error: 0.1786 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2014
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0237 - root_mean_squared_error: 0.1539INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 10s 197ms/step - loss: 0.0239 - root_mean_squared_error: 0.1545 - val_loss: 0.0296 - val_root_mean_squared_error: 0.1722
# Epoch 14/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0229 - root_mean_squared_error: 0.1514 - val_loss: 0.0301 - val_root_mean_squared_error: 0.1736
# Epoch 15/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0226 - root_mean_squared_error: 0.1502INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 10s 199ms/step - loss: 0.0225 - root_mean_squared_error: 0.1499 - val_loss: 0.0275 - val_root_mean_squared_error: 0.1657
# Epoch 16/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0189 - root_mean_squared_error: 0.1377 - val_loss: 0.0311 - val_root_mean_squared_error: 0.1762
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0210 - root_mean_squared_error: 0.1450INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 10s 192ms/step - loss: 0.0210 - root_mean_squared_error: 0.1450 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1600
# Epoch 18/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0207 - root_mean_squared_error: 0.1439 - val_loss: 0.0310 - val_root_mean_squared_error: 0.1760
# Epoch 19/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0190 - root_mean_squared_error: 0.1379 - val_loss: 0.0276 - val_root_mean_squared_error: 0.1661
# Epoch 20/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0177 - root_mean_squared_error: 0.1329 - val_loss: 0.0295 - val_root_mean_squared_error: 0.1719
# Epoch 21/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0184 - root_mean_squared_error: 0.1358 - val_loss: 0.0266 - val_root_mean_squared_error: 0.1629
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0173 - root_mean_squared_error: 0.1314INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 11s 205ms/step - loss: 0.0173 - root_mean_squared_error: 0.1314 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1560
# Epoch 23/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0180 - root_mean_squared_error: 0.1341INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 10s 189ms/step - loss: 0.0180 - root_mean_squared_error: 0.1341 - val_loss: 0.0223 - val_root_mean_squared_error: 0.1492
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0173 - root_mean_squared_error: 0.1315INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 10s 190ms/step - loss: 0.0173 - root_mean_squared_error: 0.1315 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1441
# Epoch 25/50
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0164 - root_mean_squared_error: 0.1281 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1460
# Epoch 26/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0172 - root_mean_squared_error: 0.1311 - val_loss: 0.0275 - val_root_mean_squared_error: 0.1658
# Epoch 27/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0160 - root_mean_squared_error: 0.1265 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1572
# Epoch 28/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0157 - root_mean_squared_error: 0.1254 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1507
# Epoch 29/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0155 - root_mean_squared_error: 0.1243 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1469
# Epoch 30/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0157 - root_mean_squared_error: 0.1255INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 10s 198ms/step - loss: 0.0155 - root_mean_squared_error: 0.1246 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1344
# Epoch 31/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0162 - root_mean_squared_error: 0.1272 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1555
# Epoch 32/50
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0157 - root_mean_squared_error: 0.1254 - val_loss: 0.0368 - val_root_mean_squared_error: 0.1918
# Epoch 33/50
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0148 - root_mean_squared_error: 0.1218 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1402
# Epoch 34/50
# 53/53 [==============================] - 1s 27ms/step - loss: 0.0149 - root_mean_squared_error: 0.1222 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1477
# Epoch 35/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190 - val_loss: 0.0259 - val_root_mean_squared_error: 0.1610
# Epoch 36/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0147 - root_mean_squared_error: 0.1213 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1467
# Epoch 37/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0137 - root_mean_squared_error: 0.1171 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1433
# Epoch 38/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0136 - root_mean_squared_error: 0.1166 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1428
# Epoch 39/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1416
# Epoch 40/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0133 - root_mean_squared_error: 0.1153 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1473
# Epoch 41/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1644
# Epoch 42/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0127 - root_mean_squared_error: 0.1129INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 10s 197ms/step - loss: 0.0127 - root_mean_squared_error: 0.1129 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1257
# Epoch 43/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0123 - root_mean_squared_error: 0.1109 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1450
# Epoch 44/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0119 - root_mean_squared_error: 0.1090 - val_loss: 0.0255 - val_root_mean_squared_error: 0.1597
# Epoch 45/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0248 - val_root_mean_squared_error: 0.1574
# Epoch 46/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0113 - root_mean_squared_error: 0.1061 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1389
# Epoch 47/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0125 - root_mean_squared_error: 0.1120INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 10s 188ms/step - loss: 0.0125 - root_mean_squared_error: 0.1117 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1245
# Epoch 48/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0114 - root_mean_squared_error: 0.1070 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1309
# Epoch 49/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0110 - root_mean_squared_error: 0.1050INFO:tensorflow:Assets written to: Ross_model_LT11\assets
# 53/53 [==============================] - 10s 201ms/step - loss: 0.0110 - root_mean_squared_error: 0.1050 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1209
# Epoch 50/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0118 - root_mean_squared_error: 0.1085 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1354

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 4.646446557839711 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Ross_model_LT11/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 16ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.10465322439895616
# MAE : 0.07961927446635324

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.472315e+06     979418.298
# 1        2.093061e+06    2086269.569
# 2        2.667845e+06    2852731.016
# 3        3.226103e+06    3452823.613
# 4        3.725808e+06    3846843.974
# 5        4.089715e+06    4005222.451
# 6        4.211146e+06    4129684.505
# 7        4.076472e+06    4130311.577
# 8        3.893639e+06    3987590.376
# 9        3.412955e+06    2531664.630
# 10       2.146653e+06     864796.598
# 11       9.852129e+05     366098.623
# 12       1.400708e+06    1324063.884
# 13       1.978729e+06    2094086.684
# 14       2.571630e+06    2706708.526
# 15       3.169285e+06    3380172.167
# 16       3.654726e+06    3975727.475
# 17       3.984517e+06    4016497.161
# 18       4.070405e+06    4134594.766
# 19       4.104303e+06    4278165.933
# 20       3.684756e+06    3893945.909
# 21       2.999565e+06    2389171.083
# 22       1.212224e+06     896425.932
# 23       8.093764e+05     251374.224
# 24       1.311288e+06     455056.048
# 25       1.933675e+06    1780625.872
# 26       2.563551e+06    2914989.101
# 27       3.209121e+06    3561620.245
# 28       3.760424e+06    3991717.506
# 29       4.158027e+06    4559070.778
# 30       4.238731e+06    4596327.081
# 31       4.065460e+06    4565650.139
# 32       3.658041e+06    4061902.846
# 33       2.887589e+06    2336900.967
# 34       1.108733e+06     696917.659
# 35       7.688291e+05     213657.789
# 36       1.250728e+06     765773.883
# 37       1.892963e+06    1951730.202
# 38       2.548494e+06    2610971.814
# 39       3.220486e+06    3137598.938
# 40       3.806290e+06    3201783.453
# 41       4.236448e+06    2973294.266
# 42       4.335466e+06    3354839.711
# 43       4.141450e+06    3325613.245

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 16ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
