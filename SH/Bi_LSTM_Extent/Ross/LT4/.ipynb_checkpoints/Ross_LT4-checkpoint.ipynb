# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Ross_Extent = pd.read_excel(filepath, sheet_name='Ross-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Ross_Extent)
fp.date_time(Ross_Extent)
# Out:
#           Extent       Date
# 0    1040455.516 1979-01-01
# 1     239334.118 1979-02-01
# 2     557365.154 1979-03-01
# 3    2054855.924 1979-04-01
# 4    2973925.625 1979-05-01
# ..           ...        ...
# 533  3137598.938 2023-06-01
# 534  3201783.453 2023-07-01
# 535  2973294.266 2023-08-01
# 536  3354839.711 2023-09-01
# 537  3325613.245 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Ross_Extent['Extent'] = scaler.fit_transform(Ross_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 4
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Ross_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((523, 12, 1), (523,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Ross_model_LT4/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.3117 - root_mean_squared_error: 0.5583INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 38s 500ms/step - loss: 0.3093 - root_mean_squared_error: 0.5561 - val_loss: 0.1506 - val_root_mean_squared_error: 0.3880
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0790 - root_mean_squared_error: 0.2810INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 25s 476ms/step - loss: 0.0790 - root_mean_squared_error: 0.2810 - val_loss: 0.0691 - val_root_mean_squared_error: 0.2628
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0538 - root_mean_squared_error: 0.2319INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 25s 480ms/step - loss: 0.0538 - root_mean_squared_error: 0.2319 - val_loss: 0.0605 - val_root_mean_squared_error: 0.2460
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0458 - root_mean_squared_error: 0.2141INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 25s 488ms/step - loss: 0.0458 - root_mean_squared_error: 0.2141 - val_loss: 0.0488 - val_root_mean_squared_error: 0.2210
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0370 - root_mean_squared_error: 0.1923INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 26s 496ms/step - loss: 0.0370 - root_mean_squared_error: 0.1923 - val_loss: 0.0398 - val_root_mean_squared_error: 0.1995
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0291 - root_mean_squared_error: 0.1705INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 26s 500ms/step - loss: 0.0291 - root_mean_squared_error: 0.1705 - val_loss: 0.0328 - val_root_mean_squared_error: 0.1812
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0253 - root_mean_squared_error: 0.1589INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 26s 499ms/step - loss: 0.0253 - root_mean_squared_error: 0.1589 - val_loss: 0.0279 - val_root_mean_squared_error: 0.1671
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0203 - root_mean_squared_error: 0.1425INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 27s 514ms/step - loss: 0.0203 - root_mean_squared_error: 0.1425 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1588
# Epoch 9/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0192 - root_mean_squared_error: 0.1387 - val_loss: 0.0266 - val_root_mean_squared_error: 0.1630
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0188 - root_mean_squared_error: 0.1371INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 26s 502ms/step - loss: 0.0188 - root_mean_squared_error: 0.1371 - val_loss: 0.0244 - val_root_mean_squared_error: 0.1562
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0181 - root_mean_squared_error: 0.1346INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 26s 500ms/step - loss: 0.0181 - root_mean_squared_error: 0.1346 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1458
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0169 - root_mean_squared_error: 0.1302INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 26s 501ms/step - loss: 0.0169 - root_mean_squared_error: 0.1302 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1439
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0165 - root_mean_squared_error: 0.1285INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 26s 499ms/step - loss: 0.0165 - root_mean_squared_error: 0.1285 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1386
# Epoch 14/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0160 - root_mean_squared_error: 0.1264 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1387
# Epoch 15/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0159 - root_mean_squared_error: 0.1259INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 19s 363ms/step - loss: 0.0158 - root_mean_squared_error: 0.1257 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1336
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0156 - root_mean_squared_error: 0.1249INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 18s 341ms/step - loss: 0.0156 - root_mean_squared_error: 0.1249 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1315
# Epoch 17/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0158 - root_mean_squared_error: 0.1256 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1339
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0147 - root_mean_squared_error: 0.1211INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 19s 369ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1313
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0126 - root_mean_squared_error: 0.1123INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 18s 351ms/step - loss: 0.0126 - root_mean_squared_error: 0.1123 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1228
# Epoch 20/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0139 - root_mean_squared_error: 0.1178INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 18s 354ms/step - loss: 0.0139 - root_mean_squared_error: 0.1178 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1216
# Epoch 21/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0123 - root_mean_squared_error: 0.1108INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 18s 348ms/step - loss: 0.0123 - root_mean_squared_error: 0.1108 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1184
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0127 - root_mean_squared_error: 0.1126INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 18s 349ms/step - loss: 0.0127 - root_mean_squared_error: 0.1126 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1149
# Epoch 23/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0130 - root_mean_squared_error: 0.1140INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 18s 346ms/step - loss: 0.0129 - root_mean_squared_error: 0.1137 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1129
# Epoch 24/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0129 - root_mean_squared_error: 0.1136 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1137
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0109 - root_mean_squared_error: 0.1042INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 19s 364ms/step - loss: 0.0109 - root_mean_squared_error: 0.1042 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1054
# Epoch 26/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0106 - root_mean_squared_error: 0.1027 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1175
# Epoch 27/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0104 - root_mean_squared_error: 0.1019 - val_loss: 0.0191 - val_root_mean_squared_error: 0.1384
# Epoch 28/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0113 - root_mean_squared_error: 0.1062 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1063
# Epoch 29/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0097 - root_mean_squared_error: 0.0984 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1108
# Epoch 30/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0093 - root_mean_squared_error: 0.0964INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 18s 346ms/step - loss: 0.0092 - root_mean_squared_error: 0.0962 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0994
# Epoch 31/50
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0088 - root_mean_squared_error: 0.0936 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1003
# Epoch 32/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0085 - root_mean_squared_error: 0.0924INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 19s 355ms/step - loss: 0.0085 - root_mean_squared_error: 0.0924 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0976
# Epoch 33/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0087 - root_mean_squared_error: 0.0931 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1034
# Epoch 34/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0079 - root_mean_squared_error: 0.0888INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 19s 372ms/step - loss: 0.0079 - root_mean_squared_error: 0.0888 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0960
# Epoch 35/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0076 - root_mean_squared_error: 0.0873INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 18s 342ms/step - loss: 0.0076 - root_mean_squared_error: 0.0873 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0899
# Epoch 36/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0072 - root_mean_squared_error: 0.0851 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1001
# Epoch 37/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.0075 - root_mean_squared_error: 0.0867 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0934
# Epoch 38/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0079 - root_mean_squared_error: 0.0889 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0949
# Epoch 39/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0073 - root_mean_squared_error: 0.0852INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 17s 335ms/step - loss: 0.0073 - root_mean_squared_error: 0.0852 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0784
# Epoch 40/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0074 - root_mean_squared_error: 0.0861 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0946
# Epoch 41/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0070 - root_mean_squared_error: 0.0837 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0836
# Epoch 42/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0067 - root_mean_squared_error: 0.0817 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0912
# Epoch 43/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0074 - root_mean_squared_error: 0.0862 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0811
# Epoch 44/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0073 - root_mean_squared_error: 0.0852 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0897
# Epoch 45/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0074 - root_mean_squared_error: 0.0859 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0890
# Epoch 46/50
# 53/53 [==============================] - 2s 47ms/step - loss: 0.0069 - root_mean_squared_error: 0.0830 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0895
# Epoch 47/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0072 - root_mean_squared_error: 0.0846 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 48/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0071 - root_mean_squared_error: 0.0843INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 18s 352ms/step - loss: 0.0071 - root_mean_squared_error: 0.0843 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0757
# Epoch 49/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0064 - root_mean_squared_error: 0.0798 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0920
# Epoch 50/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0065 - root_mean_squared_error: 0.0807INFO:tensorflow:Assets written to: Ross_model_LT4\assets
# 53/53 [==============================] - 18s 338ms/step - loss: 0.0065 - root_mean_squared_error: 0.0807 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0690

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 11.454181210199993 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Ross_model_LT4/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 28ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.08562135737735153
# MAE : 0.06395900019654381

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        3.948293e+06    3794128.369
# 1        3.982005e+06    3885746.442
# 2        3.804280e+06    3909211.179
# 3        3.334390e+06    3499167.351
# 4        2.446924e+06    2715890.297
# 5        7.772389e+05    1053272.694
# 6        2.995134e+05     368862.123
# 7        9.775141e+05     979418.298
# 8        1.774050e+06    2086269.569
# 9        2.527216e+06    2852731.016
# 10       3.138414e+06    3452823.613
# 11       3.564550e+06    3846843.974
# 12       3.801775e+06    4005222.451
# 13       3.855662e+06    4129684.505
# 14       3.713745e+06    4130311.577
# 15       3.296123e+06    3987590.376
# 16       2.343988e+06    2531664.630
# 17       6.138714e+05     864796.598
# 18       3.052181e+05     366098.623
# 19       9.371782e+05    1324063.884
# 20       1.868213e+06    2094086.684
# 21       2.714495e+06    2706708.526
# 22       3.344986e+06    3380172.167
# 23       3.765708e+06    3975727.475
# 24       4.013056e+06    4016497.161
# 25       4.086866e+06    4134594.766
# 26       3.942809e+06    4278165.933
# 27       3.484572e+06    3893945.909
# 28       2.541666e+06    2389171.083
# 29       6.950729e+05     896425.932
# 30       2.557799e+05     251374.224
# 31       9.762132e+05     455056.048
# 32       1.909214e+06    1780625.872
# 33       2.737652e+06    2914989.101
# 34       3.366603e+06    3561620.245
# 35       3.782186e+06    3991717.506
# 36       4.020020e+06    4559070.778
# 37       4.090301e+06    4596327.081
# 38       3.928566e+06    4565650.139
# 39       3.423464e+06    4061902.846
# 40       2.231524e+06    2336900.967
# 41       3.090106e+05     696917.659
# 42       4.325179e+04     213657.789
# 43       8.331868e+05     765773.883
# 44       1.868956e+06    1951730.202
# 45       2.782958e+06    2610971.814
# 46       3.472060e+06    3137598.938
# 47       3.975652e+06    3201783.453
# 48       4.268345e+06    2973294.266
# 49       4.348034e+06    3354839.711
# 50       4.212258e+06    3325613.245

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 30ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
