# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Weddell_Extent = pd.read_excel(filepath, sheet_name='Weddell-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Weddell_Extent)
fp.date_time(Weddell_Extent)
# Out:
#           Extent       Date
# 0    2136510.859 1979-01-01
# 1    1243495.891 1979-02-01
# 2    1699053.449 1979-03-01
# 3    2617442.085 1979-04-01
# 4    3852934.206 1979-05-01
# ..           ...        ...
# 533  3668127.143 2023-06-01
# 534  4805519.784 2023-07-01
# 535  5524445.234 2023-08-01
# 536  6006669.861 2023-09-01
# 537  5507961.583 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Weddell_Extent['Extent'] = scaler.fit_transform(Weddell_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 5
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Weddell_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((522, 12, 1), (522,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Weddell_model_LT5/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2268 - root_mean_squared_error: 0.4763INFO:tensorflow:Assets written to: Weddell_model_LT5\assets
# 53/53 [==============================] - 38s 510ms/step - loss: 0.2268 - root_mean_squared_error: 0.4763 - val_loss: 0.1111 - val_root_mean_squared_error: 0.3333
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0771 - root_mean_squared_error: 0.2777INFO:tensorflow:Assets written to: Weddell_model_LT5\assets
# 53/53 [==============================] - 25s 480ms/step - loss: 0.0772 - root_mean_squared_error: 0.2778 - val_loss: 0.0664 - val_root_mean_squared_error: 0.2576
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0620 - root_mean_squared_error: 0.2491INFO:tensorflow:Assets written to: Weddell_model_LT5\assets
# 53/53 [==============================] - 24s 459ms/step - loss: 0.0619 - root_mean_squared_error: 0.2488 - val_loss: 0.0525 - val_root_mean_squared_error: 0.2292
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0481 - root_mean_squared_error: 0.2194INFO:tensorflow:Assets written to: Weddell_model_LT5\assets
# 53/53 [==============================] - 25s 486ms/step - loss: 0.0481 - root_mean_squared_error: 0.2194 - val_loss: 0.0402 - val_root_mean_squared_error: 0.2004
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0309 - root_mean_squared_error: 0.1759INFO:tensorflow:Assets written to: Weddell_model_LT5\assets
# 53/53 [==============================] - 26s 494ms/step - loss: 0.0309 - root_mean_squared_error: 0.1759 - val_loss: 0.0195 - val_root_mean_squared_error: 0.1397
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0178 - root_mean_squared_error: 0.1334INFO:tensorflow:Assets written to: Weddell_model_LT5\assets
# 53/53 [==============================] - 23s 434ms/step - loss: 0.0177 - root_mean_squared_error: 0.1329 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0977
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0127 - root_mean_squared_error: 0.1125INFO:tensorflow:Assets written to: Weddell_model_LT5\assets
# 53/53 [==============================] - 19s 373ms/step - loss: 0.0127 - root_mean_squared_error: 0.1125 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0830
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0122 - root_mean_squared_error: 0.1105INFO:tensorflow:Assets written to: Weddell_model_LT5\assets
# 53/53 [==============================] - 18s 340ms/step - loss: 0.0122 - root_mean_squared_error: 0.1103 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0771
# Epoch 9/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0115 - root_mean_squared_error: 0.1072 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0778
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0098 - root_mean_squared_error: 0.0991INFO:tensorflow:Assets written to: Weddell_model_LT5\assets
# 53/53 [==============================] - 17s 335ms/step - loss: 0.0098 - root_mean_squared_error: 0.0992 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0665
# Epoch 11/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0089 - root_mean_squared_error: 0.0943 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0691
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0084 - root_mean_squared_error: 0.0915INFO:tensorflow:Assets written to: Weddell_model_LT5\assets
# 53/53 [==============================] - 18s 343ms/step - loss: 0.0084 - root_mean_squared_error: 0.0915 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0634
# Epoch 13/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0089 - root_mean_squared_error: 0.0944 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0761
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0078 - root_mean_squared_error: 0.0885INFO:tensorflow:Assets written to: Weddell_model_LT5\assets
# 53/53 [==============================] - 18s 337ms/step - loss: 0.0078 - root_mean_squared_error: 0.0885 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0618
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0077 - root_mean_squared_error: 0.0879INFO:tensorflow:Assets written to: Weddell_model_LT5\assets
# 53/53 [==============================] - 18s 341ms/step - loss: 0.0077 - root_mean_squared_error: 0.0879 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0067 - root_mean_squared_error: 0.0817INFO:tensorflow:Assets written to: Weddell_model_LT5\assets
# 53/53 [==============================] - 17s 327ms/step - loss: 0.0067 - root_mean_squared_error: 0.0817 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0603
# Epoch 17/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0066 - root_mean_squared_error: 0.0811 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0605
# Epoch 18/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0070 - root_mean_squared_error: 0.0838 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0726
# Epoch 19/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0066 - root_mean_squared_error: 0.0815 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0607
# Epoch 20/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0061 - root_mean_squared_error: 0.0782INFO:tensorflow:Assets written to: Weddell_model_LT5\assets
# 53/53 [==============================] - 17s 328ms/step - loss: 0.0061 - root_mean_squared_error: 0.0779 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0585
# Epoch 21/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0064 - root_mean_squared_error: 0.0802INFO:tensorflow:Assets written to: Weddell_model_LT5\assets
# 53/53 [==============================] - 17s 323ms/step - loss: 0.0064 - root_mean_squared_error: 0.0802 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0577
# Epoch 22/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0058 - root_mean_squared_error: 0.0764 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0651
# Epoch 23/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0054 - root_mean_squared_error: 0.0737INFO:tensorflow:Assets written to: Weddell_model_LT5\assets
# 53/53 [==============================] - 17s 331ms/step - loss: 0.0054 - root_mean_squared_error: 0.0736 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0569
# Epoch 24/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0058 - root_mean_squared_error: 0.0760 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0598
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0059 - root_mean_squared_error: 0.0766INFO:tensorflow:Assets written to: Weddell_model_LT5\assets
# 53/53 [==============================] - 18s 339ms/step - loss: 0.0059 - root_mean_squared_error: 0.0766 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0567
# Epoch 26/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0054 - root_mean_squared_error: 0.0734 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0568
# Epoch 27/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0053 - root_mean_squared_error: 0.0730 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0584
# Epoch 28/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0056 - root_mean_squared_error: 0.0747 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0595
# Epoch 29/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0059 - root_mean_squared_error: 0.0766 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0594
# Epoch 30/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0050 - root_mean_squared_error: 0.0706 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0595
# Epoch 31/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0052 - root_mean_squared_error: 0.0719 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613
# Epoch 32/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0053 - root_mean_squared_error: 0.0728 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0582
# Epoch 33/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0051 - root_mean_squared_error: 0.0714 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0608
# Epoch 34/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0051 - root_mean_squared_error: 0.0715 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0670
# Epoch 35/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0052 - root_mean_squared_error: 0.0720 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0602
# Epoch 36/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0046 - root_mean_squared_error: 0.0680 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0597
# Epoch 37/50
# 53/53 [==============================] - 3s 49ms/step - loss: 0.0051 - root_mean_squared_error: 0.0718 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0697
# Epoch 38/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0052 - root_mean_squared_error: 0.0724 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0583
# Epoch 39/50
# 53/53 [==============================] - 2s 46ms/step - loss: 0.0053 - root_mean_squared_error: 0.0728 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0670
# Epoch 40/50
# 53/53 [==============================] - 2s 43ms/step - loss: 0.0050 - root_mean_squared_error: 0.0704 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0673
# Epoch 41/50
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0049 - root_mean_squared_error: 0.0698 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0590
# Epoch 42/50
# 53/53 [==============================] - 2s 43ms/step - loss: 0.0050 - root_mean_squared_error: 0.0705 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0576
# Epoch 43/50
# 53/53 [==============================] - 2s 43ms/step - loss: 0.0049 - root_mean_squared_error: 0.0700 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0569
# Epoch 44/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0044 - root_mean_squared_error: 0.0665 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0576
# Epoch 45/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0050 - root_mean_squared_error: 0.0705 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0584
# Epoch 46/50
# 53/53 [==============================] - 3s 47ms/step - loss: 0.0044 - root_mean_squared_error: 0.0666 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0638
# Epoch 47/50
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0049 - root_mean_squared_error: 0.0699 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613
# Epoch 48/50
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0044 - root_mean_squared_error: 0.0664 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0569
# Epoch 49/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0048 - root_mean_squared_error: 0.0695 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0596
# Epoch 50/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0043 - root_mean_squared_error: 0.0653 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0630

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 7.47169105609258 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Weddell_model_LT5/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 17ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.060349665616776474
# MAE : 0.052048583253054045

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        6.088194e+06    6669726.076
# 1        5.994012e+06    6516136.854
# 2        5.276288e+06    5902163.675
# 3        3.793476e+06    3498103.449
# 4        1.425714e+06    1633675.726
# 5        7.534301e+05    1292668.399
# 6        1.185702e+06    1527666.815
# 7        2.130950e+06    2121949.701
# 8        3.381952e+06    3562381.775
# 9        4.557974e+06    5004305.983
# 10       5.492328e+06    6176613.878
# 11       6.141594e+06    6794233.093
# 12       6.466526e+06    7024136.637
# 13       6.284553e+06    6554271.388
# 14       5.411224e+06    6172281.701
# 15       3.725814e+06    4175225.799
# 16       1.271204e+06    1748380.899
# 17       7.601158e+05    1256191.080
# 18       1.291694e+06    1347295.364
# 19       2.338992e+06    2180184.677
# 20       3.595848e+06    3419295.982
# 21       4.830734e+06    4786146.771
# 22       5.806504e+06    5968132.718
# 23       6.492313e+06    6556934.174
# 24       6.820167e+06    6614949.980
# 25       6.610970e+06    6035207.368
# 26       5.751066e+06    5274244.730
# 27       4.196165e+06    3505146.372
# 28       1.705747e+06    1478130.228
# 29       8.106570e+05    1096780.503
# 30       1.262313e+06    1387234.069
# 31       2.314398e+06    2128693.591
# 32       3.629841e+06    3313318.704
# 33       4.752964e+06    4218076.656
# 34       5.600884e+06    5257641.941
# 35       6.185390e+06    5956603.340
# 36       6.418147e+06    6256062.049
# 37       6.158109e+06    5974548.305
# 38       5.389914e+06    5569396.731
# 39       4.054650e+06    3684108.410
# 40       1.905030e+06    1451614.707
# 41       9.183475e+05    1089888.684
# 42       1.318211e+06    1255222.909
# 43       2.179837e+06    1704492.279
# 44       3.317166e+06    2563551.804
# 45       4.385502e+06    3668127.143
# 46       5.222166e+06    4805519.784
# 47       5.808884e+06    5524445.234
# 48       6.106902e+06    6006669.861
# 49       6.005638e+06    5507961.583

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 27ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
