# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Pacific_Extent = pd.read_excel(filepath, sheet_name='Pacific-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Pacific_Extent)
fp.date_time(Pacific_Extent)
# Out:
#           Extent       Date
# 0     668714.275 1979-01-01
# 1     566930.458 1979-02-01
# 2     688420.115 1979-03-01
# 3     859963.043 1979-04-01
# 4    1127120.160 1979-05-01
# ..           ...        ...
# 533  1134056.102 2023-06-01
# 534  1484824.377 2023-07-01
# 535  1671324.717 2023-08-01
# 536  1726376.097 2023-09-01
# 537  1690631.996 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Pacific_Extent['Extent'] = scaler.fit_transform(Pacific_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 8
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Pacific_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((519, 12, 1), (519,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Pacific_model_LT8/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.2246 - root_mean_squared_error: 0.4740INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 33s 434ms/step - loss: 0.2256 - root_mean_squared_error: 0.4750 - val_loss: 0.1786 - val_root_mean_squared_error: 0.4226
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0869 - root_mean_squared_error: 0.2949INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 21s 405ms/step - loss: 0.0868 - root_mean_squared_error: 0.2946 - val_loss: 0.0520 - val_root_mean_squared_error: 0.2281
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0499 - root_mean_squared_error: 0.2233INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 21s 403ms/step - loss: 0.0499 - root_mean_squared_error: 0.2233 - val_loss: 0.0451 - val_root_mean_squared_error: 0.2124
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0429 - root_mean_squared_error: 0.2070INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 21s 412ms/step - loss: 0.0429 - root_mean_squared_error: 0.2070 - val_loss: 0.0378 - val_root_mean_squared_error: 0.1943
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0377 - root_mean_squared_error: 0.1941INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 23s 441ms/step - loss: 0.0377 - root_mean_squared_error: 0.1941 - val_loss: 0.0308 - val_root_mean_squared_error: 0.1755
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0287 - root_mean_squared_error: 0.1693INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 24s 460ms/step - loss: 0.0287 - root_mean_squared_error: 0.1693 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1642
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0223 - root_mean_squared_error: 0.1492INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 25s 472ms/step - loss: 0.0223 - root_mean_squared_error: 0.1492 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1303
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0167 - root_mean_squared_error: 0.1294INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 26s 490ms/step - loss: 0.0167 - root_mean_squared_error: 0.1294 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1151
# Epoch 9/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0140 - root_mean_squared_error: 0.1183INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 22s 419ms/step - loss: 0.0141 - root_mean_squared_error: 0.1185 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1134
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0135 - root_mean_squared_error: 0.1162INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 23s 444ms/step - loss: 0.0135 - root_mean_squared_error: 0.1162 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0992
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0131 - root_mean_squared_error: 0.1143INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 24s 455ms/step - loss: 0.0130 - root_mean_squared_error: 0.1140 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0903
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0116 - root_mean_squared_error: 0.1075INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 21s 397ms/step - loss: 0.0117 - root_mean_squared_error: 0.1082 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0862
# Epoch 13/50
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0100 - root_mean_squared_error: 0.1001 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0867
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0101 - root_mean_squared_error: 0.1007INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 22s 420ms/step - loss: 0.0101 - root_mean_squared_error: 0.1007 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0796
# Epoch 15/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0094 - root_mean_squared_error: 0.0971 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0936
# Epoch 16/50
# 53/53 [==============================] - 3s 49ms/step - loss: 0.0098 - root_mean_squared_error: 0.0989 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0828
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0091 - root_mean_squared_error: 0.0954INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 25s 477ms/step - loss: 0.0091 - root_mean_squared_error: 0.0954 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0729
# Epoch 18/50
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0089 - root_mean_squared_error: 0.0943 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0789
# Epoch 19/50
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0081 - root_mean_squared_error: 0.0901 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0749
# Epoch 20/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0090 - root_mean_squared_error: 0.0948 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0755
# Epoch 21/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.0086 - root_mean_squared_error: 0.0927 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0830
# Epoch 22/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0078 - root_mean_squared_error: 0.0885 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0745
# Epoch 23/50
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0084 - root_mean_squared_error: 0.0914 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0743
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0084 - root_mean_squared_error: 0.0915INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 24s 456ms/step - loss: 0.0084 - root_mean_squared_error: 0.0915 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0708
# Epoch 25/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0075 - root_mean_squared_error: 0.0865 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 26/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0074 - root_mean_squared_error: 0.0857INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 23s 442ms/step - loss: 0.0074 - root_mean_squared_error: 0.0857 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0699
# Epoch 27/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0071 - root_mean_squared_error: 0.0844INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 23s 438ms/step - loss: 0.0071 - root_mean_squared_error: 0.0844 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0674
# Epoch 28/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0070 - root_mean_squared_error: 0.0839 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0719
# Epoch 29/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0071 - root_mean_squared_error: 0.0845 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0718
# Epoch 30/50
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0067 - root_mean_squared_error: 0.0820 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0705
# Epoch 31/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0069 - root_mean_squared_error: 0.0832 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0753
# Epoch 32/50
# 53/53 [==============================] - 4s 75ms/step - loss: 0.0070 - root_mean_squared_error: 0.0838 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0815
# Epoch 33/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0067 - root_mean_squared_error: 0.0819 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0798
# Epoch 34/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.0068 - root_mean_squared_error: 0.0827 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0715
# Epoch 35/50
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0065 - root_mean_squared_error: 0.0805 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0742
# Epoch 36/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0066 - root_mean_squared_error: 0.0811INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 23s 435ms/step - loss: 0.0066 - root_mean_squared_error: 0.0811 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0667
# Epoch 37/50
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0066 - root_mean_squared_error: 0.0814 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0794
# Epoch 38/50
# 53/53 [==============================] - 3s 49ms/step - loss: 0.0064 - root_mean_squared_error: 0.0800 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0846
# Epoch 39/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0063 - root_mean_squared_error: 0.0794 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0694
# Epoch 40/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0067 - root_mean_squared_error: 0.0818 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0671
# Epoch 41/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0063 - root_mean_squared_error: 0.0793INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 23s 440ms/step - loss: 0.0063 - root_mean_squared_error: 0.0793 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0645
# Epoch 42/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0065 - root_mean_squared_error: 0.0808 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0851
# Epoch 43/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0067 - root_mean_squared_error: 0.0820 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0701
# Epoch 44/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0062 - root_mean_squared_error: 0.0786 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0817
# Epoch 45/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0063 - root_mean_squared_error: 0.0792 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0659
# Epoch 46/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0062 - root_mean_squared_error: 0.0790 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0671
# Epoch 47/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0072 - root_mean_squared_error: 0.0846 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0658
# Epoch 48/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0067 - root_mean_squared_error: 0.0818 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0704
# Epoch 49/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0060 - root_mean_squared_error: 0.0775 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0748
# Epoch 50/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0061 - root_mean_squared_error: 0.0783 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0759

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 9.20576850970586 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Pacific_model_LT8/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 29ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.06428674694770975
# MAE : 0.04959949594417416

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        9.018379e+05     863206.294
# 1        5.205130e+05     635624.004
# 2        4.102615e+05     460009.672
# 3        5.247446e+05     610848.036
# 4        8.668766e+05     819257.445
# 5        1.164946e+06    1129627.707
# 6        1.471145e+06    1463383.236
# 7        1.707454e+06    1614536.727
# 8        1.881529e+06    1862498.612
# 9        1.968342e+06    2099349.296
# 10       1.936576e+06    1981614.046
# 11       1.558004e+06    1433022.369
# 12       9.611411e+05     826739.716
# 13       5.283908e+05     477145.887
# 14       3.828755e+05     314469.289
# 15       4.562527e+05     463134.749
# 16       7.610856e+05     946522.292
# 17       1.154827e+06    1309266.570
# 18       1.481651e+06    1507947.309
# 19       1.712241e+06    1804167.937
# 20       1.879459e+06    1908002.139
# 21       1.965917e+06    1892748.521
# 22       1.890043e+06    1601079.640
# 23       1.525195e+06    1327804.521
# 24       8.938089e+05     812074.231
# 25       4.947415e+05     493355.897
# 26       3.906971e+05     317229.330
# 27       4.970072e+05     425777.624
# 28       8.258944e+05     827172.620
# 29       1.173811e+06    1162367.223
# 30       1.502815e+06    1413734.261
# 31       1.747529e+06    1574257.849
# 32       1.891303e+06    1786961.251
# 33       1.931695e+06    1857942.866
# 34       1.807587e+06    1406291.588
# 35       1.316509e+06    1025555.371
# 36       7.495273e+05     632862.782
# 37       4.362838e+05     308194.756
# 38       3.600152e+05     194921.078
# 39       5.170510e+05     245569.900
# 40       8.905159e+05     533532.424
# 41       1.175508e+06     943124.529
# 42       1.430969e+06    1134056.102
# 43       1.651250e+06    1484824.377
# 44       1.790475e+06    1671324.717
# 45       1.828220e+06    1726376.097
# 46       1.718896e+06    1690631.996

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 18ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
