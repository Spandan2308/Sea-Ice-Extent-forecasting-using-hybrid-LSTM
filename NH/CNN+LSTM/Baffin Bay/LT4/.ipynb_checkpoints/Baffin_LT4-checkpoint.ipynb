# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Baffin = pd.read_excel(filepath, sheet_name='Baffin-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Baffin)
fp.date_time(Baffin)
# Out:
#           Extent       Date
# 0    1090625.815 1979-01-01
# 1    1157634.866 1979-02-01
# 2    1299583.477 1979-03-01
# 3    1137194.680 1979-04-01
# 4     983083.453 1979-05-01
# ..           ...        ...
# 533   781460.891 2023-06-01
# 534   331845.048 2023-07-01
# 535    99334.625 2023-08-01
# 536    49359.723 2023-09-01
# 537    85693.282 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Baffin['Extent'] = scaler.fit_transform(Baffin['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 4
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]  # Adjusted for lead time
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Baffin['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((523, 12, 1), (523,))

# %%
X_train, y_train = X[:418], y[:418]
X_val, y_val = X[418:470], y[418:470]
X_test, y_test = X[470:], y[470:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Baffin_model_LT4/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.2907 - root_mean_squared_error: 0.5392
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 9s 106ms/step - loss: 0.2848 - root_mean_squared_error: 0.5337 - val_loss: 0.2144 - val_root_mean_squared_error: 0.4631
# Epoch 2/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.1948 - root_mean_squared_error: 0.4414
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.1905 - root_mean_squared_error: 0.4364 - val_loss: 0.1904 - val_root_mean_squared_error: 0.4363
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1346 - root_mean_squared_error: 0.3669
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 96ms/step - loss: 0.1346 - root_mean_squared_error: 0.3669 - val_loss: 0.1619 - val_root_mean_squared_error: 0.4024
# Epoch 4/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.1027 - root_mean_squared_error: 0.3204
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 103ms/step - loss: 0.1017 - root_mean_squared_error: 0.3190 - val_loss: 0.1330 - val_root_mean_squared_error: 0.3647
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0812 - root_mean_squared_error: 0.2849
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0812 - root_mean_squared_error: 0.2849 - val_loss: 0.1073 - val_root_mean_squared_error: 0.3275
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0641 - root_mean_squared_error: 0.2531
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 102ms/step - loss: 0.0641 - root_mean_squared_error: 0.2531 - val_loss: 0.0894 - val_root_mean_squared_error: 0.2989
# Epoch 7/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0545 - root_mean_squared_error: 0.2334
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0510 - root_mean_squared_error: 0.2257 - val_loss: 0.0704 - val_root_mean_squared_error: 0.2654
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0382 - root_mean_squared_error: 0.1955
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0382 - root_mean_squared_error: 0.1955 - val_loss: 0.0581 - val_root_mean_squared_error: 0.2411
# Epoch 9/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0271 - root_mean_squared_error: 0.1647
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0290 - root_mean_squared_error: 0.1704 - val_loss: 0.0448 - val_root_mean_squared_error: 0.2116
# Epoch 10/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0282 - root_mean_squared_error: 0.1678
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0259 - root_mean_squared_error: 0.1610 - val_loss: 0.0321 - val_root_mean_squared_error: 0.1793
# Epoch 11/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0197 - root_mean_squared_error: 0.1404
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0190 - root_mean_squared_error: 0.1377 - val_loss: 0.0223 - val_root_mean_squared_error: 0.1494
# Epoch 12/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0201 - root_mean_squared_error: 0.1417
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 103ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1227
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0155 - root_mean_squared_error: 0.1245
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0159 - root_mean_squared_error: 0.1263 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0942
# Epoch 14/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0171 - root_mean_squared_error: 0.1307
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0169 - root_mean_squared_error: 0.1300 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0757
# Epoch 15/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0173 - root_mean_squared_error: 0.1314
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 100ms/step - loss: 0.0158 - root_mean_squared_error: 0.1258 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0634
# Epoch 16/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0146 - root_mean_squared_error: 0.1207
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0588
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0159 - root_mean_squared_error: 0.1263 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0666
# Epoch 18/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0124 - root_mean_squared_error: 0.1115 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0591
# Epoch 19/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0154 - root_mean_squared_error: 0.1242
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 98ms/step - loss: 0.0163 - root_mean_squared_error: 0.1276 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0568
# Epoch 20/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0147 - root_mean_squared_error: 0.1213
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 99ms/step - loss: 0.0137 - root_mean_squared_error: 0.1172 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0564
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0176 - root_mean_squared_error: 0.1326 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0578
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0154 - root_mean_squared_error: 0.1239
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 94ms/step - loss: 0.0154 - root_mean_squared_error: 0.1239 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0564
# Epoch 23/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0137 - root_mean_squared_error: 0.1169 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0586
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0119 - root_mean_squared_error: 0.1089
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 92ms/step - loss: 0.0119 - root_mean_squared_error: 0.1089 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0562
# Epoch 25/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0111 - root_mean_squared_error: 0.1054 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0598
# Epoch 26/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0141 - root_mean_squared_error: 0.1186
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 93ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0560
# Epoch 27/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0148 - root_mean_squared_error: 0.1216
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 90ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0559
# Epoch 28/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0127 - root_mean_squared_error: 0.1126 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613
# Epoch 29/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0184 - root_mean_squared_error: 0.1355
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 95ms/step - loss: 0.0171 - root_mean_squared_error: 0.1308 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0553
# Epoch 30/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0140 - root_mean_squared_error: 0.1183 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0559
# Epoch 31/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0155 - root_mean_squared_error: 0.1244 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0574
# Epoch 32/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0134 - root_mean_squared_error: 0.1158 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0564
# Epoch 33/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0139 - root_mean_squared_error: 0.1179 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0555
# Epoch 34/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0130 - root_mean_squared_error: 0.1142
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 89ms/step - loss: 0.0135 - root_mean_squared_error: 0.1160 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0547
# Epoch 35/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0155 - root_mean_squared_error: 0.1244 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0552
# Epoch 36/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0121 - root_mean_squared_error: 0.1100 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0658
# Epoch 37/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0157 - root_mean_squared_error: 0.1254 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0550
# Epoch 38/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0153 - root_mean_squared_error: 0.1237 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0723
# Epoch 39/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0133 - root_mean_squared_error: 0.1151 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0778
# Epoch 40/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0132 - root_mean_squared_error: 0.1149 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0584
# Epoch 41/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0145 - root_mean_squared_error: 0.1205
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 5s 87ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0544
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0147 - root_mean_squared_error: 0.1214 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0560
# Epoch 43/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0129 - root_mean_squared_error: 0.1137 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0546
# Epoch 44/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0841
# Epoch 45/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0121 - root_mean_squared_error: 0.1098 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0562
# Epoch 46/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0141 - root_mean_squared_error: 0.1188
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# INFO:tensorflow:Assets written to: Baffin_model_LT4\assets
# 53/53 [==============================] - 4s 77ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0540
# Epoch 47/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0150 - root_mean_squared_error: 0.1226 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0548
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0115 - root_mean_squared_error: 0.1074 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0549
# Epoch 49/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0109 - root_mean_squared_error: 0.1042 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0781
# Epoch 50/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0131 - root_mean_squared_error: 0.1144 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0618

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 2.355971630414327 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %% [markdown]
# Test Predictions

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Baffin_model_LT4/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 16ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))
# Out:
# RMSE : 0.06401520777009566

# %%
mae = mean_absolute_error(y_test, test_predictions)
print(mae)
# Out:
# 0.04951553108101522

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %% [markdown]
# Prediction on whole dataset

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
mse = mean_squared_error(y, predictions)
print(mse)
# Out:
# 0.0037575852278049866

# %%
mae = mean_absolute_error(y, predictions)
print(mae)
# Out:
# 0.04810561324110379

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
