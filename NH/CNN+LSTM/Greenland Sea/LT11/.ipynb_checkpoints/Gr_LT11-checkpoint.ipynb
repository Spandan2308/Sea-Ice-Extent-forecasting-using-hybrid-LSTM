# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Greenland = pd.read_excel(filepath, sheet_name='Greenland-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Greenland)
fp.date_time(Greenland)
# Out:
#           Extent       Date
# 0    1076123.146 1979-01-01
# 1    1099248.063 1979-02-01
# 2    1036964.901 1979-03-01
# 3     958927.937 1979-04-01
# 4     823812.694 1979-05-01
# ..           ...        ...
# 533   721350.515 2023-06-01
# 534   459033.164 2023-07-01
# 535   282045.909 2023-08-01
# 536   270397.608 2023-09-01
# 537   449910.973 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Greenland['Extent'] = scaler.fit_transform(Greenland['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 11
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]  # Adjusted for lead time
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Greenland['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((524, 12, 1), (524,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Greenland_model_LT11/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.3224 - root_mean_squared_error: 0.5678
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# 53/53 [==============================] - 6s 78ms/step - loss: 0.3132 - root_mean_squared_error: 0.5597 - val_loss: 0.1500 - val_root_mean_squared_error: 0.3873
# Epoch 2/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.2411 - root_mean_squared_error: 0.4911
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# 53/53 [==============================] - 4s 78ms/step - loss: 0.2414 - root_mean_squared_error: 0.4913 - val_loss: 0.1161 - val_root_mean_squared_error: 0.3407
# Epoch 3/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.1937 - root_mean_squared_error: 0.4401
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# 53/53 [==============================] - 3s 59ms/step - loss: 0.1934 - root_mean_squared_error: 0.4398 - val_loss: 0.0866 - val_root_mean_squared_error: 0.2943
# Epoch 4/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1548 - root_mean_squared_error: 0.3934
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# 53/53 [==============================] - 3s 60ms/step - loss: 0.1537 - root_mean_squared_error: 0.3920 - val_loss: 0.0650 - val_root_mean_squared_error: 0.2550
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1188 - root_mean_squared_error: 0.3446
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# 53/53 [==============================] - 3s 55ms/step - loss: 0.1188 - root_mean_squared_error: 0.3446 - val_loss: 0.0492 - val_root_mean_squared_error: 0.2219
# Epoch 6/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0954 - root_mean_squared_error: 0.3089
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0934 - root_mean_squared_error: 0.3057 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1832
# Epoch 7/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0682 - root_mean_squared_error: 0.2611
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0701 - root_mean_squared_error: 0.2647 - val_loss: 0.0279 - val_root_mean_squared_error: 0.1670
# Epoch 8/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0562 - root_mean_squared_error: 0.2370
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0540 - root_mean_squared_error: 0.2325 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1476
# Epoch 9/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.0431 - root_mean_squared_error: 0.2075
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0407 - root_mean_squared_error: 0.2017 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1367
# Epoch 10/50
# 43/53 [=======================>......] - ETA: 0s - loss: 0.0343 - root_mean_squared_error: 0.1852
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0322 - root_mean_squared_error: 0.1793 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1300
# Epoch 11/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0241 - root_mean_squared_error: 0.1551 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1302
# Epoch 12/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0196 - root_mean_squared_error: 0.1402 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1313
# Epoch 13/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0169 - root_mean_squared_error: 0.1300
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0165 - root_mean_squared_error: 0.1285 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1207
# Epoch 14/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0147 - root_mean_squared_error: 0.1211
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0155 - root_mean_squared_error: 0.1246 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1188
# Epoch 15/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0134 - root_mean_squared_error: 0.1160 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1274
# Epoch 16/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0143 - root_mean_squared_error: 0.1194
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0141 - root_mean_squared_error: 0.1189 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1124
# Epoch 17/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0133 - root_mean_squared_error: 0.1151
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0134 - root_mean_squared_error: 0.1157 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1096
# Epoch 18/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0146 - root_mean_squared_error: 0.1208 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1501
# Epoch 19/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0131 - root_mean_squared_error: 0.1147 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1402
# Epoch 20/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0136 - root_mean_squared_error: 0.1166 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1129
# Epoch 21/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0119 - root_mean_squared_error: 0.1093 - val_loss: 0.0240 - val_root_mean_squared_error: 0.1551
# Epoch 22/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.0307 - val_root_mean_squared_error: 0.1752
# Epoch 23/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0113 - root_mean_squared_error: 0.1062 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1102
# Epoch 24/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0130 - root_mean_squared_error: 0.1139 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1154
# Epoch 25/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0129 - root_mean_squared_error: 0.1135 - val_loss: 0.0226 - val_root_mean_squared_error: 0.1502
# Epoch 26/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0123 - root_mean_squared_error: 0.1111 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1197
# Epoch 27/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1367
# Epoch 28/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0122 - root_mean_squared_error: 0.1105 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1376
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0121 - root_mean_squared_error: 0.1101 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1144
# Epoch 30/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0127 - root_mean_squared_error: 0.1128
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0129 - root_mean_squared_error: 0.1137 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1080
# Epoch 31/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0124 - root_mean_squared_error: 0.1112 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1143
# Epoch 32/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0120 - root_mean_squared_error: 0.1097
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0123 - root_mean_squared_error: 0.1111 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1035
# Epoch 33/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0119 - root_mean_squared_error: 0.1093 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1548
# Epoch 34/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1073
# Epoch 35/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0117 - root_mean_squared_error: 0.1081 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1261
# Epoch 36/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0127 - root_mean_squared_error: 0.1126 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1041
# Epoch 37/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0101 - root_mean_squared_error: 0.1006
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT3\assets
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0102 - root_mean_squared_error: 0.1010 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1022
# Epoch 38/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0121 - root_mean_squared_error: 0.1099 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1646
# Epoch 39/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1446
# Epoch 40/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0112 - root_mean_squared_error: 0.1060 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1039
# Epoch 41/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0110 - root_mean_squared_error: 0.1048 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1035
# Epoch 42/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0117 - root_mean_squared_error: 0.1080 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1306
# Epoch 43/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0121 - root_mean_squared_error: 0.1098 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1180
# Epoch 44/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0118 - root_mean_squared_error: 0.1085 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1121
# Epoch 45/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0119 - root_mean_squared_error: 0.1093 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1526
# Epoch 46/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0129 - root_mean_squared_error: 0.1135 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1337
# Epoch 47/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0129 - root_mean_squared_error: 0.1137 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1189
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0109 - root_mean_squared_error: 0.1044 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1053
# Epoch 49/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1118
# Epoch 50/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1242

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.1601461529731751 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Greenland_model_LT11/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 0s/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.10259069230198968
# MAE : 0.08828733421151136

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       241487.812500     436530.907
# 1       172990.562500     283162.646
# 2       143291.687500     212475.431
# 3       299120.000000     386546.857
# 4       421508.281250     547183.986
# 5       512695.593750     584596.262
# 6       582959.937500     584830.109
# 7       652372.875000     641562.292
# 8       659956.937500     734946.437
# 9       674227.375000     777596.225
# 10      588457.750000     687087.673
# 11      562120.750000     622337.816
# 12      366022.156250     467232.074
# 13      318514.937500     297495.641
# 14      163949.484375     268909.854
# 15      354591.406250     408072.791
# 16      425060.656250     552314.148
# 17      557970.125000     651062.408
# 18      619982.312500     695022.674
# 19      665659.937500     670974.305
# 20      706992.500000     710035.543
# 21      714937.875000     699672.538
# 22      661351.250000     730897.021
# 23      551306.062500     588598.988
# 24      395823.750000     281754.041
# 25      274541.906250     117830.266
# 26      237235.265625      81838.250
# 27      273984.718750     291418.462
# 28      501317.687500     452417.079
# 29      489480.968750     576361.148
# 30      617363.437500     676218.054
# 31      586624.750000     698410.066
# 32      687002.437500     696094.179
# 33      631986.375000     751102.742
# 34      598773.437500     765802.952
# 35      452338.718750     597649.311
# 36      262749.937500     376029.266
# 37      217402.921875     278536.574
# 38       71881.484375     285351.521
# 39      279985.187500     365256.138
# 40      434892.625000     488293.212
# 41      536598.562500     635073.900
# 42      632922.125000     684651.888
# 43      653627.937500     698053.275
# 44      716486.562500     846211.943
# 45      694025.000000     831596.370
# 46      676261.312500     834849.724
# 47      523419.812500     721350.515
# 48      375305.968750     459033.164
# 49      187277.281250     282045.909
# 50      186039.609375     270397.608
# 51      242682.734375     449910.973

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
