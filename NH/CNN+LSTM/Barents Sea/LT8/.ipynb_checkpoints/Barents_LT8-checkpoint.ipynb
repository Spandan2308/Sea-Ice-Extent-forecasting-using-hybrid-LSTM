# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Barents = pd.read_excel(filepath, sheet_name='Barents-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Barents)
fp.date_time(Barents)
# Out:
#           Extent       Date
# 0    1107873.946 1979-01-01
# 1    1211101.473 1979-02-01
# 2    1215128.770 1979-03-01
# 3    1233940.811 1979-04-01
# 4    1193061.566 1979-05-01
# ..           ...        ...
# 533   124025.343 2023-06-01
# 534    53107.426 2023-07-01
# 535    11242.827 2023-08-01
# 536     3272.024 2023-09-01
# 537    35079.225 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Barents['Extent'] = scaler.fit_transform(Barents['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 8
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]  # Adjusted for lead time
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Barents['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((519, 12, 1), (519,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Barents_model_LT8/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.2084 - root_mean_squared_error: 0.4565
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# 53/53 [==============================] - 8s 99ms/step - loss: 0.2060 - root_mean_squared_error: 0.4539 - val_loss: 0.0513 - val_root_mean_squared_error: 0.2266
# Epoch 2/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1352 - root_mean_squared_error: 0.3677
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.1361 - root_mean_squared_error: 0.3689 - val_loss: 0.0442 - val_root_mean_squared_error: 0.2102
# Epoch 3/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1052 - root_mean_squared_error: 0.3244
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# 53/53 [==============================] - 4s 67ms/step - loss: 0.1035 - root_mean_squared_error: 0.3216 - val_loss: 0.0364 - val_root_mean_squared_error: 0.1909
# Epoch 4/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0786 - root_mean_squared_error: 0.2804
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# 53/53 [==============================] - 4s 75ms/step - loss: 0.0788 - root_mean_squared_error: 0.2808 - val_loss: 0.0310 - val_root_mean_squared_error: 0.1761
# Epoch 5/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0613 - root_mean_squared_error: 0.2475
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# 53/53 [==============================] - 4s 78ms/step - loss: 0.0610 - root_mean_squared_error: 0.2470 - val_loss: 0.0272 - val_root_mean_squared_error: 0.1649
# Epoch 6/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0468 - root_mean_squared_error: 0.2163
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# 53/53 [==============================] - 5s 91ms/step - loss: 0.0462 - root_mean_squared_error: 0.2148 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1592
# Epoch 7/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0379 - root_mean_squared_error: 0.1946
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# 53/53 [==============================] - 5s 103ms/step - loss: 0.0373 - root_mean_squared_error: 0.1931 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1565
# Epoch 8/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0318 - root_mean_squared_error: 0.1783
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0316 - root_mean_squared_error: 0.1778 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1530
# Epoch 9/50
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0269 - root_mean_squared_error: 0.1640
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# 53/53 [==============================] - 6s 106ms/step - loss: 0.0269 - root_mean_squared_error: 0.1639 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1497
# Epoch 10/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0231 - root_mean_squared_error: 0.1519
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# 53/53 [==============================] - 5s 96ms/step - loss: 0.0223 - root_mean_squared_error: 0.1493 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1446
# Epoch 11/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0205 - root_mean_squared_error: 0.1434
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# 53/53 [==============================] - 6s 113ms/step - loss: 0.0218 - root_mean_squared_error: 0.1477 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1372
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0199 - root_mean_squared_error: 0.1409
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# 53/53 [==============================] - 5s 101ms/step - loss: 0.0199 - root_mean_squared_error: 0.1409 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1210
# Epoch 13/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0167 - root_mean_squared_error: 0.1293
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# 53/53 [==============================] - 4s 81ms/step - loss: 0.0160 - root_mean_squared_error: 0.1266 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1099
# Epoch 14/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0175 - root_mean_squared_error: 0.1322
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0173 - root_mean_squared_error: 0.1316 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 15/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0188 - root_mean_squared_error: 0.1371 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1120
# Epoch 16/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0232 - root_mean_squared_error: 0.1524
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# 53/53 [==============================] - 4s 82ms/step - loss: 0.0231 - root_mean_squared_error: 0.1519 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1003
# Epoch 17/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0189 - root_mean_squared_error: 0.1377 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1019
# Epoch 18/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0209 - root_mean_squared_error: 0.1445 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1015
# Epoch 19/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0145 - root_mean_squared_error: 0.1206 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1093
# Epoch 20/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0176 - root_mean_squared_error: 0.1326 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1015
# Epoch 21/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0159 - root_mean_squared_error: 0.1260
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0171 - root_mean_squared_error: 0.1308 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0998
# Epoch 22/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0170 - root_mean_squared_error: 0.1302 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1000
# Epoch 23/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0184 - root_mean_squared_error: 0.1358 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1091
# Epoch 24/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0152 - root_mean_squared_error: 0.1231 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1085
# Epoch 25/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0163 - root_mean_squared_error: 0.1277 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1068
# Epoch 26/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0215 - root_mean_squared_error: 0.1465 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1038
# Epoch 27/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0159 - root_mean_squared_error: 0.1260 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1043
# Epoch 28/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1042
# Epoch 29/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0159 - root_mean_squared_error: 0.1263 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1084
# Epoch 30/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0157 - root_mean_squared_error: 0.1254 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1003
# Epoch 31/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0157 - root_mean_squared_error: 0.1251 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1024
# Epoch 32/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0166 - root_mean_squared_error: 0.1289
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# INFO:tensorflow:Assets written to: Barents_model_LT8\assets
# 53/53 [==============================] - 4s 83ms/step - loss: 0.0166 - root_mean_squared_error: 0.1289 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 33/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0163 - root_mean_squared_error: 0.1277 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1164
# Epoch 34/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1072
# Epoch 35/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0190 - root_mean_squared_error: 0.1377 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 36/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0171 - root_mean_squared_error: 0.1307 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1042
# Epoch 37/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0164 - root_mean_squared_error: 0.1282 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1028
# Epoch 38/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0198 - root_mean_squared_error: 0.1408 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 39/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1096
# Epoch 40/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0183 - root_mean_squared_error: 0.1351 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1106
# Epoch 41/50
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1053
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0169 - root_mean_squared_error: 0.1300 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1177
# Epoch 43/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0155 - root_mean_squared_error: 0.1245 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1052
# Epoch 44/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1139
# Epoch 45/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0162 - root_mean_squared_error: 0.1271 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1022
# Epoch 46/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0182 - root_mean_squared_error: 0.1348 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1063
# Epoch 47/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0166 - root_mean_squared_error: 0.1289 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1003
# Epoch 48/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0167 - root_mean_squared_error: 0.1292 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1126
# Epoch 49/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0158 - root_mean_squared_error: 0.1256 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1016
# Epoch 50/50
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0156 - root_mean_squared_error: 0.1251 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1130

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.5959022641181946 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %% [markdown]
# Test Predictions

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Barents_model_LT8/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.10012455033144478
# MAE : 0.080897502520045

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       240633.015625     406860.687
# 1       494067.468750     605897.837
# 2       526868.187500     654073.790
# 3       610386.250000     701143.910
# 4       571492.250000     657891.340
# 5       468057.250000     432215.421
# 6       287444.437500     201834.787
# 7       134292.406250      55041.511
# 8       -16214.636719       5387.468
# 9       -37524.523438       1576.813
# 10       30534.556641      21681.895
# 11      210058.671875      37772.681
# 12      380899.937500     239568.531
# 13      519178.781250     427703.330
# 14      615295.187500     753043.012
# 15      660159.125000     764554.603
# 16      592237.937500     563799.961
# 17      426125.625000     444109.886
# 18      264487.937500     189669.492
# 19      119044.507812      63664.521
# 20       66803.054688       5984.539
# 21      -71198.492188       1192.062
# 22       -6535.053223      25987.740
# 23       68798.421875     227374.130
# 24      359830.593750     498316.637
# 25      539404.562500     666292.874
# 26      652750.812500     673348.837
# 27      684834.875000     635756.948
# 28      627147.125000     673503.693
# 29      463818.375000     550922.786
# 30      281094.500000     116554.569
# 31      167504.312500      12012.356
# 32      -41968.113281       5446.433
# 33      -30324.878906       2183.701
# 34       45818.703125      31883.576
# 35      312619.031250      98802.296
# 36      401310.937500     224779.107
# 37      544657.625000     287476.263
# 38      701369.187500     376683.928
# 39      844428.562500     571055.966
# 40      639116.000000     581039.946
# 41      503764.250000     376525.530
# 42      290318.500000     124025.343
# 43      190859.156250      53107.426
# 44       54966.394531      11242.827
# 45       16906.232422       3272.024
# 46       46665.210938      35079.225

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
