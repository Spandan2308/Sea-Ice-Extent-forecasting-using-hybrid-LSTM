# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Pacific_Extent = pd.read_excel(filepath, sheet_name='Pacific-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Pacific_Extent)
fp.date_time(Pacific_Extent)
# Out:
#           Extent       Date
# 0     668714.275 1979-01-01
# 1     566930.458 1979-02-01
# 2     688420.115 1979-03-01
# 3     859963.043 1979-04-01
# 4    1127120.160 1979-05-01
# ..           ...        ...
# 533  1134056.102 2023-06-01
# 534  1484824.377 2023-07-01
# 535  1671324.717 2023-08-01
# 536  1726376.097 2023-09-01
# 537  1690631.996 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Pacific_Extent['Extent'] = scaler.fit_transform(Pacific_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 8
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Pacific_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((519, 12, 1), (519,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Pacific_model_LT8/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.2573 - root_mean_squared_error: 0.5072
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 6s 81ms/step - loss: 0.2475 - root_mean_squared_error: 0.4975 - val_loss: 0.2204 - val_root_mean_squared_error: 0.4695
# Epoch 2/50
# 44/53 [=======================>......] - ETA: 0s - loss: 0.1932 - root_mean_squared_error: 0.4396
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.1818 - root_mean_squared_error: 0.4264 - val_loss: 0.1879 - val_root_mean_squared_error: 0.4335
# Epoch 3/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.1502 - root_mean_squared_error: 0.3875
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 3s 62ms/step - loss: 0.1465 - root_mean_squared_error: 0.3827 - val_loss: 0.1686 - val_root_mean_squared_error: 0.4107
# Epoch 4/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.1177 - root_mean_squared_error: 0.3431
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 4s 71ms/step - loss: 0.1144 - root_mean_squared_error: 0.3382 - val_loss: 0.1476 - val_root_mean_squared_error: 0.3841
# Epoch 5/50
# 40/53 [=====================>........] - ETA: 0s - loss: 0.0907 - root_mean_squared_error: 0.3011
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0912 - root_mean_squared_error: 0.3020 - val_loss: 0.1270 - val_root_mean_squared_error: 0.3563
# Epoch 6/50
# 43/53 [=======================>......] - ETA: 0s - loss: 0.0695 - root_mean_squared_error: 0.2636
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0694 - root_mean_squared_error: 0.2634 - val_loss: 0.1121 - val_root_mean_squared_error: 0.3348
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0542 - root_mean_squared_error: 0.2328
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0540 - root_mean_squared_error: 0.2324 - val_loss: 0.0865 - val_root_mean_squared_error: 0.2941
# Epoch 8/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0418 - root_mean_squared_error: 0.2044
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0416 - root_mean_squared_error: 0.2039 - val_loss: 0.0729 - val_root_mean_squared_error: 0.2700
# Epoch 9/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0310 - root_mean_squared_error: 0.1761
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0306 - root_mean_squared_error: 0.1751 - val_loss: 0.0535 - val_root_mean_squared_error: 0.2313
# Epoch 10/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0230 - root_mean_squared_error: 0.1517
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0227 - root_mean_squared_error: 0.1507 - val_loss: 0.0377 - val_root_mean_squared_error: 0.1943
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0188 - root_mean_squared_error: 0.1373
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0187 - root_mean_squared_error: 0.1369 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1837
# Epoch 12/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0194 - root_mean_squared_error: 0.1393
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 3s 67ms/step - loss: 0.0183 - root_mean_squared_error: 0.1354 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1405
# Epoch 13/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0173 - root_mean_squared_error: 0.1316
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0178 - root_mean_squared_error: 0.1335 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1200
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0138 - root_mean_squared_error: 0.1175
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0138 - root_mean_squared_error: 0.1175 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0920
# Epoch 15/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0127 - root_mean_squared_error: 0.1126
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0793
# Epoch 16/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0126 - root_mean_squared_error: 0.1121
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0130 - root_mean_squared_error: 0.1139 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0749
# Epoch 17/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0124 - root_mean_squared_error: 0.1114
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0128 - root_mean_squared_error: 0.1132 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0744
# Epoch 18/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0119 - root_mean_squared_error: 0.1093 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0801
# Epoch 19/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0101 - root_mean_squared_error: 0.1006 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0796
# Epoch 20/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0897
# Epoch 21/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0098 - root_mean_squared_error: 0.0992 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0758
# Epoch 22/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0124 - root_mean_squared_error: 0.1113
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0122 - root_mean_squared_error: 0.1106 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0728
# Epoch 23/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0127 - root_mean_squared_error: 0.1127 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0984
# Epoch 24/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0834
# Epoch 25/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0118 - root_mean_squared_error: 0.1085 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1011
# Epoch 26/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0093 - root_mean_squared_error: 0.0964 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0735
# Epoch 27/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0115 - root_mean_squared_error: 0.1072 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0733
# Epoch 28/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0096 - root_mean_squared_error: 0.0978 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0831
# Epoch 29/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0732
# Epoch 30/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0092 - root_mean_squared_error: 0.0958 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0853
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0104 - root_mean_squared_error: 0.1021 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0824
# Epoch 32/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0095 - root_mean_squared_error: 0.0974
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0095 - root_mean_squared_error: 0.0974 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0717
# Epoch 33/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0118 - root_mean_squared_error: 0.1088 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0726
# Epoch 34/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0125 - root_mean_squared_error: 0.1116 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0770
# Epoch 35/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0845
# Epoch 36/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0127 - root_mean_squared_error: 0.1125
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0126 - root_mean_squared_error: 0.1122 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0696
# Epoch 37/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0817
# Epoch 38/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0814
# Epoch 39/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0101 - root_mean_squared_error: 0.1005 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0822
# Epoch 40/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0866
# Epoch 41/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0100 - root_mean_squared_error: 0.1001 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0773
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0111 - root_mean_squared_error: 0.1056 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0852
# Epoch 43/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0801
# Epoch 44/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0709
# Epoch 45/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0101 - root_mean_squared_error: 0.1006
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# INFO:tensorflow:Assets written to: Pacific_model_LT8\assets
# 53/53 [==============================] - 4s 81ms/step - loss: 0.0102 - root_mean_squared_error: 0.1010 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0671
# Epoch 46/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0108 - root_mean_squared_error: 0.1039 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1034
# Epoch 47/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0119 - root_mean_squared_error: 0.1090 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0838
# Epoch 48/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0107 - root_mean_squared_error: 0.1033 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0753
# Epoch 49/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0129 - root_mean_squared_error: 0.1137 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0686
# Epoch 50/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0125 - root_mean_squared_error: 0.1119 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0722

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.4610438505808512 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Pacific_model_LT8/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.07234469960095911
# MAE : 0.059809407684125966

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        8.527042e+05     863206.294
# 1        5.142020e+05     635624.004
# 2        3.332562e+05     460009.672
# 3        4.289332e+05     610848.036
# 4        7.006368e+05     819257.445
# 5        1.041669e+06    1129627.707
# 6        1.349336e+06    1463383.236
# 7        1.687214e+06    1614536.727
# 8        1.785970e+06    1862498.612
# 9        1.905222e+06    2099349.296
# 10       1.731973e+06    1981614.046
# 11       1.435564e+06    1433022.369
# 12       8.703431e+05     826739.716
# 13       6.050838e+05     477145.887
# 14       3.766944e+05     314469.289
# 15       5.185506e+05     463134.749
# 16       7.705272e+05     946522.292
# 17       1.098424e+06    1309266.570
# 18       1.426672e+06    1507947.309
# 19       1.683808e+06    1804167.937
# 20       1.807011e+06    1908002.139
# 21       1.996795e+06    1892748.521
# 22       1.858413e+06    1601079.640
# 23       1.491141e+06    1327804.521
# 24       8.200462e+05     812074.231
# 25       5.540411e+05     493355.897
# 26       4.046019e+05     317229.330
# 27       6.371825e+05     425777.624
# 28       8.751211e+05     827172.620
# 29       1.251217e+06    1162367.223
# 30       1.509792e+06    1413734.261
# 31       1.701785e+06    1574257.849
# 32       1.882724e+06    1786961.251
# 33       1.872034e+06    1857942.866
# 34       1.820703e+06    1406291.588
# 35       1.376287e+06    1025555.371
# 36       8.513945e+05     632862.782
# 37       4.800054e+05     308194.756
# 38       3.734097e+05     194921.078
# 39       5.708019e+05     245569.900
# 40       8.430558e+05     533532.424
# 41       1.180279e+06     943124.529
# 42       1.428648e+06    1134056.102
# 43       1.664160e+06    1484824.377
# 44       1.776475e+06    1671324.717
# 45       1.823404e+06    1726376.097
# 46       1.690210e+06    1690631.996

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
