# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Pacific_Extent = pd.read_excel(filepath, sheet_name='Pacific-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Pacific_Extent)
fp.date_time(Pacific_Extent)
# Out:
#           Extent       Date
# 0     668714.275 1979-01-01
# 1     566930.458 1979-02-01
# 2     688420.115 1979-03-01
# 3     859963.043 1979-04-01
# 4    1127120.160 1979-05-01
# ..           ...        ...
# 533  1134056.102 2023-06-01
# 534  1484824.377 2023-07-01
# 535  1671324.717 2023-08-01
# 536  1726376.097 2023-09-01
# 537  1690631.996 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Pacific_Extent['Extent'] = scaler.fit_transform(Pacific_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 12
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Pacific_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((515, 12, 1), (515,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Pacific_model_LT12/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1941 - root_mean_squared_error: 0.4406INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 38s 511ms/step - loss: 0.1941 - root_mean_squared_error: 0.4406 - val_loss: 0.0963 - val_root_mean_squared_error: 0.3103
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0715 - root_mean_squared_error: 0.2675INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 25s 477ms/step - loss: 0.0715 - root_mean_squared_error: 0.2675 - val_loss: 0.0588 - val_root_mean_squared_error: 0.2424
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0583 - root_mean_squared_error: 0.2414INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 25s 476ms/step - loss: 0.0584 - root_mean_squared_error: 0.2417 - val_loss: 0.0513 - val_root_mean_squared_error: 0.2264
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0484 - root_mean_squared_error: 0.2200INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 26s 490ms/step - loss: 0.0483 - root_mean_squared_error: 0.2199 - val_loss: 0.0400 - val_root_mean_squared_error: 0.1999
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0355 - root_mean_squared_error: 0.1885INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 26s 490ms/step - loss: 0.0355 - root_mean_squared_error: 0.1884 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1565
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0217 - root_mean_squared_error: 0.1474INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 26s 504ms/step - loss: 0.0217 - root_mean_squared_error: 0.1474 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1164
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0153 - root_mean_squared_error: 0.1236INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 27s 509ms/step - loss: 0.0153 - root_mean_squared_error: 0.1236 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0661
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0110 - root_mean_squared_error: 0.1048INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 27s 512ms/step - loss: 0.0110 - root_mean_squared_error: 0.1048 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0616
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0102 - root_mean_squared_error: 0.1011INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 26s 503ms/step - loss: 0.0102 - root_mean_squared_error: 0.1011 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0102 - root_mean_squared_error: 0.1010INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 26s 506ms/step - loss: 0.0102 - root_mean_squared_error: 0.1010 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0561
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0107 - root_mean_squared_error: 0.1034INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 27s 513ms/step - loss: 0.0107 - root_mean_squared_error: 0.1034 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0553
# Epoch 12/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0098 - root_mean_squared_error: 0.0990 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0566
# Epoch 13/50
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0090 - root_mean_squared_error: 0.0949 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0583
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0096 - root_mean_squared_error: 0.0980INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 27s 513ms/step - loss: 0.0096 - root_mean_squared_error: 0.0980 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0552
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0097 - root_mean_squared_error: 0.0983INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 26s 506ms/step - loss: 0.0097 - root_mean_squared_error: 0.0983 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0532
# Epoch 16/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0091 - root_mean_squared_error: 0.0956 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0768
# Epoch 17/50
# 53/53 [==============================] - 4s 77ms/step - loss: 0.0098 - root_mean_squared_error: 0.0989 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0744
# Epoch 18/50
# 53/53 [==============================] - 4s 77ms/step - loss: 0.0087 - root_mean_squared_error: 0.0931 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0595
# Epoch 19/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0079 - root_mean_squared_error: 0.0889 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0557
# Epoch 20/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0078 - root_mean_squared_error: 0.0886INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 27s 518ms/step - loss: 0.0078 - root_mean_squared_error: 0.0886 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0530
# Epoch 21/50
# 53/53 [==============================] - 4s 76ms/step - loss: 0.0078 - root_mean_squared_error: 0.0884 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0547
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0085 - root_mean_squared_error: 0.0922INFO:tensorflow:Assets written to: Pacific_model_LT12\assets
# 53/53 [==============================] - 26s 507ms/step - loss: 0.0085 - root_mean_squared_error: 0.0922 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0519
# Epoch 23/50
# 53/53 [==============================] - 4s 78ms/step - loss: 0.0070 - root_mean_squared_error: 0.0839 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0519
# Epoch 24/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0075 - root_mean_squared_error: 0.0865 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0722
# Epoch 25/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0076 - root_mean_squared_error: 0.0873 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0541
# Epoch 26/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0073 - root_mean_squared_error: 0.0854 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0519
# Epoch 27/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0068 - root_mean_squared_error: 0.0825 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0551
# Epoch 28/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0065 - root_mean_squared_error: 0.0809 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0554
# Epoch 29/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0064 - root_mean_squared_error: 0.0799 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0565
# Epoch 30/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0070 - root_mean_squared_error: 0.0839 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0540
# Epoch 31/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0063 - root_mean_squared_error: 0.0797 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0526
# Epoch 32/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0064 - root_mean_squared_error: 0.0802 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0700
# Epoch 33/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0076 - root_mean_squared_error: 0.0873 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0527
# Epoch 34/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0065 - root_mean_squared_error: 0.0806 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0549
# Epoch 35/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0062 - root_mean_squared_error: 0.0788 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0536
# Epoch 36/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0065 - root_mean_squared_error: 0.0809 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0573
# Epoch 37/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0060 - root_mean_squared_error: 0.0777 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0539
# Epoch 38/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0061 - root_mean_squared_error: 0.0783 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0558
# Epoch 39/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0062 - root_mean_squared_error: 0.0785 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0556
# Epoch 40/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0060 - root_mean_squared_error: 0.0774 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0563
# Epoch 41/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0062 - root_mean_squared_error: 0.0784 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0556
# Epoch 42/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0059 - root_mean_squared_error: 0.0769 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0589
# Epoch 43/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0059 - root_mean_squared_error: 0.0767 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0607
# Epoch 44/50
# 53/53 [==============================] - 4s 78ms/step - loss: 0.0057 - root_mean_squared_error: 0.0754 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0717
# Epoch 45/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0061 - root_mean_squared_error: 0.0781 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611
# Epoch 46/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0055 - root_mean_squared_error: 0.0742 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679
# Epoch 47/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0063 - root_mean_squared_error: 0.0793 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0578
# Epoch 48/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0056 - root_mean_squared_error: 0.0751 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0574
# Epoch 49/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0061 - root_mean_squared_error: 0.0782 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0616
# Epoch 50/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.0054 - root_mean_squared_error: 0.0733 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0574

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 9.157430513699849 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Pacific_model_LT12/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 28ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.06622398554336102
# MAE : 0.05530693277328803

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        7.156271e+05     819257.445
# 1        1.072328e+06    1129627.707
# 2        1.429579e+06    1463383.236
# 3        1.744223e+06    1614536.727
# 4        1.926780e+06    1862498.612
# 5        1.987193e+06    2099349.296
# 6        1.839860e+06    1981614.046
# 7        1.378568e+06    1433022.369
# 8        9.111679e+05     826739.716
# 9        5.810563e+05     477145.887
# 10       4.271900e+05     314469.289
# 11       4.791593e+05     463134.749
# 12       7.232559e+05     946522.292
# 13       1.110873e+06    1309266.570
# 14       1.485405e+06    1507947.309
# 15       1.772325e+06    1804167.937
# 16       1.942332e+06    1908002.139
# 17       1.940007e+06    1892748.521
# 18       1.784272e+06    1601079.640
# 19       1.407936e+06    1327804.521
# 20       9.242154e+05     812074.231
# 21       5.554214e+05     493355.897
# 22       4.210651e+05     317229.330
# 23       4.544496e+05     425777.624
# 24       7.597309e+05     827172.620
# 25       1.183531e+06    1162367.223
# 26       1.523430e+06    1413734.261
# 27       1.822242e+06    1574257.849
# 28       1.990235e+06    1786961.251
# 29       1.951057e+06    1857942.866
# 30       1.688991e+06    1406291.588
# 31       1.216732e+06    1025555.371
# 32       7.568366e+05     632862.782
# 33       5.025084e+05     308194.756
# 34       4.265231e+05     194921.078
# 35       4.970732e+05     245569.900
# 36       7.914016e+05     533532.424
# 37       1.178930e+06     943124.529
# 38       1.510327e+06    1134056.102
# 39       1.709896e+06    1484824.377
# 40       1.827712e+06    1671324.717
# 41       1.840329e+06    1726376.097
# 42       1.648789e+06    1690631.996

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 28ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
