# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Baffin = pd.read_excel(filepath, sheet_name='Baffin-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Baffin)
fp.date_time(Baffin)
# Out:
#           Extent       Date
# 0    1090625.815 1979-01-01
# 1    1157634.866 1979-02-01
# 2    1299583.477 1979-03-01
# 3    1137194.680 1979-04-01
# 4     983083.453 1979-05-01
# ..           ...        ...
# 533   781460.891 2023-06-01
# 534   331845.048 2023-07-01
# 535    99334.625 2023-08-01
# 536    49359.723 2023-09-01
# 537    85693.282 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Baffin['Extent'] = scaler.fit_transform(Baffin['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 11
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Baffin['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((516, 12, 1), (516,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Baffin_model_LT11/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2257 - root_mean_squared_error: 0.4751INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 19s 216ms/step - loss: 0.2257 - root_mean_squared_error: 0.4751 - val_loss: 0.1579 - val_root_mean_squared_error: 0.3974
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1258 - root_mean_squared_error: 0.3547INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 9s 174ms/step - loss: 0.1258 - root_mean_squared_error: 0.3547 - val_loss: 0.0915 - val_root_mean_squared_error: 0.3026
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0980 - root_mean_squared_error: 0.3130INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 11s 201ms/step - loss: 0.0980 - root_mean_squared_error: 0.3130 - val_loss: 0.0826 - val_root_mean_squared_error: 0.2874
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0923 - root_mean_squared_error: 0.3038INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 11s 212ms/step - loss: 0.0925 - root_mean_squared_error: 0.3041 - val_loss: 0.0777 - val_root_mean_squared_error: 0.2787
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0872 - root_mean_squared_error: 0.2953INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 10s 199ms/step - loss: 0.0872 - root_mean_squared_error: 0.2953 - val_loss: 0.0726 - val_root_mean_squared_error: 0.2694
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0808 - root_mean_squared_error: 0.2842INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 13s 241ms/step - loss: 0.0811 - root_mean_squared_error: 0.2848 - val_loss: 0.0679 - val_root_mean_squared_error: 0.2605
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0734 - root_mean_squared_error: 0.2709INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 12s 235ms/step - loss: 0.0734 - root_mean_squared_error: 0.2709 - val_loss: 0.0575 - val_root_mean_squared_error: 0.2397
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0639 - root_mean_squared_error: 0.2528INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 10s 199ms/step - loss: 0.0638 - root_mean_squared_error: 0.2525 - val_loss: 0.0453 - val_root_mean_squared_error: 0.2128
# Epoch 9/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0525 - root_mean_squared_error: 0.2291INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 10s 202ms/step - loss: 0.0517 - root_mean_squared_error: 0.2274 - val_loss: 0.0382 - val_root_mean_squared_error: 0.1955
# Epoch 10/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0368 - root_mean_squared_error: 0.1918INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 11s 206ms/step - loss: 0.0366 - root_mean_squared_error: 0.1914 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1073
# Epoch 11/50
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0275 - root_mean_squared_error: 0.1660 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1161
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0234 - root_mean_squared_error: 0.1530INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 11s 216ms/step - loss: 0.0237 - root_mean_squared_error: 0.1539 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0747
# Epoch 13/50
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0228 - root_mean_squared_error: 0.1511 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0839
# Epoch 14/50
# 53/53 [==============================] - 1s 26ms/step - loss: 0.0219 - root_mean_squared_error: 0.1481 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1059
# Epoch 15/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0197 - root_mean_squared_error: 0.1403 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0823
# Epoch 16/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0185 - root_mean_squared_error: 0.1359 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0785
# Epoch 17/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0216 - root_mean_squared_error: 0.1469INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 11s 214ms/step - loss: 0.0218 - root_mean_squared_error: 0.1475 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0650
# Epoch 18/50
# 53/53 [==============================] - 1s 26ms/step - loss: 0.0187 - root_mean_squared_error: 0.1368 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0997
# Epoch 19/50
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0182 - root_mean_squared_error: 0.1348 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0988
# Epoch 20/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0185 - root_mean_squared_error: 0.1361 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0763
# Epoch 21/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0175 - root_mean_squared_error: 0.1324 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0716
# Epoch 22/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0168 - root_mean_squared_error: 0.1295 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0985
# Epoch 23/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0160 - root_mean_squared_error: 0.1264INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 12s 225ms/step - loss: 0.0160 - root_mean_squared_error: 0.1264 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0643
# Epoch 24/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0164 - root_mean_squared_error: 0.1282 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0855
# Epoch 25/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0167 - root_mean_squared_error: 0.1293 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 26/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0162 - root_mean_squared_error: 0.1273 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0715
# Epoch 27/50
# 53/53 [==============================] - 1s 28ms/step - loss: 0.0169 - root_mean_squared_error: 0.1298 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0925
# Epoch 28/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 29/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0144 - root_mean_squared_error: 0.1200 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0654
# Epoch 30/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0150 - root_mean_squared_error: 0.1224 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0694
# Epoch 31/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0139 - root_mean_squared_error: 0.1178 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0661
# Epoch 32/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0162 - root_mean_squared_error: 0.1274 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0794
# Epoch 33/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0139 - root_mean_squared_error: 0.1179INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 13s 247ms/step - loss: 0.0139 - root_mean_squared_error: 0.1178 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0561
# Epoch 34/50
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0664
# Epoch 35/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0129 - root_mean_squared_error: 0.1135 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0591
# Epoch 36/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0668
# Epoch 37/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0134 - root_mean_squared_error: 0.1157 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0576
# Epoch 38/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0129 - root_mean_squared_error: 0.1134INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 13s 246ms/step - loss: 0.0128 - root_mean_squared_error: 0.1130 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0554
# Epoch 39/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0133 - root_mean_squared_error: 0.1153 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0897
# Epoch 40/50
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0687
# Epoch 41/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0119 - root_mean_squared_error: 0.1092 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0607
# Epoch 42/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0125 - root_mean_squared_error: 0.1119INFO:tensorflow:Assets written to: Baffin_model_LT11\assets
# 53/53 [==============================] - 13s 244ms/step - loss: 0.0124 - root_mean_squared_error: 0.1115 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0549
# Epoch 43/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0123 - root_mean_squared_error: 0.1107 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0724
# Epoch 44/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0123 - root_mean_squared_error: 0.1110 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0773
# Epoch 45/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0109 - root_mean_squared_error: 0.1043 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0597
# Epoch 46/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0120 - root_mean_squared_error: 0.1096 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1176
# Epoch 47/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0107 - root_mean_squared_error: 0.1035 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0598
# Epoch 48/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0618
# Epoch 49/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0685
# Epoch 50/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0111 - root_mean_squared_error: 0.1052 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 3.996411454677582 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Baffin_model_LT11/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 8ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.07930168772886809
# MAE : 0.06812042959337743

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.313883e+06    1236299.254
# 1        1.240746e+06    1036981.003
# 2        9.995642e+05     847489.150
# 3        6.809083e+05     619129.338
# 4        3.128115e+05     195688.491
# 5        1.261762e+05      36670.811
# 6        8.074984e+04      31777.310
# 7        2.418051e+05      82762.022
# 8        5.496939e+05     400043.823
# 9        8.378956e+05     733089.555
# 10       1.045137e+06     917362.266
# 11       1.193990e+06    1040584.040
# 12       1.253810e+06    1147997.675
# 13       1.182020e+06    1074255.327
# 14       1.018632e+06     875527.315
# 15       8.750056e+05     629820.756
# 16       5.925408e+05     204308.900
# 17       2.549137e+05      45059.062
# 18       1.342208e+05      33770.277
# 19       2.445829e+05      64135.631
# 20       5.704411e+05     400581.715
# 21       8.773465e+05     698631.451
# 22       1.041401e+06     973313.225
# 23       1.135253e+06    1335339.087
# 24       1.197973e+06    1429096.704
# 25       1.191206e+06    1206542.314
# 26       1.019451e+06    1079292.433
# 27       8.619606e+05     788101.638
# 28       5.498995e+05     397326.270
# 29       2.137265e+05      97802.348
# 30       1.117844e+05      62212.219
# 31       2.244414e+05     154051.600
# 32       4.847499e+05     610663.893
# 33       7.807602e+05     756679.164
# 34       1.020420e+06     962270.215
# 35       1.165062e+06    1235154.518
# 36       1.232870e+06    1161744.519
# 37       1.219093e+06    1136918.669
# 38       1.033359e+06     995852.026
# 39       8.405044e+05     781460.891
# 40       4.980375e+05     331845.048
# 41       2.022691e+05      99334.625
# 42       7.791589e+04      49359.723
# 43       1.577413e+05      85693.282

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 16ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
