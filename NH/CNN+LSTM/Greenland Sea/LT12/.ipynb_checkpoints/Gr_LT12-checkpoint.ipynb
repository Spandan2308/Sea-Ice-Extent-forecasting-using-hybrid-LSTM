# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout, Conv1D, MaxPooling1D, BatchNormalization
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Greenland = pd.read_excel(filepath, sheet_name='Greenland-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Greenland)
fp.date_time(Greenland)
# Out:
#           Extent       Date
# 0    1076123.146 1979-01-01
# 1    1099248.063 1979-02-01
# 2    1036964.901 1979-03-01
# 3     958927.937 1979-04-01
# 4     823812.694 1979-05-01
# ..           ...        ...
# 533   721350.515 2023-06-01
# 534   459033.164 2023-07-01
# 535   282045.909 2023-08-01
# 536   270397.608 2023-09-01
# 537   449910.973 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Greenland['Extent'] = scaler.fit_transform(Greenland['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 12
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]  # Adjusted for lead time
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Greenland['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((515, 12, 1), (515,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(W_S, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32, kernel_constraint=MaxNorm(1.0), activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
cp = ModelCheckpoint('Greenland_model_LT12/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 40/53 [=====================>........] - ETA: 0s - loss: 0.3380 - root_mean_squared_error: 0.5814
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 6s 71ms/step - loss: 0.3196 - root_mean_squared_error: 0.5653 - val_loss: 0.1461 - val_root_mean_squared_error: 0.3823
# Epoch 2/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.2426 - root_mean_squared_error: 0.4925
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 3s 55ms/step - loss: 0.2432 - root_mean_squared_error: 0.4932 - val_loss: 0.1148 - val_root_mean_squared_error: 0.3388
# Epoch 3/50
# 41/53 [======================>.......] - ETA: 0s - loss: 0.2015 - root_mean_squared_error: 0.4489
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 3s 54ms/step - loss: 0.1966 - root_mean_squared_error: 0.4434 - val_loss: 0.0902 - val_root_mean_squared_error: 0.3003
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1589 - root_mean_squared_error: 0.3986
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 3s 58ms/step - loss: 0.1583 - root_mean_squared_error: 0.3979 - val_loss: 0.0677 - val_root_mean_squared_error: 0.2602
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1242 - root_mean_squared_error: 0.3525
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 3s 54ms/step - loss: 0.1239 - root_mean_squared_error: 0.3520 - val_loss: 0.0514 - val_root_mean_squared_error: 0.2266
# Epoch 6/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0980 - root_mean_squared_error: 0.3130
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0987 - root_mean_squared_error: 0.3142 - val_loss: 0.0365 - val_root_mean_squared_error: 0.1910
# Epoch 7/50
# 43/53 [=======================>......] - ETA: 0s - loss: 0.0793 - root_mean_squared_error: 0.2817
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0746 - root_mean_squared_error: 0.2731 - val_loss: 0.0283 - val_root_mean_squared_error: 0.1682
# Epoch 8/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0565 - root_mean_squared_error: 0.2377
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0571 - root_mean_squared_error: 0.2390 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1474
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0426 - root_mean_squared_error: 0.2064
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0426 - root_mean_squared_error: 0.2064 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1289
# Epoch 10/50
# 47/53 [=========================>....] - ETA: 0s - loss: 0.0368 - root_mean_squared_error: 0.1917
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0341 - root_mean_squared_error: 0.1847 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1205
# Epoch 11/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0280 - root_mean_squared_error: 0.1673
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0263 - root_mean_squared_error: 0.1622 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1096
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0222 - root_mean_squared_error: 0.1491
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 4s 71ms/step - loss: 0.0222 - root_mean_squared_error: 0.1491 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1042
# Epoch 13/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0170 - root_mean_squared_error: 0.1303 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1217
# Epoch 14/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0157 - root_mean_squared_error: 0.1251
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0157 - root_mean_squared_error: 0.1254 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0996
# Epoch 15/50
# 46/53 [=========================>....] - ETA: 0s - loss: 0.0143 - root_mean_squared_error: 0.1196
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0916
# Epoch 16/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0144 - root_mean_squared_error: 0.1200 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0971
# Epoch 17/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0129 - root_mean_squared_error: 0.1134 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1414
# Epoch 18/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1250
# Epoch 19/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0119 - root_mean_squared_error: 0.1091 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1347
# Epoch 20/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0119 - root_mean_squared_error: 0.1092 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1212
# Epoch 21/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0104 - root_mean_squared_error: 0.1022 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0998
# Epoch 22/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0124 - root_mean_squared_error: 0.1115 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1170
# Epoch 23/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0114 - root_mean_squared_error: 0.1068 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1121
# Epoch 24/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0109 - root_mean_squared_error: 0.1045 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1393
# Epoch 25/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0107 - root_mean_squared_error: 0.1033
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 3s 49ms/step - loss: 0.0104 - root_mean_squared_error: 0.1020 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0909
# Epoch 26/50
# 53/53 [==============================] - 0s 4ms/step - loss: 0.0112 - root_mean_squared_error: 0.1056 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1009
# Epoch 27/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0106 - root_mean_squared_error: 0.1029 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1348
# Epoch 28/50
# 42/53 [======================>.......] - ETA: 0s - loss: 0.0120 - root_mean_squared_error: 0.1095
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0120 - root_mean_squared_error: 0.1095 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0902
# Epoch 29/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0115 - root_mean_squared_error: 0.1072 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1543
# Epoch 30/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0116 - root_mean_squared_error: 0.1078 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1215
# Epoch 31/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0121 - root_mean_squared_error: 0.1102 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1321
# Epoch 32/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0121 - root_mean_squared_error: 0.1102 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0944
# Epoch 33/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0121 - root_mean_squared_error: 0.1098 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0912
# Epoch 34/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0108 - root_mean_squared_error: 0.1040 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0973
# Epoch 35/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0122 - root_mean_squared_error: 0.1103 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1428
# Epoch 36/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0108 - root_mean_squared_error: 0.1038 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1123
# Epoch 37/50
# 45/53 [========================>.....] - ETA: 0s - loss: 0.0118 - root_mean_squared_error: 0.1088
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0126 - root_mean_squared_error: 0.1122 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0902
# Epoch 38/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0118 - root_mean_squared_error: 0.1088 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1207
# Epoch 39/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0117 - root_mean_squared_error: 0.1080 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1293
# Epoch 40/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0098 - root_mean_squared_error: 0.0990 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0933
# Epoch 41/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0126 - root_mean_squared_error: 0.1122 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1148
# Epoch 42/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1085
# Epoch 43/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0113 - root_mean_squared_error: 0.1065 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0962
# Epoch 44/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0122 - root_mean_squared_error: 0.1104 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1273
# Epoch 45/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0121 - root_mean_squared_error: 0.1100 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1158
# Epoch 46/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0111 - root_mean_squared_error: 0.1053 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0917
# Epoch 47/50
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0115 - root_mean_squared_error: 0.1071
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# INFO:tensorflow:Assets written to: Greenland_model_LT12\assets
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0124 - root_mean_squared_error: 0.1115 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0874
# Epoch 48/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0109 - root_mean_squared_error: 0.1042 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1459
# Epoch 49/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0117 - root_mean_squared_error: 0.1080 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1059
# Epoch 50/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1073

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 1.1309274792671205 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Greenland_model_LT12/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 17ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.09302103274882663
# MAE : 0.07871677513173139

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0       663621.125000     777596.225
# 1       628904.000000     687087.673
# 2       557193.812500     622337.816
# 3       406535.687500     467232.074
# 4       274122.343750     297495.641
# 5       207267.984375     268909.854
# 6       323719.156250     408072.791
# 7       493200.250000     552314.148
# 8       523052.250000     651062.408
# 9       596290.000000     695022.674
# 10      603505.687500     670974.305
# 11      706368.937500     710035.543
# 12      710096.375000     699672.538
# 13      665196.812500     730897.021
# 14      570408.000000     588598.988
# 15      445876.093750     281754.041
# 16      274538.531250     117830.266
# 17      240062.593750      81838.250
# 18      365485.187500     291418.462
# 19      528816.375000     452417.079
# 20      618918.562500     576361.148
# 21      685193.187500     676218.054
# 22      675538.500000     698410.066
# 23      679370.000000     696094.179
# 24      671590.187500     751102.742
# 25      644967.750000     765802.952
# 26      550652.812500     597649.311
# 27      264079.000000     376029.266
# 28      155255.687500     278536.574
# 29      122117.585938     285351.521
# 30      285570.250000     365256.138
# 31      427787.375000     488293.212
# 32      556524.125000     635073.900
# 33      649782.625000     684651.888
# 34      682368.375000     698053.275
# 35      674206.187500     846211.943
# 36      668006.500000     831596.370
# 37      689535.937500     834849.724
# 38      541909.875000     721350.515
# 39      376943.218750     459033.164
# 40      225395.921875     282045.909
# 41      258479.921875     270397.608
# 42      334289.343750     449910.973

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
