# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Indian_Extent = pd.read_excel(filepath, sheet_name='Indian-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Indian_Extent)
fp.date_time(Indian_Extent)
# Out:
#           Extent       Date
# 0     376618.799 1979-01-01
# 1     211788.726 1979-02-01
# 2     262868.141 1979-03-01
# 3     698377.304 1979-04-01
# 4    1252407.727 1979-05-01
# ..           ...        ...
# 533  1520776.003 2023-06-01
# 534  2076164.165 2023-07-01
# 535  2731799.027 2023-08-01
# 536  3179384.692 2023-09-01
# 537  3301335.210 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Indian_Extent['Extent'] = scaler.fit_transform(Indian_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 5
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Indian_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((522, 12, 1), (522,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Indian_model_LT5/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2501 - root_mean_squared_error: 0.5001INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 17s 217ms/step - loss: 0.2501 - root_mean_squared_error: 0.5001 - val_loss: 0.1768 - val_root_mean_squared_error: 0.4204
# Epoch 2/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.1366 - root_mean_squared_error: 0.3695INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 7s 142ms/step - loss: 0.1335 - root_mean_squared_error: 0.3653 - val_loss: 0.0611 - val_root_mean_squared_error: 0.2471
# Epoch 3/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0702 - root_mean_squared_error: 0.2650INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 7s 135ms/step - loss: 0.0706 - root_mean_squared_error: 0.2656 - val_loss: 0.0545 - val_root_mean_squared_error: 0.2335
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0652 - root_mean_squared_error: 0.2553INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 185ms/step - loss: 0.0653 - root_mean_squared_error: 0.2555 - val_loss: 0.0514 - val_root_mean_squared_error: 0.2268
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0585 - root_mean_squared_error: 0.2419INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 183ms/step - loss: 0.0585 - root_mean_squared_error: 0.2419 - val_loss: 0.0469 - val_root_mean_squared_error: 0.2167
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0532 - root_mean_squared_error: 0.2307INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 188ms/step - loss: 0.0532 - root_mean_squared_error: 0.2307 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2025
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0496 - root_mean_squared_error: 0.2227INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 192ms/step - loss: 0.0496 - root_mean_squared_error: 0.2227 - val_loss: 0.0360 - val_root_mean_squared_error: 0.1898
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0391 - root_mean_squared_error: 0.1977INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 194ms/step - loss: 0.0391 - root_mean_squared_error: 0.1976 - val_loss: 0.0342 - val_root_mean_squared_error: 0.1849
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0330 - root_mean_squared_error: 0.1816INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 9s 182ms/step - loss: 0.0330 - root_mean_squared_error: 0.1816 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1588
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0252 - root_mean_squared_error: 0.1588INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 190ms/step - loss: 0.0251 - root_mean_squared_error: 0.1585 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1442
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0224 - root_mean_squared_error: 0.1497INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 11s 206ms/step - loss: 0.0226 - root_mean_squared_error: 0.1502 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1361
# Epoch 12/50
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0229 - root_mean_squared_error: 0.1513 - val_loss: 0.0191 - val_root_mean_squared_error: 0.1383
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0217 - root_mean_squared_error: 0.1472INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0215 - root_mean_squared_error: 0.1467 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1332
# Epoch 14/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0195 - root_mean_squared_error: 0.1398INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 198ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1273
# Epoch 15/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0204 - root_mean_squared_error: 0.1430INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 198ms/step - loss: 0.0203 - root_mean_squared_error: 0.1424 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1248
# Epoch 16/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0177 - root_mean_squared_error: 0.1330 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1275
# Epoch 17/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0198 - root_mean_squared_error: 0.1409INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 9s 180ms/step - loss: 0.0197 - root_mean_squared_error: 0.1404 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1205
# Epoch 18/50
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0158 - root_mean_squared_error: 0.1257 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1232
# Epoch 19/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0157 - root_mean_squared_error: 0.1251INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 191ms/step - loss: 0.0156 - root_mean_squared_error: 0.1249 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1168
# Epoch 20/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0152 - root_mean_squared_error: 0.1234INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 197ms/step - loss: 0.0152 - root_mean_squared_error: 0.1234 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 21/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0165 - root_mean_squared_error: 0.1286 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1407
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0152 - root_mean_squared_error: 0.1234INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 187ms/step - loss: 0.0152 - root_mean_squared_error: 0.1234 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1107
# Epoch 23/50
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0155 - root_mean_squared_error: 0.1244 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0128 - root_mean_squared_error: 0.1131INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 195ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1094
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0141 - root_mean_squared_error: 0.1186INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 198ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1077
# Epoch 26/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0143 - root_mean_squared_error: 0.1195INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1030
# Epoch 27/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0118 - root_mean_squared_error: 0.1086INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 201ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1025
# Epoch 28/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0132 - root_mean_squared_error: 0.1149INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 11s 205ms/step - loss: 0.0132 - root_mean_squared_error: 0.1149 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1001
# Epoch 29/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0120 - root_mean_squared_error: 0.1097INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 193ms/step - loss: 0.0120 - root_mean_squared_error: 0.1097 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0992
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0129 - root_mean_squared_error: 0.1138INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 9s 174ms/step - loss: 0.0129 - root_mean_squared_error: 0.1138 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 31/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0120 - root_mean_squared_error: 0.1095INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 192ms/step - loss: 0.0120 - root_mean_squared_error: 0.1095 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0954
# Epoch 32/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0119 - root_mean_squared_error: 0.1089 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0962
# Epoch 33/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0120 - root_mean_squared_error: 0.1093INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 194ms/step - loss: 0.0120 - root_mean_squared_error: 0.1096 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0945
# Epoch 34/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0119 - root_mean_squared_error: 0.1089 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0950
# Epoch 35/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0128 - root_mean_squared_error: 0.1131INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 200ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0928
# Epoch 36/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0113 - root_mean_squared_error: 0.1062INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 200ms/step - loss: 0.0113 - root_mean_squared_error: 0.1062 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0898
# Epoch 37/50
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0104 - root_mean_squared_error: 0.1019 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0935
# Epoch 38/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0928
# Epoch 39/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0101 - root_mean_squared_error: 0.1006INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 9s 182ms/step - loss: 0.0101 - root_mean_squared_error: 0.1006 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0880
# Epoch 40/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0092 - root_mean_squared_error: 0.0959INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 11s 207ms/step - loss: 0.0092 - root_mean_squared_error: 0.0959 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0865
# Epoch 41/50
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0104 - root_mean_squared_error: 0.1020 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0885
# Epoch 42/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0102 - root_mean_squared_error: 0.1010INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 7s 133ms/step - loss: 0.0104 - root_mean_squared_error: 0.1021 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0839
# Epoch 43/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0898
# Epoch 44/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0099 - root_mean_squared_error: 0.0994INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 10s 194ms/step - loss: 0.0098 - root_mean_squared_error: 0.0992 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0818
# Epoch 45/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0086 - root_mean_squared_error: 0.0930INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 11s 205ms/step - loss: 0.0086 - root_mean_squared_error: 0.0930 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0805
# Epoch 46/50
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0091 - root_mean_squared_error: 0.0953 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0809
# Epoch 47/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0087 - root_mean_squared_error: 0.0933INFO:tensorflow:Assets written to: Indian_model_LT5\assets
# 53/53 [==============================] - 9s 173ms/step - loss: 0.0087 - root_mean_squared_error: 0.0933 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0785
# Epoch 48/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0085 - root_mean_squared_error: 0.0923 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0820
# Epoch 49/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0083 - root_mean_squared_error: 0.0909 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0839
# Epoch 50/50
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0081 - root_mean_squared_error: 0.0899 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0793

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 6.266208589076996 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Indian_model_LT5/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 14ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.06934899679520189
# MAE : 0.058401325932705854

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        3.543369e+06    3719188.531
# 1        3.396305e+06    3636501.241
# 2        2.632194e+06    2526913.818
# 3        1.546806e+06    1128752.378
# 4        6.361931e+05     522831.371
# 5        9.113487e+04     346601.304
# 6       -1.725319e+03     444914.605
# 7        5.888588e+05     827036.916
# 8        1.158952e+06    1142021.216
# 9        1.687017e+06    1885693.654
# 10       2.279426e+06    2542569.663
# 11       2.881114e+06    3107373.845
# 12       3.232289e+06    3488175.444
# 13       3.038948e+06    3746306.528
# 14       2.320962e+06    2942322.822
# 15       1.325738e+06    1507212.955
# 16       5.020297e+05     648507.437
# 17       1.493911e+05     352564.010
# 18       2.314077e+05     453587.503
# 19       8.607369e+05     841043.793
# 20       1.380522e+06    1433155.266
# 21       1.930598e+06    2163687.646
# 22       2.548840e+06    2848863.133
# 23       3.141634e+06    3420877.229
# 24       3.456625e+06    3752886.938
# 25       3.328753e+06    3778951.818
# 26       2.591047e+06    2892177.223
# 27       1.551992e+06    1467610.428
# 28       6.933408e+05     377930.941
# 29       2.257350e+05     146440.376
# 30       3.227020e+05     244356.473
# 31       1.005640e+06     612217.566
# 32       1.592862e+06    1261627.075
# 33       2.200893e+06    1720565.225
# 34       2.898476e+06    2564005.541
# 35       3.530469e+06    2983773.529
# 36       3.783049e+06    3372645.223
# 37       3.472435e+06    3589687.043
# 38       2.629495e+06    2669385.189
# 39       1.521531e+06    1095398.946
# 40       6.045481e+05     319828.826
# 41       1.093647e+05     162541.182
# 42       3.728824e+04     179564.232
# 43       5.773576e+05     593196.107
# 44       1.192961e+06    1053508.835
# 45       1.729262e+06    1520776.003
# 46       2.336693e+06    2076164.165
# 47       2.913846e+06    2731799.027
# 48       3.236966e+06    3179384.692
# 49       3.051902e+06    3301335.210

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 15ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
