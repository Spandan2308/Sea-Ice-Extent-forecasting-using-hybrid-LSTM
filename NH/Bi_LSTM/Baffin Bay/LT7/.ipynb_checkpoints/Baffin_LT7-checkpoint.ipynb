# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/N_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Baffin = pd.read_excel(filepath, sheet_name='Baffin-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/NH/')
import Function as fp

# %%
fp.month_mapping(Baffin)
fp.date_time(Baffin)
# Out:
#           Extent       Date
# 0    1090625.815 1979-01-01
# 1    1157634.866 1979-02-01
# 2    1299583.477 1979-03-01
# 3    1137194.680 1979-04-01
# 4     983083.453 1979-05-01
# ..           ...        ...
# 533   781460.891 2023-06-01
# 534   331845.048 2023-07-01
# 535    99334.625 2023-08-01
# 536    49359.723 2023-09-01
# 537    85693.282 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Baffin['Extent'] = scaler.fit_transform(Baffin['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 7
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Baffin['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((520, 12, 1), (520,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Baffin_model_LT7/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.1716 - root_mean_squared_error: 0.4142INFO:tensorflow:Assets written to: Baffin_model_LT7\assets
# 53/53 [==============================] - 35s 474ms/step - loss: 0.1716 - root_mean_squared_error: 0.4142 - val_loss: 0.0781 - val_root_mean_squared_error: 0.2794
# Epoch 2/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0736 - root_mean_squared_error: 0.2713INFO:tensorflow:Assets written to: Baffin_model_LT7\assets
# 53/53 [==============================] - 23s 446ms/step - loss: 0.0737 - root_mean_squared_error: 0.2715 - val_loss: 0.0648 - val_root_mean_squared_error: 0.2545
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0639 - root_mean_squared_error: 0.2527INFO:tensorflow:Assets written to: Baffin_model_LT7\assets
# 53/53 [==============================] - 24s 454ms/step - loss: 0.0639 - root_mean_squared_error: 0.2527 - val_loss: 0.0594 - val_root_mean_squared_error: 0.2437
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0569 - root_mean_squared_error: 0.2385INFO:tensorflow:Assets written to: Baffin_model_LT7\assets
# 53/53 [==============================] - 23s 445ms/step - loss: 0.0564 - root_mean_squared_error: 0.2374 - val_loss: 0.0477 - val_root_mean_squared_error: 0.2184
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0444 - root_mean_squared_error: 0.2108INFO:tensorflow:Assets written to: Baffin_model_LT7\assets
# 53/53 [==============================] - 24s 461ms/step - loss: 0.0445 - root_mean_squared_error: 0.2110 - val_loss: 0.0316 - val_root_mean_squared_error: 0.1778
# Epoch 6/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0289 - root_mean_squared_error: 0.1699INFO:tensorflow:Assets written to: Baffin_model_LT7\assets
# 53/53 [==============================] - 24s 453ms/step - loss: 0.0287 - root_mean_squared_error: 0.1695 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1216
# Epoch 7/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0162 - root_mean_squared_error: 0.1271INFO:tensorflow:Assets written to: Baffin_model_LT7\assets
# 53/53 [==============================] - 24s 453ms/step - loss: 0.0159 - root_mean_squared_error: 0.1260 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0899
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0107 - root_mean_squared_error: 0.1034INFO:tensorflow:Assets written to: Baffin_model_LT7\assets
# 53/53 [==============================] - 24s 452ms/step - loss: 0.0107 - root_mean_squared_error: 0.1034 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0743
# Epoch 9/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0091 - root_mean_squared_error: 0.0956INFO:tensorflow:Assets written to: Baffin_model_LT7\assets
# 53/53 [==============================] - 23s 441ms/step - loss: 0.0092 - root_mean_squared_error: 0.0957 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0591
# Epoch 10/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0081 - root_mean_squared_error: 0.0903INFO:tensorflow:Assets written to: Baffin_model_LT7\assets
# 53/53 [==============================] - 23s 441ms/step - loss: 0.0081 - root_mean_squared_error: 0.0900 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0504
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0081 - root_mean_squared_error: 0.0902INFO:tensorflow:Assets written to: Baffin_model_LT7\assets
# 53/53 [==============================] - 25s 488ms/step - loss: 0.0081 - root_mean_squared_error: 0.0900 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0467
# Epoch 12/50
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0084 - root_mean_squared_error: 0.0918 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0647
# Epoch 13/50
# 53/53 [==============================] - 2s 38ms/step - loss: 0.0078 - root_mean_squared_error: 0.0885 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0514
# Epoch 14/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0068 - root_mean_squared_error: 0.0826INFO:tensorflow:Assets written to: Baffin_model_LT7\assets
# 53/53 [==============================] - 28s 533ms/step - loss: 0.0068 - root_mean_squared_error: 0.0825 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0434
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0065 - root_mean_squared_error: 0.0806INFO:tensorflow:Assets written to: Baffin_model_LT7\assets
# 53/53 [==============================] - 28s 535ms/step - loss: 0.0065 - root_mean_squared_error: 0.0806 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0429
# Epoch 16/50
# 53/53 [==============================] - 2s 38ms/step - loss: 0.0074 - root_mean_squared_error: 0.0860 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0431
# Epoch 17/50
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0066 - root_mean_squared_error: 0.0812 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0486
# Epoch 18/50
# 53/53 [==============================] - 2s 43ms/step - loss: 0.0064 - root_mean_squared_error: 0.0802 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0438
# Epoch 19/50
# 53/53 [==============================] - 2s 42ms/step - loss: 0.0070 - root_mean_squared_error: 0.0839 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0429
# Epoch 20/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0066 - root_mean_squared_error: 0.0812INFO:tensorflow:Assets written to: Baffin_model_LT7\assets
# 53/53 [==============================] - 28s 542ms/step - loss: 0.0066 - root_mean_squared_error: 0.0812 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0428
# Epoch 21/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0066 - root_mean_squared_error: 0.0811 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0451
# Epoch 22/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0061 - root_mean_squared_error: 0.0780 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0434
# Epoch 23/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0062 - root_mean_squared_error: 0.0788 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0429
# Epoch 24/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0062 - root_mean_squared_error: 0.0788 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0438
# Epoch 25/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0063 - root_mean_squared_error: 0.0796 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0573
# Epoch 26/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0060 - root_mean_squared_error: 0.0777 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0449
# Epoch 27/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0062 - root_mean_squared_error: 0.0789 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0450
# Epoch 28/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0060 - root_mean_squared_error: 0.0772 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0514
# Epoch 29/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0063 - root_mean_squared_error: 0.0794 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0457
# Epoch 30/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0058 - root_mean_squared_error: 0.0761 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0454
# Epoch 31/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.0054 - root_mean_squared_error: 0.0733 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0470
# Epoch 32/50
# 53/53 [==============================] - 2s 47ms/step - loss: 0.0058 - root_mean_squared_error: 0.0761 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0470
# Epoch 33/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0057 - root_mean_squared_error: 0.0756 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0486
# Epoch 34/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0056 - root_mean_squared_error: 0.0751 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0479
# Epoch 35/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0062 - root_mean_squared_error: 0.0787 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0469
# Epoch 36/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0056 - root_mean_squared_error: 0.0745 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0454
# Epoch 37/50
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0050 - root_mean_squared_error: 0.0707 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0506
# Epoch 38/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0057 - root_mean_squared_error: 0.0757 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0471
# Epoch 39/50
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0056 - root_mean_squared_error: 0.0751 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0463
# Epoch 40/50
# 53/53 [==============================] - 2s 45ms/step - loss: 0.0056 - root_mean_squared_error: 0.0751 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0472
# Epoch 41/50
# 53/53 [==============================] - 2s 45ms/step - loss: 0.0059 - root_mean_squared_error: 0.0765 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0459
# Epoch 42/50
# 53/53 [==============================] - 2s 43ms/step - loss: 0.0054 - root_mean_squared_error: 0.0736 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0480
# Epoch 43/50
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0058 - root_mean_squared_error: 0.0759 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0480
# Epoch 44/50
# 53/53 [==============================] - 2s 42ms/step - loss: 0.0057 - root_mean_squared_error: 0.0752 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0457
# Epoch 45/50
# 53/53 [==============================] - 2s 42ms/step - loss: 0.0055 - root_mean_squared_error: 0.0741 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0473
# Epoch 46/50
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0057 - root_mean_squared_error: 0.0753 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0476
# Epoch 47/50
# 53/53 [==============================] - 2s 45ms/step - loss: 0.0056 - root_mean_squared_error: 0.0749 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0467
# Epoch 48/50
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0053 - root_mean_squared_error: 0.0730 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0504
# Epoch 49/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0056 - root_mean_squared_error: 0.0748 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0471
# Epoch 50/50
# 53/53 [==============================] - 2s 46ms/step - loss: 0.0055 - root_mean_squared_error: 0.0740 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0466

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 7.491890732447306 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Baffin_model_LT7/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 33ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.058681391385028765
# MAE : 0.047412641238544974

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        4.693651e+05     291275.949
# 1        8.357897e+05     678576.504
# 2        1.095799e+06     974461.347
# 3        1.204081e+06    1181121.087
# 4        1.191432e+06    1236299.254
# 5        1.088331e+06    1036981.003
# 6        9.191366e+05     847489.150
# 7        6.960816e+05     619129.338
# 8        3.501561e+05     195688.491
# 9        6.350508e+04      36670.811
# 10      -2.018006e+04      31777.310
# 11       1.314155e+05      82762.022
# 12       4.827822e+05     400043.823
# 13       8.235449e+05     733089.555
# 14       1.046493e+06     917362.266
# 15       1.144137e+06    1040584.040
# 16       1.159141e+06    1147997.675
# 17       1.090394e+06    1074255.327
# 18       9.379575e+05     875527.315
# 19       6.557772e+05     629820.756
# 20       3.055506e+05     204308.900
# 21       5.177014e+04      45059.062
# 22      -1.077484e+04      33770.277
# 23       1.741126e+05      64135.631
# 24       4.937604e+05     400581.715
# 25       7.953363e+05     698631.451
# 26       1.020891e+06     973313.225
# 27       1.118249e+06    1335339.087
# 28       1.131901e+06    1429096.704
# 29       1.064520e+06    1206542.314
# 30       9.199994e+05    1079292.433
# 31       6.611617e+05     788101.638
# 32       3.361162e+05     397326.270
# 33       6.276754e+04      97802.348
# 34      -1.369343e+04      62212.219
# 35       1.671665e+05     154051.600
# 36       5.295312e+05     610663.893
# 37       8.712890e+05     756679.164
# 38       1.131483e+06     962270.215
# 39       1.246255e+06    1235154.518
# 40       1.278412e+06    1161744.519
# 41       1.215940e+06    1136918.669
# 42       1.053582e+06     995852.026
# 43       7.007948e+05     781460.891
# 44       3.586482e+05     331845.048
# 45       9.541841e+04      99334.625
# 46      -8.127062e+03      49359.723
# 47       8.723965e+04      85693.282

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 26ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
