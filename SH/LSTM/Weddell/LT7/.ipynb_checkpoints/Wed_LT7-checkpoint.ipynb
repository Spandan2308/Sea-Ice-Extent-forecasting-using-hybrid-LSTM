# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import shuffle

from keras.models import Sequential
from keras.layers import InputLayer, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Weddell_Extent = pd.read_excel(filepath, sheet_name='Weddell-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Weddell_Extent)
fp.date_time(Weddell_Extent)
# Out:
#           Extent       Date
# 0    2136510.859 1979-01-01
# 1    1243495.891 1979-02-01
# 2    1699053.449 1979-03-01
# 3    2617442.085 1979-04-01
# 4    3852934.206 1979-05-01
# ..           ...        ...
# 533  3668127.143 2023-06-01
# 534  4805519.784 2023-07-01
# 535  5524445.234 2023-08-01
# 536  6006669.861 2023-09-01
# 537  5507961.583 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Weddell_Extent['Extent'] = scaler.fit_transform(Weddell_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 7
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Weddell_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((520, 12, 1), (520,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0)))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Weddell_model_LT7/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
import time

stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.3013 - root_mean_squared_error: 0.5489INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 12s 139ms/step - loss: 0.3013 - root_mean_squared_error: 0.5489 - val_loss: 0.2539 - val_root_mean_squared_error: 0.5039
# Epoch 2/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.1676 - root_mean_squared_error: 0.4095INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 6s 123ms/step - loss: 0.1656 - root_mean_squared_error: 0.4069 - val_loss: 0.0964 - val_root_mean_squared_error: 0.3104
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0923 - root_mean_squared_error: 0.3037INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 6s 119ms/step - loss: 0.0923 - root_mean_squared_error: 0.3038 - val_loss: 0.0859 - val_root_mean_squared_error: 0.2930
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0794 - root_mean_squared_error: 0.2817INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 129ms/step - loss: 0.0797 - root_mean_squared_error: 0.2823 - val_loss: 0.0742 - val_root_mean_squared_error: 0.2725
# Epoch 5/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0706 - root_mean_squared_error: 0.2657INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 125ms/step - loss: 0.0699 - root_mean_squared_error: 0.2643 - val_loss: 0.0615 - val_root_mean_squared_error: 0.2481
# Epoch 6/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0564 - root_mean_squared_error: 0.2374INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 126ms/step - loss: 0.0561 - root_mean_squared_error: 0.2368 - val_loss: 0.0491 - val_root_mean_squared_error: 0.2215
# Epoch 7/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0422 - root_mean_squared_error: 0.2055INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 132ms/step - loss: 0.0422 - root_mean_squared_error: 0.2054 - val_loss: 0.0321 - val_root_mean_squared_error: 0.1791
# Epoch 8/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0281 - root_mean_squared_error: 0.1676INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 6s 123ms/step - loss: 0.0276 - root_mean_squared_error: 0.1662 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1417
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0220 - root_mean_squared_error: 0.1485INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 135ms/step - loss: 0.0220 - root_mean_squared_error: 0.1485 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1275
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0196 - root_mean_squared_error: 0.1401INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 8s 145ms/step - loss: 0.0196 - root_mean_squared_error: 0.1401 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1250
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0179 - root_mean_squared_error: 0.1336INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 131ms/step - loss: 0.0178 - root_mean_squared_error: 0.1334 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1094
# Epoch 12/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0182 - root_mean_squared_error: 0.1350INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 135ms/step - loss: 0.0181 - root_mean_squared_error: 0.1347 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1077
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0163 - root_mean_squared_error: 0.1277INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 138ms/step - loss: 0.0163 - root_mean_squared_error: 0.1277 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1017
# Epoch 14/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0155 - root_mean_squared_error: 0.1243 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1027
# Epoch 15/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0139 - root_mean_squared_error: 0.1180INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 134ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1002
# Epoch 16/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0149 - root_mean_squared_error: 0.1220 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1018
# Epoch 17/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0129 - root_mean_squared_error: 0.1138INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 127ms/step - loss: 0.0130 - root_mean_squared_error: 0.1139 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0969
# Epoch 18/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0139 - root_mean_squared_error: 0.1180 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1145
# Epoch 19/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0993
# Epoch 20/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0125 - root_mean_squared_error: 0.1116INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 140ms/step - loss: 0.0125 - root_mean_squared_error: 0.1117 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0889
# Epoch 21/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0112 - root_mean_squared_error: 0.1058INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 139ms/step - loss: 0.0111 - root_mean_squared_error: 0.1056 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0819
# Epoch 22/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0100 - root_mean_squared_error: 0.1002 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1017
# Epoch 23/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0098 - root_mean_squared_error: 0.0989 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0881
# Epoch 24/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0115 - root_mean_squared_error: 0.1074 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0837
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0105 - root_mean_squared_error: 0.1025INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 132ms/step - loss: 0.0105 - root_mean_squared_error: 0.1025 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0795
# Epoch 26/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0102 - root_mean_squared_error: 0.1008 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0848
# Epoch 27/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0099 - root_mean_squared_error: 0.0996 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0799
# Epoch 28/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0090 - root_mean_squared_error: 0.0948INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 137ms/step - loss: 0.0089 - root_mean_squared_error: 0.0946 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0755
# Epoch 29/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0098 - root_mean_squared_error: 0.0989INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 8s 144ms/step - loss: 0.0097 - root_mean_squared_error: 0.0985 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0745
# Epoch 30/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0092 - root_mean_squared_error: 0.0958 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0751
# Epoch 31/50
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0097 - root_mean_squared_error: 0.0986 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0746
# Epoch 32/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0092 - root_mean_squared_error: 0.0957INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 136ms/step - loss: 0.0092 - root_mean_squared_error: 0.0957 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0720
# Epoch 33/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0081 - root_mean_squared_error: 0.0900 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0794
# Epoch 34/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0091 - root_mean_squared_error: 0.0954INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 138ms/step - loss: 0.0092 - root_mean_squared_error: 0.0958 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0703
# Epoch 35/50
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0079 - root_mean_squared_error: 0.0886 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0760
# Epoch 36/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0079 - root_mean_squared_error: 0.0892 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0814
# Epoch 37/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0093 - root_mean_squared_error: 0.0967 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0812
# Epoch 38/50
# 53/53 [==============================] - 1s 28ms/step - loss: 0.0079 - root_mean_squared_error: 0.0890 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0841
# Epoch 39/50
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0079 - root_mean_squared_error: 0.0890 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0743
# Epoch 40/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0084 - root_mean_squared_error: 0.0915 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0719
# Epoch 41/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0073 - root_mean_squared_error: 0.0852 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0733
# Epoch 42/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0074 - root_mean_squared_error: 0.0858INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 141ms/step - loss: 0.0074 - root_mean_squared_error: 0.0858 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0688
# Epoch 43/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0080 - root_mean_squared_error: 0.0893 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0716
# Epoch 44/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0078 - root_mean_squared_error: 0.0883 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0759
# Epoch 45/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0078 - root_mean_squared_error: 0.0882 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0719
# Epoch 46/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0906INFO:tensorflow:Assets written to: Weddell_model_LT7\assets
# 53/53 [==============================] - 7s 134ms/step - loss: 0.0081 - root_mean_squared_error: 0.0901 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0669
# Epoch 47/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0072 - root_mean_squared_error: 0.0847 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0725
# Epoch 48/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0073 - root_mean_squared_error: 0.0857 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0894
# Epoch 49/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0072 - root_mean_squared_error: 0.0851 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0728
# Epoch 50/50
# 53/53 [==============================] - 1s 25ms/step - loss: 0.0082 - root_mean_squared_error: 0.0905 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0768

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 3.4198224703470865 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Weddell_model_LT7/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 11ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.06752026229981659
# MAE : 0.05375537276050372

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        5.442697e+06    5902163.675
# 1        3.939948e+06    3498103.449
# 2        2.439786e+06    1633675.726
# 3        1.546567e+06    1292668.399
# 4        1.331780e+06    1527666.815
# 5        2.133322e+06    2121949.701
# 6        3.677122e+06    3562381.775
# 7        4.899798e+06    5004305.983
# 8        5.664768e+06    6176613.878
# 9        6.075006e+06    6794233.093
# 10       6.327906e+06    7024136.637
# 11       6.232583e+06    6554271.388
# 12       5.503310e+06    6172281.701
# 13       3.645136e+06    4175225.799
# 14       2.014149e+06    1748380.899
# 15       1.161288e+06    1256191.080
# 16       9.633439e+05    1347295.364
# 17       1.940881e+06    2180184.677
# 18       3.788636e+06    3419295.982
# 19       5.172508e+06    4786146.771
# 20       5.989186e+06    5968132.718
# 21       6.427398e+06    6556934.174
# 22       6.684312e+06    6614949.980
# 23       6.555682e+06    6035207.368
# 24       5.407999e+06    5274244.730
# 25       3.467356e+06    3505146.372
# 26       1.924296e+06    1478130.228
# 27       1.115228e+06    1096780.503
# 28       8.539476e+05    1387234.069
# 29       1.705153e+06    2128693.591
# 30       3.422179e+06    3313318.704
# 31       4.816248e+06    4218076.656
# 32       5.769246e+06    5257641.941
# 33       6.111454e+06    5956603.340
# 34       6.283001e+06    6256062.049
# 35       6.115604e+06    5974548.305
# 36       5.117984e+06    5569396.731
# 37       3.323658e+06    3684108.410
# 38       1.900175e+06    1451614.707
# 39       1.228500e+06    1089888.684
# 40       1.224328e+06    1255222.909
# 41       2.346148e+06    1704492.279
# 42       3.773213e+06    2563551.804
# 43       4.820102e+06    3668127.143
# 44       5.542168e+06    4805519.784
# 45       5.905818e+06    5524445.234
# 46       6.129279e+06    6006669.861
# 47       6.017358e+06    5507961.583

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 0s 11ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
