# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from keras.models import Sequential
from keras.layers import InputLayer, Bidirectional, LSTM, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.constraints import MaxNorm
from keras.callbacks import ModelCheckpoint

import time

# %%
filepath = 'C:/Users/ss230/Documents/Study/NSIDC/Edited Data/S_Sea_Ice_Index_Regional_Monthly_Data_G02135_v3.0.xlsx'
Weddell_Extent = pd.read_excel(filepath, sheet_name='Weddell-Extent-km^2')

# %%
import sys
sys.path.append('C:/Users/ss230/Documents/Study/NSIDC/SH/Bi_LSTM_Extent/')
import Function as fp

# %%
fp.month_mapping(Weddell_Extent)
fp.date_time(Weddell_Extent)
# Out:
#           Extent       Date
# 0    2136510.859 1979-01-01
# 1    1243495.891 1979-02-01
# 2    1699053.449 1979-03-01
# 3    2617442.085 1979-04-01
# 4    3852934.206 1979-05-01
# ..           ...        ...
# 533  3668127.143 2023-06-01
# 534  4805519.784 2023-07-01
# 535  5524445.234 2023-08-01
# 536  6006669.861 2023-09-01
# 537  5507961.583 2023-10-01
#
# [538 rows x 2 columns]

# %%
scaler = MinMaxScaler()
Weddell_Extent['Extent'] = scaler.fit_transform(Weddell_Extent['Extent'].values.reshape(-1, 1))

# %%
def df_to_X_y(df, window_size):
    df_as_np = df.to_numpy()
    X = []
    y = []
    lead_time = 12
    for i in range(len(df_as_np) - window_size - lead_time + 1):
        window_data = df_as_np[i:i+window_size]
        row = [[a] for a in window_data]
        X.append(row)
        label = df_as_np[i+window_size+lead_time-1]
        y.append(label)
    return np.array(X), np.array(y)

# %%
extent = Weddell_Extent['Extent']
W_S=12
X,y = df_to_X_y(extent, W_S)
X.shape, y.shape
# Out:
# ((515, 12, 1), (515,))

# %%
X_train, y_train = X[:420], y[:420]
X_val, y_val = X[420:472], y[420:472]
X_test, y_test = X[472:], y[472:]

# %%
model = Sequential()
model.add(InputLayer((W_S, 1)))
model.add(Bidirectional(LSTM(128, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64, activation='relu', kernel_constraint=MaxNorm(1.0), return_sequences=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32, activation='relu', kernel_constraint=MaxNorm(1.0))))
model.add(Dense(1, activation='linear'))

cp = ModelCheckpoint('Weddell_model_LT12/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(0.0001), metrics=[RootMeanSquaredError()])

# %%
stime = time.time()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=8, callbacks=[cp])
etime = time.time()
# Out:
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.2467 - root_mean_squared_error: 0.4967INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 38s 508ms/step - loss: 0.2467 - root_mean_squared_error: 0.4967 - val_loss: 0.1201 - val_root_mean_squared_error: 0.3466
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0989 - root_mean_squared_error: 0.3145INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 25s 474ms/step - loss: 0.0989 - root_mean_squared_error: 0.3145 - val_loss: 0.0921 - val_root_mean_squared_error: 0.3035
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0847 - root_mean_squared_error: 0.2910INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 24s 470ms/step - loss: 0.0841 - root_mean_squared_error: 0.2900 - val_loss: 0.0871 - val_root_mean_squared_error: 0.2952
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0693 - root_mean_squared_error: 0.2632INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 25s 487ms/step - loss: 0.0693 - root_mean_squared_error: 0.2632 - val_loss: 0.0697 - val_root_mean_squared_error: 0.2640
# Epoch 5/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0490 - root_mean_squared_error: 0.2214INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 26s 491ms/step - loss: 0.0492 - root_mean_squared_error: 0.2217 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2037
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0299 - root_mean_squared_error: 0.1728INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 26s 507ms/step - loss: 0.0299 - root_mean_squared_error: 0.1728 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1394
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0160 - root_mean_squared_error: 0.1265INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 26s 502ms/step - loss: 0.0160 - root_mean_squared_error: 0.1265 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1143
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0114 - root_mean_squared_error: 0.1068INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 26s 501ms/step - loss: 0.0114 - root_mean_squared_error: 0.1068 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1007
# Epoch 9/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1021
# Epoch 10/50
# 53/53 [==============================] - 3s 55ms/step - loss: 0.0108 - root_mean_squared_error: 0.1039 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0118 - root_mean_squared_error: 0.1084INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 25s 487ms/step - loss: 0.0118 - root_mean_squared_error: 0.1084 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0807
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0110 - root_mean_squared_error: 0.1049INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 26s 491ms/step - loss: 0.0110 - root_mean_squared_error: 0.1049 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0767
# Epoch 13/50
# 53/53 [==============================] - 2s 46ms/step - loss: 0.0098 - root_mean_squared_error: 0.0990 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0941
# Epoch 14/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0090 - root_mean_squared_error: 0.0949 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0825
# Epoch 15/50
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0086 - root_mean_squared_error: 0.0929 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0953
# Epoch 16/50
# 53/53 [==============================] - 3s 65ms/step - loss: 0.0081 - root_mean_squared_error: 0.0902 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1120
# Epoch 17/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0087 - root_mean_squared_error: 0.0933 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0821
# Epoch 18/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0074 - root_mean_squared_error: 0.0859 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0898
# Epoch 19/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0080 - root_mean_squared_error: 0.0893 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0886
# Epoch 20/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0074 - root_mean_squared_error: 0.0861 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0911
# Epoch 21/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0073 - root_mean_squared_error: 0.0854 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0776
# Epoch 22/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0070 - root_mean_squared_error: 0.0837 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0843
# Epoch 23/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0065 - root_mean_squared_error: 0.0809INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 26s 491ms/step - loss: 0.0065 - root_mean_squared_error: 0.0809 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0666
# Epoch 24/50
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0067 - root_mean_squared_error: 0.0821 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0733
# Epoch 25/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0064 - root_mean_squared_error: 0.0801 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0780
# Epoch 26/50
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0069 - root_mean_squared_error: 0.0831 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0678
# Epoch 27/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0065 - root_mean_squared_error: 0.0804 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679
# Epoch 28/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0070 - root_mean_squared_error: 0.0837 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0672
# Epoch 29/50
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0066 - root_mean_squared_error: 0.0815 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0723
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0055 - root_mean_squared_error: 0.0740INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 26s 495ms/step - loss: 0.0055 - root_mean_squared_error: 0.0740 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0634
# Epoch 31/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0063 - root_mean_squared_error: 0.0796 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0765
# Epoch 32/50
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0054 - root_mean_squared_error: 0.0738 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0794
# Epoch 33/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0060 - root_mean_squared_error: 0.0771 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0934
# Epoch 34/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0059 - root_mean_squared_error: 0.0768 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0727
# Epoch 35/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0054 - root_mean_squared_error: 0.0732INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 26s 491ms/step - loss: 0.0054 - root_mean_squared_error: 0.0736 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0629
# Epoch 36/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0049 - root_mean_squared_error: 0.0702 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0773
# Epoch 37/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0050 - root_mean_squared_error: 0.0707 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0746
# Epoch 38/50
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0056 - root_mean_squared_error: 0.0749 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 39/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0058 - root_mean_squared_error: 0.0764 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0715
# Epoch 40/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0051 - root_mean_squared_error: 0.0717INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 26s 501ms/step - loss: 0.0051 - root_mean_squared_error: 0.0717 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0615
# Epoch 41/50
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0052 - root_mean_squared_error: 0.0724 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0759
# Epoch 42/50
# 53/53 [==============================] - 3s 66ms/step - loss: 0.0044 - root_mean_squared_error: 0.0663 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1046
# Epoch 43/50
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0047 - root_mean_squared_error: 0.0685 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0630
# Epoch 44/50
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0050 - root_mean_squared_error: 0.0708 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0736
# Epoch 45/50
# 53/53 [==============================] - 4s 68ms/step - loss: 0.0051 - root_mean_squared_error: 0.0716 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1010
# Epoch 46/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0061 - root_mean_squared_error: 0.0783INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 26s 501ms/step - loss: 0.0061 - root_mean_squared_error: 0.0783 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610
# Epoch 47/50
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0050 - root_mean_squared_error: 0.0709 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0859
# Epoch 48/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0053 - root_mean_squared_error: 0.0728 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0683
# Epoch 49/50
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0052 - root_mean_squared_error: 0.0720 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0753
# Epoch 50/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0046 - root_mean_squared_error: 0.0675INFO:tensorflow:Assets written to: Weddell_model_LT12\assets
# 53/53 [==============================] - 27s 511ms/step - loss: 0.0046 - root_mean_squared_error: 0.0675 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0607

# %%
time = (etime - stime)/60
print(f'{time} minutes')
# Out:
# 8.927415498097737 minutes

# %%
loss = history.history['loss']
epochs = list(range(1, len(loss) + 1))

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, label='Training Loss', marker='o', linestyle='-')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.show()

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

plt.figure(figsize=(15,6))
plt.plot(epochs, training_loss, label='Training Loss', marker='o', linestyle='-')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='s', linestyle='--')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('Weddell_model_LT12/')

# %%
test_predictions = model1.predict(X_test)
# Out:
# 2/2 [==============================] - 2s 23ms/step

# %%
mse = mean_squared_error(y_test, test_predictions)
print('RMSE :', np.sqrt(mse))

mae = mean_absolute_error(y_test, test_predictions)
print('MAE :', mae)
# Out:
# RMSE : 0.059393613049794534
# MAE : 0.04792856672412556

# %%
test_predictions = scaler.inverse_transform(test_predictions)
test_original = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
train_results = pd.DataFrame(data={'Train Predictions': test_predictions.flatten(), 'Actual Extent': test_original.flatten()})
train_results
# Out:
#     Train Predictions  Actual Extent
# 0        1.940741e+06    2121949.701
# 1        3.239200e+06    3562381.775
# 2        4.660320e+06    5004305.983
# 3        5.621756e+06    6176613.878
# 4        6.235633e+06    6794233.093
# 5        6.508405e+06    7024136.637
# 6        6.365451e+06    6554271.388
# 7        5.772184e+06    6172281.701
# 8        3.931054e+06    4175225.799
# 9        1.900187e+06    1748380.899
# 10       1.083719e+06    1256191.080
# 11       1.176891e+06    1347295.364
# 12       1.960308e+06    2180184.677
# 13       3.648002e+06    3419295.982
# 14       4.942659e+06    4786146.771
# 15       5.887112e+06    5968132.718
# 16       6.428010e+06    6556934.174
# 17       6.706732e+06    6614949.980
# 18       6.482592e+06    6035207.368
# 19       5.791614e+06    5274244.730
# 20       3.800695e+06    3505146.372
# 21       1.624901e+06    1478130.228
# 22       9.499815e+05    1096780.503
# 23       1.093255e+06    1387234.069
# 24       1.923793e+06    2128693.591
# 25       3.499980e+06    3313318.704
# 26       4.826338e+06    4218076.656
# 27       5.788149e+06    5257641.941
# 28       6.337426e+06    5956603.340
# 29       6.571888e+06    6256062.049
# 30       6.330594e+06    5974548.305
# 31       5.704996e+06    5569396.731
# 32       3.669420e+06    3684108.410
# 33       1.639206e+06    1451614.707
# 34       1.024760e+06    1089888.684
# 35       1.260112e+06    1255222.909
# 36       2.138305e+06    1704492.279
# 37       3.665256e+06    2563551.804
# 38       4.736378e+06    3668127.143
# 39       5.497229e+06    4805519.784
# 40       5.988510e+06    5524445.234
# 41       6.206620e+06    6006669.861
# 42       6.082054e+06    5507961.583

# %%
plt.figure(figsize=(15,6))
plt.plot(test_original, label='True Values')
plt.plot(test_predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()

# %%
predictions = model1.predict(X)
# Out:
# 17/17 [==============================] - 1s 30ms/step

# %%
predictions = scaler.inverse_transform(predictions)
Original = scaler.inverse_transform(y.reshape(-1,1))

# %%
plt.figure(figsize=(15,6))
plt.plot(Original, label='True Values')
plt.plot(predictions, label='Predicted Values')
plt.title('Test Predictions vs Original Test Data')
plt.legend()
plt.show()
